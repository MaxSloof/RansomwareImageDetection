# %% [markdown]
# # DenseNet

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/misc_experiments"
    for files in os.listdir(dir):
        if "densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: densenet-binary-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 2 matches(es) found
# --------------
# New folder name: densenet-binary-local-v003
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/bin_class"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 2 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = tf.keras.applications.densenet.preprocess_input(imgs)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # DenseNet
# We will now build our **DenseNet169** model using Tensorflow/Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3
#
# Nota bene that the DenseNet only takes RGB images (with 3 channels)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  2

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Build the DenseNet model
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    # Add the classification layers for this dataset
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'sigmoid')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    
    # Run the CNN
    history.append(
        head_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
     # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    
    # Save the binary data distribution
    bn_count.append(len(y_true2) - np.sum(y_true2))
    rw_count.append(np.sum(y_true2))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_true2, y_pred2)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_f1_per_fold.append(f1_score(y_true2, y_pred2, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_true2, y_pred2))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/40
# 747/747 [==============================] - 105s 121ms/step - loss: 0.1497 - accuracy: 0.9553 - val_loss: 0.9846 - val_accuracy: 0.5382
#
# Epoch 00001: val_loss improved from inf to 0.98462, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 2/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0806 - accuracy: 0.9727 - val_loss: 0.0643 - val_accuracy: 0.9797
#
# Epoch 00002: val_loss improved from 0.98462 to 0.06430, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 3/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0549 - accuracy: 0.9814 - val_loss: 0.1022 - val_accuracy: 0.9684
#
# Epoch 00003: val_loss did not improve from 0.06430
# Epoch 4/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0456 - accuracy: 0.9840 - val_loss: 0.0556 - val_accuracy: 0.9846
#
# Epoch 00004: val_loss improved from 0.06430 to 0.05562, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0676 - accuracy: 0.9796 - val_loss: 654.9050 - val_accuracy: 0.4938
#
# Epoch 00005: val_loss did not improve from 0.05562
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0802 - accuracy: 0.9740 - val_loss: 0.0629 - val_accuracy: 0.9797
#
# Epoch 00006: val_loss did not improve from 0.05562
# Epoch 7/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0435 - accuracy: 0.9842 - val_loss: 0.0445 - val_accuracy: 0.9876
#
# Epoch 00007: val_loss improved from 0.05562 to 0.04453, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0360 - accuracy: 0.9873 - val_loss: 0.0419 - val_accuracy: 0.9868
#
# Epoch 00008: val_loss improved from 0.04453 to 0.04190, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 9/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0401 - accuracy: 0.9871 - val_loss: 0.0430 - val_accuracy: 0.9842
#
# Epoch 00009: val_loss did not improve from 0.04190
# Epoch 10/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0311 - accuracy: 0.9892 - val_loss: 0.0359 - val_accuracy: 0.9876
#
# Epoch 00010: val_loss improved from 0.04190 to 0.03592, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 11/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0294 - accuracy: 0.9897 - val_loss: 0.0551 - val_accuracy: 0.9864
#
# Epoch 00011: val_loss did not improve from 0.03592
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0316 - accuracy: 0.9887 - val_loss: 0.0502 - val_accuracy: 0.9815
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00012: val_loss did not improve from 0.03592
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 0.0364 - val_accuracy: 0.9898
#
# Epoch 00013: val_loss did not improve from 0.03592
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0156 - accuracy: 0.9951 - val_loss: 0.0294 - val_accuracy: 0.9913
#
# Epoch 00014: val_loss improved from 0.03592 to 0.02940, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 15/40
# 747/747 [==============================] - 89s 118ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0361 - val_accuracy: 0.9917
#
# Epoch 00015: val_loss did not improve from 0.02940
# Epoch 16/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0109 - accuracy: 0.9954 - val_loss: 0.0375 - val_accuracy: 0.9876
#
# Epoch 00016: val_loss did not improve from 0.02940
# Epoch 17/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0109 - accuracy: 0.9959 - val_loss: 0.0360 - val_accuracy: 0.9902
#
# Epoch 00017: val_loss did not improve from 0.02940
# Epoch 18/40
# 747/747 [==============================] - 89s 119ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0427 - val_accuracy: 0.9906
#
# Epoch 00018: val_loss did not improve from 0.02940
# Epoch 19/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0309 - val_accuracy: 0.9879
#
# Epoch 00019: val_loss did not improve from 0.02940
# Epoch 20/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0375 - val_accuracy: 0.9879
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss did not improve from 0.02940
# Epoch 21/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0400 - val_accuracy: 0.9910
#
# Epoch 00021: val_loss did not improve from 0.02940
# Epoch 22/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0430 - val_accuracy: 0.9917
#
# Epoch 00022: val_loss did not improve from 0.02940
# Epoch 23/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0396 - val_accuracy: 0.9917
#
# Epoch 00023: val_loss did not improve from 0.02940
# Epoch 24/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0614 - val_accuracy: 0.9902
#
# Epoch 00024: val_loss did not improve from 0.02940
# Epoch 25/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0629 - val_accuracy: 0.9879
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_loss did not improve from 0.02940
# Epoch 26/40
# 747/747 [==============================] - 86s 114ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0496 - val_accuracy: 0.9913
#
# Epoch 00026: val_loss did not improve from 0.02940
# Epoch 27/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.8878e-04 - accuracy: 0.9999 - val_loss: 0.0485 - val_accuracy: 0.9910
#
# Epoch 00027: val_loss did not improve from 0.02940
# Epoch 28/40
# 747/747 [==============================] - 86s 115ms/step - loss: 1.3930e-04 - accuracy: 0.9999 - val_loss: 0.0594 - val_accuracy: 0.9906
#
# Epoch 00028: val_loss did not improve from 0.02940
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 6.6961e-04 - accuracy: 0.9999 - val_loss: 0.0581 - val_accuracy: 0.9913
#
# Epoch 00029: val_loss did not improve from 0.02940
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0560 - val_accuracy: 0.9898
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00030: val_loss did not improve from 0.02940
# Epoch 31/40
# 747/747 [==============================] - 87s 117ms/step - loss: 5.1262e-04 - accuracy: 0.9998 - val_loss: 0.0634 - val_accuracy: 0.9906
#
# Epoch 00031: val_loss did not improve from 0.02940
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 1.2610e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9906
#
# Epoch 00032: val_loss did not improve from 0.02940
# Epoch 33/40
# 747/747 [==============================] - 85s 114ms/step - loss: 1.3422e-04 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9902
#
# Epoch 00033: val_loss did not improve from 0.02940
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 6.5411e-04 - accuracy: 0.9997 - val_loss: 0.0640 - val_accuracy: 0.9917
#
# Epoch 00034: val_loss did not improve from 0.02940
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 1.8383e-04 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9902
#
# Epoch 00035: val_loss did not improve from 0.02940
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 2.6670e-04 - accuracy: 0.9999 - val_loss: 0.0602 - val_accuracy: 0.9917
#
# Epoch 00036: val_loss did not improve from 0.02940
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 6.0383e-04 - accuracy: 0.9998 - val_loss: 0.0636 - val_accuracy: 0.9910
#
# Epoch 00037: val_loss did not improve from 0.02940
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 4.0659e-04 - accuracy: 0.9999 - val_loss: 0.0641 - val_accuracy: 0.9913
#
# Epoch 00038: val_loss did not improve from 0.02940
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.8614e-05 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9917
#
# Epoch 00039: val_loss did not improve from 0.02940
# Epoch 40/40
# 747/747 [==============================] - 85s 114ms/step - loss: 5.3352e-04 - accuracy: 0.9998 - val_loss: 0.0694 - val_accuracy: 0.9910
#
# Epoch 00040: val_loss did not improve from 0.02940
# Score for fold 1: loss of 0.06941647082567215; accuracy of 99.09604787826538%
# Epoch 1/40
# 747/747 [==============================] - 99s 117ms/step - loss: 0.1601 - accuracy: 0.9566 - val_loss: 0.0659 - val_accuracy: 0.9748
#
# Epoch 00001: val_loss did not improve from 0.02940
# Epoch 2/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0622 - accuracy: 0.9779 - val_loss: 0.0566 - val_accuracy: 0.9812
#
# Epoch 00002: val_loss did not improve from 0.02940
# Epoch 3/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0485 - accuracy: 0.9839 - val_loss: 0.0525 - val_accuracy: 0.9800
#
# Epoch 00003: val_loss did not improve from 0.02940
# Epoch 4/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0893 - accuracy: 0.9764 - val_loss: 282773.3125 - val_accuracy: 0.5360
#
# Epoch 00004: val_loss did not improve from 0.02940
# Epoch 5/40
# 747/747 [==============================] - 88s 118ms/step - loss: 0.0972 - accuracy: 0.9675 - val_loss: 0.0606 - val_accuracy: 0.9766
#
# Epoch 00005: val_loss did not improve from 0.02940
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0628 - accuracy: 0.9798 - val_loss: 0.0698 - val_accuracy: 0.9748
#
# Epoch 00006: val_loss did not improve from 0.02940
# Epoch 7/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0449 - accuracy: 0.9845 - val_loss: 0.0536 - val_accuracy: 0.9849
#
# Epoch 00007: val_loss did not improve from 0.02940
# Epoch 8/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0472 - accuracy: 0.9839 - val_loss: 0.0420 - val_accuracy: 0.9864
#
# Epoch 00008: val_loss did not improve from 0.02940
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0407 - accuracy: 0.9849 - val_loss: 0.0601 - val_accuracy: 0.9804
#
# Epoch 00009: val_loss did not improve from 0.02940
# Epoch 10/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0301 - accuracy: 0.9889 - val_loss: 0.0455 - val_accuracy: 0.9861
#
# Epoch 00010: val_loss did not improve from 0.02940
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0295 - accuracy: 0.9893 - val_loss: 0.0486 - val_accuracy: 0.9819
#
# Epoch 00011: val_loss did not improve from 0.02940
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.0408 - val_accuracy: 0.9879
#
# Epoch 00012: val_loss did not improve from 0.02940
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0416 - accuracy: 0.9861 - val_loss: 0.0423 - val_accuracy: 0.9842
#
# Epoch 00013: val_loss did not improve from 0.02940
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0226 - accuracy: 0.9922 - val_loss: 0.0495 - val_accuracy: 0.9857
#
# Epoch 00014: val_loss did not improve from 0.02940
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0237 - accuracy: 0.9914 - val_loss: 0.0360 - val_accuracy: 0.9879
#
# Epoch 00015: val_loss did not improve from 0.02940
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0200 - accuracy: 0.9924 - val_loss: 0.0452 - val_accuracy: 0.9838
#
# Epoch 00016: val_loss did not improve from 0.02940
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 0.0496 - val_accuracy: 0.9879
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.02940
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0452 - val_accuracy: 0.9868
#
# Epoch 00018: val_loss did not improve from 0.02940
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0542 - val_accuracy: 0.9868
#
# Epoch 00019: val_loss did not improve from 0.02940
# Epoch 20/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0386 - val_accuracy: 0.9883
#
# Epoch 00020: val_loss did not improve from 0.02940
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0069 - accuracy: 0.9973 - val_loss: 0.0431 - val_accuracy: 0.9891
#
# Epoch 00021: val_loss did not improve from 0.02940
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0572 - val_accuracy: 0.9868
#
# Epoch 00022: val_loss did not improve from 0.02940
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0489 - val_accuracy: 0.9895
#
# Epoch 00023: val_loss did not improve from 0.02940
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0463 - val_accuracy: 0.9898
#
# Epoch 00024: val_loss did not improve from 0.02940
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0446 - val_accuracy: 0.9898
#
# Epoch 00025: val_loss did not improve from 0.02940
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0433 - val_accuracy: 0.9883
#
# Epoch 00026: val_loss did not improve from 0.02940
# Epoch 27/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0500 - val_accuracy: 0.9902
#
# Epoch 00027: val_loss did not improve from 0.02940
# Epoch 28/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0654 - val_accuracy: 0.9879
#
# Epoch 00028: val_loss did not improve from 0.02940
# Epoch 29/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0669 - val_accuracy: 0.9834
#
# Epoch 00029: val_loss did not improve from 0.02940
# Epoch 30/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0538 - val_accuracy: 0.9883
#
# Epoch 00030: val_loss did not improve from 0.02940
# Epoch 31/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.0453 - val_accuracy: 0.9891
#
# Epoch 00031: val_loss did not improve from 0.02940
# Epoch 32/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0654 - val_accuracy: 0.9872
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.02940
# Epoch 33/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0655 - val_accuracy: 0.9883
#
# Epoch 00033: val_loss did not improve from 0.02940
# Epoch 34/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0676 - val_accuracy: 0.9891
#
# Epoch 00034: val_loss did not improve from 0.02940
# Epoch 35/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.1778e-04 - accuracy: 0.9999 - val_loss: 0.0741 - val_accuracy: 0.9895
#
# Epoch 00035: val_loss did not improve from 0.02940
# Epoch 36/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0646 - val_accuracy: 0.9887
#
# Epoch 00036: val_loss did not improve from 0.02940
# Epoch 37/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0514 - val_accuracy: 0.9895
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00037: val_loss did not improve from 0.02940
# Epoch 38/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.6373e-04 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9902
#
# Epoch 00038: val_loss did not improve from 0.02940
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 1.9598e-04 - accuracy: 0.9999 - val_loss: 0.0637 - val_accuracy: 0.9895
#
# Epoch 00039: val_loss did not improve from 0.02940
# Epoch 40/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.8892e-05 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9902
#
# Epoch 00040: val_loss did not improve from 0.02940
# Score for fold 2: loss of 0.06642088294029236; accuracy of 99.02071356773376%
# Epoch 1/40
# 747/747 [==============================] - 99s 116ms/step - loss: 0.1729 - accuracy: 0.9603 - val_loss: 0.0436 - val_accuracy: 0.9808
#
# Epoch 00001: val_loss did not improve from 0.02940
# Epoch 2/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0565 - accuracy: 0.9802 - val_loss: 0.0470 - val_accuracy: 0.9823
#
# Epoch 00002: val_loss did not improve from 0.02940
# Epoch 3/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0478 - accuracy: 0.9830 - val_loss: 0.0484 - val_accuracy: 0.9857
#
# Epoch 00003: val_loss did not improve from 0.02940
# Epoch 4/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0495 - accuracy: 0.9828 - val_loss: 0.0429 - val_accuracy: 0.9883
#
# Epoch 00004: val_loss did not improve from 0.02940
# Epoch 5/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0495 - accuracy: 0.9826 - val_loss: 1.4809 - val_accuracy: 0.7337
#
# Epoch 00005: val_loss did not improve from 0.02940
# Epoch 6/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0638 - accuracy: 0.9784 - val_loss: 0.0524 - val_accuracy: 0.9838
#
# Epoch 00006: val_loss did not improve from 0.02940
# Epoch 7/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0416 - accuracy: 0.9857 - val_loss: 0.0310 - val_accuracy: 0.9879
#
# Epoch 00007: val_loss did not improve from 0.02940
# Epoch 8/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0295 - accuracy: 0.9900 - val_loss: 0.6873 - val_accuracy: 0.8836
#
# Epoch 00008: val_loss did not improve from 0.02940
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0284 - accuracy: 0.9899 - val_loss: 0.0355 - val_accuracy: 0.9883
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.02940
# Epoch 10/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0287 - val_accuracy: 0.9928
#
# Epoch 00010: val_loss improved from 0.02940 to 0.02865, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0302 - val_accuracy: 0.9921
#
# Epoch 00011: val_loss did not improve from 0.02865
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0410 - val_accuracy: 0.9872
#
# Epoch 00012: val_loss did not improve from 0.02865
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.0294 - val_accuracy: 0.9917
#
# Epoch 00013: val_loss did not improve from 0.02865
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0315 - val_accuracy: 0.9902
#
# Epoch 00014: val_loss did not improve from 0.02865
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.0419 - val_accuracy: 0.9887
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00015: val_loss did not improve from 0.02865
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0239 - val_accuracy: 0.9940
#
# Epoch 00016: val_loss improved from 0.02865 to 0.02389, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0288 - val_accuracy: 0.9947
#
# Epoch 00017: val_loss did not improve from 0.02389
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0355 - val_accuracy: 0.9936
#
# Epoch 00018: val_loss did not improve from 0.02389
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0347 - val_accuracy: 0.9936
#
# Epoch 00019: val_loss did not improve from 0.02389
# Epoch 20/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0359 - val_accuracy: 0.9921
#
# Epoch 00020: val_loss did not improve from 0.02389
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0393 - val_accuracy: 0.9921
#
# Epoch 00021: val_loss did not improve from 0.02389
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0436 - val_accuracy: 0.9906
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00022: val_loss did not improve from 0.02389
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0411 - val_accuracy: 0.9906
#
# Epoch 00023: val_loss did not improve from 0.02389
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0421 - val_accuracy: 0.9921
#
# Epoch 00024: val_loss did not improve from 0.02389
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.1735e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9932
#
# Epoch 00025: val_loss did not improve from 0.02389
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 5.1483e-04 - accuracy: 0.9997 - val_loss: 0.0482 - val_accuracy: 0.9932
#
# Epoch 00026: val_loss did not improve from 0.02389
# Epoch 27/40
# 747/747 [==============================] - 85s 114ms/step - loss: 4.1988e-04 - accuracy: 0.9998 - val_loss: 0.0448 - val_accuracy: 0.9940
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00027: val_loss did not improve from 0.02389
# Epoch 28/40
# 747/747 [==============================] - 85s 114ms/step - loss: 9.1004e-04 - accuracy: 0.9999 - val_loss: 0.0516 - val_accuracy: 0.9913
#
# Epoch 00028: val_loss did not improve from 0.02389
# Epoch 29/40
# 747/747 [==============================] - 85s 114ms/step - loss: 4.9534e-04 - accuracy: 0.9999 - val_loss: 0.0509 - val_accuracy: 0.9921
#
# Epoch 00029: val_loss did not improve from 0.02389
# Epoch 30/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.8349e-04 - accuracy: 0.9999 - val_loss: 0.0570 - val_accuracy: 0.9917
#
# Epoch 00030: val_loss did not improve from 0.02389
# Epoch 31/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.8311e-04 - accuracy: 0.9999 - val_loss: 0.0573 - val_accuracy: 0.9925
#
# Epoch 00031: val_loss did not improve from 0.02389
# Epoch 32/40
# 747/747 [==============================] - 85s 114ms/step - loss: 5.3781e-04 - accuracy: 0.9998 - val_loss: 0.0461 - val_accuracy: 0.9925
#
# Epoch 00032: val_loss did not improve from 0.02389
# Epoch 33/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.8344e-04 - accuracy: 0.9999 - val_loss: 0.0518 - val_accuracy: 0.9932
#
# Epoch 00033: val_loss did not improve from 0.02389
# Epoch 34/40
# 747/747 [==============================] - 85s 114ms/step - loss: 9.3291e-04 - accuracy: 0.9998 - val_loss: 0.0473 - val_accuracy: 0.9928
#
# Epoch 00034: val_loss did not improve from 0.02389
# Epoch 35/40
# 747/747 [==============================] - 85s 114ms/step - loss: 1.6200e-04 - accuracy: 1.0000 - val_loss: 0.0526 - val_accuracy: 0.9925
#
# Epoch 00035: val_loss did not improve from 0.02389
# Epoch 36/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.5912e-05 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9925
#
# Epoch 00036: val_loss did not improve from 0.02389
# Epoch 37/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.0315e-04 - accuracy: 0.9999 - val_loss: 0.0773 - val_accuracy: 0.9902
#
# Epoch 00037: val_loss did not improve from 0.02389
# Epoch 38/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0675 - val_accuracy: 0.9917
#
# Epoch 00038: val_loss did not improve from 0.02389
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.3939e-04 - accuracy: 0.9998 - val_loss: 0.0592 - val_accuracy: 0.9928
#
# Epoch 00039: val_loss did not improve from 0.02389
# Epoch 40/40
# 747/747 [==============================] - 85s 114ms/step - loss: 5.9969e-05 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9921
#
# Epoch 00040: val_loss did not improve from 0.02389
# Score for fold 3: loss of 0.05929915979504585; accuracy of 99.20904040336609%
# Epoch 1/40
# 747/747 [==============================] - 99s 117ms/step - loss: 0.1506 - accuracy: 0.9576 - val_loss: 0.0567 - val_accuracy: 0.9808
#
# Epoch 00001: val_loss did not improve from 0.02389
# Epoch 2/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0601 - accuracy: 0.9800 - val_loss: 0.0353 - val_accuracy: 0.9883
#
# Epoch 00002: val_loss did not improve from 0.02389
# Epoch 3/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0933 - accuracy: 0.9707 - val_loss: 0.1008 - val_accuracy: 0.9725
#
# Epoch 00003: val_loss did not improve from 0.02389
# Epoch 4/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0674 - accuracy: 0.9774 - val_loss: 0.0431 - val_accuracy: 0.9887
#
# Epoch 00004: val_loss did not improve from 0.02389
# Epoch 5/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0530 - accuracy: 0.9810 - val_loss: 0.6973 - val_accuracy: 0.9702
#
# Epoch 00005: val_loss did not improve from 0.02389
# Epoch 6/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0491 - accuracy: 0.9835 - val_loss: 0.0911 - val_accuracy: 0.9691
#
# Epoch 00006: val_loss did not improve from 0.02389
# Epoch 7/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0396 - accuracy: 0.9862 - val_loss: 0.0435 - val_accuracy: 0.9895
#
# Epoch 00007: val_loss did not improve from 0.02389
# Epoch 8/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0359 - accuracy: 0.9873 - val_loss: 0.4915 - val_accuracy: 0.8079
#
# Epoch 00008: val_loss did not improve from 0.02389
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0332 - accuracy: 0.9879 - val_loss: 0.0323 - val_accuracy: 0.9887
#
# Epoch 00009: val_loss did not improve from 0.02389
# Epoch 10/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0370 - accuracy: 0.9874 - val_loss: 0.0361 - val_accuracy: 0.9902
#
# Epoch 00010: val_loss did not improve from 0.02389
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0323 - accuracy: 0.9883 - val_loss: 0.0934 - val_accuracy: 0.9676
#
# Epoch 00011: val_loss did not improve from 0.02389
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.1318 - accuracy: 0.9679 - val_loss: 0.0597 - val_accuracy: 0.9785
#
# Epoch 00012: val_loss did not improve from 0.02389
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0504 - accuracy: 0.9822 - val_loss: 0.0392 - val_accuracy: 0.9864
#
# Epoch 00013: val_loss did not improve from 0.02389
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0371 - accuracy: 0.9881 - val_loss: 0.0416 - val_accuracy: 0.9887
#
# Epoch 00014: val_loss did not improve from 0.02389
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.0586 - val_accuracy: 0.9774
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.02389
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0216 - accuracy: 0.9928 - val_loss: 0.0233 - val_accuracy: 0.9913
#
# Epoch 00016: val_loss improved from 0.02389 to 0.02326, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.0266 - val_accuracy: 0.9910
#
# Epoch 00017: val_loss did not improve from 0.02326
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0303 - val_accuracy: 0.9917
#
# Epoch 00018: val_loss did not improve from 0.02326
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0285 - val_accuracy: 0.9917
#
# Epoch 00019: val_loss did not improve from 0.02326
# Epoch 20/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.0321 - val_accuracy: 0.9906
#
# Epoch 00020: val_loss did not improve from 0.02326
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0441 - val_accuracy: 0.9913
#
# Epoch 00021: val_loss did not improve from 0.02326
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0277 - val_accuracy: 0.9947
#
# Epoch 00022: val_loss did not improve from 0.02326
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0267 - val_accuracy: 0.9917
#
# Epoch 00023: val_loss did not improve from 0.02326
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0313 - val_accuracy: 0.9917
#
# Epoch 00024: val_loss did not improve from 0.02326
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0093 - accuracy: 0.9964 - val_loss: 0.0293 - val_accuracy: 0.9898
#
# Epoch 00025: val_loss did not improve from 0.02326
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0313 - val_accuracy: 0.9921
#
# Epoch 00026: val_loss did not improve from 0.02326
# Epoch 27/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.0307 - val_accuracy: 0.9932
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.02326
# Epoch 28/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0356 - val_accuracy: 0.9940
#
# Epoch 00028: val_loss did not improve from 0.02326
# Epoch 29/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0335 - val_accuracy: 0.9955
#
# Epoch 00029: val_loss did not improve from 0.02326
# Epoch 30/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0443 - val_accuracy: 0.9932
#
# Epoch 00030: val_loss did not improve from 0.02326
# Epoch 31/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0365 - val_accuracy: 0.9940
#
# Epoch 00031: val_loss did not improve from 0.02326
# Epoch 32/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0432 - val_accuracy: 0.9932
#
# Epoch 00032: val_loss did not improve from 0.02326
# Epoch 33/40
# 747/747 [==============================] - 85s 114ms/step - loss: 9.6895e-04 - accuracy: 0.9999 - val_loss: 0.0508 - val_accuracy: 0.9944
#
# Epoch 00033: val_loss did not improve from 0.02326
# Epoch 34/40
# 747/747 [==============================] - 86s 114ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0363 - val_accuracy: 0.9936
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_loss did not improve from 0.02326
# Epoch 35/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0246 - val_accuracy: 0.9951
#
# Epoch 00035: val_loss did not improve from 0.02326
# Epoch 36/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.3842e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9940
#
# Epoch 00036: val_loss did not improve from 0.02326
# Epoch 37/40
# 747/747 [==============================] - 85s 114ms/step - loss: 1.5185e-04 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9936
#
# Epoch 00037: val_loss did not improve from 0.02326
# Epoch 38/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.8816e-04 - accuracy: 0.9999 - val_loss: 0.0440 - val_accuracy: 0.9944
#
# Epoch 00038: val_loss did not improve from 0.02326
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.0916e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9936
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00039: val_loss did not improve from 0.02326
# Epoch 40/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.0521e-04 - accuracy: 0.9999 - val_loss: 0.0446 - val_accuracy: 0.9932
#
# Epoch 00040: val_loss did not improve from 0.02326
# Score for fold 4: loss of 0.044555772095918655; accuracy of 99.3220329284668%
# Epoch 1/40
# 747/747 [==============================] - 100s 117ms/step - loss: 0.1505 - accuracy: 0.9637 - val_loss: 0.1433 - val_accuracy: 0.9616
#
# Epoch 00001: val_loss did not improve from 0.02326
# Epoch 2/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0706 - accuracy: 0.9752 - val_loss: 6.1220 - val_accuracy: 0.7141
#
# Epoch 00002: val_loss did not improve from 0.02326
# Epoch 3/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0459 - accuracy: 0.9840 - val_loss: 4.0014 - val_accuracy: 0.8403
#
# Epoch 00003: val_loss did not improve from 0.02326
# Epoch 4/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0419 - accuracy: 0.9851 - val_loss: 0.0572 - val_accuracy: 0.9812
#
# Epoch 00004: val_loss did not improve from 0.02326
# Epoch 5/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0579 - accuracy: 0.9809 - val_loss: 0.0528 - val_accuracy: 0.9827
#
# Epoch 00005: val_loss did not improve from 0.02326
# Epoch 6/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0389 - accuracy: 0.9864 - val_loss: 0.0380 - val_accuracy: 0.9868
#
# Epoch 00006: val_loss did not improve from 0.02326
# Epoch 7/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0329 - accuracy: 0.9881 - val_loss: 0.0487 - val_accuracy: 0.9831
#
# Epoch 00007: val_loss did not improve from 0.02326
# Epoch 8/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0276 - accuracy: 0.9902 - val_loss: 0.0413 - val_accuracy: 0.9876
#
# Epoch 00008: val_loss did not improve from 0.02326
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0246 - accuracy: 0.9916 - val_loss: 0.0377 - val_accuracy: 0.9864
#
# Epoch 00009: val_loss did not improve from 0.02326
# Epoch 10/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0257 - accuracy: 0.9914 - val_loss: 0.0441 - val_accuracy: 0.9849
#
# Epoch 00010: val_loss did not improve from 0.02326
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.0402 - val_accuracy: 0.9895
#
# Epoch 00011: val_loss did not improve from 0.02326
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 0.0726 - val_accuracy: 0.9763
#
# Epoch 00012: val_loss did not improve from 0.02326
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 0.0309 - val_accuracy: 0.9895
#
# Epoch 00013: val_loss did not improve from 0.02326
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.0334 - val_accuracy: 0.9872
#
# Epoch 00014: val_loss did not improve from 0.02326
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.1203 - accuracy: 0.9796 - val_loss: 0.0715 - val_accuracy: 0.9782
#
# Epoch 00015: val_loss did not improve from 0.02326
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.0392 - val_accuracy: 0.9895
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.02326
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.0349 - val_accuracy: 0.9921
#
# Epoch 00017: val_loss did not improve from 0.02326
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 0.0392 - val_accuracy: 0.9902
#
# Epoch 00018: val_loss did not improve from 0.02326
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0365 - val_accuracy: 0.9910
#
# Epoch 00019: val_loss did not improve from 0.02326
# Epoch 20/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.0463 - val_accuracy: 0.9887
#
# Epoch 00020: val_loss did not improve from 0.02326
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0341 - val_accuracy: 0.9921
#
# Epoch 00021: val_loss did not improve from 0.02326
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0365 - val_accuracy: 0.9921
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.02326
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0397 - val_accuracy: 0.9921
#
# Epoch 00023: val_loss did not improve from 0.02326
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0458 - val_accuracy: 0.9925
#
# Epoch 00024: val_loss did not improve from 0.02326
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0496 - val_accuracy: 0.9932
#
# Epoch 00025: val_loss did not improve from 0.02326
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0394 - val_accuracy: 0.9921
#
# Epoch 00026: val_loss did not improve from 0.02326
# Epoch 27/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0454 - val_accuracy: 0.9936
#
# Epoch 00027: val_loss did not improve from 0.02326
# Epoch 28/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0420 - val_accuracy: 0.9925
#
# Epoch 00028: val_loss did not improve from 0.02326
# Epoch 29/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0413 - val_accuracy: 0.9925
#
# Epoch 00029: val_loss did not improve from 0.02326
# Epoch 30/40
# 747/747 [==============================] - 85s 114ms/step - loss: 6.8114e-04 - accuracy: 0.9998 - val_loss: 0.0508 - val_accuracy: 0.9917
#
# Epoch 00030: val_loss did not improve from 0.02326
# Epoch 31/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0536 - val_accuracy: 0.9917
#
# Epoch 00031: val_loss did not improve from 0.02326
# Epoch 32/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0454 - val_accuracy: 0.9917
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.02326
# Epoch 33/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.8078e-04 - accuracy: 0.9998 - val_loss: 0.0533 - val_accuracy: 0.9921
# Epoch 00033: val_loss did not improve from 0.02326
# Epoch 34/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.1527e-04 - accuracy: 0.9998 - val_loss: 0.0561 - val_accuracy: 0.9928
#
# Epoch 00034: val_loss did not improve from 0.02326
# Epoch 35/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.6923e-04 - accuracy: 0.9998 - val_loss: 0.0585 - val_accuracy: 0.9925
#
# Epoch 00035: val_loss did not improve from 0.02326
# Epoch 36/40
# 747/747 [==============================] - 85s 114ms/step - loss: 9.6444e-04 - accuracy: 0.9998 - val_loss: 0.0544 - val_accuracy: 0.9913
#
# Epoch 00036: val_loss did not improve from 0.02326
# Epoch 37/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.4769e-04 - accuracy: 0.9997 - val_loss: 0.0592 - val_accuracy: 0.9932
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00037: val_loss did not improve from 0.02326
# Epoch 38/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.0808e-05 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9917
#
# Epoch 00038: val_loss did not improve from 0.02326
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 4.4146e-04 - accuracy: 0.9998 - val_loss: 0.0538 - val_accuracy: 0.9932
#
# Epoch 00039: val_loss did not improve from 0.02326
# Epoch 40/40
# 747/747 [==============================] - 85s 114ms/step - loss: 4.7685e-04 - accuracy: 0.9998 - val_loss: 0.0588 - val_accuracy: 0.9913
#
# Epoch 00040: val_loss did not improve from 0.02326
# Score for fold 5: loss of 0.05881878733634949; accuracy of 99.13371205329895%
# Epoch 1/40
# 747/747 [==============================] - 100s 116ms/step - loss: 0.1243 - accuracy: 0.9644 - val_loss: 0.0610 - val_accuracy: 0.9782
#
# Epoch 00001: val_loss did not improve from 0.02326
# Epoch 2/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0546 - accuracy: 0.9800 - val_loss: 0.0456 - val_accuracy: 0.9849
#
# Epoch 00002: val_loss did not improve from 0.02326
# Epoch 3/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0499 - accuracy: 0.9842 - val_loss: 0.0663 - val_accuracy: 0.9736
#
# Epoch 00003: val_loss did not improve from 0.02326
# Epoch 4/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0467 - accuracy: 0.9837 - val_loss: 0.0590 - val_accuracy: 0.9782
#
# Epoch 00004: val_loss did not improve from 0.02326
# Epoch 5/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0354 - accuracy: 0.9877 - val_loss: 0.0427 - val_accuracy: 0.9861
#
# Epoch 00005: val_loss did not improve from 0.02326
# Epoch 6/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0325 - accuracy: 0.9879 - val_loss: 0.0492 - val_accuracy: 0.9834
#
# Epoch 00006: val_loss did not improve from 0.02326
# Epoch 7/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0423 - accuracy: 0.9879 - val_loss: 0.0403 - val_accuracy: 0.9842
#
# Epoch 00007: val_loss did not improve from 0.02326
# Epoch 8/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0914 - accuracy: 0.9756 - val_loss: 0.1014 - val_accuracy: 0.9635
#
# Epoch 00008: val_loss did not improve from 0.02326
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.2215 - accuracy: 0.9552 - val_loss: 0.0847 - val_accuracy: 0.9718
#
# Epoch 00009: val_loss did not improve from 0.02326
# Epoch 10/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0829 - accuracy: 0.9713 - val_loss: 0.0545 - val_accuracy: 0.9778
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_loss did not improve from 0.02326
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0506 - accuracy: 0.9816 - val_loss: 0.0453 - val_accuracy: 0.9808
#
# Epoch 00011: val_loss did not improve from 0.02326
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0486 - accuracy: 0.9845 - val_loss: 0.0532 - val_accuracy: 0.9808
#
# Epoch 00012: val_loss did not improve from 0.02326
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0403 - accuracy: 0.9855 - val_loss: 0.0393 - val_accuracy: 0.9846
#
# Epoch 00013: val_loss did not improve from 0.02326
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0343 - accuracy: 0.9874 - val_loss: 0.0334 - val_accuracy: 0.9872
#
# Epoch 00014: val_loss did not improve from 0.02326
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0311 - accuracy: 0.9884 - val_loss: 0.0621 - val_accuracy: 0.9782
#
# Epoch 00015: val_loss did not improve from 0.02326
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0269 - accuracy: 0.9905 - val_loss: 0.0357 - val_accuracy: 0.9887
#
# Epoch 00016: val_loss did not improve from 0.02326
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0256 - accuracy: 0.9911 - val_loss: 0.0349 - val_accuracy: 0.9895
#
# Epoch 00017: val_loss did not improve from 0.02326
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.0350 - val_accuracy: 0.9868
#
# Epoch 00018: val_loss did not improve from 0.02326
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.0334 - val_accuracy: 0.9872
#
# Epoch 00019: val_loss did not improve from 0.02326
# Epoch 20/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0324 - accuracy: 0.9905 - val_loss: 0.0346 - val_accuracy: 0.9898
#
# Epoch 00020: val_loss did not improve from 0.02326
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0165 - accuracy: 0.9936 - val_loss: 0.0407 - val_accuracy: 0.9876
#
# Epoch 00021: val_loss did not improve from 0.02326
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.0344 - val_accuracy: 0.9898
#
# Epoch 00022: val_loss did not improve from 0.02326
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.0261 - val_accuracy: 0.9917
#
# Epoch 00023: val_loss did not improve from 0.02326
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.0355 - val_accuracy: 0.9910
#
# Epoch 00024: val_loss did not improve from 0.02326
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0111 - accuracy: 0.9956 - val_loss: 0.0484 - val_accuracy: 0.9849
#
# Epoch 00025: val_loss did not improve from 0.02326
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0385 - val_accuracy: 0.9898
#
# Epoch 00026: val_loss did not improve from 0.02326
# Epoch 27/40
# ...
# Epoch 5/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0957 - accuracy: 0.9688 - val_loss: 0.0517 - val_accuracy: 0.9838
#
# Epoch 00005: val_loss did not improve from 0.02326
# Epoch 6/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0450 - accuracy: 0.9829 - val_loss: 0.0309 - val_accuracy: 0.9879
#
# Epoch 00006: val_loss did not improve from 0.02326
# Epoch 7/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0369 - accuracy: 0.9866 - val_loss: 0.0309 - val_accuracy: 0.9887
#
# Epoch 00007: val_loss did not improve from 0.02326
# Epoch 8/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0321 - accuracy: 0.9881 - val_loss: 0.0300 - val_accuracy: 0.9891
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_loss did not improve from 0.02326
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0186 - accuracy: 0.9931 - val_loss: 0.0392 - val_accuracy: 0.9830
#
# Epoch 00009: val_loss did not improve from 0.02326
# Epoch 10/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0172 - accuracy: 0.9936 - val_loss: 0.0289 - val_accuracy: 0.9902
#
# Epoch 00010: val_loss did not improve from 0.02326
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0185 - accuracy: 0.9934 - val_loss: 0.0297 - val_accuracy: 0.9906
#
# Epoch 00011: val_loss did not improve from 0.02326
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.0188 - val_accuracy: 0.9925
#
# Epoch 00012: val_loss improved from 0.02326 to 0.01879, saving model to /Users/Max/Documents/GitHub/misc_experiments/densenet-binary-local-v003\model.h5
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.0222 - val_accuracy: 0.9932
#
# Epoch 00013: val_loss did not improve from 0.01879
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0382 - accuracy: 0.9872 - val_loss: 0.0366 - val_accuracy: 0.9887
#
# Epoch 00014: val_loss did not improve from 0.01879
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0221 - accuracy: 0.9916 - val_loss: 0.0386 - val_accuracy: 0.9876
#
# Epoch 00015: val_loss did not improve from 0.01879
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0295 - val_accuracy: 0.9917
#
# Epoch 00016: val_loss did not improve from 0.01879
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0126 - accuracy: 0.9947 - val_loss: 0.0312 - val_accuracy: 0.9928
#
# Epoch 00017: val_loss did not improve from 0.01879
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0413 - val_accuracy: 0.9910
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_loss did not improve from 0.01879
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0326 - val_accuracy: 0.9925
#
# Epoch 00019: val_loss did not improve from 0.01879
# Epoch 20/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0044 - accuracy: 0.9983 - val_loss: 0.0457 - val_accuracy: 0.9910
#
# Epoch 00020: val_loss did not improve from 0.01879
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0402 - val_accuracy: 0.9925
#
# Epoch 00021: val_loss did not improve from 0.01879
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0376 - val_accuracy: 0.9925
#
# Epoch 00022: val_loss did not improve from 0.01879
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0441 - val_accuracy: 0.9917
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00023: val_loss did not improve from 0.01879
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0433 - val_accuracy: 0.9928
#
# Epoch 00024: val_loss did not improve from 0.01879
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 9.4169e-04 - accuracy: 0.9997 - val_loss: 0.0481 - val_accuracy: 0.9928
#
# Epoch 00025: val_loss did not improve from 0.01879
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0562 - val_accuracy: 0.9917
#
# Epoch 00026: val_loss did not improve from 0.01879
# Epoch 27/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0500 - val_accuracy: 0.9917
#
# Epoch 00027: val_loss did not improve from 0.01879
# Epoch 28/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0464 - val_accuracy: 0.9943
#
# Epoch 00028: val_loss did not improve from 0.01879
# Epoch 29/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.9127e-04 - accuracy: 0.9999 - val_loss: 0.0501 - val_accuracy: 0.9943
#
# Epoch 00029: val_loss did not improve from 0.01879
# Epoch 30/40
# 747/747 [==============================] - 85s 113ms/step - loss: 6.7460e-04 - accuracy: 0.9997 - val_loss: 0.0610 - val_accuracy: 0.9925
#
# Epoch 00030: val_loss did not improve from 0.01879
# Epoch 31/40
# 747/747 [==============================] - 85s 114ms/step - loss: 1.5788e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9921
#
# Epoch 00031: val_loss did not improve from 0.01879
# Epoch 32/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0653 - val_accuracy: 0.9928
#
# Epoch 00032: val_loss did not improve from 0.01879
# Epoch 33/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0623 - val_accuracy: 0.9917
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00033: val_loss did not improve from 0.01879
# Epoch 34/40
# 747/747 [==============================] - 85s 114ms/step - loss: 4.8022e-04 - accuracy: 0.9998 - val_loss: 0.0676 - val_accuracy: 0.9921
#
# Epoch 00034: val_loss did not improve from 0.01879
# Epoch 35/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0652 - val_accuracy: 0.9921
#
# Epoch 00035: val_loss did not improve from 0.01879
# Epoch 36/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.2019e-04 - accuracy: 0.9999 - val_loss: 0.0667 - val_accuracy: 0.9921
#
# Epoch 00036: val_loss did not improve from 0.01879
# Epoch 37/40
# 747/747 [==============================] - 85s 113ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0604 - val_accuracy: 0.9921
#
# Epoch 00037: val_loss did not improve from 0.01879
# Epoch 38/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0506 - val_accuracy: 0.9940
#
# Epoch 00038: val_loss did not improve from 0.01879
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.5090e-04 - accuracy: 0.9997 - val_loss: 0.0614 - val_accuracy: 0.9928
#
# Epoch 00039: val_loss did not improve from 0.01879
# Epoch 40/40
# 747/747 [==============================] - 85s 114ms/step - loss: 4.0109e-04 - accuracy: 0.9998 - val_loss: 0.0586 - val_accuracy: 0.9932
#
# Epoch 00040: val_loss did not improve from 0.01879
# Score for fold 9: loss of 0.05863339826464653; accuracy of 99.32177662849426%
# Epoch 1/40
# 747/747 [==============================] - 98s 117ms/step - loss: 0.1418 - accuracy: 0.9618 - val_loss: 0.0855 - val_accuracy: 0.9650
#
# Epoch 00001: val_loss did not improve from 0.01879
# Epoch 2/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0671 - accuracy: 0.9759 - val_loss: 0.1268 - val_accuracy: 0.9469
#
# Epoch 00002: val_loss did not improve from 0.01879
# Epoch 3/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0606 - accuracy: 0.9792 - val_loss: 0.0726 - val_accuracy: 0.9815
#
# Epoch 00003: val_loss did not improve from 0.01879
# Epoch 4/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0818 - accuracy: 0.9759 - val_loss: 223.1542 - val_accuracy: 0.5961
#
# Epoch 00004: val_loss did not improve from 0.01879
# Epoch 5/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0672 - accuracy: 0.9766 - val_loss: 0.0484 - val_accuracy: 0.9861
#
# Epoch 00005: val_loss did not improve from 0.01879
# Epoch 6/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0442 - accuracy: 0.9849 - val_loss: 0.0535 - val_accuracy: 0.9804
#
# Epoch 00006: val_loss did not improve from 0.01879
# Epoch 7/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0390 - accuracy: 0.9851 - val_loss: 0.0407 - val_accuracy: 0.9868
#
# Epoch 00007: val_loss did not improve from 0.01879
# Epoch 8/40
# 747/747 [==============================] - 86s 114ms/step - loss: 0.0340 - accuracy: 0.9882 - val_loss: 0.0867 - val_accuracy: 0.9774
#
# Epoch 00008: val_loss did not improve from 0.01879
# Epoch 9/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0331 - accuracy: 0.9880 - val_loss: 0.1043 - val_accuracy: 0.9804
#
# Epoch 00009: val_loss did not improve from 0.01879
# Epoch 10/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0296 - accuracy: 0.9896 - val_loss: 0.0347 - val_accuracy: 0.9894
#
# Epoch 00010: val_loss did not improve from 0.01879
# Epoch 11/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0294 - accuracy: 0.9898 - val_loss: 0.4441 - val_accuracy: 0.9846
#
# Epoch 00011: val_loss did not improve from 0.01879
# Epoch 12/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0681 - accuracy: 0.9828 - val_loss: 0.0401 - val_accuracy: 0.9846
#
# Epoch 00012: val_loss did not improve from 0.01879
# Epoch 13/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0310 - accuracy: 0.9891 - val_loss: 0.0375 - val_accuracy: 0.9857
#
# Epoch 00013: val_loss did not improve from 0.01879
# Epoch 14/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0272 - accuracy: 0.9906 - val_loss: 0.0323 - val_accuracy: 0.9894
#
# Epoch 00014: val_loss did not improve from 0.01879
# Epoch 15/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.0354 - val_accuracy: 0.9891
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.01879
# Epoch 16/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0275 - val_accuracy: 0.9932
#
# Epoch 00016: val_loss did not improve from 0.01879
# Epoch 17/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0119 - accuracy: 0.9956 - val_loss: 0.0277 - val_accuracy: 0.9913
#
# Epoch 00017: val_loss did not improve from 0.01879
# Epoch 18/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0374 - val_accuracy: 0.9894
#
# Epoch 00018: val_loss did not improve from 0.01879
# Epoch 19/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0336 - val_accuracy: 0.9910
#
# Epoch 00019: val_loss did not improve from 0.01879
# Epoch 20/40
# 747/747 [==============================] - 86s 114ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0300 - val_accuracy: 0.9925
#
# Epoch 00020: val_loss did not improve from 0.01879
# Epoch 21/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0367 - val_accuracy: 0.9910
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.01879
# Epoch 22/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0342 - val_accuracy: 0.9932
#
# Epoch 00022: val_loss did not improve from 0.01879
# Epoch 23/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0341 - val_accuracy: 0.9936
#
# Epoch 00023: val_loss did not improve from 0.01879
# Epoch 24/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0412 - val_accuracy: 0.9921
#
# Epoch 00024: val_loss did not improve from 0.01879
# Epoch 25/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0565 - val_accuracy: 0.9906
#
# Epoch 00025: val_loss did not improve from 0.01879
# Epoch 26/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0417 - val_accuracy: 0.9921
#
# Epoch 00026: val_loss did not improve from 0.01879
# Epoch 27/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0440 - val_accuracy: 0.9921
#
# Epoch 00027: val_loss did not improve from 0.01879
# Epoch 28/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 0.0481 - val_accuracy: 0.9902
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00028: val_loss did not improve from 0.01879
# Epoch 29/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0419 - val_accuracy: 0.9921
#
# Epoch 00029: val_loss did not improve from 0.01879
# Epoch 30/40
# 747/747 [==============================] - 85s 114ms/step - loss: 8.7666e-04 - accuracy: 0.9997 - val_loss: 0.0535 - val_accuracy: 0.9917
#
# Epoch 00030: val_loss did not improve from 0.01879
# Epoch 31/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0452 - val_accuracy: 0.9925
#
# Epoch 00031: val_loss did not improve from 0.01879
# Epoch 32/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0390 - val_accuracy: 0.9932
#
# Epoch 00032: val_loss did not improve from 0.01879
# Epoch 33/40
# 747/747 [==============================] - 85s 114ms/step - loss: 3.1511e-04 - accuracy: 0.9999 - val_loss: 0.0440 - val_accuracy: 0.9928
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00033: val_loss did not improve from 0.01879
# Epoch 34/40
# 747/747 [==============================] - 85s 114ms/step - loss: 5.6621e-04 - accuracy: 0.9997 - val_loss: 0.0464 - val_accuracy: 0.9928
#
# Epoch 00034: val_loss did not improve from 0.01879
# Epoch 35/40
# 747/747 [==============================] - 85s 114ms/step - loss: 2.2484e-04 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9928
#
# Epoch 00035: val_loss did not improve from 0.01879
# Epoch 36/40
# 747/747 [==============================] - 85s 114ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0476 - val_accuracy: 0.9925
#
# Epoch 00036: val_loss did not improve from 0.01879
# Epoch 37/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.4559e-04 - accuracy: 0.9998 - val_loss: 0.0448 - val_accuracy: 0.9921
#
# Epoch 00037: val_loss did not improve from 0.01879
# Epoch 38/40
# 747/747 [==============================] - 85s 114ms/step - loss: 9.3720e-05 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9925
#
# Epoch 00038: val_loss did not improve from 0.01879
# Epoch 39/40
# 747/747 [==============================] - 85s 114ms/step - loss: 7.5180e-04 - accuracy: 0.9998 - val_loss: 0.0572 - val_accuracy: 0.9921
#
# Epoch 00039: val_loss did not improve from 0.01879
# Epoch 40/40
# 747/747 [==============================] - 86s 114ms/step - loss: 9.0649e-04 - accuracy: 0.9997 - val_loss: 0.0539 - val_accuracy: 0.9913
#
# Epoch 00040: val_loss did not improve from 0.01879
# Score for fold 10: loss of 0.05387541651725769; accuracy of 99.13338422775269%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.06941647082567215 - Accuracy: 99.09604787826538%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.06642088294029236 - Accuracy: 99.02071356773376%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.05929915979504585 - Accuracy: 99.20904040336609%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.044555772095918655 - Accuracy: 99.3220329284668%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.05881878733634949 - Accuracy: 99.13371205329895%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.03374470770359039 - Accuracy: 99.3220329284668%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.05550345778465271 - Accuracy: 98.9830493927002%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.04085450991988182 - Accuracy: 99.35969710350037%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.05863339826464653 - Accuracy: 99.32177662849426%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.05387541651725769 - Accuracy: 99.13338422775269%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 99.19014871120453% (+- 0.0012964452196814595)
# > Loss: 0.05411225631833076
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of DenseNet169"
print(t)
# Out:
# +--------------------------------------+
# |      Performance of DenseNet169      |
# | Metric  | Performance | St.Deviation |
# | TPR     | 0.9935      | 0.0014       |
# | Acc     | 0.9919      | 0.0013       |
# | Loss    | 0.0541      | 0.0107       |
# | F1      | 0.9914      | 0.0013       |
# | MCC     | 0.9838      | 0.0026       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for DenseNet169 across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - DenseNet169")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'binary-class', figsize = (20,7), fontsize=14)
