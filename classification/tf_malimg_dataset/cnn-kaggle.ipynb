# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer.

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 25

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/malimg_dataset"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 7 matches(es) found
# --------------
# New folder name: cnn-local-v007
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/malimg_paper_dataset_imgs"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 9339 images belonging to 25 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()

# %% [markdown]
# Plot data distribution among all classes

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)
plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Split the data into train and test/val set using chosen split (70-30 in this case). Then separate the test/val split into validation and test set using 0.5 split. This leads to 70-15-15 split

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)

X_test, X_val, y_test, y_val =  train_test_split(X_test, y_test, test_size=0.5)

# %%
X_train_size = len(X_train)
X_test_size = len(X_test)
X_val_size = len(X_val)

print(f"Size of training data: {X_train_size} | Shape of training data {X_train.shape}")
print(f"Size of test data: {X_test_size}  | Shape of test data {X_test.shape}")
print(f"Size of training data: {X_val_size}  | Shape of training data {X_val.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 6537 | Shape of training data (6537, 64, 64, 1)
# Size of test data: 1401  | Shape of test data (1401, 64, 64, 1)
# Size of training data: 1401  | Shape of training data (1401, 64, 64, 1)
# Shape of training labels (6537, 25)
# Shape of training labels (1401, 25)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = X_train_size + X_test_size + X_val_size

# %%
patches, texts, autotexts = plt.pie(
    [X_train_size, X_val_size, X_test_size], 
    labels = ["Training", "Validation", "Test"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['cornflowerblue', 'cornflowerblue', 'cornflowerblue'],
    radius=1.2
)

plt.title("Training, validation, and test data distribution", y = 1.15)

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  25

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='relu'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='relu'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %% [markdown]
# Compiling and showing overview of the model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 2940)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               376448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                1275
# =================================================================
# Total params: 388,538
# Trainable params: 388,538
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Run the model

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_val, y_val), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint]) # The actual computation of the CNN
# Out:
# Epoch 1/25
# 205/205 [==============================] - 4s 8ms/step - loss: 1.8106 - accuracy: 0.4620 - val_loss: 0.6805 - val_accuracy: 0.8208
#
# Epoch 00001: val_loss improved from inf to 0.68051, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 2/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.5896 - accuracy: 0.8229 - val_loss: 0.2267 - val_accuracy: 0.9329
#
# Epoch 00002: val_loss improved from 0.68051 to 0.22675, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 3/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.3462 - accuracy: 0.8972 - val_loss: 0.2000 - val_accuracy: 0.9429
#
# Epoch 00003: val_loss improved from 0.22675 to 0.19999, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 4/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.2765 - accuracy: 0.9154 - val_loss: 0.1713 - val_accuracy: 0.9522
#
# Epoch 00004: val_loss improved from 0.19999 to 0.17129, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 5/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.2424 - accuracy: 0.9220 - val_loss: 0.1425 - val_accuracy: 0.9493
#
# Epoch 00005: val_loss improved from 0.17129 to 0.14248, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 6/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.2104 - accuracy: 0.9319 - val_loss: 0.1206 - val_accuracy: 0.9622
#
# Epoch 00006: val_loss improved from 0.14248 to 0.12058, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 7/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1800 - accuracy: 0.9399 - val_loss: 0.1244 - val_accuracy: 0.9643
#
# Epoch 00007: val_loss did not improve from 0.12058
# Epoch 8/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1691 - accuracy: 0.9442 - val_loss: 0.1030 - val_accuracy: 0.9657
#
# Epoch 00008: val_loss improved from 0.12058 to 0.10297, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 9/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1646 - accuracy: 0.9439 - val_loss: 0.1073 - val_accuracy: 0.9657
#
# Epoch 00009: val_loss did not improve from 0.10297
# Epoch 10/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1485 - accuracy: 0.9512 - val_loss: 0.0937 - val_accuracy: 0.9665
#
# Epoch 00010: val_loss improved from 0.10297 to 0.09371, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 11/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1488 - accuracy: 0.9514 - val_loss: 0.0916 - val_accuracy: 0.9707
#
# Epoch 00011: val_loss improved from 0.09371 to 0.09163, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 12/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1425 - accuracy: 0.9510 - val_loss: 0.1003 - val_accuracy: 0.9693
#
# Epoch 00012: val_loss did not improve from 0.09163
# Epoch 13/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1401 - accuracy: 0.9504 - val_loss: 0.0889 - val_accuracy: 0.9672
#
# Epoch 00013: val_loss improved from 0.09163 to 0.08888, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 14/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1451 - accuracy: 0.9515 - val_loss: 0.0927 - val_accuracy: 0.9707
#
# Epoch 00014: val_loss did not improve from 0.08888
# Epoch 15/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1416 - accuracy: 0.9507 - val_loss: 0.0948 - val_accuracy: 0.9657
#
# Epoch 00015: val_loss did not improve from 0.08888
# Epoch 16/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1244 - accuracy: 0.9572 - val_loss: 0.0873 - val_accuracy: 0.9722
#
# Epoch 00016: val_loss improved from 0.08888 to 0.08732, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 17/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1181 - accuracy: 0.9602 - val_loss: 0.0991 - val_accuracy: 0.9700
#
# Epoch 00017: val_loss did not improve from 0.08732
# Epoch 18/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1204 - accuracy: 0.9579 - val_loss: 0.0816 - val_accuracy: 0.9714
#
# Epoch 00018: val_loss improved from 0.08732 to 0.08158, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 19/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1074 - accuracy: 0.9663 - val_loss: 0.0962 - val_accuracy: 0.9679
#
# Epoch 00019: val_loss did not improve from 0.08158
# Epoch 20/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1111 - accuracy: 0.9619 - val_loss: 0.0795 - val_accuracy: 0.9707
#
# Epoch 00020: val_loss improved from 0.08158 to 0.07948, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 21/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.1207 - accuracy: 0.9604 - val_loss: 0.0988 - val_accuracy: 0.9707
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.07948
# Epoch 22/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.0978 - accuracy: 0.9650 - val_loss: 0.0954 - val_accuracy: 0.9700
#
# Epoch 00022: val_loss did not improve from 0.07948
# Epoch 23/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.0949 - accuracy: 0.9670 - val_loss: 0.0769 - val_accuracy: 0.9729
#
# Epoch 00023: val_loss improved from 0.07948 to 0.07693, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v007\model.h5
# Epoch 24/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.0938 - accuracy: 0.9700 - val_loss: 0.0870 - val_accuracy: 0.9722
#
# Epoch 00024: val_loss did not improve from 0.07693
# Epoch 25/25
# 205/205 [==============================] - 1s 7ms/step - loss: 0.0888 - accuracy: 0.9697 - val_loss: 0.0799 - val_accuracy: 0.9750
#
# Epoch 00025: val_loss did not improve from 0.07693

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# Load the best performing model. N.B. the best performing model did so on the validation set. The model has never seen the test set at this point

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %% [markdown]
# Evaluate the model based on the test set

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9772
# Overall CNN Accuracy: 0.9771591424942017
# (The number of correct predictions divided by the number of total predictions)

# %% [markdown]
# Save a table with the performance on the test set

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9772          |
# | Validation loss               | 0.0718          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
# Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_test2 = np.argmax(y_test, axis=1)

# %% [markdown]
# Create confusion matrix for the multi-class classification

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)
