# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 35

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 4 matches(es) found
# --------------
# New folder name: cnn-local-v009
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"
    path_root_gen = '/kaggle/input/cganlocalv007/cgan-local-v008'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-local-v008"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 100000 images belonging to 10 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))
    
    # Include lower weights for CGAN data
    sample_weights1 = np.full(len(labels[train]), 1)
    sample_weights2 = np.full(len(labels_gen), 0.5)
    sample_weights = np.concatenate((sample_weights1, sample_weights2))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        sample_weight=sample_weights,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 1997/1997 [==============================] - 15s 6ms/step - loss: 0.2204 - accuracy: 0.9261 - val_loss: 0.2694 - val_accuracy: 0.9205
#
# Epoch 00001: val_loss improved from inf to 0.26940, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 2/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.1176 - accuracy: 0.9646 - val_loss: 0.2258 - val_accuracy: 0.9288
#
# Epoch 00002: val_loss improved from 0.26940 to 0.22578, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0982 - accuracy: 0.9697 - val_loss: 0.1910 - val_accuracy: 0.9390
#
# Epoch 00003: val_loss improved from 0.22578 to 0.19101, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0854 - accuracy: 0.9734 - val_loss: 0.1884 - val_accuracy: 0.9386
#
# Epoch 00004: val_loss improved from 0.19101 to 0.18839, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 5/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0777 - accuracy: 0.9753 - val_loss: 0.1816 - val_accuracy: 0.9427
#
# Epoch 00005: val_loss improved from 0.18839 to 0.18156, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0734 - accuracy: 0.9770 - val_loss: 0.2182 - val_accuracy: 0.9375
#
# Epoch 00006: val_loss did not improve from 0.18156
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0664 - accuracy: 0.9782 - val_loss: 0.1779 - val_accuracy: 0.9431
#
# Epoch 00007: val_loss improved from 0.18156 to 0.17789, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0615 - accuracy: 0.9799 - val_loss: 0.1626 - val_accuracy: 0.9492
#
# Epoch 00008: val_loss improved from 0.17789 to 0.16263, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0590 - accuracy: 0.9803 - val_loss: 0.1614 - val_accuracy: 0.9495
#
# Epoch 00009: val_loss improved from 0.16263 to 0.16136, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0563 - accuracy: 0.9816 - val_loss: 0.1729 - val_accuracy: 0.9488
#
# Epoch 00010: val_loss did not improve from 0.16136
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0541 - accuracy: 0.9824 - val_loss: 0.1613 - val_accuracy: 0.9529
#
# Epoch 00011: val_loss improved from 0.16136 to 0.16130, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0517 - accuracy: 0.9830 - val_loss: 0.1685 - val_accuracy: 0.9548
#
# Epoch 00012: val_loss did not improve from 0.16130
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0499 - accuracy: 0.9833 - val_loss: 0.1614 - val_accuracy: 0.9548
#
# Epoch 00013: val_loss did not improve from 0.16130
# Epoch 14/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0482 - accuracy: 0.9838 - val_loss: 0.1543 - val_accuracy: 0.9567
#
# Epoch 00014: val_loss improved from 0.16130 to 0.15428, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 15/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0471 - accuracy: 0.9846 - val_loss: 0.1658 - val_accuracy: 0.9540
#
# Epoch 00015: val_loss did not improve from 0.15428
# Epoch 16/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0438 - accuracy: 0.9855 - val_loss: 0.1584 - val_accuracy: 0.9548
#
# Epoch 00016: val_loss did not improve from 0.15428
# Epoch 17/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0437 - accuracy: 0.9854 - val_loss: 0.1635 - val_accuracy: 0.9537
#
# Epoch 00017: val_loss did not improve from 0.15428
# Epoch 18/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.1821 - val_accuracy: 0.9514
#
# Epoch 00018: val_loss did not improve from 0.15428
# Epoch 19/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0432 - accuracy: 0.9857 - val_loss: 0.1689 - val_accuracy: 0.9563
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.15428
# Epoch 20/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0331 - accuracy: 0.9891 - val_loss: 0.1621 - val_accuracy: 0.9563
#
# Epoch 00020: val_loss did not improve from 0.15428
# Epoch 21/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.1733 - val_accuracy: 0.9544
#
# Epoch 00021: val_loss did not improve from 0.15428
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0314 - accuracy: 0.9898 - val_loss: 0.1611 - val_accuracy: 0.9567
#
# Epoch 00022: val_loss did not improve from 0.15428
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.1705 - val_accuracy: 0.9578
#
# Epoch 00023: val_loss did not improve from 0.15428
# Epoch 24/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0294 - accuracy: 0.9899 - val_loss: 0.1676 - val_accuracy: 0.9552
#
# Epoch 00024: val_loss did not improve from 0.15428
# Epoch 25/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0286 - accuracy: 0.9902 - val_loss: 0.1742 - val_accuracy: 0.9589
#
# Epoch 00025: val_loss did not improve from 0.15428
# Epoch 26/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.1814 - val_accuracy: 0.9567
#
# Epoch 00026: val_loss did not improve from 0.15428
# Epoch 27/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0277 - accuracy: 0.9902 - val_loss: 0.1939 - val_accuracy: 0.9571
#
# Epoch 00027: val_loss did not improve from 0.15428
# Epoch 28/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0262 - accuracy: 0.9908 - val_loss: 0.1696 - val_accuracy: 0.9589
#
# Epoch 00028: val_loss did not improve from 0.15428
# Epoch 29/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 0.1716 - val_accuracy: 0.9582
#
# Epoch 00029: val_loss did not improve from 0.15428
# Epoch 30/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0267 - accuracy: 0.9909 - val_loss: 0.1679 - val_accuracy: 0.9597
#
# Epoch 00030: val_loss did not improve from 0.15428
# Epoch 31/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0265 - accuracy: 0.9906 - val_loss: 0.1960 - val_accuracy: 0.9586
#
# Epoch 00031: val_loss did not improve from 0.15428
# Epoch 32/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0262 - accuracy: 0.9912 - val_loss: 0.1766 - val_accuracy: 0.9582
#
# Epoch 00032: val_loss did not improve from 0.15428
# Epoch 33/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.1800 - val_accuracy: 0.9601
#
# Epoch 00033: val_loss did not improve from 0.15428
# Epoch 34/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 0.2042 - val_accuracy: 0.9548
#
# Epoch 00034: val_loss did not improve from 0.15428
# Epoch 35/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 0.1955 - val_accuracy: 0.9571
#
# Epoch 00035: val_loss did not improve from 0.15428
# Score for fold 1: loss of 0.19547180831432343; accuracy of 95.70621252059937%
# Epoch 1/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.2353 - accuracy: 0.9185 - val_loss: 0.3143 - val_accuracy: 0.9077
#
# Epoch 00001: val_loss did not improve from 0.15428
# Epoch 2/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.1240 - accuracy: 0.9626 - val_loss: 0.2744 - val_accuracy: 0.9213
#
# Epoch 00002: val_loss did not improve from 0.15428
# Epoch 3/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.1046 - accuracy: 0.9683 - val_loss: 0.2368 - val_accuracy: 0.9296
#
# Epoch 00003: val_loss did not improve from 0.15428
# Epoch 4/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0915 - accuracy: 0.9715 - val_loss: 0.2144 - val_accuracy: 0.9352
#
# Epoch 00004: val_loss did not improve from 0.15428
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0811 - accuracy: 0.9745 - val_loss: 0.1914 - val_accuracy: 0.9427
#
# Epoch 00005: val_loss did not improve from 0.15428
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0746 - accuracy: 0.9761 - val_loss: 0.1807 - val_accuracy: 0.9439
#
# Epoch 00006: val_loss did not improve from 0.15428
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0689 - accuracy: 0.9779 - val_loss: 0.1793 - val_accuracy: 0.9450
#
# Epoch 00007: val_loss did not improve from 0.15428
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0643 - accuracy: 0.9791 - val_loss: 0.1757 - val_accuracy: 0.9499
#
# Epoch 00008: val_loss did not improve from 0.15428
# Epoch 9/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0600 - accuracy: 0.9802 - val_loss: 0.1588 - val_accuracy: 0.9499
#
# Epoch 00009: val_loss did not improve from 0.15428
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0554 - accuracy: 0.9815 - val_loss: 0.1645 - val_accuracy: 0.9525
#
# Epoch 00010: val_loss did not improve from 0.15428
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0541 - accuracy: 0.9821 - val_loss: 0.1745 - val_accuracy: 0.9533
#
# Epoch 00011: val_loss did not improve from 0.15428
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0516 - accuracy: 0.9830 - val_loss: 0.1599 - val_accuracy: 0.9510
#
# Epoch 00012: val_loss did not improve from 0.15428
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0488 - accuracy: 0.9838 - val_loss: 0.1618 - val_accuracy: 0.9548
#
# Epoch 00013: val_loss did not improve from 0.15428
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0470 - accuracy: 0.9842 - val_loss: 0.1796 - val_accuracy: 0.9514
#
# Epoch 00014: val_loss did not improve from 0.15428
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0458 - accuracy: 0.9847 - val_loss: 0.1574 - val_accuracy: 0.9529
#
# Epoch 00015: val_loss did not improve from 0.15428
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0450 - accuracy: 0.9852 - val_loss: 0.1733 - val_accuracy: 0.9514
#
# Epoch 00016: val_loss did not improve from 0.15428
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0433 - accuracy: 0.9856 - val_loss: 0.1601 - val_accuracy: 0.9548
#
# Epoch 00017: val_loss did not improve from 0.15428
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0404 - accuracy: 0.9865 - val_loss: 0.1721 - val_accuracy: 0.9567
#
# Epoch 00018: val_loss did not improve from 0.15428
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0399 - accuracy: 0.9868 - val_loss: 0.1745 - val_accuracy: 0.9540
#
# Epoch 00019: val_loss did not improve from 0.15428
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0391 - accuracy: 0.9874 - val_loss: 0.1824 - val_accuracy: 0.9537
#
# Epoch 00020: val_loss did not improve from 0.15428
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0387 - accuracy: 0.9873 - val_loss: 0.1618 - val_accuracy: 0.9563
#
# Epoch 00021: val_loss did not improve from 0.15428
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0376 - accuracy: 0.9876 - val_loss: 0.1590 - val_accuracy: 0.9567
#
# Epoch 00022: val_loss did not improve from 0.15428
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0366 - accuracy: 0.9882 - val_loss: 0.1740 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss did not improve from 0.15428
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0378 - accuracy: 0.9877 - val_loss: 0.1698 - val_accuracy: 0.9571
#
# Epoch 00024: val_loss did not improve from 0.15428
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0343 - accuracy: 0.9885 - val_loss: 0.1868 - val_accuracy: 0.9525
#
# Epoch 00025: val_loss did not improve from 0.15428
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0373 - accuracy: 0.9878 - val_loss: 0.1721 - val_accuracy: 0.9552
#
# Epoch 00026: val_loss did not improve from 0.15428
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0337 - accuracy: 0.9886 - val_loss: 0.1741 - val_accuracy: 0.9540
#
# Epoch 00027: val_loss did not improve from 0.15428
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0331 - accuracy: 0.9893 - val_loss: 0.1762 - val_accuracy: 0.9567
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.15428
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0282 - accuracy: 0.9903 - val_loss: 0.1867 - val_accuracy: 0.9559
#
# Epoch 00029: val_loss did not improve from 0.15428
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0262 - accuracy: 0.9908 - val_loss: 0.1985 - val_accuracy: 0.9552
#
# Epoch 00030: val_loss did not improve from 0.15428
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.1917 - val_accuracy: 0.9567
#
# Epoch 00031: val_loss did not improve from 0.15428
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.1924 - val_accuracy: 0.9567
#
# Epoch 00032: val_loss did not improve from 0.15428
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0254 - accuracy: 0.9913 - val_loss: 0.1931 - val_accuracy: 0.9548
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.15428
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0221 - accuracy: 0.9921 - val_loss: 0.1936 - val_accuracy: 0.9574
#
# Epoch 00034: val_loss did not improve from 0.15428
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.2098 - val_accuracy: 0.9574
#
# Epoch 00035: val_loss did not improve from 0.15428
# Score for fold 2: loss of 0.2098383903503418; accuracy of 95.74387669563293%
# Epoch 1/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.2136 - accuracy: 0.9307 - val_loss: 0.3163 - val_accuracy: 0.9062
#
# Epoch 00001: val_loss did not improve from 0.15428
# Epoch 2/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.1168 - accuracy: 0.9661 - val_loss: 0.2627 - val_accuracy: 0.9266
#
# Epoch 00002: val_loss did not improve from 0.15428
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0962 - accuracy: 0.9703 - val_loss: 0.2321 - val_accuracy: 0.9243
#
# Epoch 00003: val_loss did not improve from 0.15428
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0842 - accuracy: 0.9737 - val_loss: 0.2023 - val_accuracy: 0.9397
#
# Epoch 00004: val_loss did not improve from 0.15428
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0756 - accuracy: 0.9759 - val_loss: 0.2081 - val_accuracy: 0.9386
#
# Epoch 00005: val_loss did not improve from 0.15428
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0703 - accuracy: 0.9776 - val_loss: 0.2120 - val_accuracy: 0.9431
#
# Epoch 00006: val_loss did not improve from 0.15428
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0653 - accuracy: 0.9789 - val_loss: 0.1893 - val_accuracy: 0.9420
#
# Epoch 00007: val_loss did not improve from 0.15428
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0592 - accuracy: 0.9812 - val_loss: 0.1805 - val_accuracy: 0.9469
#
# Epoch 00008: val_loss did not improve from 0.15428
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0563 - accuracy: 0.9818 - val_loss: 0.1749 - val_accuracy: 0.9503
#
# Epoch 00009: val_loss did not improve from 0.15428
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0537 - accuracy: 0.9823 - val_loss: 0.1662 - val_accuracy: 0.9495
#
# Epoch 00010: val_loss did not improve from 0.15428
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0501 - accuracy: 0.9832 - val_loss: 0.1995 - val_accuracy: 0.9476
#
# Epoch 00011: val_loss did not improve from 0.15428
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0487 - accuracy: 0.9841 - val_loss: 0.1693 - val_accuracy: 0.9544
#
# Epoch 00012: val_loss did not improve from 0.15428
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0475 - accuracy: 0.9846 - val_loss: 0.1761 - val_accuracy: 0.9514
#
# Epoch 00013: val_loss did not improve from 0.15428
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0439 - accuracy: 0.9859 - val_loss: 0.1787 - val_accuracy: 0.9525
#
# Epoch 00014: val_loss did not improve from 0.15428
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0442 - accuracy: 0.9859 - val_loss: 0.2048 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.15428
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0414 - accuracy: 0.9864 - val_loss: 0.1815 - val_accuracy: 0.9529
#
# Epoch 00016: val_loss did not improve from 0.15428
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0409 - accuracy: 0.9867 - val_loss: 0.1753 - val_accuracy: 0.9499
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.15428
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.1847 - val_accuracy: 0.9537
#
# Epoch 00018: val_loss did not improve from 0.15428
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0308 - accuracy: 0.9895 - val_loss: 0.1969 - val_accuracy: 0.9548
#
# Epoch 00019: val_loss did not improve from 0.15428
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0302 - accuracy: 0.9899 - val_loss: 0.1860 - val_accuracy: 0.9518
#
# Epoch 00020: val_loss did not improve from 0.15428
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0288 - accuracy: 0.9902 - val_loss: 0.1907 - val_accuracy: 0.9544
#
# Epoch 00021: val_loss did not improve from 0.15428
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0279 - accuracy: 0.9905 - val_loss: 0.2180 - val_accuracy: 0.9510
#
# Epoch 00022: val_loss did not improve from 0.15428
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0294 - accuracy: 0.9905 - val_loss: 0.2117 - val_accuracy: 0.9533
#
# Epoch 00023: val_loss did not improve from 0.15428
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.2087 - val_accuracy: 0.9533
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.15428
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.2097 - val_accuracy: 0.9552
#
# Epoch 00025: val_loss did not improve from 0.15428
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.2146 - val_accuracy: 0.9544
#
# Epoch 00026: val_loss did not improve from 0.15428
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.2053 - val_accuracy: 0.9563
#
# Epoch 00027: val_loss did not improve from 0.15428
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.2075 - val_accuracy: 0.9559
#
# Epoch 00028: val_loss did not improve from 0.15428
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.2082 - val_accuracy: 0.9556
#
# Epoch 00029: val_loss did not improve from 0.15428
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0228 - accuracy: 0.9918 - val_loss: 0.2251 - val_accuracy: 0.9556
#
# Epoch 00030: val_loss did not improve from 0.15428
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.2136 - val_accuracy: 0.9544
#
# Epoch 00031: val_loss did not improve from 0.15428
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.2309 - val_accuracy: 0.9559
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.15428
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0209 - accuracy: 0.9927 - val_loss: 0.2248 - val_accuracy: 0.9552
#
# Epoch 00033: val_loss did not improve from 0.15428
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0207 - accuracy: 0.9926 - val_loss: 0.2189 - val_accuracy: 0.9540
#
# Epoch 00034: val_loss did not improve from 0.15428
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0202 - accuracy: 0.9928 - val_loss: 0.2306 - val_accuracy: 0.9556
#
# Epoch 00035: val_loss did not improve from 0.15428
# Score for fold 3: loss of 0.23057496547698975; accuracy of 95.55555582046509%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2080 - accuracy: 0.9317 - val_loss: 0.2557 - val_accuracy: 0.9243
#
# Epoch 00001: val_loss did not improve from 0.15428
# Epoch 2/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.1090 - accuracy: 0.9673 - val_loss: 0.2257 - val_accuracy: 0.9318
#
# Epoch 00002: val_loss did not improve from 0.15428
# Epoch 3/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0900 - accuracy: 0.9722 - val_loss: 0.2106 - val_accuracy: 0.9397
#
# Epoch 00003: val_loss did not improve from 0.15428
# Epoch 4/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0795 - accuracy: 0.9748 - val_loss: 0.1906 - val_accuracy: 0.9431
#
# Epoch 00004: val_loss did not improve from 0.15428
# Epoch 5/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0720 - accuracy: 0.9773 - val_loss: 0.1881 - val_accuracy: 0.9420
#
# Epoch 00005: val_loss did not improve from 0.15428
# Epoch 6/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0668 - accuracy: 0.9782 - val_loss: 0.1762 - val_accuracy: 0.9443
#
# Epoch 00006: val_loss did not improve from 0.15428
# Epoch 7/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0599 - accuracy: 0.9811 - val_loss: 0.1744 - val_accuracy: 0.9454
#
# Epoch 00007: val_loss did not improve from 0.15428
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0565 - accuracy: 0.9812 - val_loss: 0.1854 - val_accuracy: 0.9465
#
# Epoch 00008: val_loss did not improve from 0.15428
# Epoch 9/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0540 - accuracy: 0.9823 - val_loss: 0.1637 - val_accuracy: 0.9514
#
# Epoch 00009: val_loss did not improve from 0.15428
# Epoch 10/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0500 - accuracy: 0.9836 - val_loss: 0.1694 - val_accuracy: 0.9495
#
# Epoch 00010: val_loss did not improve from 0.15428
# Epoch 11/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0470 - accuracy: 0.9845 - val_loss: 0.1926 - val_accuracy: 0.9488
#
# Epoch 00011: val_loss did not improve from 0.15428
# Epoch 12/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0436 - accuracy: 0.9858 - val_loss: 0.1696 - val_accuracy: 0.9522
#
# Epoch 00012: val_loss did not improve from 0.15428
# Epoch 13/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0425 - accuracy: 0.9859 - val_loss: 0.1746 - val_accuracy: 0.9492
#
# Epoch 00013: val_loss did not improve from 0.15428
# Epoch 14/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0422 - accuracy: 0.9865 - val_loss: 0.1779 - val_accuracy: 0.9510
#
# Epoch 00014: val_loss did not improve from 0.15428
# Epoch 15/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0408 - accuracy: 0.9862 - val_loss: 0.1900 - val_accuracy: 0.9529
#
# Epoch 00015: val_loss did not improve from 0.15428
# Epoch 16/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0379 - accuracy: 0.9873 - val_loss: 0.1797 - val_accuracy: 0.9522
#
# Epoch 00016: val_loss did not improve from 0.15428
# Epoch 17/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0393 - accuracy: 0.9872 - val_loss: 0.1650 - val_accuracy: 0.9548
#
# Epoch 00017: val_loss did not improve from 0.15428
# Epoch 18/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0375 - accuracy: 0.9874 - val_loss: 0.1930 - val_accuracy: 0.9503
#
# Epoch 00018: val_loss did not improve from 0.15428
# Epoch 19/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0356 - accuracy: 0.9884 - val_loss: 0.1924 - val_accuracy: 0.9510
#
# Epoch 00019: val_loss did not improve from 0.15428
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0349 - accuracy: 0.9883 - val_loss: 0.1885 - val_accuracy: 0.9525
#
# Epoch 00020: val_loss did not improve from 0.15428
# Epoch 21/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0320 - accuracy: 0.9893 - val_loss: 0.2205 - val_accuracy: 0.9518
#
# Epoch 00021: val_loss did not improve from 0.15428
# Epoch 22/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0344 - accuracy: 0.9886 - val_loss: 0.1996 - val_accuracy: 0.9548
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.15428
# Epoch 23/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0293 - accuracy: 0.9904 - val_loss: 0.2086 - val_accuracy: 0.9548
#
# Epoch 00023: val_loss did not improve from 0.15428
# Epoch 24/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.1927 - val_accuracy: 0.9559
#
# Epoch 00024: val_loss did not improve from 0.15428
# Epoch 25/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.2064 - val_accuracy: 0.9548
#
# Epoch 00025: val_loss did not improve from 0.15428
# Epoch 26/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.2316 - val_accuracy: 0.9537
#
# Epoch 00026: val_loss did not improve from 0.15428
# Epoch 27/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0256 - accuracy: 0.9911 - val_loss: 0.2019 - val_accuracy: 0.9533
#
# Epoch 00027: val_loss did not improve from 0.15428
# Epoch 28/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0242 - accuracy: 0.9918 - val_loss: 0.2329 - val_accuracy: 0.9544
#
# Epoch 00028: val_loss did not improve from 0.15428
# Epoch 29/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.2258 - val_accuracy: 0.9552
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.15428
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.2194 - val_accuracy: 0.9552
#
# Epoch 00030: val_loss did not improve from 0.15428
# Epoch 31/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0207 - accuracy: 0.9927 - val_loss: 0.2137 - val_accuracy: 0.9563
#
# Epoch 00031: val_loss did not improve from 0.15428
# Epoch 32/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0203 - accuracy: 0.9929 - val_loss: 0.2337 - val_accuracy: 0.9556
#
# Epoch 00032: val_loss did not improve from 0.15428
# Epoch 33/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.2324 - val_accuracy: 0.9540
#
# Epoch 00033: val_loss did not improve from 0.15428
# Epoch 34/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.2537 - val_accuracy: 0.9552
#
# Epoch 00034: val_loss did not improve from 0.15428
# Epoch 35/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.2554 - val_accuracy: 0.9544
#
# Epoch 00035: val_loss did not improve from 0.15428
# Score for fold 4: loss of 0.2554072439670563; accuracy of 95.44256329536438%
# Epoch 1/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.2040 - accuracy: 0.9341 - val_loss: 0.3088 - val_accuracy: 0.9134
#
# Epoch 00001: val_loss did not improve from 0.15428
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1076 - accuracy: 0.9678 - val_loss: 0.2451 - val_accuracy: 0.9266
#
# Epoch 00002: val_loss did not improve from 0.15428
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0908 - accuracy: 0.9721 - val_loss: 0.2473 - val_accuracy: 0.9288
#
# Epoch 00003: val_loss did not improve from 0.15428
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0801 - accuracy: 0.9748 - val_loss: 0.2491 - val_accuracy: 0.9175
#
# Epoch 00004: val_loss did not improve from 0.15428
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0722 - accuracy: 0.9771 - val_loss: 0.2212 - val_accuracy: 0.9356
#
# Epoch 00005: val_loss did not improve from 0.15428
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0681 - accuracy: 0.9781 - val_loss: 0.2015 - val_accuracy: 0.9409
#
# Epoch 00006: val_loss did not improve from 0.15428
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0615 - accuracy: 0.9802 - val_loss: 0.1879 - val_accuracy: 0.9424
#
# Epoch 00007: val_loss did not improve from 0.15428
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0575 - accuracy: 0.9812 - val_loss: 0.2018 - val_accuracy: 0.9435
#
# Epoch 00008: val_loss did not improve from 0.15428
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0541 - accuracy: 0.9822 - val_loss: 0.1963 - val_accuracy: 0.9431
#
# Epoch 00009: val_loss did not improve from 0.15428
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0514 - accuracy: 0.9829 - val_loss: 0.1930 - val_accuracy: 0.9446
#
# Epoch 00010: val_loss did not improve from 0.15428
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0512 - accuracy: 0.9835 - val_loss: 0.1851 - val_accuracy: 0.9458
#
# Epoch 00011: val_loss did not improve from 0.15428
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0477 - accuracy: 0.9845 - val_loss: 0.2037 - val_accuracy: 0.9401
#
# Epoch 00012: val_loss did not improve from 0.15428
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0462 - accuracy: 0.9850 - val_loss: 0.2204 - val_accuracy: 0.9382
#
# Epoch 00013: val_loss did not improve from 0.15428
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0448 - accuracy: 0.9853 - val_loss: 0.1944 - val_accuracy: 0.9480
#
# Epoch 00014: val_loss did not improve from 0.15428
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0421 - accuracy: 0.9861 - val_loss: 0.2017 - val_accuracy: 0.9461
#
# Epoch 00015: val_loss did not improve from 0.15428
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0414 - accuracy: 0.9865 - val_loss: 0.2224 - val_accuracy: 0.9420
#
# Epoch 00016: val_loss did not improve from 0.15428
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0406 - accuracy: 0.9869 - val_loss: 0.2174 - val_accuracy: 0.9458
#
# Epoch 00017: val_loss did not improve from 0.15428
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0394 - accuracy: 0.9868 - val_loss: 0.2108 - val_accuracy: 0.9454
#
# Epoch 00018: val_loss did not improve from 0.15428
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0398 - accuracy: 0.9874 - val_loss: 0.1983 - val_accuracy: 0.9492
#
# Epoch 00019: val_loss did not improve from 0.15428
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0375 - accuracy: 0.9875 - val_loss: 0.2161 - val_accuracy: 0.9480
#
# Epoch 00020: val_loss did not improve from 0.15428
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.2208 - val_accuracy: 0.9484
#
# Epoch 00021: val_loss did not improve from 0.15428
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0356 - accuracy: 0.9886 - val_loss: 0.2483 - val_accuracy: 0.9458
#
# Epoch 00022: val_loss did not improve from 0.15428
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0342 - accuracy: 0.9890 - val_loss: 0.2246 - val_accuracy: 0.9461
#
# Epoch 00023: val_loss did not improve from 0.15428
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0334 - accuracy: 0.9890 - val_loss: 0.2162 - val_accuracy: 0.9465
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.15428
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0278 - accuracy: 0.9910 - val_loss: 0.2297 - val_accuracy: 0.9484
#
# Epoch 00025: val_loss did not improve from 0.15428
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.2230 - val_accuracy: 0.9499
#
# Epoch 00026: val_loss did not improve from 0.15428
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.2280 - val_accuracy: 0.9533
#
# Epoch 00027: val_loss did not improve from 0.15428
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.2372 - val_accuracy: 0.9484
#
# Epoch 00028: val_loss did not improve from 0.15428
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.2445 - val_accuracy: 0.9473
#
# Epoch 00029: val_loss did not improve from 0.15428
# Epoch 30/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0252 - accuracy: 0.9916 - val_loss: 0.2423 - val_accuracy: 0.9484
#
# Epoch 00030: val_loss did not improve from 0.15428
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0235 - accuracy: 0.9916 - val_loss: 0.2417 - val_accuracy: 0.9503
#
# Epoch 00031: val_loss did not improve from 0.15428
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.2332 - val_accuracy: 0.9484
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.15428
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.2499 - val_accuracy: 0.9499
#
# Epoch 00033: val_loss did not improve from 0.15428
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.2561 - val_accuracy: 0.9503
#
# Epoch 00034: val_loss did not improve from 0.15428
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.2476 - val_accuracy: 0.9492
#
# Epoch 00035: val_loss did not improve from 0.15428
# Score for fold 5: loss of 0.24760065972805023; accuracy of 94.91525292396545%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2237 - accuracy: 0.9250 - val_loss: 0.2996 - val_accuracy: 0.9028
#
# Epoch 00001: val_loss did not improve from 0.15428
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1194 - accuracy: 0.9636 - val_loss: 0.2316 - val_accuracy: 0.9345
#
# Epoch 00002: val_loss did not improve from 0.15428
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1000 - accuracy: 0.9693 - val_loss: 0.2056 - val_accuracy: 0.9326
#
# Epoch 00003: val_loss did not improve from 0.15428
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0884 - accuracy: 0.9723 - val_loss: 0.2014 - val_accuracy: 0.9360
#
# Epoch 00004: val_loss did not improve from 0.15428
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0796 - accuracy: 0.9748 - val_loss: 0.1824 - val_accuracy: 0.9401
#
# Epoch 00005: val_loss did not improve from 0.15428
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0750 - accuracy: 0.9757 - val_loss: 0.1855 - val_accuracy: 0.9435
#
# Epoch 00006: val_loss did not improve from 0.15428
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0681 - accuracy: 0.9774 - val_loss: 0.1832 - val_accuracy: 0.9454
#
# Epoch 00007: val_loss did not improve from 0.15428
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0644 - accuracy: 0.9795 - val_loss: 0.1755 - val_accuracy: 0.9454
#
# Epoch 00008: val_loss did not improve from 0.15428
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0578 - accuracy: 0.9810 - val_loss: 0.1638 - val_accuracy: 0.9518
#
# Epoch 00009: val_loss did not improve from 0.15428
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0559 - accuracy: 0.9819 - val_loss: 0.1743 - val_accuracy: 0.9510
#
# Epoch 00010: val_loss did not improve from 0.15428
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0541 - accuracy: 0.9822 - val_loss: 0.1667 - val_accuracy: 0.9510
#
# Epoch 00011: val_loss did not improve from 0.15428
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0513 - accuracy: 0.9831 - val_loss: 0.1726 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.15428
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0487 - accuracy: 0.9840 - val_loss: 0.1639 - val_accuracy: 0.9525
#
# Epoch 00013: val_loss did not improve from 0.15428
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0460 - accuracy: 0.9847 - val_loss: 0.1743 - val_accuracy: 0.9525
#
# Epoch 00014: val_loss did not improve from 0.15428
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0450 - accuracy: 0.9853 - val_loss: 0.1829 - val_accuracy: 0.9529
#
# Epoch 00015: val_loss did not improve from 0.15428
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0422 - accuracy: 0.9861 - val_loss: 0.1798 - val_accuracy: 0.9537
#
# Epoch 00016: val_loss did not improve from 0.15428
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0421 - accuracy: 0.9860 - val_loss: 0.1571 - val_accuracy: 0.9552
#
# Epoch 00017: val_loss did not improve from 0.15428
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0395 - accuracy: 0.9869 - val_loss: 0.1871 - val_accuracy: 0.9540
#
# Epoch 00018: val_loss did not improve from 0.15428
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0377 - accuracy: 0.9873 - val_loss: 0.1948 - val_accuracy: 0.9548
#
# Epoch 00019: val_loss did not improve from 0.15428
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0389 - accuracy: 0.9873 - val_loss: 0.1728 - val_accuracy: 0.9559
#
# Epoch 00020: val_loss did not improve from 0.15428
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0375 - accuracy: 0.9876 - val_loss: 0.1614 - val_accuracy: 0.9544
#
# Epoch 00021: val_loss did not improve from 0.15428
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0370 - accuracy: 0.9877 - val_loss: 0.1655 - val_accuracy: 0.9544
#
# Epoch 00022: val_loss did not improve from 0.15428
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0359 - accuracy: 0.9881 - val_loss: 0.1763 - val_accuracy: 0.9540
#
# Epoch 00023: val_loss did not improve from 0.15428
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.1861 - val_accuracy: 0.9533
#
# Epoch 00024: val_loss did not improve from 0.15428
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.2087 - val_accuracy: 0.9537
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.15428
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0276 - accuracy: 0.9908 - val_loss: 0.1895 - val_accuracy: 0.9544
#
# Epoch 00026: val_loss did not improve from 0.15428
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0272 - accuracy: 0.9910 - val_loss: 0.1876 - val_accuracy: 0.9563
#
# Epoch 00027: val_loss did not improve from 0.15428
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0251 - accuracy: 0.9912 - val_loss: 0.1917 - val_accuracy: 0.9578
#
# Epoch 00028: val_loss did not improve from 0.15428
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0249 - accuracy: 0.9914 - val_loss: 0.1881 - val_accuracy: 0.9559
#
# Epoch 00029: val_loss did not improve from 0.15428
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0233 - accuracy: 0.9921 - val_loss: 0.1984 - val_accuracy: 0.9574
#
# Epoch 00030: val_loss did not improve from 0.15428
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.1823 - val_accuracy: 0.9567
#
# Epoch 00031: val_loss did not improve from 0.15428
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.2027 - val_accuracy: 0.9559
#
# Epoch 00032: val_loss did not improve from 0.15428
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.1965 - val_accuracy: 0.9578
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.15428
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.2043 - val_accuracy: 0.9571
#
# Epoch 00034: val_loss did not improve from 0.15428
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0199 - accuracy: 0.9931 - val_loss: 0.2146 - val_accuracy: 0.9567
#
# Epoch 00035: val_loss did not improve from 0.15428
# Score for fold 6: loss of 0.21461264789104462; accuracy of 95.6685483455658%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2038 - accuracy: 0.9317 - val_loss: 0.2691 - val_accuracy: 0.9250
#
# Epoch 00001: val_loss did not improve from 0.15428
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1055 - accuracy: 0.9677 - val_loss: 0.2128 - val_accuracy: 0.9337
#
# Epoch 00002: val_loss did not improve from 0.15428
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0882 - accuracy: 0.9724 - val_loss: 0.1985 - val_accuracy: 0.9443
#
# Epoch 00003: val_loss did not improve from 0.15428
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0800 - accuracy: 0.9754 - val_loss: 0.1699 - val_accuracy: 0.9484
#
# Epoch 00004: val_loss did not improve from 0.15428
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0717 - accuracy: 0.9774 - val_loss: 0.1807 - val_accuracy: 0.9454
#
# Epoch 00005: val_loss did not improve from 0.15428
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0664 - accuracy: 0.9787 - val_loss: 0.1616 - val_accuracy: 0.9514
#
# Epoch 00006: val_loss did not improve from 0.15428
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0610 - accuracy: 0.9805 - val_loss: 0.1639 - val_accuracy: 0.9522
#
# Epoch 00007: val_loss did not improve from 0.15428
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.1571 - val_accuracy: 0.9578
#
# Epoch 00008: val_loss did not improve from 0.15428
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0561 - accuracy: 0.9818 - val_loss: 0.1516 - val_accuracy: 0.9559
#
# Epoch 00009: val_loss improved from 0.15428 to 0.15157, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0517 - accuracy: 0.9838 - val_loss: 0.1605 - val_accuracy: 0.9548
#
# Epoch 00010: val_loss did not improve from 0.15157
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0483 - accuracy: 0.9841 - val_loss: 0.1606 - val_accuracy: 0.9544
#
# Epoch 00011: val_loss did not improve from 0.15157
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0483 - accuracy: 0.9843 - val_loss: 0.1510 - val_accuracy: 0.9574
#
# Epoch 00012: val_loss improved from 0.15157 to 0.15100, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0448 - accuracy: 0.9856 - val_loss: 0.1448 - val_accuracy: 0.9612
#
# Epoch 00013: val_loss improved from 0.15100 to 0.14476, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v009\model.h5
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0445 - accuracy: 0.9857 - val_loss: 0.1513 - val_accuracy: 0.9586
#
# Epoch 00014: val_loss did not improve from 0.14476
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0427 - accuracy: 0.9861 - val_loss: 0.1675 - val_accuracy: 0.9548
#
# Epoch 00015: val_loss did not improve from 0.14476
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0412 - accuracy: 0.9866 - val_loss: 0.1614 - val_accuracy: 0.9574
#
# Epoch 00016: val_loss did not improve from 0.14476
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0397 - accuracy: 0.9876 - val_loss: 0.1612 - val_accuracy: 0.9612
#
# Epoch 00017: val_loss did not improve from 0.14476
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0397 - accuracy: 0.9868 - val_loss: 0.1699 - val_accuracy: 0.9593
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.14476
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0333 - accuracy: 0.9885 - val_loss: 0.1687 - val_accuracy: 0.9608
#
# Epoch 00019: val_loss did not improve from 0.14476
# Epoch 20/35
# ...
# Epoch 00028: val_loss did not improve from 0.12711
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0258 - accuracy: 0.9914 - val_loss: 0.1479 - val_accuracy: 0.9665
#
# Epoch 00029: val_loss did not improve from 0.12711
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.1440 - val_accuracy: 0.9627
#
# Epoch 00030: val_loss did not improve from 0.12711
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.1552 - val_accuracy: 0.9623
#
# Epoch 00031: val_loss did not improve from 0.12711
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.1425 - val_accuracy: 0.9665
#
# Epoch 00032: val_loss did not improve from 0.12711
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.1411 - val_accuracy: 0.9657
#
# Epoch 00033: val_loss did not improve from 0.12711
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.1530 - val_accuracy: 0.9657
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.12711
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0204 - accuracy: 0.9928 - val_loss: 0.1603 - val_accuracy: 0.9646
#
# Epoch 00035: val_loss did not improve from 0.12711
# Score for fold 8: loss of 0.16032052040100098; accuracy of 96.4595079421997%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2088 - accuracy: 0.9309 - val_loss: 0.2835 - val_accuracy: 0.9024
#
# Epoch 00001: val_loss did not improve from 0.12711
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1091 - accuracy: 0.9669 - val_loss: 0.2712 - val_accuracy: 0.9133
#
# Epoch 00002: val_loss did not improve from 0.12711
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0902 - accuracy: 0.9723 - val_loss: 0.2259 - val_accuracy: 0.9261
#
# Epoch 00003: val_loss did not improve from 0.12711
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0788 - accuracy: 0.9756 - val_loss: 0.1982 - val_accuracy: 0.9310
#
# Epoch 00004: val_loss did not improve from 0.12711
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0725 - accuracy: 0.9771 - val_loss: 0.2010 - val_accuracy: 0.9348
#
# Epoch 00005: val_loss did not improve from 0.12711
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0658 - accuracy: 0.9786 - val_loss: 0.2010 - val_accuracy: 0.9341
#
# Epoch 00006: val_loss did not improve from 0.12711
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0628 - accuracy: 0.9795 - val_loss: 0.2274 - val_accuracy: 0.9292
#
# Epoch 00007: val_loss did not improve from 0.12711
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0587 - accuracy: 0.9809 - val_loss: 0.1698 - val_accuracy: 0.9469
#
# Epoch 00008: val_loss did not improve from 0.12711
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0535 - accuracy: 0.9826 - val_loss: 0.1921 - val_accuracy: 0.9439
#
# Epoch 00009: val_loss did not improve from 0.12711
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0512 - accuracy: 0.9831 - val_loss: 0.1639 - val_accuracy: 0.9506
#
# Epoch 00010: val_loss did not improve from 0.12711
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0508 - accuracy: 0.9834 - val_loss: 0.1630 - val_accuracy: 0.9506
#
# Epoch 00011: val_loss did not improve from 0.12711
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0479 - accuracy: 0.9842 - val_loss: 0.1859 - val_accuracy: 0.9435
#
# Epoch 00012: val_loss did not improve from 0.12711
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0450 - accuracy: 0.9854 - val_loss: 0.1827 - val_accuracy: 0.9469
#
# Epoch 00013: val_loss did not improve from 0.12711
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0447 - accuracy: 0.9852 - val_loss: 0.1767 - val_accuracy: 0.9499
#
# Epoch 00014: val_loss did not improve from 0.12711
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0432 - accuracy: 0.9859 - val_loss: 0.1655 - val_accuracy: 0.9484
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.12711
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0341 - accuracy: 0.9884 - val_loss: 0.1695 - val_accuracy: 0.9514
#
# Epoch 00016: val_loss did not improve from 0.12711
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0335 - accuracy: 0.9885 - val_loss: 0.1652 - val_accuracy: 0.9521
#
# Epoch 00017: val_loss did not improve from 0.12711
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0308 - accuracy: 0.9896 - val_loss: 0.1769 - val_accuracy: 0.9510
#
# Epoch 00018: val_loss did not improve from 0.12711
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0308 - accuracy: 0.9897 - val_loss: 0.1796 - val_accuracy: 0.9521
#
# Epoch 00019: val_loss did not improve from 0.12711
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0307 - accuracy: 0.9893 - val_loss: 0.1800 - val_accuracy: 0.9510
#
# Epoch 00020: val_loss did not improve from 0.12711
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0284 - accuracy: 0.9901 - val_loss: 0.1786 - val_accuracy: 0.9525
#
# Epoch 00021: val_loss did not improve from 0.12711
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.1846 - val_accuracy: 0.9514
#
# Epoch 00022: val_loss did not improve from 0.12711
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0276 - accuracy: 0.9905 - val_loss: 0.1892 - val_accuracy: 0.9499
#
# Epoch 00023: val_loss did not improve from 0.12711
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0272 - accuracy: 0.9908 - val_loss: 0.1856 - val_accuracy: 0.9488
#
# Epoch 00024: val_loss did not improve from 0.12711
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0268 - accuracy: 0.9907 - val_loss: 0.1975 - val_accuracy: 0.9525
#
# Epoch 00025: val_loss did not improve from 0.12711
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0268 - accuracy: 0.9910 - val_loss: 0.1903 - val_accuracy: 0.9506
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00026: val_loss did not improve from 0.12711
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.2011 - val_accuracy: 0.9506
#
# Epoch 00027: val_loss did not improve from 0.12711
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0224 - accuracy: 0.9920 - val_loss: 0.1950 - val_accuracy: 0.9529
#
# Epoch 00028: val_loss did not improve from 0.12711
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0225 - accuracy: 0.9922 - val_loss: 0.2105 - val_accuracy: 0.9514
#
# Epoch 00029: val_loss did not improve from 0.12711
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 0.2070 - val_accuracy: 0.9510
#
# Epoch 00030: val_loss did not improve from 0.12711
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.1930 - val_accuracy: 0.9503
#
# Epoch 00031: val_loss did not improve from 0.12711
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.2321 - val_accuracy: 0.9461
#
# Epoch 00032: val_loss did not improve from 0.12711
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0204 - accuracy: 0.9931 - val_loss: 0.2219 - val_accuracy: 0.9495
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.12711
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.2145 - val_accuracy: 0.9518
#
# Epoch 00034: val_loss did not improve from 0.12711
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0189 - accuracy: 0.9932 - val_loss: 0.2240 - val_accuracy: 0.9506
#
# Epoch 00035: val_loss did not improve from 0.12711
# Score for fold 9: loss of 0.22396185994148254; accuracy of 95.06405591964722%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2205 - accuracy: 0.9268 - val_loss: 0.2865 - val_accuracy: 0.9122
#
# Epoch 00001: val_loss did not improve from 0.12711
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1129 - accuracy: 0.9658 - val_loss: 0.2332 - val_accuracy: 0.9243
#
# Epoch 00002: val_loss did not improve from 0.12711
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0927 - accuracy: 0.9714 - val_loss: 0.2082 - val_accuracy: 0.9329
#
# Epoch 00003: val_loss did not improve from 0.12711
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0818 - accuracy: 0.9742 - val_loss: 0.1946 - val_accuracy: 0.9382
#
# Epoch 00004: val_loss did not improve from 0.12711
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0739 - accuracy: 0.9762 - val_loss: 0.1882 - val_accuracy: 0.9401
#
# Epoch 00005: val_loss did not improve from 0.12711
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0677 - accuracy: 0.9781 - val_loss: 0.1751 - val_accuracy: 0.9450
#
# Epoch 00006: val_loss did not improve from 0.12711
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0622 - accuracy: 0.9797 - val_loss: 0.1712 - val_accuracy: 0.9472
#
# Epoch 00007: val_loss did not improve from 0.12711
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0581 - accuracy: 0.9815 - val_loss: 0.1711 - val_accuracy: 0.9461
#
# Epoch 00008: val_loss did not improve from 0.12711
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0532 - accuracy: 0.9828 - val_loss: 0.1599 - val_accuracy: 0.9484
#
# Epoch 00009: val_loss did not improve from 0.12711
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0502 - accuracy: 0.9835 - val_loss: 0.1696 - val_accuracy: 0.9491
#
# Epoch 00010: val_loss did not improve from 0.12711
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0490 - accuracy: 0.9838 - val_loss: 0.1697 - val_accuracy: 0.9488
#
# Epoch 00011: val_loss did not improve from 0.12711
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0464 - accuracy: 0.9851 - val_loss: 0.1764 - val_accuracy: 0.9503
#
# Epoch 00012: val_loss did not improve from 0.12711
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0433 - accuracy: 0.9859 - val_loss: 0.1665 - val_accuracy: 0.9506
#
# Epoch 00013: val_loss did not improve from 0.12711
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0419 - accuracy: 0.9862 - val_loss: 0.1991 - val_accuracy: 0.9476
#
# Epoch 00014: val_loss did not improve from 0.12711
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0417 - accuracy: 0.9867 - val_loss: 0.1802 - val_accuracy: 0.9518
#
# Epoch 00015: val_loss did not improve from 0.12711
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.1876 - val_accuracy: 0.9506
#
# Epoch 00016: val_loss did not improve from 0.12711
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0366 - accuracy: 0.9880 - val_loss: 0.1831 - val_accuracy: 0.9499
#
# Epoch 00017: val_loss did not improve from 0.12711
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0359 - accuracy: 0.9882 - val_loss: 0.1936 - val_accuracy: 0.9537
#
# Epoch 00018: val_loss did not improve from 0.12711
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0362 - accuracy: 0.9880 - val_loss: 0.1790 - val_accuracy: 0.9518
#
# Epoch 00019: val_loss did not improve from 0.12711
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0357 - accuracy: 0.9884 - val_loss: 0.1965 - val_accuracy: 0.9525
#
# Epoch 00020: val_loss did not improve from 0.12711
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0343 - accuracy: 0.9886 - val_loss: 0.1956 - val_accuracy: 0.9544
#
# Epoch 00021: val_loss did not improve from 0.12711
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.2028 - val_accuracy: 0.9540
#
# Epoch 00022: val_loss did not improve from 0.12711
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0346 - accuracy: 0.9884 - val_loss: 0.1875 - val_accuracy: 0.9506
#
# Epoch 00023: val_loss did not improve from 0.12711
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0312 - accuracy: 0.9894 - val_loss: 0.1817 - val_accuracy: 0.9514
#
# Epoch 00024: val_loss did not improve from 0.12711
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 0.2006 - val_accuracy: 0.9533
#
# Epoch 00025: val_loss did not improve from 0.12711
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0303 - accuracy: 0.9902 - val_loss: 0.2057 - val_accuracy: 0.9495
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00026: val_loss did not improve from 0.12711
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0255 - accuracy: 0.9913 - val_loss: 0.2078 - val_accuracy: 0.9537
#
# Epoch 00027: val_loss did not improve from 0.12711
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 0.2022 - val_accuracy: 0.9563
#
# Epoch 00028: val_loss did not improve from 0.12711
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.2232 - val_accuracy: 0.9548
#
# Epoch 00029: val_loss did not improve from 0.12711
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.2094 - val_accuracy: 0.9533
#
# Epoch 00030: val_loss did not improve from 0.12711
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0225 - accuracy: 0.9922 - val_loss: 0.2164 - val_accuracy: 0.9533
#
# Epoch 00031: val_loss did not improve from 0.12711
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.2276 - val_accuracy: 0.9525
#
# Epoch 00032: val_loss did not improve from 0.12711
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0221 - accuracy: 0.9923 - val_loss: 0.2334 - val_accuracy: 0.9521
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.12711
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0193 - accuracy: 0.9930 - val_loss: 0.2331 - val_accuracy: 0.9525
#
# Epoch 00034: val_loss did not improve from 0.12711
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.2338 - val_accuracy: 0.9521
#
# Epoch 00035: val_loss did not improve from 0.12711
# Score for fold 10: loss of 0.23384210467338562; accuracy of 95.21477222442627%

# %%
(np.argmax(Malware_model.predict(imgs[test]), axis=-1))
# Out:
# array([10, 10,  0, ..., 10,  0,  4], dtype=int64)

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.19547180831432343 - Accuracy: 95.70621252059937%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.2098383903503418 - Accuracy: 95.74387669563293%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.23057496547698975 - Accuracy: 95.55555582046509%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.2554072439670563 - Accuracy: 95.44256329536438%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.24760065972805023 - Accuracy: 94.91525292396545%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.21461264789104462 - Accuracy: 95.6685483455658%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.20318298041820526 - Accuracy: 96.1205244064331%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.16032052040100098 - Accuracy: 96.4595079421997%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.22396185994148254 - Accuracy: 95.06405591964722%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.23384210467338562 - Accuracy: 95.21477222442627%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.58908700942993% (+- 0.004445746012831602)
# > Loss: 0.21748131811618804
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9559      | 0.0044       |
# | Loss     | 0.2175      | 0.0262       |
# | Macro F1 | 0.8857      | 0.0098       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9788      | 0.0037       |
# | Acc      | 0.9838      | 0.003        |
# | F1       | 0.9848      | 0.0027       |
# | MCC      | 0.9676      | 0.006        |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
