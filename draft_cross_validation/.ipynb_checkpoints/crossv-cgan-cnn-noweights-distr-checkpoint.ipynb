# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 150000 # Set very high so it uses all the images in the directory, does not actually take 150,000 images

# Number of epochs
epoch_t = 35 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import time

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-weights-distr-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 7 matches(es) found
# --------------
# New folder name: cnn-weights-distr-local-v015
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"
    path_root_gen = '/kaggle/input/cganlocalv007/cgan-ckpt-local-v010-half'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-ckpt-v010-half"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# Count number of files in the CGAN folder

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 63791 images belonging to 10 classes.

# %%
plt.imshow(imgs_gen[900],cmap='gray')

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 2741/2741 [==============================] - 17s 5ms/step - loss: 0.1621 - accuracy: 0.9534 - val_loss: 0.2693 - val_accuracy: 0.9183
#
# Epoch 00001: val_loss improved from inf to 0.26933, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 2/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0795 - accuracy: 0.9763 - val_loss: 0.2053 - val_accuracy: 0.9363
#
# Epoch 00002: val_loss improved from 0.26933 to 0.20533, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 3/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0663 - accuracy: 0.9792 - val_loss: 0.1965 - val_accuracy: 0.9363
#
# Epoch 00003: val_loss improved from 0.20533 to 0.19649, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 4/35
# 2741/2741 [==============================] - 13s 5ms/step - loss: 0.0589 - accuracy: 0.9818 - val_loss: 0.1925 - val_accuracy: 0.9394
#
# Epoch 00004: val_loss improved from 0.19649 to 0.19251, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 5/35
# 2741/2741 [==============================] - 13s 5ms/step - loss: 0.0516 - accuracy: 0.9833 - val_loss: 0.1813 - val_accuracy: 0.9409
#
# Epoch 00005: val_loss improved from 0.19251 to 0.18125, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 6/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0479 - accuracy: 0.9849 - val_loss: 0.1858 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.18125
# Epoch 7/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0448 - accuracy: 0.9855 - val_loss: 0.1728 - val_accuracy: 0.9461
#
# Epoch 00007: val_loss improved from 0.18125 to 0.17282, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 8/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0420 - accuracy: 0.9865 - val_loss: 0.1761 - val_accuracy: 0.9476
#
# Epoch 00008: val_loss did not improve from 0.17282
# Epoch 9/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.1855 - val_accuracy: 0.9458
#
# Epoch 00009: val_loss did not improve from 0.17282
# Epoch 10/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0382 - accuracy: 0.9876 - val_loss: 0.1636 - val_accuracy: 0.9476
#
# Epoch 00010: val_loss improved from 0.17282 to 0.16360, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 11/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0351 - accuracy: 0.9886 - val_loss: 0.1713 - val_accuracy: 0.9514
#
# Epoch 00011: val_loss did not improve from 0.16360
# Epoch 12/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0338 - accuracy: 0.9893 - val_loss: 0.1643 - val_accuracy: 0.9510
#
# Epoch 00012: val_loss did not improve from 0.16360
# Epoch 13/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0326 - accuracy: 0.9894 - val_loss: 0.1620 - val_accuracy: 0.9503
#
# Epoch 00013: val_loss improved from 0.16360 to 0.16199, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 14/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0308 - accuracy: 0.9901 - val_loss: 0.1786 - val_accuracy: 0.9510
#
# Epoch 00014: val_loss did not improve from 0.16199
# Epoch 15/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.1770 - val_accuracy: 0.9518
#
# Epoch 00015: val_loss did not improve from 0.16199
# Epoch 16/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.1777 - val_accuracy: 0.9503
#
# Epoch 00016: val_loss did not improve from 0.16199
# Epoch 17/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.1830 - val_accuracy: 0.9495
#
# Epoch 00017: val_loss did not improve from 0.16199
# Epoch 18/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0286 - accuracy: 0.9907 - val_loss: 0.1683 - val_accuracy: 0.9522
#
# Epoch 00018: val_loss did not improve from 0.16199
# Epoch 19/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.2300 - val_accuracy: 0.9450
#
# Epoch 00019: val_loss did not improve from 0.16199
# Epoch 20/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.1882 - val_accuracy: 0.9525
#
# Epoch 00020: val_loss did not improve from 0.16199
# Epoch 21/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.2160 - val_accuracy: 0.9499
#
# Epoch 00021: val_loss did not improve from 0.16199
# Epoch 22/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 0.1873 - val_accuracy: 0.9514
#
# Epoch 00022: val_loss did not improve from 0.16199
# Epoch 23/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.1797 - val_accuracy: 0.9540
#
# Epoch 00023: val_loss did not improve from 0.16199
# Epoch 24/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 0.2244 - val_accuracy: 0.9484
#
# Epoch 00024: val_loss did not improve from 0.16199
# Epoch 25/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.1891 - val_accuracy: 0.9484
#
# Epoch 00025: val_loss did not improve from 0.16199
# Epoch 26/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0221 - accuracy: 0.9928 - val_loss: 0.2237 - val_accuracy: 0.9518
#
# Epoch 00026: val_loss did not improve from 0.16199
# Epoch 27/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.2099 - val_accuracy: 0.9525
#
# Epoch 00027: val_loss did not improve from 0.16199
# Epoch 28/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.1981 - val_accuracy: 0.9510
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.16199
# Epoch 29/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.2281 - val_accuracy: 0.9514
#
# Epoch 00029: val_loss did not improve from 0.16199
# Epoch 30/35
# 2741/2741 [==============================] - 17s 6ms/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 0.2181 - val_accuracy: 0.9514
#
# Epoch 00030: val_loss did not improve from 0.16199
# Epoch 31/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.2296 - val_accuracy: 0.9529
#
# Epoch 00031: val_loss did not improve from 0.16199
# Epoch 32/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.2238 - val_accuracy: 0.9525
#
# Epoch 00032: val_loss did not improve from 0.16199
# Epoch 33/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.2422 - val_accuracy: 0.9499
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.16199
# Epoch 34/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.2307 - val_accuracy: 0.9552
#
# Epoch 00034: val_loss did not improve from 0.16199
# Epoch 35/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0142 - accuracy: 0.9951 - val_loss: 0.2337 - val_accuracy: 0.9563
#
# Epoch 00035: val_loss did not improve from 0.16199
# Score for fold 1: loss of 0.23369906842708588; accuracy of 95.63088417053223%
# Epoch 1/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.1743 - accuracy: 0.9490 - val_loss: 0.2873 - val_accuracy: 0.9194
#
# Epoch 00001: val_loss did not improve from 0.16199
# Epoch 2/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0851 - accuracy: 0.9741 - val_loss: 0.2347 - val_accuracy: 0.9318
#
# Epoch 00002: val_loss did not improve from 0.16199
# Epoch 3/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0718 - accuracy: 0.9784 - val_loss: 0.2088 - val_accuracy: 0.9390
#
# Epoch 00003: val_loss did not improve from 0.16199
# Epoch 4/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0635 - accuracy: 0.9802 - val_loss: 0.2012 - val_accuracy: 0.9409
#
# Epoch 00004: val_loss did not improve from 0.16199
# Epoch 5/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0569 - accuracy: 0.9817 - val_loss: 0.1920 - val_accuracy: 0.9431
#
# Epoch 00005: val_loss did not improve from 0.16199
# Epoch 6/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0524 - accuracy: 0.9828 - val_loss: 0.2169 - val_accuracy: 0.9352
#
# Epoch 00006: val_loss did not improve from 0.16199
# Epoch 7/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0469 - accuracy: 0.9850 - val_loss: 0.1859 - val_accuracy: 0.9473
#
# Epoch 00007: val_loss did not improve from 0.16199
# Epoch 8/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0440 - accuracy: 0.9857 - val_loss: 0.1726 - val_accuracy: 0.9492
#
# Epoch 00008: val_loss did not improve from 0.16199
# Epoch 9/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0433 - accuracy: 0.9863 - val_loss: 0.1852 - val_accuracy: 0.9544
#
# Epoch 00009: val_loss did not improve from 0.16199
# Epoch 10/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0404 - accuracy: 0.9867 - val_loss: 0.1787 - val_accuracy: 0.9492
#
# Epoch 00010: val_loss did not improve from 0.16199
# Epoch 11/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.1980 - val_accuracy: 0.9533
#
# Epoch 00011: val_loss did not improve from 0.16199
# Epoch 12/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.1801 - val_accuracy: 0.9529
#
# Epoch 00012: val_loss did not improve from 0.16199
# Epoch 13/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0342 - accuracy: 0.9887 - val_loss: 0.1732 - val_accuracy: 0.9544
#
# Epoch 00013: val_loss did not improve from 0.16199
# Epoch 14/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0340 - accuracy: 0.9890 - val_loss: 0.1643 - val_accuracy: 0.9548
#
# Epoch 00014: val_loss did not improve from 0.16199
# Epoch 15/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.1784 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.16199
# Epoch 16/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.1782 - val_accuracy: 0.9559
#
# Epoch 00016: val_loss did not improve from 0.16199
# Epoch 17/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0312 - accuracy: 0.9898 - val_loss: 0.1739 - val_accuracy: 0.9559
#
# Epoch 00017: val_loss did not improve from 0.16199
# Epoch 18/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0300 - accuracy: 0.9901 - val_loss: 0.1908 - val_accuracy: 0.9533
#
# Epoch 00018: val_loss did not improve from 0.16199
# Epoch 19/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0296 - accuracy: 0.9903 - val_loss: 0.1841 - val_accuracy: 0.9571
#
# Epoch 00019: val_loss did not improve from 0.16199
# Epoch 20/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.1800 - val_accuracy: 0.9552
#
# Epoch 00020: val_loss did not improve from 0.16199
# Epoch 21/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0269 - accuracy: 0.9912 - val_loss: 0.1867 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss did not improve from 0.16199
# Epoch 22/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.1853 - val_accuracy: 0.9582
#
# Epoch 00022: val_loss did not improve from 0.16199
# Epoch 23/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0270 - accuracy: 0.9910 - val_loss: 0.2010 - val_accuracy: 0.9589
#
# Epoch 00023: val_loss did not improve from 0.16199
# Epoch 24/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.2171 - val_accuracy: 0.9559
#
# Epoch 00024: val_loss did not improve from 0.16199
# Epoch 25/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 0.1978 - val_accuracy: 0.9574
#
# Epoch 00025: val_loss did not improve from 0.16199
# Epoch 26/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 0.1973 - val_accuracy: 0.9544
#
# Epoch 00026: val_loss did not improve from 0.16199
# Epoch 27/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0248 - accuracy: 0.9920 - val_loss: 0.1809 - val_accuracy: 0.9589
#
# Epoch 00027: val_loss did not improve from 0.16199
# Epoch 28/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0245 - accuracy: 0.9922 - val_loss: 0.1921 - val_accuracy: 0.9582
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.16199
# Epoch 29/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.2094 - val_accuracy: 0.9586
#
# Epoch 00029: val_loss did not improve from 0.16199
# Epoch 30/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0193 - accuracy: 0.9934 - val_loss: 0.2118 - val_accuracy: 0.9593
#
# Epoch 00030: val_loss did not improve from 0.16199
# Epoch 31/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0193 - accuracy: 0.9934 - val_loss: 0.2200 - val_accuracy: 0.9586
#
# Epoch 00031: val_loss did not improve from 0.16199
# Epoch 32/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.2129 - val_accuracy: 0.9593
#
# Epoch 00032: val_loss did not improve from 0.16199
# Epoch 33/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.2306 - val_accuracy: 0.9589
#
# Epoch 00033: val_loss did not improve from 0.16199
# Epoch 34/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.2384 - val_accuracy: 0.9601
#
# Epoch 00034: val_loss did not improve from 0.16199
# Epoch 35/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.2444 - val_accuracy: 0.9593
#
# Epoch 00035: val_loss did not improve from 0.16199
# Score for fold 2: loss of 0.24442678689956665; accuracy of 95.93220353126526%
# Epoch 1/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.1594 - accuracy: 0.9547 - val_loss: 0.2784 - val_accuracy: 0.9171
#
# Epoch 00001: val_loss did not improve from 0.16199
# Epoch 2/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0821 - accuracy: 0.9758 - val_loss: 0.2230 - val_accuracy: 0.9345
#
# Epoch 00002: val_loss did not improve from 0.16199
# Epoch 3/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0682 - accuracy: 0.9791 - val_loss: 0.2034 - val_accuracy: 0.9382
#
# Epoch 00003: val_loss did not improve from 0.16199
# Epoch 4/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0599 - accuracy: 0.9814 - val_loss: 0.1960 - val_accuracy: 0.9420
#
# Epoch 00004: val_loss did not improve from 0.16199
# Epoch 5/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0547 - accuracy: 0.9828 - val_loss: 0.1710 - val_accuracy: 0.9476
#
# Epoch 00005: val_loss did not improve from 0.16199
# Epoch 6/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0494 - accuracy: 0.9843 - val_loss: 0.1646 - val_accuracy: 0.9450
#
# Epoch 00006: val_loss did not improve from 0.16199
# Epoch 7/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 0.1712 - val_accuracy: 0.9476
# Epoch 00007: val_loss did not improve from 0.16199
# Epoch 8/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0440 - accuracy: 0.9860 - val_loss: 0.1660 - val_accuracy: 0.9503
#
# Epoch 00008: val_loss did not improve from 0.16199
# Epoch 9/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0417 - accuracy: 0.9868 - val_loss: 0.1726 - val_accuracy: 0.9480
#
# Epoch 00009: val_loss did not improve from 0.16199
# Epoch 10/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0386 - accuracy: 0.9875 - val_loss: 0.1644 - val_accuracy: 0.9503
#
# Epoch 00010: val_loss did not improve from 0.16199
# Epoch 11/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0376 - accuracy: 0.9878 - val_loss: 0.1739 - val_accuracy: 0.9507
#
# Epoch 00011: val_loss did not improve from 0.16199
# Epoch 12/35
# 2741/2741 [==============================] - 17s 6ms/step - loss: 0.0358 - accuracy: 0.9886 - val_loss: 0.1695 - val_accuracy: 0.9510
#
# Epoch 00012: val_loss did not improve from 0.16199
# Epoch 13/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0343 - accuracy: 0.9889 - val_loss: 0.1702 - val_accuracy: 0.9510
#
# Epoch 00013: val_loss did not improve from 0.16199
# Epoch 14/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0339 - accuracy: 0.9890 - val_loss: 0.1919 - val_accuracy: 0.9507
#
# Epoch 00014: val_loss did not improve from 0.16199
# Epoch 15/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0315 - accuracy: 0.9899 - val_loss: 0.1803 - val_accuracy: 0.9533
#
# Epoch 00015: val_loss did not improve from 0.16199
# Epoch 16/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0305 - accuracy: 0.9903 - val_loss: 0.1849 - val_accuracy: 0.9533
#
# Epoch 00016: val_loss did not improve from 0.16199
# Epoch 17/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0305 - accuracy: 0.9898 - val_loss: 0.1876 - val_accuracy: 0.9495
#
# Epoch 00017: val_loss did not improve from 0.16199
# Epoch 18/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.1835 - val_accuracy: 0.9525
#
# Epoch 00018: val_loss did not improve from 0.16199
# Epoch 19/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0281 - accuracy: 0.9909 - val_loss: 0.1799 - val_accuracy: 0.9514
#
# Epoch 00019: val_loss did not improve from 0.16199
# Epoch 20/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0286 - accuracy: 0.9909 - val_loss: 0.2308 - val_accuracy: 0.9499
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.16199
# Epoch 21/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0234 - accuracy: 0.9925 - val_loss: 0.1824 - val_accuracy: 0.9548
#
# Epoch 00021: val_loss did not improve from 0.16199
# Epoch 22/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.1919 - val_accuracy: 0.9556
#
# Epoch 00022: val_loss did not improve from 0.16199
# Epoch 23/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 0.1976 - val_accuracy: 0.9529
#
# Epoch 00023: val_loss did not improve from 0.16199
# Epoch 24/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 0.1852 - val_accuracy: 0.9559
#
# Epoch 00024: val_loss did not improve from 0.16199
# Epoch 25/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.1918 - val_accuracy: 0.9544
#
# Epoch 00025: val_loss did not improve from 0.16199
# Epoch 26/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.1973 - val_accuracy: 0.9529
#
# Epoch 00026: val_loss did not improve from 0.16199
# Epoch 27/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.2162 - val_accuracy: 0.9544
#
# Epoch 00027: val_loss did not improve from 0.16199
# Epoch 28/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.2382 - val_accuracy: 0.9556
#
# Epoch 00028: val_loss did not improve from 0.16199
# Epoch 29/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.2120 - val_accuracy: 0.9559
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.16199
# Epoch 30/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0166 - accuracy: 0.9943 - val_loss: 0.2309 - val_accuracy: 0.9548
#
# Epoch 00030: val_loss did not improve from 0.16199
# Epoch 31/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0156 - accuracy: 0.9946 - val_loss: 0.2260 - val_accuracy: 0.9556
#
# Epoch 00031: val_loss did not improve from 0.16199
# Epoch 32/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.2235 - val_accuracy: 0.9533
#
# Epoch 00032: val_loss did not improve from 0.16199
# Epoch 33/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.2315 - val_accuracy: 0.9548
#
# Epoch 00033: val_loss did not improve from 0.16199
# Epoch 34/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 0.2591 - val_accuracy: 0.9540
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_loss did not improve from 0.16199
# Epoch 35/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.2465 - val_accuracy: 0.9552
#
# Epoch 00035: val_loss did not improve from 0.16199
# Score for fold 3: loss of 0.24650438129901886; accuracy of 95.51789164543152%
# Epoch 1/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.1666 - accuracy: 0.9512 - val_loss: 0.3126 - val_accuracy: 0.9104
#
# Epoch 00001: val_loss did not improve from 0.16199
# Epoch 2/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0847 - accuracy: 0.9747 - val_loss: 0.2871 - val_accuracy: 0.9186
#
# Epoch 00002: val_loss did not improve from 0.16199
# Epoch 3/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0690 - accuracy: 0.9793 - val_loss: 0.2409 - val_accuracy: 0.9296
#
# Epoch 00003: val_loss did not improve from 0.16199
# Epoch 4/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0617 - accuracy: 0.9811 - val_loss: 0.2232 - val_accuracy: 0.9326
#
# Epoch 00004: val_loss did not improve from 0.16199
# Epoch 5/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0561 - accuracy: 0.9825 - val_loss: 0.2194 - val_accuracy: 0.9337
#
# Epoch 00005: val_loss did not improve from 0.16199
# Epoch 6/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0520 - accuracy: 0.9834 - val_loss: 0.2174 - val_accuracy: 0.9360
#
# Epoch 00006: val_loss did not improve from 0.16199
# Epoch 7/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0472 - accuracy: 0.9851 - val_loss: 0.2040 - val_accuracy: 0.9394
#
# Epoch 00007: val_loss did not improve from 0.16199
# Epoch 8/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0445 - accuracy: 0.9859 - val_loss: 0.1989 - val_accuracy: 0.9416
#
# Epoch 00008: val_loss did not improve from 0.16199
# Epoch 9/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0421 - accuracy: 0.9865 - val_loss: 0.1918 - val_accuracy: 0.9424
#
# Epoch 00009: val_loss did not improve from 0.16199
# Epoch 10/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0397 - accuracy: 0.9873 - val_loss: 0.1838 - val_accuracy: 0.9480
#
# Epoch 00010: val_loss did not improve from 0.16199
# Epoch 11/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0393 - accuracy: 0.9875 - val_loss: 0.1813 - val_accuracy: 0.9473
#
# Epoch 00011: val_loss did not improve from 0.16199
# Epoch 12/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 0.1829 - val_accuracy: 0.9492
# Epoch 00012: val_loss did not improve from 0.16199
# Epoch 13/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0348 - accuracy: 0.9887 - val_loss: 0.1880 - val_accuracy: 0.9492
#
# Epoch 00013: val_loss did not improve from 0.16199
# Epoch 14/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.1917 - val_accuracy: 0.9507
#
# Epoch 00014: val_loss did not improve from 0.16199
# Epoch 15/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 0.2012 - val_accuracy: 0.9507
#
# Epoch 00015: val_loss did not improve from 0.16199
# Epoch 16/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0325 - accuracy: 0.9895 - val_loss: 0.2084 - val_accuracy: 0.9499
#
# Epoch 00016: val_loss did not improve from 0.16199
# Epoch 17/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.1946 - val_accuracy: 0.9525
#
# Epoch 00017: val_loss did not improve from 0.16199
# Epoch 18/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0311 - accuracy: 0.9899 - val_loss: 0.1913 - val_accuracy: 0.9518
#
# Epoch 00018: val_loss did not improve from 0.16199
# Epoch 19/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0294 - accuracy: 0.9905 - val_loss: 0.1965 - val_accuracy: 0.9529
#
# Epoch 00019: val_loss did not improve from 0.16199
# Epoch 20/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0288 - accuracy: 0.9909 - val_loss: 0.1956 - val_accuracy: 0.9552
#
# Epoch 00020: val_loss did not improve from 0.16199
# Epoch 21/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0270 - accuracy: 0.9914 - val_loss: 0.2197 - val_accuracy: 0.9529
#
# Epoch 00021: val_loss did not improve from 0.16199
# Epoch 22/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.1997 - val_accuracy: 0.9525
#
# Epoch 00022: val_loss did not improve from 0.16199
# Epoch 23/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.2028 - val_accuracy: 0.9514
#
# Epoch 00023: val_loss did not improve from 0.16199
# Epoch 24/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0256 - accuracy: 0.9919 - val_loss: 0.2107 - val_accuracy: 0.9510
#
# Epoch 00024: val_loss did not improve from 0.16199
# Epoch 25/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0261 - accuracy: 0.9916 - val_loss: 0.2225 - val_accuracy: 0.9492
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.16199
# Epoch 26/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0217 - accuracy: 0.9928 - val_loss: 0.2169 - val_accuracy: 0.9537
#
# Epoch 00026: val_loss did not improve from 0.16199
# Epoch 27/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.2241 - val_accuracy: 0.9537
#
# Epoch 00027: val_loss did not improve from 0.16199
# Epoch 28/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.2400 - val_accuracy: 0.9525
#
# Epoch 00028: val_loss did not improve from 0.16199
# Epoch 29/35
# 2741/2741 [==============================] - 17s 6ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.2214 - val_accuracy: 0.9552
#
# Epoch 00029: val_loss did not improve from 0.16199
# Epoch 30/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.2169 - val_accuracy: 0.9533
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.16199
# Epoch 31/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.2443 - val_accuracy: 0.9518
#
# Epoch 00031: val_loss did not improve from 0.16199
# Epoch 32/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.2430 - val_accuracy: 0.9552
#
# Epoch 00032: val_loss did not improve from 0.16199
# Epoch 33/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.2392 - val_accuracy: 0.9548
#
# Epoch 00033: val_loss did not improve from 0.16199
# Epoch 34/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.2712 - val_accuracy: 0.9559
#
# Epoch 00034: val_loss did not improve from 0.16199
# Epoch 35/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.2633 - val_accuracy: 0.9552
#
# Epoch 00035: val_loss did not improve from 0.16199
# Score for fold 4: loss of 0.2632792890071869; accuracy of 95.51789164543152%
# Epoch 1/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.1673 - accuracy: 0.9515 - val_loss: 0.2860 - val_accuracy: 0.9164
#
# Epoch 00001: val_loss did not improve from 0.16199
# Epoch 2/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0845 - accuracy: 0.9748 - val_loss: 0.2409 - val_accuracy: 0.9281
#
# Epoch 00002: val_loss did not improve from 0.16199
# Epoch 3/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0692 - accuracy: 0.9790 - val_loss: 0.2159 - val_accuracy: 0.9322
#
# Epoch 00003: val_loss did not improve from 0.16199
# Epoch 4/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0616 - accuracy: 0.9803 - val_loss: 0.1935 - val_accuracy: 0.9386
#
# Epoch 00004: val_loss did not improve from 0.16199
# Epoch 5/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0565 - accuracy: 0.9823 - val_loss: 0.1798 - val_accuracy: 0.9443
#
# Epoch 00005: val_loss did not improve from 0.16199
# Epoch 6/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0522 - accuracy: 0.9833 - val_loss: 0.1735 - val_accuracy: 0.9458
#
# Epoch 00006: val_loss did not improve from 0.16199
# Epoch 7/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0499 - accuracy: 0.9840 - val_loss: 0.1781 - val_accuracy: 0.9405
#
# Epoch 00007: val_loss did not improve from 0.16199
# Epoch 8/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0446 - accuracy: 0.9858 - val_loss: 0.1705 - val_accuracy: 0.9488
#
# Epoch 00008: val_loss did not improve from 0.16199
# Epoch 9/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0426 - accuracy: 0.9864 - val_loss: 0.1698 - val_accuracy: 0.9480
#
# Epoch 00009: val_loss did not improve from 0.16199
# Epoch 10/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0404 - accuracy: 0.9868 - val_loss: 0.1924 - val_accuracy: 0.9454
#
# Epoch 00010: val_loss did not improve from 0.16199
# Epoch 11/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0402 - accuracy: 0.9873 - val_loss: 0.1600 - val_accuracy: 0.9514
#
# Epoch 00011: val_loss improved from 0.16199 to 0.16003, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 12/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.1575 - val_accuracy: 0.9499
#
# Epoch 00012: val_loss improved from 0.16003 to 0.15751, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-weights-distr-local-v015\model.h5
# Epoch 13/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.1637 - val_accuracy: 0.9503
#
# Epoch 00013: val_loss did not improve from 0.15751
# Epoch 14/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 0.1649 - val_accuracy: 0.9484
#
# Epoch 00014: val_loss did not improve from 0.15751
# Epoch 15/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.1680 - val_accuracy: 0.9488
#
# Epoch 00015: val_loss did not improve from 0.15751
# Epoch 16/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0319 - accuracy: 0.9895 - val_loss: 0.1675 - val_accuracy: 0.9499
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.15751
# Epoch 17/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0272 - accuracy: 0.9911 - val_loss: 0.1585 - val_accuracy: 0.9522
#
# Epoch 00017: val_loss did not improve from 0.15751
# Epoch 18/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.1741 - val_accuracy: 0.9507
#
# Epoch 00018: val_loss did not improve from 0.15751
# Epoch 19/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.1582 - val_accuracy: 0.9529
#
# Epoch 00019: val_loss did not improve from 0.15751
# Epoch 20/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.1807 - val_accuracy: 0.9537
#
# Epoch 00020: val_loss did not improve from 0.15751
# Epoch 21/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0234 - accuracy: 0.9924 - val_loss: 0.1866 - val_accuracy: 0.9518
#
# Epoch 00021: val_loss did not improve from 0.15751
# Epoch 22/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0216 - accuracy: 0.9922 - val_loss: 0.1813 - val_accuracy: 0.9533
#
# Epoch 00022: val_loss did not improve from 0.15751
# Epoch 23/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0222 - accuracy: 0.9926 - val_loss: 0.1792 - val_accuracy: 0.9510
#
# Epoch 00023: val_loss did not improve from 0.15751
# Epoch 24/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0217 - accuracy: 0.9929 - val_loss: 0.1958 - val_accuracy: 0.9522
#
# Epoch 00024: val_loss did not improve from 0.15751
# Epoch 25/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.1856 - val_accuracy: 0.9548
#
# Epoch 00025: val_loss did not improve from 0.15751
# Epoch 26/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.1883 - val_accuracy: 0.9525
#
# Epoch 00026: val_loss did not improve from 0.15751
# Epoch 27/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0216 - accuracy: 0.9928 - val_loss: 0.1907 - val_accuracy: 0.9522
#
# Epoch 00027: val_loss did not improve from 0.15751
# Epoch 28/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.1942 - val_accuracy: 0.9522
#
# Epoch 00028: val_loss did not improve from 0.15751
# Epoch 29/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.2091 - val_accuracy: 0.9510
#
# Epoch 00029: val_loss did not improve from 0.15751
# Epoch 30/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.1885 - val_accuracy: 0.9525
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.15751
# Epoch 31/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0168 - accuracy: 0.9941 - val_loss: 0.1926 - val_accuracy: 0.9514
#
# Epoch 00031: val_loss did not improve from 0.15751
# Epoch 32/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.1992 - val_accuracy: 0.9514
#
# Epoch 00032: val_loss did not improve from 0.15751
# Epoch 33/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0166 - accuracy: 0.9943 - val_loss: 0.2057 - val_accuracy: 0.9514
#
# Epoch 00033: val_loss did not improve from 0.15751
# Epoch 34/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.2032 - val_accuracy: 0.9533
#
# Epoch 00034: val_loss did not improve from 0.15751
# Epoch 35/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.2029 - val_accuracy: 0.9492
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00035: val_loss did not improve from 0.15751
# Score for fold 5: loss of 0.2028912752866745; accuracy of 94.91525292396545%
# Epoch 1/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.1593 - accuracy: 0.9535 - val_loss: 0.2800 - val_accuracy: 0.9164
#
# Epoch 00001: val_loss did not improve from 0.15751
# Epoch 2/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0809 - accuracy: 0.9758 - val_loss: 0.2393 - val_accuracy: 0.9243
#
# Epoch 00002: val_loss did not improve from 0.15751
# Epoch 3/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0690 - accuracy: 0.9789 - val_loss: 0.2274 - val_accuracy: 0.9348
#
# Epoch 00003: val_loss did not improve from 0.15751
# Epoch 4/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0602 - accuracy: 0.9809 - val_loss: 0.2029 - val_accuracy: 0.9397
#
# Epoch 00004: val_loss did not improve from 0.15751
# Epoch 5/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0553 - accuracy: 0.9829 - val_loss: 0.1848 - val_accuracy: 0.9427
#
# Epoch 00005: val_loss did not improve from 0.15751
# Epoch 6/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0501 - accuracy: 0.9841 - val_loss: 0.1854 - val_accuracy: 0.9427
#
# Epoch 00006: val_loss did not improve from 0.15751
# Epoch 7/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0466 - accuracy: 0.9851 - val_loss: 0.2023 - val_accuracy: 0.9397
#
# Epoch 00007: val_loss did not improve from 0.15751
# Epoch 8/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0443 - accuracy: 0.9858 - val_loss: 0.1893 - val_accuracy: 0.9435
#
# Epoch 00008: val_loss did not improve from 0.15751
# Epoch 9/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 0.1832 - val_accuracy: 0.9461
#
# Epoch 00009: val_loss did not improve from 0.15751
# Epoch 10/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0396 - accuracy: 0.9872 - val_loss: 0.1861 - val_accuracy: 0.9469
#
# Epoch 00010: val_loss did not improve from 0.15751
# Epoch 11/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0376 - accuracy: 0.9879 - val_loss: 0.1656 - val_accuracy: 0.9522
#
# Epoch 00011: val_loss did not improve from 0.15751
# Epoch 12/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0359 - accuracy: 0.9881 - val_loss: 0.1594 - val_accuracy: 0.9559
#
# Epoch 00012: val_loss did not improve from 0.15751
# Epoch 13/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0349 - accuracy: 0.9889 - val_loss: 0.1681 - val_accuracy: 0.9529
#
# Epoch 00013: val_loss did not improve from 0.15751
# Epoch 14/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0333 - accuracy: 0.9896 - val_loss: 0.1838 - val_accuracy: 0.9507
#
# Epoch 00014: val_loss did not improve from 0.15751
# Epoch 15/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0313 - accuracy: 0.9898 - val_loss: 0.1631 - val_accuracy: 0.9533
#
# Epoch 00015: val_loss did not improve from 0.15751
# Epoch 16/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.1604 - val_accuracy: 0.9533
#
# Epoch 00016: val_loss did not improve from 0.15751
# Epoch 17/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.1750 - val_accuracy: 0.9529
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.15751
# Epoch 18/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0251 - accuracy: 0.9917 - val_loss: 0.1690 - val_accuracy: 0.9540
#
# Epoch 00018: val_loss did not improve from 0.15751
# Epoch 19/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0242 - accuracy: 0.9918 - val_loss: 0.1856 - val_accuracy: 0.9533
#
# Epoch 00019: val_loss did not improve from 0.15751
# Epoch 20/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0235 - accuracy: 0.9921 - val_loss: 0.1714 - val_accuracy: 0.9567
#
# Epoch 00020: val_loss did not improve from 0.15751
# Epoch 21/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.1848 - val_accuracy: 0.9529
#
# Epoch 00021: val_loss did not improve from 0.15751
# Epoch 22/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.1751 - val_accuracy: 0.9552
#
# Epoch 00022: val_loss did not improve from 0.15751
# Epoch 23/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.1718 - val_accuracy: 0.9578
#
# Epoch 00023: val_loss did not improve from 0.15751
# Epoch 24/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0209 - accuracy: 0.9931 - val_loss: 0.1708 - val_accuracy: 0.9578
#
# Epoch 00024: val_loss did not improve from 0.15751
# Epoch 25/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.1796 - val_accuracy: 0.9559
#
# Epoch 00025: val_loss did not improve from 0.15751
# Epoch 26/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.1859 - val_accuracy: 0.9567
#
# Epoch 00026: val_loss did not improve from 0.15751
# Epoch 27/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.1869 - val_accuracy: 0.9559
#
# Epoch 00027: val_loss did not improve from 0.15751
# Epoch 28/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.1965 - val_accuracy: 0.9563
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.15751
# Epoch 29/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0168 - accuracy: 0.9943 - val_loss: 0.2034 - val_accuracy: 0.9567
#
# Epoch 00029: val_loss did not improve from 0.15751
# Epoch 30/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.2001 - val_accuracy: 0.9552
#
# Epoch 00030: val_loss did not improve from 0.15751
# Epoch 31/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 0.1978 - val_accuracy: 0.9589
#
# Epoch 00031: val_loss did not improve from 0.15751
# Epoch 32/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.1920 - val_accuracy: 0.9582
#
# Epoch 00032: val_loss did not improve from 0.15751
# Epoch 33/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.1989 - val_accuracy: 0.9578
#
# Epoch 00033: val_loss did not improve from 0.15751
# Epoch 34/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.1919 - val_accuracy: 0.9563
#
# Epoch 00034: val_loss did not improve from 0.15751
# Epoch 35/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.2042 - val_accuracy: 0.9544
#
# Epoch 00035: val_loss did not improve from 0.15751
# Score for fold 6: loss of 0.204205721616745; accuracy of 95.44256329536438%
# Epoch 1/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.1677 - accuracy: 0.9504 - val_loss: 0.2951 - val_accuracy: 0.9171
#
# Epoch 00001: val_loss did not improve from 0.15751
# Epoch 2/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0853 - accuracy: 0.9749 - val_loss: 0.2314 - val_accuracy: 0.9254
#
# Epoch 00002: val_loss did not improve from 0.15751
# Epoch 3/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0703 - accuracy: 0.9786 - val_loss: 0.2048 - val_accuracy: 0.9345
#
# Epoch 00003: val_loss did not improve from 0.15751
# Epoch 4/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0631 - accuracy: 0.9803 - val_loss: 0.1897 - val_accuracy: 0.9379
#
# Epoch 00004: val_loss did not improve from 0.15751
# Epoch 5/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0555 - accuracy: 0.9823 - val_loss: 0.1913 - val_accuracy: 0.9390
#
# Epoch 00005: val_loss did not improve from 0.15751
# Epoch 6/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0519 - accuracy: 0.9837 - val_loss: 0.1828 - val_accuracy: 0.9405
#
# Epoch 00006: val_loss did not improve from 0.15751
# Epoch 7/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0494 - accuracy: 0.9840 - val_loss: 0.1834 - val_accuracy: 0.9431
#
# Epoch 00007: val_loss did not improve from 0.15751
# Epoch 8/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0466 - accuracy: 0.9852 - val_loss: 0.1808 - val_accuracy: 0.9409
#
# Epoch 00008: val_loss did not improve from 0.15751
# Epoch 9/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0433 - accuracy: 0.9858 - val_loss: 0.1758 - val_accuracy: 0.9465
#
# Epoch 00009: val_loss did not improve from 0.15751
# Epoch 10/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0427 - accuracy: 0.9863 - val_loss: 0.1721 - val_accuracy: 0.9443
#
# Epoch 00010: val_loss did not improve from 0.15751
# Epoch 11/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0397 - accuracy: 0.9869 - val_loss: 0.1764 - val_accuracy: 0.9446
#
# Epoch 00011: val_loss did not improve from 0.15751
# Epoch 12/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0394 - accuracy: 0.9874 - val_loss: 0.1725 - val_accuracy: 0.9469
#
# Epoch 00012: val_loss did not improve from 0.15751
# Epoch 13/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 0.1658 - val_accuracy: 0.9503
#
# Epoch 00013: val_loss did not improve from 0.15751
# Epoch 14/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0359 - accuracy: 0.9886 - val_loss: 0.1651 - val_accuracy: 0.9480
#
# Epoch 00014: val_loss did not improve from 0.15751
# Epoch 15/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0360 - accuracy: 0.9883 - val_loss: 0.1796 - val_accuracy: 0.9439
#
# Epoch 00015: val_loss did not improve from 0.15751
# Epoch 16/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.1825 - val_accuracy: 0.9488
#
# Epoch 00016: val_loss did not improve from 0.15751
# Epoch 17/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0323 - accuracy: 0.9896 - val_loss: 0.1778 - val_accuracy: 0.9537
#
# Epoch 00017: val_loss did not improve from 0.15751
# Epoch 18/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0317 - accuracy: 0.9898 - val_loss: 0.1849 - val_accuracy: 0.9525
#
# Epoch 00018: val_loss did not improve from 0.15751
# Epoch 19/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0318 - accuracy: 0.9898 - val_loss: 0.1800 - val_accuracy: 0.9510
#
# Epoch 00019: val_loss did not improve from 0.15751
# Epoch 20/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 0.1841 - val_accuracy: 0.9507
#
# Epoch 00020: val_loss did not improve from 0.15751
# Epoch 21/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0292 - accuracy: 0.9904 - val_loss: 0.1787 - val_accuracy: 0.9533
#
# Epoch 00021: val_loss did not improve from 0.15751
# Epoch 22/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0299 - accuracy: 0.9902 - val_loss: 0.1901 - val_accuracy: 0.9495
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.15751
# Epoch 23/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0248 - accuracy: 0.9919 - val_loss: 0.1900 - val_accuracy: 0.9540
#
# Epoch 00023: val_loss did not improve from 0.15751
# Epoch 24/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0235 - accuracy: 0.9921 - val_loss: 0.1929 - val_accuracy: 0.9525
#
# Epoch 00024: val_loss did not improve from 0.15751
# Epoch 25/35
# 2741/2741 [==============================] - 14s 5ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.2074 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.15751
# Epoch 26/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.2033 - val_accuracy: 0.9499
#
# Epoch 00026: val_loss did not improve from 0.15751
# Epoch 27/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.1983 - val_accuracy: 0.9514
#
# Epoch 00027: val_loss did not improve from 0.15751
# Epoch 28/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.1986 - val_accuracy: 0.9507
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.15751
# Epoch 29/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.2003 - val_accuracy: 0.9533
#
# Epoch 00029: val_loss did not improve from 0.15751
# Epoch 30/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.2126 - val_accuracy: 0.9510
#
# Epoch 00030: val_loss did not improve from 0.15751
# Epoch 31/35
# 2741/2741 [==============================] - 15s 5ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 0.2164 - val_accuracy: 0.9514
#
# Epoch 00031: val_loss did not improve from 0.15751
# Epoch 32/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.2001 - val_accuracy: 0.9525
#
# Epoch 00032: val_loss did not improve from 0.15751
# Epoch 33/35
# 2741/2741 [==============================] - 15s 6ms/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 0.2055 - val_accuracy: 0.9533
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.15751
# Epoch 34/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.2180 - val_accuracy: 0.9548
#
# Epoch 00034: val_loss did not improve from 0.15751
# Epoch 35/35
# 2741/2741 [==============================] - 16s 6ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.2085 - val_accuracy: 0.9525
#
# Epoch 00035: val_loss did not improve from 0.15751
# Score for fold 7: loss of 0.20847643911838531; accuracy of 95.25423645973206%
# Epoch 1/35
#  754/2741 [=======>......................] - ETA: 11s - loss: 0.2776 - accuracy: 0.9199
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1708/2163265769.py in <module>
#      12     # Run the CNN
#      13     history.append(
# ---> 14         Malware_model.fit(
#      15         train_images,
#      16         train_labels,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.23369906842708588 - Accuracy: 95.63088417053223%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.24442678689956665 - Accuracy: 95.93220353126526%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.24650438129901886 - Accuracy: 95.51789164543152%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.2632792890071869 - Accuracy: 95.51789164543152%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.2028912752866745 - Accuracy: 94.91525292396545%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.204205721616745 - Accuracy: 95.44256329536438%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.20847643911838531 - Accuracy: 95.25423645973206%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.45870338167462% (+- 0.002923453782737535)
# > Loss: 0.22906899452209473
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph (I will use around 20% of cases for benign for and the remaining 80% equally distributed across the 10 ransomware families)

# %%
np.array(train_distr)
# Out:
# array([[ 9.08717668,  9.22745313,  8.36982802,  8.36868756,  8.29113635,
#          8.63099311,  8.43483418,  8.65266183,  8.29455773,  8.24209662,
#         14.40057479],
#        [ 9.0894576 ,  9.22745313,  8.36640664,  8.37096848,  8.2842936 ,
#          8.6481    ,  8.42114867,  8.64581908,  8.28657452,  8.24095616,
#         14.41882213],
#        [ 9.10770494,  9.23201496,  8.37895169,  8.37553031,  8.29113635,
#          8.65152137,  8.42685096,  8.64581908,  8.29227681,  8.23069203,
#         14.36750148],
#        [ 9.10770494,  9.19894165,  8.3869349 ,  8.3675471 ,  8.30254094,
#          8.65722367,  8.42457005,  8.66406642,  8.28771498,  8.22156836,
#         14.38118699],
#        [ 9.13051412,  9.23771726,  8.3675471 ,  8.36640664,  8.28657452,
#          8.63669541,  8.44509831,  8.66634734,  8.28201268,  8.23411341,
#         14.34697322],
#        [ 9.11226678,  9.22973404,  8.37438985,  8.37667077,  8.29683865,
#          8.6617855 ,  8.41430592,  8.67319009,  8.28087222,  8.23525387,
#         14.3446923 ],
#        [ 9.07463163,  9.23315542,  8.38351353,  8.36526618,  8.30710278,
#          8.67433055,  8.41886775,  8.66406642,  8.28657452,  8.23183249,
#         14.36065873]])

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN - CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9546      | 0.0029       |
# | Loss     | 0.2291      | 0.0222       |
# | Macro F1 | 0.884       | 0.0079       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.977       | 0.0025       |
# | Acc      | 0.983       | 0.0017       |
# | F1       | 0.984       | 0.0017       |
# | MCC      | 0.9659      | 0.0034       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
