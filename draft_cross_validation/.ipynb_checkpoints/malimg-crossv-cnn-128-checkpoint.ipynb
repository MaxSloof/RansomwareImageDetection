# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 128x128 images with ReLU activation and Adam optimizer. No class or sample specific weights are used

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 128
iw = 128

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 50

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset"
    for files in os.listdir(dir):
        if "crossv-cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-cnn128-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 7 matches(es) found
# --------------
# New folder name: crossv-cnn128-local-v008
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/image_data/malimg_paper_dataset_imgs/"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 9339 images belonging to 25 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  25

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix_bin_model(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []

bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/50
# 263/263 [==============================] - 4s 14ms/step - loss: 1.4166 - accuracy: 0.5842 - val_loss: 0.5688 - val_accuracy: 0.8266
#
# Epoch 00001: val_loss improved from inf to 0.56881, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 2/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.5000 - accuracy: 0.8500 - val_loss: 0.3326 - val_accuracy: 0.8758
#
# Epoch 00002: val_loss improved from 0.56881 to 0.33263, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 3/50
# 263/263 [==============================] - 4s 13ms/step - loss: 0.3315 - accuracy: 0.8986 - val_loss: 0.1970 - val_accuracy: 0.9293
#
# Epoch 00003: val_loss improved from 0.33263 to 0.19702, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 4/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.2728 - accuracy: 0.9149 - val_loss: 0.1790 - val_accuracy: 0.9358
#
# Epoch 00004: val_loss improved from 0.19702 to 0.17905, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 5/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.2396 - accuracy: 0.9254 - val_loss: 0.1606 - val_accuracy: 0.9454
#
# Epoch 00005: val_loss improved from 0.17905 to 0.16063, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 6/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.2205 - accuracy: 0.9280 - val_loss: 0.1577 - val_accuracy: 0.9475
#
# Epoch 00006: val_loss improved from 0.16063 to 0.15770, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 7/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.2030 - accuracy: 0.9333 - val_loss: 0.1713 - val_accuracy: 0.9422
#
# Epoch 00007: val_loss did not improve from 0.15770
# Epoch 8/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1922 - accuracy: 0.9377 - val_loss: 0.1205 - val_accuracy: 0.9518
#
# Epoch 00008: val_loss improved from 0.15770 to 0.12047, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 9/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1579 - accuracy: 0.9488 - val_loss: 0.1203 - val_accuracy: 0.9593
#
# Epoch 00009: val_loss improved from 0.12047 to 0.12026, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 10/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1573 - accuracy: 0.9460 - val_loss: 0.1196 - val_accuracy: 0.9561
#
# Epoch 00010: val_loss improved from 0.12026 to 0.11957, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 11/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1606 - accuracy: 0.9469 - val_loss: 0.1215 - val_accuracy: 0.9518
#
# Epoch 00011: val_loss did not improve from 0.11957
# Epoch 12/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1448 - accuracy: 0.9516 - val_loss: 0.1508 - val_accuracy: 0.9443
#
# Epoch 00012: val_loss did not improve from 0.11957
# Epoch 13/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1454 - accuracy: 0.9510 - val_loss: 0.1094 - val_accuracy: 0.9561
#
# Epoch 00013: val_loss improved from 0.11957 to 0.10943, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 14/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1347 - accuracy: 0.9535 - val_loss: 0.1039 - val_accuracy: 0.9615
#
# Epoch 00014: val_loss improved from 0.10943 to 0.10390, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 15/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1389 - accuracy: 0.9530 - val_loss: 0.1062 - val_accuracy: 0.9572
#
# Epoch 00015: val_loss did not improve from 0.10390
# Epoch 16/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1322 - accuracy: 0.9566 - val_loss: 0.1052 - val_accuracy: 0.9582
#
# Epoch 00016: val_loss did not improve from 0.10390
# Epoch 17/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1239 - accuracy: 0.9554 - val_loss: 0.1013 - val_accuracy: 0.9604
#
# Epoch 00017: val_loss improved from 0.10390 to 0.10131, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 18/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1277 - accuracy: 0.9568 - val_loss: 0.1013 - val_accuracy: 0.9604
#
# Epoch 00018: val_loss did not improve from 0.10131
# Epoch 19/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1180 - accuracy: 0.9576 - val_loss: 0.0885 - val_accuracy: 0.9690
#
# Epoch 00019: val_loss improved from 0.10131 to 0.08850, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 20/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1141 - accuracy: 0.9624 - val_loss: 0.0923 - val_accuracy: 0.9636
#
# Epoch 00020: val_loss did not improve from 0.08850
# Epoch 21/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1130 - accuracy: 0.9616 - val_loss: 0.0943 - val_accuracy: 0.9668
#
# Epoch 00021: val_loss did not improve from 0.08850
# Epoch 22/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1147 - accuracy: 0.9610 - val_loss: 0.1125 - val_accuracy: 0.9572
#
# Epoch 00022: val_loss did not improve from 0.08850
# Epoch 23/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1135 - accuracy: 0.9616 - val_loss: 0.1044 - val_accuracy: 0.9657
#
# Epoch 00023: val_loss did not improve from 0.08850
# Epoch 24/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1082 - accuracy: 0.9622 - val_loss: 0.1056 - val_accuracy: 0.9679
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.08850
# Epoch 25/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0979 - accuracy: 0.9668 - val_loss: 0.0975 - val_accuracy: 0.9625
#
# Epoch 00025: val_loss did not improve from 0.08850
# Epoch 26/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0957 - accuracy: 0.9659 - val_loss: 0.0929 - val_accuracy: 0.9679
#
# Epoch 00026: val_loss did not improve from 0.08850
# Epoch 27/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0880 - accuracy: 0.9682 - val_loss: 0.0972 - val_accuracy: 0.9647
#
# Epoch 00027: val_loss did not improve from 0.08850
# Epoch 28/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0842 - accuracy: 0.9709 - val_loss: 0.0912 - val_accuracy: 0.9690
#
# Epoch 00028: val_loss did not improve from 0.08850
# Epoch 29/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0833 - accuracy: 0.9706 - val_loss: 0.0961 - val_accuracy: 0.9657
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.08850
# Epoch 30/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0779 - accuracy: 0.9741 - val_loss: 0.0929 - val_accuracy: 0.9668
#
# Epoch 00030: val_loss did not improve from 0.08850
# Epoch 31/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0741 - accuracy: 0.9732 - val_loss: 0.0929 - val_accuracy: 0.9722
#
# Epoch 00031: val_loss did not improve from 0.08850
# Epoch 32/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0755 - accuracy: 0.9731 - val_loss: 0.0908 - val_accuracy: 0.9700
#
# Epoch 00032: val_loss did not improve from 0.08850
# Epoch 33/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0733 - accuracy: 0.9743 - val_loss: 0.0938 - val_accuracy: 0.9700
#
# Epoch 00033: val_loss did not improve from 0.08850
# Epoch 34/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0773 - accuracy: 0.9725 - val_loss: 0.0943 - val_accuracy: 0.9668
#
# Epoch 00034: val_loss did not improve from 0.08850
# Epoch 35/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0759 - accuracy: 0.9730 - val_loss: 0.0915 - val_accuracy: 0.9668
#
# Epoch 00035: val_loss did not improve from 0.08850
# Epoch 36/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0777 - accuracy: 0.9725 - val_loss: 0.0878 - val_accuracy: 0.9700
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00036: val_loss improved from 0.08850 to 0.08784, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 37/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0744 - accuracy: 0.9733 - val_loss: 0.0917 - val_accuracy: 0.9700
#
# Epoch 00037: val_loss did not improve from 0.08784
# Epoch 38/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0701 - accuracy: 0.9748 - val_loss: 0.0900 - val_accuracy: 0.9690
#
# Epoch 00038: val_loss did not improve from 0.08784
# Epoch 39/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0711 - accuracy: 0.9763 - val_loss: 0.0861 - val_accuracy: 0.9679
#
# Epoch 00039: val_loss improved from 0.08784 to 0.08610, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 40/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0734 - accuracy: 0.9739 - val_loss: 0.0907 - val_accuracy: 0.9700
#
# Epoch 00040: val_loss did not improve from 0.08610
# Epoch 41/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0677 - accuracy: 0.9769 - val_loss: 0.0908 - val_accuracy: 0.9679
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00041: val_loss did not improve from 0.08610
# Epoch 42/50
# 263/263 [==============================] - 4s 13ms/step - loss: 0.0713 - accuracy: 0.9760 - val_loss: 0.0890 - val_accuracy: 0.9690
#
# Epoch 00042: val_loss did not improve from 0.08610
# Epoch 43/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0663 - accuracy: 0.9775 - val_loss: 0.0910 - val_accuracy: 0.9690
#
# Epoch 00043: val_loss did not improve from 0.08610
# Epoch 44/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0664 - accuracy: 0.9770 - val_loss: 0.0915 - val_accuracy: 0.9679
#
# Epoch 00044: val_loss did not improve from 0.08610
# Epoch 45/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0674 - accuracy: 0.9768 - val_loss: 0.0878 - val_accuracy: 0.9700
#
# Epoch 00045: val_loss did not improve from 0.08610
# Epoch 46/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0684 - accuracy: 0.9749 - val_loss: 0.0909 - val_accuracy: 0.9679
#
# Epoch 00046: val_loss did not improve from 0.08610
# Epoch 47/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0687 - accuracy: 0.9750 - val_loss: 0.0928 - val_accuracy: 0.9679
#
# Epoch 00047: val_loss did not improve from 0.08610
# Epoch 48/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0697 - accuracy: 0.9754 - val_loss: 0.0893 - val_accuracy: 0.9711
#
# Epoch 00048: val_loss did not improve from 0.08610
# Epoch 49/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0702 - accuracy: 0.9753 - val_loss: 0.0944 - val_accuracy: 0.9668
#
# Epoch 00049: val_loss did not improve from 0.08610
# Epoch 50/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0723 - accuracy: 0.9744 - val_loss: 0.0876 - val_accuracy: 0.9711
#
# Epoch 00050: val_loss did not improve from 0.08610
# Score for fold 1: loss of 0.08762793242931366; accuracy of 97.10921049118042%
# Epoch 1/50
# 263/263 [==============================] - 4s 14ms/step - loss: 1.3294 - accuracy: 0.6152 - val_loss: 0.3430 - val_accuracy: 0.9090
#
# Epoch 00001: val_loss did not improve from 0.08610
# Epoch 2/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.3907 - accuracy: 0.8847 - val_loss: 0.1998 - val_accuracy: 0.9400
#
# Epoch 00002: val_loss did not improve from 0.08610
# Epoch 3/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2573 - accuracy: 0.9227 - val_loss: 0.1475 - val_accuracy: 0.9572
#
# Epoch 00003: val_loss did not improve from 0.08610
# Epoch 4/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2184 - accuracy: 0.9335 - val_loss: 0.1429 - val_accuracy: 0.9604
#
# Epoch 00004: val_loss did not improve from 0.08610
# Epoch 5/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1888 - accuracy: 0.9390 - val_loss: 0.1398 - val_accuracy: 0.9518
#
# Epoch 00005: val_loss did not improve from 0.08610
# Epoch 6/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1638 - accuracy: 0.9471 - val_loss: 0.1422 - val_accuracy: 0.9540
#
# Epoch 00006: val_loss did not improve from 0.08610
# Epoch 7/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1573 - accuracy: 0.9485 - val_loss: 0.1182 - val_accuracy: 0.9647
#
# Epoch 00007: val_loss did not improve from 0.08610
# Epoch 8/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1444 - accuracy: 0.9525 - val_loss: 0.1124 - val_accuracy: 0.9679
#
# Epoch 00008: val_loss did not improve from 0.08610
# Epoch 9/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1305 - accuracy: 0.9568 - val_loss: 0.1046 - val_accuracy: 0.9679
#
# Epoch 00009: val_loss did not improve from 0.08610
# Epoch 10/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1265 - accuracy: 0.9570 - val_loss: 0.1082 - val_accuracy: 0.9722
#
# Epoch 00010: val_loss did not improve from 0.08610
# Epoch 11/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1335 - accuracy: 0.9554 - val_loss: 0.1031 - val_accuracy: 0.9647
#
# Epoch 00011: val_loss did not improve from 0.08610
# Epoch 12/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1257 - accuracy: 0.9600 - val_loss: 0.0997 - val_accuracy: 0.9711
#
# Epoch 00012: val_loss did not improve from 0.08610
# Epoch 13/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1213 - accuracy: 0.9595 - val_loss: 0.0990 - val_accuracy: 0.9722
#
# Epoch 00013: val_loss did not improve from 0.08610
# Epoch 14/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1022 - accuracy: 0.9651 - val_loss: 0.1009 - val_accuracy: 0.9732
#
# Epoch 00014: val_loss did not improve from 0.08610
# Epoch 15/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1054 - accuracy: 0.9642 - val_loss: 0.1031 - val_accuracy: 0.9732
#
# Epoch 00015: val_loss did not improve from 0.08610
# Epoch 16/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1095 - accuracy: 0.9624 - val_loss: 0.1022 - val_accuracy: 0.9711
#
# Epoch 00016: val_loss did not improve from 0.08610
# Epoch 17/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0937 - accuracy: 0.9675 - val_loss: 0.1215 - val_accuracy: 0.9722
#
# Epoch 00017: val_loss did not improve from 0.08610
# Epoch 18/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1000 - accuracy: 0.9672 - val_loss: 0.1084 - val_accuracy: 0.9711
#
# Epoch 00018: val_loss did not improve from 0.08610
# Epoch 19/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0941 - accuracy: 0.9686 - val_loss: 0.1073 - val_accuracy: 0.9711
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.08610
# Epoch 20/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0803 - accuracy: 0.9717 - val_loss: 0.0976 - val_accuracy: 0.9722
#
# Epoch 00020: val_loss did not improve from 0.08610
# Epoch 21/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0789 - accuracy: 0.9730 - val_loss: 0.1073 - val_accuracy: 0.9732
#
# Epoch 00021: val_loss did not improve from 0.08610
# Epoch 22/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0792 - accuracy: 0.9714 - val_loss: 0.1105 - val_accuracy: 0.9732
#
# Epoch 00022: val_loss did not improve from 0.08610
# Epoch 23/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0764 - accuracy: 0.9750 - val_loss: 0.1085 - val_accuracy: 0.9743
#
# Epoch 00023: val_loss did not improve from 0.08610
# Epoch 24/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0796 - accuracy: 0.9724 - val_loss: 0.0978 - val_accuracy: 0.9732
#
# Epoch 00024: val_loss did not improve from 0.08610
# Epoch 25/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0736 - accuracy: 0.9744 - val_loss: 0.1119 - val_accuracy: 0.9711
#
# Epoch 00025: val_loss did not improve from 0.08610
# Epoch 26/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0766 - accuracy: 0.9737 - val_loss: 0.1048 - val_accuracy: 0.9754
#
# Epoch 00026: val_loss did not improve from 0.08610
# Epoch 27/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0713 - accuracy: 0.9753 - val_loss: 0.1003 - val_accuracy: 0.9732
#
# Epoch 00027: val_loss did not improve from 0.08610
# Epoch 28/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0749 - accuracy: 0.9741 - val_loss: 0.1110 - val_accuracy: 0.9743
#
# Epoch 00028: val_loss did not improve from 0.08610
# Epoch 29/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0686 - accuracy: 0.9764 - val_loss: 0.1003 - val_accuracy: 0.9732
#
# Epoch 00029: val_loss did not improve from 0.08610
# Epoch 30/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0684 - accuracy: 0.9762 - val_loss: 0.1152 - val_accuracy: 0.9743
#
# Epoch 00030: val_loss did not improve from 0.08610
# Epoch 31/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0728 - accuracy: 0.9755 - val_loss: 0.1458 - val_accuracy: 0.9636
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00031: val_loss did not improve from 0.08610
# Epoch 32/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0681 - accuracy: 0.9769 - val_loss: 0.0972 - val_accuracy: 0.9732
#
# Epoch 00032: val_loss did not improve from 0.08610
# Epoch 33/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0595 - accuracy: 0.9797 - val_loss: 0.1011 - val_accuracy: 0.9754
#
# Epoch 00033: val_loss did not improve from 0.08610
# Epoch 34/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0611 - accuracy: 0.9791 - val_loss: 0.1014 - val_accuracy: 0.9732
#
# Epoch 00034: val_loss did not improve from 0.08610
# Epoch 35/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0625 - accuracy: 0.9770 - val_loss: 0.1078 - val_accuracy: 0.9722
#
# Epoch 00035: val_loss did not improve from 0.08610
# Epoch 36/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0571 - accuracy: 0.9808 - val_loss: 0.1214 - val_accuracy: 0.9754
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00036: val_loss did not improve from 0.08610
# Epoch 37/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0596 - accuracy: 0.9787 - val_loss: 0.1089 - val_accuracy: 0.9722
#
# Epoch 00037: val_loss did not improve from 0.08610
# Epoch 38/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0571 - accuracy: 0.9801 - val_loss: 0.1085 - val_accuracy: 0.9722
#
# Epoch 00038: val_loss did not improve from 0.08610
# Epoch 39/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0603 - accuracy: 0.9778 - val_loss: 0.1077 - val_accuracy: 0.9722
#
# Epoch 00039: val_loss did not improve from 0.08610
# Epoch 40/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0601 - accuracy: 0.9792 - val_loss: 0.1140 - val_accuracy: 0.9732
#
# Epoch 00040: val_loss did not improve from 0.08610
# Epoch 41/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0594 - accuracy: 0.9791 - val_loss: 0.1096 - val_accuracy: 0.9743
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00041: val_loss did not improve from 0.08610
# Epoch 42/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0591 - accuracy: 0.9792 - val_loss: 0.1088 - val_accuracy: 0.9743
#
# Epoch 00042: val_loss did not improve from 0.08610
# Epoch 43/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0566 - accuracy: 0.9808 - val_loss: 0.1116 - val_accuracy: 0.9743
#
# Epoch 00043: val_loss did not improve from 0.08610
# Epoch 44/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0561 - accuracy: 0.9814 - val_loss: 0.1092 - val_accuracy: 0.9732
#
# Epoch 00044: val_loss did not improve from 0.08610
# Epoch 45/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0554 - accuracy: 0.9818 - val_loss: 0.1133 - val_accuracy: 0.9754
#
# Epoch 00045: val_loss did not improve from 0.08610
# Epoch 46/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0546 - accuracy: 0.9812 - val_loss: 0.1005 - val_accuracy: 0.9732
#
# Epoch 00046: val_loss did not improve from 0.08610
# Epoch 47/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0535 - accuracy: 0.9818 - val_loss: 0.1061 - val_accuracy: 0.9722
#
# Epoch 00047: val_loss did not improve from 0.08610
# Epoch 48/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0565 - accuracy: 0.9813 - val_loss: 0.1123 - val_accuracy: 0.9732
#
# Epoch 00048: val_loss did not improve from 0.08610
# Epoch 49/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0565 - accuracy: 0.9804 - val_loss: 0.1151 - val_accuracy: 0.9743
#
# Epoch 00049: val_loss did not improve from 0.08610
# Epoch 50/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0543 - accuracy: 0.9816 - val_loss: 0.1061 - val_accuracy: 0.9732
#
# Epoch 00050: val_loss did not improve from 0.08610
# Score for fold 2: loss of 0.1060974970459938; accuracy of 97.32334017753601%
# Epoch 1/50
# 263/263 [==============================] - 4s 14ms/step - loss: 1.2659 - accuracy: 0.6376 - val_loss: 0.2327 - val_accuracy: 0.9079
#
# Epoch 00001: val_loss did not improve from 0.08610
# Epoch 2/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.3130 - accuracy: 0.9016 - val_loss: 0.1580 - val_accuracy: 0.9433
#
# Epoch 00002: val_loss did not improve from 0.08610
# Epoch 3/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2538 - accuracy: 0.9208 - val_loss: 0.1119 - val_accuracy: 0.9668
#
# Epoch 00003: val_loss did not improve from 0.08610
# Epoch 4/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1908 - accuracy: 0.9387 - val_loss: 0.1094 - val_accuracy: 0.9625
#
# Epoch 00004: val_loss did not improve from 0.08610
# Epoch 5/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1732 - accuracy: 0.9441 - val_loss: 0.1142 - val_accuracy: 0.9711
#
# Epoch 00005: val_loss did not improve from 0.08610
# Epoch 6/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1672 - accuracy: 0.9442 - val_loss: 0.1292 - val_accuracy: 0.9572
#
# Epoch 00006: val_loss did not improve from 0.08610
# Epoch 7/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1507 - accuracy: 0.9493 - val_loss: 0.0958 - val_accuracy: 0.9711
#
# Epoch 00007: val_loss did not improve from 0.08610
# Epoch 8/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1398 - accuracy: 0.9530 - val_loss: 0.0816 - val_accuracy: 0.9732
#
# Epoch 00008: val_loss improved from 0.08610 to 0.08160, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 9/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1381 - accuracy: 0.9548 - val_loss: 0.0976 - val_accuracy: 0.9743
#
# Epoch 00009: val_loss did not improve from 0.08160
# Epoch 10/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1234 - accuracy: 0.9554 - val_loss: 0.0863 - val_accuracy: 0.9722
#
# Epoch 00010: val_loss did not improve from 0.08160
# Epoch 11/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1212 - accuracy: 0.9576 - val_loss: 0.0931 - val_accuracy: 0.9743
# Epoch 00011: val_loss did not improve from 0.08160
# Epoch 12/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1188 - accuracy: 0.9582 - val_loss: 0.0988 - val_accuracy: 0.9668
#
# Epoch 00012: val_loss did not improve from 0.08160
# Epoch 13/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1237 - accuracy: 0.9572 - val_loss: 0.0925 - val_accuracy: 0.9754
#
# Epoch 00013: val_loss did not improve from 0.08160
# Epoch 14/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1122 - accuracy: 0.9620 - val_loss: 0.0795 - val_accuracy: 0.9764
#
# Epoch 00014: val_loss improved from 0.08160 to 0.07946, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 15/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1069 - accuracy: 0.9617 - val_loss: 0.0752 - val_accuracy: 0.9732
#
# Epoch 00015: val_loss improved from 0.07946 to 0.07516, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 16/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1147 - accuracy: 0.9629 - val_loss: 0.0814 - val_accuracy: 0.9732
#
# Epoch 00016: val_loss did not improve from 0.07516
# Epoch 17/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0988 - accuracy: 0.9672 - val_loss: 0.0673 - val_accuracy: 0.9754
#
# Epoch 00017: val_loss improved from 0.07516 to 0.06734, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 18/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1054 - accuracy: 0.9642 - val_loss: 0.0834 - val_accuracy: 0.9764
#
# Epoch 00018: val_loss did not improve from 0.06734
# Epoch 19/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1057 - accuracy: 0.9643 - val_loss: 0.0717 - val_accuracy: 0.9764
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.06734
# Epoch 20/50
# 263/263 [==============================] - 4s 13ms/step - loss: 0.0818 - accuracy: 0.9709 - val_loss: 0.0860 - val_accuracy: 0.9732
#
# Epoch 00020: val_loss did not improve from 0.06734
# Epoch 21/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0783 - accuracy: 0.9714 - val_loss: 0.0848 - val_accuracy: 0.9807
#
# Epoch 00021: val_loss did not improve from 0.06734
# Epoch 22/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0762 - accuracy: 0.9732 - val_loss: 0.0691 - val_accuracy: 0.9797
#
# Epoch 00022: val_loss did not improve from 0.06734
# Epoch 23/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0747 - accuracy: 0.9742 - val_loss: 0.0695 - val_accuracy: 0.9807
#
# Epoch 00023: val_loss did not improve from 0.06734
# Epoch 24/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0787 - accuracy: 0.9732 - val_loss: 0.0646 - val_accuracy: 0.9775
#
# Epoch 00024: val_loss improved from 0.06734 to 0.06459, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 25/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0787 - accuracy: 0.9724 - val_loss: 0.0678 - val_accuracy: 0.9818
#
# Epoch 00025: val_loss did not improve from 0.06459
# Epoch 26/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0774 - accuracy: 0.9730 - val_loss: 0.0749 - val_accuracy: 0.9786
#
# Epoch 00026: val_loss did not improve from 0.06459
# Epoch 27/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0719 - accuracy: 0.9747 - val_loss: 0.0811 - val_accuracy: 0.9829
#
# Epoch 00027: val_loss did not improve from 0.06459
# Epoch 28/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0844 - accuracy: 0.9725 - val_loss: 0.0530 - val_accuracy: 0.9818
#
# Epoch 00028: val_loss improved from 0.06459 to 0.05303, saving model to C:/Users/Max/OneDrive - Erasmus University Rotterdam/Documents/GitHub/malimg_dataset/crossv-cnn128-local-v008\model.h5
# Epoch 29/50
# 263/263 [==============================] - 4s 15ms/step - loss: 0.0682 - accuracy: 0.9756 - val_loss: 0.0688 - val_accuracy: 0.9839
#
# Epoch 00029: val_loss did not improve from 0.05303
# Epoch 30/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0767 - accuracy: 0.9744 - val_loss: 0.0680 - val_accuracy: 0.9797
#
# Epoch 00030: val_loss did not improve from 0.05303
# Epoch 31/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0668 - accuracy: 0.9760 - val_loss: 0.0635 - val_accuracy: 0.9839
#
# Epoch 00031: val_loss did not improve from 0.05303
# Epoch 32/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0700 - accuracy: 0.9761 - val_loss: 0.0734 - val_accuracy: 0.9775
#
# Epoch 00032: val_loss did not improve from 0.05303
# Epoch 33/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0671 - accuracy: 0.9767 - val_loss: 0.0621 - val_accuracy: 0.9807
#
# Epoch 00033: val_loss did not improve from 0.05303
# Epoch 34/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0644 - accuracy: 0.9786 - val_loss: 0.0600 - val_accuracy: 0.9829
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.05303
# Epoch 35/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0591 - accuracy: 0.9799 - val_loss: 0.0702 - val_accuracy: 0.9818
#
# Epoch 00035: val_loss did not improve from 0.05303
# Epoch 36/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0586 - accuracy: 0.9797 - val_loss: 0.0587 - val_accuracy: 0.9829
#
# Epoch 00036: val_loss did not improve from 0.05303
# Epoch 37/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0593 - accuracy: 0.9795 - val_loss: 0.0623 - val_accuracy: 0.9839
#
# Epoch 00037: val_loss did not improve from 0.05303
# Epoch 38/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0587 - accuracy: 0.9806 - val_loss: 0.0638 - val_accuracy: 0.9829
#
# Epoch 00038: val_loss did not improve from 0.05303
# Epoch 39/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0579 - accuracy: 0.9806 - val_loss: 0.0663 - val_accuracy: 0.9839
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00039: val_loss did not improve from 0.05303
# Epoch 40/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0563 - accuracy: 0.9822 - val_loss: 0.0643 - val_accuracy: 0.9839
#
# Epoch 00040: val_loss did not improve from 0.05303
# Epoch 41/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0542 - accuracy: 0.9808 - val_loss: 0.0606 - val_accuracy: 0.9839
#
# Epoch 00041: val_loss did not improve from 0.05303
# Epoch 42/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0536 - accuracy: 0.9814 - val_loss: 0.0593 - val_accuracy: 0.9850
#
# Epoch 00042: val_loss did not improve from 0.05303
# Epoch 43/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0543 - accuracy: 0.9816 - val_loss: 0.0643 - val_accuracy: 0.9861
#
# Epoch 00043: val_loss did not improve from 0.05303
# Epoch 44/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0550 - accuracy: 0.9813 - val_loss: 0.0690 - val_accuracy: 0.9797
#
# Epoch 00044: val_loss did not improve from 0.05303
# Epoch 45/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0560 - accuracy: 0.9807 - val_loss: 0.0687 - val_accuracy: 0.9807
#
# Epoch 00045: val_loss did not improve from 0.05303
# Epoch 46/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0544 - accuracy: 0.9822 - val_loss: 0.0658 - val_accuracy: 0.9818
#
# Epoch 00046: val_loss did not improve from 0.05303
# Epoch 47/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0558 - accuracy: 0.9820 - val_loss: 0.0656 - val_accuracy: 0.9829
#
# Epoch 00047: val_loss did not improve from 0.05303
# Epoch 48/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0540 - accuracy: 0.9820 - val_loss: 0.0654 - val_accuracy: 0.9818
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00048: val_loss did not improve from 0.05303
# Epoch 49/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0520 - accuracy: 0.9825 - val_loss: 0.0618 - val_accuracy: 0.9839
#
# Epoch 00049: val_loss did not improve from 0.05303
# Epoch 50/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0519 - accuracy: 0.9820 - val_loss: 0.0629 - val_accuracy: 0.9829
#
# Epoch 00050: val_loss did not improve from 0.05303
# Score for fold 3: loss of 0.06289993226528168; accuracy of 98.28693866729736%
# Epoch 1/50
# 263/263 [==============================] - 4s 13ms/step - loss: 1.2191 - accuracy: 0.6594 - val_loss: 0.2287 - val_accuracy: 0.9154
#
# Epoch 00001: val_loss did not improve from 0.05303
# Epoch 2/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.3397 - accuracy: 0.9023 - val_loss: 0.1284 - val_accuracy: 0.9647
#
# Epoch 00002: val_loss did not improve from 0.05303
# Epoch 3/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.2435 - accuracy: 0.9265 - val_loss: 0.1003 - val_accuracy: 0.9690
#
# Epoch 00003: val_loss did not improve from 0.05303
# Epoch 4/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1922 - accuracy: 0.9388 - val_loss: 0.0960 - val_accuracy: 0.9722
#
# Epoch 00004: val_loss did not improve from 0.05303
# Epoch 5/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1646 - accuracy: 0.9485 - val_loss: 0.0917 - val_accuracy: 0.9722
#
# Epoch 00005: val_loss did not improve from 0.05303
# Epoch 6/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1681 - accuracy: 0.9481 - val_loss: 0.0813 - val_accuracy: 0.9754
#
# Epoch 00006: val_loss did not improve from 0.05303
# Epoch 7/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1510 - accuracy: 0.9532 - val_loss: 0.0973 - val_accuracy: 0.9690
#
# Epoch 00007: val_loss did not improve from 0.05303
# Epoch 8/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1532 - accuracy: 0.9510 - val_loss: 0.0826 - val_accuracy: 0.9732
#
# Epoch 00008: val_loss did not improve from 0.05303
# Epoch 9/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1319 - accuracy: 0.9566 - val_loss: 0.0769 - val_accuracy: 0.9743
#
# Epoch 00009: val_loss did not improve from 0.05303
# Epoch 10/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1256 - accuracy: 0.9593 - val_loss: 0.0751 - val_accuracy: 0.9743
#
# Epoch 00010: val_loss did not improve from 0.05303
# Epoch 11/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1184 - accuracy: 0.9631 - val_loss: 0.0764 - val_accuracy: 0.9775
#
# Epoch 00011: val_loss did not improve from 0.05303
# Epoch 12/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1123 - accuracy: 0.9628 - val_loss: 0.0801 - val_accuracy: 0.9775
#
# Epoch 00012: val_loss did not improve from 0.05303
# Epoch 13/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1114 - accuracy: 0.9626 - val_loss: 0.0810 - val_accuracy: 0.9764
#
# Epoch 00013: val_loss did not improve from 0.05303
# Epoch 14/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1419 - accuracy: 0.9550 - val_loss: 0.0769 - val_accuracy: 0.9754
#
# Epoch 00014: val_loss did not improve from 0.05303
# Epoch 15/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1038 - accuracy: 0.9649 - val_loss: 0.0797 - val_accuracy: 0.9732
#
# Epoch 00015: val_loss did not improve from 0.05303
# Epoch 16/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0988 - accuracy: 0.9662 - val_loss: 0.0828 - val_accuracy: 0.9764
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.05303
# Epoch 17/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0872 - accuracy: 0.9703 - val_loss: 0.0709 - val_accuracy: 0.9764
#
# Epoch 00017: val_loss did not improve from 0.05303
# Epoch 18/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0851 - accuracy: 0.9704 - val_loss: 0.0745 - val_accuracy: 0.9764
#
# Epoch 00018: val_loss did not improve from 0.05303
# Epoch 19/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0791 - accuracy: 0.9724 - val_loss: 0.0843 - val_accuracy: 0.9722
#
# Epoch 00019: val_loss did not improve from 0.05303
# Epoch 20/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0752 - accuracy: 0.9753 - val_loss: 0.0688 - val_accuracy: 0.9775
#
# Epoch 00020: val_loss did not improve from 0.05303
# Epoch 21/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0774 - accuracy: 0.9730 - val_loss: 0.0735 - val_accuracy: 0.9775
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.05303
# Epoch 22/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0692 - accuracy: 0.9757 - val_loss: 0.0738 - val_accuracy: 0.9786
#
# Epoch 00022: val_loss did not improve from 0.05303
# Epoch 23/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0687 - accuracy: 0.9761 - val_loss: 0.0739 - val_accuracy: 0.9764
#
# Epoch 00023: val_loss did not improve from 0.05303
# Epoch 24/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0696 - accuracy: 0.9760 - val_loss: 0.0851 - val_accuracy: 0.9722
#
# Epoch 00024: val_loss did not improve from 0.05303
# Epoch 25/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0698 - accuracy: 0.9753 - val_loss: 0.0691 - val_accuracy: 0.9786
#
# Epoch 00025: val_loss did not improve from 0.05303
# Epoch 26/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0669 - accuracy: 0.9768 - val_loss: 0.0726 - val_accuracy: 0.9786
#
# Epoch 00026: val_loss did not improve from 0.05303
# Epoch 27/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0679 - accuracy: 0.9762 - val_loss: 0.0733 - val_accuracy: 0.9807
#
# Epoch 00027: val_loss did not improve from 0.05303
# Epoch 28/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0685 - accuracy: 0.9754 - val_loss: 0.0733 - val_accuracy: 0.9775
#
# Epoch 00028: val_loss did not improve from 0.05303
# Epoch 29/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0635 - accuracy: 0.9783 - val_loss: 0.0738 - val_accuracy: 0.9754
#
# Epoch 00029: val_loss did not improve from 0.05303
# Epoch 30/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0644 - accuracy: 0.9775 - val_loss: 0.0726 - val_accuracy: 0.9797
#
# Epoch 00030: val_loss did not improve from 0.05303
# Epoch 31/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0617 - accuracy: 0.9779 - val_loss: 0.0698 - val_accuracy: 0.9797
#
# Epoch 00031: val_loss did not improve from 0.05303
# Epoch 32/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0613 - accuracy: 0.9779 - val_loss: 0.0694 - val_accuracy: 0.9807
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.05303
# Epoch 33/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0572 - accuracy: 0.9811 - val_loss: 0.0734 - val_accuracy: 0.9807
#
# Epoch 00033: val_loss did not improve from 0.05303
# Epoch 34/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0585 - accuracy: 0.9801 - val_loss: 0.0691 - val_accuracy: 0.9807
#
# Epoch 00034: val_loss did not improve from 0.05303
# Epoch 35/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0584 - accuracy: 0.9805 - val_loss: 0.0706 - val_accuracy: 0.9818
#
# Epoch 00035: val_loss did not improve from 0.05303
# Epoch 36/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0596 - accuracy: 0.9793 - val_loss: 0.0706 - val_accuracy: 0.9786
#
# Epoch 00036: val_loss did not improve from 0.05303
# Epoch 37/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0551 - accuracy: 0.9816 - val_loss: 0.0707 - val_accuracy: 0.9786
#
# Epoch 00037: val_loss did not improve from 0.05303
# Epoch 38/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0586 - accuracy: 0.9799 - val_loss: 0.0688 - val_accuracy: 0.9797
# Epoch 00038: val_loss did not improve from 0.05303
# Epoch 39/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0599 - accuracy: 0.9791 - val_loss: 0.0722 - val_accuracy: 0.9807
#
# Epoch 00039: val_loss did not improve from 0.05303
# Epoch 40/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0573 - accuracy: 0.9806 - val_loss: 0.0715 - val_accuracy: 0.9764
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00040: val_loss did not improve from 0.05303
# Epoch 41/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0572 - accuracy: 0.9793 - val_loss: 0.0761 - val_accuracy: 0.9786
#
# Epoch 00041: val_loss did not improve from 0.05303
# Epoch 42/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0554 - accuracy: 0.9804 - val_loss: 0.0734 - val_accuracy: 0.9775
#
# Epoch 00042: val_loss did not improve from 0.05303
# Epoch 43/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0549 - accuracy: 0.9810 - val_loss: 0.0757 - val_accuracy: 0.9775
#
# Epoch 00043: val_loss did not improve from 0.05303
# Epoch 44/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0591 - accuracy: 0.9797 - val_loss: 0.0721 - val_accuracy: 0.9786
#
# Epoch 00044: val_loss did not improve from 0.05303
# Epoch 45/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0561 - accuracy: 0.9805 - val_loss: 0.0759 - val_accuracy: 0.9786
#
# Epoch 00045: val_loss did not improve from 0.05303
# Epoch 46/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0562 - accuracy: 0.9806 - val_loss: 0.0702 - val_accuracy: 0.9786
#
# Epoch 00046: val_loss did not improve from 0.05303
# Epoch 47/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0543 - accuracy: 0.9814 - val_loss: 0.0720 - val_accuracy: 0.9797
#
# Epoch 00047: val_loss did not improve from 0.05303
# Epoch 48/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0551 - accuracy: 0.9814 - val_loss: 0.0715 - val_accuracy: 0.9807
#
# Epoch 00048: val_loss did not improve from 0.05303
# Epoch 49/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0568 - accuracy: 0.9805 - val_loss: 0.0749 - val_accuracy: 0.9807
#
# Epoch 00049: val_loss did not improve from 0.05303
# Epoch 50/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0540 - accuracy: 0.9822 - val_loss: 0.0684 - val_accuracy: 0.9807
#
# Epoch 00050: val_loss did not improve from 0.05303
# Score for fold 4: loss of 0.0684090405702591; accuracy of 98.0728030204773%
# Epoch 1/50
# 263/263 [==============================] - 4s 15ms/step - loss: 1.5052 - accuracy: 0.5764 - val_loss: 0.4511 - val_accuracy: 0.8694
#
# Epoch 00001: val_loss did not improve from 0.05303
# Epoch 2/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.4714 - accuracy: 0.8565 - val_loss: 0.2233 - val_accuracy: 0.9251
#
# Epoch 00002: val_loss did not improve from 0.05303
# Epoch 3/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.3217 - accuracy: 0.8998 - val_loss: 0.1418 - val_accuracy: 0.9507
#
# Epoch 00003: val_loss did not improve from 0.05303
# Epoch 4/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.2457 - accuracy: 0.9248 - val_loss: 0.1379 - val_accuracy: 0.9497
#
# Epoch 00004: val_loss did not improve from 0.05303
# Epoch 5/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2294 - accuracy: 0.9267 - val_loss: 0.1121 - val_accuracy: 0.9582
#
# Epoch 00005: val_loss did not improve from 0.05303
# Epoch 6/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.2170 - accuracy: 0.9328 - val_loss: 0.1048 - val_accuracy: 0.9593
#
# Epoch 00006: val_loss did not improve from 0.05303
# Epoch 7/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.2013 - accuracy: 0.9369 - val_loss: 0.0935 - val_accuracy: 0.9615
#
# Epoch 00007: val_loss did not improve from 0.05303
# Epoch 8/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1723 - accuracy: 0.9457 - val_loss: 0.0905 - val_accuracy: 0.9679
#
# Epoch 00008: val_loss did not improve from 0.05303
# Epoch 9/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1588 - accuracy: 0.9475 - val_loss: 0.0762 - val_accuracy: 0.9743
#
# Epoch 00009: val_loss did not improve from 0.05303
# Epoch 10/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1568 - accuracy: 0.9465 - val_loss: 0.0782 - val_accuracy: 0.9711
#
# Epoch 00010: val_loss did not improve from 0.05303
# Epoch 11/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1463 - accuracy: 0.9510 - val_loss: 0.0777 - val_accuracy: 0.9690
#
# Epoch 00011: val_loss did not improve from 0.05303
# Epoch 12/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1468 - accuracy: 0.9492 - val_loss: 0.0802 - val_accuracy: 0.9690
#
# Epoch 00012: val_loss did not improve from 0.05303
# Epoch 13/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1485 - accuracy: 0.9515 - val_loss: 0.0745 - val_accuracy: 0.9743
#
# Epoch 00013: val_loss did not improve from 0.05303
# Epoch 14/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1315 - accuracy: 0.9566 - val_loss: 0.0765 - val_accuracy: 0.9700
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.05303
# Epoch 15/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1101 - accuracy: 0.9622 - val_loss: 0.0695 - val_accuracy: 0.9743
#
# Epoch 00015: val_loss did not improve from 0.05303
# Epoch 16/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1016 - accuracy: 0.9642 - val_loss: 0.0696 - val_accuracy: 0.9722
#
# Epoch 00016: val_loss did not improve from 0.05303
# Epoch 17/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1044 - accuracy: 0.9654 - val_loss: 0.0653 - val_accuracy: 0.9754
#
# Epoch 00017: val_loss did not improve from 0.05303
# Epoch 18/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0989 - accuracy: 0.9660 - val_loss: 0.0629 - val_accuracy: 0.9775
#
# Epoch 00018: val_loss did not improve from 0.05303
# Epoch 19/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0952 - accuracy: 0.9673 - val_loss: 0.0672 - val_accuracy: 0.9807
#
# Epoch 00019: val_loss did not improve from 0.05303
# Epoch 20/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1006 - accuracy: 0.9669 - val_loss: 0.0733 - val_accuracy: 0.9764
#
# Epoch 00020: val_loss did not improve from 0.05303
# Epoch 21/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0971 - accuracy: 0.9663 - val_loss: 0.0663 - val_accuracy: 0.9786
#
# Epoch 00021: val_loss did not improve from 0.05303
# Epoch 22/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0892 - accuracy: 0.9681 - val_loss: 0.0775 - val_accuracy: 0.9700
#
# ...
# Epoch 23/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1130 - accuracy: 0.9604 - val_loss: 0.1135 - val_accuracy: 0.9582
#
# Epoch 00023: val_loss did not improve from 0.05303
# Epoch 24/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1073 - accuracy: 0.9612 - val_loss: 0.1149 - val_accuracy: 0.9625
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.05303
# Epoch 25/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0992 - accuracy: 0.9629 - val_loss: 0.0994 - val_accuracy: 0.9668
#
# Epoch 00025: val_loss did not improve from 0.05303
# Epoch 26/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0912 - accuracy: 0.9673 - val_loss: 0.0973 - val_accuracy: 0.9668
#
# Epoch 00026: val_loss did not improve from 0.05303
# Epoch 27/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0926 - accuracy: 0.9664 - val_loss: 0.0988 - val_accuracy: 0.9647
#
# Epoch 00027: val_loss did not improve from 0.05303
# Epoch 28/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0910 - accuracy: 0.9675 - val_loss: 0.1080 - val_accuracy: 0.9657
#
# Epoch 00028: val_loss did not improve from 0.05303
# Epoch 29/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0886 - accuracy: 0.9681 - val_loss: 0.0987 - val_accuracy: 0.9690
#
# Epoch 00029: val_loss did not improve from 0.05303
# Epoch 30/50
# 263/263 [==============================] - 4s 13ms/step - loss: 0.0968 - accuracy: 0.9648 - val_loss: 0.1053 - val_accuracy: 0.9668
# Epoch 00030: val_loss did not improve from 0.05303
# Epoch 31/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0921 - accuracy: 0.9664 - val_loss: 0.0979 - val_accuracy: 0.9647
#
# Epoch 00031: val_loss did not improve from 0.05303
# Epoch 32/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0901 - accuracy: 0.9685 - val_loss: 0.1007 - val_accuracy: 0.9647
#
# Epoch 00032: val_loss did not improve from 0.05303
# Epoch 33/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0859 - accuracy: 0.9692 - val_loss: 0.0909 - val_accuracy: 0.9647
#
# Epoch 00033: val_loss did not improve from 0.05303
# Epoch 34/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0893 - accuracy: 0.9678 - val_loss: 0.0920 - val_accuracy: 0.9668
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_loss did not improve from 0.05303
# Epoch 35/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0844 - accuracy: 0.9675 - val_loss: 0.0909 - val_accuracy: 0.9722
#
# Epoch 00035: val_loss did not improve from 0.05303
# Epoch 36/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0836 - accuracy: 0.9684 - val_loss: 0.0940 - val_accuracy: 0.9668
#
# Epoch 00036: val_loss did not improve from 0.05303
# Epoch 37/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0855 - accuracy: 0.9680 - val_loss: 0.0864 - val_accuracy: 0.9679
#
# Epoch 00037: val_loss did not improve from 0.05303
# Epoch 38/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0843 - accuracy: 0.9700 - val_loss: 0.0946 - val_accuracy: 0.9668
#
# Epoch 00038: val_loss did not improve from 0.05303
# Epoch 39/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0844 - accuracy: 0.9688 - val_loss: 0.0909 - val_accuracy: 0.9679
#
# Epoch 00039: val_loss did not improve from 0.05303
# Epoch 40/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0845 - accuracy: 0.9686 - val_loss: 0.0912 - val_accuracy: 0.9690
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00040: val_loss did not improve from 0.05303
# Epoch 41/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0805 - accuracy: 0.9709 - val_loss: 0.0934 - val_accuracy: 0.9690
#
# Epoch 00041: val_loss did not improve from 0.05303
# Epoch 42/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0810 - accuracy: 0.9697 - val_loss: 0.0882 - val_accuracy: 0.9700
#
# Epoch 00042: val_loss did not improve from 0.05303
# Epoch 43/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0813 - accuracy: 0.9711 - val_loss: 0.0910 - val_accuracy: 0.9690
#
# Epoch 00043: val_loss did not improve from 0.05303
# Epoch 44/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0816 - accuracy: 0.9691 - val_loss: 0.0940 - val_accuracy: 0.9679
#
# Epoch 00044: val_loss did not improve from 0.05303
# Epoch 45/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0806 - accuracy: 0.9731 - val_loss: 0.0929 - val_accuracy: 0.9679
#
# Epoch 00045: val_loss did not improve from 0.05303
# Epoch 46/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0755 - accuracy: 0.9728 - val_loss: 0.0920 - val_accuracy: 0.9679
#
# Epoch 00046: val_loss did not improve from 0.05303
# Epoch 47/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0759 - accuracy: 0.9723 - val_loss: 0.0927 - val_accuracy: 0.9690
#
# Epoch 00047: val_loss did not improve from 0.05303
# Epoch 48/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0765 - accuracy: 0.9712 - val_loss: 0.0890 - val_accuracy: 0.9690
#
# Epoch 00048: val_loss did not improve from 0.05303
# Epoch 49/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0746 - accuracy: 0.9725 - val_loss: 0.0876 - val_accuracy: 0.9700
#
# Epoch 00049: val_loss did not improve from 0.05303
# Epoch 50/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0804 - accuracy: 0.9692 - val_loss: 0.0914 - val_accuracy: 0.9668
#
# Epoch 00050: val_loss did not improve from 0.05303
# Score for fold 9: loss of 0.09143032133579254; accuracy of 96.68094515800476%
# Epoch 1/50
# 263/263 [==============================] - 4s 13ms/step - loss: 1.4947 - accuracy: 0.5666 - val_loss: 0.3964 - val_accuracy: 0.8746
#
# Epoch 00001: val_loss did not improve from 0.05303
# Epoch 2/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.4423 - accuracy: 0.8626 - val_loss: 0.1903 - val_accuracy: 0.9421
#
# Epoch 00002: val_loss did not improve from 0.05303
# Epoch 3/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.3049 - accuracy: 0.9063 - val_loss: 0.1719 - val_accuracy: 0.9368
#
# Epoch 00003: val_loss did not improve from 0.05303
# Epoch 4/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2569 - accuracy: 0.9180 - val_loss: 0.1204 - val_accuracy: 0.9539
#
# Epoch 00004: val_loss did not improve from 0.05303
# Epoch 5/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2199 - accuracy: 0.9273 - val_loss: 0.1192 - val_accuracy: 0.9582
#
# Epoch 00005: val_loss did not improve from 0.05303
# Epoch 6/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2085 - accuracy: 0.9322 - val_loss: 0.1122 - val_accuracy: 0.9625
#
# Epoch 00006: val_loss did not improve from 0.05303
# Epoch 7/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1775 - accuracy: 0.9403 - val_loss: 0.1049 - val_accuracy: 0.9668
#
# Epoch 00007: val_loss did not improve from 0.05303
# Epoch 8/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1612 - accuracy: 0.9453 - val_loss: 0.1131 - val_accuracy: 0.9636
#
# Epoch 00008: val_loss did not improve from 0.05303
# Epoch 9/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1691 - accuracy: 0.9425 - val_loss: 0.0866 - val_accuracy: 0.9689
#
# Epoch 00009: val_loss did not improve from 0.05303
# Epoch 10/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1489 - accuracy: 0.9504 - val_loss: 0.1063 - val_accuracy: 0.9700
#
# Epoch 00010: val_loss did not improve from 0.05303
# Epoch 11/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1527 - accuracy: 0.9484 - val_loss: 0.0901 - val_accuracy: 0.9700
#
# Epoch 00011: val_loss did not improve from 0.05303
# Epoch 12/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1493 - accuracy: 0.9509 - val_loss: 0.0962 - val_accuracy: 0.9700
#
# Epoch 00012: val_loss did not improve from 0.05303
# Epoch 13/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1313 - accuracy: 0.9554 - val_loss: 0.1024 - val_accuracy: 0.9625
#
# Epoch 00013: val_loss did not improve from 0.05303
# Epoch 14/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1325 - accuracy: 0.9538 - val_loss: 0.1095 - val_accuracy: 0.9646
#
# Epoch 00014: val_loss did not improve from 0.05303
# Epoch 15/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1214 - accuracy: 0.9599 - val_loss: 0.0983 - val_accuracy: 0.9711
#
# Epoch 00015: val_loss did not improve from 0.05303
# Epoch 16/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1291 - accuracy: 0.9552 - val_loss: 0.0899 - val_accuracy: 0.9732
#
# Epoch 00016: val_loss did not improve from 0.05303
# Epoch 17/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1229 - accuracy: 0.9559 - val_loss: 0.0891 - val_accuracy: 0.9721
#
# Epoch 00017: val_loss did not improve from 0.05303
# Epoch 18/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1142 - accuracy: 0.9601 - val_loss: 0.0811 - val_accuracy: 0.9764
#
# Epoch 00018: val_loss did not improve from 0.05303
# Epoch 19/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1026 - accuracy: 0.9647 - val_loss: 0.0987 - val_accuracy: 0.9700
#
# Epoch 00019: val_loss did not improve from 0.05303
# Epoch 20/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.1123 - accuracy: 0.9610 - val_loss: 0.0856 - val_accuracy: 0.9689
#
# Epoch 00020: val_loss did not improve from 0.05303
# Epoch 21/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1030 - accuracy: 0.9651 - val_loss: 0.0876 - val_accuracy: 0.9700
#
# Epoch 00021: val_loss did not improve from 0.05303
# Epoch 22/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.1090 - accuracy: 0.9630 - val_loss: 0.0901 - val_accuracy: 0.9689
#
# Epoch 00022: val_loss did not improve from 0.05303
# Epoch 23/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.1002 - accuracy: 0.9650 - val_loss: 0.0993 - val_accuracy: 0.9721
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.05303
# Epoch 24/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0885 - accuracy: 0.9699 - val_loss: 0.0846 - val_accuracy: 0.9711
#
# Epoch 00024: val_loss did not improve from 0.05303
# Epoch 25/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0785 - accuracy: 0.9736 - val_loss: 0.0901 - val_accuracy: 0.9700
#
# Epoch 00025: val_loss did not improve from 0.05303
# Epoch 26/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0830 - accuracy: 0.9722 - val_loss: 0.0967 - val_accuracy: 0.9743
#
# Epoch 00026: val_loss did not improve from 0.05303
# Epoch 27/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0816 - accuracy: 0.9712 - val_loss: 0.0854 - val_accuracy: 0.9743
#
# Epoch 00027: val_loss did not improve from 0.05303
# Epoch 28/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0789 - accuracy: 0.9718 - val_loss: 0.0825 - val_accuracy: 0.9764
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.05303
# Epoch 29/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0751 - accuracy: 0.9731 - val_loss: 0.0909 - val_accuracy: 0.9721
#
# Epoch 00029: val_loss did not improve from 0.05303
# Epoch 30/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0738 - accuracy: 0.9749 - val_loss: 0.0868 - val_accuracy: 0.9753
#
# Epoch 00030: val_loss did not improve from 0.05303
# Epoch 31/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0696 - accuracy: 0.9751 - val_loss: 0.0833 - val_accuracy: 0.9721
#
# Epoch 00031: val_loss did not improve from 0.05303
# Epoch 32/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0719 - accuracy: 0.9749 - val_loss: 0.0882 - val_accuracy: 0.9721
#
# Epoch 00032: val_loss did not improve from 0.05303
# Epoch 33/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0689 - accuracy: 0.9750 - val_loss: 0.0900 - val_accuracy: 0.9732
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.05303
# Epoch 34/50
# 263/263 [==============================] - 4s 14ms/step - loss: 0.0700 - accuracy: 0.9755 - val_loss: 0.0931 - val_accuracy: 0.9678
#
# Epoch 00034: val_loss did not improve from 0.05303
# Epoch 35/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0666 - accuracy: 0.9762 - val_loss: 0.0886 - val_accuracy: 0.9721
#
# Epoch 00035: val_loss did not improve from 0.05303
# Epoch 36/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0642 - accuracy: 0.9761 - val_loss: 0.0875 - val_accuracy: 0.9721
#
# Epoch 00036: val_loss did not improve from 0.05303
# Epoch 37/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0622 - accuracy: 0.9776 - val_loss: 0.0879 - val_accuracy: 0.9721
#
# Epoch 00037: val_loss did not improve from 0.05303
# Epoch 38/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0646 - accuracy: 0.9785 - val_loss: 0.0895 - val_accuracy: 0.9711
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00038: val_loss did not improve from 0.05303
# Epoch 39/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0614 - accuracy: 0.9780 - val_loss: 0.0898 - val_accuracy: 0.9732
#
# Epoch 00039: val_loss did not improve from 0.05303
# Epoch 40/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0654 - accuracy: 0.9761 - val_loss: 0.0847 - val_accuracy: 0.9711
#
# Epoch 00040: val_loss did not improve from 0.05303
# Epoch 41/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0641 - accuracy: 0.9767 - val_loss: 0.0864 - val_accuracy: 0.9700
#
# Epoch 00041: val_loss did not improve from 0.05303
# Epoch 42/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0659 - accuracy: 0.9772 - val_loss: 0.0881 - val_accuracy: 0.9711
#
# Epoch 00042: val_loss did not improve from 0.05303
# Epoch 43/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0620 - accuracy: 0.9791 - val_loss: 0.0900 - val_accuracy: 0.9732
#
# Epoch 00043: val_loss did not improve from 0.05303
# Epoch 44/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0610 - accuracy: 0.9794 - val_loss: 0.0960 - val_accuracy: 0.9711
#
# Epoch 00044: val_loss did not improve from 0.05303
# Epoch 45/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0652 - accuracy: 0.9767 - val_loss: 0.0864 - val_accuracy: 0.9711
#
# Epoch 00045: val_loss did not improve from 0.05303
# Epoch 46/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0613 - accuracy: 0.9787 - val_loss: 0.0914 - val_accuracy: 0.9700
#
# Epoch 00046: val_loss did not improve from 0.05303
# Epoch 47/50
# 263/263 [==============================] - 3s 13ms/step - loss: 0.0587 - accuracy: 0.9806 - val_loss: 0.0847 - val_accuracy: 0.9732
#
# Epoch 00047: val_loss did not improve from 0.05303
# Epoch 48/50
# 263/263 [==============================] - 4s 13ms/step - loss: 0.0643 - accuracy: 0.9772 - val_loss: 0.0863 - val_accuracy: 0.9753
#
# Epoch 00048: val_loss did not improve from 0.05303
# Epoch 49/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0604 - accuracy: 0.9793 - val_loss: 0.0919 - val_accuracy: 0.9700
#
# Epoch 00049: val_loss did not improve from 0.05303
# Epoch 50/50
# 263/263 [==============================] - 3s 12ms/step - loss: 0.0586 - accuracy: 0.9797 - val_loss: 0.0922 - val_accuracy: 0.9721
#
# Epoch 00050: val_loss did not improve from 0.05303
# Score for fold 10: loss of 0.09219908714294434; accuracy of 97.2132921218872%

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.08762793242931366 - Accuracy: 97.10921049118042%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.1060974970459938 - Accuracy: 97.32334017753601%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.06289993226528168 - Accuracy: 98.28693866729736%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.0684090405702591 - Accuracy: 98.0728030204773%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.06195078045129776 - Accuracy: 97.96574115753174%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.12227918952703476 - Accuracy: 97.43040800094604%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.11925011873245239 - Accuracy: 97.21627235412598%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.07088097184896469 - Accuracy: 97.32334017753601%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.09143032133579254 - Accuracy: 96.68094515800476%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.09219908714294434 - Accuracy: 97.2132921218872%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 97.46222913265228% (+- 0.0046942035521006864)
# > Loss: 0.08830248713493347
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the Malimg dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1     ', round(np.mean(multi_f1_per_fold),4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN on Malimg"
print(t)
# Out:
# +--------------------------------------------+
# |        Performance of CNN on Malimg        |
# | Metric        | Performance | St.Deviation |
# | M-Class       |             |              |
# | Acc           | 0.9746      | 0.0047       |
# | Loss          | 0.0883      | 0.0212       |
# | Macro F1      | 0.9186      | 0.011        |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0, 1.2)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8, 1)

# %% [markdown]
# **Confusion Matrix**

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)
