# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 02

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 7 matches(es) found
# --------------
# New folder name: cnn-local-v011
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"
    path_root_gen = '/kaggle/input/cganlocalv007/cgan-local-v008'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-ckpt-local-v009"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 150000 images belonging to 10 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 1997/1997 [==============================] - 17s 6ms/step - loss: 0.2279 - accuracy: 0.9340 - val_loss: 0.3030 - val_accuracy: 0.9115
#
# Epoch 00001: val_loss improved from inf to 0.30299, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 2/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.1148 - accuracy: 0.9661 - val_loss: 0.2578 - val_accuracy: 0.9228
#
# Epoch 00002: val_loss improved from 0.30299 to 0.25778, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 3/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0983 - accuracy: 0.9697 - val_loss: 0.2158 - val_accuracy: 0.9330
#
# Epoch 00003: val_loss improved from 0.25778 to 0.21575, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 4/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0844 - accuracy: 0.9742 - val_loss: 0.2188 - val_accuracy: 0.9326
#
# Epoch 00004: val_loss did not improve from 0.21575
# Epoch 5/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 0.1867 - val_accuracy: 0.9394
#
# Epoch 00005: val_loss improved from 0.21575 to 0.18667, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 6/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0715 - accuracy: 0.9776 - val_loss: 0.1723 - val_accuracy: 0.9465
#
# Epoch 00006: val_loss improved from 0.18667 to 0.17227, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 7/35
# 1997/1997 [==============================] - 13s 7ms/step - loss: 0.0665 - accuracy: 0.9787 - val_loss: 0.1710 - val_accuracy: 0.9454
#
# Epoch 00007: val_loss improved from 0.17227 to 0.17101, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 8/35
# 1997/1997 [==============================] - 13s 6ms/step - loss: 0.0624 - accuracy: 0.9800 - val_loss: 0.1806 - val_accuracy: 0.9431
#
# Epoch 00008: val_loss did not improve from 0.17101
# Epoch 9/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0584 - accuracy: 0.9811 - val_loss: 0.1689 - val_accuracy: 0.9476
#
# Epoch 00009: val_loss improved from 0.17101 to 0.16888, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 10/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0554 - accuracy: 0.9821 - val_loss: 0.1645 - val_accuracy: 0.9514
#
# Epoch 00010: val_loss improved from 0.16888 to 0.16455, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 11/35
# 1997/1997 [==============================] - 13s 7ms/step - loss: 0.0523 - accuracy: 0.9830 - val_loss: 0.1640 - val_accuracy: 0.9499
#
# Epoch 00011: val_loss improved from 0.16455 to 0.16402, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 12/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0514 - accuracy: 0.9832 - val_loss: 0.1533 - val_accuracy: 0.9514
#
# Epoch 00012: val_loss improved from 0.16402 to 0.15329, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 13/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0466 - accuracy: 0.9847 - val_loss: 0.1448 - val_accuracy: 0.9537
#
# Epoch 00013: val_loss improved from 0.15329 to 0.14479, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 14/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0454 - accuracy: 0.9849 - val_loss: 0.1804 - val_accuracy: 0.9529
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0448 - accuracy: 0.9854 - val_loss: 0.1762 - val_accuracy: 0.9510
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0437 - accuracy: 0.9862 - val_loss: 0.1734 - val_accuracy: 0.9510
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 16s 8ms/step - loss: 0.0430 - accuracy: 0.9859 - val_loss: 0.1699 - val_accuracy: 0.9514
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 23s 12ms/step - loss: 0.0403 - accuracy: 0.9872 - val_loss: 0.1677 - val_accuracy: 0.9563
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 22s 11ms/step - loss: 0.0389 - accuracy: 0.9875 - val_loss: 0.1776 - val_accuracy: 0.9529
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 16s 8ms/step - loss: 0.0387 - accuracy: 0.9873 - val_loss: 0.1693 - val_accuracy: 0.9540
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 13s 6ms/step - loss: 0.0377 - accuracy: 0.9875 - val_loss: 0.1593 - val_accuracy: 0.9571
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0372 - accuracy: 0.9882 - val_loss: 0.1581 - val_accuracy: 0.9556
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0356 - accuracy: 0.9883 - val_loss: 0.1610 - val_accuracy: 0.9548
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 0.1685 - val_accuracy: 0.9567
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.1664 - val_accuracy: 0.9529
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0320 - accuracy: 0.9893 - val_loss: 0.1800 - val_accuracy: 0.9578
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0331 - accuracy: 0.9892 - val_loss: 0.1870 - val_accuracy: 0.9525
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0339 - accuracy: 0.9888 - val_loss: 0.1663 - val_accuracy: 0.9556
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0316 - accuracy: 0.9898 - val_loss: 0.1696 - val_accuracy: 0.9563
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.1942 - val_accuracy: 0.9529
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0322 - accuracy: 0.9893 - val_loss: 0.1614 - val_accuracy: 0.9559
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0249 - accuracy: 0.9915 - val_loss: 0.1874 - val_accuracy: 0.9529
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.1838 - val_accuracy: 0.9559
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.0226 - accuracy: 0.9922 - val_loss: 0.1906 - val_accuracy: 0.9563
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0220 - accuracy: 0.9923 - val_loss: 0.2032 - val_accuracy: 0.9563
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 1: loss of 0.20321743190288544; accuracy of 95.63088417053223%
# Epoch 1/35
# 1997/1997 [==============================] - 12s 6ms/step - loss: 0.2168 - accuracy: 0.9364 - val_loss: 0.2842 - val_accuracy: 0.9141
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.1089 - accuracy: 0.9676 - val_loss: 0.2422 - val_accuracy: 0.9247
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0917 - accuracy: 0.9715 - val_loss: 0.2404 - val_accuracy: 0.9220
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0800 - accuracy: 0.9747 - val_loss: 0.2049 - val_accuracy: 0.9360
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0723 - accuracy: 0.9772 - val_loss: 0.1934 - val_accuracy: 0.9401
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0675 - accuracy: 0.9782 - val_loss: 0.2208 - val_accuracy: 0.9341
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0626 - accuracy: 0.9796 - val_loss: 0.1986 - val_accuracy: 0.9420
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0583 - accuracy: 0.9807 - val_loss: 0.1961 - val_accuracy: 0.9412
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0545 - accuracy: 0.9827 - val_loss: 0.1811 - val_accuracy: 0.9473
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0511 - accuracy: 0.9833 - val_loss: 0.1893 - val_accuracy: 0.9465
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0492 - accuracy: 0.9841 - val_loss: 0.1883 - val_accuracy: 0.9473
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0466 - accuracy: 0.9845 - val_loss: 0.1852 - val_accuracy: 0.9473
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0457 - accuracy: 0.9856 - val_loss: 0.1841 - val_accuracy: 0.9480
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0441 - accuracy: 0.9857 - val_loss: 0.1807 - val_accuracy: 0.9484
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0404 - accuracy: 0.9867 - val_loss: 0.2041 - val_accuracy: 0.9465
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0423 - accuracy: 0.9864 - val_loss: 0.1884 - val_accuracy: 0.9473
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0390 - accuracy: 0.9876 - val_loss: 0.1967 - val_accuracy: 0.9476
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.2134 - val_accuracy: 0.9492
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.2141 - val_accuracy: 0.9484
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.1971 - val_accuracy: 0.9503
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 0.2026 - val_accuracy: 0.9533
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.2003 - val_accuracy: 0.9518
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 0.2205 - val_accuracy: 0.9492
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0342 - accuracy: 0.9893 - val_loss: 0.2257 - val_accuracy: 0.9469
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0330 - accuracy: 0.9894 - val_loss: 0.2069 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0323 - accuracy: 0.9898 - val_loss: 0.1981 - val_accuracy: 0.9507
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.2071 - val_accuracy: 0.9503
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0258 - accuracy: 0.9913 - val_loss: 0.2253 - val_accuracy: 0.9522
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.2033 - val_accuracy: 0.9525
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0240 - accuracy: 0.9918 - val_loss: 0.2069 - val_accuracy: 0.9529
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0237 - accuracy: 0.9918 - val_loss: 0.2166 - val_accuracy: 0.9518
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.2258 - val_accuracy: 0.9510
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.2277 - val_accuracy: 0.9518
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0193 - accuracy: 0.9934 - val_loss: 0.2426 - val_accuracy: 0.9518
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0201 - accuracy: 0.9930 - val_loss: 0.2576 - val_accuracy: 0.9510
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 2: loss of 0.25763270258903503; accuracy of 95.10357975959778%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.2224 - accuracy: 0.9362 - val_loss: 0.3030 - val_accuracy: 0.8949
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1175 - accuracy: 0.9655 - val_loss: 0.2262 - val_accuracy: 0.9288
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0963 - accuracy: 0.9705 - val_loss: 0.2030 - val_accuracy: 0.9363
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0862 - accuracy: 0.9724 - val_loss: 0.1856 - val_accuracy: 0.9427
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0776 - accuracy: 0.9753 - val_loss: 0.1730 - val_accuracy: 0.9469
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0709 - accuracy: 0.9773 - val_loss: 0.1688 - val_accuracy: 0.9431
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0672 - accuracy: 0.9786 - val_loss: 0.1868 - val_accuracy: 0.9458
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0638 - accuracy: 0.9794 - val_loss: 0.1659 - val_accuracy: 0.9488
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0589 - accuracy: 0.9808 - val_loss: 0.1630 - val_accuracy: 0.9480
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0556 - accuracy: 0.9818 - val_loss: 0.1536 - val_accuracy: 0.9533
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0518 - accuracy: 0.9838 - val_loss: 0.1629 - val_accuracy: 0.9518
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0515 - accuracy: 0.9836 - val_loss: 0.1805 - val_accuracy: 0.9514
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0497 - accuracy: 0.9839 - val_loss: 0.1603 - val_accuracy: 0.9529
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0469 - accuracy: 0.9846 - val_loss: 0.1633 - val_accuracy: 0.9540
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0463 - accuracy: 0.9854 - val_loss: 0.1657 - val_accuracy: 0.9548
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0434 - accuracy: 0.9860 - val_loss: 0.1746 - val_accuracy: 0.9533
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0436 - accuracy: 0.9855 - val_loss: 0.1781 - val_accuracy: 0.9552
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0417 - accuracy: 0.9864 - val_loss: 0.1647 - val_accuracy: 0.9529
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0420 - accuracy: 0.9861 - val_loss: 0.1636 - val_accuracy: 0.9552
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 0.1647 - val_accuracy: 0.9552
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0378 - accuracy: 0.9877 - val_loss: 0.1748 - val_accuracy: 0.9559
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0403 - accuracy: 0.9874 - val_loss: 0.1778 - val_accuracy: 0.9544
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.1655 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0367 - accuracy: 0.9877 - val_loss: 0.2026 - val_accuracy: 0.9544
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0354 - accuracy: 0.9884 - val_loss: 0.1900 - val_accuracy: 0.9559
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0344 - accuracy: 0.9888 - val_loss: 0.1879 - val_accuracy: 0.9548
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.1804 - val_accuracy: 0.9544
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0352 - accuracy: 0.9887 - val_loss: 0.1772 - val_accuracy: 0.9540
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0278 - accuracy: 0.9906 - val_loss: 0.1754 - val_accuracy: 0.9586
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0260 - accuracy: 0.9911 - val_loss: 0.1807 - val_accuracy: 0.9563
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0255 - accuracy: 0.9914 - val_loss: 0.1916 - val_accuracy: 0.9582
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.1979 - val_accuracy: 0.9582
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 0.2000 - val_accuracy: 0.9563
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.2152 - val_accuracy: 0.9574
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0225 - accuracy: 0.9921 - val_loss: 0.1971 - val_accuracy: 0.9567
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 3: loss of 0.19705146551132202; accuracy of 95.6685483455658%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.2152 - accuracy: 0.9388 - val_loss: 0.2828 - val_accuracy: 0.9175
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1121 - accuracy: 0.9668 - val_loss: 0.2425 - val_accuracy: 0.9273
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0953 - accuracy: 0.9714 - val_loss: 0.2155 - val_accuracy: 0.9367
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0843 - accuracy: 0.9742 - val_loss: 0.1912 - val_accuracy: 0.9379
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0743 - accuracy: 0.9766 - val_loss: 0.1825 - val_accuracy: 0.9424
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 11s 6ms/step - loss: 0.0691 - accuracy: 0.9782 - val_loss: 0.1918 - val_accuracy: 0.9409
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0630 - accuracy: 0.9795 - val_loss: 0.1815 - val_accuracy: 0.9461
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0601 - accuracy: 0.9806 - val_loss: 0.1729 - val_accuracy: 0.9461
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 0.1974 - val_accuracy: 0.9435
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0531 - accuracy: 0.9830 - val_loss: 0.1693 - val_accuracy: 0.9503
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0507 - accuracy: 0.9836 - val_loss: 0.1807 - val_accuracy: 0.9458
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0478 - accuracy: 0.9844 - val_loss: 0.1814 - val_accuracy: 0.9503
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0444 - accuracy: 0.9855 - val_loss: 0.1920 - val_accuracy: 0.9473
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0432 - accuracy: 0.9860 - val_loss: 0.1735 - val_accuracy: 0.9552
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0408 - accuracy: 0.9868 - val_loss: 0.1816 - val_accuracy: 0.9518
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0405 - accuracy: 0.9870 - val_loss: 0.1794 - val_accuracy: 0.9495
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0383 - accuracy: 0.9876 - val_loss: 0.1674 - val_accuracy: 0.9548
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0388 - accuracy: 0.9873 - val_loss: 0.1737 - val_accuracy: 0.9492
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0365 - accuracy: 0.9882 - val_loss: 0.1759 - val_accuracy: 0.9552
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0305 - accuracy: 0.9896 - val_loss: 0.1858 - val_accuracy: 0.9559
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0290 - accuracy: 0.9904 - val_loss: 0.1905 - val_accuracy: 0.9559
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0283 - accuracy: 0.9908 - val_loss: 0.1879 - val_accuracy: 0.9518
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0287 - accuracy: 0.9904 - val_loss: 0.1996 - val_accuracy: 0.9525
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.1860 - val_accuracy: 0.9533
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.2034 - val_accuracy: 0.9544
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.2167 - val_accuracy: 0.9540
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0229 - accuracy: 0.9923 - val_loss: 0.2046 - val_accuracy: 0.9537
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.2036 - val_accuracy: 0.9556
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0209 - accuracy: 0.9928 - val_loss: 0.2216 - val_accuracy: 0.9548
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.2113 - val_accuracy: 0.9548
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 0.2185 - val_accuracy: 0.9571
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0195 - accuracy: 0.9929 - val_loss: 0.2184 - val_accuracy: 0.9567
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.2310 - val_accuracy: 0.9559
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.2175 - val_accuracy: 0.9556
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.2336 - val_accuracy: 0.9563
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 4: loss of 0.23362568020820618; accuracy of 95.63088417053223%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2304 - accuracy: 0.9320 - val_loss: 0.2849 - val_accuracy: 0.9205
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.1181 - accuracy: 0.9649 - val_loss: 0.2289 - val_accuracy: 0.9315
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0972 - accuracy: 0.9704 - val_loss: 0.2055 - val_accuracy: 0.9345
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0864 - accuracy: 0.9738 - val_loss: 0.1882 - val_accuracy: 0.9397
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0785 - accuracy: 0.9752 - val_loss: 0.1869 - val_accuracy: 0.9397
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0716 - accuracy: 0.9780 - val_loss: 0.1782 - val_accuracy: 0.9435
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0678 - accuracy: 0.9786 - val_loss: 0.1780 - val_accuracy: 0.9443
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0623 - accuracy: 0.9802 - val_loss: 0.1716 - val_accuracy: 0.9458
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0593 - accuracy: 0.9811 - val_loss: 0.1716 - val_accuracy: 0.9484
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0554 - accuracy: 0.9818 - val_loss: 0.1827 - val_accuracy: 0.9473
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0528 - accuracy: 0.9828 - val_loss: 0.1746 - val_accuracy: 0.9476
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0504 - accuracy: 0.9835 - val_loss: 0.1668 - val_accuracy: 0.9476
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0476 - accuracy: 0.9848 - val_loss: 0.1819 - val_accuracy: 0.9473
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0468 - accuracy: 0.9848 - val_loss: 0.1844 - val_accuracy: 0.9507
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0445 - accuracy: 0.9852 - val_loss: 0.1680 - val_accuracy: 0.9507
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0421 - accuracy: 0.9862 - val_loss: 0.1805 - val_accuracy: 0.9533
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0413 - accuracy: 0.9867 - val_loss: 0.1894 - val_accuracy: 0.9480
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.2073 - val_accuracy: 0.9495
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.1773 - val_accuracy: 0.9548
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0373 - accuracy: 0.9875 - val_loss: 0.1884 - val_accuracy: 0.9537
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0374 - accuracy: 0.9879 - val_loss: 0.1795 - val_accuracy: 0.9522
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0340 - accuracy: 0.9886 - val_loss: 0.1931 - val_accuracy: 0.9522
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.1845 - val_accuracy: 0.9522
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0351 - accuracy: 0.9882 - val_loss: 0.1946 - val_accuracy: 0.9540
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0287 - accuracy: 0.9906 - val_loss: 0.1790 - val_accuracy: 0.9556
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.1960 - val_accuracy: 0.9540
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.1964 - val_accuracy: 0.9552
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.2031 - val_accuracy: 0.9548
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.2302 - val_accuracy: 0.9540
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0244 - accuracy: 0.9917 - val_loss: 0.2253 - val_accuracy: 0.9540
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0213 - accuracy: 0.9925 - val_loss: 0.2078 - val_accuracy: 0.9544
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.2372 - val_accuracy: 0.9556
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0203 - accuracy: 0.9927 - val_loss: 0.2256 - val_accuracy: 0.9556
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.2332 - val_accuracy: 0.9544
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0199 - accuracy: 0.9930 - val_loss: 0.2497 - val_accuracy: 0.9567
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 5: loss of 0.24974803626537323; accuracy of 95.6685483455658%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2235 - accuracy: 0.9349 - val_loss: 0.2782 - val_accuracy: 0.9153
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.1152 - accuracy: 0.9657 - val_loss: 0.2178 - val_accuracy: 0.9288
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0971 - accuracy: 0.9707 - val_loss: 0.2058 - val_accuracy: 0.9333
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0861 - accuracy: 0.9735 - val_loss: 0.1994 - val_accuracy: 0.9348
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0784 - accuracy: 0.9755 - val_loss: 0.1810 - val_accuracy: 0.9416
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0715 - accuracy: 0.9774 - val_loss: 0.1769 - val_accuracy: 0.9439
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0656 - accuracy: 0.9790 - val_loss: 0.1794 - val_accuracy: 0.9435
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0648 - accuracy: 0.9796 - val_loss: 0.1651 - val_accuracy: 0.9503
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0587 - accuracy: 0.9812 - val_loss: 0.1785 - val_accuracy: 0.9469
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0557 - accuracy: 0.9821 - val_loss: 0.1656 - val_accuracy: 0.9533
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0523 - accuracy: 0.9833 - val_loss: 0.1712 - val_accuracy: 0.9537
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0502 - accuracy: 0.9843 - val_loss: 0.1555 - val_accuracy: 0.9537
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0482 - accuracy: 0.9848 - val_loss: 0.1616 - val_accuracy: 0.9525
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0463 - accuracy: 0.9846 - val_loss: 0.1532 - val_accuracy: 0.9574
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0448 - accuracy: 0.9854 - val_loss: 0.1788 - val_accuracy: 0.9559
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0433 - accuracy: 0.9859 - val_loss: 0.1770 - val_accuracy: 0.9503
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0436 - accuracy: 0.9860 - val_loss: 0.1608 - val_accuracy: 0.9578
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0416 - accuracy: 0.9865 - val_loss: 0.1608 - val_accuracy: 0.9563
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.1729 - val_accuracy: 0.9586
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0397 - accuracy: 0.9871 - val_loss: 0.1589 - val_accuracy: 0.9571
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0387 - accuracy: 0.9874 - val_loss: 0.1624 - val_accuracy: 0.9567
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0350 - accuracy: 0.9883 - val_loss: 0.1657 - val_accuracy: 0.9582
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.1831 - val_accuracy: 0.9548
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0364 - accuracy: 0.9880 - val_loss: 0.1708 - val_accuracy: 0.9533
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0298 - accuracy: 0.9901 - val_loss: 0.1554 - val_accuracy: 0.9563
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.1696 - val_accuracy: 0.9578
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.1711 - val_accuracy: 0.9578
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0269 - accuracy: 0.9912 - val_loss: 0.1805 - val_accuracy: 0.9574
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.1774 - val_accuracy: 0.9589
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0248 - accuracy: 0.9913 - val_loss: 0.1723 - val_accuracy: 0.9593
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0258 - accuracy: 0.9914 - val_loss: 0.1691 - val_accuracy: 0.9563
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0244 - accuracy: 0.9912 - val_loss: 0.1983 - val_accuracy: 0.9593
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.1947 - val_accuracy: 0.9612
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0255 - accuracy: 0.9913 - val_loss: 0.1901 - val_accuracy: 0.9605
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0226 - accuracy: 0.9921 - val_loss: 0.1855 - val_accuracy: 0.9582
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 6: loss of 0.18545901775360107; accuracy of 95.81921100616455%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2430 - accuracy: 0.9285 - val_loss: 0.3041 - val_accuracy: 0.9115
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.1136 - accuracy: 0.9655 - val_loss: 0.2426 - val_accuracy: 0.9232
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0948 - accuracy: 0.9703 - val_loss: 0.2076 - val_accuracy: 0.9337
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0836 - accuracy: 0.9738 - val_loss: 0.2251 - val_accuracy: 0.9228
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0746 - accuracy: 0.9762 - val_loss: 0.1822 - val_accuracy: 0.9409
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0688 - accuracy: 0.9779 - val_loss: 0.1772 - val_accuracy: 0.9446
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0647 - accuracy: 0.9797 - val_loss: 0.1736 - val_accuracy: 0.9450
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0584 - accuracy: 0.9807 - val_loss: 0.1794 - val_accuracy: 0.9439
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0569 - accuracy: 0.9821 - val_loss: 0.1874 - val_accuracy: 0.9450
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0524 - accuracy: 0.9832 - val_loss: 0.1712 - val_accuracy: 0.9469
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0507 - accuracy: 0.9833 - val_loss: 0.1810 - val_accuracy: 0.9454
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0486 - accuracy: 0.9841 - val_loss: 0.1849 - val_accuracy: 0.9461
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0459 - accuracy: 0.9848 - val_loss: 0.1707 - val_accuracy: 0.9484
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0457 - accuracy: 0.9851 - val_loss: 0.1818 - val_accuracy: 0.9458
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0444 - accuracy: 0.9860 - val_loss: 0.1815 - val_accuracy: 0.9473
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0420 - accuracy: 0.9861 - val_loss: 0.1885 - val_accuracy: 0.9473
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0417 - accuracy: 0.9866 - val_loss: 0.2171 - val_accuracy: 0.9454
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.2071 - val_accuracy: 0.9458
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.1879 - val_accuracy: 0.9507
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0316 - accuracy: 0.9897 - val_loss: 0.1908 - val_accuracy: 0.9522
#
# Epoch 00020: val_loss did not improve from 0.14479
# ...
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.1871 - val_accuracy: 0.9586
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0256 - accuracy: 0.9910 - val_loss: 0.2005 - val_accuracy: 0.9589
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 0.2100 - val_accuracy: 0.9597
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.2021 - val_accuracy: 0.9601
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.1924 - val_accuracy: 0.9589
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0209 - accuracy: 0.9929 - val_loss: 0.2007 - val_accuracy: 0.9605
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 8: loss of 0.2007051557302475; accuracy of 96.04519605636597%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2070 - accuracy: 0.9392 - val_loss: 0.2949 - val_accuracy: 0.9092
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.1047 - accuracy: 0.9684 - val_loss: 0.2271 - val_accuracy: 0.9254
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0878 - accuracy: 0.9734 - val_loss: 0.2277 - val_accuracy: 0.9254
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0790 - accuracy: 0.9754 - val_loss: 0.1960 - val_accuracy: 0.9386
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0725 - accuracy: 0.9777 - val_loss: 0.1818 - val_accuracy: 0.9408
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0665 - accuracy: 0.9787 - val_loss: 0.1835 - val_accuracy: 0.9439
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0623 - accuracy: 0.9800 - val_loss: 0.1693 - val_accuracy: 0.9476
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0571 - accuracy: 0.9814 - val_loss: 0.1703 - val_accuracy: 0.9472
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0556 - accuracy: 0.9817 - val_loss: 0.1722 - val_accuracy: 0.9488
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0507 - accuracy: 0.9836 - val_loss: 0.1812 - val_accuracy: 0.9506
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0500 - accuracy: 0.9837 - val_loss: 0.1659 - val_accuracy: 0.9521
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0483 - accuracy: 0.9843 - val_loss: 0.1641 - val_accuracy: 0.9518
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 0.1813 - val_accuracy: 0.9499
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0443 - accuracy: 0.9857 - val_loss: 0.1719 - val_accuracy: 0.9488
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0420 - accuracy: 0.9868 - val_loss: 0.1771 - val_accuracy: 0.9533
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0401 - accuracy: 0.9871 - val_loss: 0.1708 - val_accuracy: 0.9518
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.1954 - val_accuracy: 0.9469
#
# Epoch 00017: val_loss did not improve from 0.14479
# Epoch 18/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0396 - accuracy: 0.9874 - val_loss: 0.1668 - val_accuracy: 0.9518
#
# Epoch 00018: val_loss did not improve from 0.14479
# Epoch 19/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0391 - accuracy: 0.9875 - val_loss: 0.1724 - val_accuracy: 0.9529
#
# Epoch 00019: val_loss did not improve from 0.14479
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0362 - accuracy: 0.9884 - val_loss: 0.1891 - val_accuracy: 0.9529
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.14479
# Epoch 21/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 0.1857 - val_accuracy: 0.9552
#
# Epoch 00021: val_loss did not improve from 0.14479
# Epoch 22/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0285 - accuracy: 0.9908 - val_loss: 0.1879 - val_accuracy: 0.9567
#
# Epoch 00022: val_loss did not improve from 0.14479
# Epoch 23/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0279 - accuracy: 0.9903 - val_loss: 0.2029 - val_accuracy: 0.9518
#
# Epoch 00023: val_loss did not improve from 0.14479
# Epoch 24/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.1829 - val_accuracy: 0.9555
#
# Epoch 00024: val_loss did not improve from 0.14479
# Epoch 25/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0265 - accuracy: 0.9912 - val_loss: 0.1967 - val_accuracy: 0.9555
#
# Epoch 00025: val_loss did not improve from 0.14479
# Epoch 26/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0271 - accuracy: 0.9908 - val_loss: 0.2039 - val_accuracy: 0.9518
#
# Epoch 00026: val_loss did not improve from 0.14479
# Epoch 27/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0265 - accuracy: 0.9911 - val_loss: 0.2131 - val_accuracy: 0.9514
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.14479
# Epoch 28/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0230 - accuracy: 0.9920 - val_loss: 0.2109 - val_accuracy: 0.9521
#
# Epoch 00028: val_loss did not improve from 0.14479
# Epoch 29/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.2079 - val_accuracy: 0.9533
#
# Epoch 00029: val_loss did not improve from 0.14479
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.1946 - val_accuracy: 0.9559
#
# Epoch 00030: val_loss did not improve from 0.14479
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.2085 - val_accuracy: 0.9548
#
# Epoch 00031: val_loss did not improve from 0.14479
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 0.2346 - val_accuracy: 0.9525
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.14479
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0191 - accuracy: 0.9931 - val_loss: 0.2217 - val_accuracy: 0.9540
#
# Epoch 00033: val_loss did not improve from 0.14479
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.2147 - val_accuracy: 0.9540
#
# Epoch 00034: val_loss did not improve from 0.14479
# Epoch 35/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.2105 - val_accuracy: 0.9559
#
# Epoch 00035: val_loss did not improve from 0.14479
# Score for fold 9: loss of 0.21053475141525269; accuracy of 95.59155702590942%
# Epoch 1/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.2283 - accuracy: 0.9336 - val_loss: 0.2718 - val_accuracy: 0.9194
#
# Epoch 00001: val_loss did not improve from 0.14479
# Epoch 2/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.1167 - accuracy: 0.9651 - val_loss: 0.2267 - val_accuracy: 0.9367
#
# Epoch 00002: val_loss did not improve from 0.14479
# Epoch 3/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0992 - accuracy: 0.9697 - val_loss: 0.2093 - val_accuracy: 0.9378
#
# Epoch 00003: val_loss did not improve from 0.14479
# Epoch 4/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0863 - accuracy: 0.9729 - val_loss: 0.1871 - val_accuracy: 0.9420
#
# Epoch 00004: val_loss did not improve from 0.14479
# Epoch 5/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0776 - accuracy: 0.9759 - val_loss: 0.1773 - val_accuracy: 0.9450
#
# Epoch 00005: val_loss did not improve from 0.14479
# Epoch 6/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0735 - accuracy: 0.9766 - val_loss: 0.1672 - val_accuracy: 0.9525
#
# Epoch 00006: val_loss did not improve from 0.14479
# Epoch 7/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0666 - accuracy: 0.9789 - val_loss: 0.1673 - val_accuracy: 0.9491
#
# Epoch 00007: val_loss did not improve from 0.14479
# Epoch 8/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0619 - accuracy: 0.9802 - val_loss: 0.1496 - val_accuracy: 0.9540
#
# Epoch 00008: val_loss did not improve from 0.14479
# Epoch 9/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0563 - accuracy: 0.9818 - val_loss: 0.1481 - val_accuracy: 0.9574
#
# Epoch 00009: val_loss did not improve from 0.14479
# Epoch 10/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0540 - accuracy: 0.9828 - val_loss: 0.1625 - val_accuracy: 0.9574
#
# Epoch 00010: val_loss did not improve from 0.14479
# Epoch 11/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0521 - accuracy: 0.9833 - val_loss: 0.1520 - val_accuracy: 0.9555
#
# Epoch 00011: val_loss did not improve from 0.14479
# Epoch 12/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0487 - accuracy: 0.9839 - val_loss: 0.1663 - val_accuracy: 0.9570
#
# Epoch 00012: val_loss did not improve from 0.14479
# Epoch 13/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0486 - accuracy: 0.9841 - val_loss: 0.1478 - val_accuracy: 0.9593
#
# Epoch 00013: val_loss did not improve from 0.14479
# Epoch 14/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0431 - accuracy: 0.9859 - val_loss: 0.1499 - val_accuracy: 0.9593
#
# Epoch 00014: val_loss did not improve from 0.14479
# Epoch 15/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0432 - accuracy: 0.9861 - val_loss: 0.1557 - val_accuracy: 0.9601
#
# Epoch 00015: val_loss did not improve from 0.14479
# Epoch 16/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0422 - accuracy: 0.9862 - val_loss: 0.1597 - val_accuracy: 0.9570
#
# Epoch 00016: val_loss did not improve from 0.14479
# Epoch 17/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0402 - accuracy: 0.9867 - val_loss: 0.1428 - val_accuracy: 0.9608
#
# Epoch 00017: val_loss improved from 0.14479 to 0.14281, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 18/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0398 - accuracy: 0.9875 - val_loss: 0.1408 - val_accuracy: 0.9616
#
# Epoch 00018: val_loss improved from 0.14281 to 0.14084, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-gan1000-local-v011\model.h5
# Epoch 19/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0372 - accuracy: 0.9872 - val_loss: 0.1451 - val_accuracy: 0.9608
#
# Epoch 00019: val_loss did not improve from 0.14084
# Epoch 20/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0385 - accuracy: 0.9878 - val_loss: 0.1588 - val_accuracy: 0.9563
#
# Epoch 00020: val_loss did not improve from 0.14084
# Epoch 21/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0350 - accuracy: 0.9884 - val_loss: 0.1572 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss did not improve from 0.14084
# Epoch 22/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0365 - accuracy: 0.9883 - val_loss: 0.1568 - val_accuracy: 0.9597
#
# Epoch 00022: val_loss did not improve from 0.14084
# Epoch 23/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.1564 - val_accuracy: 0.9616
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.14084
# Epoch 24/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.1471 - val_accuracy: 0.9631
#
# Epoch 00024: val_loss did not improve from 0.14084
# Epoch 25/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.1574 - val_accuracy: 0.9604
#
# Epoch 00025: val_loss did not improve from 0.14084
# Epoch 26/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0247 - accuracy: 0.9916 - val_loss: 0.1573 - val_accuracy: 0.9616
#
# Epoch 00026: val_loss did not improve from 0.14084
# Epoch 27/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0243 - accuracy: 0.9915 - val_loss: 0.1555 - val_accuracy: 0.9646
#
# Epoch 00027: val_loss did not improve from 0.14084
# Epoch 28/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 0.1556 - val_accuracy: 0.9623
#
# Epoch 00028: val_loss did not improve from 0.14084
# Epoch 29/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.1578 - val_accuracy: 0.9619
#
# Epoch 00029: val_loss did not improve from 0.14084
# Epoch 30/35
# 1997/1997 [==============================] - 10s 5ms/step - loss: 0.0232 - accuracy: 0.9918 - val_loss: 0.1766 - val_accuracy: 0.9631
#
# Epoch 00030: val_loss did not improve from 0.14084
# Epoch 31/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.1553 - val_accuracy: 0.9642
#
# Epoch 00031: val_loss did not improve from 0.14084
# Epoch 32/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0224 - accuracy: 0.9922 - val_loss: 0.1662 - val_accuracy: 0.9635
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.14084
# Epoch 33/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0204 - accuracy: 0.9928 - val_loss: 0.1727 - val_accuracy: 0.9635
#
# Epoch 00033: val_loss did not improve from 0.14084
# Epoch 34/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0195 - accuracy: 0.9929 - val_loss: 0.1704 - val_accuracy: 0.9650
#
# Epoch 00034: val_loss did not improve from 0.14084
# Epoch 35/35
# 1997/1997 [==============================] - 11s 5ms/step - loss: 0.0192 - accuracy: 0.9930 - val_loss: 0.1682 - val_accuracy: 0.9612
#
# Epoch 00035: val_loss did not improve from 0.14084
# Score for fold 10: loss of 0.1681787222623825; accuracy of 96.11906409263611%

# %%
(np.argmax(Malware_model.predict(imgs[test]), axis=-1))
# Out:
# array([10,  0,  5, ..., 10, 10, 10], dtype=int64)

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.20321743190288544 - Accuracy: 95.63088417053223%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.25763270258903503 - Accuracy: 95.10357975959778%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.19705146551132202 - Accuracy: 95.6685483455658%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.23362568020820618 - Accuracy: 95.63088417053223%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.24974803626537323 - Accuracy: 95.6685483455658%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.18545901775360107 - Accuracy: 95.81921100616455%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.2197854071855545 - Accuracy: 95.10357975959778%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.2007051557302475 - Accuracy: 96.04519605636597%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.21053475141525269 - Accuracy: 95.59155702590942%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.1681787222623825 - Accuracy: 96.11906409263611%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.63810527324677% (+- 0.0031708093870675357)
# > Loss: 0.21259383708238602
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9564      | 0.0032       |
# | Loss     | 0.2126      | 0.0266       |
# | Macro F1 | 0.8865      | 0.0076       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.979       | 0.0048       |
# | Acc      | 0.9841      | 0.0025       |
# | F1       | 0.985       | 0.0025       |
# | MCC      | 0.9681      | 0.005        |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
