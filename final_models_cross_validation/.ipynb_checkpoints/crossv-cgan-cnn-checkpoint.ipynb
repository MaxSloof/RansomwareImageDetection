# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 150000 # Set very high so it uses all the images in the directory, does not actually take 150,000 images

# Number of epochs
epoch_t = 30 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import time

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cgan-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 2 matches(es) found
# --------------
# New folder name: cgan-cnn-local-v003
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"
    path_root_gen = '/kaggle/input/cganlocalv007/cgan-ckpt-local-v010-half'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-ckpt-v009-thirdsize"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# Count number of files in the CGAN folder

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 42528 images belonging to 10 classes.

# %%
plt.imshow(imgs_gen[900],cmap='gray')

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.2088 - accuracy: 0.9394 - val_loss: 0.2951 - val_accuracy: 0.9104
#
# Epoch 00001: val_loss improved from inf to 0.29508, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1078 - accuracy: 0.9680 - val_loss: 0.2351 - val_accuracy: 0.9292
#
# Epoch 00002: val_loss improved from 0.29508 to 0.23515, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 3/30
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0932 - accuracy: 0.9720 - val_loss: 0.1937 - val_accuracy: 0.9420
#
# Epoch 00003: val_loss improved from 0.23515 to 0.19367, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0800 - accuracy: 0.9756 - val_loss: 0.1908 - val_accuracy: 0.9416
#
# Epoch 00004: val_loss improved from 0.19367 to 0.19079, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 5/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0733 - accuracy: 0.9771 - val_loss: 0.1936 - val_accuracy: 0.9435
#
# Epoch 00005: val_loss did not improve from 0.19079
# Epoch 6/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0674 - accuracy: 0.9786 - val_loss: 0.1683 - val_accuracy: 0.9499
#
# Epoch 00006: val_loss improved from 0.19079 to 0.16833, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 7/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0622 - accuracy: 0.9796 - val_loss: 0.1886 - val_accuracy: 0.9450
#
# Epoch 00007: val_loss did not improve from 0.16833
# Epoch 8/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0559 - accuracy: 0.9820 - val_loss: 0.1720 - val_accuracy: 0.9469
#
# Epoch 00008: val_loss did not improve from 0.16833
# Epoch 9/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0545 - accuracy: 0.9822 - val_loss: 0.1632 - val_accuracy: 0.9518
#
# Epoch 00009: val_loss improved from 0.16833 to 0.16321, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 10/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0503 - accuracy: 0.9835 - val_loss: 0.1682 - val_accuracy: 0.9525
#
# Epoch 00010: val_loss did not improve from 0.16321
# Epoch 11/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0473 - accuracy: 0.9844 - val_loss: 0.1751 - val_accuracy: 0.9503
#
# Epoch 00011: val_loss did not improve from 0.16321
# Epoch 12/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0464 - accuracy: 0.9848 - val_loss: 0.1706 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.16321
# Epoch 13/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0448 - accuracy: 0.9854 - val_loss: 0.1856 - val_accuracy: 0.9529
#
# Epoch 00013: val_loss did not improve from 0.16321
# Epoch 14/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0425 - accuracy: 0.9862 - val_loss: 0.1933 - val_accuracy: 0.9537
#
# Epoch 00014: val_loss did not improve from 0.16321
# Epoch 15/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0420 - accuracy: 0.9865 - val_loss: 0.1769 - val_accuracy: 0.9495
#
# Epoch 00015: val_loss did not improve from 0.16321
# Epoch 16/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0399 - accuracy: 0.9870 - val_loss: 0.1620 - val_accuracy: 0.9556
#
# Epoch 00016: val_loss improved from 0.16321 to 0.16201, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 17/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0412 - accuracy: 0.9869 - val_loss: 0.1660 - val_accuracy: 0.9552
#
# Epoch 00017: val_loss did not improve from 0.16201
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0381 - accuracy: 0.9880 - val_loss: 0.1977 - val_accuracy: 0.9518
#
# Epoch 00018: val_loss did not improve from 0.16201
# Epoch 19/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0357 - accuracy: 0.9881 - val_loss: 0.1879 - val_accuracy: 0.9510
#
# Epoch 00019: val_loss did not improve from 0.16201
# Epoch 20/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0353 - accuracy: 0.9887 - val_loss: 0.1746 - val_accuracy: 0.9552
#
# Epoch 00020: val_loss did not improve from 0.16201
# Epoch 21/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0360 - accuracy: 0.9883 - val_loss: 0.1702 - val_accuracy: 0.9544
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.16201
# Epoch 22/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0304 - accuracy: 0.9905 - val_loss: 0.1650 - val_accuracy: 0.9571
#
# Epoch 00022: val_loss did not improve from 0.16201
# Epoch 23/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0258 - accuracy: 0.9913 - val_loss: 0.1725 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss did not improve from 0.16201
# Epoch 24/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.1750 - val_accuracy: 0.9548
#
# Epoch 00024: val_loss did not improve from 0.16201
# Epoch 25/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.1971 - val_accuracy: 0.9571
#
# Epoch 00025: val_loss did not improve from 0.16201
# Epoch 26/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.1764 - val_accuracy: 0.9571
#
# Epoch 00026: val_loss did not improve from 0.16201
# Epoch 27/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0229 - accuracy: 0.9922 - val_loss: 0.1896 - val_accuracy: 0.9571
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.16201
# Epoch 28/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0225 - accuracy: 0.9923 - val_loss: 0.1893 - val_accuracy: 0.9578
#
# Epoch 00028: val_loss did not improve from 0.16201
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.1998 - val_accuracy: 0.9563
#
# Epoch 00029: val_loss did not improve from 0.16201
# Epoch 30/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.1896 - val_accuracy: 0.9586
#
# Epoch 00030: val_loss did not improve from 0.16201
# Score for fold 1: loss of 0.18961820006370544; accuracy of 95.85687518119812%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2183 - accuracy: 0.9363 - val_loss: 0.3165 - val_accuracy: 0.9085
#
# Epoch 00001: val_loss did not improve from 0.16201
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1121 - accuracy: 0.9665 - val_loss: 0.2703 - val_accuracy: 0.9156
#
# Epoch 00002: val_loss did not improve from 0.16201
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0902 - accuracy: 0.9725 - val_loss: 0.2581 - val_accuracy: 0.9156
#
# Epoch 00003: val_loss did not improve from 0.16201
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0803 - accuracy: 0.9748 - val_loss: 0.2300 - val_accuracy: 0.9315
#
# Epoch 00004: val_loss did not improve from 0.16201
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0723 - accuracy: 0.9767 - val_loss: 0.2044 - val_accuracy: 0.9326
#
# Epoch 00005: val_loss did not improve from 0.16201
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0647 - accuracy: 0.9790 - val_loss: 0.2056 - val_accuracy: 0.9352
#
# Epoch 00006: val_loss did not improve from 0.16201
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0611 - accuracy: 0.9805 - val_loss: 0.2031 - val_accuracy: 0.9401
#
# Epoch 00007: val_loss did not improve from 0.16201
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0553 - accuracy: 0.9820 - val_loss: 0.2160 - val_accuracy: 0.9356
#
# Epoch 00008: val_loss did not improve from 0.16201
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0537 - accuracy: 0.9825 - val_loss: 0.1887 - val_accuracy: 0.9446
#
# Epoch 00009: val_loss did not improve from 0.16201
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0500 - accuracy: 0.9839 - val_loss: 0.2088 - val_accuracy: 0.9412
#
# Epoch 00010: val_loss did not improve from 0.16201
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0480 - accuracy: 0.9846 - val_loss: 0.2097 - val_accuracy: 0.9416
#
# Epoch 00011: val_loss did not improve from 0.16201
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0453 - accuracy: 0.9853 - val_loss: 0.2072 - val_accuracy: 0.9409
#
# Epoch 00012: val_loss did not improve from 0.16201
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0441 - accuracy: 0.9855 - val_loss: 0.2044 - val_accuracy: 0.9446
#
# Epoch 00013: val_loss did not improve from 0.16201
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0435 - accuracy: 0.9859 - val_loss: 0.2274 - val_accuracy: 0.9435
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.16201
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.2067 - val_accuracy: 0.9473
#
# Epoch 00015: val_loss did not improve from 0.16201
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 0.2131 - val_accuracy: 0.9484
#
# Epoch 00016: val_loss did not improve from 0.16201
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0314 - accuracy: 0.9894 - val_loss: 0.2114 - val_accuracy: 0.9488
#
# Epoch 00017: val_loss did not improve from 0.16201
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0281 - accuracy: 0.9907 - val_loss: 0.2250 - val_accuracy: 0.9488
#
# Epoch 00018: val_loss did not improve from 0.16201
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.2200 - val_accuracy: 0.9510
#
# Epoch 00019: val_loss did not improve from 0.16201
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0283 - accuracy: 0.9906 - val_loss: 0.2414 - val_accuracy: 0.9488
#
# Epoch 00020: val_loss did not improve from 0.16201
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.2281 - val_accuracy: 0.9503
#
# Epoch 00021: val_loss did not improve from 0.16201
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.2350 - val_accuracy: 0.9492
#
# Epoch 00022: val_loss did not improve from 0.16201
# Epoch 23/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0262 - accuracy: 0.9913 - val_loss: 0.2402 - val_accuracy: 0.9480
#
# Epoch 00023: val_loss did not improve from 0.16201
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 0.2394 - val_accuracy: 0.9488
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.16201
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.2652 - val_accuracy: 0.9492
#
# Epoch 00025: val_loss did not improve from 0.16201
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.2543 - val_accuracy: 0.9507
#
# Epoch 00026: val_loss did not improve from 0.16201
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.2746 - val_accuracy: 0.9499
#
# Epoch 00027: val_loss did not improve from 0.16201
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.2605 - val_accuracy: 0.9476
#
# Epoch 00028: val_loss did not improve from 0.16201
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.2460 - val_accuracy: 0.9488
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.16201
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.2883 - val_accuracy: 0.9469
#
# Epoch 00030: val_loss did not improve from 0.16201
# Score for fold 2: loss of 0.28834250569343567; accuracy of 94.68926787376404%
# Epoch 1/30
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.2335 - accuracy: 0.9319 - val_loss: 0.2704 - val_accuracy: 0.9171
#
# Epoch 00001: val_loss did not improve from 0.16201
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1150 - accuracy: 0.9662 - val_loss: 0.2235 - val_accuracy: 0.9269
#
# Epoch 00002: val_loss did not improve from 0.16201
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0972 - accuracy: 0.9705 - val_loss: 0.2095 - val_accuracy: 0.9382
#
# Epoch 00003: val_loss did not improve from 0.16201
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0850 - accuracy: 0.9740 - val_loss: 0.1900 - val_accuracy: 0.9431
#
# Epoch 00004: val_loss did not improve from 0.16201
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0789 - accuracy: 0.9754 - val_loss: 0.1794 - val_accuracy: 0.9446
#
# Epoch 00005: val_loss did not improve from 0.16201
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0727 - accuracy: 0.9766 - val_loss: 0.1693 - val_accuracy: 0.9484
#
# Epoch 00006: val_loss did not improve from 0.16201
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0671 - accuracy: 0.9786 - val_loss: 0.1666 - val_accuracy: 0.9484
#
# Epoch 00007: val_loss did not improve from 0.16201
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0633 - accuracy: 0.9797 - val_loss: 0.1735 - val_accuracy: 0.9480
#
# Epoch 00008: val_loss did not improve from 0.16201
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0583 - accuracy: 0.9811 - val_loss: 0.1668 - val_accuracy: 0.9484
#
# Epoch 00009: val_loss did not improve from 0.16201
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0567 - accuracy: 0.9819 - val_loss: 0.1508 - val_accuracy: 0.9514
#
# Epoch 00010: val_loss improved from 0.16201 to 0.15082, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0514 - accuracy: 0.9826 - val_loss: 0.1515 - val_accuracy: 0.9567
#
# Epoch 00011: val_loss did not improve from 0.15082
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0501 - accuracy: 0.9831 - val_loss: 0.1484 - val_accuracy: 0.9548
#
# Epoch 00012: val_loss improved from 0.15082 to 0.14840, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0477 - accuracy: 0.9845 - val_loss: 0.1495 - val_accuracy: 0.9552
#
# Epoch 00013: val_loss did not improve from 0.14840
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0455 - accuracy: 0.9851 - val_loss: 0.1619 - val_accuracy: 0.9552
#
# Epoch 00014: val_loss did not improve from 0.14840
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0451 - accuracy: 0.9854 - val_loss: 0.1509 - val_accuracy: 0.9563
#
# Epoch 00015: val_loss did not improve from 0.14840
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0436 - accuracy: 0.9860 - val_loss: 0.1485 - val_accuracy: 0.9574
#
# Epoch 00016: val_loss did not improve from 0.14840
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0397 - accuracy: 0.9868 - val_loss: 0.1625 - val_accuracy: 0.9552
#
# Epoch 00017: val_loss did not improve from 0.14840
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0410 - accuracy: 0.9869 - val_loss: 0.1629 - val_accuracy: 0.9563
#
# Epoch 00018: val_loss did not improve from 0.14840
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0398 - accuracy: 0.9867 - val_loss: 0.1538 - val_accuracy: 0.9597
#
# Epoch 00019: val_loss did not improve from 0.14840
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0401 - accuracy: 0.9868 - val_loss: 0.1516 - val_accuracy: 0.9571
#
# Epoch 00020: val_loss did not improve from 0.14840
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0387 - accuracy: 0.9876 - val_loss: 0.1449 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss improved from 0.14840 to 0.14493, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.1718 - val_accuracy: 0.9548
#
# Epoch 00022: val_loss did not improve from 0.14493
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0365 - accuracy: 0.9880 - val_loss: 0.1642 - val_accuracy: 0.9612
#
# Epoch 00023: val_loss did not improve from 0.14493
# Epoch 24/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.1732 - val_accuracy: 0.9605
#
# Epoch 00024: val_loss did not improve from 0.14493
# Epoch 25/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0333 - accuracy: 0.9892 - val_loss: 0.1685 - val_accuracy: 0.9601
#
# Epoch 00025: val_loss did not improve from 0.14493
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0346 - accuracy: 0.9884 - val_loss: 0.1664 - val_accuracy: 0.9582
#
# Epoch 00026: val_loss did not improve from 0.14493
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.1745 - val_accuracy: 0.9567
#
# Epoch 00027: val_loss did not improve from 0.14493
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.1763 - val_accuracy: 0.9578
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.14493
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0271 - accuracy: 0.9906 - val_loss: 0.1699 - val_accuracy: 0.9589
#
# Epoch 00029: val_loss did not improve from 0.14493
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0256 - accuracy: 0.9913 - val_loss: 0.1692 - val_accuracy: 0.9608
#
# Epoch 00030: val_loss did not improve from 0.14493
# Score for fold 3: loss of 0.1691843420267105; accuracy of 96.08286023139954%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2126 - accuracy: 0.9387 - val_loss: 0.2523 - val_accuracy: 0.9205
#
# Epoch 00001: val_loss did not improve from 0.14493
# Epoch 2/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.1039 - accuracy: 0.9680 - val_loss: 0.2147 - val_accuracy: 0.9352
#
# Epoch 00002: val_loss did not improve from 0.14493
# Epoch 3/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0867 - accuracy: 0.9732 - val_loss: 0.1900 - val_accuracy: 0.9420
#
# Epoch 00003: val_loss did not improve from 0.14493
# Epoch 4/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0786 - accuracy: 0.9755 - val_loss: 0.1853 - val_accuracy: 0.9439
#
# Epoch 00004: val_loss did not improve from 0.14493
# Epoch 5/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0694 - accuracy: 0.9779 - val_loss: 0.1700 - val_accuracy: 0.9488
#
# Epoch 00005: val_loss did not improve from 0.14493
# Epoch 6/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0639 - accuracy: 0.9794 - val_loss: 0.1621 - val_accuracy: 0.9492
#
# Epoch 00006: val_loss did not improve from 0.14493
# Epoch 7/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 0.1655 - val_accuracy: 0.9529
#
# Epoch 00007: val_loss did not improve from 0.14493
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0580 - accuracy: 0.9815 - val_loss: 0.1766 - val_accuracy: 0.9469
#
# Epoch 00008: val_loss did not improve from 0.14493
# Epoch 9/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0529 - accuracy: 0.9827 - val_loss: 0.1625 - val_accuracy: 0.9529
#
# Epoch 00009: val_loss did not improve from 0.14493
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0491 - accuracy: 0.9839 - val_loss: 0.1614 - val_accuracy: 0.9540
#
# Epoch 00010: val_loss did not improve from 0.14493
# Epoch 11/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0473 - accuracy: 0.9844 - val_loss: 0.1762 - val_accuracy: 0.9522
#
# Epoch 00011: val_loss did not improve from 0.14493
# Epoch 12/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0454 - accuracy: 0.9849 - val_loss: 0.1645 - val_accuracy: 0.9552
#
# Epoch 00012: val_loss did not improve from 0.14493
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0435 - accuracy: 0.9863 - val_loss: 0.1576 - val_accuracy: 0.9582
#
# Epoch 00013: val_loss did not improve from 0.14493
# Epoch 14/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0427 - accuracy: 0.9859 - val_loss: 0.1830 - val_accuracy: 0.9552
#
# Epoch 00014: val_loss did not improve from 0.14493
# Epoch 15/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0389 - accuracy: 0.9871 - val_loss: 0.1684 - val_accuracy: 0.9556
#
# Epoch 00015: val_loss did not improve from 0.14493
# Epoch 16/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0382 - accuracy: 0.9873 - val_loss: 0.1607 - val_accuracy: 0.9571
#
# Epoch 00016: val_loss did not improve from 0.14493
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0356 - accuracy: 0.9884 - val_loss: 0.1768 - val_accuracy: 0.9574
#
# Epoch 00017: val_loss did not improve from 0.14493
# Epoch 18/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0374 - accuracy: 0.9881 - val_loss: 0.1804 - val_accuracy: 0.9601
#
# Epoch 00018: val_loss did not improve from 0.14493
# Epoch 19/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.1942 - val_accuracy: 0.9529
#
# Epoch 00019: val_loss did not improve from 0.14493
# Epoch 20/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 0.2122 - val_accuracy: 0.9556
#
# Epoch 00020: val_loss did not improve from 0.14493
# Epoch 21/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.1806 - val_accuracy: 0.9578
#
# Epoch 00021: val_loss did not improve from 0.14493
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.2164 - val_accuracy: 0.9552
#
# Epoch 00022: val_loss did not improve from 0.14493
# Epoch 23/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0328 - accuracy: 0.9895 - val_loss: 0.1744 - val_accuracy: 0.9597
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.14493
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0272 - accuracy: 0.9907 - val_loss: 0.1898 - val_accuracy: 0.9582
#
# Epoch 00024: val_loss did not improve from 0.14493
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0255 - accuracy: 0.9913 - val_loss: 0.1865 - val_accuracy: 0.9593
#
# Epoch 00025: val_loss did not improve from 0.14493
# Epoch 26/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.1945 - val_accuracy: 0.9597
#
# Epoch 00026: val_loss did not improve from 0.14493
# Epoch 27/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 0.2030 - val_accuracy: 0.9582
#
# Epoch 00027: val_loss did not improve from 0.14493
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0237 - accuracy: 0.9920 - val_loss: 0.2106 - val_accuracy: 0.9567
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.14493
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.1979 - val_accuracy: 0.9601
#
# Epoch 00029: val_loss did not improve from 0.14493
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.2163 - val_accuracy: 0.9597
#
# Epoch 00030: val_loss did not improve from 0.14493
# Score for fold 4: loss of 0.21627090871334076; accuracy of 95.96986770629883%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2449 - accuracy: 0.9261 - val_loss: 0.3017 - val_accuracy: 0.9186
#
# Epoch 00001: val_loss did not improve from 0.14493
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1224 - accuracy: 0.9637 - val_loss: 0.2565 - val_accuracy: 0.9269
#
# Epoch 00002: val_loss did not improve from 0.14493
# Epoch 3/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.1005 - accuracy: 0.9697 - val_loss: 0.2333 - val_accuracy: 0.9299
#
# Epoch 00003: val_loss did not improve from 0.14493
# Epoch 4/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0894 - accuracy: 0.9727 - val_loss: 0.2314 - val_accuracy: 0.9367
#
# Epoch 00004: val_loss did not improve from 0.14493
# Epoch 5/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0825 - accuracy: 0.9743 - val_loss: 0.2069 - val_accuracy: 0.9397
#
# Epoch 00005: val_loss did not improve from 0.14493
# Epoch 6/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0770 - accuracy: 0.9759 - val_loss: 0.2100 - val_accuracy: 0.9416
#
# Epoch 00006: val_loss did not improve from 0.14493
# Epoch 7/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0705 - accuracy: 0.9776 - val_loss: 0.1937 - val_accuracy: 0.9450
#
# Epoch 00007: val_loss did not improve from 0.14493
# Epoch 8/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0659 - accuracy: 0.9789 - val_loss: 0.1929 - val_accuracy: 0.9465
#
# Epoch 00008: val_loss did not improve from 0.14493
# Epoch 9/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0636 - accuracy: 0.9795 - val_loss: 0.2097 - val_accuracy: 0.9454
#
# Epoch 00009: val_loss did not improve from 0.14493
# Epoch 10/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0589 - accuracy: 0.9810 - val_loss: 0.1829 - val_accuracy: 0.9439
#
# Epoch 00010: val_loss did not improve from 0.14493
# Epoch 11/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0539 - accuracy: 0.9827 - val_loss: 0.1774 - val_accuracy: 0.9495
#
# Epoch 00011: val_loss did not improve from 0.14493
# Epoch 12/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0540 - accuracy: 0.9819 - val_loss: 0.1835 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss did not improve from 0.14493
# Epoch 13/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0494 - accuracy: 0.9837 - val_loss: 0.1850 - val_accuracy: 0.9514
#
# Epoch 00013: val_loss did not improve from 0.14493
# Epoch 14/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0487 - accuracy: 0.9844 - val_loss: 0.1871 - val_accuracy: 0.9484
#
# Epoch 00014: val_loss did not improve from 0.14493
# Epoch 15/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0460 - accuracy: 0.9845 - val_loss: 0.2213 - val_accuracy: 0.9544
#
# Epoch 00015: val_loss did not improve from 0.14493
# Epoch 16/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0464 - accuracy: 0.9849 - val_loss: 0.1998 - val_accuracy: 0.9492
#
# Epoch 00016: val_loss did not improve from 0.14493
# Epoch 17/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0434 - accuracy: 0.9855 - val_loss: 0.1977 - val_accuracy: 0.9518
#
# Epoch 00017: val_loss did not improve from 0.14493
# Epoch 18/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0434 - accuracy: 0.9857 - val_loss: 0.1821 - val_accuracy: 0.9503
#
# Epoch 00018: val_loss did not improve from 0.14493
# Epoch 19/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0402 - accuracy: 0.9870 - val_loss: 0.2114 - val_accuracy: 0.9540
#
# Epoch 00019: val_loss did not improve from 0.14493
# Epoch 20/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0403 - accuracy: 0.9870 - val_loss: 0.2089 - val_accuracy: 0.9540
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.14493
# Epoch 21/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0337 - accuracy: 0.9886 - val_loss: 0.2022 - val_accuracy: 0.9544
#
# Epoch 00021: val_loss did not improve from 0.14493
# Epoch 22/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0317 - accuracy: 0.9892 - val_loss: 0.1901 - val_accuracy: 0.9522
#
# Epoch 00022: val_loss did not improve from 0.14493
# Epoch 23/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 0.2043 - val_accuracy: 0.9552
#
# Epoch 00023: val_loss did not improve from 0.14493
# Epoch 24/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0292 - accuracy: 0.9902 - val_loss: 0.2156 - val_accuracy: 0.9559
#
# Epoch 00024: val_loss did not improve from 0.14493
# Epoch 25/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0289 - accuracy: 0.9901 - val_loss: 0.2123 - val_accuracy: 0.9544
#
# Epoch 00025: val_loss did not improve from 0.14493
# Epoch 26/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0286 - accuracy: 0.9904 - val_loss: 0.2369 - val_accuracy: 0.9533
#
# Epoch 00026: val_loss did not improve from 0.14493
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0266 - accuracy: 0.9911 - val_loss: 0.2096 - val_accuracy: 0.9518
#
# Epoch 00027: val_loss did not improve from 0.14493
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0267 - accuracy: 0.9910 - val_loss: 0.2286 - val_accuracy: 0.9571
#
# Epoch 00028: val_loss did not improve from 0.14493
# Epoch 29/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0270 - accuracy: 0.9912 - val_loss: 0.2214 - val_accuracy: 0.9537
#
# Epoch 00029: val_loss did not improve from 0.14493
# Epoch 30/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.2186 - val_accuracy: 0.9563
#
# Epoch 00030: val_loss did not improve from 0.14493
# Score for fold 5: loss of 0.21860738098621368; accuracy of 95.63088417053223%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2098 - accuracy: 0.9381 - val_loss: 0.2609 - val_accuracy: 0.9179
#
# Epoch 00001: val_loss did not improve from 0.14493
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1033 - accuracy: 0.9678 - val_loss: 0.2579 - val_accuracy: 0.9160
#
# Epoch 00002: val_loss did not improve from 0.14493
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0863 - accuracy: 0.9735 - val_loss: 0.2028 - val_accuracy: 0.9337
#
# Epoch 00003: val_loss did not improve from 0.14493
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0775 - accuracy: 0.9758 - val_loss: 0.1914 - val_accuracy: 0.9401
#
# Epoch 00004: val_loss did not improve from 0.14493
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0691 - accuracy: 0.9785 - val_loss: 0.1743 - val_accuracy: 0.9439
#
# Epoch 00005: val_loss did not improve from 0.14493
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0643 - accuracy: 0.9797 - val_loss: 0.1668 - val_accuracy: 0.9473
#
# Epoch 00006: val_loss did not improve from 0.14493
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0584 - accuracy: 0.9814 - val_loss: 0.1695 - val_accuracy: 0.9446
#
# Epoch 00007: val_loss did not improve from 0.14493
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0550 - accuracy: 0.9823 - val_loss: 0.1591 - val_accuracy: 0.9484
#
# Epoch 00008: val_loss did not improve from 0.14493
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0523 - accuracy: 0.9831 - val_loss: 0.1660 - val_accuracy: 0.9492
#
# Epoch 00009: val_loss did not improve from 0.14493
# Epoch 10/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0482 - accuracy: 0.9839 - val_loss: 0.1570 - val_accuracy: 0.9507
#
# Epoch 00010: val_loss did not improve from 0.14493
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0471 - accuracy: 0.9851 - val_loss: 0.1653 - val_accuracy: 0.9476
#
# Epoch 00011: val_loss did not improve from 0.14493
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0463 - accuracy: 0.9853 - val_loss: 0.1677 - val_accuracy: 0.9507
#
# Epoch 00012: val_loss did not improve from 0.14493
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0430 - accuracy: 0.9863 - val_loss: 0.1640 - val_accuracy: 0.9484
#
# Epoch 00013: val_loss did not improve from 0.14493
# Epoch 14/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0420 - accuracy: 0.9868 - val_loss: 0.1591 - val_accuracy: 0.9522
#
# Epoch 00014: val_loss did not improve from 0.14493
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 0.1752 - val_accuracy: 0.9522
#
# Epoch 00015: val_loss did not improve from 0.14493
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0388 - accuracy: 0.9871 - val_loss: 0.1677 - val_accuracy: 0.9525
#
# Epoch 00016: val_loss did not improve from 0.14493
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0374 - accuracy: 0.9879 - val_loss: 0.1679 - val_accuracy: 0.9533
#
# Epoch 00017: val_loss did not improve from 0.14493
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0364 - accuracy: 0.9881 - val_loss: 0.2079 - val_accuracy: 0.9514
#
# Epoch 00018: val_loss did not improve from 0.14493
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0374 - accuracy: 0.9877 - val_loss: 0.2007 - val_accuracy: 0.9525
#
# Epoch 00019: val_loss did not improve from 0.14493
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0360 - accuracy: 0.9882 - val_loss: 0.1674 - val_accuracy: 0.9540
#
# Epoch 00020: val_loss did not improve from 0.14493
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0333 - accuracy: 0.9888 - val_loss: 0.1820 - val_accuracy: 0.9495
#
# Epoch 00021: val_loss did not improve from 0.14493
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0349 - accuracy: 0.9882 - val_loss: 0.1891 - val_accuracy: 0.9518
#
# Epoch 00022: val_loss did not improve from 0.14493
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0337 - accuracy: 0.9890 - val_loss: 0.1867 - val_accuracy: 0.9522
#
# Epoch 00023: val_loss did not improve from 0.14493
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0311 - accuracy: 0.9899 - val_loss: 0.1960 - val_accuracy: 0.9503
#
# Epoch 00024: val_loss did not improve from 0.14493
# Epoch 25/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0342 - accuracy: 0.9891 - val_loss: 0.1764 - val_accuracy: 0.9540
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.14493
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0269 - accuracy: 0.9912 - val_loss: 0.2041 - val_accuracy: 0.9522
#
# Epoch 00026: val_loss did not improve from 0.14493
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 0.2101 - val_accuracy: 0.9525
#
# Epoch 00027: val_loss did not improve from 0.14493
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.2042 - val_accuracy: 0.9529
#
# Epoch 00028: val_loss did not improve from 0.14493
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.1918 - val_accuracy: 0.9544
#
# Epoch 00029: val_loss did not improve from 0.14493
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.2322 - val_accuracy: 0.9522
#
# Epoch 00030: val_loss did not improve from 0.14493
# Score for fold 6: loss of 0.23215451836585999; accuracy of 95.21657228469849%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2236 - accuracy: 0.9345 - val_loss: 0.2906 - val_accuracy: 0.9145
#
# Epoch 00001: val_loss did not improve from 0.14493
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1132 - accuracy: 0.9668 - val_loss: 0.2537 - val_accuracy: 0.9239
#
# Epoch 00002: val_loss did not improve from 0.14493
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0960 - accuracy: 0.9716 - val_loss: 0.2238 - val_accuracy: 0.9303
#
# Epoch 00003: val_loss did not improve from 0.14493
# Epoch 4/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0840 - accuracy: 0.9740 - val_loss: 0.2099 - val_accuracy: 0.9352
#
# Epoch 00004: val_loss did not improve from 0.14493
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0762 - accuracy: 0.9759 - val_loss: 0.2082 - val_accuracy: 0.9394
#
# Epoch 00005: val_loss did not improve from 0.14493
# Epoch 6/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0716 - accuracy: 0.9773 - val_loss: 0.2178 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.14493
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0657 - accuracy: 0.9790 - val_loss: 0.1897 - val_accuracy: 0.9435
#
# Epoch 00007: val_loss did not improve from 0.14493
# Epoch 8/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0617 - accuracy: 0.9807 - val_loss: 0.1816 - val_accuracy: 0.9458
#
# Epoch 00008: val_loss did not improve from 0.14493
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0582 - accuracy: 0.9811 - val_loss: 0.1870 - val_accuracy: 0.9439
#
# Epoch 00009: val_loss did not improve from 0.14493
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0549 - accuracy: 0.9828 - val_loss: 0.1945 - val_accuracy: 0.9435
#
# Epoch 00010: val_loss did not improve from 0.14493
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0517 - accuracy: 0.9836 - val_loss: 0.1956 - val_accuracy: 0.9461
#
# Epoch 00011: val_loss did not improve from 0.14493
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0503 - accuracy: 0.9835 - val_loss: 0.1949 - val_accuracy: 0.9416
#
# Epoch 00012: val_loss did not improve from 0.14493
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0479 - accuracy: 0.9845 - val_loss: 0.2105 - val_accuracy: 0.9469
#
# Epoch 00013: val_loss did not improve from 0.14493
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0468 - accuracy: 0.9850 - val_loss: 0.1757 - val_accuracy: 0.9492
#
# Epoch 00014: val_loss did not improve from 0.14493
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0452 - accuracy: 0.9855 - val_loss: 0.1933 - val_accuracy: 0.9503
#
# Epoch 00015: val_loss did not improve from 0.14493
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0429 - accuracy: 0.9860 - val_loss: 0.2057 - val_accuracy: 0.9461
#
# Epoch 00016: val_loss did not improve from 0.14493
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0424 - accuracy: 0.9864 - val_loss: 0.1774 - val_accuracy: 0.9492
# Epoch 00017: val_loss did not improve from 0.14493
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0421 - accuracy: 0.9863 - val_loss: 0.2591 - val_accuracy: 0.9465
#
# Epoch 00018: val_loss did not improve from 0.14493
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.2061 - val_accuracy: 0.9480
#
# Epoch 00019: val_loss did not improve from 0.14493
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0386 - accuracy: 0.9874 - val_loss: 0.1937 - val_accuracy: 0.9488
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.14493
# Epoch 21/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0307 - accuracy: 0.9900 - val_loss: 0.2030 - val_accuracy: 0.9495
#
# Epoch 00021: val_loss did not improve from 0.14493
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0297 - accuracy: 0.9901 - val_loss: 0.2074 - val_accuracy: 0.9514
#
# Epoch 00022: val_loss did not improve from 0.14493
# Epoch 23/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0287 - accuracy: 0.9904 - val_loss: 0.2176 - val_accuracy: 0.9510
#
# Epoch 00023: val_loss did not improve from 0.14493
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0288 - accuracy: 0.9907 - val_loss: 0.1997 - val_accuracy: 0.9518
#
# Epoch 00024: val_loss did not improve from 0.14493
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 0.2110 - val_accuracy: 0.9499
#
# Epoch 00025: val_loss did not improve from 0.14493
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0265 - accuracy: 0.9911 - val_loss: 0.2193 - val_accuracy: 0.9510
#
# Epoch 00026: val_loss did not improve from 0.14493
# Epoch 27/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.2215 - val_accuracy: 0.9510
#
# Epoch 00027: val_loss did not improve from 0.14493
# Epoch 28/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0249 - accuracy: 0.9912 - val_loss: 0.2327 - val_accuracy: 0.9529
#
# Epoch 00028: val_loss did not improve from 0.14493
# Epoch 29/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0257 - accuracy: 0.9915 - val_loss: 0.2132 - val_accuracy: 0.9507
#
# Epoch 00029: val_loss did not improve from 0.14493
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.2369 - val_accuracy: 0.9495
#
# Epoch 00030: val_loss did not improve from 0.14493
# Score for fold 7: loss of 0.23688697814941406; accuracy of 94.95291709899902%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2176 - accuracy: 0.9360 - val_loss: 0.2776 - val_accuracy: 0.9183
#
# Epoch 00001: val_loss did not improve from 0.14493
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1107 - accuracy: 0.9667 - val_loss: 0.2124 - val_accuracy: 0.9356
#
# Epoch 00002: val_loss did not improve from 0.14493
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0949 - accuracy: 0.9710 - val_loss: 0.2042 - val_accuracy: 0.9394
#
# Epoch 00003: val_loss did not improve from 0.14493
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0843 - accuracy: 0.9737 - val_loss: 0.1799 - val_accuracy: 0.9427
#
# Epoch 00004: val_loss did not improve from 0.14493
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0751 - accuracy: 0.9766 - val_loss: 0.1913 - val_accuracy: 0.9465
#
# Epoch 00005: val_loss did not improve from 0.14493
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0702 - accuracy: 0.9778 - val_loss: 0.1628 - val_accuracy: 0.9480
#
# Epoch 00006: val_loss did not improve from 0.14493
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0649 - accuracy: 0.9792 - val_loss: 0.1603 - val_accuracy: 0.9507
#
# Epoch 00007: val_loss did not improve from 0.14493
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0629 - accuracy: 0.9803 - val_loss: 0.1657 - val_accuracy: 0.9503
#
# Epoch 00008: val_loss did not improve from 0.14493
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0572 - accuracy: 0.9817 - val_loss: 0.1595 - val_accuracy: 0.9552
#
# Epoch 00009: val_loss did not improve from 0.14493
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0544 - accuracy: 0.9824 - val_loss: 0.1687 - val_accuracy: 0.9533
#
# Epoch 00010: val_loss did not improve from 0.14493
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0529 - accuracy: 0.9831 - val_loss: 0.1494 - val_accuracy: 0.9597
#
# Epoch 00011: val_loss did not improve from 0.14493
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0482 - accuracy: 0.9841 - val_loss: 0.1539 - val_accuracy: 0.9593
#
# Epoch 00012: val_loss did not improve from 0.14493
# Epoch 13/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0483 - accuracy: 0.9848 - val_loss: 0.1433 - val_accuracy: 0.9608
#
# Epoch 00013: val_loss improved from 0.14493 to 0.14334, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 14/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0437 - accuracy: 0.9856 - val_loss: 0.1478 - val_accuracy: 0.9605
#
# Epoch 00014: val_loss did not improve from 0.14334
# Epoch 15/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0455 - accuracy: 0.9851 - val_loss: 0.1498 - val_accuracy: 0.9597
#
# Epoch 00015: val_loss did not improve from 0.14334
# Epoch 16/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.1467 - val_accuracy: 0.9605
#
# Epoch 00016: val_loss did not improve from 0.14334
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0415 - accuracy: 0.9865 - val_loss: 0.1466 - val_accuracy: 0.9608
#
# Epoch 00017: val_loss did not improve from 0.14334
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0407 - accuracy: 0.9868 - val_loss: 0.1622 - val_accuracy: 0.9578
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.14334
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0334 - accuracy: 0.9887 - val_loss: 0.1495 - val_accuracy: 0.9627
#
# Epoch 00019: val_loss did not improve from 0.14334
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.1481 - val_accuracy: 0.9646
#
# Epoch 00020: val_loss did not improve from 0.14334
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 0.1396 - val_accuracy: 0.9638
#
# Epoch 00021: val_loss improved from 0.14334 to 0.13959, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v003\model.h5
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0309 - accuracy: 0.9895 - val_loss: 0.1548 - val_accuracy: 0.9627
#
# Epoch 00022: val_loss did not improve from 0.13959
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0290 - accuracy: 0.9900 - val_loss: 0.1425 - val_accuracy: 0.9631
#
# Epoch 00023: val_loss did not improve from 0.13959
# Epoch 24/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.1527 - val_accuracy: 0.9616
#
# Epoch 00024: val_loss did not improve from 0.13959
# Epoch 25/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.1602 - val_accuracy: 0.9627
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.13959
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.1550 - val_accuracy: 0.9620
# Epoch 00026: val_loss did not improve from 0.13959
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.1561 - val_accuracy: 0.9631
#
# Epoch 00027: val_loss did not improve from 0.13959
# Epoch 28/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.1493 - val_accuracy: 0.9638
#
# Epoch 00028: val_loss did not improve from 0.13959
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 0.1679 - val_accuracy: 0.9631
#
# Epoch 00029: val_loss did not improve from 0.13959
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 0.1565 - val_accuracy: 0.9650
#
# Epoch 00030: val_loss did not improve from 0.13959
# Score for fold 8: loss of 0.15653197467327118; accuracy of 96.49717807769775%
# Epoch 1/30
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.2064 - accuracy: 0.9395 - val_loss: 0.3303 - val_accuracy: 0.8983
#
# Epoch 00001: val_loss did not improve from 0.13959
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1084 - accuracy: 0.9677 - val_loss: 0.2592 - val_accuracy: 0.9269
#
# Epoch 00002: val_loss did not improve from 0.13959
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0916 - accuracy: 0.9724 - val_loss: 0.2319 - val_accuracy: 0.9273
#
# Epoch 00003: val_loss did not improve from 0.13959
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0798 - accuracy: 0.9754 - val_loss: 0.2088 - val_accuracy: 0.9363
#
# Epoch 00004: val_loss did not improve from 0.13959
# Epoch 5/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0717 - accuracy: 0.9773 - val_loss: 0.2074 - val_accuracy: 0.9378
#
# Epoch 00005: val_loss did not improve from 0.13959
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0664 - accuracy: 0.9789 - val_loss: 0.2145 - val_accuracy: 0.9359
#
# Epoch 00006: val_loss did not improve from 0.13959
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0600 - accuracy: 0.9805 - val_loss: 0.1930 - val_accuracy: 0.9371
#
# Epoch 00007: val_loss did not improve from 0.13959
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0571 - accuracy: 0.9820 - val_loss: 0.1889 - val_accuracy: 0.9408
#
# Epoch 00008: val_loss did not improve from 0.13959
# Epoch 9/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0554 - accuracy: 0.9823 - val_loss: 0.1978 - val_accuracy: 0.9390
#
# Epoch 00009: val_loss did not improve from 0.13959
# Epoch 10/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0516 - accuracy: 0.9830 - val_loss: 0.1863 - val_accuracy: 0.9450
#
# Epoch 00010: val_loss did not improve from 0.13959
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0489 - accuracy: 0.9846 - val_loss: 0.1900 - val_accuracy: 0.9435
#
# Epoch 00011: val_loss did not improve from 0.13959
# Epoch 12/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0480 - accuracy: 0.9844 - val_loss: 0.1991 - val_accuracy: 0.9465
#
# Epoch 00012: val_loss did not improve from 0.13959
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.1761 - val_accuracy: 0.9495
#
# Epoch 00013: val_loss did not improve from 0.13959
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0435 - accuracy: 0.9860 - val_loss: 0.1875 - val_accuracy: 0.9472
#
# Epoch 00014: val_loss did not improve from 0.13959
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0443 - accuracy: 0.9856 - val_loss: 0.1908 - val_accuracy: 0.9499
#
# Epoch 00015: val_loss did not improve from 0.13959
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0392 - accuracy: 0.9870 - val_loss: 0.1816 - val_accuracy: 0.9488
#
# Epoch 00016: val_loss did not improve from 0.13959
# Epoch 17/30
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0424 - accuracy: 0.9863 - val_loss: 0.1962 - val_accuracy: 0.9488
#
# Epoch 00017: val_loss did not improve from 0.13959
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0384 - accuracy: 0.9876 - val_loss: 0.2086 - val_accuracy: 0.9503
#
# Epoch 00018: val_loss did not improve from 0.13959
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0380 - accuracy: 0.9875 - val_loss: 0.1960 - val_accuracy: 0.9499
#
# Epoch 00019: val_loss did not improve from 0.13959
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0399 - accuracy: 0.9874 - val_loss: 0.2029 - val_accuracy: 0.9476
#
# Epoch 00020: val_loss did not improve from 0.13959
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0362 - accuracy: 0.9885 - val_loss: 0.1988 - val_accuracy: 0.9480
#
# Epoch 00021: val_loss did not improve from 0.13959
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0350 - accuracy: 0.9887 - val_loss: 0.2070 - val_accuracy: 0.9510
#
# Epoch 00022: val_loss did not improve from 0.13959
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 0.1930 - val_accuracy: 0.9533
#
# Epoch 00023: val_loss did not improve from 0.13959
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.2040 - val_accuracy: 0.9495
#
# Epoch 00024: val_loss did not improve from 0.13959
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0342 - accuracy: 0.9889 - val_loss: 0.2356 - val_accuracy: 0.9495
#
# Epoch 00025: val_loss did not improve from 0.13959
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0348 - accuracy: 0.9894 - val_loss: 0.2282 - val_accuracy: 0.9469
#
# Epoch 00026: val_loss did not improve from 0.13959
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0328 - accuracy: 0.9892 - val_loss: 0.1972 - val_accuracy: 0.9506
#
# Epoch 00027: val_loss did not improve from 0.13959
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0313 - accuracy: 0.9901 - val_loss: 0.2065 - val_accuracy: 0.9510
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.13959
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0262 - accuracy: 0.9913 - val_loss: 0.2303 - val_accuracy: 0.9503
#
# Epoch 00029: val_loss did not improve from 0.13959
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.2253 - val_accuracy: 0.9495
#
# Epoch 00030: val_loss did not improve from 0.13959
# Score for fold 9: loss of 0.22528089582920074; accuracy of 94.95101571083069%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2132 - accuracy: 0.9390 - val_loss: 0.2996 - val_accuracy: 0.9032
#
# Epoch 00001: val_loss did not improve from 0.13959
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1060 - accuracy: 0.9683 - val_loss: 0.2261 - val_accuracy: 0.9299
#
# Epoch 00002: val_loss did not improve from 0.13959
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0885 - accuracy: 0.9732 - val_loss: 0.1871 - val_accuracy: 0.9393
#
# Epoch 00003: val_loss did not improve from 0.13959
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0800 - accuracy: 0.9749 - val_loss: 0.1805 - val_accuracy: 0.9431
#
# Epoch 00004: val_loss did not improve from 0.13959
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0703 - accuracy: 0.9780 - val_loss: 0.1757 - val_accuracy: 0.9442
#
# Epoch 00005: val_loss did not improve from 0.13959
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0641 - accuracy: 0.9796 - val_loss: 0.1752 - val_accuracy: 0.9461
#
# Epoch 00006: val_loss did not improve from 0.13959
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0600 - accuracy: 0.9807 - val_loss: 0.1652 - val_accuracy: 0.9525
#
# Epoch 00007: val_loss did not improve from 0.13959
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0572 - accuracy: 0.9817 - val_loss: 0.1625 - val_accuracy: 0.9503
#
# Epoch 00008: val_loss did not improve from 0.13959
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0542 - accuracy: 0.9827 - val_loss: 0.1625 - val_accuracy: 0.9488
#
# Epoch 00009: val_loss did not improve from 0.13959
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0519 - accuracy: 0.9835 - val_loss: 0.1572 - val_accuracy: 0.9529
#
# Epoch 00010: val_loss did not improve from 0.13959
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0499 - accuracy: 0.9840 - val_loss: 0.1550 - val_accuracy: 0.9567
#
# Epoch 00011: val_loss did not improve from 0.13959
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0470 - accuracy: 0.9848 - val_loss: 0.1457 - val_accuracy: 0.9555
#
# Epoch 00012: val_loss did not improve from 0.13959
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0429 - accuracy: 0.9862 - val_loss: 0.1555 - val_accuracy: 0.9537
#
# Epoch 00013: val_loss did not improve from 0.13959
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0444 - accuracy: 0.9856 - val_loss: 0.1566 - val_accuracy: 0.9570
#
# Epoch 00014: val_loss did not improve from 0.13959
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0424 - accuracy: 0.9858 - val_loss: 0.1849 - val_accuracy: 0.9537
#
# Epoch 00015: val_loss did not improve from 0.13959
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 0.1475 - val_accuracy: 0.9578
#
# Epoch 00016: val_loss did not improve from 0.13959
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0386 - accuracy: 0.9877 - val_loss: 0.1693 - val_accuracy: 0.9521
#
# Epoch 00017: val_loss did not improve from 0.13959
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0383 - accuracy: 0.9878 - val_loss: 0.1525 - val_accuracy: 0.9586
#
# Epoch 00018: val_loss did not improve from 0.13959
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0378 - accuracy: 0.9879 - val_loss: 0.1580 - val_accuracy: 0.9597
#
# Epoch 00019: val_loss did not improve from 0.13959
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.1747 - val_accuracy: 0.9555
#
# Epoch 00020: val_loss did not improve from 0.13959
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.1622 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss did not improve from 0.13959
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.1761 - val_accuracy: 0.9578
#
# Epoch 00022: val_loss did not improve from 0.13959
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0356 - accuracy: 0.9885 - val_loss: 0.1652 - val_accuracy: 0.9582
#
# Epoch 00023: val_loss did not improve from 0.13959
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0331 - accuracy: 0.9891 - val_loss: 0.1726 - val_accuracy: 0.9582
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.13959
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0276 - accuracy: 0.9906 - val_loss: 0.1632 - val_accuracy: 0.9597
#
# Epoch 00025: val_loss did not improve from 0.13959
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.1664 - val_accuracy: 0.9593
#
# Epoch 00026: val_loss did not improve from 0.13959
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.1729 - val_accuracy: 0.9601
#
# Epoch 00027: val_loss did not improve from 0.13959
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.1725 - val_accuracy: 0.9623
#
# Epoch 00028: val_loss did not improve from 0.13959
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.1778 - val_accuracy: 0.9601
#
# Epoch 00029: val_loss did not improve from 0.13959
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0234 - accuracy: 0.9921 - val_loss: 0.1842 - val_accuracy: 0.9604
#
# Epoch 00030: val_loss did not improve from 0.13959
# Score for fold 10: loss of 0.18420881032943726; accuracy of 96.04370594024658%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.18961820006370544 - Accuracy: 95.85687518119812%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.28834250569343567 - Accuracy: 94.68926787376404%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.1691843420267105 - Accuracy: 96.08286023139954%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.21627090871334076 - Accuracy: 95.96986770629883%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.21860738098621368 - Accuracy: 95.63088417053223%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.23215451836585999 - Accuracy: 95.21657228469849%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.23688697814941406 - Accuracy: 94.95291709899902%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.15653197467327118 - Accuracy: 96.49717807769775%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.22528089582920074 - Accuracy: 94.95101571083069%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.18420881032943726 - Accuracy: 96.04370594024658%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.58911442756653% (+- 0.005704261589855911)
# > Loss: 0.21170865148305892
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph (I will use around 20% of cases for benign for and the remaining 80% equally distributed across the 10 ransomware families)

# %%
np.array(train_distr)
# Out:
# array([[ 9.06339862,  9.34794719,  7.74303308,  7.74152753,  7.60452267,
#          8.2368528 ,  7.81831047,  8.31664684,  7.59097273,  7.49010102,
#         19.04668704],
#        [ 9.10103732,  9.35848602,  7.77013294,  7.74604417,  7.6180726 ,
#          8.24438054,  7.86046582,  8.27599705,  7.57441171,  7.45547342,
#         18.99549841],
#        [ 9.1537315 ,  9.33289171,  7.7595941 ,  7.75808856,  7.59247828,
#          8.28653588,  7.81228828,  8.30460246,  7.56838952,  7.48407883,
#         18.94732088],
#        [ 9.08598184,  9.33138616,  7.73851643,  7.77013294,  7.60452267,
#          8.26846931,  7.84089369,  8.27900815,  7.5804339 ,  7.49762876,
#         19.00302615],
#        [ 9.13717047,  9.31934177,  7.72195541,  7.75206636,  7.59850047,
#          8.25040273,  7.85896027,  8.3091191 ,  7.58645609,  7.49461767,
#         18.97140964],
#        [ 9.0844763 ,  9.3389139 ,  7.75658301,  7.75206636,  7.59850047,
#          8.30460246,  7.8348715 ,  8.29105253,  7.61054486,  7.48859547,
#         18.93979314],
#        [ 9.11157616,  9.34945273,  7.74754972,  7.73550534,  7.6150615 ,
#          8.24438054,  7.8694991 ,  8.26846931,  7.58495054,  7.49160657,
#         18.98194848],
#        [ 9.09652068,  9.3012752 ,  7.72195541,  7.74303308,  7.59699493,
#          8.29707472,  7.85293808,  8.29105253,  7.58946719,  7.48859547,
#         19.02109273],
#        [ 9.11746108,  9.33726777,  7.73388335,  7.72936678,  7.58634187,
#          8.25931167,  7.85733642,  8.29694981,  7.58483635,  7.47643853,
#         19.02080636],
#        [ 9.12799976,  9.36737828,  7.75797176,  7.7489386 ,  7.60290265,
#          8.2547951 ,  7.8558309 ,  8.29544428,  7.5818253 ,  7.47342748,
#         18.93348589]])

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN - CNN"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of CGAN - CNN       |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9559      | 0.0057       |
# | Loss     | 0.2117      | 0.0364       |
# | Macro F1 | 0.8845      | 0.0137       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9764      | 0.0075       |
# | Acc      | 0.9832      | 0.0042       |
# | F1       | 0.9842      | 0.0039       |
# | MCC      | 0.9664      | 0.0083       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
