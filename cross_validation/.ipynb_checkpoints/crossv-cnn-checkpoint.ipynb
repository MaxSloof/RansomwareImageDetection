# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021.
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000 # Set high so all the images in the directory

# Number of epochs
epoch_t = 35 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 1 matches(es) found
# --------------
# New folder name: cnn-local-v002
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
    
    # Save the binary data distribution
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 747/747 [==============================] - 6s 6ms/step - loss: 0.5927 - accuracy: 0.8225 - val_loss: 0.3470 - val_accuracy: 0.8885
#
# Epoch 00001: val_loss improved from inf to 0.34697, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3352 - accuracy: 0.8942 - val_loss: 0.2607 - val_accuracy: 0.9190
#
# Epoch 00002: val_loss improved from 0.34697 to 0.26066, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2795 - accuracy: 0.9101 - val_loss: 0.2305 - val_accuracy: 0.9307
#
# Epoch 00003: val_loss improved from 0.26066 to 0.23045, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2475 - accuracy: 0.9203 - val_loss: 0.2176 - val_accuracy: 0.9352
#
# Epoch 00004: val_loss improved from 0.23045 to 0.21757, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2259 - accuracy: 0.9269 - val_loss: 0.2042 - val_accuracy: 0.9345
#
# Epoch 00005: val_loss improved from 0.21757 to 0.20423, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2101 - accuracy: 0.9336 - val_loss: 0.1851 - val_accuracy: 0.9420
#
# Epoch 00006: val_loss improved from 0.20423 to 0.18515, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1927 - accuracy: 0.9381 - val_loss: 0.1751 - val_accuracy: 0.9461
#
# Epoch 00007: val_loss improved from 0.18515 to 0.17514, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1818 - accuracy: 0.9422 - val_loss: 0.1655 - val_accuracy: 0.9484
#
# Epoch 00008: val_loss improved from 0.17514 to 0.16549, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1718 - accuracy: 0.9430 - val_loss: 0.1688 - val_accuracy: 0.9507
#
# Epoch 00009: val_loss did not improve from 0.16549
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1618 - accuracy: 0.9470 - val_loss: 0.1739 - val_accuracy: 0.9484
#
# Epoch 00010: val_loss did not improve from 0.16549
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1543 - accuracy: 0.9482 - val_loss: 0.1577 - val_accuracy: 0.9510
#
# Epoch 00011: val_loss improved from 0.16549 to 0.15768, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1465 - accuracy: 0.9520 - val_loss: 0.1620 - val_accuracy: 0.9518
#
# Epoch 00012: val_loss did not improve from 0.15768
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1374 - accuracy: 0.9546 - val_loss: 0.1583 - val_accuracy: 0.9503
#
# Epoch 00013: val_loss did not improve from 0.15768
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1343 - accuracy: 0.9558 - val_loss: 0.1569 - val_accuracy: 0.9540
#
# Epoch 00014: val_loss improved from 0.15768 to 0.15694, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1310 - accuracy: 0.9566 - val_loss: 0.1488 - val_accuracy: 0.9582
#
# Epoch 00015: val_loss improved from 0.15694 to 0.14876, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1232 - accuracy: 0.9594 - val_loss: 0.1576 - val_accuracy: 0.9563
#
# Epoch 00016: val_loss did not improve from 0.14876
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1185 - accuracy: 0.9612 - val_loss: 0.1611 - val_accuracy: 0.9574
#
# Epoch 00017: val_loss did not improve from 0.14876
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1198 - accuracy: 0.9607 - val_loss: 0.1553 - val_accuracy: 0.9556
#
# Epoch 00018: val_loss did not improve from 0.14876
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1066 - accuracy: 0.9650 - val_loss: 0.1586 - val_accuracy: 0.9586
#
# Epoch 00019: val_loss did not improve from 0.14876
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1066 - accuracy: 0.9651 - val_loss: 0.1661 - val_accuracy: 0.9589
#
# Epoch 00020: val_loss did not improve from 0.14876
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1050 - accuracy: 0.9647 - val_loss: 0.1671 - val_accuracy: 0.9593
#
# Epoch 00021: val_loss did not improve from 0.14876
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1018 - accuracy: 0.9662 - val_loss: 0.1586 - val_accuracy: 0.9593
#
# Epoch 00022: val_loss did not improve from 0.14876
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0994 - accuracy: 0.9667 - val_loss: 0.1562 - val_accuracy: 0.9605
#
# Epoch 00023: val_loss did not improve from 0.14876
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0982 - accuracy: 0.9662 - val_loss: 0.1625 - val_accuracy: 0.9623
#
# Epoch 00024: val_loss did not improve from 0.14876
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0941 - accuracy: 0.9689 - val_loss: 0.1664 - val_accuracy: 0.9623
#
# Epoch 00025: val_loss did not improve from 0.14876
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0913 - accuracy: 0.9694 - val_loss: 0.1711 - val_accuracy: 0.9593
#
# Epoch 00026: val_loss did not improve from 0.14876
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0938 - accuracy: 0.9699 - val_loss: 0.1642 - val_accuracy: 0.9616
#
# Epoch 00027: val_loss did not improve from 0.14876
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0892 - accuracy: 0.9702 - val_loss: 0.1642 - val_accuracy: 0.9601
#
# Epoch 00028: val_loss did not improve from 0.14876
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0883 - accuracy: 0.9703 - val_loss: 0.1584 - val_accuracy: 0.9612
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00029: val_loss did not improve from 0.14876
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0717 - accuracy: 0.9761 - val_loss: 0.1761 - val_accuracy: 0.9605
#
# Epoch 00030: val_loss did not improve from 0.14876
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0713 - accuracy: 0.9762 - val_loss: 0.1660 - val_accuracy: 0.9601
#
# Epoch 00031: val_loss did not improve from 0.14876
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0747 - accuracy: 0.9755 - val_loss: 0.1714 - val_accuracy: 0.9638
#
# Epoch 00032: val_loss did not improve from 0.14876
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0714 - accuracy: 0.9755 - val_loss: 0.1724 - val_accuracy: 0.9631
#
# Epoch 00033: val_loss did not improve from 0.14876
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0744 - accuracy: 0.9741 - val_loss: 0.1726 - val_accuracy: 0.9616
#
# Epoch 00034: val_loss did not improve from 0.14876
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0684 - accuracy: 0.9761 - val_loss: 0.1863 - val_accuracy: 0.9616
#
# Epoch 00035: val_loss did not improve from 0.14876
# Score for fold 1: loss of 0.1862785667181015; accuracy of 96.15819454193115%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.6088 - accuracy: 0.8174 - val_loss: 0.3272 - val_accuracy: 0.8938
#
# Epoch 00001: val_loss did not improve from 0.14876
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3266 - accuracy: 0.8962 - val_loss: 0.2607 - val_accuracy: 0.9156
#
# Epoch 00002: val_loss did not improve from 0.14876
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2708 - accuracy: 0.9126 - val_loss: 0.2342 - val_accuracy: 0.9202
#
# Epoch 00003: val_loss did not improve from 0.14876
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2401 - accuracy: 0.9234 - val_loss: 0.2062 - val_accuracy: 0.9262
#
# Epoch 00004: val_loss did not improve from 0.14876
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2241 - accuracy: 0.9287 - val_loss: 0.1962 - val_accuracy: 0.9348
#
# Epoch 00005: val_loss did not improve from 0.14876
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2091 - accuracy: 0.9327 - val_loss: 0.1806 - val_accuracy: 0.9412
#
# Epoch 00006: val_loss did not improve from 0.14876
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1964 - accuracy: 0.9371 - val_loss: 0.1729 - val_accuracy: 0.9416
#
# Epoch 00007: val_loss did not improve from 0.14876
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1807 - accuracy: 0.9419 - val_loss: 0.1857 - val_accuracy: 0.9360
#
# Epoch 00008: val_loss did not improve from 0.14876
# Epoch 9/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1732 - accuracy: 0.9427 - val_loss: 0.1658 - val_accuracy: 0.9431
#
# Epoch 00009: val_loss did not improve from 0.14876
# Epoch 10/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1635 - accuracy: 0.9465 - val_loss: 0.1655 - val_accuracy: 0.9427
#
# Epoch 00010: val_loss did not improve from 0.14876
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1554 - accuracy: 0.9489 - val_loss: 0.1687 - val_accuracy: 0.9458
#
# Epoch 00011: val_loss did not improve from 0.14876
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1493 - accuracy: 0.9504 - val_loss: 0.1474 - val_accuracy: 0.9518
#
# Epoch 00012: val_loss improved from 0.14876 to 0.14740, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1419 - accuracy: 0.9527 - val_loss: 0.1505 - val_accuracy: 0.9514
#
# Epoch 00013: val_loss did not improve from 0.14740
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1343 - accuracy: 0.9556 - val_loss: 0.1507 - val_accuracy: 0.9510
#
# Epoch 00014: val_loss did not improve from 0.14740
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1294 - accuracy: 0.9575 - val_loss: 0.1541 - val_accuracy: 0.9499
#
# Epoch 00015: val_loss did not improve from 0.14740
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1260 - accuracy: 0.9585 - val_loss: 0.1449 - val_accuracy: 0.9552
#
# Epoch 00016: val_loss improved from 0.14740 to 0.14486, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1230 - accuracy: 0.9606 - val_loss: 0.1433 - val_accuracy: 0.9548
#
# Epoch 00017: val_loss improved from 0.14486 to 0.14331, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1144 - accuracy: 0.9621 - val_loss: 0.1531 - val_accuracy: 0.9567
#
# Epoch 00018: val_loss did not improve from 0.14331
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1138 - accuracy: 0.9628 - val_loss: 0.1688 - val_accuracy: 0.9525
#
# Epoch 00019: val_loss did not improve from 0.14331
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1117 - accuracy: 0.9631 - val_loss: 0.1542 - val_accuracy: 0.9582
#
# Epoch 00020: val_loss did not improve from 0.14331
# Epoch 21/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1109 - accuracy: 0.9638 - val_loss: 0.1521 - val_accuracy: 0.9548
#
# Epoch 00021: val_loss did not improve from 0.14331
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1004 - accuracy: 0.9671 - val_loss: 0.1477 - val_accuracy: 0.9540
#
# Epoch 00022: val_loss did not improve from 0.14331
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0991 - accuracy: 0.9668 - val_loss: 0.1603 - val_accuracy: 0.9567
#
# Epoch 00023: val_loss did not improve from 0.14331
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0953 - accuracy: 0.9681 - val_loss: 0.1551 - val_accuracy: 0.9574
#
# Epoch 00024: val_loss did not improve from 0.14331
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0942 - accuracy: 0.9687 - val_loss: 0.1636 - val_accuracy: 0.9586
#
# Epoch 00025: val_loss did not improve from 0.14331
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0938 - accuracy: 0.9691 - val_loss: 0.1646 - val_accuracy: 0.9571
#
# Epoch 00026: val_loss did not improve from 0.14331
# Epoch 27/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0917 - accuracy: 0.9693 - val_loss: 0.1623 - val_accuracy: 0.9582
#
# Epoch 00027: val_loss did not improve from 0.14331
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0933 - accuracy: 0.9700 - val_loss: 0.1662 - val_accuracy: 0.9571
#
# Epoch 00028: val_loss did not improve from 0.14331
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0865 - accuracy: 0.9719 - val_loss: 0.1609 - val_accuracy: 0.9589
#
# Epoch 00029: val_loss did not improve from 0.14331
# Epoch 30/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0865 - accuracy: 0.9710 - val_loss: 0.1735 - val_accuracy: 0.9571
#
# Epoch 00030: val_loss did not improve from 0.14331
# Epoch 31/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0815 - accuracy: 0.9740 - val_loss: 0.1812 - val_accuracy: 0.9559
#
# Epoch 00031: val_loss did not improve from 0.14331
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0840 - accuracy: 0.9723 - val_loss: 0.1707 - val_accuracy: 0.9593
#
# Epoch 00032: val_loss did not improve from 0.14331
# Epoch 33/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0826 - accuracy: 0.9732 - val_loss: 0.1816 - val_accuracy: 0.9589
#
# Epoch 00033: val_loss did not improve from 0.14331
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0832 - accuracy: 0.9729 - val_loss: 0.1729 - val_accuracy: 0.9589
#
# Epoch 00034: val_loss did not improve from 0.14331
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0817 - accuracy: 0.9736 - val_loss: 0.1686 - val_accuracy: 0.9574
#
# Epoch 00035: val_loss did not improve from 0.14331
# Score for fold 2: loss of 0.1685820370912552; accuracy of 95.74387669563293%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5531 - accuracy: 0.8344 - val_loss: 0.2864 - val_accuracy: 0.9104
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3158 - accuracy: 0.9011 - val_loss: 0.2393 - val_accuracy: 0.9292
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2596 - accuracy: 0.9175 - val_loss: 0.2002 - val_accuracy: 0.9397
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2380 - accuracy: 0.9248 - val_loss: 0.1962 - val_accuracy: 0.9409
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2123 - accuracy: 0.9330 - val_loss: 0.1799 - val_accuracy: 0.9443
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1983 - accuracy: 0.9371 - val_loss: 0.1696 - val_accuracy: 0.9514
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1825 - accuracy: 0.9409 - val_loss: 0.1788 - val_accuracy: 0.9529
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1713 - accuracy: 0.9434 - val_loss: 0.1584 - val_accuracy: 0.9540
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1621 - accuracy: 0.9476 - val_loss: 0.1860 - val_accuracy: 0.9446
#
# Epoch 00009: val_loss did not improve from 0.14331
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1553 - accuracy: 0.9494 - val_loss: 0.1532 - val_accuracy: 0.9559
#
# Epoch 00010: val_loss did not improve from 0.14331
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1437 - accuracy: 0.9530 - val_loss: 0.1613 - val_accuracy: 0.9571
#
# Epoch 00011: val_loss did not improve from 0.14331
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1338 - accuracy: 0.9559 - val_loss: 0.1576 - val_accuracy: 0.9567
#
# Epoch 00012: val_loss did not improve from 0.14331
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1340 - accuracy: 0.9568 - val_loss: 0.1512 - val_accuracy: 0.9563
#
# Epoch 00013: val_loss did not improve from 0.14331
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1224 - accuracy: 0.9594 - val_loss: 0.1507 - val_accuracy: 0.9586
#
# Epoch 00014: val_loss did not improve from 0.14331
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1216 - accuracy: 0.9607 - val_loss: 0.1465 - val_accuracy: 0.9597
#
# Epoch 00015: val_loss did not improve from 0.14331
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1174 - accuracy: 0.9620 - val_loss: 0.1487 - val_accuracy: 0.9605
#
# Epoch 00016: val_loss did not improve from 0.14331
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1129 - accuracy: 0.9633 - val_loss: 0.1520 - val_accuracy: 0.9593
#
# Epoch 00017: val_loss did not improve from 0.14331
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1144 - accuracy: 0.9616 - val_loss: 0.1531 - val_accuracy: 0.9605
#
# Epoch 00018: val_loss did not improve from 0.14331
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1064 - accuracy: 0.9638 - val_loss: 0.1479 - val_accuracy: 0.9597
#
# Epoch 00019: val_loss did not improve from 0.14331
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1029 - accuracy: 0.9663 - val_loss: 0.1616 - val_accuracy: 0.9578
#
# Epoch 00020: val_loss did not improve from 0.14331
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0987 - accuracy: 0.9670 - val_loss: 0.1594 - val_accuracy: 0.9593
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.14331
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0910 - accuracy: 0.9703 - val_loss: 0.1473 - val_accuracy: 0.9616
#
# Epoch 00022: val_loss did not improve from 0.14331
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0821 - accuracy: 0.9720 - val_loss: 0.1462 - val_accuracy: 0.9646
#
# Epoch 00023: val_loss did not improve from 0.14331
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0787 - accuracy: 0.9742 - val_loss: 0.1606 - val_accuracy: 0.9642
#
# Epoch 00024: val_loss did not improve from 0.14331
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0788 - accuracy: 0.9740 - val_loss: 0.1501 - val_accuracy: 0.9650
#
# Epoch 00025: val_loss did not improve from 0.14331
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0779 - accuracy: 0.9744 - val_loss: 0.1573 - val_accuracy: 0.9635
#
# Epoch 00026: val_loss did not improve from 0.14331
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0785 - accuracy: 0.9731 - val_loss: 0.1560 - val_accuracy: 0.9642
#
# Epoch 00027: val_loss did not improve from 0.14331
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0736 - accuracy: 0.9753 - val_loss: 0.1727 - val_accuracy: 0.9623
#
# Epoch 00028: val_loss did not improve from 0.14331
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0723 - accuracy: 0.9761 - val_loss: 0.1474 - val_accuracy: 0.9653
#
# Epoch 00029: val_loss did not improve from 0.14331
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0706 - accuracy: 0.9771 - val_loss: 0.1752 - val_accuracy: 0.9627
#
# Epoch 00030: val_loss did not improve from 0.14331
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0691 - accuracy: 0.9762 - val_loss: 0.1674 - val_accuracy: 0.9646
#
# Epoch 00031: val_loss did not improve from 0.14331
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0698 - accuracy: 0.9769 - val_loss: 0.1607 - val_accuracy: 0.9653
#
# Epoch 00032: val_loss did not improve from 0.14331
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0683 - accuracy: 0.9758 - val_loss: 0.1544 - val_accuracy: 0.9638
#
# Epoch 00033: val_loss did not improve from 0.14331
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0670 - accuracy: 0.9771 - val_loss: 0.1747 - val_accuracy: 0.9623
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.14331
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0642 - accuracy: 0.9781 - val_loss: 0.1588 - val_accuracy: 0.9650
#
# Epoch 00035: val_loss did not improve from 0.14331
# Score for fold 3: loss of 0.1588248610496521; accuracy of 96.49717807769775%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5945 - accuracy: 0.8213 - val_loss: 0.3241 - val_accuracy: 0.8964
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3251 - accuracy: 0.8949 - val_loss: 0.2589 - val_accuracy: 0.9224
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2727 - accuracy: 0.9141 - val_loss: 0.2438 - val_accuracy: 0.9232
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2465 - accuracy: 0.9210 - val_loss: 0.2423 - val_accuracy: 0.9235
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2252 - accuracy: 0.9286 - val_loss: 0.2121 - val_accuracy: 0.9345
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2062 - accuracy: 0.9337 - val_loss: 0.2060 - val_accuracy: 0.9367
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1916 - accuracy: 0.9386 - val_loss: 0.2157 - val_accuracy: 0.9375
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1827 - accuracy: 0.9397 - val_loss: 0.1907 - val_accuracy: 0.9382
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1679 - accuracy: 0.9446 - val_loss: 0.1880 - val_accuracy: 0.9401
#
# Epoch 00009: val_loss did not improve from 0.14331
# Epoch 10/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1629 - accuracy: 0.9463 - val_loss: 0.1886 - val_accuracy: 0.9427
#
# Epoch 00010: val_loss did not improve from 0.14331
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1536 - accuracy: 0.9494 - val_loss: 0.2010 - val_accuracy: 0.9412
#
# Epoch 00011: val_loss did not improve from 0.14331
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1450 - accuracy: 0.9517 - val_loss: 0.1884 - val_accuracy: 0.9409
#
# Epoch 00012: val_loss did not improve from 0.14331
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1405 - accuracy: 0.9526 - val_loss: 0.1921 - val_accuracy: 0.9431
#
# Epoch 00013: val_loss did not improve from 0.14331
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1370 - accuracy: 0.9550 - val_loss: 0.1704 - val_accuracy: 0.9473
#
# Epoch 00014: val_loss did not improve from 0.14331
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1285 - accuracy: 0.9568 - val_loss: 0.1843 - val_accuracy: 0.9473
#
# Epoch 00015: val_loss did not improve from 0.14331
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1252 - accuracy: 0.9582 - val_loss: 0.1825 - val_accuracy: 0.9480
#
# Epoch 00016: val_loss did not improve from 0.14331
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1204 - accuracy: 0.9598 - val_loss: 0.1703 - val_accuracy: 0.9488
#
# Epoch 00017: val_loss did not improve from 0.14331
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1216 - accuracy: 0.9603 - val_loss: 0.1724 - val_accuracy: 0.9473
#
# Epoch 00018: val_loss did not improve from 0.14331
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1140 - accuracy: 0.9614 - val_loss: 0.1881 - val_accuracy: 0.9510
#
# Epoch 00019: val_loss did not improve from 0.14331
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1104 - accuracy: 0.9633 - val_loss: 0.1770 - val_accuracy: 0.9499
#
# Epoch 00020: val_loss did not improve from 0.14331
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1101 - accuracy: 0.9629 - val_loss: 0.1728 - val_accuracy: 0.9488
#
# Epoch 00021: val_loss did not improve from 0.14331
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1048 - accuracy: 0.9647 - val_loss: 0.2031 - val_accuracy: 0.9488
#
# Epoch 00022: val_loss did not improve from 0.14331
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1041 - accuracy: 0.9650 - val_loss: 0.2114 - val_accuracy: 0.9507
#
# Epoch 00023: val_loss did not improve from 0.14331
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1038 - accuracy: 0.9656 - val_loss: 0.1906 - val_accuracy: 0.9495
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.14331
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0877 - accuracy: 0.9700 - val_loss: 0.1798 - val_accuracy: 0.9522
#
# Epoch 00025: val_loss did not improve from 0.14331
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0790 - accuracy: 0.9736 - val_loss: 0.1885 - val_accuracy: 0.9507
#
# Epoch 00026: val_loss did not improve from 0.14331
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0779 - accuracy: 0.9741 - val_loss: 0.1848 - val_accuracy: 0.9544
#
# Epoch 00027: val_loss did not improve from 0.14331
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0801 - accuracy: 0.9732 - val_loss: 0.2168 - val_accuracy: 0.9514
#
# Epoch 00028: val_loss did not improve from 0.14331
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0741 - accuracy: 0.9752 - val_loss: 0.2060 - val_accuracy: 0.9529
#
# Epoch 00029: val_loss did not improve from 0.14331
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0748 - accuracy: 0.9741 - val_loss: 0.1969 - val_accuracy: 0.9529
#
# Epoch 00030: val_loss did not improve from 0.14331
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0741 - accuracy: 0.9749 - val_loss: 0.1980 - val_accuracy: 0.9533
#
# Epoch 00031: val_loss did not improve from 0.14331
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0706 - accuracy: 0.9768 - val_loss: 0.2083 - val_accuracy: 0.9548
#
# Epoch 00032: val_loss did not improve from 0.14331
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0698 - accuracy: 0.9761 - val_loss: 0.2158 - val_accuracy: 0.9552
#
# Epoch 00033: val_loss did not improve from 0.14331
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0670 - accuracy: 0.9777 - val_loss: 0.1982 - val_accuracy: 0.9556
#
# Epoch 00034: val_loss did not improve from 0.14331
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0705 - accuracy: 0.9760 - val_loss: 0.2098 - val_accuracy: 0.9522
#
# Epoch 00035: val_loss did not improve from 0.14331
# Score for fold 4: loss of 0.20977143943309784; accuracy of 95.21657228469849%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5529 - accuracy: 0.8315 - val_loss: 0.3063 - val_accuracy: 0.9081
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3054 - accuracy: 0.9015 - val_loss: 0.2482 - val_accuracy: 0.9288
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2535 - accuracy: 0.9190 - val_loss: 0.2275 - val_accuracy: 0.9315
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2256 - accuracy: 0.9264 - val_loss: 0.2077 - val_accuracy: 0.9371
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2025 - accuracy: 0.9352 - val_loss: 0.1993 - val_accuracy: 0.9409
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1846 - accuracy: 0.9393 - val_loss: 0.1865 - val_accuracy: 0.9427
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1727 - accuracy: 0.9440 - val_loss: 0.2014 - val_accuracy: 0.9446
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1619 - accuracy: 0.9484 - val_loss: 0.1799 - val_accuracy: 0.9507
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1473 - accuracy: 0.9514 - val_loss: 0.1788 - val_accuracy: 0.9540
#
# Epoch 00009: val_loss did not improve from 0.14331
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1433 - accuracy: 0.9534 - val_loss: 0.1763 - val_accuracy: 0.9529
#
# Epoch 00010: val_loss did not improve from 0.14331
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1353 - accuracy: 0.9556 - val_loss: 0.1739 - val_accuracy: 0.9537
#
# Epoch 00011: val_loss did not improve from 0.14331
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1288 - accuracy: 0.9584 - val_loss: 0.1742 - val_accuracy: 0.9533
#
# Epoch 00012: val_loss did not improve from 0.14331
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1219 - accuracy: 0.9587 - val_loss: 0.1714 - val_accuracy: 0.9567
#
# Epoch 00013: val_loss did not improve from 0.14331
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1180 - accuracy: 0.9610 - val_loss: 0.1814 - val_accuracy: 0.9537
#
# Epoch 00014: val_loss did not improve from 0.14331
# Epoch 15/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1138 - accuracy: 0.9621 - val_loss: 0.1848 - val_accuracy: 0.9544
#
# Epoch 00015: val_loss did not improve from 0.14331
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1096 - accuracy: 0.9627 - val_loss: 0.1890 - val_accuracy: 0.9559
#
# Epoch 00016: val_loss did not improve from 0.14331
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1061 - accuracy: 0.9646 - val_loss: 0.1876 - val_accuracy: 0.9563
#
# Epoch 00017: val_loss did not improve from 0.14331
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1063 - accuracy: 0.9657 - val_loss: 0.1785 - val_accuracy: 0.9559
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.14331
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0852 - accuracy: 0.9720 - val_loss: 0.1893 - val_accuracy: 0.9563
#
# Epoch 00019: val_loss did not improve from 0.14331
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0821 - accuracy: 0.9725 - val_loss: 0.1996 - val_accuracy: 0.9574
#
# Epoch 00020: val_loss did not improve from 0.14331
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0805 - accuracy: 0.9731 - val_loss: 0.1881 - val_accuracy: 0.9559
#
# Epoch 00021: val_loss did not improve from 0.14331
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0770 - accuracy: 0.9744 - val_loss: 0.1973 - val_accuracy: 0.9589
#
# Epoch 00022: val_loss did not improve from 0.14331
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0766 - accuracy: 0.9741 - val_loss: 0.1986 - val_accuracy: 0.9608
#
# Epoch 00023: val_loss did not improve from 0.14331
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0737 - accuracy: 0.9747 - val_loss: 0.2129 - val_accuracy: 0.9601
#
# Epoch 00024: val_loss did not improve from 0.14331
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0728 - accuracy: 0.9758 - val_loss: 0.2242 - val_accuracy: 0.9586
#
# Epoch 00025: val_loss did not improve from 0.14331
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0695 - accuracy: 0.9766 - val_loss: 0.2190 - val_accuracy: 0.9589
#
# Epoch 00026: val_loss did not improve from 0.14331
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0687 - accuracy: 0.9767 - val_loss: 0.2107 - val_accuracy: 0.9582
#
# Epoch 00027: val_loss did not improve from 0.14331
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0675 - accuracy: 0.9772 - val_loss: 0.2150 - val_accuracy: 0.9586
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.14331
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0650 - accuracy: 0.9777 - val_loss: 0.2225 - val_accuracy: 0.9582
#
# Epoch 00029: val_loss did not improve from 0.14331
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0594 - accuracy: 0.9798 - val_loss: 0.2122 - val_accuracy: 0.9586
#
# Epoch 00030: val_loss did not improve from 0.14331
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0616 - accuracy: 0.9789 - val_loss: 0.2243 - val_accuracy: 0.9582
#
# Epoch 00031: val_loss did not improve from 0.14331
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0600 - accuracy: 0.9792 - val_loss: 0.2343 - val_accuracy: 0.9578
#
# Epoch 00032: val_loss did not improve from 0.14331
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0581 - accuracy: 0.9793 - val_loss: 0.2423 - val_accuracy: 0.9601
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.14331
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0572 - accuracy: 0.9805 - val_loss: 0.2304 - val_accuracy: 0.9589
#
# Epoch 00034: val_loss did not improve from 0.14331
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0552 - accuracy: 0.9810 - val_loss: 0.2371 - val_accuracy: 0.9589
#
# Epoch 00035: val_loss did not improve from 0.14331
# Score for fold 5: loss of 0.2371147722005844; accuracy of 95.89453935623169%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5947 - accuracy: 0.8244 - val_loss: 0.3733 - val_accuracy: 0.8723
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.3340 - accuracy: 0.8943 - val_loss: 0.2481 - val_accuracy: 0.9171
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2694 - accuracy: 0.9135 - val_loss: 0.2304 - val_accuracy: 0.9232
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2378 - accuracy: 0.9254 - val_loss: 0.2136 - val_accuracy: 0.9296
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2211 - accuracy: 0.9298 - val_loss: 0.1975 - val_accuracy: 0.9363
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.2036 - accuracy: 0.9348 - val_loss: 0.1880 - val_accuracy: 0.9379
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1947 - accuracy: 0.9375 - val_loss: 0.1739 - val_accuracy: 0.9443
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1805 - accuracy: 0.9429 - val_loss: 0.1751 - val_accuracy: 0.9412
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1695 - accuracy: 0.9450 - val_loss: 0.1629 - val_accuracy: 0.9484
#
# Epoch 00009: val_loss did not improve from 0.14331
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1621 - accuracy: 0.9481 - val_loss: 0.1663 - val_accuracy: 0.9465
#
# Epoch 00010: val_loss did not improve from 0.14331
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1527 - accuracy: 0.9503 - val_loss: 0.1624 - val_accuracy: 0.9473
#
# Epoch 00011: val_loss did not improve from 0.14331
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1466 - accuracy: 0.9522 - val_loss: 0.1664 - val_accuracy: 0.9495
#
# Epoch 00012: val_loss did not improve from 0.14331
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1405 - accuracy: 0.9540 - val_loss: 0.1639 - val_accuracy: 0.9495
#
# Epoch 00013: val_loss did not improve from 0.14331
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1328 - accuracy: 0.9554 - val_loss: 0.1717 - val_accuracy: 0.9473
#
# Epoch 00014: val_loss did not improve from 0.14331
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1298 - accuracy: 0.9575 - val_loss: 0.1685 - val_accuracy: 0.9499
#
# Epoch 00015: val_loss did not improve from 0.14331
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1251 - accuracy: 0.9591 - val_loss: 0.1725 - val_accuracy: 0.9510
#
# Epoch 00016: val_loss did not improve from 0.14331
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1197 - accuracy: 0.9615 - val_loss: 0.1780 - val_accuracy: 0.9514
#
# Epoch 00017: val_loss did not improve from 0.14331
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1171 - accuracy: 0.9620 - val_loss: 0.1790 - val_accuracy: 0.9507
#
# Epoch 00018: val_loss did not improve from 0.14331
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1135 - accuracy: 0.9622 - val_loss: 0.1777 - val_accuracy: 0.9514
#
# Epoch 00019: val_loss did not improve from 0.14331
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1095 - accuracy: 0.9647 - val_loss: 0.1739 - val_accuracy: 0.9510
#
# Epoch 00020: val_loss did not improve from 0.14331
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1070 - accuracy: 0.9645 - val_loss: 0.1638 - val_accuracy: 0.9533
#
# Epoch 00021: val_loss did not improve from 0.14331
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1007 - accuracy: 0.9663 - val_loss: 0.1783 - val_accuracy: 0.9522
#
# Epoch 00022: val_loss did not improve from 0.14331
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1035 - accuracy: 0.9661 - val_loss: 0.1741 - val_accuracy: 0.9514
#
# Epoch 00023: val_loss did not improve from 0.14331
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0972 - accuracy: 0.9684 - val_loss: 0.1751 - val_accuracy: 0.9507
#
# Epoch 00024: val_loss did not improve from 0.14331
# Epoch 25/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0937 - accuracy: 0.9691 - val_loss: 0.1665 - val_accuracy: 0.9540
#
# Epoch 00025: val_loss did not improve from 0.14331
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0975 - accuracy: 0.9694 - val_loss: 0.1823 - val_accuracy: 0.9522
#
# Epoch 00026: val_loss did not improve from 0.14331
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0913 - accuracy: 0.9701 - val_loss: 0.1755 - val_accuracy: 0.9559
#
# Epoch 00027: val_loss did not improve from 0.14331
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0905 - accuracy: 0.9705 - val_loss: 0.1841 - val_accuracy: 0.9563
#
# Epoch 00028: val_loss did not improve from 0.14331
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0883 - accuracy: 0.9708 - val_loss: 0.1956 - val_accuracy: 0.9533
#
# Epoch 00029: val_loss did not improve from 0.14331
# Epoch 30/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0869 - accuracy: 0.9713 - val_loss: 0.1727 - val_accuracy: 0.9563
#
# Epoch 00030: val_loss did not improve from 0.14331
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0833 - accuracy: 0.9731 - val_loss: 0.1927 - val_accuracy: 0.9537
#
# Epoch 00031: val_loss did not improve from 0.14331
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0823 - accuracy: 0.9730 - val_loss: 0.2015 - val_accuracy: 0.9514
#
# Epoch 00032: val_loss did not improve from 0.14331
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0886 - accuracy: 0.9723 - val_loss: 0.1762 - val_accuracy: 0.9556
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00033: val_loss did not improve from 0.14331
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0695 - accuracy: 0.9774 - val_loss: 0.1879 - val_accuracy: 0.9567
#
# Epoch 00034: val_loss did not improve from 0.14331
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0678 - accuracy: 0.9773 - val_loss: 0.1865 - val_accuracy: 0.9574
#
# Epoch 00035: val_loss did not improve from 0.14331
# Score for fold 6: loss of 0.1865232139825821; accuracy of 95.74387669563293%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5655 - accuracy: 0.8294 - val_loss: 0.2936 - val_accuracy: 0.9081
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3091 - accuracy: 0.9011 - val_loss: 0.2555 - val_accuracy: 0.9190
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2621 - accuracy: 0.9148 - val_loss: 0.2297 - val_accuracy: 0.9307
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2395 - accuracy: 0.9239 - val_loss: 0.2181 - val_accuracy: 0.9333
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2151 - accuracy: 0.9311 - val_loss: 0.1933 - val_accuracy: 0.9416
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2042 - accuracy: 0.9345 - val_loss: 0.1758 - val_accuracy: 0.9443
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1894 - accuracy: 0.9393 - val_loss: 0.1706 - val_accuracy: 0.9473
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1800 - accuracy: 0.9427 - val_loss: 0.1744 - val_accuracy: 0.9473
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1685 - accuracy: 0.9442 - val_loss: 0.1596 - val_accuracy: 0.9525
#
# Epoch 00009: val_loss did not improve from 0.14331
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1622 - accuracy: 0.9468 - val_loss: 0.1545 - val_accuracy: 0.9544
#
# Epoch 00010: val_loss did not improve from 0.14331
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1466 - accuracy: 0.9512 - val_loss: 0.1576 - val_accuracy: 0.9529
#
# Epoch 00011: val_loss did not improve from 0.14331
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1434 - accuracy: 0.9526 - val_loss: 0.1587 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.14331
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1376 - accuracy: 0.9544 - val_loss: 0.1650 - val_accuracy: 0.9525
#
# Epoch 00013: val_loss did not improve from 0.14331
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1332 - accuracy: 0.9559 - val_loss: 0.1510 - val_accuracy: 0.9518
#
# Epoch 00014: val_loss did not improve from 0.14331
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1232 - accuracy: 0.9596 - val_loss: 0.1562 - val_accuracy: 0.9552
#
# Epoch 00015: val_loss did not improve from 0.14331
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1175 - accuracy: 0.9608 - val_loss: 0.1520 - val_accuracy: 0.9586
#
# Epoch 00016: val_loss did not improve from 0.14331
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1144 - accuracy: 0.9611 - val_loss: 0.1531 - val_accuracy: 0.9574
#
# Epoch 00017: val_loss did not improve from 0.14331
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1158 - accuracy: 0.9614 - val_loss: 0.1494 - val_accuracy: 0.9571
#
# Epoch 00018: val_loss did not improve from 0.14331
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1089 - accuracy: 0.9640 - val_loss: 0.1641 - val_accuracy: 0.9563
#
# Epoch 00019: val_loss did not improve from 0.14331
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1072 - accuracy: 0.9639 - val_loss: 0.1486 - val_accuracy: 0.9563
#
# Epoch 00020: val_loss did not improve from 0.14331
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1077 - accuracy: 0.9636 - val_loss: 0.1581 - val_accuracy: 0.9567
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.14331
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0882 - accuracy: 0.9704 - val_loss: 0.1542 - val_accuracy: 0.9582
#
# Epoch 00022: val_loss did not improve from 0.14331
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0863 - accuracy: 0.9720 - val_loss: 0.1800 - val_accuracy: 0.9540
#
# Epoch 00023: val_loss did not improve from 0.14331
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0792 - accuracy: 0.9731 - val_loss: 0.1567 - val_accuracy: 0.9574
#
# ...
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0685 - accuracy: 0.9767 - val_loss: 0.1799 - val_accuracy: 0.9556
#
# Epoch 00030: val_loss did not improve from 0.14331
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0657 - accuracy: 0.9774 - val_loss: 0.1886 - val_accuracy: 0.9578
#
# Epoch 00031: val_loss did not improve from 0.14331
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0695 - accuracy: 0.9763 - val_loss: 0.1924 - val_accuracy: 0.9567
#
# Epoch 00032: val_loss did not improve from 0.14331
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0670 - accuracy: 0.9778 - val_loss: 0.1888 - val_accuracy: 0.9563
#
# Epoch 00033: val_loss did not improve from 0.14331
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0686 - accuracy: 0.9771 - val_loss: 0.1943 - val_accuracy: 0.9563
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.14331
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0619 - accuracy: 0.9789 - val_loss: 0.1950 - val_accuracy: 0.9586
#
# Epoch 00035: val_loss did not improve from 0.14331
# Score for fold 8: loss of 0.19503435492515564; accuracy of 95.85687518119812%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5398 - accuracy: 0.8379 - val_loss: 0.2574 - val_accuracy: 0.9164
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3010 - accuracy: 0.9045 - val_loss: 0.2037 - val_accuracy: 0.9273
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2516 - accuracy: 0.9201 - val_loss: 0.1929 - val_accuracy: 0.9310
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2263 - accuracy: 0.9279 - val_loss: 0.1692 - val_accuracy: 0.9461
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2124 - accuracy: 0.9320 - val_loss: 0.1604 - val_accuracy: 0.9506
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1909 - accuracy: 0.9388 - val_loss: 0.1550 - val_accuracy: 0.9529
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1762 - accuracy: 0.9437 - val_loss: 0.1457 - val_accuracy: 0.9529
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1679 - accuracy: 0.9453 - val_loss: 0.1443 - val_accuracy: 0.9570
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1581 - accuracy: 0.9489 - val_loss: 0.1359 - val_accuracy: 0.9593
#
# Epoch 00009: val_loss improved from 0.14331 to 0.13588, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1486 - accuracy: 0.9511 - val_loss: 0.1391 - val_accuracy: 0.9601
#
# Epoch 00010: val_loss did not improve from 0.13588
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1432 - accuracy: 0.9528 - val_loss: 0.1709 - val_accuracy: 0.9476
#
# Epoch 00011: val_loss did not improve from 0.13588
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1340 - accuracy: 0.9561 - val_loss: 0.1350 - val_accuracy: 0.9589
#
# Epoch 00012: val_loss improved from 0.13588 to 0.13501, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1310 - accuracy: 0.9563 - val_loss: 0.1349 - val_accuracy: 0.9597
#
# Epoch 00013: val_loss improved from 0.13501 to 0.13487, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1250 - accuracy: 0.9587 - val_loss: 0.1850 - val_accuracy: 0.9457
#
# Epoch 00014: val_loss did not improve from 0.13487
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1205 - accuracy: 0.9605 - val_loss: 0.1291 - val_accuracy: 0.9612
#
# Epoch 00015: val_loss improved from 0.13487 to 0.12915, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1147 - accuracy: 0.9623 - val_loss: 0.1320 - val_accuracy: 0.9597
#
# Epoch 00016: val_loss did not improve from 0.12915
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1122 - accuracy: 0.9625 - val_loss: 0.1431 - val_accuracy: 0.9627
#
# Epoch 00017: val_loss did not improve from 0.12915
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1083 - accuracy: 0.9648 - val_loss: 0.1257 - val_accuracy: 0.9616
#
# Epoch 00018: val_loss improved from 0.12915 to 0.12569, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1058 - accuracy: 0.9649 - val_loss: 0.1243 - val_accuracy: 0.9635
#
# Epoch 00019: val_loss improved from 0.12569 to 0.12430, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1018 - accuracy: 0.9662 - val_loss: 0.1400 - val_accuracy: 0.9608
#
# Epoch 00020: val_loss did not improve from 0.12430
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0989 - accuracy: 0.9674 - val_loss: 0.1501 - val_accuracy: 0.9638
#
# Epoch 00021: val_loss did not improve from 0.12430
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0985 - accuracy: 0.9674 - val_loss: 0.1399 - val_accuracy: 0.9604
#
# Epoch 00022: val_loss did not improve from 0.12430
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0906 - accuracy: 0.9691 - val_loss: 0.1537 - val_accuracy: 0.9608
#
# Epoch 00023: val_loss did not improve from 0.12430
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0935 - accuracy: 0.9692 - val_loss: 0.1459 - val_accuracy: 0.9612
#
# Epoch 00024: val_loss did not improve from 0.12430
# Epoch 25/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0902 - accuracy: 0.9703 - val_loss: 0.1522 - val_accuracy: 0.9623
#
# Epoch 00025: val_loss did not improve from 0.12430
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0923 - accuracy: 0.9693 - val_loss: 0.1371 - val_accuracy: 0.9638
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00026: val_loss did not improve from 0.12430
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0796 - accuracy: 0.9745 - val_loss: 0.1335 - val_accuracy: 0.9638
#
# Epoch 00027: val_loss did not improve from 0.12430
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0748 - accuracy: 0.9750 - val_loss: 0.1321 - val_accuracy: 0.9653
#
# Epoch 00028: val_loss did not improve from 0.12430
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0724 - accuracy: 0.9764 - val_loss: 0.1279 - val_accuracy: 0.9657
#
# Epoch 00029: val_loss did not improve from 0.12430
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0729 - accuracy: 0.9762 - val_loss: 0.1507 - val_accuracy: 0.9638
#
# Epoch 00030: val_loss did not improve from 0.12430
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0687 - accuracy: 0.9768 - val_loss: 0.1467 - val_accuracy: 0.9653
#
# Epoch 00031: val_loss did not improve from 0.12430
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0676 - accuracy: 0.9772 - val_loss: 0.1558 - val_accuracy: 0.9642
#
# Epoch 00032: val_loss did not improve from 0.12430
# Epoch 33/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0703 - accuracy: 0.9772 - val_loss: 0.1452 - val_accuracy: 0.9638
#
# Epoch 00033: val_loss did not improve from 0.12430
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0676 - accuracy: 0.9771 - val_loss: 0.1520 - val_accuracy: 0.9635
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.12430
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0627 - accuracy: 0.9785 - val_loss: 0.1518 - val_accuracy: 0.9642
#
# Epoch 00035: val_loss did not improve from 0.12430
# Score for fold 9: loss of 0.15177185833454132; accuracy of 96.42049670219421%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.6018 - accuracy: 0.8218 - val_loss: 0.3419 - val_accuracy: 0.8888
#
# Epoch 00001: val_loss did not improve from 0.12430
# Epoch 2/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.3242 - accuracy: 0.8979 - val_loss: 0.2639 - val_accuracy: 0.9182
# Epoch 00002: val_loss did not improve from 0.12430
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2673 - accuracy: 0.9143 - val_loss: 0.2321 - val_accuracy: 0.9284
#
# Epoch 00003: val_loss did not improve from 0.12430
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2408 - accuracy: 0.9225 - val_loss: 0.2160 - val_accuracy: 0.9341
#
# Epoch 00004: val_loss did not improve from 0.12430
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2183 - accuracy: 0.9300 - val_loss: 0.2060 - val_accuracy: 0.9386
#
# Epoch 00005: val_loss did not improve from 0.12430
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2075 - accuracy: 0.9311 - val_loss: 0.2042 - val_accuracy: 0.9386
#
# Epoch 00006: val_loss did not improve from 0.12430
# Epoch 7/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1956 - accuracy: 0.9359 - val_loss: 0.1879 - val_accuracy: 0.9412
#
# Epoch 00007: val_loss did not improve from 0.12430
# Epoch 8/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1852 - accuracy: 0.9379 - val_loss: 0.1848 - val_accuracy: 0.9405
#
# Epoch 00008: val_loss did not improve from 0.12430
# Epoch 9/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1786 - accuracy: 0.9420 - val_loss: 0.2052 - val_accuracy: 0.9393
#
# Epoch 00009: val_loss did not improve from 0.12430
# Epoch 10/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1664 - accuracy: 0.9467 - val_loss: 0.1746 - val_accuracy: 0.9472
#
# Epoch 00010: val_loss did not improve from 0.12430
# Epoch 11/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1571 - accuracy: 0.9471 - val_loss: 0.1901 - val_accuracy: 0.9427
#
# Epoch 00011: val_loss did not improve from 0.12430
# Epoch 12/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1517 - accuracy: 0.9499 - val_loss: 0.1765 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss did not improve from 0.12430
# Epoch 13/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1478 - accuracy: 0.9512 - val_loss: 0.1778 - val_accuracy: 0.9491
#
# Epoch 00013: val_loss did not improve from 0.12430
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1392 - accuracy: 0.9538 - val_loss: 0.1907 - val_accuracy: 0.9431
#
# Epoch 00014: val_loss did not improve from 0.12430
# Epoch 15/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1382 - accuracy: 0.9535 - val_loss: 0.1739 - val_accuracy: 0.9529
#
# Epoch 00015: val_loss did not improve from 0.12430
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1288 - accuracy: 0.9573 - val_loss: 0.1778 - val_accuracy: 0.9476
#
# Epoch 00016: val_loss did not improve from 0.12430
# Epoch 17/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1292 - accuracy: 0.9570 - val_loss: 0.1852 - val_accuracy: 0.9469
#
# Epoch 00017: val_loss did not improve from 0.12430
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1242 - accuracy: 0.9588 - val_loss: 0.1684 - val_accuracy: 0.9518
#
# Epoch 00018: val_loss did not improve from 0.12430
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1195 - accuracy: 0.9596 - val_loss: 0.1748 - val_accuracy: 0.9491
#
# Epoch 00019: val_loss did not improve from 0.12430
# Epoch 20/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1165 - accuracy: 0.9620 - val_loss: 0.1812 - val_accuracy: 0.9521
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.12430
# Epoch 21/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1026 - accuracy: 0.9661 - val_loss: 0.1775 - val_accuracy: 0.9540
#
# Epoch 00021: val_loss did not improve from 0.12430
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0979 - accuracy: 0.9673 - val_loss: 0.1798 - val_accuracy: 0.9529
#
# Epoch 00022: val_loss did not improve from 0.12430
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0929 - accuracy: 0.9688 - val_loss: 0.1775 - val_accuracy: 0.9548
#
# Epoch 00023: val_loss did not improve from 0.12430
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0913 - accuracy: 0.9687 - val_loss: 0.1897 - val_accuracy: 0.9521
#
# Epoch 00024: val_loss did not improve from 0.12430
# Epoch 25/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0887 - accuracy: 0.9699 - val_loss: 0.1861 - val_accuracy: 0.9537
#
# Epoch 00025: val_loss did not improve from 0.12430
# Epoch 26/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0870 - accuracy: 0.9707 - val_loss: 0.1922 - val_accuracy: 0.9552
#
# Epoch 00026: val_loss did not improve from 0.12430
# Epoch 27/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0849 - accuracy: 0.9716 - val_loss: 0.1863 - val_accuracy: 0.9521
#
# Epoch 00027: val_loss did not improve from 0.12430
# Epoch 28/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0856 - accuracy: 0.9702 - val_loss: 0.1895 - val_accuracy: 0.9559
#
# Epoch 00028: val_loss did not improve from 0.12430
# Epoch 29/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0829 - accuracy: 0.9709 - val_loss: 0.1876 - val_accuracy: 0.9544
#
# Epoch 00029: val_loss did not improve from 0.12430
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0810 - accuracy: 0.9731 - val_loss: 0.2040 - val_accuracy: 0.9548
#
# Epoch 00030: val_loss did not improve from 0.12430
# Epoch 31/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0793 - accuracy: 0.9738 - val_loss: 0.1986 - val_accuracy: 0.9559
#
# Epoch 00031: val_loss did not improve from 0.12430
# Epoch 32/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0799 - accuracy: 0.9732 - val_loss: 0.1932 - val_accuracy: 0.9555
#
# Epoch 00032: val_loss did not improve from 0.12430
# Epoch 33/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0799 - accuracy: 0.9736 - val_loss: 0.2113 - val_accuracy: 0.9555
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.12430
# Epoch 34/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0739 - accuracy: 0.9756 - val_loss: 0.2064 - val_accuracy: 0.9552
#
# Epoch 00034: val_loss did not improve from 0.12430
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0692 - accuracy: 0.9762 - val_loss: 0.2001 - val_accuracy: 0.9552
#
# Epoch 00035: val_loss did not improve from 0.12430
# Score for fold 10: loss of 0.20009787380695343; accuracy of 95.51620483398438%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.1862785667181015 - Accuracy: 96.15819454193115%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.1685820370912552 - Accuracy: 95.74387669563293%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.1588248610496521 - Accuracy: 96.49717807769775%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.20977143943309784 - Accuracy: 95.21657228469849%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.2371147722005844 - Accuracy: 95.89453935623169%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.1865232139825821 - Accuracy: 95.74387669563293%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.16861972212791443 - Accuracy: 95.96986770629883%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.19503435492515564 - Accuracy: 95.85687518119812%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.15177185833454132 - Accuracy: 96.42049670219421%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.20009787380695343 - Accuracy: 95.51620483398438%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.90176820755005% (+- 0.0036933234873541515)
# > Loss: 0.1862618699669838
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.959       | 0.0037       |
# | Loss     | 0.1863      | 0.0244       |
# | Macro F1 | 0.8923      | 0.0088       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9806      | 0.0036       |
# | Acc      | 0.9857      | 0.0018       |
# | F1       | 0.9865      | 0.0017       |
# | MCC      | 0.9713      | 0.0035       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
