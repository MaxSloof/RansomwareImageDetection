# %% [markdown]
# # DenseNet

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-densenet-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# No matches found
# New folder name: crossv-densenet-local-v001
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = tf.keras.applications.densenet.preprocess_input(imgs)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # DenseNet
# We will now build our **DenseNet169** model using Tensorflow/Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3
#
# Nota bene that the DenseNet only takes RGB images (with 3 channels)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Build the DenseNet model
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    # Add the classification layers for this dataset
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    
    # Run the CNN
    history.append(
        head_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
    
    # Save the binary data distribution
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/40
# 747/747 [==============================] - 106s 123ms/step - loss: 0.5987 - accuracy: 0.8736 - val_loss: 0.2609 - val_accuracy: 0.9145
#
# Epoch 00001: val_loss improved from inf to 0.26088, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 2/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.2667 - accuracy: 0.9217 - val_loss: 0.1816 - val_accuracy: 0.9431
#
# Epoch 00002: val_loss improved from 0.26088 to 0.18163, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 3/40
# 747/747 [==============================] - 88s 117ms/step - loss: 0.2039 - accuracy: 0.9341 - val_loss: 0.1800 - val_accuracy: 0.9427
#
# Epoch 00003: val_loss improved from 0.18163 to 0.18000, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 4/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.2455 - accuracy: 0.9348 - val_loss: 0.2008 - val_accuracy: 0.9333
#
# Epoch 00004: val_loss did not improve from 0.18000
# Epoch 5/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.2558 - accuracy: 0.9352 - val_loss: 0.2162 - val_accuracy: 0.9348
#
# Epoch 00005: val_loss did not improve from 0.18000
# Epoch 6/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1777 - accuracy: 0.9418 - val_loss: 0.1564 - val_accuracy: 0.9518
#
# Epoch 00006: val_loss improved from 0.18000 to 0.15642, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 7/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1543 - accuracy: 0.9499 - val_loss: 0.1888 - val_accuracy: 0.9375
#
# Epoch 00007: val_loss did not improve from 0.15642
# Epoch 8/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1365 - accuracy: 0.9557 - val_loss: 0.1592 - val_accuracy: 0.9522
#
# Epoch 00008: val_loss did not improve from 0.15642
# Epoch 9/40
# 747/747 [==============================] - 88s 118ms/step - loss: 0.1542 - accuracy: 0.9515 - val_loss: 0.1640 - val_accuracy: 0.9514
#
# Epoch 00009: val_loss did not improve from 0.15642
# Epoch 10/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1313 - accuracy: 0.9569 - val_loss: 0.1590 - val_accuracy: 0.9559
#
# Epoch 00010: val_loss did not improve from 0.15642
# Epoch 11/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1329 - accuracy: 0.9576 - val_loss: 48.8769 - val_accuracy: 0.8429
#
# Epoch 00011: val_loss did not improve from 0.15642
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1221 - accuracy: 0.9602 - val_loss: 0.1359 - val_accuracy: 0.9601
#
# Epoch 00012: val_loss improved from 0.15642 to 0.13587, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1059 - accuracy: 0.9647 - val_loss: 0.1385 - val_accuracy: 0.9653
#
# Epoch 00013: val_loss did not improve from 0.13587
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0991 - accuracy: 0.9676 - val_loss: 0.1396 - val_accuracy: 0.9586
#
# Epoch 00014: val_loss did not improve from 0.13587
# Epoch 15/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0958 - accuracy: 0.9686 - val_loss: 0.1379 - val_accuracy: 0.9616
#
# Epoch 00015: val_loss did not improve from 0.13587
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0981 - accuracy: 0.9672 - val_loss: 0.1450 - val_accuracy: 0.9620
#
# Epoch 00016: val_loss did not improve from 0.13587
# Epoch 17/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1140 - accuracy: 0.9654 - val_loss: 0.1300 - val_accuracy: 0.9627
#
# Epoch 00017: val_loss improved from 0.13587 to 0.12996, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 18/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0866 - accuracy: 0.9725 - val_loss: 0.1287 - val_accuracy: 0.9661
#
# Epoch 00018: val_loss improved from 0.12996 to 0.12874, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0791 - accuracy: 0.9743 - val_loss: 0.1428 - val_accuracy: 0.9608
#
# Epoch 00019: val_loss did not improve from 0.12874
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0776 - accuracy: 0.9748 - val_loss: 0.1608 - val_accuracy: 0.9608
#
# Epoch 00020: val_loss did not improve from 0.12874
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0739 - accuracy: 0.9766 - val_loss: 0.1570 - val_accuracy: 0.9631
#
# Epoch 00021: val_loss did not improve from 0.12874
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0782 - accuracy: 0.9741 - val_loss: 0.1534 - val_accuracy: 0.9631
#
# Epoch 00022: val_loss did not improve from 0.12874
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0704 - accuracy: 0.9770 - val_loss: 0.1293 - val_accuracy: 0.9657
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.12874
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0538 - accuracy: 0.9823 - val_loss: 0.1509 - val_accuracy: 0.9665
#
# Epoch 00024: val_loss did not improve from 0.12874
# Epoch 25/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0508 - accuracy: 0.9831 - val_loss: 0.1645 - val_accuracy: 0.9676
#
# Epoch 00025: val_loss did not improve from 0.12874
# Epoch 26/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0517 - accuracy: 0.9830 - val_loss: 0.1949 - val_accuracy: 0.9650
#
# Epoch 00026: val_loss did not improve from 0.12874
# Epoch 27/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0517 - accuracy: 0.9826 - val_loss: 0.1927 - val_accuracy: 0.9567
#
# Epoch 00027: val_loss did not improve from 0.12874
# Epoch 28/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0484 - accuracy: 0.9837 - val_loss: 0.1658 - val_accuracy: 0.9695
#
# Epoch 00028: val_loss did not improve from 0.12874
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0527 - accuracy: 0.9826 - val_loss: 0.1573 - val_accuracy: 0.9676
#
# Epoch 00029: val_loss did not improve from 0.12874
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0469 - accuracy: 0.9841 - val_loss: 0.1742 - val_accuracy: 0.9669
#
# Epoch 00030: val_loss did not improve from 0.12874
# Epoch 31/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0482 - accuracy: 0.9833 - val_loss: 0.1646 - val_accuracy: 0.9665
#
# Epoch 00031: val_loss did not improve from 0.12874
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0435 - accuracy: 0.9858 - val_loss: 0.1743 - val_accuracy: 0.9680
#
# Epoch 00032: val_loss did not improve from 0.12874
# Epoch 33/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0461 - accuracy: 0.9844 - val_loss: 0.1876 - val_accuracy: 0.9657
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.12874
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0415 - accuracy: 0.9854 - val_loss: 0.1836 - val_accuracy: 0.9672
#
# Epoch 00034: val_loss did not improve from 0.12874
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0390 - accuracy: 0.9861 - val_loss: 0.1914 - val_accuracy: 0.9661
#
# Epoch 00035: val_loss did not improve from 0.12874
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0375 - accuracy: 0.9865 - val_loss: 0.1938 - val_accuracy: 0.9676
#
# Epoch 00036: val_loss did not improve from 0.12874
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0377 - accuracy: 0.9862 - val_loss: 0.1970 - val_accuracy: 0.9691
#
# Epoch 00037: val_loss did not improve from 0.12874
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0365 - accuracy: 0.9870 - val_loss: 0.2053 - val_accuracy: 0.9687
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00038: val_loss did not improve from 0.12874
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0317 - accuracy: 0.9875 - val_loss: 0.2234 - val_accuracy: 0.9672
#
# Epoch 00039: val_loss did not improve from 0.12874
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0306 - accuracy: 0.9881 - val_loss: 0.2247 - val_accuracy: 0.9661
#
# Epoch 00040: val_loss did not improve from 0.12874
# Score for fold 1: loss of 0.2246897965669632; accuracy of 96.61017060279846%
# Epoch 1/40
# 747/747 [==============================] - 100s 118ms/step - loss: 0.5445 - accuracy: 0.8842 - val_loss: 0.6865 - val_accuracy: 0.8527
#
# Epoch 00001: val_loss did not improve from 0.12874
# Epoch 2/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.3606 - accuracy: 0.9052 - val_loss: 0.2601 - val_accuracy: 0.9141
#
# Epoch 00002: val_loss did not improve from 0.12874
# Epoch 3/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2250 - accuracy: 0.9294 - val_loss: 0.2139 - val_accuracy: 0.9296
#
# Epoch 00003: val_loss did not improve from 0.12874
# Epoch 4/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1946 - accuracy: 0.9384 - val_loss: 0.1905 - val_accuracy: 0.9367
#
# Epoch 00004: val_loss did not improve from 0.12874
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1745 - accuracy: 0.9434 - val_loss: 0.1721 - val_accuracy: 0.9461
#
# Epoch 00005: val_loss did not improve from 0.12874
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1770 - accuracy: 0.9461 - val_loss: 0.1554 - val_accuracy: 0.9503
#
# Epoch 00006: val_loss did not improve from 0.12874
# Epoch 7/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.4664 - accuracy: 0.9115 - val_loss: 0.7481 - val_accuracy: 0.9062
#
# Epoch 00007: val_loss did not improve from 0.12874
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2571 - accuracy: 0.9355 - val_loss: 113.0411 - val_accuracy: 0.7412
#
# Epoch 00008: val_loss did not improve from 0.12874
# Epoch 9/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.2427 - accuracy: 0.9384 - val_loss: 0.1809 - val_accuracy: 0.9397
#
# Epoch 00009: val_loss did not improve from 0.12874
# Epoch 10/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1667 - accuracy: 0.9465 - val_loss: 0.1757 - val_accuracy: 0.9465
#
# Epoch 00010: val_loss did not improve from 0.12874
# Epoch 11/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1437 - accuracy: 0.9543 - val_loss: 0.1559 - val_accuracy: 0.9510
#
# Epoch 00011: val_loss did not improve from 0.12874
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1405 - accuracy: 0.9550 - val_loss: 0.1572 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss did not improve from 0.12874
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1280 - accuracy: 0.9590 - val_loss: 0.1558 - val_accuracy: 0.9495
#
# Epoch 00013: val_loss did not improve from 0.12874
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1213 - accuracy: 0.9606 - val_loss: 0.1560 - val_accuracy: 0.9499
#
# Epoch 00014: val_loss did not improve from 0.12874
# Epoch 15/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1153 - accuracy: 0.9619 - val_loss: 0.1474 - val_accuracy: 0.9556
#
# Epoch 00015: val_loss did not improve from 0.12874
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1471 - accuracy: 0.9576 - val_loss: 2.9291 - val_accuracy: 0.8693
#
# Epoch 00016: val_loss did not improve from 0.12874
# Epoch 17/40
# 747/747 [==============================] - 88s 118ms/step - loss: 0.2120 - accuracy: 0.9521 - val_loss: 0.1882 - val_accuracy: 0.9529
#
# Epoch 00017: val_loss did not improve from 0.12874
# Epoch 18/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.1110 - accuracy: 0.9638 - val_loss: 0.1322 - val_accuracy: 0.9578
#
# Epoch 00018: val_loss did not improve from 0.12874
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0984 - accuracy: 0.9676 - val_loss: 0.1696 - val_accuracy: 0.9582
#
# Epoch 00019: val_loss did not improve from 0.12874
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0937 - accuracy: 0.9690 - val_loss: 0.1298 - val_accuracy: 0.9593
#
# Epoch 00020: val_loss did not improve from 0.12874
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0890 - accuracy: 0.9711 - val_loss: 0.1815 - val_accuracy: 0.9375
#
# Epoch 00021: val_loss did not improve from 0.12874
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0890 - accuracy: 0.9716 - val_loss: 0.1459 - val_accuracy: 0.9514
#
# Epoch 00022: val_loss did not improve from 0.12874
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0848 - accuracy: 0.9722 - val_loss: 0.4432 - val_accuracy: 0.9556
#
# Epoch 00023: val_loss did not improve from 0.12874
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0812 - accuracy: 0.9737 - val_loss: 0.1529 - val_accuracy: 0.9593
#
# Epoch 00024: val_loss did not improve from 0.12874
# Epoch 25/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0791 - accuracy: 0.9743 - val_loss: 0.1649 - val_accuracy: 0.9563
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.12874
# Epoch 26/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0652 - accuracy: 0.9793 - val_loss: 0.1194 - val_accuracy: 0.9661
#
# Epoch 00026: val_loss improved from 0.12874 to 0.11942, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 27/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0573 - accuracy: 0.9826 - val_loss: 0.1251 - val_accuracy: 0.9646
#
# Epoch 00027: val_loss did not improve from 0.11942
# Epoch 28/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0556 - accuracy: 0.9825 - val_loss: 0.1293 - val_accuracy: 0.9631
#
# Epoch 00028: val_loss did not improve from 0.11942
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0532 - accuracy: 0.9830 - val_loss: 0.1343 - val_accuracy: 0.9650
#
# Epoch 00029: val_loss did not improve from 0.11942
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0534 - accuracy: 0.9824 - val_loss: 0.1528 - val_accuracy: 0.9631
#
# Epoch 00030: val_loss did not improve from 0.11942
# Epoch 31/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0526 - accuracy: 0.9833 - val_loss: 0.1459 - val_accuracy: 0.9650
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00031: val_loss did not improve from 0.11942
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0462 - accuracy: 0.9852 - val_loss: 0.1437 - val_accuracy: 0.9650
#
# Epoch 00032: val_loss did not improve from 0.11942
# Epoch 33/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0448 - accuracy: 0.9854 - val_loss: 0.1368 - val_accuracy: 0.9661
#
# Epoch 00033: val_loss did not improve from 0.11942
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0444 - accuracy: 0.9855 - val_loss: 0.1403 - val_accuracy: 0.9650
#
# Epoch 00034: val_loss did not improve from 0.11942
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0422 - accuracy: 0.9862 - val_loss: 0.1466 - val_accuracy: 0.9661
#
# Epoch 00035: val_loss did not improve from 0.11942
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0426 - accuracy: 0.9857 - val_loss: 0.1589 - val_accuracy: 0.9631
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00036: val_loss did not improve from 0.11942
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0404 - accuracy: 0.9866 - val_loss: 0.1437 - val_accuracy: 0.9653
#
# Epoch 00037: val_loss did not improve from 0.11942
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0389 - accuracy: 0.9867 - val_loss: 0.1542 - val_accuracy: 0.9665
#
# Epoch 00038: val_loss did not improve from 0.11942
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0381 - accuracy: 0.9868 - val_loss: 0.1700 - val_accuracy: 0.9661
#
# Epoch 00039: val_loss did not improve from 0.11942
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0382 - accuracy: 0.9866 - val_loss: 0.1635 - val_accuracy: 0.9650
#
# Epoch 00040: val_loss did not improve from 0.11942
# Score for fold 2: loss of 0.1635352224111557; accuracy of 96.49717807769775%
# Epoch 1/40
# 747/747 [==============================] - 100s 118ms/step - loss: 0.5456 - accuracy: 0.8811 - val_loss: 0.2465 - val_accuracy: 0.9205
#
# Epoch 00001: val_loss did not improve from 0.11942
# Epoch 2/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.2265 - accuracy: 0.9284 - val_loss: 0.1982 - val_accuracy: 0.9333
#
# Epoch 00002: val_loss did not improve from 0.11942
# Epoch 3/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.2108 - accuracy: 0.9337 - val_loss: 0.1829 - val_accuracy: 0.9390
#
# Epoch 00003: val_loss did not improve from 0.11942
# Epoch 4/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1716 - accuracy: 0.9439 - val_loss: 0.1597 - val_accuracy: 0.9492
#
# Epoch 00004: val_loss did not improve from 0.11942
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1591 - accuracy: 0.9481 - val_loss: 0.3567 - val_accuracy: 0.8750
#
# Epoch 00005: val_loss did not improve from 0.11942
# Epoch 6/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.1532 - accuracy: 0.9506 - val_loss: 0.2054 - val_accuracy: 0.9386
#
# Epoch 00006: val_loss did not improve from 0.11942
# Epoch 7/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.1489 - accuracy: 0.9517 - val_loss: 0.5450 - val_accuracy: 0.9186
#
# Epoch 00007: val_loss did not improve from 0.11942
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.9370 - accuracy: 0.8520 - val_loss: 0.2908 - val_accuracy: 0.9111
#
# Epoch 00008: val_loss did not improve from 0.11942
# Epoch 9/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.2743 - accuracy: 0.9152 - val_loss: 0.2162 - val_accuracy: 0.9363
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.11942
# Epoch 10/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.2116 - accuracy: 0.9323 - val_loss: 0.1924 - val_accuracy: 0.9382
#
# Epoch 00010: val_loss did not improve from 0.11942
# Epoch 11/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1928 - accuracy: 0.9395 - val_loss: 0.1818 - val_accuracy: 0.9427
#
# Epoch 00011: val_loss did not improve from 0.11942
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1776 - accuracy: 0.9420 - val_loss: 0.1632 - val_accuracy: 0.9499
#
# Epoch 00012: val_loss did not improve from 0.11942
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1667 - accuracy: 0.9456 - val_loss: 0.1618 - val_accuracy: 0.9522
#
# Epoch 00013: val_loss did not improve from 0.11942
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1589 - accuracy: 0.9492 - val_loss: 0.1570 - val_accuracy: 0.9499
#
# Epoch 00014: val_loss did not improve from 0.11942
# Epoch 15/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1479 - accuracy: 0.9519 - val_loss: 0.1396 - val_accuracy: 0.9556
#
# Epoch 00015: val_loss did not improve from 0.11942
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1418 - accuracy: 0.9540 - val_loss: 0.1363 - val_accuracy: 0.9556
#
# Epoch 00016: val_loss did not improve from 0.11942
# Epoch 17/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1358 - accuracy: 0.9557 - val_loss: 0.1327 - val_accuracy: 0.9571
#
# Epoch 00017: val_loss did not improve from 0.11942
# Epoch 18/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1239 - accuracy: 0.9590 - val_loss: 0.1448 - val_accuracy: 0.9582
#
# Epoch 00018: val_loss did not improve from 0.11942
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1276 - accuracy: 0.9582 - val_loss: 0.1357 - val_accuracy: 0.9586
#
# Epoch 00019: val_loss did not improve from 0.11942
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1124 - accuracy: 0.9635 - val_loss: 0.1970 - val_accuracy: 0.9473
#
# Epoch 00020: val_loss did not improve from 0.11942
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1252 - accuracy: 0.9625 - val_loss: 0.1205 - val_accuracy: 0.9653
#
# Epoch 00021: val_loss did not improve from 0.11942
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1015 - accuracy: 0.9664 - val_loss: 0.1333 - val_accuracy: 0.9612
#
# Epoch 00022: val_loss did not improve from 0.11942
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0981 - accuracy: 0.9679 - val_loss: 0.1287 - val_accuracy: 0.9627
#
# Epoch 00023: val_loss did not improve from 0.11942
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0999 - accuracy: 0.9679 - val_loss: 0.1358 - val_accuracy: 0.9627
#
# Epoch 00024: val_loss did not improve from 0.11942
# Epoch 25/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0909 - accuracy: 0.9703 - val_loss: 0.1160 - val_accuracy: 0.9676
#
# Epoch 00025: val_loss improved from 0.11942 to 0.11595, saving model to /Users/Max/Documents/GitHub/cross_validation/crossv-densenet-local-v001\model.h5
# Epoch 26/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0838 - accuracy: 0.9720 - val_loss: 0.1193 - val_accuracy: 0.9684
#
# Epoch 00026: val_loss did not improve from 0.11595
# Epoch 27/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0831 - accuracy: 0.9721 - val_loss: 0.1236 - val_accuracy: 0.9691
#
# Epoch 00027: val_loss did not improve from 0.11595
# Epoch 28/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0796 - accuracy: 0.9738 - val_loss: 0.1218 - val_accuracy: 0.9669
#
# Epoch 00028: val_loss did not improve from 0.11595
# Epoch 29/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0750 - accuracy: 0.9754 - val_loss: 0.1218 - val_accuracy: 0.9680
#
# Epoch 00029: val_loss did not improve from 0.11595
# Epoch 30/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0722 - accuracy: 0.9758 - val_loss: 0.1257 - val_accuracy: 0.9695
#
# Epoch 00030: val_loss did not improve from 0.11595
# Epoch 31/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0817 - accuracy: 0.9744 - val_loss: 0.1297 - val_accuracy: 0.9695
#
# Epoch 00031: val_loss did not improve from 0.11595
# Epoch 32/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0733 - accuracy: 0.9762 - val_loss: 0.1212 - val_accuracy: 0.9699
#
# Epoch 00032: val_loss did not improve from 0.11595
# Epoch 33/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0660 - accuracy: 0.9785 - val_loss: 0.1260 - val_accuracy: 0.9702
#
# Epoch 00033: val_loss did not improve from 0.11595
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0637 - accuracy: 0.9785 - val_loss: 0.1378 - val_accuracy: 0.9684
#
# Epoch 00034: val_loss did not improve from 0.11595
# Epoch 35/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0642 - accuracy: 0.9788 - val_loss: 0.1309 - val_accuracy: 0.9699
#
# Epoch 00035: val_loss did not improve from 0.11595
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0652 - accuracy: 0.9789 - val_loss: 0.1321 - val_accuracy: 0.9669
#
# Epoch 00036: val_loss did not improve from 0.11595
# Epoch 37/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0619 - accuracy: 0.9796 - val_loss: 0.1309 - val_accuracy: 0.9684
#
# Epoch 00037: val_loss did not improve from 0.11595
# Epoch 38/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.0595 - accuracy: 0.9810 - val_loss: 0.1477 - val_accuracy: 0.9672
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00038: val_loss did not improve from 0.11595
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0494 - accuracy: 0.9836 - val_loss: 0.1435 - val_accuracy: 0.9691
#
# Epoch 00039: val_loss did not improve from 0.11595
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0481 - accuracy: 0.9838 - val_loss: 0.1382 - val_accuracy: 0.9733
#
# Epoch 00040: val_loss did not improve from 0.11595
# Score for fold 3: loss of 0.13819965720176697; accuracy of 97.32580184936523%
# Epoch 1/40
# 747/747 [==============================] - 100s 118ms/step - loss: 0.3633 - accuracy: 0.8997 - val_loss: 0.2441 - val_accuracy: 0.9269
#
# Epoch 00001: val_loss did not improve from 0.11595
# Epoch 2/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1972 - accuracy: 0.9368 - val_loss: 0.2868 - val_accuracy: 0.9284
#
# Epoch 00002: val_loss did not improve from 0.11595
# Epoch 3/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.5569 - accuracy: 0.8725 - val_loss: 0.6746 - val_accuracy: 0.8260
#
# Epoch 00003: val_loss did not improve from 0.11595
# Epoch 4/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.3031 - accuracy: 0.9147 - val_loss: 0.2646 - val_accuracy: 0.9141
#
# Epoch 00004: val_loss did not improve from 0.11595
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2219 - accuracy: 0.9299 - val_loss: 0.2202 - val_accuracy: 0.9296
#
# Epoch 00005: val_loss did not improve from 0.11595
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2048 - accuracy: 0.9363 - val_loss: 0.2079 - val_accuracy: 0.9363
#
# Epoch 00006: val_loss did not improve from 0.11595
# Epoch 7/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1767 - accuracy: 0.9419 - val_loss: 0.4804 - val_accuracy: 0.8497
#
# Epoch 00007: val_loss did not improve from 0.11595
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1705 - accuracy: 0.9443 - val_loss: 0.2412 - val_accuracy: 0.9043
#
# Epoch 00008: val_loss did not improve from 0.11595
# Epoch 9/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1537 - accuracy: 0.9495 - val_loss: 0.1771 - val_accuracy: 0.9469
#
# Epoch 00009: val_loss did not improve from 0.11595
# Epoch 10/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1421 - accuracy: 0.9544 - val_loss: 0.1758 - val_accuracy: 0.9469
#
# Epoch 00010: val_loss did not improve from 0.11595
# Epoch 11/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1405 - accuracy: 0.9546 - val_loss: 0.1717 - val_accuracy: 0.9446
#
# Epoch 00011: val_loss did not improve from 0.11595
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1337 - accuracy: 0.9563 - val_loss: 0.1701 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss did not improve from 0.11595
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1235 - accuracy: 0.9603 - val_loss: 0.2069 - val_accuracy: 0.9292
#
# Epoch 00013: val_loss did not improve from 0.11595
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1202 - accuracy: 0.9610 - val_loss: 0.1596 - val_accuracy: 0.9480
#
# Epoch 00014: val_loss did not improve from 0.11595
# Epoch 15/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.4925 - accuracy: 0.9462 - val_loss: 6197.3438 - val_accuracy: 0.5876
#
# Epoch 00015: val_loss did not improve from 0.11595
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2352 - accuracy: 0.9281 - val_loss: 0.1823 - val_accuracy: 0.9476
#
# Epoch 00016: val_loss did not improve from 0.11595
# Epoch 17/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1616 - accuracy: 0.9510 - val_loss: 0.1691 - val_accuracy: 0.9522
#
# Epoch 00017: val_loss did not improve from 0.11595
# Epoch 18/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1273 - accuracy: 0.9581 - val_loss: 0.1494 - val_accuracy: 0.9537
#
# Epoch 00018: val_loss did not improve from 0.11595
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1120 - accuracy: 0.9622 - val_loss: 0.1636 - val_accuracy: 0.9537
#
# Epoch 00019: val_loss did not improve from 0.11595
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1072 - accuracy: 0.9650 - val_loss: 0.1544 - val_accuracy: 0.9563
#
# Epoch 00020: val_loss did not improve from 0.11595
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1047 - accuracy: 0.9658 - val_loss: 0.1592 - val_accuracy: 0.9499
#
# Epoch 00021: val_loss did not improve from 0.11595
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0940 - accuracy: 0.9692 - val_loss: 0.1573 - val_accuracy: 0.9548
#
# Epoch 00022: val_loss did not improve from 0.11595
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0959 - accuracy: 0.9684 - val_loss: 0.1552 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss did not improve from 0.11595
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2975 - accuracy: 0.9553 - val_loss: 0.2683 - val_accuracy: 0.9420
#
# Epoch 00024: val_loss did not improve from 0.11595
# Epoch 25/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1562 - accuracy: 0.9572 - val_loss: 0.1622 - val_accuracy: 0.9552
#
# Epoch 00025: val_loss did not improve from 0.11595
# Epoch 26/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1020 - accuracy: 0.9691 - val_loss: 0.1633 - val_accuracy: 0.9586
#
# Epoch 00026: val_loss did not improve from 0.11595
# Epoch 27/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0895 - accuracy: 0.9715 - val_loss: 0.1505 - val_accuracy: 0.9612
#
# Epoch 00027: val_loss did not improve from 0.11595
# Epoch 28/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0826 - accuracy: 0.9732 - val_loss: 0.1544 - val_accuracy: 0.9582
#
# Epoch 00028: val_loss did not improve from 0.11595
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0818 - accuracy: 0.9737 - val_loss: 0.1612 - val_accuracy: 0.9578
#
# Epoch 00029: val_loss did not improve from 0.11595
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0741 - accuracy: 0.9758 - val_loss: 0.1866 - val_accuracy: 0.9552
#
# Epoch 00030: val_loss did not improve from 0.11595
# Epoch 31/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0826 - accuracy: 0.9730 - val_loss: 0.1618 - val_accuracy: 0.9597
#
# Epoch 00031: val_loss did not improve from 0.11595
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0882 - accuracy: 0.9729 - val_loss: 0.2487 - val_accuracy: 0.8814
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00032: val_loss did not improve from 0.11595
# Epoch 33/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0642 - accuracy: 0.9794 - val_loss: 0.1571 - val_accuracy: 0.9616
#
# Epoch 00033: val_loss did not improve from 0.11595
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0576 - accuracy: 0.9810 - val_loss: 0.1550 - val_accuracy: 0.9627
#
# Epoch 00034: val_loss did not improve from 0.11595
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0570 - accuracy: 0.9813 - val_loss: 0.1829 - val_accuracy: 0.9605
#
# Epoch 00035: val_loss did not improve from 0.11595
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0543 - accuracy: 0.9826 - val_loss: 3.7101 - val_accuracy: 0.9070
#
# Epoch 00036: val_loss did not improve from 0.11595
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0532 - accuracy: 0.9822 - val_loss: 0.1848 - val_accuracy: 0.9597
#
# Epoch 00037: val_loss did not improve from 0.11595
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0583 - accuracy: 0.9816 - val_loss: 0.1817 - val_accuracy: 0.9605
#
# Epoch 00038: val_loss did not improve from 0.11595
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0531 - accuracy: 0.9829 - val_loss: 0.1635 - val_accuracy: 0.9616
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00039: val_loss did not improve from 0.11595
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.1772 - val_accuracy: 0.9642
#
# Epoch 00040: val_loss did not improve from 0.11595
# Score for fold 4: loss of 0.17718730866909027; accuracy of 96.42184376716614%
# Epoch 1/40
# 747/747 [==============================] - 100s 118ms/step - loss: 0.4120 - accuracy: 0.8908 - val_loss: 0.2560 - val_accuracy: 0.9220
#
# Epoch 00001: val_loss did not improve from 0.11595
# Epoch 2/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.3412 - accuracy: 0.9127 - val_loss: 0.9267 - val_accuracy: 0.8192
#
# Epoch 00002: val_loss did not improve from 0.11595
# Epoch 3/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2268 - accuracy: 0.9312 - val_loss: 0.1837 - val_accuracy: 0.9427
#
# Epoch 00003: val_loss did not improve from 0.11595
# Epoch 4/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2260 - accuracy: 0.9357 - val_loss: 0.1787 - val_accuracy: 0.9454
#
# Epoch 00004: val_loss did not improve from 0.11595
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.3693 - accuracy: 0.9040 - val_loss: 0.1911 - val_accuracy: 0.9367
#
# Epoch 00005: val_loss did not improve from 0.11595
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1947 - accuracy: 0.9378 - val_loss: 0.1807 - val_accuracy: 0.9446
#
# Epoch 00006: val_loss did not improve from 0.11595
# Epoch 7/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2305 - accuracy: 0.9323 - val_loss: 1.0630 - val_accuracy: 0.7492
#
# Epoch 00007: val_loss did not improve from 0.11595
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1946 - accuracy: 0.9367 - val_loss: 0.1612 - val_accuracy: 0.9461
#
# Epoch 00008: val_loss did not improve from 0.11595
# Epoch 9/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1576 - accuracy: 0.9491 - val_loss: 0.1537 - val_accuracy: 0.9495
#
# Epoch 00009: val_loss did not improve from 0.11595
# Epoch 10/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1452 - accuracy: 0.9538 - val_loss: 0.1804 - val_accuracy: 0.9450
#
# Epoch 00010: val_loss did not improve from 0.11595
# Epoch 11/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1390 - accuracy: 0.9545 - val_loss: 0.1769 - val_accuracy: 0.9492
#
# Epoch 00011: val_loss did not improve from 0.11595
# Epoch 12/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1284 - accuracy: 0.9592 - val_loss: 0.1332 - val_accuracy: 0.9574
#
# Epoch 00012: val_loss did not improve from 0.11595
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1249 - accuracy: 0.9580 - val_loss: 0.6538 - val_accuracy: 0.8576
#
# Epoch 00013: val_loss did not improve from 0.11595
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1213 - accuracy: 0.9604 - val_loss: 0.1383 - val_accuracy: 0.9548
#
# Epoch 00014: val_loss did not improve from 0.11595
# Epoch 15/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1098 - accuracy: 0.9643 - val_loss: 0.1488 - val_accuracy: 0.9567
#
# Epoch 00015: val_loss did not improve from 0.11595
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1047 - accuracy: 0.9657 - val_loss: 0.1273 - val_accuracy: 0.9623
#
# Epoch 00016: val_loss did not improve from 0.11595
# Epoch 17/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1281 - accuracy: 0.9607 - val_loss: 0.1340 - val_accuracy: 0.9597
#
# Epoch 00017: val_loss did not improve from 0.11595
# Epoch 18/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0993 - accuracy: 0.9669 - val_loss: 0.1430 - val_accuracy: 0.9522
#
# Epoch 00018: val_loss did not improve from 0.11595
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0913 - accuracy: 0.9696 - val_loss: 0.1381 - val_accuracy: 0.9616
#
# Epoch 00019: val_loss did not improve from 0.11595
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0931 - accuracy: 0.9694 - val_loss: 0.1471 - val_accuracy: 0.9571
#
# Epoch 00020: val_loss did not improve from 0.11595
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0845 - accuracy: 0.9711 - val_loss: 0.1481 - val_accuracy: 0.9623
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.11595
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0665 - accuracy: 0.9786 - val_loss: 0.1235 - val_accuracy: 0.9684
#
# Epoch 00022: val_loss did not improve from 0.11595
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0576 - accuracy: 0.9804 - val_loss: 0.1301 - val_accuracy: 0.9657
#
# Epoch 00023: val_loss did not improve from 0.11595
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1213 - accuracy: 0.9769 - val_loss: 0.1282 - val_accuracy: 0.9646
#
# Epoch 00024: val_loss did not improve from 0.11595
# Epoch 25/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0571 - accuracy: 0.9811 - val_loss: 0.1460 - val_accuracy: 0.9616
#
# Epoch 00025: val_loss did not improve from 0.11595
# Epoch 26/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.0537 - accuracy: 0.9824 - val_loss: 0.1490 - val_accuracy: 0.9646
#
# Epoch 00026: val_loss did not improve from 0.11595
# Epoch 27/40
# 747/747 [==============================] - 87s 116ms/step - loss: 0.0514 - accuracy: 0.9837 - val_loss: 0.1466 - val_accuracy: 0.9638
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.11595
# Epoch 28/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0448 - accuracy: 0.9848 - val_loss: 0.1450 - val_accuracy: 0.9669
#
# Epoch 00028: val_loss did not improve from 0.11595
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0432 - accuracy: 0.9857 - val_loss: 0.1456 - val_accuracy: 0.9657
#
# Epoch 00029: val_loss did not improve from 0.11595
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0809 - accuracy: 0.9861 - val_loss: 0.1481 - val_accuracy: 0.9665
#
# Epoch 00030: val_loss did not improve from 0.11595
# Epoch 31/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0415 - accuracy: 0.9863 - val_loss: 0.1672 - val_accuracy: 0.9642
#
# Epoch 00031: val_loss did not improve from 0.11595
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0408 - accuracy: 0.9866 - val_loss: 0.1658 - val_accuracy: 0.9635
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.11595
# Epoch 33/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.1684 - val_accuracy: 0.9635
#
# Epoch 00033: val_loss did not improve from 0.11595
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0366 - accuracy: 0.9877 - val_loss: 0.1676 - val_accuracy: 0.9657
#
# Epoch 00034: val_loss did not improve from 0.11595
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0355 - accuracy: 0.9881 - val_loss: 0.1567 - val_accuracy: 0.9650
#
# Epoch 00035: val_loss did not improve from 0.11595
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 0.1714 - val_accuracy: 0.9684
#
# Epoch 00036: val_loss did not improve from 0.11595
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0342 - accuracy: 0.9885 - val_loss: 0.1799 - val_accuracy: 0.9653
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00037: val_loss did not improve from 0.11595
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0328 - accuracy: 0.9887 - val_loss: 0.1769 - val_accuracy: 0.9642
#
# Epoch 00038: val_loss did not improve from 0.11595
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.1750 - val_accuracy: 0.9646
#
# Epoch 00039: val_loss did not improve from 0.11595
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0314 - accuracy: 0.9888 - val_loss: 0.1827 - val_accuracy: 0.9635
#
# Epoch 00040: val_loss did not improve from 0.11595
# Score for fold 5: loss of 0.18271249532699585; accuracy of 96.346515417099%
# Epoch 1/40
# 747/747 [==============================] - 102s 119ms/step - loss: 0.3974 - accuracy: 0.8974 - val_loss: 89.0491 - val_accuracy: 0.3849
#
# Epoch 00001: val_loss did not improve from 0.11595
# Epoch 2/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.6473 - accuracy: 0.8655 - val_loss: 0.4176 - val_accuracy: 0.9119
#
# Epoch 00002: val_loss did not improve from 0.11595
# Epoch 3/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.2400 - accuracy: 0.9243 - val_loss: 0.2065 - val_accuracy: 0.9326
#
# Epoch 00003: val_loss did not improve from 0.11595
# Epoch 4/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.2061 - accuracy: 0.9332 - val_loss: 3.4482 - val_accuracy: 0.9292
#
# Epoch 00004: val_loss did not improve from 0.11595
# Epoch 5/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1930 - accuracy: 0.9374 - val_loss: 0.1762 - val_accuracy: 0.9420
#
# Epoch 00005: val_loss did not improve from 0.11595
# Epoch 6/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1791 - accuracy: 0.9423 - val_loss: 0.7313 - val_accuracy: 0.8433
#
# Epoch 00006: val_loss did not improve from 0.11595
# Epoch 7/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1550 - accuracy: 0.9508 - val_loss: 0.1686 - val_accuracy: 0.9488
#
# Epoch 00007: val_loss did not improve from 0.11595
# Epoch 8/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1520 - accuracy: 0.9518 - val_loss: 0.1618 - val_accuracy: 0.9480
#
# Epoch 00008: val_loss did not improve from 0.11595
# Epoch 9/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1370 - accuracy: 0.9556 - val_loss: 0.1241 - val_accuracy: 0.9616
#
# Epoch 00009: val_loss did not improve from 0.11595
# Epoch 10/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1427 - accuracy: 0.9548 - val_loss: 0.1903 - val_accuracy: 0.9386
#
# Epoch 00010: val_loss did not improve from 0.11595
# Epoch 11/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1543 - accuracy: 0.9538 - val_loss: 0.1549 - val_accuracy: 0.9507
#
# Epoch 00011: val_loss did not improve from 0.11595
# Epoch 12/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1242 - accuracy: 0.9589 - val_loss: 0.1346 - val_accuracy: 0.9548
#
# Epoch 00012: val_loss did not improve from 0.11595
# Epoch 13/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1127 - accuracy: 0.9634 - val_loss: 0.1371 - val_accuracy: 0.9586
#
# Epoch 00013: val_loss did not improve from 0.11595
# Epoch 14/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1077 - accuracy: 0.9653 - val_loss: 0.1267 - val_accuracy: 0.9605
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.11595
# Epoch 15/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0821 - accuracy: 0.9730 - val_loss: 0.1262 - val_accuracy: 0.9635
#
# Epoch 00015: val_loss did not improve from 0.11595
# Epoch 16/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0738 - accuracy: 0.9761 - val_loss: 0.1230 - val_accuracy: 0.9635
#
# Epoch 00016: val_loss did not improve from 0.11595
# Epoch 17/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0718 - accuracy: 0.9765 - val_loss: 0.1377 - val_accuracy: 0.9623
#
# Epoch 00017: val_loss did not improve from 0.11595
# Epoch 18/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0707 - accuracy: 0.9765 - val_loss: 0.1223 - val_accuracy: 0.9650
#
# Epoch 00018: val_loss did not improve from 0.11595
# Epoch 19/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0674 - accuracy: 0.9782 - val_loss: 0.1286 - val_accuracy: 0.9642
#
# Epoch 00019: val_loss did not improve from 0.11595
# Epoch 20/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0620 - accuracy: 0.9790 - val_loss: 0.1305 - val_accuracy: 0.9661
#
# Epoch 00020: val_loss did not improve from 0.11595
# Epoch 21/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0636 - accuracy: 0.9789 - val_loss: 0.1301 - val_accuracy: 0.9661
#
# Epoch 00021: val_loss did not improve from 0.11595
# Epoch 22/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0578 - accuracy: 0.9810 - val_loss: 0.1374 - val_accuracy: 0.9650
#
# Epoch 00022: val_loss did not improve from 0.11595
# Epoch 23/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0577 - accuracy: 0.9805 - val_loss: 0.1381 - val_accuracy: 0.9653
#
# Epoch 00023: val_loss did not improve from 0.11595
# Epoch 24/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0547 - accuracy: 0.9818 - val_loss: 0.1503 - val_accuracy: 0.9646
#
# Epoch 00024: val_loss did not improve from 0.11595
# Epoch 25/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0594 - accuracy: 0.9802 - val_loss: 0.1489 - val_accuracy: 0.9669
#
# Epoch 00025: val_loss did not improve from 0.11595
# Epoch 26/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0530 - accuracy: 0.9825 - val_loss: 0.2256 - val_accuracy: 0.9258
#
# Epoch 00026: val_loss did not improve from 0.11595
# Epoch 27/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0534 - accuracy: 0.9822 - val_loss: 0.1550 - val_accuracy: 0.9653
#
# Epoch 00027: val_loss did not improve from 0.11595
# Epoch 28/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0545 - accuracy: 0.9818 - val_loss: 0.1608 - val_accuracy: 0.9661
#
# Epoch 00028: val_loss did not improve from 0.11595
# Epoch 29/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0494 - accuracy: 0.9833 - val_loss: 0.1441 - val_accuracy: 0.9684
#
# Epoch 00029: val_loss did not improve from 0.11595
# Epoch 30/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.0486 - accuracy: 0.9834 - val_loss: 0.1713 - val_accuracy: 0.9593
#
# Epoch 00030: val_loss did not improve from 0.11595
# ...
#
# Epoch 00003: val_loss did not improve from 0.11595
# Epoch 4/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2767 - accuracy: 0.9072 - val_loss: 0.2270 - val_accuracy: 0.9269
#
# Epoch 00004: val_loss did not improve from 0.11595
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.3229 - accuracy: 0.8973 - val_loss: 0.3883 - val_accuracy: 0.8855
#
# Epoch 00005: val_loss did not improve from 0.11595
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2883 - accuracy: 0.9073 - val_loss: 0.2157 - val_accuracy: 0.9277
#
# Epoch 00006: val_loss did not improve from 0.11595
# Epoch 7/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2263 - accuracy: 0.9252 - val_loss: 0.1894 - val_accuracy: 0.9405
#
# Epoch 00007: val_loss did not improve from 0.11595
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1986 - accuracy: 0.9348 - val_loss: 0.2154 - val_accuracy: 0.9250
#
# Epoch 00008: val_loss did not improve from 0.11595
# Epoch 9/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2019 - accuracy: 0.9345 - val_loss: 0.3783 - val_accuracy: 0.8361
#
# Epoch 00009: val_loss did not improve from 0.11595
# Epoch 10/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1779 - accuracy: 0.9412 - val_loss: 0.1802 - val_accuracy: 0.9416
#
# Epoch 00010: val_loss did not improve from 0.11595
# Epoch 11/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1624 - accuracy: 0.9466 - val_loss: 0.1533 - val_accuracy: 0.9480
#
# Epoch 00011: val_loss did not improve from 0.11595
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1521 - accuracy: 0.9502 - val_loss: 0.1625 - val_accuracy: 0.9503
#
# Epoch 00012: val_loss did not improve from 0.11595
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1516 - accuracy: 0.9510 - val_loss: 0.1430 - val_accuracy: 0.9567
#
# Epoch 00013: val_loss did not improve from 0.11595
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1404 - accuracy: 0.9536 - val_loss: 0.1506 - val_accuracy: 0.9567
#
# Epoch 00014: val_loss did not improve from 0.11595
# Epoch 15/40
# 747/747 [==============================] - 87s 117ms/step - loss: 0.1478 - accuracy: 0.9529 - val_loss: 0.1686 - val_accuracy: 0.9510
#
# Epoch 00015: val_loss did not improve from 0.11595
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1873 - accuracy: 0.9433 - val_loss: 0.1471 - val_accuracy: 0.9559
#
# Epoch 00016: val_loss did not improve from 0.11595
# Epoch 17/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1345 - accuracy: 0.9576 - val_loss: 0.1382 - val_accuracy: 0.9578
#
# Epoch 00017: val_loss did not improve from 0.11595
# Epoch 18/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1430 - accuracy: 0.9541 - val_loss: 0.1438 - val_accuracy: 0.9567
#
# Epoch 00018: val_loss did not improve from 0.11595
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1223 - accuracy: 0.9594 - val_loss: 0.1513 - val_accuracy: 0.9612
#
# Epoch 00019: val_loss did not improve from 0.11595
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1181 - accuracy: 0.9617 - val_loss: 0.1305 - val_accuracy: 0.9608
#
# Epoch 00020: val_loss did not improve from 0.11595
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1093 - accuracy: 0.9635 - val_loss: 0.1419 - val_accuracy: 0.9597
#
# Epoch 00021: val_loss did not improve from 0.11595
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1135 - accuracy: 0.9636 - val_loss: 0.1321 - val_accuracy: 0.9619
#
# Epoch 00022: val_loss did not improve from 0.11595
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1028 - accuracy: 0.9660 - val_loss: 0.1459 - val_accuracy: 0.9544
#
# Epoch 00023: val_loss did not improve from 0.11595
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0984 - accuracy: 0.9678 - val_loss: 0.1270 - val_accuracy: 0.9616
#
# Epoch 00024: val_loss did not improve from 0.11595
# Epoch 25/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1062 - accuracy: 0.9678 - val_loss: 0.1291 - val_accuracy: 0.9653
#
# Epoch 00025: val_loss did not improve from 0.11595
# Epoch 26/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2154 - accuracy: 0.9514 - val_loss: 0.1283 - val_accuracy: 0.9631
#
# Epoch 00026: val_loss did not improve from 0.11595
# Epoch 27/40
# 747/747 [==============================] - 86s 116ms/step - loss: 0.1071 - accuracy: 0.9644 - val_loss: 0.1309 - val_accuracy: 0.9638
#
# Epoch 00027: val_loss did not improve from 0.11595
# Epoch 28/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0962 - accuracy: 0.9688 - val_loss: 0.1283 - val_accuracy: 0.9627
#
# Epoch 00028: val_loss did not improve from 0.11595
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0871 - accuracy: 0.9712 - val_loss: 0.1254 - val_accuracy: 0.9650
#
# Epoch 00029: val_loss did not improve from 0.11595
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0867 - accuracy: 0.9717 - val_loss: 0.1395 - val_accuracy: 0.9623
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00030: val_loss did not improve from 0.11595
# Epoch 31/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0710 - accuracy: 0.9770 - val_loss: 0.1327 - val_accuracy: 0.9665
#
# Epoch 00031: val_loss did not improve from 0.11595
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0730 - accuracy: 0.9786 - val_loss: 0.1195 - val_accuracy: 0.9680
#
# Epoch 00032: val_loss did not improve from 0.11595
# Epoch 33/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0694 - accuracy: 0.9792 - val_loss: 0.1463 - val_accuracy: 0.9665
#
# Epoch 00033: val_loss did not improve from 0.11595
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0622 - accuracy: 0.9806 - val_loss: 0.1418 - val_accuracy: 0.9683
#
# Epoch 00034: val_loss did not improve from 0.11595
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0646 - accuracy: 0.9790 - val_loss: 0.1431 - val_accuracy: 0.9676
#
# Epoch 00035: val_loss did not improve from 0.11595
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0587 - accuracy: 0.9811 - val_loss: 0.1428 - val_accuracy: 0.9680
#
# Epoch 00036: val_loss did not improve from 0.11595
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0648 - accuracy: 0.9787 - val_loss: 0.1472 - val_accuracy: 0.9665
#
# Epoch 00037: val_loss did not improve from 0.11595
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0560 - accuracy: 0.9815 - val_loss: 0.1668 - val_accuracy: 0.9653
#
# Epoch 00038: val_loss did not improve from 0.11595
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0566 - accuracy: 0.9816 - val_loss: 0.1515 - val_accuracy: 0.9680
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00039: val_loss did not improve from 0.11595
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0500 - accuracy: 0.9838 - val_loss: 0.1661 - val_accuracy: 0.9668
#
# Epoch 00040: val_loss did not improve from 0.11595
# Score for fold 9: loss of 0.16606405377388; accuracy of 96.68424725532532%
# Epoch 1/40
# 747/747 [==============================] - 98s 117ms/step - loss: 0.5616 - accuracy: 0.8705 - val_loss: 0.2170 - val_accuracy: 0.9352
#
# Epoch 00001: val_loss did not improve from 0.11595
# Epoch 2/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2592 - accuracy: 0.9186 - val_loss: 0.2234 - val_accuracy: 0.9303
#
# Epoch 00002: val_loss did not improve from 0.11595
# Epoch 3/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2227 - accuracy: 0.9327 - val_loss: 0.2328 - val_accuracy: 0.9209
#
# Epoch 00003: val_loss did not improve from 0.11595
# Epoch 4/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.4805 - accuracy: 0.8917 - val_loss: 0.3235 - val_accuracy: 0.9228
#
# Epoch 00004: val_loss did not improve from 0.11595
# Epoch 5/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.3768 - accuracy: 0.8996 - val_loss: 0.2755 - val_accuracy: 0.9118
#
# Epoch 00005: val_loss did not improve from 0.11595
# Epoch 6/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2669 - accuracy: 0.9189 - val_loss: 0.1926 - val_accuracy: 0.9442
#
# Epoch 00006: val_loss did not improve from 0.11595
# Epoch 7/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.2078 - accuracy: 0.9346 - val_loss: 0.1629 - val_accuracy: 0.9435
#
# Epoch 00007: val_loss did not improve from 0.11595
# Epoch 8/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1960 - accuracy: 0.9403 - val_loss: 2.8819 - val_accuracy: 0.6044
#
# Epoch 00008: val_loss did not improve from 0.11595
# Epoch 9/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1720 - accuracy: 0.9449 - val_loss: 0.4601 - val_accuracy: 0.8580
#
# Epoch 00009: val_loss did not improve from 0.11595
# Epoch 10/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1888 - accuracy: 0.9417 - val_loss: 0.1589 - val_accuracy: 0.9499
#
# Epoch 00010: val_loss did not improve from 0.11595
# Epoch 11/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1515 - accuracy: 0.9510 - val_loss: 0.1577 - val_accuracy: 0.9442
#
# Epoch 00011: val_loss did not improve from 0.11595
# Epoch 12/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1378 - accuracy: 0.9558 - val_loss: 0.1323 - val_accuracy: 0.9578
#
# Epoch 00012: val_loss did not improve from 0.11595
# Epoch 13/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1310 - accuracy: 0.9579 - val_loss: 0.1812 - val_accuracy: 0.9408
#
# Epoch 00013: val_loss did not improve from 0.11595
# Epoch 14/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1279 - accuracy: 0.9585 - val_loss: 0.1389 - val_accuracy: 0.9582
#
# Epoch 00014: val_loss did not improve from 0.11595
# Epoch 15/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1188 - accuracy: 0.9607 - val_loss: 0.1220 - val_accuracy: 0.9631
#
# Epoch 00015: val_loss did not improve from 0.11595
# Epoch 16/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1102 - accuracy: 0.9639 - val_loss: 0.1574 - val_accuracy: 0.9476
#
# Epoch 00016: val_loss did not improve from 0.11595
# Epoch 17/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1803 - accuracy: 0.9502 - val_loss: 0.1394 - val_accuracy: 0.9555
#
# Epoch 00017: val_loss did not improve from 0.11595
# Epoch 18/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1196 - accuracy: 0.9602 - val_loss: 0.1217 - val_accuracy: 0.9631
#
# Epoch 00018: val_loss did not improve from 0.11595
# Epoch 19/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.1032 - accuracy: 0.9661 - val_loss: 0.1392 - val_accuracy: 0.9593
#
# Epoch 00019: val_loss did not improve from 0.11595
# Epoch 20/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0945 - accuracy: 0.9690 - val_loss: 0.1450 - val_accuracy: 0.9601
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.11595
# Epoch 21/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0785 - accuracy: 0.9741 - val_loss: 0.1184 - val_accuracy: 0.9702
#
# Epoch 00021: val_loss did not improve from 0.11595
# Epoch 22/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0700 - accuracy: 0.9771 - val_loss: 0.1186 - val_accuracy: 0.9683
#
# Epoch 00022: val_loss did not improve from 0.11595
# Epoch 23/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0656 - accuracy: 0.9788 - val_loss: 0.1281 - val_accuracy: 0.9653
#
# Epoch 00023: val_loss did not improve from 0.11595
# Epoch 24/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0644 - accuracy: 0.9787 - val_loss: 0.1257 - val_accuracy: 0.9665
#
# Epoch 00024: val_loss did not improve from 0.11595
# Epoch 25/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0661 - accuracy: 0.9778 - val_loss: 0.1424 - val_accuracy: 0.9676
#
# Epoch 00025: val_loss did not improve from 0.11595
# Epoch 26/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0631 - accuracy: 0.9798 - val_loss: 0.1370 - val_accuracy: 0.9668
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00026: val_loss did not improve from 0.11595
# Epoch 27/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 0.1336 - val_accuracy: 0.9687
#
# Epoch 00027: val_loss did not improve from 0.11595
# Epoch 28/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0508 - accuracy: 0.9833 - val_loss: 0.1287 - val_accuracy: 0.9691
#
# Epoch 00028: val_loss did not improve from 0.11595
# Epoch 29/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0483 - accuracy: 0.9842 - val_loss: 0.1492 - val_accuracy: 0.9687
#
# Epoch 00029: val_loss did not improve from 0.11595
# Epoch 30/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0486 - accuracy: 0.9842 - val_loss: 0.1490 - val_accuracy: 0.9691
#
# Epoch 00030: val_loss did not improve from 0.11595
# Epoch 31/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0508 - accuracy: 0.9833 - val_loss: 0.1672 - val_accuracy: 0.9683
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00031: val_loss did not improve from 0.11595
# Epoch 32/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0446 - accuracy: 0.9850 - val_loss: 0.1487 - val_accuracy: 0.9687
#
# Epoch 00032: val_loss did not improve from 0.11595
# Epoch 33/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0431 - accuracy: 0.9855 - val_loss: 0.1671 - val_accuracy: 0.9665
#
# Epoch 00033: val_loss did not improve from 0.11595
# Epoch 34/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0433 - accuracy: 0.9852 - val_loss: 0.1664 - val_accuracy: 0.9676
#
# Epoch 00034: val_loss did not improve from 0.11595
# Epoch 35/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0425 - accuracy: 0.9855 - val_loss: 0.1654 - val_accuracy: 0.9672
#
# Epoch 00035: val_loss did not improve from 0.11595
# Epoch 36/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.1687 - val_accuracy: 0.9665
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00036: val_loss did not improve from 0.11595
# Epoch 37/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0405 - accuracy: 0.9861 - val_loss: 0.1706 - val_accuracy: 0.9668
#
# Epoch 00037: val_loss did not improve from 0.11595
# Epoch 38/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0399 - accuracy: 0.9866 - val_loss: 0.1706 - val_accuracy: 0.9668
#
# Epoch 00038: val_loss did not improve from 0.11595
# Epoch 39/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0390 - accuracy: 0.9870 - val_loss: 0.1712 - val_accuracy: 0.9668
#
# Epoch 00039: val_loss did not improve from 0.11595
# Epoch 40/40
# 747/747 [==============================] - 86s 115ms/step - loss: 0.0388 - accuracy: 0.9869 - val_loss: 0.1774 - val_accuracy: 0.9665
#
# Epoch 00040: val_loss did not improve from 0.11595
# Score for fold 10: loss of 0.17736338078975677; accuracy of 96.6465711593628%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.2246897965669632 - Accuracy: 96.61017060279846%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.1635352224111557 - Accuracy: 96.49717807769775%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.13819965720176697 - Accuracy: 97.32580184936523%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.17718730866909027 - Accuracy: 96.42184376716614%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.18271249532699585 - Accuracy: 96.346515417099%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.1678403913974762 - Accuracy: 96.83615565299988%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.13958507776260376 - Accuracy: 96.57250642776489%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.16923576593399048 - Accuracy: 96.49717807769775%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.16606405377388 - Accuracy: 96.68424725532532%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.17736338078975677 - Accuracy: 96.6465711593628%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.64381682872772% (+- 0.002627971185640986)
# > Loss: 0.17064131498336793
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of DenseNet169"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of DenseNet169      |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9664      | 0.0026       |
# | Loss     | 0.1706      | 0.0229       |
# | Macro F1 | 0.9099      | 0.0051       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9889      | 0.0025       |
# | Acc      | 0.9922      | 0.0014       |
# | F1       | 0.9926      | 0.0014       |
# | MCC      | 0.9843      | 0.0028       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for DenseNet169 across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - DenseNet169")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
