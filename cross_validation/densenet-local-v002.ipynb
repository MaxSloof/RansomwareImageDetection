# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: densenet-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/densenet-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# No matches found
# New folder name: densenet-local-v001
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = tf.keras.applications.densenet.preprocess_input(imgs)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # DenseNet
# We will now build our **DenseNet** model using Tensorflow/Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # DenseNet
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    
    # Run the CNN
    history.append(
        head_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/40
# 747/747 [==============================] - 116s 132ms/step - loss: 0.3759 - accuracy: 0.8968 - val_loss: 0.1938 - val_accuracy: 0.9363
#
# Epoch 00001: val_loss improved from inf to 0.19383, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 2/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.2612 - accuracy: 0.9256 - val_loss: 4131.1045 - val_accuracy: 0.6644
#
# Epoch 00002: val_loss did not improve from 0.19383
# Epoch 3/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.6208 - accuracy: 0.8730 - val_loss: 0.2651 - val_accuracy: 0.9164
#
# Epoch 00003: val_loss did not improve from 0.19383
# Epoch 4/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.2556 - accuracy: 0.9205 - val_loss: 0.1981 - val_accuracy: 0.9367
#
# Epoch 00004: val_loss did not improve from 0.19383
# Epoch 5/40
# 747/747 [==============================] - 94s 125ms/step - loss: 0.2435 - accuracy: 0.9267 - val_loss: 0.1747 - val_accuracy: 0.9439
#
# Epoch 00005: val_loss improved from 0.19383 to 0.17469, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 6/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1892 - accuracy: 0.9389 - val_loss: 0.1863 - val_accuracy: 0.9431
#
# Epoch 00006: val_loss did not improve from 0.17469
# Epoch 7/40
# 747/747 [==============================] - 102s 136ms/step - loss: 0.1695 - accuracy: 0.9444 - val_loss: 0.1504 - val_accuracy: 0.9510
#
# Epoch 00007: val_loss improved from 0.17469 to 0.15037, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 8/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1572 - accuracy: 0.9477 - val_loss: 0.1583 - val_accuracy: 0.9514
#
# Epoch 00008: val_loss did not improve from 0.15037
# Epoch 9/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1535 - accuracy: 0.9506 - val_loss: 0.1399 - val_accuracy: 0.9544
#
# Epoch 00009: val_loss improved from 0.15037 to 0.13991, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 10/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.1390 - accuracy: 0.9541 - val_loss: 0.1308 - val_accuracy: 0.9589
#
# Epoch 00010: val_loss improved from 0.13991 to 0.13078, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 11/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1431 - accuracy: 0.9547 - val_loss: 0.1437 - val_accuracy: 0.9548
#
# Epoch 00011: val_loss did not improve from 0.13078
# Epoch 12/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1272 - accuracy: 0.9589 - val_loss: 0.1381 - val_accuracy: 0.9582
#
# Epoch 00012: val_loss did not improve from 0.13078
# Epoch 13/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1213 - accuracy: 0.9594 - val_loss: 0.1247 - val_accuracy: 0.9563
#
# Epoch 00013: val_loss improved from 0.13078 to 0.12470, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 14/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.3733 - accuracy: 0.9369 - val_loss: 38.4078 - val_accuracy: 0.9518
#
# Epoch 00014: val_loss did not improve from 0.12470
# Epoch 15/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.1339 - accuracy: 0.9581 - val_loss: 1.0458 - val_accuracy: 0.9544
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.12470
# Epoch 16/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1054 - accuracy: 0.9665 - val_loss: 0.2222 - val_accuracy: 0.9631
#
# Epoch 00016: val_loss did not improve from 0.12470
# Epoch 17/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0983 - accuracy: 0.9689 - val_loss: 0.1241 - val_accuracy: 0.9684
#
# Epoch 00017: val_loss improved from 0.12470 to 0.12407, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 18/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0918 - accuracy: 0.9697 - val_loss: 0.1058 - val_accuracy: 0.9661
#
# Epoch 00018: val_loss improved from 0.12407 to 0.10583, saving model to /Users/Max/Documents/GitHub/cross_validation/densenet-local-v001\model.h5
# Epoch 19/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0841 - accuracy: 0.9730 - val_loss: 0.1208 - val_accuracy: 0.9672
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0826 - accuracy: 0.9725 - val_loss: 0.1213 - val_accuracy: 0.9669
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0774 - accuracy: 0.9751 - val_loss: 0.1292 - val_accuracy: 0.9623
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0867 - accuracy: 0.9733 - val_loss: 0.1278 - val_accuracy: 0.9672
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0663 - accuracy: 0.9781 - val_loss: 0.1215 - val_accuracy: 0.9706
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0608 - accuracy: 0.9802 - val_loss: 0.1191 - val_accuracy: 0.9702
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0639 - accuracy: 0.9797 - val_loss: 0.1112 - val_accuracy: 0.9714
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0583 - accuracy: 0.9809 - val_loss: 0.1187 - val_accuracy: 0.9695
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0556 - accuracy: 0.9816 - val_loss: 0.1096 - val_accuracy: 0.9714
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0538 - accuracy: 0.9823 - val_loss: 0.1172 - val_accuracy: 0.9710
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0518 - accuracy: 0.9828 - val_loss: 0.1180 - val_accuracy: 0.9699
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0531 - accuracy: 0.9821 - val_loss: 0.1336 - val_accuracy: 0.9699
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.0484 - accuracy: 0.9836 - val_loss: 0.1201 - val_accuracy: 0.9706
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 104s 139ms/step - loss: 0.0474 - accuracy: 0.9839 - val_loss: 0.1228 - val_accuracy: 0.9684
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0446 - accuracy: 0.9850 - val_loss: 0.1334 - val_accuracy: 0.9687
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 100s 134ms/step - loss: 0.0436 - accuracy: 0.9850 - val_loss: 0.1433 - val_accuracy: 0.9661
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.0434 - accuracy: 0.9851 - val_loss: 0.1366 - val_accuracy: 0.9680
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.0417 - accuracy: 0.9855 - val_loss: 0.1325 - val_accuracy: 0.9699
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 100s 134ms/step - loss: 0.0408 - accuracy: 0.9856 - val_loss: 0.1377 - val_accuracy: 0.9702
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 98s 131ms/step - loss: 0.0395 - accuracy: 0.9858 - val_loss: 0.1523 - val_accuracy: 0.9684
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.0401 - accuracy: 0.9859 - val_loss: 0.1465 - val_accuracy: 0.9699
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.0382 - accuracy: 0.9865 - val_loss: 0.1453 - val_accuracy: 0.9695
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 1: loss of 0.14528357982635498; accuracy of 96.94915413856506%
# Epoch 1/40
# 747/747 [==============================] - 119s 141ms/step - loss: 0.6093 - accuracy: 0.8503 - val_loss: 0.3253 - val_accuracy: 0.8911
#
# Epoch 00001: val_loss did not improve from 0.10583
# Epoch 2/40
# 747/747 [==============================] - 100s 134ms/step - loss: 0.3711 - accuracy: 0.8955 - val_loss: 0.2744 - val_accuracy: 0.9171
#
# Epoch 00002: val_loss did not improve from 0.10583
# Epoch 3/40
# 747/747 [==============================] - 98s 131ms/step - loss: 0.2428 - accuracy: 0.9220 - val_loss: 0.2096 - val_accuracy: 0.9322
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 107s 143ms/step - loss: 0.2035 - accuracy: 0.9337 - val_loss: 0.2153 - val_accuracy: 0.9348
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 107s 143ms/step - loss: 0.1855 - accuracy: 0.9396 - val_loss: 0.2324 - val_accuracy: 0.9232
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.1745 - accuracy: 0.9421 - val_loss: 0.2002 - val_accuracy: 0.9318
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1638 - accuracy: 0.9466 - val_loss: 0.1709 - val_accuracy: 0.9461
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.5167 - accuracy: 0.8967 - val_loss: 41.4250 - val_accuracy: 0.9006
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 94s 127ms/step - loss: 0.3085 - accuracy: 0.9160 - val_loss: 0.2437 - val_accuracy: 0.9205
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.2305 - accuracy: 0.9288 - val_loss: 0.9709 - val_accuracy: 0.9247
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.1861 - accuracy: 0.9409 - val_loss: 0.7417 - val_accuracy: 0.9326
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 99s 132ms/step - loss: 0.1689 - accuracy: 0.9452 - val_loss: 0.5159 - val_accuracy: 0.9341
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 98s 131ms/step - loss: 0.1345 - accuracy: 0.9557 - val_loss: 0.2193 - val_accuracy: 0.9461
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.1258 - accuracy: 0.9596 - val_loss: 0.1562 - val_accuracy: 0.9529
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 99s 132ms/step - loss: 0.1251 - accuracy: 0.9585 - val_loss: 2.2008 - val_accuracy: 0.9058
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 99s 133ms/step - loss: 0.1177 - accuracy: 0.9605 - val_loss: 0.5262 - val_accuracy: 0.9412
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 102s 136ms/step - loss: 0.1121 - accuracy: 0.9637 - val_loss: 0.2135 - val_accuracy: 0.9503
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 97s 130ms/step - loss: 0.1054 - accuracy: 0.9652 - val_loss: 0.6230 - val_accuracy: 0.9394
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.0986 - accuracy: 0.9679 - val_loss: 0.2192 - val_accuracy: 0.9540
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0950 - accuracy: 0.9689 - val_loss: 0.1539 - val_accuracy: 0.9503
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0983 - accuracy: 0.9688 - val_loss: 0.3104 - val_accuracy: 0.9574
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 99s 132ms/step - loss: 0.0896 - accuracy: 0.9711 - val_loss: 0.1513 - val_accuracy: 0.9586
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.0908 - accuracy: 0.9725 - val_loss: 0.1609 - val_accuracy: 0.9563
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.0879 - accuracy: 0.9715 - val_loss: 0.1481 - val_accuracy: 0.9616
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 101s 136ms/step - loss: 0.0775 - accuracy: 0.9750 - val_loss: 0.1698 - val_accuracy: 0.9574
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 102s 137ms/step - loss: 0.0768 - accuracy: 0.9750 - val_loss: 0.3657 - val_accuracy: 0.9514
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 99s 132ms/step - loss: 0.0729 - accuracy: 0.9772 - val_loss: 0.1576 - val_accuracy: 0.9593
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.0721 - accuracy: 0.9759 - val_loss: 107.2413 - val_accuracy: 0.9081
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0645 - accuracy: 0.9784 - val_loss: 1.1526 - val_accuracy: 0.9480
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 99s 132ms/step - loss: 0.0650 - accuracy: 0.9813 - val_loss: 0.4984 - val_accuracy: 0.9518
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 104s 139ms/step - loss: 0.0533 - accuracy: 0.9827 - val_loss: 0.2941 - val_accuracy: 0.9582
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.0498 - accuracy: 0.9835 - val_loss: 0.3035 - val_accuracy: 0.9586
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 98s 132ms/step - loss: 0.0531 - accuracy: 0.9827 - val_loss: 5.4013 - val_accuracy: 0.9367
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.0493 - accuracy: 0.9840 - val_loss: 0.4554 - val_accuracy: 0.9507
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 100s 134ms/step - loss: 0.0465 - accuracy: 0.9847 - val_loss: 0.1617 - val_accuracy: 0.9635
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 0.1692 - val_accuracy: 0.9665
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.0423 - accuracy: 0.9854 - val_loss: 0.1692 - val_accuracy: 0.9661
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0414 - accuracy: 0.9861 - val_loss: 0.1812 - val_accuracy: 0.9653
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 99s 133ms/step - loss: 0.0409 - accuracy: 0.9866 - val_loss: 0.1806 - val_accuracy: 0.9635
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 103s 138ms/step - loss: 0.0400 - accuracy: 0.9864 - val_loss: 0.1885 - val_accuracy: 0.9642
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 2: loss of 0.1885290890932083; accuracy of 96.42184376716614%
# Epoch 1/40
# 747/747 [==============================] - 114s 134ms/step - loss: 0.5405 - accuracy: 0.8861 - val_loss: 35514544.0000 - val_accuracy: 0.0497
#
# Epoch 00001: val_loss did not improve from 0.10583
# Epoch 2/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.4641 - accuracy: 0.8805 - val_loss: 0.8340 - val_accuracy: 0.8185
#
# Epoch 00002: val_loss did not improve from 0.10583
# Epoch 3/40
# 747/747 [==============================] - 100s 134ms/step - loss: 0.2731 - accuracy: 0.9209 - val_loss: 1.0377 - val_accuracy: 0.8362
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 92s 124ms/step - loss: 0.2198 - accuracy: 0.9323 - val_loss: 0.1897 - val_accuracy: 0.9390
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.1886 - accuracy: 0.9386 - val_loss: 0.2931 - val_accuracy: 0.9239
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.1880 - accuracy: 0.9422 - val_loss: 0.1608 - val_accuracy: 0.9465
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.2330 - accuracy: 0.9384 - val_loss: 0.2548 - val_accuracy: 0.9077
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 97s 129ms/step - loss: 0.1664 - accuracy: 0.9474 - val_loss: 0.1440 - val_accuracy: 0.9548
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.1620 - accuracy: 0.9510 - val_loss: 0.2679 - val_accuracy: 0.8512
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1385 - accuracy: 0.9556 - val_loss: 0.1888 - val_accuracy: 0.9073
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 99s 133ms/step - loss: 0.1737 - accuracy: 0.9493 - val_loss: 0.6232 - val_accuracy: 0.9266
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.1683 - accuracy: 0.9499 - val_loss: 0.1518 - val_accuracy: 0.9529
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.1301 - accuracy: 0.9601 - val_loss: 0.1809 - val_accuracy: 0.9533
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.0999 - accuracy: 0.9676 - val_loss: 0.1292 - val_accuracy: 0.9612
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.0914 - accuracy: 0.9699 - val_loss: 0.1210 - val_accuracy: 0.9638
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 92s 124ms/step - loss: 0.0859 - accuracy: 0.9712 - val_loss: 0.1272 - val_accuracy: 0.9627
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0847 - accuracy: 0.9719 - val_loss: 0.1294 - val_accuracy: 0.9646
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0797 - accuracy: 0.9739 - val_loss: 0.1458 - val_accuracy: 0.9582
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0796 - accuracy: 0.9735 - val_loss: 0.1173 - val_accuracy: 0.9669
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0726 - accuracy: 0.9767 - val_loss: 0.1402 - val_accuracy: 0.9627
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0720 - accuracy: 0.9753 - val_loss: 0.1566 - val_accuracy: 0.9559
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0657 - accuracy: 0.9787 - val_loss: 0.1371 - val_accuracy: 0.9642
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0651 - accuracy: 0.9779 - val_loss: 0.1345 - val_accuracy: 0.9650
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0664 - accuracy: 0.9785 - val_loss: 0.1442 - val_accuracy: 0.9653
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0524 - accuracy: 0.9832 - val_loss: 0.1385 - val_accuracy: 0.9669
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0488 - accuracy: 0.9840 - val_loss: 0.1403 - val_accuracy: 0.9676
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0472 - accuracy: 0.9845 - val_loss: 0.1411 - val_accuracy: 0.9680
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0458 - accuracy: 0.9850 - val_loss: 0.1452 - val_accuracy: 0.9680
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0464 - accuracy: 0.9848 - val_loss: 0.1496 - val_accuracy: 0.9676
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0455 - accuracy: 0.9841 - val_loss: 0.1526 - val_accuracy: 0.9661
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.1517 - val_accuracy: 0.9638
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0433 - accuracy: 0.9856 - val_loss: 0.1615 - val_accuracy: 0.9665
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0393 - accuracy: 0.9859 - val_loss: 0.1538 - val_accuracy: 0.9684
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 104s 139ms/step - loss: 0.0369 - accuracy: 0.9874 - val_loss: 0.1555 - val_accuracy: 0.9665
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 98s 131ms/step - loss: 0.0364 - accuracy: 0.9874 - val_loss: 0.1559 - val_accuracy: 0.9684
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0349 - accuracy: 0.9883 - val_loss: 0.1645 - val_accuracy: 0.9650
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.0341 - accuracy: 0.9882 - val_loss: 0.1608 - val_accuracy: 0.9661
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0330 - accuracy: 0.9888 - val_loss: 0.1684 - val_accuracy: 0.9653
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0309 - accuracy: 0.9895 - val_loss: 0.1815 - val_accuracy: 0.9631
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0301 - accuracy: 0.9895 - val_loss: 0.1745 - val_accuracy: 0.9650
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 3: loss of 0.1745254099369049; accuracy of 96.49717807769775%
# Epoch 1/40
# 747/747 [==============================] - 109s 126ms/step - loss: 0.4422 - accuracy: 0.8821 - val_loss: 0.2473 - val_accuracy: 0.9269
#
# Epoch 00001: val_loss did not improve from 0.10583
# Epoch 2/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.4901 - accuracy: 0.8945 - val_loss: 0.4659 - val_accuracy: 0.9002
#
# Epoch 00002: val_loss did not improve from 0.10583
# Epoch 3/40
# 747/747 [==============================] - 92s 124ms/step - loss: 0.3409 - accuracy: 0.9030 - val_loss: 0.2390 - val_accuracy: 0.9228
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.2198 - accuracy: 0.9302 - val_loss: 0.2191 - val_accuracy: 0.9318
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.1891 - accuracy: 0.9390 - val_loss: 0.1872 - val_accuracy: 0.9416
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1712 - accuracy: 0.9443 - val_loss: 0.1662 - val_accuracy: 0.9480
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.1892 - accuracy: 0.9432 - val_loss: 0.3439 - val_accuracy: 0.8911
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1686 - accuracy: 0.9456 - val_loss: 0.2204 - val_accuracy: 0.9341
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1439 - accuracy: 0.9527 - val_loss: 0.1896 - val_accuracy: 0.9458
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.1366 - accuracy: 0.9560 - val_loss: 0.1613 - val_accuracy: 0.9537
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.1873 - accuracy: 0.9484 - val_loss: 8.1952 - val_accuracy: 0.2418
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1923 - accuracy: 0.9386 - val_loss: 0.1734 - val_accuracy: 0.9454
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 97s 130ms/step - loss: 0.1390 - accuracy: 0.9544 - val_loss: 0.1563 - val_accuracy: 0.9533
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 95s 128ms/step - loss: 0.1338 - accuracy: 0.9560 - val_loss: 0.1464 - val_accuracy: 0.9533
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 100s 133ms/step - loss: 0.1161 - accuracy: 0.9612 - val_loss: 0.2306 - val_accuracy: 0.9548
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.1071 - accuracy: 0.9654 - val_loss: 0.1415 - val_accuracy: 0.9597
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.1043 - accuracy: 0.9652 - val_loss: 0.1412 - val_accuracy: 0.9608
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1027 - accuracy: 0.9666 - val_loss: 0.1744 - val_accuracy: 0.9499
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0946 - accuracy: 0.9688 - val_loss: 0.1507 - val_accuracy: 0.9559
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0927 - accuracy: 0.9697 - val_loss: 0.7746 - val_accuracy: 0.9484
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0943 - accuracy: 0.9698 - val_loss: 0.1631 - val_accuracy: 0.9574
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0858 - accuracy: 0.9725 - val_loss: 0.7039 - val_accuracy: 0.9518
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0646 - accuracy: 0.9791 - val_loss: 0.5328 - val_accuracy: 0.9616
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0589 - accuracy: 0.9806 - val_loss: 0.1451 - val_accuracy: 0.9642
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 96s 129ms/step - loss: 0.0579 - accuracy: 0.9813 - val_loss: 1.0312 - val_accuracy: 0.9631
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0583 - accuracy: 0.9806 - val_loss: 0.1789 - val_accuracy: 0.9608
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0583 - accuracy: 0.9813 - val_loss: 0.9517 - val_accuracy: 0.9623
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0606 - accuracy: 0.9799 - val_loss: 1.2058 - val_accuracy: 0.9586
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0560 - accuracy: 0.9820 - val_loss: 0.1670 - val_accuracy: 0.9608
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0450 - accuracy: 0.9849 - val_loss: 0.1695 - val_accuracy: 0.9635
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0436 - accuracy: 0.9854 - val_loss: 0.1641 - val_accuracy: 0.9631
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0425 - accuracy: 0.9859 - val_loss: 0.1831 - val_accuracy: 0.9623
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 92s 124ms/step - loss: 0.0427 - accuracy: 0.9859 - val_loss: 0.1846 - val_accuracy: 0.9642
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0412 - accuracy: 0.9861 - val_loss: 0.1876 - val_accuracy: 0.9653
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0412 - accuracy: 0.9858 - val_loss: 0.2010 - val_accuracy: 0.9612
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 108s 144ms/step - loss: 0.0395 - accuracy: 0.9866 - val_loss: 0.4071 - val_accuracy: 0.9642
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 106s 142ms/step - loss: 0.0392 - accuracy: 0.9865 - val_loss: 0.2093 - val_accuracy: 0.9616
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 106s 142ms/step - loss: 0.0389 - accuracy: 0.9867 - val_loss: 0.2053 - val_accuracy: 0.9601
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 106s 142ms/step - loss: 0.0385 - accuracy: 0.9864 - val_loss: 0.1851 - val_accuracy: 0.9638
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 106s 141ms/step - loss: 0.0346 - accuracy: 0.9880 - val_loss: 0.1949 - val_accuracy: 0.9605
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 4: loss of 0.19488979876041412; accuracy of 96.04519605636597%
# Epoch 1/40
# 747/747 [==============================] - 122s 144ms/step - loss: 0.5951 - accuracy: 0.8674 - val_loss: 4066.3879 - val_accuracy: 0.3175
#
# Epoch 00001: val_loss did not improve from 0.10583
# Epoch 2/40
# 747/747 [==============================] - 105s 141ms/step - loss: 0.4353 - accuracy: 0.8831 - val_loss: 0.2729 - val_accuracy: 0.9190
#
# Epoch 00002: val_loss did not improve from 0.10583
# Epoch 3/40
# 747/747 [==============================] - 105s 141ms/step - loss: 0.2749 - accuracy: 0.9155 - val_loss: 0.2181 - val_accuracy: 0.9330
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 105s 141ms/step - loss: 0.2134 - accuracy: 0.9301 - val_loss: 0.2056 - val_accuracy: 0.9348
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 106s 142ms/step - loss: 0.1902 - accuracy: 0.9382 - val_loss: 0.1796 - val_accuracy: 0.9450
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 106s 142ms/step - loss: 0.2019 - accuracy: 0.9381 - val_loss: 492.1457 - val_accuracy: 0.6143
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 106s 142ms/step - loss: 0.3038 - accuracy: 0.9193 - val_loss: 0.2188 - val_accuracy: 0.9322
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 98s 131ms/step - loss: 0.1901 - accuracy: 0.9378 - val_loss: 0.2556 - val_accuracy: 0.9213
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1673 - accuracy: 0.9443 - val_loss: 0.2029 - val_accuracy: 0.9397
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 96s 128ms/step - loss: 0.1534 - accuracy: 0.9492 - val_loss: 0.1796 - val_accuracy: 0.9424
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 101s 135ms/step - loss: 0.1295 - accuracy: 0.9566 - val_loss: 0.1504 - val_accuracy: 0.9571
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 92s 124ms/step - loss: 0.1176 - accuracy: 0.9612 - val_loss: 0.1348 - val_accuracy: 0.9574
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1157 - accuracy: 0.9610 - val_loss: 0.1415 - val_accuracy: 0.9574
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 98s 132ms/step - loss: 0.1096 - accuracy: 0.9646 - val_loss: 0.1525 - val_accuracy: 0.9567
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.1054 - accuracy: 0.9652 - val_loss: 0.1567 - val_accuracy: 0.9522
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1014 - accuracy: 0.9666 - val_loss: 0.1426 - val_accuracy: 0.9631
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0940 - accuracy: 0.9696 - val_loss: 0.1489 - val_accuracy: 0.9574
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 95s 127ms/step - loss: 0.0888 - accuracy: 0.9697 - val_loss: 0.1497 - val_accuracy: 0.9582
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0892 - accuracy: 0.9707 - val_loss: 0.1494 - val_accuracy: 0.9574
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0813 - accuracy: 0.9732 - val_loss: 0.1426 - val_accuracy: 0.9593
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 89s 119ms/step - loss: 0.0806 - accuracy: 0.9735 - val_loss: 0.1321 - val_accuracy: 0.9669
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0747 - accuracy: 0.9750 - val_loss: 0.1406 - val_accuracy: 0.9646
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0815 - accuracy: 0.9759 - val_loss: 0.1430 - val_accuracy: 0.9627
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0700 - accuracy: 0.9771 - val_loss: 0.1558 - val_accuracy: 0.9593
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0936 - accuracy: 0.9751 - val_loss: 0.1539 - val_accuracy: 0.9620
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0665 - accuracy: 0.9789 - val_loss: 0.1459 - val_accuracy: 0.9657
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0527 - accuracy: 0.9831 - val_loss: 0.1556 - val_accuracy: 0.9680
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0501 - accuracy: 0.9838 - val_loss: 0.1578 - val_accuracy: 0.9672
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0505 - accuracy: 0.9836 - val_loss: 0.1607 - val_accuracy: 0.9669
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0500 - accuracy: 0.9833 - val_loss: 0.1609 - val_accuracy: 0.9669
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 97s 130ms/step - loss: 0.0498 - accuracy: 0.9834 - val_loss: 0.1608 - val_accuracy: 0.9676
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.0478 - accuracy: 0.9841 - val_loss: 0.1766 - val_accuracy: 0.9650
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.0433 - accuracy: 0.9856 - val_loss: 0.1728 - val_accuracy: 0.9665
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0412 - accuracy: 0.9858 - val_loss: 0.1903 - val_accuracy: 0.9657
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0413 - accuracy: 0.9856 - val_loss: 0.1796 - val_accuracy: 0.9672
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0417 - accuracy: 0.9854 - val_loss: 0.1748 - val_accuracy: 0.9669
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0396 - accuracy: 0.9859 - val_loss: 0.1816 - val_accuracy: 0.9691
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0384 - accuracy: 0.9861 - val_loss: 0.1916 - val_accuracy: 0.9657
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0382 - accuracy: 0.9866 - val_loss: 0.1947 - val_accuracy: 0.9669
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0376 - accuracy: 0.9864 - val_loss: 0.1921 - val_accuracy: 0.9676
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 5: loss of 0.19207589328289032; accuracy of 96.76082730293274%
# Epoch 1/40
# 747/747 [==============================] - 107s 125ms/step - loss: 0.4572 - accuracy: 0.8870 - val_loss: 0.4599 - val_accuracy: 0.8663
#
# Epoch 00001: val_loss did not improve from 0.10583
# Epoch 2/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.3541 - accuracy: 0.9029 - val_loss: 0.3248 - val_accuracy: 0.8953
#
# Epoch 00002: val_loss did not improve from 0.10583
# Epoch 3/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.2206 - accuracy: 0.9299 - val_loss: 0.1810 - val_accuracy: 0.9405
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1782 - accuracy: 0.9407 - val_loss: 0.1775 - val_accuracy: 0.9492
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.1644 - accuracy: 0.9461 - val_loss: 0.1688 - val_accuracy: 0.9424
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.1452 - accuracy: 0.9531 - val_loss: 0.1658 - val_accuracy: 0.9529
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.1720 - accuracy: 0.9475 - val_loss: 0.6692 - val_accuracy: 0.9179
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1756 - accuracy: 0.9462 - val_loss: 0.1454 - val_accuracy: 0.9582
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1326 - accuracy: 0.9563 - val_loss: 0.1500 - val_accuracy: 0.9578
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.1216 - accuracy: 0.9596 - val_loss: 0.1471 - val_accuracy: 0.9571
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.1178 - accuracy: 0.9624 - val_loss: 0.1343 - val_accuracy: 0.9616
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1111 - accuracy: 0.9634 - val_loss: 0.1438 - val_accuracy: 0.9612
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1057 - accuracy: 0.9654 - val_loss: 0.1581 - val_accuracy: 0.9507
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1338 - accuracy: 0.9576 - val_loss: 0.1783 - val_accuracy: 0.9612
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 94s 126ms/step - loss: 0.1094 - accuracy: 0.9641 - val_loss: 0.1395 - val_accuracy: 0.9586
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0928 - accuracy: 0.9698 - val_loss: 0.1268 - val_accuracy: 0.9676
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0883 - accuracy: 0.9702 - val_loss: 0.1302 - val_accuracy: 0.9665
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0851 - accuracy: 0.9718 - val_loss: 0.1313 - val_accuracy: 0.9635
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 95s 128ms/step - loss: 0.0795 - accuracy: 0.9739 - val_loss: 0.1168 - val_accuracy: 0.9680
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.4426 - accuracy: 0.9624 - val_loss: 0.3238 - val_accuracy: 0.8441
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1240 - accuracy: 0.9591 - val_loss: 0.1263 - val_accuracy: 0.9635
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0900 - accuracy: 0.9710 - val_loss: 0.1156 - val_accuracy: 0.9661
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0784 - accuracy: 0.9739 - val_loss: 0.1201 - val_accuracy: 0.9642
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0728 - accuracy: 0.9764 - val_loss: 0.1197 - val_accuracy: 0.9627
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.0604 - accuracy: 0.9800 - val_loss: 0.1111 - val_accuracy: 0.9714
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1225 - accuracy: 0.9756 - val_loss: 0.1126 - val_accuracy: 0.9684
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0673 - accuracy: 0.9776 - val_loss: 0.1249 - val_accuracy: 0.9684
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0593 - accuracy: 0.9807 - val_loss: 0.1326 - val_accuracy: 0.9676
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0550 - accuracy: 0.9823 - val_loss: 0.1429 - val_accuracy: 0.9684
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# ...
# Epoch 3/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.3103 - accuracy: 0.9031 - val_loss: 0.2036 - val_accuracy: 0.9310
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.2101 - accuracy: 0.9317 - val_loss: 0.2245 - val_accuracy: 0.9292
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1803 - accuracy: 0.9412 - val_loss: 0.1775 - val_accuracy: 0.9427
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.2631 - accuracy: 0.9290 - val_loss: 1.4334 - val_accuracy: 0.9359
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1879 - accuracy: 0.9394 - val_loss: 0.1478 - val_accuracy: 0.9521
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1489 - accuracy: 0.9503 - val_loss: 0.1318 - val_accuracy: 0.9570
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.2377 - accuracy: 0.9323 - val_loss: 0.1626 - val_accuracy: 0.9503
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1498 - accuracy: 0.9510 - val_loss: 0.1525 - val_accuracy: 0.9491
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.1333 - accuracy: 0.9564 - val_loss: 0.1700 - val_accuracy: 0.9461
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1343 - accuracy: 0.9567 - val_loss: 0.1397 - val_accuracy: 0.9552
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.1192 - accuracy: 0.9610 - val_loss: 0.1235 - val_accuracy: 0.9619
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.1139 - accuracy: 0.9624 - val_loss: 0.1212 - val_accuracy: 0.9586
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1103 - accuracy: 0.9645 - val_loss: 0.1234 - val_accuracy: 0.9631
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1051 - accuracy: 0.9653 - val_loss: 0.1148 - val_accuracy: 0.9638
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1012 - accuracy: 0.9680 - val_loss: 0.1255 - val_accuracy: 0.9612
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1032 - accuracy: 0.9675 - val_loss: 0.1341 - val_accuracy: 0.9597
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0888 - accuracy: 0.9710 - val_loss: 0.1184 - val_accuracy: 0.9661
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0875 - accuracy: 0.9723 - val_loss: 0.1253 - val_accuracy: 0.9616
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0858 - accuracy: 0.9719 - val_loss: 0.1578 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0778 - accuracy: 0.9751 - val_loss: 0.1297 - val_accuracy: 0.9631
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0779 - accuracy: 0.9749 - val_loss: 0.1225 - val_accuracy: 0.9683
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0793 - accuracy: 0.9747 - val_loss: 0.1511 - val_accuracy: 0.9552
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.1323 - accuracy: 0.9732 - val_loss: 7449.6099 - val_accuracy: 0.6797
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1367 - accuracy: 0.9635 - val_loss: 0.1345 - val_accuracy: 0.9604
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.1059 - accuracy: 0.9664 - val_loss: 0.1237 - val_accuracy: 0.9638
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0808 - accuracy: 0.9744 - val_loss: 0.1192 - val_accuracy: 0.9653
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0630 - accuracy: 0.9795 - val_loss: 0.1264 - val_accuracy: 0.9672
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0596 - accuracy: 0.9808 - val_loss: 0.1345 - val_accuracy: 0.9661
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0571 - accuracy: 0.9819 - val_loss: 0.1377 - val_accuracy: 0.9687
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0545 - accuracy: 0.9821 - val_loss: 0.1381 - val_accuracy: 0.9661
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0526 - accuracy: 0.9828 - val_loss: 0.1414 - val_accuracy: 0.9680
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0520 - accuracy: 0.9833 - val_loss: 0.1511 - val_accuracy: 0.9676
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0542 - accuracy: 0.9820 - val_loss: 0.1413 - val_accuracy: 0.9702
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0522 - accuracy: 0.9828 - val_loss: 0.1351 - val_accuracy: 0.9702
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0521 - accuracy: 0.9828 - val_loss: 0.1578 - val_accuracy: 0.9668
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0509 - accuracy: 0.9836 - val_loss: 0.1472 - val_accuracy: 0.9676
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0527 - accuracy: 0.9822 - val_loss: 0.1532 - val_accuracy: 0.9676
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0503 - accuracy: 0.9833 - val_loss: 0.1517 - val_accuracy: 0.9695
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 9: loss of 0.15173473954200745; accuracy of 96.9480037689209%
# Epoch 1/40
# 747/747 [==============================] - 105s 125ms/step - loss: 0.5167 - accuracy: 0.8762 - val_loss: 0.2516 - val_accuracy: 0.9171
#
# Epoch 00001: val_loss did not improve from 0.10583
# Epoch 2/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.7540 - accuracy: 0.8595 - val_loss: 0.5782 - val_accuracy: 0.8719
#
# Epoch 00002: val_loss did not improve from 0.10583
# Epoch 3/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.3531 - accuracy: 0.9022 - val_loss: 0.2626 - val_accuracy: 0.9111
#
# Epoch 00003: val_loss did not improve from 0.10583
# Epoch 4/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.2604 - accuracy: 0.9193 - val_loss: 0.2331 - val_accuracy: 0.9164
#
# Epoch 00004: val_loss did not improve from 0.10583
# Epoch 5/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.2276 - accuracy: 0.9298 - val_loss: 0.2266 - val_accuracy: 0.9209
#
# Epoch 00005: val_loss did not improve from 0.10583
# Epoch 6/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.2114 - accuracy: 0.9358 - val_loss: 57.2710 - val_accuracy: 0.5539
#
# Epoch 00006: val_loss did not improve from 0.10583
# Epoch 7/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1931 - accuracy: 0.9394 - val_loss: 0.1903 - val_accuracy: 0.9424
#
# Epoch 00007: val_loss did not improve from 0.10583
# Epoch 8/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1893 - accuracy: 0.9438 - val_loss: 110.9232 - val_accuracy: 0.3101
#
# Epoch 00008: val_loss did not improve from 0.10583
# Epoch 9/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.2318 - accuracy: 0.9370 - val_loss: 0.1789 - val_accuracy: 0.9450
#
# Epoch 00009: val_loss did not improve from 0.10583
# Epoch 10/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.3241 - accuracy: 0.9199 - val_loss: 0.2169 - val_accuracy: 0.9310
#
# Epoch 00010: val_loss did not improve from 0.10583
# Epoch 11/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1811 - accuracy: 0.9425 - val_loss: 0.2019 - val_accuracy: 0.9401
#
# Epoch 00011: val_loss did not improve from 0.10583
# Epoch 12/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1603 - accuracy: 0.9488 - val_loss: 0.1623 - val_accuracy: 0.9506
#
# Epoch 00012: val_loss did not improve from 0.10583
# Epoch 13/40
# 747/747 [==============================] - 93s 125ms/step - loss: 0.1480 - accuracy: 0.9525 - val_loss: 0.1543 - val_accuracy: 0.9529
#
# Epoch 00013: val_loss did not improve from 0.10583
# Epoch 14/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1612 - accuracy: 0.9510 - val_loss: 0.1698 - val_accuracy: 0.9472
#
# Epoch 00014: val_loss did not improve from 0.10583
# Epoch 15/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.1359 - accuracy: 0.9570 - val_loss: 0.1525 - val_accuracy: 0.9518
#
# Epoch 00015: val_loss did not improve from 0.10583
# Epoch 16/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1317 - accuracy: 0.9583 - val_loss: 0.1510 - val_accuracy: 0.9518
#
# Epoch 00016: val_loss did not improve from 0.10583
# Epoch 17/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.1195 - accuracy: 0.9613 - val_loss: 0.1630 - val_accuracy: 0.9525
#
# Epoch 00017: val_loss did not improve from 0.10583
# Epoch 18/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.1106 - accuracy: 0.9638 - val_loss: 0.2039 - val_accuracy: 0.9375
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.10583
# Epoch 19/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0884 - accuracy: 0.9712 - val_loss: 0.1436 - val_accuracy: 0.9597
#
# Epoch 00019: val_loss did not improve from 0.10583
# Epoch 20/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0837 - accuracy: 0.9720 - val_loss: 0.1363 - val_accuracy: 0.9616
#
# Epoch 00020: val_loss did not improve from 0.10583
# Epoch 21/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0817 - accuracy: 0.9733 - val_loss: 0.1352 - val_accuracy: 0.9619
#
# Epoch 00021: val_loss did not improve from 0.10583
# Epoch 22/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0757 - accuracy: 0.9753 - val_loss: 0.1422 - val_accuracy: 0.9578
#
# Epoch 00022: val_loss did not improve from 0.10583
# Epoch 23/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0745 - accuracy: 0.9759 - val_loss: 0.1264 - val_accuracy: 0.9608
#
# Epoch 00023: val_loss did not improve from 0.10583
# Epoch 24/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0687 - accuracy: 0.9778 - val_loss: 0.1443 - val_accuracy: 0.9627
#
# Epoch 00024: val_loss did not improve from 0.10583
# Epoch 25/40
# 747/747 [==============================] - 93s 124ms/step - loss: 0.0689 - accuracy: 0.9774 - val_loss: 0.1554 - val_accuracy: 0.9619
#
# Epoch 00025: val_loss did not improve from 0.10583
# Epoch 26/40
# 747/747 [==============================] - 92s 123ms/step - loss: 0.0642 - accuracy: 0.9791 - val_loss: 0.1532 - val_accuracy: 0.9619
#
# Epoch 00026: val_loss did not improve from 0.10583
# Epoch 27/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0617 - accuracy: 0.9797 - val_loss: 0.1419 - val_accuracy: 0.9631
#
# Epoch 00027: val_loss did not improve from 0.10583
# Epoch 28/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0610 - accuracy: 0.9801 - val_loss: 0.1483 - val_accuracy: 0.9623
#
# Epoch 00028: val_loss did not improve from 0.10583
# Epoch 29/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0609 - accuracy: 0.9799 - val_loss: 0.1642 - val_accuracy: 0.9601
#
# Epoch 00029: val_loss did not improve from 0.10583
# Epoch 30/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0581 - accuracy: 0.9803 - val_loss: 0.1623 - val_accuracy: 0.9619
#
# Epoch 00030: val_loss did not improve from 0.10583
# Epoch 31/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0562 - accuracy: 0.9817 - val_loss: 0.1528 - val_accuracy: 0.9574
#
# Epoch 00031: val_loss did not improve from 0.10583
# Epoch 32/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0571 - accuracy: 0.9813 - val_loss: 0.1648 - val_accuracy: 0.9537
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.10583
# Epoch 33/40
# 747/747 [==============================] - 89s 120ms/step - loss: 0.0490 - accuracy: 0.9835 - val_loss: 0.1541 - val_accuracy: 0.9612
#
# Epoch 00033: val_loss did not improve from 0.10583
# Epoch 34/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0441 - accuracy: 0.9847 - val_loss: 0.1592 - val_accuracy: 0.9616
#
# Epoch 00034: val_loss did not improve from 0.10583
# Epoch 35/40
# 747/747 [==============================] - 90s 120ms/step - loss: 0.0431 - accuracy: 0.9855 - val_loss: 0.1545 - val_accuracy: 0.9646
#
# Epoch 00035: val_loss did not improve from 0.10583
# Epoch 36/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0429 - accuracy: 0.9855 - val_loss: 0.1661 - val_accuracy: 0.9635
#
# Epoch 00036: val_loss did not improve from 0.10583
# Epoch 37/40
# 747/747 [==============================] - 91s 122ms/step - loss: 0.0422 - accuracy: 0.9852 - val_loss: 0.1810 - val_accuracy: 0.9631
#
# Epoch 00037: val_loss did not improve from 0.10583
# Epoch 38/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0420 - accuracy: 0.9853 - val_loss: 0.1596 - val_accuracy: 0.9638
#
# Epoch 00038: val_loss did not improve from 0.10583
# Epoch 39/40
# 747/747 [==============================] - 90s 121ms/step - loss: 0.0397 - accuracy: 0.9861 - val_loss: 0.1727 - val_accuracy: 0.9604
#
# Epoch 00039: val_loss did not improve from 0.10583
# Epoch 40/40
# 747/747 [==============================] - 91s 121ms/step - loss: 0.0409 - accuracy: 0.9856 - val_loss: 0.1659 - val_accuracy: 0.9635
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00040: val_loss did not improve from 0.10583
# Score for fold 10: loss of 0.16592136025428772; accuracy of 96.34513854980469%

# %%
(np.argmax(head_model.predict(imgs[test]), axis=-1))
# Out:
# array([ 5,  0, 10, ...,  0, 10, 10], dtype=int64)

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.14528357982635498 - Accuracy: 96.94915413856506%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.1885290890932083 - Accuracy: 96.42184376716614%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.1745254099369049 - Accuracy: 96.49717807769775%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.19488979876041412 - Accuracy: 96.04519605636597%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.19207589328289032 - Accuracy: 96.76082730293274%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.17236852645874023 - Accuracy: 96.79849147796631%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.15418550372123718 - Accuracy: 96.79849147796631%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.2029610425233841 - Accuracy: 96.04519605636597%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.15173473954200745 - Accuracy: 96.9480037689209%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.16592136025428772 - Accuracy: 96.34513854980469%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.56095206737518% (+- 0.003248556851587407)
# > Loss: 0.17424749433994294
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of DenseNet169"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of DenseNet169      |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9656      | 0.0032       |
# | Loss     | 0.1742      | 0.019        |
# | Macro F1 | 0.9089      | 0.0057       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9903      | 0.0032       |
# | Acc      | 0.9926      | 0.0018       |
# | F1       | 0.993       | 0.0017       |
# | MCC      | 0.9852      | 0.0037       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for DenseNet169 across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - DenseNet169")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
