# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 150000 # Set very high so it uses all the images in the directory, does not actually take 150,000 images

# Number of epochs
epoch_t = 35 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import time

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cgan-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# No matches found
# New folder name: cgan-cnn-local-v001
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"
    path_root_gen = '/kaggle/input/cganlocalv007/cgan-ckpt-local-v010-half'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-ckpt-v009-thirdsize"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# Count number of files in the CGAN folder

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 42528 images belonging to 10 classes.

# %%
plt.imshow(imgs_gen[900],cmap='gray')

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 2076/2076 [==============================] - 13s 5ms/step - loss: 0.2083 - accuracy: 0.9383 - val_loss: 0.2804 - val_accuracy: 0.9205
#
# Epoch 00001: val_loss improved from inf to 0.28044, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 2/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1039 - accuracy: 0.9676 - val_loss: 0.2255 - val_accuracy: 0.9367
#
# Epoch 00002: val_loss improved from 0.28044 to 0.22547, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 3/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0870 - accuracy: 0.9736 - val_loss: 0.1987 - val_accuracy: 0.9439
#
# Epoch 00003: val_loss improved from 0.22547 to 0.19866, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0748 - accuracy: 0.9767 - val_loss: 0.1687 - val_accuracy: 0.9476
#
# Epoch 00004: val_loss improved from 0.19866 to 0.16873, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0665 - accuracy: 0.9790 - val_loss: 0.1796 - val_accuracy: 0.9469
#
# Epoch 00005: val_loss did not improve from 0.16873
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0627 - accuracy: 0.9800 - val_loss: 0.1702 - val_accuracy: 0.9540
#
# Epoch 00006: val_loss did not improve from 0.16873
# Epoch 7/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0568 - accuracy: 0.9820 - val_loss: 0.1674 - val_accuracy: 0.9518
#
# Epoch 00007: val_loss improved from 0.16873 to 0.16742, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0529 - accuracy: 0.9829 - val_loss: 0.1706 - val_accuracy: 0.9514
#
# Epoch 00008: val_loss did not improve from 0.16742
# Epoch 9/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0514 - accuracy: 0.9835 - val_loss: 0.1575 - val_accuracy: 0.9540
#
# Epoch 00009: val_loss improved from 0.16742 to 0.15754, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0471 - accuracy: 0.9845 - val_loss: 0.1594 - val_accuracy: 0.9556
#
# Epoch 00010: val_loss did not improve from 0.15754
# Epoch 11/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0447 - accuracy: 0.9855 - val_loss: 0.1559 - val_accuracy: 0.9556
#
# Epoch 00011: val_loss improved from 0.15754 to 0.15587, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 12/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0417 - accuracy: 0.9863 - val_loss: 0.1750 - val_accuracy: 0.9540
#
# Epoch 00012: val_loss did not improve from 0.15587
# Epoch 13/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.1661 - val_accuracy: 0.9522
#
# Epoch 00013: val_loss did not improve from 0.15587
# Epoch 14/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.1806 - val_accuracy: 0.9529
#
# Epoch 00014: val_loss did not improve from 0.15587
# Epoch 15/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.1619 - val_accuracy: 0.9556
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.15587
# Epoch 16/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.1621 - val_accuracy: 0.9578
#
# Epoch 00016: val_loss did not improve from 0.15587
# Epoch 17/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0305 - accuracy: 0.9899 - val_loss: 0.1659 - val_accuracy: 0.9567
#
# Epoch 00017: val_loss did not improve from 0.15587
# Epoch 18/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.1644 - val_accuracy: 0.9563
#
# Epoch 00018: val_loss did not improve from 0.15587
# Epoch 19/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.1622 - val_accuracy: 0.9578
#
# Epoch 00019: val_loss did not improve from 0.15587
# Epoch 20/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.1661 - val_accuracy: 0.9589
#
# Epoch 00020: val_loss did not improve from 0.15587
# Epoch 21/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.1712 - val_accuracy: 0.9578
#
# Epoch 00021: val_loss did not improve from 0.15587
# Epoch 22/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.1716 - val_accuracy: 0.9586
#
# Epoch 00022: val_loss did not improve from 0.15587
# Epoch 23/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.1788 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss did not improve from 0.15587
# Epoch 24/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0247 - accuracy: 0.9916 - val_loss: 0.1919 - val_accuracy: 0.9563
#
# Epoch 00024: val_loss did not improve from 0.15587
# Epoch 25/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0235 - accuracy: 0.9922 - val_loss: 0.1714 - val_accuracy: 0.9582
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.15587
# Epoch 26/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.1837 - val_accuracy: 0.9578
#
# Epoch 00026: val_loss did not improve from 0.15587
# Epoch 27/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.1948 - val_accuracy: 0.9582
#
# Epoch 00027: val_loss did not improve from 0.15587
# Epoch 28/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.1994 - val_accuracy: 0.9571
#
# Epoch 00028: val_loss did not improve from 0.15587
# Epoch 29/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.1813 - val_accuracy: 0.9578
#
# Epoch 00029: val_loss did not improve from 0.15587
# Epoch 30/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.1974 - val_accuracy: 0.9574
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.15587
# Epoch 31/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0178 - accuracy: 0.9938 - val_loss: 0.2017 - val_accuracy: 0.9571
#
# Epoch 00031: val_loss did not improve from 0.15587
# Epoch 32/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 0.2069 - val_accuracy: 0.9578
#
# Epoch 00032: val_loss did not improve from 0.15587
# Epoch 33/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0178 - accuracy: 0.9936 - val_loss: 0.2017 - val_accuracy: 0.9574
#
# Epoch 00033: val_loss did not improve from 0.15587
# Epoch 34/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.2003 - val_accuracy: 0.9571
#
# Epoch 00034: val_loss did not improve from 0.15587
# Epoch 35/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.2089 - val_accuracy: 0.9571
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.15587
# Score for fold 1: loss of 0.20893380045890808; accuracy of 95.70621252059937%
# Epoch 1/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.2134 - accuracy: 0.9381 - val_loss: 0.2831 - val_accuracy: 0.9149
#
# Epoch 00001: val_loss did not improve from 0.15587
# Epoch 2/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1107 - accuracy: 0.9676 - val_loss: 0.2400 - val_accuracy: 0.9303
#
# Epoch 00002: val_loss did not improve from 0.15587
# Epoch 3/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0903 - accuracy: 0.9730 - val_loss: 0.1970 - val_accuracy: 0.9367
#
# Epoch 00003: val_loss did not improve from 0.15587
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0811 - accuracy: 0.9750 - val_loss: 0.1814 - val_accuracy: 0.9405
#
# Epoch 00004: val_loss did not improve from 0.15587
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0714 - accuracy: 0.9774 - val_loss: 0.1714 - val_accuracy: 0.9424
#
# Epoch 00005: val_loss did not improve from 0.15587
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0648 - accuracy: 0.9797 - val_loss: 0.1568 - val_accuracy: 0.9484
#
# Epoch 00006: val_loss did not improve from 0.15587
# Epoch 7/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0604 - accuracy: 0.9813 - val_loss: 0.1738 - val_accuracy: 0.9458
#
# Epoch 00007: val_loss did not improve from 0.15587
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0561 - accuracy: 0.9817 - val_loss: 0.1544 - val_accuracy: 0.9522
#
# Epoch 00008: val_loss improved from 0.15587 to 0.15438, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 9/35
# 2076/2076 [==============================] - 14s 7ms/step - loss: 0.0507 - accuracy: 0.9836 - val_loss: 0.1510 - val_accuracy: 0.9537
#
# Epoch 00009: val_loss improved from 0.15438 to 0.15097, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0496 - accuracy: 0.9837 - val_loss: 0.1694 - val_accuracy: 0.9529
#
# Epoch 00010: val_loss did not improve from 0.15097
# Epoch 11/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0482 - accuracy: 0.9846 - val_loss: 0.1522 - val_accuracy: 0.9540
#
# Epoch 00011: val_loss did not improve from 0.15097
# Epoch 12/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 0.1623 - val_accuracy: 0.9540
#
# Epoch 00012: val_loss did not improve from 0.15097
# Epoch 13/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.1649 - val_accuracy: 0.9522
#
# Epoch 00013: val_loss did not improve from 0.15097
# Epoch 14/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0418 - accuracy: 0.9861 - val_loss: 0.1573 - val_accuracy: 0.9544
#
# Epoch 00014: val_loss did not improve from 0.15097
# Epoch 15/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0404 - accuracy: 0.9868 - val_loss: 0.1680 - val_accuracy: 0.9537
#
# Epoch 00015: val_loss did not improve from 0.15097
# Epoch 16/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0388 - accuracy: 0.9877 - val_loss: 0.1748 - val_accuracy: 0.9563
#
# Epoch 00016: val_loss did not improve from 0.15097
# Epoch 17/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0372 - accuracy: 0.9877 - val_loss: 0.1901 - val_accuracy: 0.9537
#
# Epoch 00017: val_loss did not improve from 0.15097
# Epoch 18/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0361 - accuracy: 0.9886 - val_loss: 0.1853 - val_accuracy: 0.9556
#
# Epoch 00018: val_loss did not improve from 0.15097
# Epoch 19/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0375 - accuracy: 0.9883 - val_loss: 0.1781 - val_accuracy: 0.9540
#
# Epoch 00019: val_loss did not improve from 0.15097
# Epoch 20/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 0.1615 - val_accuracy: 0.9552
#
# Epoch 00020: val_loss did not improve from 0.15097
# Epoch 21/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0329 - accuracy: 0.9891 - val_loss: 0.1858 - val_accuracy: 0.9529
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.15097
# Epoch 22/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.1829 - val_accuracy: 0.9559
#
# Epoch 00022: val_loss did not improve from 0.15097
# Epoch 23/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0275 - accuracy: 0.9907 - val_loss: 0.1685 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss did not improve from 0.15097
# Epoch 24/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.1854 - val_accuracy: 0.9567
#
# Epoch 00024: val_loss did not improve from 0.15097
# Epoch 25/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.1835 - val_accuracy: 0.9559
#
# Epoch 00025: val_loss did not improve from 0.15097
# Epoch 26/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0247 - accuracy: 0.9916 - val_loss: 0.1836 - val_accuracy: 0.9582
#
# Epoch 00026: val_loss did not improve from 0.15097
# Epoch 27/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0248 - accuracy: 0.9917 - val_loss: 0.1826 - val_accuracy: 0.9571
#
# Epoch 00027: val_loss did not improve from 0.15097
# Epoch 28/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.1911 - val_accuracy: 0.9556
#
# Epoch 00028: val_loss did not improve from 0.15097
# Epoch 29/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.1859 - val_accuracy: 0.9582
#
# Epoch 00029: val_loss did not improve from 0.15097
# Epoch 30/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.1931 - val_accuracy: 0.9556
#
# Epoch 00030: val_loss did not improve from 0.15097
# Epoch 31/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0220 - accuracy: 0.9928 - val_loss: 0.2156 - val_accuracy: 0.9556
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00031: val_loss did not improve from 0.15097
# Epoch 32/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.2104 - val_accuracy: 0.9578
#
# Epoch 00032: val_loss did not improve from 0.15097
# Epoch 33/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0191 - accuracy: 0.9933 - val_loss: 0.2007 - val_accuracy: 0.9563
#
# Epoch 00033: val_loss did not improve from 0.15097
# Epoch 34/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.2114 - val_accuracy: 0.9556
#
# Epoch 00034: val_loss did not improve from 0.15097
# Epoch 35/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.2175 - val_accuracy: 0.9567
#
# Epoch 00035: val_loss did not improve from 0.15097
# Score for fold 2: loss of 0.21753382682800293; accuracy of 95.6685483455658%
# Epoch 1/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.2154 - accuracy: 0.9379 - val_loss: 0.2813 - val_accuracy: 0.9183
#
# Epoch 00001: val_loss did not improve from 0.15097
# Epoch 2/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1113 - accuracy: 0.9667 - val_loss: 0.2331 - val_accuracy: 0.9311
#
# Epoch 00002: val_loss did not improve from 0.15097
# Epoch 3/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0923 - accuracy: 0.9722 - val_loss: 0.2174 - val_accuracy: 0.9341
#
# Epoch 00003: val_loss did not improve from 0.15097
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0831 - accuracy: 0.9741 - val_loss: 0.1928 - val_accuracy: 0.9412
#
# Epoch 00004: val_loss did not improve from 0.15097
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0751 - accuracy: 0.9768 - val_loss: 0.1869 - val_accuracy: 0.9461
#
# Epoch 00005: val_loss did not improve from 0.15097
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0714 - accuracy: 0.9770 - val_loss: 0.1798 - val_accuracy: 0.9454
#
# Epoch 00006: val_loss did not improve from 0.15097
# Epoch 7/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0647 - accuracy: 0.9796 - val_loss: 0.1798 - val_accuracy: 0.9492
#
# Epoch 00007: val_loss did not improve from 0.15097
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0613 - accuracy: 0.9806 - val_loss: 0.1881 - val_accuracy: 0.9473
#
# Epoch 00008: val_loss did not improve from 0.15097
# Epoch 9/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0584 - accuracy: 0.9812 - val_loss: 0.1849 - val_accuracy: 0.9510
#
# Epoch 00009: val_loss did not improve from 0.15097
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0558 - accuracy: 0.9819 - val_loss: 0.1793 - val_accuracy: 0.9518
#
# Epoch 00010: val_loss did not improve from 0.15097
# Epoch 11/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0514 - accuracy: 0.9830 - val_loss: 0.1802 - val_accuracy: 0.9525
#
# Epoch 00011: val_loss did not improve from 0.15097
# Epoch 12/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0495 - accuracy: 0.9836 - val_loss: 0.1708 - val_accuracy: 0.9510
#
# Epoch 00012: val_loss did not improve from 0.15097
# Epoch 13/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0493 - accuracy: 0.9838 - val_loss: 0.1752 - val_accuracy: 0.9537
#
# Epoch 00013: val_loss did not improve from 0.15097
# Epoch 14/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0472 - accuracy: 0.9849 - val_loss: 0.1738 - val_accuracy: 0.9533
#
# Epoch 00014: val_loss did not improve from 0.15097
# Epoch 15/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0445 - accuracy: 0.9852 - val_loss: 0.1841 - val_accuracy: 0.9522
#
# Epoch 00015: val_loss did not improve from 0.15097
# Epoch 16/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0423 - accuracy: 0.9862 - val_loss: 0.1709 - val_accuracy: 0.9522
#
# Epoch 00016: val_loss did not improve from 0.15097
# Epoch 17/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.1945 - val_accuracy: 0.9514
#
# Epoch 00017: val_loss did not improve from 0.15097
# Epoch 18/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0389 - accuracy: 0.9869 - val_loss: 0.1815 - val_accuracy: 0.9525
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.15097
# Epoch 19/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 0.1844 - val_accuracy: 0.9537
#
# Epoch 00019: val_loss did not improve from 0.15097
# Epoch 20/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0300 - accuracy: 0.9896 - val_loss: 0.1854 - val_accuracy: 0.9548
#
# Epoch 00020: val_loss did not improve from 0.15097
# Epoch 21/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0295 - accuracy: 0.9902 - val_loss: 0.1992 - val_accuracy: 0.9559
#
# Epoch 00021: val_loss did not improve from 0.15097
# Epoch 22/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0300 - accuracy: 0.9900 - val_loss: 0.2065 - val_accuracy: 0.9540
#
# Epoch 00022: val_loss did not improve from 0.15097
# Epoch 23/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0284 - accuracy: 0.9903 - val_loss: 0.1936 - val_accuracy: 0.9544
#
# Epoch 00023: val_loss did not improve from 0.15097
# Epoch 24/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 0.1936 - val_accuracy: 0.9563
#
# Epoch 00024: val_loss did not improve from 0.15097
# Epoch 25/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0261 - accuracy: 0.9910 - val_loss: 0.1883 - val_accuracy: 0.9548
#
# Epoch 00025: val_loss did not improve from 0.15097
# Epoch 26/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0273 - accuracy: 0.9908 - val_loss: 0.2030 - val_accuracy: 0.9552
#
# Epoch 00026: val_loss did not improve from 0.15097
# Epoch 27/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0255 - accuracy: 0.9911 - val_loss: 0.1972 - val_accuracy: 0.9540
#
# Epoch 00027: val_loss did not improve from 0.15097
# Epoch 28/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0253 - accuracy: 0.9913 - val_loss: 0.2072 - val_accuracy: 0.9525
#
# Epoch 00028: val_loss did not improve from 0.15097
# Epoch 29/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.2564 - val_accuracy: 0.9514
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.15097
# Epoch 30/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0218 - accuracy: 0.9922 - val_loss: 0.2174 - val_accuracy: 0.9540
#
# Epoch 00030: val_loss did not improve from 0.15097
# Epoch 31/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0210 - accuracy: 0.9924 - val_loss: 0.2428 - val_accuracy: 0.9552
#
# Epoch 00031: val_loss did not improve from 0.15097
# Epoch 32/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0214 - accuracy: 0.9926 - val_loss: 0.2126 - val_accuracy: 0.9552
#
# Epoch 00032: val_loss did not improve from 0.15097
# Epoch 33/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.2336 - val_accuracy: 0.9548
#
# Epoch 00033: val_loss did not improve from 0.15097
# Epoch 34/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 0.2246 - val_accuracy: 0.9571
#
# Epoch 00034: val_loss did not improve from 0.15097
# Epoch 35/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0209 - accuracy: 0.9927 - val_loss: 0.2387 - val_accuracy: 0.9525
#
# Epoch 00035: val_loss did not improve from 0.15097
# Score for fold 3: loss of 0.23867690563201904; accuracy of 95.25423645973206%
# Epoch 1/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.2257 - accuracy: 0.9354 - val_loss: 0.3047 - val_accuracy: 0.9017
#
# Epoch 00001: val_loss did not improve from 0.15097
# Epoch 2/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.1143 - accuracy: 0.9658 - val_loss: 0.2544 - val_accuracy: 0.9209
#
# Epoch 00002: val_loss did not improve from 0.15097
# Epoch 3/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0973 - accuracy: 0.9703 - val_loss: 0.2341 - val_accuracy: 0.9258
#
# Epoch 00003: val_loss did not improve from 0.15097
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0857 - accuracy: 0.9735 - val_loss: 0.2086 - val_accuracy: 0.9360
#
# Epoch 00004: val_loss did not improve from 0.15097
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0771 - accuracy: 0.9764 - val_loss: 0.1969 - val_accuracy: 0.9367
#
# Epoch 00005: val_loss did not improve from 0.15097
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0712 - accuracy: 0.9777 - val_loss: 0.1876 - val_accuracy: 0.9379
#
# Epoch 00006: val_loss did not improve from 0.15097
# Epoch 7/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0681 - accuracy: 0.9782 - val_loss: 0.1866 - val_accuracy: 0.9431
#
# Epoch 00007: val_loss did not improve from 0.15097
# Epoch 8/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0632 - accuracy: 0.9802 - val_loss: 0.1846 - val_accuracy: 0.9401
#
# Epoch 00008: val_loss did not improve from 0.15097
# Epoch 9/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0588 - accuracy: 0.9809 - val_loss: 0.1781 - val_accuracy: 0.9458
#
# Epoch 00009: val_loss did not improve from 0.15097
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0558 - accuracy: 0.9819 - val_loss: 0.1799 - val_accuracy: 0.9435
#
# Epoch 00010: val_loss did not improve from 0.15097
# Epoch 11/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0525 - accuracy: 0.9826 - val_loss: 0.1712 - val_accuracy: 0.9469
#
# Epoch 00011: val_loss did not improve from 0.15097
# Epoch 12/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0508 - accuracy: 0.9835 - val_loss: 0.1770 - val_accuracy: 0.9454
#
# Epoch 00012: val_loss did not improve from 0.15097
# Epoch 13/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0483 - accuracy: 0.9846 - val_loss: 0.1817 - val_accuracy: 0.9446
#
# Epoch 00013: val_loss did not improve from 0.15097
# Epoch 14/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0474 - accuracy: 0.9842 - val_loss: 0.1821 - val_accuracy: 0.9443
#
# Epoch 00014: val_loss did not improve from 0.15097
# Epoch 15/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0452 - accuracy: 0.9851 - val_loss: 0.1898 - val_accuracy: 0.9476
#
# Epoch 00015: val_loss did not improve from 0.15097
# Epoch 16/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0463 - accuracy: 0.9853 - val_loss: 0.1950 - val_accuracy: 0.9492
#
# Epoch 00016: val_loss did not improve from 0.15097
# Epoch 17/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0428 - accuracy: 0.9857 - val_loss: 0.1891 - val_accuracy: 0.9525
#
# Epoch 00017: val_loss did not improve from 0.15097
# Epoch 18/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0399 - accuracy: 0.9868 - val_loss: 0.1802 - val_accuracy: 0.9495
#
# Epoch 00018: val_loss did not improve from 0.15097
# Epoch 19/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 0.1702 - val_accuracy: 0.9503
#
# Epoch 00019: val_loss did not improve from 0.15097
# Epoch 20/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0389 - accuracy: 0.9872 - val_loss: 0.1870 - val_accuracy: 0.9499
#
# Epoch 00020: val_loss did not improve from 0.15097
# Epoch 21/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0362 - accuracy: 0.9876 - val_loss: 0.1781 - val_accuracy: 0.9518
#
# Epoch 00021: val_loss did not improve from 0.15097
# Epoch 22/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0371 - accuracy: 0.9880 - val_loss: 0.1908 - val_accuracy: 0.9473
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.15097
# Epoch 23/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.1880 - val_accuracy: 0.9529
#
# Epoch 00023: val_loss did not improve from 0.15097
# Epoch 24/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0296 - accuracy: 0.9902 - val_loss: 0.1876 - val_accuracy: 0.9492
#
# Epoch 00024: val_loss did not improve from 0.15097
# Epoch 25/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0262 - accuracy: 0.9911 - val_loss: 0.1980 - val_accuracy: 0.9514
#
# Epoch 00025: val_loss did not improve from 0.15097
# Epoch 26/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0273 - accuracy: 0.9908 - val_loss: 0.1940 - val_accuracy: 0.9499
#
# Epoch 00026: val_loss did not improve from 0.15097
# Epoch 27/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.1943 - val_accuracy: 0.9533
#
# Epoch 00027: val_loss did not improve from 0.15097
# Epoch 28/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.2218 - val_accuracy: 0.9507
#
# Epoch 00028: val_loss did not improve from 0.15097
# Epoch 29/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.2025 - val_accuracy: 0.9518
#
# Epoch 00029: val_loss did not improve from 0.15097
# Epoch 30/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0257 - accuracy: 0.9910 - val_loss: 0.2009 - val_accuracy: 0.9525
#
# Epoch 00030: val_loss did not improve from 0.15097
# Epoch 31/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0248 - accuracy: 0.9911 - val_loss: 0.2073 - val_accuracy: 0.9533
#
# Epoch 00031: val_loss did not improve from 0.15097
# Epoch 32/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.2147 - val_accuracy: 0.9514
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.15097
# Epoch 33/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 0.2028 - val_accuracy: 0.9525
#
# Epoch 00033: val_loss did not improve from 0.15097
# Epoch 34/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0209 - accuracy: 0.9924 - val_loss: 0.2098 - val_accuracy: 0.9514
#
# Epoch 00034: val_loss did not improve from 0.15097
# Epoch 35/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 0.2173 - val_accuracy: 0.9518
#
# Epoch 00035: val_loss did not improve from 0.15097
# Score for fold 4: loss of 0.21727588772773743; accuracy of 95.17890810966492%
# Epoch 1/35
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.2142 - accuracy: 0.9380 - val_loss: 0.4601 - val_accuracy: 0.8614
#
# Epoch 00001: val_loss did not improve from 0.15097
# Epoch 2/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1069 - accuracy: 0.9677 - val_loss: 0.2995 - val_accuracy: 0.9058
#
# Epoch 00002: val_loss did not improve from 0.15097
# Epoch 3/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0901 - accuracy: 0.9722 - val_loss: 0.2462 - val_accuracy: 0.9209
#
# Epoch 00003: val_loss did not improve from 0.15097
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0801 - accuracy: 0.9755 - val_loss: 0.2189 - val_accuracy: 0.9281
#
# Epoch 00004: val_loss did not improve from 0.15097
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0724 - accuracy: 0.9776 - val_loss: 0.2014 - val_accuracy: 0.9322
#
# Epoch 00005: val_loss did not improve from 0.15097
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0661 - accuracy: 0.9796 - val_loss: 0.2070 - val_accuracy: 0.9322
#
# Epoch 00006: val_loss did not improve from 0.15097
# Epoch 7/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0612 - accuracy: 0.9805 - val_loss: 0.1914 - val_accuracy: 0.9375
#
# Epoch 00007: val_loss did not improve from 0.15097
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0585 - accuracy: 0.9815 - val_loss: 0.1917 - val_accuracy: 0.9390
#
# Epoch 00008: val_loss did not improve from 0.15097
# Epoch 9/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0541 - accuracy: 0.9826 - val_loss: 0.1783 - val_accuracy: 0.9405
#
# Epoch 00009: val_loss did not improve from 0.15097
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0507 - accuracy: 0.9838 - val_loss: 0.1802 - val_accuracy: 0.9431
#
# Epoch 00010: val_loss did not improve from 0.15097
# Epoch 11/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0472 - accuracy: 0.9846 - val_loss: 0.1834 - val_accuracy: 0.9439
#
# Epoch 00011: val_loss did not improve from 0.15097
# Epoch 12/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0460 - accuracy: 0.9853 - val_loss: 0.1744 - val_accuracy: 0.9424
#
# Epoch 00012: val_loss did not improve from 0.15097
# Epoch 13/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0443 - accuracy: 0.9857 - val_loss: 0.1942 - val_accuracy: 0.9435
#
# Epoch 00013: val_loss did not improve from 0.15097
# Epoch 14/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0438 - accuracy: 0.9860 - val_loss: 0.1776 - val_accuracy: 0.9461
#
# Epoch 00014: val_loss did not improve from 0.15097
# Epoch 15/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0420 - accuracy: 0.9864 - val_loss: 0.1913 - val_accuracy: 0.9443
#
# Epoch 00015: val_loss did not improve from 0.15097
# Epoch 16/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0408 - accuracy: 0.9863 - val_loss: 0.1855 - val_accuracy: 0.9461
#
# Epoch 00016: val_loss did not improve from 0.15097
# Epoch 17/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.1900 - val_accuracy: 0.9469
#
# Epoch 00017: val_loss did not improve from 0.15097
# Epoch 18/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0380 - accuracy: 0.9876 - val_loss: 0.2044 - val_accuracy: 0.9446
#
# Epoch 00018: val_loss did not improve from 0.15097
# Epoch 19/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0386 - accuracy: 0.9873 - val_loss: 0.1923 - val_accuracy: 0.9469
#
# Epoch 00019: val_loss did not improve from 0.15097
# Epoch 20/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0370 - accuracy: 0.9878 - val_loss: 0.2072 - val_accuracy: 0.9465
#
# Epoch 00020: val_loss did not improve from 0.15097
# Epoch 21/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0357 - accuracy: 0.9883 - val_loss: 0.2158 - val_accuracy: 0.9465
#
# Epoch 00021: val_loss did not improve from 0.15097
# Epoch 22/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.2134 - val_accuracy: 0.9443
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.15097
# Epoch 23/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.1974 - val_accuracy: 0.9480
#
# Epoch 00023: val_loss did not improve from 0.15097
# Epoch 24/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0274 - accuracy: 0.9905 - val_loss: 0.2157 - val_accuracy: 0.9484
#
# Epoch 00024: val_loss did not improve from 0.15097
# Epoch 25/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0262 - accuracy: 0.9912 - val_loss: 0.2236 - val_accuracy: 0.9488
#
# Epoch 00025: val_loss did not improve from 0.15097
# Epoch 26/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0250 - accuracy: 0.9918 - val_loss: 0.2215 - val_accuracy: 0.9484
#
# Epoch 00026: val_loss did not improve from 0.15097
# Epoch 27/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.2371 - val_accuracy: 0.9476
#
# Epoch 00027: val_loss did not improve from 0.15097
# Epoch 28/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0237 - accuracy: 0.9921 - val_loss: 0.2444 - val_accuracy: 0.9454
#
# Epoch 00028: val_loss did not improve from 0.15097
# Epoch 29/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0229 - accuracy: 0.9922 - val_loss: 0.2226 - val_accuracy: 0.9476
#
# Epoch 00029: val_loss did not improve from 0.15097
# Epoch 30/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0248 - accuracy: 0.9917 - val_loss: 0.2278 - val_accuracy: 0.9495
#
# Epoch 00030: val_loss did not improve from 0.15097
# Epoch 31/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0228 - accuracy: 0.9924 - val_loss: 0.2397 - val_accuracy: 0.9492
#
# Epoch 00031: val_loss did not improve from 0.15097
# Epoch 32/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0227 - accuracy: 0.9922 - val_loss: 0.2191 - val_accuracy: 0.9503
#
# Epoch 00032: val_loss did not improve from 0.15097
# Epoch 33/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.2313 - val_accuracy: 0.9458
#
# Epoch 00033: val_loss did not improve from 0.15097
# Epoch 34/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.2491 - val_accuracy: 0.9503
#
# Epoch 00034: val_loss did not improve from 0.15097
# Epoch 35/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.2451 - val_accuracy: 0.9492
#
# Epoch 00035: val_loss did not improve from 0.15097
# Score for fold 5: loss of 0.24509896337985992; accuracy of 94.91525292396545%
# Epoch 1/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.2121 - accuracy: 0.9379 - val_loss: 0.3104 - val_accuracy: 0.9070
#
# Epoch 00001: val_loss did not improve from 0.15097
# Epoch 2/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.1067 - accuracy: 0.9674 - val_loss: 0.2156 - val_accuracy: 0.9458
#
# Epoch 00002: val_loss did not improve from 0.15097
# Epoch 3/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0875 - accuracy: 0.9727 - val_loss: 0.1707 - val_accuracy: 0.9495
#
# Epoch 00003: val_loss did not improve from 0.15097
# Epoch 4/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0771 - accuracy: 0.9755 - val_loss: 0.1620 - val_accuracy: 0.9503
#
# Epoch 00004: val_loss did not improve from 0.15097
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0711 - accuracy: 0.9779 - val_loss: 0.1481 - val_accuracy: 0.9559
#
# Epoch 00005: val_loss improved from 0.15097 to 0.14809, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0640 - accuracy: 0.9796 - val_loss: 0.1503 - val_accuracy: 0.9537
#
# Epoch 00006: val_loss did not improve from 0.14809
# Epoch 7/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0602 - accuracy: 0.9807 - val_loss: 0.1552 - val_accuracy: 0.9559
#
# Epoch 00007: val_loss did not improve from 0.14809
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0572 - accuracy: 0.9817 - val_loss: 0.1505 - val_accuracy: 0.9567
#
# Epoch 00008: val_loss did not improve from 0.14809
# Epoch 9/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0531 - accuracy: 0.9827 - val_loss: 0.1604 - val_accuracy: 0.9582
#
# Epoch 00009: val_loss did not improve from 0.14809
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0501 - accuracy: 0.9840 - val_loss: 0.1355 - val_accuracy: 0.9608
#
# Epoch 00010: val_loss improved from 0.14809 to 0.13548, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 11/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0472 - accuracy: 0.9844 - val_loss: 0.1534 - val_accuracy: 0.9589
#
# Epoch 00011: val_loss did not improve from 0.13548
# Epoch 12/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0448 - accuracy: 0.9852 - val_loss: 0.1477 - val_accuracy: 0.9623
#
# Epoch 00012: val_loss did not improve from 0.13548
# Epoch 13/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0428 - accuracy: 0.9863 - val_loss: 0.1419 - val_accuracy: 0.9605
#
# Epoch 00013: val_loss did not improve from 0.13548
# Epoch 14/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0412 - accuracy: 0.9866 - val_loss: 0.1428 - val_accuracy: 0.9601
#
# Epoch 00014: val_loss did not improve from 0.13548
# Epoch 15/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.1323 - val_accuracy: 0.9635
#
# Epoch 00015: val_loss improved from 0.13548 to 0.13228, saving model to /Users/Max/Documents/GitHub/cross_validation/cgan-cnn-local-v001\model.h5
# Epoch 16/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0393 - accuracy: 0.9873 - val_loss: 0.1465 - val_accuracy: 0.9638
#
# Epoch 00016: val_loss did not improve from 0.13228
# Epoch 17/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.1451 - val_accuracy: 0.9653
#
# Epoch 00017: val_loss did not improve from 0.13228
# Epoch 18/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0377 - accuracy: 0.9877 - val_loss: 0.1624 - val_accuracy: 0.9601
#
# Epoch 00018: val_loss did not improve from 0.13228
# Epoch 19/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0378 - accuracy: 0.9877 - val_loss: 0.1523 - val_accuracy: 0.9635
#
# Epoch 00019: val_loss did not improve from 0.13228
# Epoch 20/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0346 - accuracy: 0.9888 - val_loss: 0.1728 - val_accuracy: 0.9650
#
# Epoch 00020: val_loss did not improve from 0.13228
# Epoch 21/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0342 - accuracy: 0.9887 - val_loss: 0.1460 - val_accuracy: 0.9635
#
# Epoch 00021: val_loss did not improve from 0.13228
# Epoch 22/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0326 - accuracy: 0.9893 - val_loss: 0.2196 - val_accuracy: 0.9567
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.13228
# Epoch 23/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0278 - accuracy: 0.9905 - val_loss: 0.1471 - val_accuracy: 0.9661
#
# Epoch 00023: val_loss did not improve from 0.13228
# Epoch 24/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0257 - accuracy: 0.9916 - val_loss: 0.1492 - val_accuracy: 0.9657
#
# Epoch 00024: val_loss did not improve from 0.13228
# Epoch 25/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.1658 - val_accuracy: 0.9642
#
# Epoch 00025: val_loss did not improve from 0.13228
# Epoch 26/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.1634 - val_accuracy: 0.9650
#
# Epoch 00026: val_loss did not improve from 0.13228
# Epoch 27/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.1827 - val_accuracy: 0.9657
#
# Epoch 00027: val_loss did not improve from 0.13228
# Epoch 28/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.1770 - val_accuracy: 0.9657
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.13228
# Epoch 29/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0223 - accuracy: 0.9921 - val_loss: 0.1778 - val_accuracy: 0.9646
#
# Epoch 00029: val_loss did not improve from 0.13228
# Epoch 30/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.1633 - val_accuracy: 0.9661
#
# Epoch 00030: val_loss did not improve from 0.13228
# Epoch 31/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0196 - accuracy: 0.9932 - val_loss: 0.1823 - val_accuracy: 0.9672
#
# Epoch 00031: val_loss did not improve from 0.13228
# Epoch 32/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0207 - accuracy: 0.9929 - val_loss: 0.1741 - val_accuracy: 0.9657
#
# Epoch 00032: val_loss did not improve from 0.13228
# Epoch 33/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0187 - accuracy: 0.9934 - val_loss: 0.1905 - val_accuracy: 0.9661
#
# Epoch 00033: val_loss did not improve from 0.13228
# Epoch 34/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.1834 - val_accuracy: 0.9665
#
# Epoch 00034: val_loss did not improve from 0.13228
# Epoch 35/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.1699 - val_accuracy: 0.9650
#
# Epoch 00035: val_loss did not improve from 0.13228
# Score for fold 6: loss of 0.16986314952373505; accuracy of 96.49717807769775%
# Epoch 1/35
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.2106 - accuracy: 0.9391 - val_loss: 0.2543 - val_accuracy: 0.9277
#
# Epoch 00001: val_loss did not improve from 0.13228
# Epoch 2/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1035 - accuracy: 0.9687 - val_loss: 0.2208 - val_accuracy: 0.9360
#
# Epoch 00002: val_loss did not improve from 0.13228
# Epoch 3/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0864 - accuracy: 0.9731 - val_loss: 0.1920 - val_accuracy: 0.9465
#
# Epoch 00003: val_loss did not improve from 0.13228
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0767 - accuracy: 0.9764 - val_loss: 0.1802 - val_accuracy: 0.9476
#
# Epoch 00004: val_loss did not improve from 0.13228
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0692 - accuracy: 0.9782 - val_loss: 0.2080 - val_accuracy: 0.9458
#
# Epoch 00005: val_loss did not improve from 0.13228
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0636 - accuracy: 0.9795 - val_loss: 0.1601 - val_accuracy: 0.9495
#
# Epoch 00006: val_loss did not improve from 0.13228
# Epoch 7/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0602 - accuracy: 0.9806 - val_loss: 0.1607 - val_accuracy: 0.9518
#
# Epoch 00007: val_loss did not improve from 0.13228
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0560 - accuracy: 0.9821 - val_loss: 0.1648 - val_accuracy: 0.9525
#
# Epoch 00008: val_loss did not improve from 0.13228
# Epoch 9/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0528 - accuracy: 0.9834 - val_loss: 0.1561 - val_accuracy: 0.9574
#
# Epoch 00009: val_loss did not improve from 0.13228
# Epoch 10/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0503 - accuracy: 0.9836 - val_loss: 0.1623 - val_accuracy: 0.9537
#
# Epoch 00010: val_loss did not improve from 0.13228
# Epoch 11/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0472 - accuracy: 0.9843 - val_loss: 0.1579 - val_accuracy: 0.9559
#
# Epoch 00011: val_loss did not improve from 0.13228
# Epoch 12/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0456 - accuracy: 0.9854 - val_loss: 0.1604 - val_accuracy: 0.9571
#
# Epoch 00012: val_loss did not improve from 0.13228
# Epoch 13/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0421 - accuracy: 0.9862 - val_loss: 0.1525 - val_accuracy: 0.9608
#
# Epoch 00013: val_loss did not improve from 0.13228
# Epoch 14/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0430 - accuracy: 0.9862 - val_loss: 0.1661 - val_accuracy: 0.9571
#
# Epoch 00014: val_loss did not improve from 0.13228
# Epoch 15/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0397 - accuracy: 0.9868 - val_loss: 0.1736 - val_accuracy: 0.9563
#
# Epoch 00015: val_loss did not improve from 0.13228
# Epoch 16/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0401 - accuracy: 0.9872 - val_loss: 0.1559 - val_accuracy: 0.9593
#
# Epoch 00016: val_loss did not improve from 0.13228
# Epoch 17/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0390 - accuracy: 0.9875 - val_loss: 0.1437 - val_accuracy: 0.9593
#
# Epoch 00017: val_loss did not improve from 0.13228
# Epoch 18/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0365 - accuracy: 0.9879 - val_loss: 0.1596 - val_accuracy: 0.9605
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.13228
# Epoch 19/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.1530 - val_accuracy: 0.9582
#
# ...
#
# Epoch 00029: val_loss did not improve from 0.13228
# Epoch 30/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.2491 - val_accuracy: 0.9522
#
# Epoch 00030: val_loss did not improve from 0.13228
# Epoch 31/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.2398 - val_accuracy: 0.9537
#
# Epoch 00031: val_loss did not improve from 0.13228
# Epoch 32/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.2611 - val_accuracy: 0.9533
#
# Epoch 00032: val_loss did not improve from 0.13228
# Epoch 33/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.2558 - val_accuracy: 0.9537
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.13228
# Epoch 34/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0185 - accuracy: 0.9936 - val_loss: 0.2568 - val_accuracy: 0.9540
#
# Epoch 00034: val_loss did not improve from 0.13228
# Epoch 35/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.2418 - val_accuracy: 0.9522
#
# Epoch 00035: val_loss did not improve from 0.13228
# Score for fold 8: loss of 0.24175266921520233; accuracy of 95.21657228469849%
# Epoch 1/35
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.2128 - accuracy: 0.9386 - val_loss: 0.2882 - val_accuracy: 0.9126
#
# Epoch 00001: val_loss did not improve from 0.13228
# Epoch 2/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.1081 - accuracy: 0.9683 - val_loss: 0.2948 - val_accuracy: 0.9137
#
# Epoch 00002: val_loss did not improve from 0.13228
# Epoch 3/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0914 - accuracy: 0.9722 - val_loss: 0.2123 - val_accuracy: 0.9310
#
# Epoch 00003: val_loss did not improve from 0.13228
# Epoch 4/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0798 - accuracy: 0.9752 - val_loss: 0.2130 - val_accuracy: 0.9310
#
# Epoch 00004: val_loss did not improve from 0.13228
# Epoch 5/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0737 - accuracy: 0.9771 - val_loss: 0.1909 - val_accuracy: 0.9378
#
# Epoch 00005: val_loss did not improve from 0.13228
# Epoch 6/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0666 - accuracy: 0.9793 - val_loss: 0.1784 - val_accuracy: 0.9412
#
# Epoch 00006: val_loss did not improve from 0.13228
# Epoch 7/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0632 - accuracy: 0.9798 - val_loss: 0.1725 - val_accuracy: 0.9431
#
# Epoch 00007: val_loss did not improve from 0.13228
# Epoch 8/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0569 - accuracy: 0.9818 - val_loss: 0.1573 - val_accuracy: 0.9480
#
# Epoch 00008: val_loss did not improve from 0.13228
# Epoch 9/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0547 - accuracy: 0.9821 - val_loss: 0.1643 - val_accuracy: 0.9450
#
# Epoch 00009: val_loss did not improve from 0.13228
# Epoch 10/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0513 - accuracy: 0.9837 - val_loss: 0.1796 - val_accuracy: 0.9472
#
# Epoch 00010: val_loss did not improve from 0.13228
# Epoch 11/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0481 - accuracy: 0.9844 - val_loss: 0.1713 - val_accuracy: 0.9503
#
# Epoch 00011: val_loss did not improve from 0.13228
# Epoch 12/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0487 - accuracy: 0.9843 - val_loss: 0.1682 - val_accuracy: 0.9499
#
# Epoch 00012: val_loss did not improve from 0.13228
# Epoch 13/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0438 - accuracy: 0.9857 - val_loss: 0.1703 - val_accuracy: 0.9503
#
# Epoch 00013: val_loss did not improve from 0.13228
# Epoch 14/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0437 - accuracy: 0.9860 - val_loss: 0.1822 - val_accuracy: 0.9472
#
# Epoch 00014: val_loss did not improve from 0.13228
# Epoch 15/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0409 - accuracy: 0.9865 - val_loss: 0.1613 - val_accuracy: 0.9499
#
# Epoch 00015: val_loss did not improve from 0.13228
# Epoch 16/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0405 - accuracy: 0.9867 - val_loss: 0.1579 - val_accuracy: 0.9503
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.13228
# Epoch 17/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0315 - accuracy: 0.9896 - val_loss: 0.1667 - val_accuracy: 0.9506
#
# Epoch 00017: val_loss did not improve from 0.13228
# Epoch 18/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0323 - accuracy: 0.9894 - val_loss: 0.1793 - val_accuracy: 0.9537
#
# Epoch 00018: val_loss did not improve from 0.13228
# Epoch 19/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0303 - accuracy: 0.9902 - val_loss: 0.1679 - val_accuracy: 0.9518
#
# Epoch 00019: val_loss did not improve from 0.13228
# Epoch 20/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0287 - accuracy: 0.9904 - val_loss: 0.1632 - val_accuracy: 0.9540
#
# Epoch 00020: val_loss did not improve from 0.13228
# Epoch 21/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.1825 - val_accuracy: 0.9506
#
# Epoch 00021: val_loss did not improve from 0.13228
# Epoch 22/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0275 - accuracy: 0.9911 - val_loss: 0.1760 - val_accuracy: 0.9518
#
# Epoch 00022: val_loss did not improve from 0.13228
# Epoch 23/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.1938 - val_accuracy: 0.9510
#
# Epoch 00023: val_loss did not improve from 0.13228
# Epoch 24/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0259 - accuracy: 0.9914 - val_loss: 0.2001 - val_accuracy: 0.9525
#
# Epoch 00024: val_loss did not improve from 0.13228
# Epoch 25/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.1887 - val_accuracy: 0.9514
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.13228
# Epoch 26/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.1904 - val_accuracy: 0.9518
#
# Epoch 00026: val_loss did not improve from 0.13228
# Epoch 27/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.1858 - val_accuracy: 0.9529
#
# Epoch 00027: val_loss did not improve from 0.13228
# Epoch 28/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.1861 - val_accuracy: 0.9533
#
# Epoch 00028: val_loss did not improve from 0.13228
# Epoch 29/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.1934 - val_accuracy: 0.9537
#
# Epoch 00029: val_loss did not improve from 0.13228
# Epoch 30/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.2129 - val_accuracy: 0.9533
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.13228
# Epoch 31/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0204 - accuracy: 0.9929 - val_loss: 0.2062 - val_accuracy: 0.9514
#
# Epoch 00031: val_loss did not improve from 0.13228
# Epoch 32/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.1962 - val_accuracy: 0.9510
#
# Epoch 00032: val_loss did not improve from 0.13228
# Epoch 33/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.2118 - val_accuracy: 0.9521
#
# Epoch 00033: val_loss did not improve from 0.13228
# Epoch 34/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.2087 - val_accuracy: 0.9533
#
# Epoch 00034: val_loss did not improve from 0.13228
# Epoch 35/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.2132 - val_accuracy: 0.9518
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.13228
# Score for fold 9: loss of 0.21320413053035736; accuracy of 95.17709016799927%
# Epoch 1/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.2170 - accuracy: 0.9357 - val_loss: 0.2940 - val_accuracy: 0.9133
#
# Epoch 00001: val_loss did not improve from 0.13228
# Epoch 2/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.1121 - accuracy: 0.9671 - val_loss: 0.2448 - val_accuracy: 0.9288
#
# Epoch 00002: val_loss did not improve from 0.13228
# Epoch 3/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0949 - accuracy: 0.9714 - val_loss: 0.2262 - val_accuracy: 0.9314
#
# Epoch 00003: val_loss did not improve from 0.13228
# Epoch 4/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0828 - accuracy: 0.9743 - val_loss: 0.2152 - val_accuracy: 0.9314
#
# Epoch 00004: val_loss did not improve from 0.13228
# Epoch 5/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0744 - accuracy: 0.9765 - val_loss: 0.2051 - val_accuracy: 0.9363
#
# Epoch 00005: val_loss did not improve from 0.13228
# Epoch 6/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0675 - accuracy: 0.9781 - val_loss: 0.1931 - val_accuracy: 0.9408
#
# Epoch 00006: val_loss did not improve from 0.13228
# Epoch 7/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0636 - accuracy: 0.9794 - val_loss: 0.1970 - val_accuracy: 0.9412
#
# Epoch 00007: val_loss did not improve from 0.13228
# Epoch 8/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0597 - accuracy: 0.9806 - val_loss: 0.1961 - val_accuracy: 0.9431
#
# Epoch 00008: val_loss did not improve from 0.13228
# Epoch 9/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0562 - accuracy: 0.9812 - val_loss: 0.1919 - val_accuracy: 0.9465
#
# Epoch 00009: val_loss did not improve from 0.13228
# Epoch 10/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0531 - accuracy: 0.9825 - val_loss: 0.1979 - val_accuracy: 0.9450
#
# Epoch 00010: val_loss did not improve from 0.13228
# Epoch 11/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0501 - accuracy: 0.9835 - val_loss: 0.1957 - val_accuracy: 0.9450
#
# Epoch 00011: val_loss did not improve from 0.13228
# Epoch 12/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0465 - accuracy: 0.9851 - val_loss: 0.2400 - val_accuracy: 0.9427
#
# Epoch 00012: val_loss did not improve from 0.13228
# Epoch 13/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0458 - accuracy: 0.9849 - val_loss: 0.1909 - val_accuracy: 0.9465
#
# Epoch 00013: val_loss did not improve from 0.13228
# Epoch 14/35
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0448 - accuracy: 0.9855 - val_loss: 0.1892 - val_accuracy: 0.9461
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.13228
# Epoch 15/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 0.2001 - val_accuracy: 0.9491
#
# Epoch 00015: val_loss did not improve from 0.13228
# Epoch 16/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.2037 - val_accuracy: 0.9503
#
# Epoch 00016: val_loss did not improve from 0.13228
# Epoch 17/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0320 - accuracy: 0.9892 - val_loss: 0.2560 - val_accuracy: 0.9476
#
# Epoch 00017: val_loss did not improve from 0.13228
# Epoch 18/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0307 - accuracy: 0.9898 - val_loss: 0.2189 - val_accuracy: 0.9510
#
# Epoch 00018: val_loss did not improve from 0.13228
# Epoch 19/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0287 - accuracy: 0.9900 - val_loss: 0.2306 - val_accuracy: 0.9480
#
# Epoch 00019: val_loss did not improve from 0.13228
# Epoch 20/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.2187 - val_accuracy: 0.9506
#
# Epoch 00020: val_loss did not improve from 0.13228
# Epoch 21/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0281 - accuracy: 0.9904 - val_loss: 0.2243 - val_accuracy: 0.9506
#
# Epoch 00021: val_loss did not improve from 0.13228
# Epoch 22/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.2355 - val_accuracy: 0.9506
#
# Epoch 00022: val_loss did not improve from 0.13228
# Epoch 23/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0279 - accuracy: 0.9906 - val_loss: 0.2624 - val_accuracy: 0.9503
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_loss did not improve from 0.13228
# Epoch 24/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 0.2316 - val_accuracy: 0.9529
#
# Epoch 00024: val_loss did not improve from 0.13228
# Epoch 25/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.2620 - val_accuracy: 0.9499
#
# Epoch 00025: val_loss did not improve from 0.13228
# Epoch 26/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.2435 - val_accuracy: 0.9514
#
# Epoch 00026: val_loss did not improve from 0.13228
# Epoch 27/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.2616 - val_accuracy: 0.9514
#
# Epoch 00027: val_loss did not improve from 0.13228
# Epoch 28/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.2658 - val_accuracy: 0.9514
#
# Epoch 00028: val_loss did not improve from 0.13228
# Epoch 29/35
# 2076/2076 [==============================] - 11s 6ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.2576 - val_accuracy: 0.9499
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.13228
# Epoch 30/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.2589 - val_accuracy: 0.9525
#
# Epoch 00030: val_loss did not improve from 0.13228
# Epoch 31/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0200 - accuracy: 0.9929 - val_loss: 0.2712 - val_accuracy: 0.9510
#
# Epoch 00031: val_loss did not improve from 0.13228
# Epoch 32/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.2561 - val_accuracy: 0.9544
#
# Epoch 00032: val_loss did not improve from 0.13228
# Epoch 33/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.2562 - val_accuracy: 0.9514
#
# Epoch 00033: val_loss did not improve from 0.13228
# Epoch 34/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.2721 - val_accuracy: 0.9529
#
# Epoch 00034: val_loss did not improve from 0.13228
# Epoch 35/35
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0190 - accuracy: 0.9934 - val_loss: 0.2704 - val_accuracy: 0.9503
#
# Epoch 00035: val_loss did not improve from 0.13228
# Score for fold 10: loss of 0.27041855454444885; accuracy of 95.02637386322021%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.20893380045890808 - Accuracy: 95.70621252059937%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.21753382682800293 - Accuracy: 95.6685483455658%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.23867690563201904 - Accuracy: 95.25423645973206%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.21727588772773743 - Accuracy: 95.17890810966492%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.24509896337985992 - Accuracy: 94.91525292396545%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.16986314952373505 - Accuracy: 96.49717807769775%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.17980028688907623 - Accuracy: 96.27118706703186%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.24175266921520233 - Accuracy: 95.21657228469849%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.21320413053035736 - Accuracy: 95.17709016799927%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.27041855454444885 - Accuracy: 95.02637386322021%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.49115598201752% (+- 0.005073062391142079)
# > Loss: 0.2202558174729347
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph (I will use around 20% of cases for benign for and the remaining 80% equally distributed across the 10 ransomware families)

# %%
np.array(train_distr)
# Out:
# array([[ 9.10856506,  9.31633068,  7.75056082,  7.77013294,  7.60452267,
#          8.25642493,  7.85594917,  8.29858027,  7.60602821,  7.49913431,
#         18.93377095],
#        [ 9.13566493,  9.30428629,  7.73249424,  7.73399979,  7.62108369,
#          8.28804143,  7.84089369,  8.30309691,  7.58495054,  7.47805664,
#         18.97743184],
#        [ 9.05135424,  9.35848602,  7.76862739,  7.74303308,  7.58495054,
#          8.25491938,  7.84842143,  8.2744915 ,  7.59247828,  7.49311212,
#         19.03012601],
#        [ 9.10103732,  9.33439725,  7.74303308,  7.75658301,  7.58796164,
#          8.28352479,  7.85594917,  8.29858027,  7.56838952,  7.48558438,
#         18.98495958],
#        [ 9.1537315 ,  9.3389139 ,  7.74754972,  7.70087773,  7.60753376,
#          8.25341383,  7.82433267,  8.28051369,  7.5774228 ,  7.47956219,
#         19.03614821],
#        [ 9.09953177,  9.37956369,  7.73851643,  7.77766068,  7.60602821,
#          8.25943602,  7.84541034,  8.30460246,  7.58495054,  7.48708993,
#         18.91720992],
#        [ 9.10103732,  9.34343054,  7.73550534,  7.77314404,  7.59398383,
#          8.25943602,  7.84390479,  8.27298595,  7.59097273,  7.47655109,
#         19.00904834],
#        [ 9.12813719,  9.31482513,  7.76712184,  7.74604417,  7.60753376,
#          8.23384171,  7.86197136,  8.30309691,  7.58193945,  7.47353999,
#         18.98194848],
#        [ 9.10391135,  9.34178435,  7.73237783,  7.71732257,  7.59537503,
#          8.28340008,  7.85733642,  8.29393876,  7.5758032 ,  7.49149378,
#         19.00725663],
#        [ 9.09638373,  9.35232303,  7.73538888,  7.75797176,  7.60892475,
#          8.27436693,  7.82722592,  8.29845533,  7.58935293,  7.47643853,
#         18.98316823]])

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN - CNN"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of CGAN - CNN       |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9549      | 0.0051       |
# | Loss     | 0.2203      | 0.0288       |
# | Macro F1 | 0.8831      | 0.0105       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9784      | 0.0042       |
# | Acc      | 0.9834      | 0.0018       |
# | F1       | 0.9843      | 0.0018       |
# | MCC      | 0.9667      | 0.0037       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
