# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 35

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cross_validation/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 1 matches(es) found
# --------------
# New folder name: cnn-local-v002
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 252

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5740 - accuracy: 0.8262 - val_loss: 0.4000 - val_accuracy: 0.8716
#
# Epoch 00001: val_loss improved from inf to 0.40001, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 2/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3180 - accuracy: 0.9004 - val_loss: 0.2610 - val_accuracy: 0.9156
#
# Epoch 00002: val_loss improved from 0.40001 to 0.26099, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 3/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2644 - accuracy: 0.9173 - val_loss: 0.2370 - val_accuracy: 0.9247
#
# Epoch 00003: val_loss improved from 0.26099 to 0.23700, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2394 - accuracy: 0.9228 - val_loss: 0.2173 - val_accuracy: 0.9330
#
# Epoch 00004: val_loss improved from 0.23700 to 0.21732, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 5/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2187 - accuracy: 0.9307 - val_loss: 0.2055 - val_accuracy: 0.9379
#
# Epoch 00005: val_loss improved from 0.21732 to 0.20554, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2055 - accuracy: 0.9342 - val_loss: 0.1968 - val_accuracy: 0.9390
#
# Epoch 00006: val_loss improved from 0.20554 to 0.19682, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1945 - accuracy: 0.9366 - val_loss: 0.1930 - val_accuracy: 0.9412
#
# Epoch 00007: val_loss improved from 0.19682 to 0.19304, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1818 - accuracy: 0.9418 - val_loss: 0.1926 - val_accuracy: 0.9401
#
# Epoch 00008: val_loss improved from 0.19304 to 0.19256, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1721 - accuracy: 0.9440 - val_loss: 0.1808 - val_accuracy: 0.9465
#
# Epoch 00009: val_loss improved from 0.19256 to 0.18081, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 10/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1657 - accuracy: 0.9453 - val_loss: 0.1900 - val_accuracy: 0.9431
#
# Epoch 00010: val_loss did not improve from 0.18081
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1580 - accuracy: 0.9490 - val_loss: 0.1795 - val_accuracy: 0.9431
#
# Epoch 00011: val_loss improved from 0.18081 to 0.17948, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 12/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1476 - accuracy: 0.9516 - val_loss: 0.2026 - val_accuracy: 0.9341
#
# Epoch 00012: val_loss did not improve from 0.17948
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1438 - accuracy: 0.9517 - val_loss: 0.1859 - val_accuracy: 0.9439
#
# Epoch 00013: val_loss did not improve from 0.17948
# Epoch 14/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1357 - accuracy: 0.9552 - val_loss: 0.1800 - val_accuracy: 0.9469
#
# Epoch 00014: val_loss did not improve from 0.17948
# Epoch 15/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1306 - accuracy: 0.9563 - val_loss: 0.1765 - val_accuracy: 0.9492
#
# Epoch 00015: val_loss improved from 0.17948 to 0.17655, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 16/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1274 - accuracy: 0.9586 - val_loss: 0.1758 - val_accuracy: 0.9495
#
# Epoch 00016: val_loss improved from 0.17655 to 0.17576, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1244 - accuracy: 0.9587 - val_loss: 0.1895 - val_accuracy: 0.9476
#
# Epoch 00017: val_loss did not improve from 0.17576
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1200 - accuracy: 0.9607 - val_loss: 0.1759 - val_accuracy: 0.9484
#
# Epoch 00018: val_loss did not improve from 0.17576
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1141 - accuracy: 0.9630 - val_loss: 0.1873 - val_accuracy: 0.9465
#
# Epoch 00019: val_loss did not improve from 0.17576
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1095 - accuracy: 0.9639 - val_loss: 0.1800 - val_accuracy: 0.9510
#
# Epoch 00020: val_loss did not improve from 0.17576
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1065 - accuracy: 0.9636 - val_loss: 0.1789 - val_accuracy: 0.9476
#
# Epoch 00021: val_loss did not improve from 0.17576
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1050 - accuracy: 0.9655 - val_loss: 0.1844 - val_accuracy: 0.9525
#
# Epoch 00022: val_loss did not improve from 0.17576
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0984 - accuracy: 0.9678 - val_loss: 0.1805 - val_accuracy: 0.9518
#
# Epoch 00023: val_loss did not improve from 0.17576
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1008 - accuracy: 0.9661 - val_loss: 0.1887 - val_accuracy: 0.9537
#
# Epoch 00024: val_loss did not improve from 0.17576
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0976 - accuracy: 0.9678 - val_loss: 0.1818 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.17576
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0939 - accuracy: 0.9686 - val_loss: 0.2074 - val_accuracy: 0.9537
#
# Epoch 00026: val_loss did not improve from 0.17576
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0940 - accuracy: 0.9689 - val_loss: 0.1960 - val_accuracy: 0.9537
#
# Epoch 00027: val_loss did not improve from 0.17576
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0863 - accuracy: 0.9708 - val_loss: 0.1960 - val_accuracy: 0.9499
#
# Epoch 00028: val_loss did not improve from 0.17576
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0871 - accuracy: 0.9708 - val_loss: 0.1925 - val_accuracy: 0.9522
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00029: val_loss did not improve from 0.17576
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0754 - accuracy: 0.9747 - val_loss: 0.2006 - val_accuracy: 0.9537
#
# Epoch 00030: val_loss did not improve from 0.17576
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0747 - accuracy: 0.9754 - val_loss: 0.1933 - val_accuracy: 0.9540
#
# Epoch 00031: val_loss did not improve from 0.17576
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0723 - accuracy: 0.9755 - val_loss: 0.2022 - val_accuracy: 0.9525
#
# Epoch 00032: val_loss did not improve from 0.17576
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0719 - accuracy: 0.9761 - val_loss: 0.1909 - val_accuracy: 0.9540
#
# Epoch 00033: val_loss did not improve from 0.17576
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0691 - accuracy: 0.9764 - val_loss: 0.2033 - val_accuracy: 0.9522
#
# Epoch 00034: val_loss did not improve from 0.17576
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0652 - accuracy: 0.9785 - val_loss: 0.2089 - val_accuracy: 0.9533
#
# Epoch 00035: val_loss did not improve from 0.17576
# Score for fold 1: loss of 0.20893573760986328; accuracy of 95.3295648097992%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5600 - accuracy: 0.8330 - val_loss: 0.3588 - val_accuracy: 0.8742
#
# Epoch 00001: val_loss did not improve from 0.17576
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2993 - accuracy: 0.9064 - val_loss: 0.2609 - val_accuracy: 0.9156
#
# Epoch 00002: val_loss did not improve from 0.17576
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2504 - accuracy: 0.9206 - val_loss: 0.2380 - val_accuracy: 0.9217
#
# Epoch 00003: val_loss did not improve from 0.17576
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2298 - accuracy: 0.9267 - val_loss: 0.2223 - val_accuracy: 0.9299
#
# Epoch 00004: val_loss did not improve from 0.17576
# Epoch 5/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2120 - accuracy: 0.9315 - val_loss: 0.2121 - val_accuracy: 0.9326
#
# Epoch 00005: val_loss did not improve from 0.17576
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1944 - accuracy: 0.9374 - val_loss: 0.2144 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.17576
# Epoch 7/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1828 - accuracy: 0.9419 - val_loss: 0.2062 - val_accuracy: 0.9371
#
# Epoch 00007: val_loss did not improve from 0.17576
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1708 - accuracy: 0.9443 - val_loss: 0.2091 - val_accuracy: 0.9371
#
# Epoch 00008: val_loss did not improve from 0.17576
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1624 - accuracy: 0.9477 - val_loss: 0.1869 - val_accuracy: 0.9446
#
# Epoch 00009: val_loss did not improve from 0.17576
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1530 - accuracy: 0.9491 - val_loss: 0.2236 - val_accuracy: 0.9416
#
# Epoch 00010: val_loss did not improve from 0.17576
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1526 - accuracy: 0.9503 - val_loss: 0.2021 - val_accuracy: 0.9412
#
# Epoch 00011: val_loss did not improve from 0.17576
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1405 - accuracy: 0.9532 - val_loss: 0.2009 - val_accuracy: 0.9458
#
# Epoch 00012: val_loss did not improve from 0.17576
# Epoch 13/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1314 - accuracy: 0.9559 - val_loss: 0.2052 - val_accuracy: 0.9469
#
# Epoch 00013: val_loss did not improve from 0.17576
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1281 - accuracy: 0.9573 - val_loss: 0.1899 - val_accuracy: 0.9461
#
# Epoch 00014: val_loss did not improve from 0.17576
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1256 - accuracy: 0.9593 - val_loss: 0.1816 - val_accuracy: 0.9499
#
# Epoch 00015: val_loss did not improve from 0.17576
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1216 - accuracy: 0.9595 - val_loss: 0.1882 - val_accuracy: 0.9473
#
# Epoch 00016: val_loss did not improve from 0.17576
# Epoch 17/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1184 - accuracy: 0.9607 - val_loss: 0.1876 - val_accuracy: 0.9499
#
# Epoch 00017: val_loss did not improve from 0.17576
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1126 - accuracy: 0.9624 - val_loss: 0.2019 - val_accuracy: 0.9484
#
# Epoch 00018: val_loss did not improve from 0.17576
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1044 - accuracy: 0.9651 - val_loss: 0.2004 - val_accuracy: 0.9469
#
# Epoch 00019: val_loss did not improve from 0.17576
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1082 - accuracy: 0.9643 - val_loss: 0.2058 - val_accuracy: 0.9484
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.17576
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0888 - accuracy: 0.9706 - val_loss: 0.2060 - val_accuracy: 0.9495
#
# Epoch 00021: val_loss did not improve from 0.17576
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0884 - accuracy: 0.9702 - val_loss: 0.2128 - val_accuracy: 0.9514
#
# Epoch 00022: val_loss did not improve from 0.17576
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0838 - accuracy: 0.9712 - val_loss: 0.2201 - val_accuracy: 0.9480
#
# Epoch 00023: val_loss did not improve from 0.17576
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0834 - accuracy: 0.9710 - val_loss: 0.2123 - val_accuracy: 0.9529
#
# Epoch 00024: val_loss did not improve from 0.17576
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0815 - accuracy: 0.9721 - val_loss: 0.2046 - val_accuracy: 0.9529
#
# Epoch 00025: val_loss did not improve from 0.17576
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0788 - accuracy: 0.9731 - val_loss: 0.2299 - val_accuracy: 0.9492
#
# Epoch 00026: val_loss did not improve from 0.17576
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0780 - accuracy: 0.9745 - val_loss: 0.2438 - val_accuracy: 0.9484
#
# Epoch 00027: val_loss did not improve from 0.17576
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0743 - accuracy: 0.9747 - val_loss: 0.2336 - val_accuracy: 0.9533
#
# Epoch 00028: val_loss did not improve from 0.17576
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0754 - accuracy: 0.9740 - val_loss: 0.2224 - val_accuracy: 0.9522
#
# Epoch 00029: val_loss did not improve from 0.17576
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0734 - accuracy: 0.9746 - val_loss: 0.2308 - val_accuracy: 0.9529
#
# Epoch 00030: val_loss did not improve from 0.17576
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0703 - accuracy: 0.9757 - val_loss: 0.2396 - val_accuracy: 0.9537
#
# Epoch 00031: val_loss did not improve from 0.17576
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0734 - accuracy: 0.9749 - val_loss: 0.2394 - val_accuracy: 0.9522
#
# Epoch 00032: val_loss did not improve from 0.17576
# Epoch 33/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0713 - accuracy: 0.9758 - val_loss: 0.2514 - val_accuracy: 0.9469
#
# Epoch 00033: val_loss did not improve from 0.17576
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0703 - accuracy: 0.9765 - val_loss: 0.2348 - val_accuracy: 0.9537
#
# Epoch 00034: val_loss did not improve from 0.17576
# Epoch 35/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0659 - accuracy: 0.9773 - val_loss: 0.2412 - val_accuracy: 0.9518
#
# Epoch 00035: val_loss did not improve from 0.17576
# Score for fold 2: loss of 0.24118348956108093; accuracy of 95.17890810966492%
# Epoch 1/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.5810 - accuracy: 0.8276 - val_loss: 0.3290 - val_accuracy: 0.8900
#
# Epoch 00001: val_loss did not improve from 0.17576
# Epoch 2/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3381 - accuracy: 0.8962 - val_loss: 0.2568 - val_accuracy: 0.9250
#
# Epoch 00002: val_loss did not improve from 0.17576
# Epoch 3/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2812 - accuracy: 0.9127 - val_loss: 0.2204 - val_accuracy: 0.9315
#
# Epoch 00003: val_loss did not improve from 0.17576
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2531 - accuracy: 0.9210 - val_loss: 0.2063 - val_accuracy: 0.9397
#
# Epoch 00004: val_loss did not improve from 0.17576
# Epoch 5/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2333 - accuracy: 0.9274 - val_loss: 0.1921 - val_accuracy: 0.9405
#
# Epoch 00005: val_loss did not improve from 0.17576
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2107 - accuracy: 0.9315 - val_loss: 0.1768 - val_accuracy: 0.9484
#
# Epoch 00006: val_loss did not improve from 0.17576
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1964 - accuracy: 0.9374 - val_loss: 0.1729 - val_accuracy: 0.9476
#
# Epoch 00007: val_loss improved from 0.17576 to 0.17291, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1880 - accuracy: 0.9398 - val_loss: 0.1739 - val_accuracy: 0.9507
#
# Epoch 00008: val_loss did not improve from 0.17291
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1700 - accuracy: 0.9445 - val_loss: 0.1663 - val_accuracy: 0.9499
#
# Epoch 00009: val_loss improved from 0.17291 to 0.16631, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1598 - accuracy: 0.9473 - val_loss: 0.1770 - val_accuracy: 0.9514
#
# Epoch 00010: val_loss did not improve from 0.16631
# Epoch 11/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1490 - accuracy: 0.9514 - val_loss: 0.1549 - val_accuracy: 0.9525
#
# Epoch 00011: val_loss improved from 0.16631 to 0.15488, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 12/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1441 - accuracy: 0.9525 - val_loss: 0.1576 - val_accuracy: 0.9537
#
# Epoch 00012: val_loss did not improve from 0.15488
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1416 - accuracy: 0.9530 - val_loss: 0.1701 - val_accuracy: 0.9510
#
# Epoch 00013: val_loss did not improve from 0.15488
# Epoch 14/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1362 - accuracy: 0.9552 - val_loss: 0.1501 - val_accuracy: 0.9552
#
# Epoch 00014: val_loss improved from 0.15488 to 0.15012, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1271 - accuracy: 0.9571 - val_loss: 0.1606 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.15012
# Epoch 16/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1217 - accuracy: 0.9599 - val_loss: 0.1540 - val_accuracy: 0.9563
#
# Epoch 00016: val_loss did not improve from 0.15012
# Epoch 17/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1161 - accuracy: 0.9623 - val_loss: 0.1689 - val_accuracy: 0.9533
#
# Epoch 00017: val_loss did not improve from 0.15012
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1143 - accuracy: 0.9623 - val_loss: 0.1564 - val_accuracy: 0.9529
#
# Epoch 00018: val_loss did not improve from 0.15012
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1096 - accuracy: 0.9633 - val_loss: 0.1771 - val_accuracy: 0.9537
#
# Epoch 00019: val_loss did not improve from 0.15012
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1071 - accuracy: 0.9651 - val_loss: 0.1483 - val_accuracy: 0.9571
#
# Epoch 00020: val_loss improved from 0.15012 to 0.14833, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1008 - accuracy: 0.9671 - val_loss: 0.1628 - val_accuracy: 0.9571
#
# Epoch 00021: val_loss did not improve from 0.14833
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0943 - accuracy: 0.9687 - val_loss: 0.1666 - val_accuracy: 0.9556
#
# Epoch 00022: val_loss did not improve from 0.14833
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0966 - accuracy: 0.9676 - val_loss: 0.1531 - val_accuracy: 0.9582
#
# Epoch 00023: val_loss did not improve from 0.14833
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0978 - accuracy: 0.9678 - val_loss: 0.1756 - val_accuracy: 0.9559
#
# Epoch 00024: val_loss did not improve from 0.14833
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0923 - accuracy: 0.9689 - val_loss: 0.1628 - val_accuracy: 0.9544
#
# Epoch 00025: val_loss did not improve from 0.14833
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0943 - accuracy: 0.9692 - val_loss: 0.1571 - val_accuracy: 0.9574
#
# Epoch 00026: val_loss did not improve from 0.14833
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0879 - accuracy: 0.9717 - val_loss: 0.1683 - val_accuracy: 0.9589
#
# Epoch 00027: val_loss did not improve from 0.14833
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0907 - accuracy: 0.9707 - val_loss: 0.1669 - val_accuracy: 0.9574
#
# Epoch 00028: val_loss did not improve from 0.14833
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0829 - accuracy: 0.9735 - val_loss: 0.1678 - val_accuracy: 0.9567
#
# Epoch 00029: val_loss did not improve from 0.14833
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0882 - accuracy: 0.9711 - val_loss: 0.1620 - val_accuracy: 0.9578
#
# Epoch 00030: val_loss did not improve from 0.14833
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0851 - accuracy: 0.9723 - val_loss: 0.1648 - val_accuracy: 0.9571
#
# Epoch 00031: val_loss did not improve from 0.14833
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0845 - accuracy: 0.9727 - val_loss: 0.1561 - val_accuracy: 0.9567
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00032: val_loss did not improve from 0.14833
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0700 - accuracy: 0.9772 - val_loss: 0.1719 - val_accuracy: 0.9582
#
# Epoch 00033: val_loss did not improve from 0.14833
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0685 - accuracy: 0.9769 - val_loss: 0.1707 - val_accuracy: 0.9578
#
# Epoch 00034: val_loss did not improve from 0.14833
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0657 - accuracy: 0.9782 - val_loss: 0.1790 - val_accuracy: 0.9586
#
# Epoch 00035: val_loss did not improve from 0.14833
# Score for fold 3: loss of 0.17903254926204681; accuracy of 95.85687518119812%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5797 - accuracy: 0.8287 - val_loss: 0.3355 - val_accuracy: 0.9013
#
# Epoch 00001: val_loss did not improve from 0.14833
# Epoch 2/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3184 - accuracy: 0.9011 - val_loss: 0.2280 - val_accuracy: 0.9247
#
# Epoch 00002: val_loss did not improve from 0.14833
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2608 - accuracy: 0.9168 - val_loss: 0.1996 - val_accuracy: 0.9367
#
# Epoch 00003: val_loss did not improve from 0.14833
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2365 - accuracy: 0.9242 - val_loss: 0.1904 - val_accuracy: 0.9439
#
# Epoch 00004: val_loss did not improve from 0.14833
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2144 - accuracy: 0.9312 - val_loss: 0.1785 - val_accuracy: 0.9458
#
# Epoch 00005: val_loss did not improve from 0.14833
# Epoch 6/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.2020 - accuracy: 0.9340 - val_loss: 0.1801 - val_accuracy: 0.9431
#
# Epoch 00006: val_loss did not improve from 0.14833
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1907 - accuracy: 0.9390 - val_loss: 0.1598 - val_accuracy: 0.9507
#
# Epoch 00007: val_loss did not improve from 0.14833
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1722 - accuracy: 0.9433 - val_loss: 0.1618 - val_accuracy: 0.9495
#
# Epoch 00008: val_loss did not improve from 0.14833
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1625 - accuracy: 0.9466 - val_loss: 0.1557 - val_accuracy: 0.9522
#
# Epoch 00009: val_loss did not improve from 0.14833
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1528 - accuracy: 0.9497 - val_loss: 0.1604 - val_accuracy: 0.9540
#
# Epoch 00010: val_loss did not improve from 0.14833
# Epoch 11/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1479 - accuracy: 0.9518 - val_loss: 0.1635 - val_accuracy: 0.9518
#
# Epoch 00011: val_loss did not improve from 0.14833
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1348 - accuracy: 0.9552 - val_loss: 0.1496 - val_accuracy: 0.9537
#
# Epoch 00012: val_loss did not improve from 0.14833
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1269 - accuracy: 0.9581 - val_loss: 0.1500 - val_accuracy: 0.9529
#
# Epoch 00013: val_loss did not improve from 0.14833
# Epoch 14/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1268 - accuracy: 0.9600 - val_loss: 0.1526 - val_accuracy: 0.9563
#
# Epoch 00014: val_loss did not improve from 0.14833
# Epoch 15/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1198 - accuracy: 0.9607 - val_loss: 0.1461 - val_accuracy: 0.9567
#
# Epoch 00015: val_loss improved from 0.14833 to 0.14608, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1115 - accuracy: 0.9639 - val_loss: 0.1626 - val_accuracy: 0.9559
#
# Epoch 00016: val_loss did not improve from 0.14608
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1136 - accuracy: 0.9629 - val_loss: 0.1503 - val_accuracy: 0.9582
#
# Epoch 00017: val_loss did not improve from 0.14608
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1049 - accuracy: 0.9652 - val_loss: 0.1570 - val_accuracy: 0.9601
#
# Epoch 00018: val_loss did not improve from 0.14608
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1090 - accuracy: 0.9642 - val_loss: 0.1606 - val_accuracy: 0.9589
#
# Epoch 00019: val_loss did not improve from 0.14608
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0993 - accuracy: 0.9672 - val_loss: 0.1465 - val_accuracy: 0.9601
#
# Epoch 00020: val_loss did not improve from 0.14608
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0922 - accuracy: 0.9703 - val_loss: 0.1654 - val_accuracy: 0.9608
#
# Epoch 00021: val_loss did not improve from 0.14608
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0968 - accuracy: 0.9683 - val_loss: 0.1388 - val_accuracy: 0.9616
#
# Epoch 00022: val_loss improved from 0.14608 to 0.13884, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v002\model.h5
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0911 - accuracy: 0.9696 - val_loss: 0.1599 - val_accuracy: 0.9593
#
# Epoch 00023: val_loss did not improve from 0.13884
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0965 - accuracy: 0.9685 - val_loss: 0.1669 - val_accuracy: 0.9593
#
# Epoch 00024: val_loss did not improve from 0.13884
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0856 - accuracy: 0.9714 - val_loss: 0.1758 - val_accuracy: 0.9586
#
# Epoch 00025: val_loss did not improve from 0.13884
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0883 - accuracy: 0.9705 - val_loss: 0.1514 - val_accuracy: 0.9616
#
# Epoch 00026: val_loss did not improve from 0.13884
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0898 - accuracy: 0.9703 - val_loss: 0.1517 - val_accuracy: 0.9623
#
# Epoch 00027: val_loss did not improve from 0.13884
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0838 - accuracy: 0.9720 - val_loss: 0.1555 - val_accuracy: 0.9593
#
# Epoch 00028: val_loss did not improve from 0.13884
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0846 - accuracy: 0.9714 - val_loss: 0.1778 - val_accuracy: 0.9608
#
# Epoch 00029: val_loss did not improve from 0.13884
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0832 - accuracy: 0.9717 - val_loss: 0.1611 - val_accuracy: 0.9597
#
# Epoch 00030: val_loss did not improve from 0.13884
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0802 - accuracy: 0.9725 - val_loss: 0.1634 - val_accuracy: 0.9589
#
# Epoch 00031: val_loss did not improve from 0.13884
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0789 - accuracy: 0.9737 - val_loss: 0.1531 - val_accuracy: 0.9631
#
# Epoch 00032: val_loss did not improve from 0.13884
# Epoch 33/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0780 - accuracy: 0.9737 - val_loss: 0.1895 - val_accuracy: 0.9612
#
# Epoch 00033: val_loss did not improve from 0.13884
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0764 - accuracy: 0.9738 - val_loss: 0.1706 - val_accuracy: 0.9608
#
# Epoch 00034: val_loss did not improve from 0.13884
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0759 - accuracy: 0.9750 - val_loss: 0.1753 - val_accuracy: 0.9605
#
# Epoch 00035: val_loss did not improve from 0.13884
# Score for fold 4: loss of 0.17528529465198517; accuracy of 96.04519605636597%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5882 - accuracy: 0.8213 - val_loss: 0.3267 - val_accuracy: 0.8915
#
# Epoch 00001: val_loss did not improve from 0.13884
# Epoch 2/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3407 - accuracy: 0.8919 - val_loss: 0.2461 - val_accuracy: 0.9258
#
# Epoch 00002: val_loss did not improve from 0.13884
# Epoch 3/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2887 - accuracy: 0.9087 - val_loss: 0.2167 - val_accuracy: 0.9326
#
# Epoch 00003: val_loss did not improve from 0.13884
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2594 - accuracy: 0.9166 - val_loss: 0.2033 - val_accuracy: 0.9382
#
# Epoch 00004: val_loss did not improve from 0.13884
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2361 - accuracy: 0.9252 - val_loss: 0.1899 - val_accuracy: 0.9386
#
# Epoch 00005: val_loss did not improve from 0.13884
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2204 - accuracy: 0.9298 - val_loss: 0.1879 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.13884
# Epoch 7/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2031 - accuracy: 0.9335 - val_loss: 0.1710 - val_accuracy: 0.9507
#
# Epoch 00007: val_loss did not improve from 0.13884
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1960 - accuracy: 0.9362 - val_loss: 0.1678 - val_accuracy: 0.9484
#
# Epoch 00008: val_loss did not improve from 0.13884
# Epoch 9/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1863 - accuracy: 0.9393 - val_loss: 0.1631 - val_accuracy: 0.9514
#
# Epoch 00009: val_loss did not improve from 0.13884
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1742 - accuracy: 0.9433 - val_loss: 0.1628 - val_accuracy: 0.9510
#
# Epoch 00010: val_loss did not improve from 0.13884
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1711 - accuracy: 0.9434 - val_loss: 0.1684 - val_accuracy: 0.9522
#
# Epoch 00011: val_loss did not improve from 0.13884
# Epoch 12/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1578 - accuracy: 0.9479 - val_loss: 0.1567 - val_accuracy: 0.9533
#
# Epoch 00012: val_loss did not improve from 0.13884
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1509 - accuracy: 0.9508 - val_loss: 0.1472 - val_accuracy: 0.9556
#
# Epoch 00013: val_loss did not improve from 0.13884
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1458 - accuracy: 0.9519 - val_loss: 0.1529 - val_accuracy: 0.9556
#
# Epoch 00014: val_loss did not improve from 0.13884
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1408 - accuracy: 0.9547 - val_loss: 0.1503 - val_accuracy: 0.9552
#
# Epoch 00015: val_loss did not improve from 0.13884
# Epoch 16/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1338 - accuracy: 0.9556 - val_loss: 0.1488 - val_accuracy: 0.9556
#
# Epoch 00016: val_loss did not improve from 0.13884
# Epoch 17/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1296 - accuracy: 0.9578 - val_loss: 0.1538 - val_accuracy: 0.9540
#
# Epoch 00017: val_loss did not improve from 0.13884
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1288 - accuracy: 0.9567 - val_loss: 0.1538 - val_accuracy: 0.9567
#
# Epoch 00018: val_loss did not improve from 0.13884
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1208 - accuracy: 0.9596 - val_loss: 0.1516 - val_accuracy: 0.9556
#
# Epoch 00019: val_loss did not improve from 0.13884
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1181 - accuracy: 0.9610 - val_loss: 0.1497 - val_accuracy: 0.9582
#
# Epoch 00020: val_loss did not improve from 0.13884
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1152 - accuracy: 0.9618 - val_loss: 0.1550 - val_accuracy: 0.9578
#
# Epoch 00021: val_loss did not improve from 0.13884
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1097 - accuracy: 0.9629 - val_loss: 0.1462 - val_accuracy: 0.9612
#
# Epoch 00022: val_loss did not improve from 0.13884
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1116 - accuracy: 0.9629 - val_loss: 0.1780 - val_accuracy: 0.9525
#
# Epoch 00023: val_loss did not improve from 0.13884
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1119 - accuracy: 0.9630 - val_loss: 0.1592 - val_accuracy: 0.9589
#
# Epoch 00024: val_loss did not improve from 0.13884
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1035 - accuracy: 0.9649 - val_loss: 0.1715 - val_accuracy: 0.9593
#
# Epoch 00025: val_loss did not improve from 0.13884
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1055 - accuracy: 0.9647 - val_loss: 0.1833 - val_accuracy: 0.9582
#
# Epoch 00026: val_loss did not improve from 0.13884
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1063 - accuracy: 0.9652 - val_loss: 0.1669 - val_accuracy: 0.9582
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00027: val_loss did not improve from 0.13884
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0895 - accuracy: 0.9691 - val_loss: 0.1610 - val_accuracy: 0.9597
#
# Epoch 00028: val_loss did not improve from 0.13884
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0848 - accuracy: 0.9707 - val_loss: 0.1588 - val_accuracy: 0.9593
#
# Epoch 00029: val_loss did not improve from 0.13884
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0843 - accuracy: 0.9717 - val_loss: 0.1683 - val_accuracy: 0.9593
#
# Epoch 00030: val_loss did not improve from 0.13884
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0814 - accuracy: 0.9718 - val_loss: 0.1719 - val_accuracy: 0.9593
#
# Epoch 00031: val_loss did not improve from 0.13884
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0778 - accuracy: 0.9734 - val_loss: 0.1677 - val_accuracy: 0.9605
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.13884
# Epoch 33/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0740 - accuracy: 0.9749 - val_loss: 0.1627 - val_accuracy: 0.9620
#
# Epoch 00033: val_loss did not improve from 0.13884
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0730 - accuracy: 0.9751 - val_loss: 0.1687 - val_accuracy: 0.9620
#
# Epoch 00034: val_loss did not improve from 0.13884
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0739 - accuracy: 0.9750 - val_loss: 0.1653 - val_accuracy: 0.9635
#
# Epoch 00035: val_loss did not improve from 0.13884
# Score for fold 5: loss of 0.16525477170944214; accuracy of 96.346515417099%
# Epoch 1/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.6048 - accuracy: 0.8222 - val_loss: 0.3198 - val_accuracy: 0.9073
#
# Epoch 00001: val_loss did not improve from 0.13884
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3193 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.9202
#
# Epoch 00002: val_loss did not improve from 0.13884
# Epoch 3/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2703 - accuracy: 0.9149 - val_loss: 0.2111 - val_accuracy: 0.9311
#
# Epoch 00003: val_loss did not improve from 0.13884
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2401 - accuracy: 0.9231 - val_loss: 0.2231 - val_accuracy: 0.9266
#
# Epoch 00004: val_loss did not improve from 0.13884
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2241 - accuracy: 0.9280 - val_loss: 0.1922 - val_accuracy: 0.9416
#
# Epoch 00005: val_loss did not improve from 0.13884
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2066 - accuracy: 0.9329 - val_loss: 0.1872 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.13884
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1946 - accuracy: 0.9368 - val_loss: 0.1796 - val_accuracy: 0.9435
#
# Epoch 00007: val_loss did not improve from 0.13884
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1824 - accuracy: 0.9402 - val_loss: 0.1728 - val_accuracy: 0.9476
#
# Epoch 00008: val_loss did not improve from 0.13884
# Epoch 9/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1700 - accuracy: 0.9447 - val_loss: 0.1659 - val_accuracy: 0.9499
#
# Epoch 00009: val_loss did not improve from 0.13884
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1668 - accuracy: 0.9445 - val_loss: 0.1598 - val_accuracy: 0.9522
#
# Epoch 00010: val_loss did not improve from 0.13884
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1567 - accuracy: 0.9481 - val_loss: 0.1626 - val_accuracy: 0.9518
#
# Epoch 00011: val_loss did not improve from 0.13884
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1484 - accuracy: 0.9508 - val_loss: 0.1552 - val_accuracy: 0.9540
#
# Epoch 00012: val_loss did not improve from 0.13884
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1390 - accuracy: 0.9536 - val_loss: 0.1556 - val_accuracy: 0.9540
#
# Epoch 00013: val_loss did not improve from 0.13884
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1340 - accuracy: 0.9544 - val_loss: 0.1630 - val_accuracy: 0.9537
#
# Epoch 00014: val_loss did not improve from 0.13884
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1318 - accuracy: 0.9564 - val_loss: 0.1587 - val_accuracy: 0.9578
#
# Epoch 00015: val_loss did not improve from 0.13884
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1247 - accuracy: 0.9588 - val_loss: 0.1654 - val_accuracy: 0.9533
#
# Epoch 00016: val_loss did not improve from 0.13884
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1228 - accuracy: 0.9596 - val_loss: 0.1534 - val_accuracy: 0.9593
#
# Epoch 00017: val_loss did not improve from 0.13884
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1202 - accuracy: 0.9606 - val_loss: 0.1566 - val_accuracy: 0.9574
#
# Epoch 00018: val_loss did not improve from 0.13884
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1137 - accuracy: 0.9627 - val_loss: 0.1641 - val_accuracy: 0.9559
#
# Epoch 00019: val_loss did not improve from 0.13884
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1101 - accuracy: 0.9630 - val_loss: 0.1621 - val_accuracy: 0.9571
#
# Epoch 00020: val_loss did not improve from 0.13884
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1063 - accuracy: 0.9653 - val_loss: 0.1804 - val_accuracy: 0.9559
#
# Epoch 00021: val_loss did not improve from 0.13884
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1043 - accuracy: 0.9650 - val_loss: 0.1631 - val_accuracy: 0.9586
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.13884
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0900 - accuracy: 0.9694 - val_loss: 0.1638 - val_accuracy: 0.9642
#
# Epoch 00023: val_loss did not improve from 0.13884
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0868 - accuracy: 0.9705 - val_loss: 0.1666 - val_accuracy: 0.9620
#
# Epoch 00024: val_loss did not improve from 0.13884
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0853 - accuracy: 0.9711 - val_loss: 0.1572 - val_accuracy: 0.9620
#
# Epoch 00025: val_loss did not improve from 0.13884
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0833 - accuracy: 0.9725 - val_loss: 0.1669 - val_accuracy: 0.9616
#
# Epoch 00026: val_loss did not improve from 0.13884
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0779 - accuracy: 0.9743 - val_loss: 0.1803 - val_accuracy: 0.9623
#
# Epoch 00027: val_loss did not improve from 0.13884
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0763 - accuracy: 0.9738 - val_loss: 0.1791 - val_accuracy: 0.9620
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.13884
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0735 - accuracy: 0.9746 - val_loss: 0.1809 - val_accuracy: 0.9631
#
# Epoch 00029: val_loss did not improve from 0.13884
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0736 - accuracy: 0.9750 - val_loss: 0.1711 - val_accuracy: 0.9627
#
# Epoch 00030: val_loss did not improve from 0.13884
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0699 - accuracy: 0.9767 - val_loss: 0.1776 - val_accuracy: 0.9616
#
# Epoch 00031: val_loss did not improve from 0.13884
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0689 - accuracy: 0.9767 - val_loss: 0.2028 - val_accuracy: 0.9612
#
# Epoch 00032: val_loss did not improve from 0.13884
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0672 - accuracy: 0.9774 - val_loss: 0.1907 - val_accuracy: 0.9620
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.13884
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0650 - accuracy: 0.9777 - val_loss: 0.1906 - val_accuracy: 0.9635
#
# Epoch 00034: val_loss did not improve from 0.13884
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0666 - accuracy: 0.9779 - val_loss: 0.1902 - val_accuracy: 0.9631
#
# Epoch 00035: val_loss did not improve from 0.13884
# Score for fold 6: loss of 0.19023074209690094; accuracy of 96.30885124206543%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.6248 - accuracy: 0.8131 - val_loss: 0.3713 - val_accuracy: 0.8670
#
# Epoch 00001: val_loss did not improve from 0.13884
# Epoch 2/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.3487 - accuracy: 0.8894 - val_loss: 0.2991 - val_accuracy: 0.9055
#
# Epoch 00002: val_loss did not improve from 0.13884
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2891 - accuracy: 0.9075 - val_loss: 0.2535 - val_accuracy: 0.9164
#
# Epoch 00003: val_loss did not improve from 0.13884
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2577 - accuracy: 0.9160 - val_loss: 0.2337 - val_accuracy: 0.9205
#
# Epoch 00004: val_loss did not improve from 0.13884
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2354 - accuracy: 0.9235 - val_loss: 0.2215 - val_accuracy: 0.9220
#
# Epoch 00005: val_loss did not improve from 0.13884
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2220 - accuracy: 0.9263 - val_loss: 0.2284 - val_accuracy: 0.9273
#
# Epoch 00006: val_loss did not improve from 0.13884
# Epoch 7/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2046 - accuracy: 0.9337 - val_loss: 0.2003 - val_accuracy: 0.9330
#
# Epoch 00007: val_loss did not improve from 0.13884
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1913 - accuracy: 0.9376 - val_loss: 0.2109 - val_accuracy: 0.9345
#
# Epoch 00008: val_loss did not improve from 0.13884
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1818 - accuracy: 0.9407 - val_loss: 0.1854 - val_accuracy: 0.9420
#
# Epoch 00009: val_loss did not improve from 0.13884
# Epoch 10/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1695 - accuracy: 0.9461 - val_loss: 0.1814 - val_accuracy: 0.9409
#
# Epoch 00010: val_loss did not improve from 0.13884
# Epoch 11/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1590 - accuracy: 0.9481 - val_loss: 0.1868 - val_accuracy: 0.9427
#
# Epoch 00011: val_loss did not improve from 0.13884
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1524 - accuracy: 0.9496 - val_loss: 0.1749 - val_accuracy: 0.9435
#
# Epoch 00012: val_loss did not improve from 0.13884
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1466 - accuracy: 0.9526 - val_loss: 0.2058 - val_accuracy: 0.9394
#
# Epoch 00013: val_loss did not improve from 0.13884
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1375 - accuracy: 0.9545 - val_loss: 0.1680 - val_accuracy: 0.9465
#
# Epoch 00014: val_loss did not improve from 0.13884
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1354 - accuracy: 0.9547 - val_loss: 0.2077 - val_accuracy: 0.9420
#
# Epoch 00015: val_loss did not improve from 0.13884
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1325 - accuracy: 0.9563 - val_loss: 0.2117 - val_accuracy: 0.9397
#
# Epoch 00016: val_loss did not improve from 0.13884
# Epoch 17/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1234 - accuracy: 0.9599 - val_loss: 0.1949 - val_accuracy: 0.9465
#
# Epoch 00017: val_loss did not improve from 0.13884
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1237 - accuracy: 0.9594 - val_loss: 0.1824 - val_accuracy: 0.9443
#
# Epoch 00018: val_loss did not improve from 0.13884
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1193 - accuracy: 0.9605 - val_loss: 0.1928 - val_accuracy: 0.9465
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.13884
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1019 - accuracy: 0.9648 - val_loss: 0.1988 - val_accuracy: 0.9461
#
# Epoch 00020: val_loss did not improve from 0.13884
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0970 - accuracy: 0.9673 - val_loss: 0.1899 - val_accuracy: 0.9465
#
# Epoch 00021: val_loss did not improve from 0.13884
# Epoch 22/35
# ...
#
# Epoch 00027: val_loss did not improve from 0.13884
# Epoch 28/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0685 - accuracy: 0.9771 - val_loss: 0.1868 - val_accuracy: 0.9556
#
# Epoch 00028: val_loss did not improve from 0.13884
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0719 - accuracy: 0.9763 - val_loss: 0.1995 - val_accuracy: 0.9589
#
# Epoch 00029: val_loss did not improve from 0.13884
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0696 - accuracy: 0.9767 - val_loss: 0.2239 - val_accuracy: 0.9586
#
# Epoch 00030: val_loss did not improve from 0.13884
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0699 - accuracy: 0.9769 - val_loss: 0.2045 - val_accuracy: 0.9608
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00031: val_loss did not improve from 0.13884
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0648 - accuracy: 0.9787 - val_loss: 0.1905 - val_accuracy: 0.9631
#
# Epoch 00032: val_loss did not improve from 0.13884
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0608 - accuracy: 0.9796 - val_loss: 0.1879 - val_accuracy: 0.9627
#
# Epoch 00033: val_loss did not improve from 0.13884
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0594 - accuracy: 0.9800 - val_loss: 0.2037 - val_accuracy: 0.9601
#
# Epoch 00034: val_loss did not improve from 0.13884
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0608 - accuracy: 0.9795 - val_loss: 0.1937 - val_accuracy: 0.9612
#
# Epoch 00035: val_loss did not improve from 0.13884
# Score for fold 8: loss of 0.1936933547258377; accuracy of 96.1205244064331%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.6002 - accuracy: 0.8240 - val_loss: 0.3400 - val_accuracy: 0.8900
#
# Epoch 00001: val_loss did not improve from 0.13884
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3275 - accuracy: 0.8978 - val_loss: 0.2663 - val_accuracy: 0.9096
#
# Epoch 00002: val_loss did not improve from 0.13884
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2761 - accuracy: 0.9140 - val_loss: 0.2629 - val_accuracy: 0.9171
#
# Epoch 00003: val_loss did not improve from 0.13884
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2492 - accuracy: 0.9221 - val_loss: 0.2451 - val_accuracy: 0.9265
#
# Epoch 00004: val_loss did not improve from 0.13884
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2281 - accuracy: 0.9285 - val_loss: 0.2307 - val_accuracy: 0.9303
#
# Epoch 00005: val_loss did not improve from 0.13884
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2135 - accuracy: 0.9322 - val_loss: 0.2210 - val_accuracy: 0.9307
#
# Epoch 00006: val_loss did not improve from 0.13884
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1977 - accuracy: 0.9357 - val_loss: 0.2105 - val_accuracy: 0.9341
#
# Epoch 00007: val_loss did not improve from 0.13884
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1850 - accuracy: 0.9414 - val_loss: 0.2043 - val_accuracy: 0.9322
#
# Epoch 00008: val_loss did not improve from 0.13884
# Epoch 9/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1757 - accuracy: 0.9435 - val_loss: 0.1925 - val_accuracy: 0.9390
#
# Epoch 00009: val_loss did not improve from 0.13884
# Epoch 10/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1693 - accuracy: 0.9454 - val_loss: 0.1909 - val_accuracy: 0.9393
#
# Epoch 00010: val_loss did not improve from 0.13884
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1590 - accuracy: 0.9487 - val_loss: 0.1849 - val_accuracy: 0.9424
#
# Epoch 00011: val_loss did not improve from 0.13884
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1493 - accuracy: 0.9521 - val_loss: 0.1856 - val_accuracy: 0.9427
#
# Epoch 00012: val_loss did not improve from 0.13884
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1468 - accuracy: 0.9524 - val_loss: 0.1843 - val_accuracy: 0.9431
#
# Epoch 00013: val_loss did not improve from 0.13884
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1440 - accuracy: 0.9545 - val_loss: 0.1842 - val_accuracy: 0.9427
#
# Epoch 00014: val_loss did not improve from 0.13884
# Epoch 15/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1326 - accuracy: 0.9568 - val_loss: 0.1807 - val_accuracy: 0.9442
#
# Epoch 00015: val_loss did not improve from 0.13884
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1279 - accuracy: 0.9571 - val_loss: 0.2042 - val_accuracy: 0.9457
#
# Epoch 00016: val_loss did not improve from 0.13884
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1283 - accuracy: 0.9581 - val_loss: 0.2203 - val_accuracy: 0.9439
#
# Epoch 00017: val_loss did not improve from 0.13884
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1218 - accuracy: 0.9598 - val_loss: 0.1805 - val_accuracy: 0.9491
#
# Epoch 00018: val_loss did not improve from 0.13884
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1149 - accuracy: 0.9622 - val_loss: 0.1729 - val_accuracy: 0.9491
#
# Epoch 00019: val_loss did not improve from 0.13884
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1142 - accuracy: 0.9617 - val_loss: 0.1880 - val_accuracy: 0.9454
#
# Epoch 00020: val_loss did not improve from 0.13884
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1140 - accuracy: 0.9629 - val_loss: 0.1868 - val_accuracy: 0.9446
#
# Epoch 00021: val_loss did not improve from 0.13884
# Epoch 22/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1072 - accuracy: 0.9636 - val_loss: 0.1841 - val_accuracy: 0.9488
#
# Epoch 00022: val_loss did not improve from 0.13884
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1030 - accuracy: 0.9655 - val_loss: 0.1838 - val_accuracy: 0.9491
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.13884
# Epoch 24/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0930 - accuracy: 0.9687 - val_loss: 0.1859 - val_accuracy: 0.9484
#
# Epoch 00024: val_loss did not improve from 0.13884
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0850 - accuracy: 0.9710 - val_loss: 0.2066 - val_accuracy: 0.9484
#
# Epoch 00025: val_loss did not improve from 0.13884
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0815 - accuracy: 0.9728 - val_loss: 0.2123 - val_accuracy: 0.9476
#
# Epoch 00026: val_loss did not improve from 0.13884
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0780 - accuracy: 0.9730 - val_loss: 0.1962 - val_accuracy: 0.9518
#
# Epoch 00027: val_loss did not improve from 0.13884
# Epoch 28/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0799 - accuracy: 0.9728 - val_loss: 0.1977 - val_accuracy: 0.9484
#
# Epoch 00028: val_loss did not improve from 0.13884
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0777 - accuracy: 0.9732 - val_loss: 0.2177 - val_accuracy: 0.9495
#
# Epoch 00029: val_loss did not improve from 0.13884
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0747 - accuracy: 0.9746 - val_loss: 0.2098 - val_accuracy: 0.9533
#
# Epoch 00030: val_loss did not improve from 0.13884
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0711 - accuracy: 0.9759 - val_loss: 0.2054 - val_accuracy: 0.9506
#
# Epoch 00031: val_loss did not improve from 0.13884
# Epoch 32/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0760 - accuracy: 0.9753 - val_loss: 0.2005 - val_accuracy: 0.9510
#
# Epoch 00032: val_loss did not improve from 0.13884
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0722 - accuracy: 0.9755 - val_loss: 0.1970 - val_accuracy: 0.9529
#
# Epoch 00033: val_loss did not improve from 0.13884
# Epoch 34/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0699 - accuracy: 0.9763 - val_loss: 0.2337 - val_accuracy: 0.9510
#
# Epoch 00034: val_loss did not improve from 0.13884
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0733 - accuracy: 0.9746 - val_loss: 0.2116 - val_accuracy: 0.9503
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00035: val_loss did not improve from 0.13884
# Score for fold 9: loss of 0.2116328477859497; accuracy of 95.02637386322021%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5502 - accuracy: 0.8353 - val_loss: 0.3019 - val_accuracy: 0.9039
#
# Epoch 00001: val_loss did not improve from 0.13884
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3137 - accuracy: 0.9010 - val_loss: 0.2245 - val_accuracy: 0.9295
#
# Epoch 00002: val_loss did not improve from 0.13884
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2643 - accuracy: 0.9170 - val_loss: 0.1985 - val_accuracy: 0.9371
# Epoch 00003: val_loss did not improve from 0.13884
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2325 - accuracy: 0.9262 - val_loss: 0.1930 - val_accuracy: 0.9367
#
# Epoch 00004: val_loss did not improve from 0.13884
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2135 - accuracy: 0.9292 - val_loss: 0.1682 - val_accuracy: 0.9499
#
# Epoch 00005: val_loss did not improve from 0.13884
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1990 - accuracy: 0.9367 - val_loss: 0.1671 - val_accuracy: 0.9480
#
# Epoch 00006: val_loss did not improve from 0.13884
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1881 - accuracy: 0.9397 - val_loss: 0.1562 - val_accuracy: 0.9495
#
# Epoch 00007: val_loss did not improve from 0.13884
# Epoch 8/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1748 - accuracy: 0.9437 - val_loss: 0.1529 - val_accuracy: 0.9506
#
# Epoch 00008: val_loss did not improve from 0.13884
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1635 - accuracy: 0.9472 - val_loss: 0.1535 - val_accuracy: 0.9529
#
# Epoch 00009: val_loss did not improve from 0.13884
# Epoch 10/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1545 - accuracy: 0.9498 - val_loss: 0.1443 - val_accuracy: 0.9552
#
# Epoch 00010: val_loss did not improve from 0.13884
# Epoch 11/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1472 - accuracy: 0.9515 - val_loss: 0.1436 - val_accuracy: 0.9548
#
# Epoch 00011: val_loss did not improve from 0.13884
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1404 - accuracy: 0.9535 - val_loss: 0.1449 - val_accuracy: 0.9540
#
# Epoch 00012: val_loss did not improve from 0.13884
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1372 - accuracy: 0.9545 - val_loss: 0.1513 - val_accuracy: 0.9552
#
# Epoch 00013: val_loss did not improve from 0.13884
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1265 - accuracy: 0.9588 - val_loss: 0.1447 - val_accuracy: 0.9570
#
# Epoch 00014: val_loss did not improve from 0.13884
# Epoch 15/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1219 - accuracy: 0.9593 - val_loss: 0.1444 - val_accuracy: 0.9582
#
# Epoch 00015: val_loss did not improve from 0.13884
# Epoch 16/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1214 - accuracy: 0.9600 - val_loss: 0.1454 - val_accuracy: 0.9574
#
# Epoch 00016: val_loss did not improve from 0.13884
# Epoch 17/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1127 - accuracy: 0.9626 - val_loss: 0.1476 - val_accuracy: 0.9555
#
# Epoch 00017: val_loss did not improve from 0.13884
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1138 - accuracy: 0.9606 - val_loss: 0.1471 - val_accuracy: 0.9597
#
# Epoch 00018: val_loss did not improve from 0.13884
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1043 - accuracy: 0.9652 - val_loss: 0.1573 - val_accuracy: 0.9601
#
# Epoch 00019: val_loss did not improve from 0.13884
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1027 - accuracy: 0.9665 - val_loss: 0.1651 - val_accuracy: 0.9589
#
# Epoch 00020: val_loss did not improve from 0.13884
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1007 - accuracy: 0.9664 - val_loss: 0.1504 - val_accuracy: 0.9593
#
# Epoch 00021: val_loss did not improve from 0.13884
# Epoch 22/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1040 - accuracy: 0.9662 - val_loss: 0.1561 - val_accuracy: 0.9582
#
# Epoch 00022: val_loss did not improve from 0.13884
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0974 - accuracy: 0.9684 - val_loss: 0.1562 - val_accuracy: 0.9586
#
# Epoch 00023: val_loss did not improve from 0.13884
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0894 - accuracy: 0.9707 - val_loss: 0.1648 - val_accuracy: 0.9589
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.13884
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0783 - accuracy: 0.9737 - val_loss: 0.1647 - val_accuracy: 0.9589
#
# Epoch 00025: val_loss did not improve from 0.13884
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0783 - accuracy: 0.9739 - val_loss: 0.1590 - val_accuracy: 0.9578
#
# Epoch 00026: val_loss did not improve from 0.13884
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0741 - accuracy: 0.9751 - val_loss: 0.1689 - val_accuracy: 0.9589
#
# Epoch 00027: val_loss did not improve from 0.13884
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0762 - accuracy: 0.9746 - val_loss: 0.1593 - val_accuracy: 0.9586
#
# Epoch 00028: val_loss did not improve from 0.13884
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0708 - accuracy: 0.9755 - val_loss: 0.1500 - val_accuracy: 0.9627
#
# Epoch 00029: val_loss did not improve from 0.13884
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0751 - accuracy: 0.9751 - val_loss: 0.1642 - val_accuracy: 0.9593
#
# Epoch 00030: val_loss did not improve from 0.13884
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0691 - accuracy: 0.9771 - val_loss: 0.1836 - val_accuracy: 0.9597
#
# Epoch 00031: val_loss did not improve from 0.13884
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0668 - accuracy: 0.9770 - val_loss: 0.1740 - val_accuracy: 0.9604
#
# Epoch 00032: val_loss did not improve from 0.13884
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0670 - accuracy: 0.9779 - val_loss: 0.1761 - val_accuracy: 0.9593
#
# Epoch 00033: val_loss did not improve from 0.13884
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0674 - accuracy: 0.9768 - val_loss: 0.1802 - val_accuracy: 0.9582
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.13884
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0612 - accuracy: 0.9790 - val_loss: 0.1746 - val_accuracy: 0.9627
#
# Epoch 00035: val_loss did not improve from 0.13884
# Score for fold 10: loss of 0.17462483048439026; accuracy of 96.26978039741516%

# %%
(np.argmax(Malware_model.predict(imgs[test]), axis=-1))
# Out:
# array([10,  7,  0, ..., 10,  1,  9], dtype=int64)

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.20893573760986328 - Accuracy: 95.3295648097992%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.24118348956108093 - Accuracy: 95.17890810966492%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.17903254926204681 - Accuracy: 95.85687518119812%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.17528529465198517 - Accuracy: 96.04519605636597%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.16525477170944214 - Accuracy: 96.346515417099%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.19023074209690094 - Accuracy: 96.30885124206543%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.23063813149929047 - Accuracy: 94.65160369873047%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.1936933547258377 - Accuracy: 96.1205244064331%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.2116328477859497 - Accuracy: 95.02637386322021%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.17462483048439026 - Accuracy: 96.26978039741516%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.71341931819916% (+- 0.005825639725363772)
# > Loss: 0.19705117493867874
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9571      | 0.0058       |
# | Loss     | 0.1971      | 0.0241       |
# | Macro F1 | 0.8871      | 0.0072       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9813      | 0.0039       |
# | Acc      | 0.9855      | 0.0026       |
# | F1       | 0.9862      | 0.0026       |
# | MCC      | 0.9708      | 0.0052       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
