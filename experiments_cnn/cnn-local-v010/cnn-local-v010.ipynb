# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with LeakyReLU activation.
#
# Includes weights for all classes to overcome unbalanced data.

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 50

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cnn"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cnn/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 9 matches(es) found
# --------------
# New folder name: cnn-local-v010
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# **Automatic reverse weight calculation.**
#
# The weight is determined by how well respresented the class is in the dataset; the less represented, the higher the weigth. This way of calculating weights aims to overcome the unbalanced data. The 'Adam' optimizer is not affected by the weights like other optimizer would be

# %%
distr = (sum(labels)/labels.shape[0])
weights = wf/distr

# %%
class_weight = {0: weights[0], 1: weights[1], 2: weights[2], 3: weights[3], 4: weights[4], 5: weights[5],
               6: weights[6], 7: weights[7], 8: weights[8], 9: weights[9], 10: weights[10]}

# %%
print(class_weight)
# Out:
# {0: 5.453574, 1: 4.9108396, 2: 15.87799, 3: 15.821215, 4: 19.871258, 5: 9.186159, 6: 13.899477, 7: 8.981055, 8: 20.484568, 9: 25.045284, 10: 0.94733083}

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9,
#  'benign': 10}

# %%
imgs.shape
# Out:
# (26548, 64, 64, 1)

# %%
labels.shape
# Out:
# (26548, 11)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (7965, 11)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 18583 | Shape of training data (18583, 64, 64, 1)
# Size of training data: 7965  | Shape of training data (7965, 64, 64, 1)
# Shape of training labels (18583, 11)
# Shape of training labels (7965, 11)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = 11
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='LeakyReLU'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='LeakyReLU'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='LeakyReLU'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2940)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               376448
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_8 (Dense)              (None, 11)                561
# =================================================================
# Total params: 387,824
# Trainable params: 387,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint],
    class_weight=class_weight) # The actual computation of the CNN
# Out:
# Epoch 1/50
# 581/581 [==============================] - 4s 7ms/step - loss: 5.0239 - accuracy: 0.7331 - val_loss: 0.5991 - val_accuracy: 0.8210
#
# Epoch 00001: val_loss improved from inf to 0.59909, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 2/50
# 581/581 [==============================] - 4s 7ms/step - loss: 3.2050 - accuracy: 0.8441 - val_loss: 0.4001 - val_accuracy: 0.8832
#
# Epoch 00002: val_loss improved from 0.59909 to 0.40010, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 3/50
# 581/581 [==============================] - 4s 7ms/step - loss: 2.6196 - accuracy: 0.8705 - val_loss: 0.3227 - val_accuracy: 0.8992
#
# Epoch 00003: val_loss improved from 0.40010 to 0.32269, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 4/50
# 581/581 [==============================] - 4s 7ms/step - loss: 2.2938 - accuracy: 0.8824 - val_loss: 0.2689 - val_accuracy: 0.9161
#
# Epoch 00004: val_loss improved from 0.32269 to 0.26887, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 5/50
# 581/581 [==============================] - 4s 7ms/step - loss: 2.0200 - accuracy: 0.8965 - val_loss: 0.3170 - val_accuracy: 0.9085
#
# Epoch 00005: val_loss did not improve from 0.26887
# Epoch 6/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.8360 - accuracy: 0.8996 - val_loss: 0.2681 - val_accuracy: 0.9183
#
# Epoch 00006: val_loss improved from 0.26887 to 0.26806, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 7/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.6114 - accuracy: 0.9088 - val_loss: 0.2630 - val_accuracy: 0.9171
#
# Epoch 00007: val_loss improved from 0.26806 to 0.26299, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 8/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.4743 - accuracy: 0.9138 - val_loss: 0.2633 - val_accuracy: 0.9244
#
# Epoch 00008: val_loss did not improve from 0.26299
# Epoch 9/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.3875 - accuracy: 0.9193 - val_loss: 0.3562 - val_accuracy: 0.9076
#
# Epoch 00009: val_loss did not improve from 0.26299
# Epoch 10/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.3058 - accuracy: 0.9226 - val_loss: 0.2991 - val_accuracy: 0.9126
#
# Epoch 00010: val_loss did not improve from 0.26299
# Epoch 11/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.2023 - accuracy: 0.9251 - val_loss: 0.2494 - val_accuracy: 0.9341
#
# Epoch 00011: val_loss improved from 0.26299 to 0.24943, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 12/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.0812 - accuracy: 0.9356 - val_loss: 0.3313 - val_accuracy: 0.9151
#
# Epoch 00012: val_loss did not improve from 0.24943
# Epoch 13/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.0825 - accuracy: 0.9333 - val_loss: 0.2672 - val_accuracy: 0.9281
#
# Epoch 00013: val_loss did not improve from 0.24943
# Epoch 14/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.9852 - accuracy: 0.9341 - val_loss: 0.2550 - val_accuracy: 0.9363
#
# Epoch 00014: val_loss did not improve from 0.24943
# Epoch 15/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.0198 - accuracy: 0.9377 - val_loss: 0.2386 - val_accuracy: 0.9387
#
# Epoch 00015: val_loss improved from 0.24943 to 0.23856, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 16/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.9759 - accuracy: 0.9388 - val_loss: 0.2470 - val_accuracy: 0.9335
#
# Epoch 00016: val_loss did not improve from 0.23856
# Epoch 17/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.9600 - accuracy: 0.9395 - val_loss: 0.2335 - val_accuracy: 0.9390
#
# Epoch 00017: val_loss improved from 0.23856 to 0.23354, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v010\model.h5
# Epoch 18/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.9351 - accuracy: 0.9389 - val_loss: 0.2417 - val_accuracy: 0.9360
#
# Epoch 00018: val_loss did not improve from 0.23354
# Epoch 19/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.8824 - accuracy: 0.9395 - val_loss: 0.2745 - val_accuracy: 0.9178
#
# Epoch 00019: val_loss did not improve from 0.23354
# Epoch 20/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.8578 - accuracy: 0.9443 - val_loss: 0.2544 - val_accuracy: 0.9351
#
# Epoch 00020: val_loss did not improve from 0.23354
# Epoch 21/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.9366 - accuracy: 0.9347 - val_loss: 0.2706 - val_accuracy: 0.9316
#
# Epoch 00021: val_loss did not improve from 0.23354
# Epoch 22/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.8264 - accuracy: 0.9466 - val_loss: 0.2658 - val_accuracy: 0.9353
#
# Epoch 00022: val_loss did not improve from 0.23354
# Epoch 23/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.8064 - accuracy: 0.9493 - val_loss: 0.2581 - val_accuracy: 0.9347
#
# Epoch 00023: val_loss did not improve from 0.23354
# Epoch 24/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.8469 - accuracy: 0.9440 - val_loss: 0.3156 - val_accuracy: 0.9234
#
# Epoch 00024: val_loss did not improve from 0.23354
# Epoch 25/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.8090 - accuracy: 0.9470 - val_loss: 0.2677 - val_accuracy: 0.9320
#
# Epoch 00025: val_loss did not improve from 0.23354
# Epoch 26/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7887 - accuracy: 0.9531 - val_loss: 0.2699 - val_accuracy: 0.9303
#
# Epoch 00026: val_loss did not improve from 0.23354
# Epoch 27/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7504 - accuracy: 0.9514 - val_loss: 0.2717 - val_accuracy: 0.9326
#
# Epoch 00027: val_loss did not improve from 0.23354
# Epoch 28/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7626 - accuracy: 0.9515 - val_loss: 0.2960 - val_accuracy: 0.9229
#
# Epoch 00028: val_loss did not improve from 0.23354
# Epoch 29/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7466 - accuracy: 0.9488 - val_loss: 0.2863 - val_accuracy: 0.9343
#
# Epoch 00029: val_loss did not improve from 0.23354
# Epoch 30/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7485 - accuracy: 0.9510 - val_loss: 0.2878 - val_accuracy: 0.9313
#
# Epoch 00030: val_loss did not improve from 0.23354
# Epoch 31/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7087 - accuracy: 0.9550 - val_loss: 0.2917 - val_accuracy: 0.9308
#
# Epoch 00031: val_loss did not improve from 0.23354
# Epoch 32/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7029 - accuracy: 0.9543 - val_loss: 0.3098 - val_accuracy: 0.9299
#
# Epoch 00032: val_loss did not improve from 0.23354
# Epoch 33/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6414 - accuracy: 0.9544 - val_loss: 0.3353 - val_accuracy: 0.9244
#
# Epoch 00033: val_loss did not improve from 0.23354
# Epoch 34/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7007 - accuracy: 0.9523 - val_loss: 0.2864 - val_accuracy: 0.9318
#
# Epoch 00034: val_loss did not improve from 0.23354
# Epoch 35/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7823 - accuracy: 0.9508 - val_loss: 0.2580 - val_accuracy: 0.9391
#
# Epoch 00035: val_loss did not improve from 0.23354
# Epoch 36/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6732 - accuracy: 0.9536 - val_loss: 0.2686 - val_accuracy: 0.9368
#
# Epoch 00036: val_loss did not improve from 0.23354
# Epoch 37/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.7023 - accuracy: 0.9524 - val_loss: 0.2800 - val_accuracy: 0.9414
#
# Epoch 00037: val_loss did not improve from 0.23354
# Epoch 38/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6693 - accuracy: 0.9561 - val_loss: 0.3006 - val_accuracy: 0.9332
#
# Epoch 00038: val_loss did not improve from 0.23354
# Epoch 39/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6443 - accuracy: 0.9593 - val_loss: 0.3072 - val_accuracy: 0.9309
# Epoch 00039: val_loss did not improve from 0.23354
# Epoch 40/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6461 - accuracy: 0.9546 - val_loss: 0.3198 - val_accuracy: 0.9243
#
# Epoch 00040: val_loss did not improve from 0.23354
# Epoch 41/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6706 - accuracy: 0.9517 - val_loss: 0.3846 - val_accuracy: 0.9127
#
# Epoch 00041: val_loss did not improve from 0.23354
# Epoch 42/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.5968 - accuracy: 0.9575 - val_loss: 0.2930 - val_accuracy: 0.9325
#
# Epoch 00042: val_loss did not improve from 0.23354
# Epoch 43/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6157 - accuracy: 0.9588 - val_loss: 0.3050 - val_accuracy: 0.9327
#
# Epoch 00043: val_loss did not improve from 0.23354
# Epoch 44/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6640 - accuracy: 0.9585 - val_loss: 0.2786 - val_accuracy: 0.9390
#
# Epoch 00044: val_loss did not improve from 0.23354
# Epoch 45/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6423 - accuracy: 0.9586 - val_loss: 0.2555 - val_accuracy: 0.9395
#
# Epoch 00045: val_loss did not improve from 0.23354
# Epoch 46/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.5975 - accuracy: 0.9591 - val_loss: 0.2883 - val_accuracy: 0.9268
#
# Epoch 00046: val_loss did not improve from 0.23354
# Epoch 47/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.5957 - accuracy: 0.9597 - val_loss: 0.2767 - val_accuracy: 0.9358
#
# Epoch 00047: val_loss did not improve from 0.23354
# Epoch 48/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6437 - accuracy: 0.9547 - val_loss: 0.3112 - val_accuracy: 0.9309
#
# Epoch 00048: val_loss did not improve from 0.23354
# Epoch 49/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.6583 - accuracy: 0.9563 - val_loss: 0.2512 - val_accuracy: 0.9425
#
# Epoch 00049: val_loss did not improve from 0.23354
# Epoch 50/50
# 581/581 [==============================] - 4s 7ms/step - loss: 0.5355 - accuracy: 0.9605 - val_loss: 0.3350 - val_accuracy: 0.9217
#
# Epoch 00050: val_loss did not improve from 0.23354

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 249/249 [==============================] - 1s 3ms/step - loss: 0.2335 - accuracy: 0.9390
# Overall CNN Accuracy: 0.9389830231666565
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.939           |
# | Validation loss               | 0.2335          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([10,  5, 10, ...,  6, 10,  9], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([10,  5, 10, ...,  6, 10,  8], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 7965
# 7965

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Ransomware' 'Benign' 'Benign' ... 'Ransomware' 'Ransomware' 'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 14012

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +------------------------------------------------+
# |               Performance of CNN               |
# +----------------------------------+-------------+
# | Metric                           | Performance |
# +----------------------------------+-------------+
# | True Positive Rate               | 0.9897      |
# | Accuracy                         | 0.9715      |
# | F1 Score                         | 0.9724      |
# | Matthews Correlation Coefficient | 0.9436      |
# +----------------------------------+-------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)
