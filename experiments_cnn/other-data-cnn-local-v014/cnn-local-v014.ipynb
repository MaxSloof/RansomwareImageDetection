# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# This notebook only ran on the ransomware images excl. occamy (and thus excl. benign)!
#
# Uses rgb, 64x64 images with LeakyReLU activation.
#
# Weights were not included

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 50

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cnn"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cnn/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 13 matches(es) found
# --------------
# New folder name: cnn-local-v014
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/data_wo_benign_and_occamy"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 11697 images belonging to 9 classes.

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'OnLineGames.CTB': 3,
#  'Reveton.A': 4,
#  'Sfone': 5,
#  'VB.IL': 6,
#  'Zbot': 7,
#  'Zbot!CI': 8}

# %%
imgs.shape
# Out:
# (11697, 64, 64, 1)

# %%
labels.shape
# Out:
# (11697, 9)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (3510, 9)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 8187 | Shape of training data (8187, 64, 64, 1)
# Size of training data: 3510  | Shape of training data (3510, 64, 64, 1)
# Shape of training labels (8187, 9)
# Shape of training labels (3510, 9)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Retrieve the number of classes in our dataset

# %%
num_classes = labels[1].shape[0]
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  9

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='LeakyReLU'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='LeakyReLU'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='LeakyReLU'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2940)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               376448
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                6450
# _________________________________________________________________
# dense_14 (Dense)             (None, 9)                 459
# =================================================================
# Total params: 387,722
# Trainable params: 387,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint]) # The actual computation of the CNN
# Out:
# Epoch 1/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.5914 - accuracy: 0.7946 - val_loss: 0.4001 - val_accuracy: 0.8852
#
# Epoch 00001: val_loss improved from inf to 0.40008, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 2/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.2819 - accuracy: 0.9008 - val_loss: 0.2040 - val_accuracy: 0.9291
#
# Epoch 00002: val_loss improved from 0.40008 to 0.20398, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 3/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.2140 - accuracy: 0.9224 - val_loss: 0.1957 - val_accuracy: 0.9336
#
# Epoch 00003: val_loss improved from 0.20398 to 0.19570, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 4/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.1780 - accuracy: 0.9354 - val_loss: 0.1542 - val_accuracy: 0.9544
#
# Epoch 00004: val_loss improved from 0.19570 to 0.15418, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 5/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.1499 - accuracy: 0.9489 - val_loss: 0.1375 - val_accuracy: 0.9550
#
# Epoch 00005: val_loss improved from 0.15418 to 0.13751, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 6/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.1268 - accuracy: 0.9569 - val_loss: 0.1244 - val_accuracy: 0.9578
#
# Epoch 00006: val_loss improved from 0.13751 to 0.12444, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 7/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.1073 - accuracy: 0.9619 - val_loss: 0.1186 - val_accuracy: 0.9624
#
# Epoch 00007: val_loss improved from 0.12444 to 0.11863, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 8/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.1009 - accuracy: 0.9662 - val_loss: 0.1170 - val_accuracy: 0.9652
#
# Epoch 00008: val_loss improved from 0.11863 to 0.11696, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v014\model.h5
# Epoch 9/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0776 - accuracy: 0.9737 - val_loss: 0.1392 - val_accuracy: 0.9567
#
# Epoch 00009: val_loss did not improve from 0.11696
# Epoch 10/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0760 - accuracy: 0.9737 - val_loss: 0.1221 - val_accuracy: 0.9658
#
# Epoch 00010: val_loss did not improve from 0.11696
# Epoch 11/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0616 - accuracy: 0.9779 - val_loss: 0.1504 - val_accuracy: 0.9621
#
# Epoch 00011: val_loss did not improve from 0.11696
# Epoch 12/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0539 - accuracy: 0.9830 - val_loss: 0.1189 - val_accuracy: 0.9672
#
# Epoch 00012: val_loss did not improve from 0.11696
# Epoch 13/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0471 - accuracy: 0.9852 - val_loss: 0.1259 - val_accuracy: 0.9647
#
# Epoch 00013: val_loss did not improve from 0.11696
# Epoch 14/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0441 - accuracy: 0.9864 - val_loss: 0.1315 - val_accuracy: 0.9684
#
# Epoch 00014: val_loss did not improve from 0.11696
# Epoch 15/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 0.1262 - val_accuracy: 0.9670
#
# Epoch 00015: val_loss did not improve from 0.11696
# Epoch 16/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0418 - accuracy: 0.9851 - val_loss: 0.1242 - val_accuracy: 0.9687
#
# Epoch 00016: val_loss did not improve from 0.11696
# Epoch 17/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0382 - accuracy: 0.9895 - val_loss: 0.1385 - val_accuracy: 0.9664
#
# Epoch 00017: val_loss did not improve from 0.11696
# Epoch 18/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 0.1387 - val_accuracy: 0.9692
#
# Epoch 00018: val_loss did not improve from 0.11696
# Epoch 19/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0330 - accuracy: 0.9902 - val_loss: 0.1347 - val_accuracy: 0.9698
#
# Epoch 00019: val_loss did not improve from 0.11696
# Epoch 20/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.1370 - val_accuracy: 0.9675
#
# Epoch 00020: val_loss did not improve from 0.11696
# Epoch 21/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0194 - accuracy: 0.9944 - val_loss: 0.1381 - val_accuracy: 0.9704
#
# Epoch 00021: val_loss did not improve from 0.11696
# Epoch 22/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0264 - accuracy: 0.9921 - val_loss: 0.1494 - val_accuracy: 0.9687
#
# Epoch 00022: val_loss did not improve from 0.11696
# Epoch 23/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0257 - accuracy: 0.9913 - val_loss: 0.1601 - val_accuracy: 0.9704
#
# Epoch 00023: val_loss did not improve from 0.11696
# Epoch 24/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.1643 - val_accuracy: 0.9681
#
# Epoch 00024: val_loss did not improve from 0.11696
# Epoch 25/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0283 - accuracy: 0.9923 - val_loss: 0.1656 - val_accuracy: 0.9644
#
# Epoch 00025: val_loss did not improve from 0.11696
# Epoch 26/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0267 - accuracy: 0.9923 - val_loss: 0.1550 - val_accuracy: 0.9692
#
# Epoch 00026: val_loss did not improve from 0.11696
# Epoch 27/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0259 - accuracy: 0.9918 - val_loss: 0.1728 - val_accuracy: 0.9698
#
# Epoch 00027: val_loss did not improve from 0.11696
# Epoch 28/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.1521 - val_accuracy: 0.9692
#
# Epoch 00028: val_loss did not improve from 0.11696
# Epoch 29/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.1709 - val_accuracy: 0.9687
#
# Epoch 00029: val_loss did not improve from 0.11696
# Epoch 30/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0226 - accuracy: 0.9936 - val_loss: 0.1856 - val_accuracy: 0.9698
#
# Epoch 00030: val_loss did not improve from 0.11696
# Epoch 31/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.1742 - val_accuracy: 0.9670
#
# Epoch 00031: val_loss did not improve from 0.11696
# Epoch 32/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 0.1725 - val_accuracy: 0.9670
#
# Epoch 00032: val_loss did not improve from 0.11696
# Epoch 33/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9965 - val_loss: 0.1796 - val_accuracy: 0.9658
#
# Epoch 00033: val_loss did not improve from 0.11696
# Epoch 34/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.1812 - val_accuracy: 0.9689
#
# Epoch 00034: val_loss did not improve from 0.11696
# Epoch 35/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.1741 - val_accuracy: 0.9689
#
# Epoch 00035: val_loss did not improve from 0.11696
# Epoch 36/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.2247 - val_accuracy: 0.9638
#
# Epoch 00036: val_loss did not improve from 0.11696
# Epoch 37/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.1946 - val_accuracy: 0.9672
#
# Epoch 00037: val_loss did not improve from 0.11696
# Epoch 38/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0264 - accuracy: 0.9924 - val_loss: 0.1830 - val_accuracy: 0.9650
#
# Epoch 00038: val_loss did not improve from 0.11696
# Epoch 39/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0177 - accuracy: 0.9936 - val_loss: 0.2031 - val_accuracy: 0.9647
#
# Epoch 00039: val_loss did not improve from 0.11696
# Epoch 40/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0187 - accuracy: 0.9946 - val_loss: 0.1947 - val_accuracy: 0.9707
#
# Epoch 00040: val_loss did not improve from 0.11696
# Epoch 41/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.1922 - val_accuracy: 0.9672
#
# Epoch 00041: val_loss did not improve from 0.11696
# Epoch 42/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0207 - accuracy: 0.9943 - val_loss: 0.2218 - val_accuracy: 0.9641
#
# Epoch 00042: val_loss did not improve from 0.11696
# Epoch 43/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.2024 - val_accuracy: 0.9667
#
# Epoch 00043: val_loss did not improve from 0.11696
# Epoch 44/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0211 - accuracy: 0.9939 - val_loss: 0.1839 - val_accuracy: 0.9707
#
# Epoch 00044: val_loss did not improve from 0.11696
# Epoch 45/50
# 256/256 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.1757 - val_accuracy: 0.9704
#
# Epoch 00045: val_loss did not improve from 0.11696
# Epoch 46/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.1863 - val_accuracy: 0.9715
#
# Epoch 00046: val_loss did not improve from 0.11696
# Epoch 47/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0193 - accuracy: 0.9946 - val_loss: 0.2009 - val_accuracy: 0.9701
#
# Epoch 00047: val_loss did not improve from 0.11696
# Epoch 48/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.2045 - val_accuracy: 0.9704
#
# Epoch 00048: val_loss did not improve from 0.11696
# Epoch 49/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.1815 - val_accuracy: 0.9695
#
# Epoch 00049: val_loss did not improve from 0.11696
# Epoch 50/50
# 256/256 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.2039 - val_accuracy: 0.9652
#
# Epoch 00050: val_loss did not improve from 0.11696

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.1170 - accuracy: 0.9652
# Overall CNN Accuracy: 0.9652421474456787
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9652          |
# | Validation loss               | 0.117           |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([8, 6, 0, ..., 4, 4, 8], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([7, 6, 0, ..., 4, 4, 8], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 3510
# 3510

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Ransomware' 'Ransomware' 'Ransomware' ... 'Ransomware' 'Ransomware'
#  'Ransomware']
# Ransomware Occurences: 11697, Benign Occurences: 0

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1674                 blocks = [
# -> 1675                     make_block(
#    1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2741
# -> 2742     return klass(values, ndim=ndim, placement=placement)
#    2743
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 1, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16476/3489594119.py in <module>
#       1 class_names_bin= ("ransomware", "benign")
# ----> 2 confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
#
# ~\AppData\Local\Temp/ipykernel_16476/2541008972.py in confusion_matrix_bin(confusion_matrix, class_names_bin, figsize, fontsize)
#       2 def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
#       3
# ----> 4     df_cm = pd.DataFrame(
#       5         confusion_matrix, index=class_names_bin, columns=class_names_bin,
#       6     )
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# ValueError: Shape of passed values is (1, 1), indices imply (2, 2)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)
