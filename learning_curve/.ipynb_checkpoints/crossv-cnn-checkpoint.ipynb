# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021.
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 20000 # Set high so all the images in the directory

# Number of epochs
epoch_t = 35 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/learning_curve"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn{batch_size}-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/learning_curve/cnn{batch_size}-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 8 matches(es) found
# --------------
# New folder name: cnn20000-local-v009
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
    
    # Save the binary data distribution
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6356 - accuracy: 0.8140 - val_loss: 0.3532 - val_accuracy: 0.9000
#
# Epoch 00001: val_loss improved from inf to 0.35323, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3700 - accuracy: 0.8863 - val_loss: 0.2639 - val_accuracy: 0.9220
#
# Epoch 00002: val_loss improved from 0.35323 to 0.26387, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 3/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2974 - accuracy: 0.9063 - val_loss: 0.2564 - val_accuracy: 0.9285
#
# Epoch 00003: val_loss improved from 0.26387 to 0.25637, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 4/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2654 - accuracy: 0.9181 - val_loss: 0.2221 - val_accuracy: 0.9385
#
# Epoch 00004: val_loss improved from 0.25637 to 0.22208, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 5/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2461 - accuracy: 0.9206 - val_loss: 0.2280 - val_accuracy: 0.9390
#
# Epoch 00005: val_loss did not improve from 0.22208
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2230 - accuracy: 0.9282 - val_loss: 0.2089 - val_accuracy: 0.9410
#
# Epoch 00006: val_loss improved from 0.22208 to 0.20891, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2112 - accuracy: 0.9316 - val_loss: 0.2031 - val_accuracy: 0.9465
#
# Epoch 00007: val_loss improved from 0.20891 to 0.20314, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 8/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1964 - accuracy: 0.9362 - val_loss: 0.1955 - val_accuracy: 0.9450
#
# Epoch 00008: val_loss improved from 0.20314 to 0.19548, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1886 - accuracy: 0.9391 - val_loss: 0.1958 - val_accuracy: 0.9495
#
# Epoch 00009: val_loss did not improve from 0.19548
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1761 - accuracy: 0.9413 - val_loss: 0.1862 - val_accuracy: 0.9535
#
# Epoch 00010: val_loss improved from 0.19548 to 0.18620, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 11/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1691 - accuracy: 0.9439 - val_loss: 0.2020 - val_accuracy: 0.9445
#
# Epoch 00011: val_loss did not improve from 0.18620
# Epoch 12/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1604 - accuracy: 0.9462 - val_loss: 0.1976 - val_accuracy: 0.9485
#
# Epoch 00012: val_loss did not improve from 0.18620
# Epoch 13/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1534 - accuracy: 0.9490 - val_loss: 0.1731 - val_accuracy: 0.9560
#
# Epoch 00013: val_loss improved from 0.18620 to 0.17313, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 14/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1523 - accuracy: 0.9493 - val_loss: 0.1936 - val_accuracy: 0.9535
#
# Epoch 00014: val_loss did not improve from 0.17313
# Epoch 15/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1400 - accuracy: 0.9524 - val_loss: 0.1872 - val_accuracy: 0.9560
#
# Epoch 00015: val_loss did not improve from 0.17313
# Epoch 16/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1409 - accuracy: 0.9539 - val_loss: 0.1918 - val_accuracy: 0.9525
#
# Epoch 00016: val_loss did not improve from 0.17313
# Epoch 17/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1342 - accuracy: 0.9559 - val_loss: 0.1911 - val_accuracy: 0.9530
#
# Epoch 00017: val_loss did not improve from 0.17313
# Epoch 18/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1283 - accuracy: 0.9569 - val_loss: 0.2016 - val_accuracy: 0.9470
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.17313
# Epoch 19/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1088 - accuracy: 0.9638 - val_loss: 0.1994 - val_accuracy: 0.9560
#
# Epoch 00019: val_loss did not improve from 0.17313
# Epoch 20/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1015 - accuracy: 0.9674 - val_loss: 0.2208 - val_accuracy: 0.9570
#
# Epoch 00020: val_loss did not improve from 0.17313
# Epoch 21/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1010 - accuracy: 0.9662 - val_loss: 0.2126 - val_accuracy: 0.9540
#
# Epoch 00021: val_loss did not improve from 0.17313
# Epoch 22/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0976 - accuracy: 0.9680 - val_loss: 0.2203 - val_accuracy: 0.9540
#
# Epoch 00022: val_loss did not improve from 0.17313
# Epoch 23/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0977 - accuracy: 0.9670 - val_loss: 0.2171 - val_accuracy: 0.9535
#
# Epoch 00023: val_loss did not improve from 0.17313
# Epoch 24/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0938 - accuracy: 0.9684 - val_loss: 0.2090 - val_accuracy: 0.9540
#
# Epoch 00024: val_loss did not improve from 0.17313
# Epoch 25/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0932 - accuracy: 0.9681 - val_loss: 0.2237 - val_accuracy: 0.9560
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.17313
# Epoch 26/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0819 - accuracy: 0.9723 - val_loss: 0.2092 - val_accuracy: 0.9550
#
# Epoch 00026: val_loss did not improve from 0.17313
# Epoch 27/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0802 - accuracy: 0.9732 - val_loss: 0.2134 - val_accuracy: 0.9565
#
# Epoch 00027: val_loss did not improve from 0.17313
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0793 - accuracy: 0.9727 - val_loss: 0.2214 - val_accuracy: 0.9560
#
# Epoch 00028: val_loss did not improve from 0.17313
# Epoch 29/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0767 - accuracy: 0.9744 - val_loss: 0.2077 - val_accuracy: 0.9580
#
# Epoch 00029: val_loss did not improve from 0.17313
# Epoch 30/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0760 - accuracy: 0.9746 - val_loss: 0.2340 - val_accuracy: 0.9540
#
# Epoch 00030: val_loss did not improve from 0.17313
# Epoch 31/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0741 - accuracy: 0.9751 - val_loss: 0.2214 - val_accuracy: 0.9580
#
# Epoch 00031: val_loss did not improve from 0.17313
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0758 - accuracy: 0.9745 - val_loss: 0.2316 - val_accuracy: 0.9550
#
# Epoch 00032: val_loss did not improve from 0.17313
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0766 - accuracy: 0.9739 - val_loss: 0.2199 - val_accuracy: 0.9560
#
# Epoch 00033: val_loss did not improve from 0.17313
# Epoch 34/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0727 - accuracy: 0.9749 - val_loss: 0.2284 - val_accuracy: 0.9545
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_loss did not improve from 0.17313
# Epoch 35/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0669 - accuracy: 0.9761 - val_loss: 0.2354 - val_accuracy: 0.9550
#
# Epoch 00035: val_loss did not improve from 0.17313
# Score for fold 1: loss of 0.23542647063732147; accuracy of 95.49999833106995%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6601 - accuracy: 0.8037 - val_loss: 0.4036 - val_accuracy: 0.8590
#
# Epoch 00001: val_loss did not improve from 0.17313
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3816 - accuracy: 0.8786 - val_loss: 0.3033 - val_accuracy: 0.9065
#
# Epoch 00002: val_loss did not improve from 0.17313
# Epoch 3/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.3131 - accuracy: 0.9009 - val_loss: 0.2646 - val_accuracy: 0.9135
#
# Epoch 00003: val_loss did not improve from 0.17313
# Epoch 4/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2870 - accuracy: 0.9101 - val_loss: 0.2659 - val_accuracy: 0.9185
#
# Epoch 00004: val_loss did not improve from 0.17313
# Epoch 5/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2588 - accuracy: 0.9166 - val_loss: 0.2410 - val_accuracy: 0.9275
#
# Epoch 00005: val_loss did not improve from 0.17313
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2383 - accuracy: 0.9233 - val_loss: 0.2162 - val_accuracy: 0.9345
#
# Epoch 00006: val_loss did not improve from 0.17313
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2271 - accuracy: 0.9276 - val_loss: 0.2078 - val_accuracy: 0.9370
#
# Epoch 00007: val_loss did not improve from 0.17313
# Epoch 8/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2094 - accuracy: 0.9318 - val_loss: 0.2046 - val_accuracy: 0.9360
#
# Epoch 00008: val_loss did not improve from 0.17313
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2004 - accuracy: 0.9357 - val_loss: 0.1962 - val_accuracy: 0.9430
#
# Epoch 00009: val_loss did not improve from 0.17313
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1947 - accuracy: 0.9370 - val_loss: 0.1908 - val_accuracy: 0.9410
#
# Epoch 00010: val_loss did not improve from 0.17313
# Epoch 11/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1845 - accuracy: 0.9394 - val_loss: 0.1903 - val_accuracy: 0.9455
#
# Epoch 00011: val_loss did not improve from 0.17313
# Epoch 12/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1746 - accuracy: 0.9417 - val_loss: 0.1966 - val_accuracy: 0.9485
#
# Epoch 00012: val_loss did not improve from 0.17313
# Epoch 13/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1633 - accuracy: 0.9465 - val_loss: 0.1812 - val_accuracy: 0.9505
#
# Epoch 00013: val_loss did not improve from 0.17313
# Epoch 14/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1602 - accuracy: 0.9478 - val_loss: 0.1889 - val_accuracy: 0.9495
#
# Epoch 00014: val_loss did not improve from 0.17313
# Epoch 15/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1541 - accuracy: 0.9487 - val_loss: 0.2021 - val_accuracy: 0.9475
#
# Epoch 00015: val_loss did not improve from 0.17313
# Epoch 16/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1422 - accuracy: 0.9529 - val_loss: 0.2137 - val_accuracy: 0.9470
#
# Epoch 00016: val_loss did not improve from 0.17313
# Epoch 17/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1451 - accuracy: 0.9514 - val_loss: 0.1824 - val_accuracy: 0.9505
#
# Epoch 00017: val_loss did not improve from 0.17313
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1399 - accuracy: 0.9546 - val_loss: 0.1785 - val_accuracy: 0.9515
#
# Epoch 00018: val_loss did not improve from 0.17313
# Epoch 19/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1358 - accuracy: 0.9541 - val_loss: 0.1953 - val_accuracy: 0.9485
#
# Epoch 00019: val_loss did not improve from 0.17313
# Epoch 20/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1297 - accuracy: 0.9571 - val_loss: 0.1891 - val_accuracy: 0.9515
#
# Epoch 00020: val_loss did not improve from 0.17313
# Epoch 21/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1235 - accuracy: 0.9585 - val_loss: 0.2162 - val_accuracy: 0.9460
#
# Epoch 00021: val_loss did not improve from 0.17313
# Epoch 22/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1218 - accuracy: 0.9601 - val_loss: 0.2162 - val_accuracy: 0.9490
#
# Epoch 00022: val_loss did not improve from 0.17313
# Epoch 23/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1161 - accuracy: 0.9597 - val_loss: 0.2047 - val_accuracy: 0.9485
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.17313
# Epoch 24/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1064 - accuracy: 0.9650 - val_loss: 0.2253 - val_accuracy: 0.9470
#
# Epoch 00024: val_loss did not improve from 0.17313
# Epoch 25/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0938 - accuracy: 0.9681 - val_loss: 0.2166 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.17313
# Epoch 26/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0965 - accuracy: 0.9683 - val_loss: 0.2358 - val_accuracy: 0.9485
#
# Epoch 00026: val_loss did not improve from 0.17313
# Epoch 27/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0930 - accuracy: 0.9692 - val_loss: 0.2336 - val_accuracy: 0.9510
#
# Epoch 00027: val_loss did not improve from 0.17313
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0888 - accuracy: 0.9702 - val_loss: 0.2273 - val_accuracy: 0.9520
#
# Epoch 00028: val_loss did not improve from 0.17313
# Epoch 29/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0884 - accuracy: 0.9699 - val_loss: 0.2451 - val_accuracy: 0.9505
#
# Epoch 00029: val_loss did not improve from 0.17313
# Epoch 30/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0870 - accuracy: 0.9702 - val_loss: 0.2341 - val_accuracy: 0.9500
#
# Epoch 00030: val_loss did not improve from 0.17313
# Epoch 31/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0867 - accuracy: 0.9706 - val_loss: 0.2256 - val_accuracy: 0.9545
#
# Epoch 00031: val_loss did not improve from 0.17313
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0814 - accuracy: 0.9712 - val_loss: 0.2293 - val_accuracy: 0.9515
#
# Epoch 00032: val_loss did not improve from 0.17313
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0823 - accuracy: 0.9723 - val_loss: 0.2359 - val_accuracy: 0.9525
#
# Epoch 00033: val_loss did not improve from 0.17313
# Epoch 34/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0792 - accuracy: 0.9731 - val_loss: 0.2463 - val_accuracy: 0.9510
#
# Epoch 00034: val_loss did not improve from 0.17313
# Epoch 35/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0793 - accuracy: 0.9724 - val_loss: 0.2511 - val_accuracy: 0.9490
#
# Epoch 00035: val_loss did not improve from 0.17313
# Score for fold 2: loss of 0.2510700523853302; accuracy of 94.90000009536743%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6461 - accuracy: 0.8051 - val_loss: 0.3704 - val_accuracy: 0.8790
#
# Epoch 00001: val_loss did not improve from 0.17313
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3544 - accuracy: 0.8883 - val_loss: 0.2935 - val_accuracy: 0.8975
#
# Epoch 00002: val_loss did not improve from 0.17313
# Epoch 3/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2935 - accuracy: 0.9085 - val_loss: 0.2721 - val_accuracy: 0.9105
#
# Epoch 00003: val_loss did not improve from 0.17313
# Epoch 4/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2567 - accuracy: 0.9197 - val_loss: 0.2616 - val_accuracy: 0.9070
#
# Epoch 00004: val_loss did not improve from 0.17313
# Epoch 5/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2411 - accuracy: 0.9231 - val_loss: 0.2277 - val_accuracy: 0.9205
#
# Epoch 00005: val_loss did not improve from 0.17313
# Epoch 6/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.2221 - accuracy: 0.9294 - val_loss: 0.2143 - val_accuracy: 0.9285
#
# Epoch 00006: val_loss did not improve from 0.17313
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2033 - accuracy: 0.9340 - val_loss: 0.2247 - val_accuracy: 0.9310
#
# Epoch 00007: val_loss did not improve from 0.17313
# Epoch 8/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1907 - accuracy: 0.9368 - val_loss: 0.2060 - val_accuracy: 0.9340
#
# Epoch 00008: val_loss did not improve from 0.17313
# Epoch 9/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1878 - accuracy: 0.9388 - val_loss: 0.2003 - val_accuracy: 0.9345
#
# Epoch 00009: val_loss did not improve from 0.17313
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1741 - accuracy: 0.9420 - val_loss: 0.1916 - val_accuracy: 0.9345
#
# Epoch 00010: val_loss did not improve from 0.17313
# Epoch 11/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1694 - accuracy: 0.9443 - val_loss: 0.2005 - val_accuracy: 0.9325
#
# Epoch 00011: val_loss did not improve from 0.17313
# Epoch 12/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1578 - accuracy: 0.9475 - val_loss: 0.1841 - val_accuracy: 0.9405
#
# Epoch 00012: val_loss did not improve from 0.17313
# Epoch 13/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1479 - accuracy: 0.9528 - val_loss: 0.1867 - val_accuracy: 0.9395
#
# Epoch 00013: val_loss did not improve from 0.17313
# Epoch 14/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1446 - accuracy: 0.9516 - val_loss: 0.2001 - val_accuracy: 0.9390
#
# Epoch 00014: val_loss did not improve from 0.17313
# Epoch 15/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1406 - accuracy: 0.9537 - val_loss: 0.1946 - val_accuracy: 0.9445
#
# Epoch 00015: val_loss did not improve from 0.17313
# Epoch 16/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1323 - accuracy: 0.9564 - val_loss: 0.1875 - val_accuracy: 0.9450
#
# Epoch 00016: val_loss did not improve from 0.17313
# Epoch 17/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1265 - accuracy: 0.9582 - val_loss: 0.1968 - val_accuracy: 0.9405
#
# Epoch 00017: val_loss did not improve from 0.17313
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1258 - accuracy: 0.9578 - val_loss: 0.1882 - val_accuracy: 0.9445
#
# Epoch 00018: val_loss did not improve from 0.17313
# Epoch 19/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1166 - accuracy: 0.9604 - val_loss: 0.1833 - val_accuracy: 0.9430
#
# Epoch 00019: val_loss did not improve from 0.17313
# Epoch 20/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1174 - accuracy: 0.9588 - val_loss: 0.1995 - val_accuracy: 0.9445
#
# Epoch 00020: val_loss did not improve from 0.17313
# Epoch 21/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1164 - accuracy: 0.9606 - val_loss: 0.1998 - val_accuracy: 0.9425
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.17313
# Epoch 22/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0964 - accuracy: 0.9680 - val_loss: 0.2022 - val_accuracy: 0.9460
#
# Epoch 00022: val_loss did not improve from 0.17313
# Epoch 23/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0906 - accuracy: 0.9686 - val_loss: 0.1789 - val_accuracy: 0.9485
#
# Epoch 00023: val_loss did not improve from 0.17313
# Epoch 24/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0845 - accuracy: 0.9718 - val_loss: 0.2015 - val_accuracy: 0.9470
#
# Epoch 00024: val_loss did not improve from 0.17313
# Epoch 25/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0883 - accuracy: 0.9708 - val_loss: 0.1927 - val_accuracy: 0.9485
#
# Epoch 00025: val_loss did not improve from 0.17313
# Epoch 26/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0869 - accuracy: 0.9698 - val_loss: 0.1827 - val_accuracy: 0.9510
#
# Epoch 00026: val_loss did not improve from 0.17313
# Epoch 27/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0795 - accuracy: 0.9734 - val_loss: 0.1918 - val_accuracy: 0.9480
#
# Epoch 00027: val_loss did not improve from 0.17313
# Epoch 28/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0829 - accuracy: 0.9717 - val_loss: 0.1868 - val_accuracy: 0.9475
#
# Epoch 00028: val_loss did not improve from 0.17313
# Epoch 29/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0808 - accuracy: 0.9731 - val_loss: 0.1985 - val_accuracy: 0.9465
#
# Epoch 00029: val_loss did not improve from 0.17313
# Epoch 30/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0789 - accuracy: 0.9730 - val_loss: 0.1970 - val_accuracy: 0.9520
#
# Epoch 00030: val_loss did not improve from 0.17313
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0714 - accuracy: 0.9759 - val_loss: 0.1967 - val_accuracy: 0.9470
#
# Epoch 00031: val_loss did not improve from 0.17313
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0777 - accuracy: 0.9736 - val_loss: 0.1988 - val_accuracy: 0.9505
#
# Epoch 00032: val_loss did not improve from 0.17313
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0778 - accuracy: 0.9743 - val_loss: 0.2060 - val_accuracy: 0.9490
#
# Epoch 00033: val_loss did not improve from 0.17313
# Epoch 34/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0749 - accuracy: 0.9740 - val_loss: 0.1999 - val_accuracy: 0.9490
#
# Epoch 00034: val_loss did not improve from 0.17313
# Epoch 35/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0722 - accuracy: 0.9749 - val_loss: 0.1913 - val_accuracy: 0.9505
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00035: val_loss did not improve from 0.17313
# Score for fold 3: loss of 0.19125594198703766; accuracy of 95.05000114440918%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6257 - accuracy: 0.8148 - val_loss: 0.3976 - val_accuracy: 0.8855
#
# Epoch 00001: val_loss did not improve from 0.17313
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3488 - accuracy: 0.8913 - val_loss: 0.2887 - val_accuracy: 0.9100
#
# Epoch 00002: val_loss did not improve from 0.17313
# Epoch 3/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2977 - accuracy: 0.9061 - val_loss: 0.2536 - val_accuracy: 0.9195
#
# Epoch 00003: val_loss did not improve from 0.17313
# Epoch 4/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2681 - accuracy: 0.9164 - val_loss: 0.2309 - val_accuracy: 0.9285
#
# Epoch 00004: val_loss did not improve from 0.17313
# Epoch 5/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2366 - accuracy: 0.9239 - val_loss: 0.2147 - val_accuracy: 0.9355
#
# Epoch 00005: val_loss did not improve from 0.17313
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2233 - accuracy: 0.9289 - val_loss: 0.2234 - val_accuracy: 0.9345
#
# Epoch 00006: val_loss did not improve from 0.17313
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2056 - accuracy: 0.9333 - val_loss: 0.2064 - val_accuracy: 0.9345
#
# Epoch 00007: val_loss did not improve from 0.17313
# Epoch 8/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1986 - accuracy: 0.9365 - val_loss: 0.2003 - val_accuracy: 0.9385
#
# Epoch 00008: val_loss did not improve from 0.17313
# Epoch 9/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1852 - accuracy: 0.9394 - val_loss: 0.1921 - val_accuracy: 0.9405
#
# Epoch 00009: val_loss did not improve from 0.17313
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1706 - accuracy: 0.9428 - val_loss: 0.2008 - val_accuracy: 0.9435
#
# Epoch 00010: val_loss did not improve from 0.17313
# Epoch 11/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1647 - accuracy: 0.9446 - val_loss: 0.1941 - val_accuracy: 0.9425
#
# Epoch 00011: val_loss did not improve from 0.17313
# Epoch 12/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1535 - accuracy: 0.9499 - val_loss: 0.1881 - val_accuracy: 0.9415
#
# Epoch 00012: val_loss did not improve from 0.17313
# Epoch 13/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1466 - accuracy: 0.9505 - val_loss: 0.1971 - val_accuracy: 0.9430
#
# Epoch 00013: val_loss did not improve from 0.17313
# Epoch 14/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1450 - accuracy: 0.9523 - val_loss: 0.1906 - val_accuracy: 0.9445
#
# Epoch 00014: val_loss did not improve from 0.17313
# Epoch 15/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1314 - accuracy: 0.9553 - val_loss: 0.1999 - val_accuracy: 0.9430
#
# Epoch 00015: val_loss did not improve from 0.17313
# Epoch 16/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1266 - accuracy: 0.9577 - val_loss: 0.1958 - val_accuracy: 0.9490
#
# Epoch 00016: val_loss did not improve from 0.17313
# Epoch 17/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1259 - accuracy: 0.9563 - val_loss: 0.2005 - val_accuracy: 0.9460
#
# Epoch 00017: val_loss did not improve from 0.17313
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1184 - accuracy: 0.9603 - val_loss: 0.2017 - val_accuracy: 0.9490
#
# Epoch 00018: val_loss did not improve from 0.17313
# Epoch 19/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1150 - accuracy: 0.9619 - val_loss: 0.2125 - val_accuracy: 0.9490
#
# Epoch 00019: val_loss did not improve from 0.17313
# Epoch 20/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1124 - accuracy: 0.9624 - val_loss: 0.2392 - val_accuracy: 0.9500
#
# Epoch 00020: val_loss did not improve from 0.17313
# Epoch 21/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1072 - accuracy: 0.9637 - val_loss: 0.1994 - val_accuracy: 0.9470
#
# Epoch 00021: val_loss did not improve from 0.17313
# Epoch 22/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1043 - accuracy: 0.9656 - val_loss: 0.2185 - val_accuracy: 0.9495
#
# Epoch 00022: val_loss did not improve from 0.17313
# Epoch 23/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1025 - accuracy: 0.9657 - val_loss: 0.2031 - val_accuracy: 0.9505
#
# Epoch 00023: val_loss did not improve from 0.17313
# Epoch 24/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1009 - accuracy: 0.9661 - val_loss: 0.1959 - val_accuracy: 0.9470
#
# Epoch 00024: val_loss did not improve from 0.17313
# Epoch 25/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0952 - accuracy: 0.9677 - val_loss: 0.2124 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.17313
# Epoch 26/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0920 - accuracy: 0.9689 - val_loss: 0.2215 - val_accuracy: 0.9510
#
# Epoch 00026: val_loss did not improve from 0.17313
# Epoch 27/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0963 - accuracy: 0.9662 - val_loss: 0.2314 - val_accuracy: 0.9495
#
# Epoch 00027: val_loss did not improve from 0.17313
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0863 - accuracy: 0.9711 - val_loss: 0.2288 - val_accuracy: 0.9460
#
# Epoch 00028: val_loss did not improve from 0.17313
# Epoch 29/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0860 - accuracy: 0.9710 - val_loss: 0.2300 - val_accuracy: 0.9475
#
# Epoch 00029: val_loss did not improve from 0.17313
# Epoch 30/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0838 - accuracy: 0.9711 - val_loss: 0.2691 - val_accuracy: 0.9455
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00030: val_loss did not improve from 0.17313
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0733 - accuracy: 0.9749 - val_loss: 0.2359 - val_accuracy: 0.9480
#
# Epoch 00031: val_loss did not improve from 0.17313
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0703 - accuracy: 0.9749 - val_loss: 0.2440 - val_accuracy: 0.9485
#
# Epoch 00032: val_loss did not improve from 0.17313
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0677 - accuracy: 0.9769 - val_loss: 0.2500 - val_accuracy: 0.9500
#
# Epoch 00033: val_loss did not improve from 0.17313
# Epoch 34/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0691 - accuracy: 0.9762 - val_loss: 0.2532 - val_accuracy: 0.9490
#
# Epoch 00034: val_loss did not improve from 0.17313
# Epoch 35/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0672 - accuracy: 0.9756 - val_loss: 0.2632 - val_accuracy: 0.9515
#
# Epoch 00035: val_loss did not improve from 0.17313
# Score for fold 4: loss of 0.26322922110557556; accuracy of 95.14999985694885%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6306 - accuracy: 0.8141 - val_loss: 0.3773 - val_accuracy: 0.8735
#
# Epoch 00001: val_loss did not improve from 0.17313
# Epoch 2/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3611 - accuracy: 0.8832 - val_loss: 0.3077 - val_accuracy: 0.9025
#
# Epoch 00002: val_loss did not improve from 0.17313
# Epoch 3/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3017 - accuracy: 0.9032 - val_loss: 0.2617 - val_accuracy: 0.9140
#
# Epoch 00003: val_loss did not improve from 0.17313
# Epoch 4/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.2606 - accuracy: 0.9178 - val_loss: 0.2313 - val_accuracy: 0.9220
#
# Epoch 00004: val_loss did not improve from 0.17313
# Epoch 5/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.2448 - accuracy: 0.9208 - val_loss: 0.2180 - val_accuracy: 0.9270
#
# Epoch 00005: val_loss did not improve from 0.17313
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2250 - accuracy: 0.9280 - val_loss: 0.2220 - val_accuracy: 0.9315
#
# Epoch 00006: val_loss did not improve from 0.17313
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2050 - accuracy: 0.9342 - val_loss: 0.1958 - val_accuracy: 0.9335
#
# Epoch 00007: val_loss did not improve from 0.17313
# Epoch 8/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1947 - accuracy: 0.9359 - val_loss: 0.1887 - val_accuracy: 0.9360
#
# Epoch 00008: val_loss did not improve from 0.17313
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1843 - accuracy: 0.9393 - val_loss: 0.1782 - val_accuracy: 0.9405
#
# Epoch 00009: val_loss did not improve from 0.17313
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1732 - accuracy: 0.9434 - val_loss: 0.1822 - val_accuracy: 0.9370
#
# Epoch 00010: val_loss did not improve from 0.17313
# Epoch 11/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1666 - accuracy: 0.9457 - val_loss: 0.1625 - val_accuracy: 0.9475
#
# Epoch 00011: val_loss improved from 0.17313 to 0.16253, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 12/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1534 - accuracy: 0.9505 - val_loss: 0.1670 - val_accuracy: 0.9440
#
# Epoch 00012: val_loss did not improve from 0.16253
# Epoch 13/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1444 - accuracy: 0.9514 - val_loss: 0.1674 - val_accuracy: 0.9460
#
# Epoch 00013: val_loss did not improve from 0.16253
# Epoch 14/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1401 - accuracy: 0.9533 - val_loss: 0.1666 - val_accuracy: 0.9450
#
# Epoch 00014: val_loss did not improve from 0.16253
# Epoch 15/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1322 - accuracy: 0.9569 - val_loss: 0.1571 - val_accuracy: 0.9460
#
# Epoch 00015: val_loss improved from 0.16253 to 0.15711, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 16/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1301 - accuracy: 0.9576 - val_loss: 0.1605 - val_accuracy: 0.9470
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.15711
# Epoch 17/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1065 - accuracy: 0.9657 - val_loss: 0.1645 - val_accuracy: 0.9475
#
# Epoch 00017: val_loss did not improve from 0.15711
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1043 - accuracy: 0.9653 - val_loss: 0.1663 - val_accuracy: 0.9455
#
# Epoch 00018: val_loss did not improve from 0.15711
# Epoch 19/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1015 - accuracy: 0.9658 - val_loss: 0.1574 - val_accuracy: 0.9475
#
# Epoch 00019: val_loss did not improve from 0.15711
# Epoch 20/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0917 - accuracy: 0.9694 - val_loss: 0.1647 - val_accuracy: 0.9480
#
# Epoch 00020: val_loss did not improve from 0.15711
# Epoch 21/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0952 - accuracy: 0.9696 - val_loss: 0.1646 - val_accuracy: 0.9500
#
# Epoch 00021: val_loss did not improve from 0.15711
# Epoch 22/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0909 - accuracy: 0.9699 - val_loss: 0.1622 - val_accuracy: 0.9510
#
# Epoch 00022: val_loss did not improve from 0.15711
# Epoch 23/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0865 - accuracy: 0.9708 - val_loss: 0.1649 - val_accuracy: 0.9465
#
# Epoch 00023: val_loss did not improve from 0.15711
# Epoch 24/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0825 - accuracy: 0.9729 - val_loss: 0.1739 - val_accuracy: 0.9470
#
# Epoch 00024: val_loss did not improve from 0.15711
# Epoch 25/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0839 - accuracy: 0.9717 - val_loss: 0.1697 - val_accuracy: 0.9485
#
# Epoch 00025: val_loss did not improve from 0.15711
# Epoch 26/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0818 - accuracy: 0.9730 - val_loss: 0.1743 - val_accuracy: 0.9470
#
# Epoch 00026: val_loss did not improve from 0.15711
# Epoch 27/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0802 - accuracy: 0.9730 - val_loss: 0.1783 - val_accuracy: 0.9490
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.15711
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0712 - accuracy: 0.9755 - val_loss: 0.1750 - val_accuracy: 0.9515
#
# Epoch 00028: val_loss did not improve from 0.15711
# Epoch 29/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0704 - accuracy: 0.9756 - val_loss: 0.1734 - val_accuracy: 0.9480
#
# Epoch 00029: val_loss did not improve from 0.15711
# Epoch 30/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0671 - accuracy: 0.9766 - val_loss: 0.1798 - val_accuracy: 0.9505
#
# Epoch 00030: val_loss did not improve from 0.15711
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0670 - accuracy: 0.9768 - val_loss: 0.1941 - val_accuracy: 0.9470
#
# Epoch 00031: val_loss did not improve from 0.15711
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0700 - accuracy: 0.9762 - val_loss: 0.1823 - val_accuracy: 0.9470
#
# Epoch 00032: val_loss did not improve from 0.15711
# Epoch 33/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0657 - accuracy: 0.9774 - val_loss: 0.1793 - val_accuracy: 0.9495
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.15711
# Epoch 34/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0640 - accuracy: 0.9783 - val_loss: 0.1836 - val_accuracy: 0.9500
#
# Epoch 00034: val_loss did not improve from 0.15711
# Epoch 35/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0625 - accuracy: 0.9782 - val_loss: 0.1786 - val_accuracy: 0.9490
#
# Epoch 00035: val_loss did not improve from 0.15711
# Score for fold 5: loss of 0.17862586677074432; accuracy of 94.90000009536743%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6857 - accuracy: 0.7994 - val_loss: 0.3802 - val_accuracy: 0.8705
#
# Epoch 00001: val_loss did not improve from 0.15711
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3855 - accuracy: 0.8789 - val_loss: 0.2912 - val_accuracy: 0.9120
#
# Epoch 00002: val_loss did not improve from 0.15711
# Epoch 3/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3080 - accuracy: 0.9014 - val_loss: 0.2453 - val_accuracy: 0.9250
#
# Epoch 00003: val_loss did not improve from 0.15711
# Epoch 4/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.2709 - accuracy: 0.9136 - val_loss: 0.1937 - val_accuracy: 0.9365
#
# Epoch 00004: val_loss did not improve from 0.15711
# Epoch 5/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2435 - accuracy: 0.9212 - val_loss: 0.1892 - val_accuracy: 0.9445
#
# Epoch 00005: val_loss did not improve from 0.15711
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2238 - accuracy: 0.9262 - val_loss: 0.1691 - val_accuracy: 0.9520
#
# Epoch 00006: val_loss did not improve from 0.15711
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2158 - accuracy: 0.9307 - val_loss: 0.1638 - val_accuracy: 0.9510
#
# Epoch 00007: val_loss did not improve from 0.15711
# Epoch 8/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1999 - accuracy: 0.9343 - val_loss: 0.1605 - val_accuracy: 0.9550
#
# Epoch 00008: val_loss did not improve from 0.15711
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1864 - accuracy: 0.9389 - val_loss: 0.1736 - val_accuracy: 0.9520
#
# Epoch 00009: val_loss did not improve from 0.15711
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1812 - accuracy: 0.9408 - val_loss: 0.1638 - val_accuracy: 0.9505
#
# Epoch 00010: val_loss did not improve from 0.15711
# Epoch 11/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1716 - accuracy: 0.9446 - val_loss: 0.1505 - val_accuracy: 0.9545
#
# Epoch 00011: val_loss improved from 0.15711 to 0.15054, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 12/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1635 - accuracy: 0.9478 - val_loss: 0.1614 - val_accuracy: 0.9510
#
# Epoch 00012: val_loss did not improve from 0.15054
# Epoch 13/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1529 - accuracy: 0.9482 - val_loss: 0.1493 - val_accuracy: 0.9550
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss improved from 0.15054 to 0.14927, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 14/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1364 - accuracy: 0.9537 - val_loss: 0.1474 - val_accuracy: 0.9585
#
# Epoch 00014: val_loss improved from 0.14927 to 0.14742, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 15/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1266 - accuracy: 0.9572 - val_loss: 0.1334 - val_accuracy: 0.9615
#
# Epoch 00015: val_loss improved from 0.14742 to 0.13342, saving model to /Users/Max/Documents/GitHub/learning_curve/cnn20000-local-v009\model.h5
# Epoch 16/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1233 - accuracy: 0.9589 - val_loss: 0.1475 - val_accuracy: 0.9600
#
# Epoch 00016: val_loss did not improve from 0.13342
# Epoch 17/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1166 - accuracy: 0.9617 - val_loss: 0.1423 - val_accuracy: 0.9625
#
# Epoch 00017: val_loss did not improve from 0.13342
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1158 - accuracy: 0.9600 - val_loss: 0.1746 - val_accuracy: 0.9540
#
# Epoch 00018: val_loss did not improve from 0.13342
# Epoch 19/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1123 - accuracy: 0.9618 - val_loss: 0.1408 - val_accuracy: 0.9610
#
# Epoch 00019: val_loss did not improve from 0.13342
# Epoch 20/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1087 - accuracy: 0.9616 - val_loss: 0.1441 - val_accuracy: 0.9615
#
# Epoch 00020: val_loss did not improve from 0.13342
# Epoch 21/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1059 - accuracy: 0.9644 - val_loss: 0.1430 - val_accuracy: 0.9620
#
# Epoch 00021: val_loss did not improve from 0.13342
# Epoch 22/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.1020 - accuracy: 0.9657 - val_loss: 0.1523 - val_accuracy: 0.9605
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.13342
# Epoch 23/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0929 - accuracy: 0.9686 - val_loss: 0.1490 - val_accuracy: 0.9625
#
# Epoch 00023: val_loss did not improve from 0.13342
# Epoch 24/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0919 - accuracy: 0.9691 - val_loss: 0.1444 - val_accuracy: 0.9635
#
# Epoch 00024: val_loss did not improve from 0.13342
# Epoch 25/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0892 - accuracy: 0.9696 - val_loss: 0.1482 - val_accuracy: 0.9630
#
# Epoch 00025: val_loss did not improve from 0.13342
# Epoch 26/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0872 - accuracy: 0.9714 - val_loss: 0.1517 - val_accuracy: 0.9630
#
# Epoch 00026: val_loss did not improve from 0.13342
# Epoch 27/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0854 - accuracy: 0.9707 - val_loss: 0.1440 - val_accuracy: 0.9630
#
# Epoch 00027: val_loss did not improve from 0.13342
# Epoch 28/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0849 - accuracy: 0.9714 - val_loss: 0.1508 - val_accuracy: 0.9635
#
# Epoch 00028: val_loss did not improve from 0.13342
# Epoch 29/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0821 - accuracy: 0.9721 - val_loss: 0.1430 - val_accuracy: 0.9640
#
# Epoch 00029: val_loss did not improve from 0.13342
# Epoch 30/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0833 - accuracy: 0.9716 - val_loss: 0.1557 - val_accuracy: 0.9635
#
# Epoch 00030: val_loss did not improve from 0.13342
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0808 - accuracy: 0.9726 - val_loss: 0.1475 - val_accuracy: 0.9635
#
# Epoch 00031: val_loss did not improve from 0.13342
# Epoch 32/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0787 - accuracy: 0.9733 - val_loss: 0.1504 - val_accuracy: 0.9665
#
# Epoch 00032: val_loss did not improve from 0.13342
# Epoch 33/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0748 - accuracy: 0.9737 - val_loss: 0.1494 - val_accuracy: 0.9655
#
# Epoch 00033: val_loss did not improve from 0.13342
# Epoch 34/35
# 563/563 [==============================] - 3s 5ms/step - loss: 0.0796 - accuracy: 0.9729 - val_loss: 0.1531 - val_accuracy: 0.9640
#
# Epoch 00034: val_loss did not improve from 0.13342
# Epoch 35/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0794 - accuracy: 0.9732 - val_loss: 0.1620 - val_accuracy: 0.9620
#
# Epoch 00035: val_loss did not improve from 0.13342
# Score for fold 6: loss of 0.16195952892303467; accuracy of 96.20000123977661%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6855 - accuracy: 0.7984 - val_loss: 0.3556 - val_accuracy: 0.9030
#
# Epoch 00001: val_loss did not improve from 0.13342
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3859 - accuracy: 0.8792 - val_loss: 0.2602 - val_accuracy: 0.9145
#
# Epoch 00002: val_loss did not improve from 0.13342
# Epoch 3/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3138 - accuracy: 0.9006 - val_loss: 0.2063 - val_accuracy: 0.9370
#
# Epoch 00003: val_loss did not improve from 0.13342
# Epoch 4/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2769 - accuracy: 0.9113 - val_loss: 0.2025 - val_accuracy: 0.9315
#
# Epoch 00004: val_loss did not improve from 0.13342
# Epoch 5/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2584 - accuracy: 0.9145 - val_loss: 0.1959 - val_accuracy: 0.9355
#
# Epoch 00005: val_loss did not improve from 0.13342
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2395 - accuracy: 0.9205 - val_loss: 0.1743 - val_accuracy: 0.9475
#
# Epoch 00006: val_loss did not improve from 0.13342
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2258 - accuracy: 0.9251 - val_loss: 0.1702 - val_accuracy: 0.9465
#
# Epoch 00007: val_loss did not improve from 0.13342
# Epoch 8/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2128 - accuracy: 0.9303 - val_loss: 0.1788 - val_accuracy: 0.9460
#
# Epoch 00008: val_loss did not improve from 0.13342
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2031 - accuracy: 0.9342 - val_loss: 0.1589 - val_accuracy: 0.9470
#
# Epoch 00009: val_loss did not improve from 0.13342
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1912 - accuracy: 0.9368 - val_loss: 0.1535 - val_accuracy: 0.9500
#
# Epoch 00010: val_loss did not improve from 0.13342
# Epoch 11/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1830 - accuracy: 0.9394 - val_loss: 0.1540 - val_accuracy: 0.9500
#
# Epoch 00011: val_loss did not improve from 0.13342
# Epoch 12/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1718 - accuracy: 0.9434 - val_loss: 0.1492 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.13342
# Epoch 13/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1652 - accuracy: 0.9447 - val_loss: 0.1497 - val_accuracy: 0.9560
#
# Epoch 00013: val_loss did not improve from 0.13342
# Epoch 14/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1580 - accuracy: 0.9468 - val_loss: 0.1510 - val_accuracy: 0.9560
#
# Epoch 00014: val_loss did not improve from 0.13342
# Epoch 15/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1510 - accuracy: 0.9502 - val_loss: 0.1553 - val_accuracy: 0.9510
#
# Epoch 00015: val_loss did not improve from 0.13342
# Epoch 16/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1490 - accuracy: 0.9521 - val_loss: 0.1438 - val_accuracy: 0.9575
#
# Epoch 00016: val_loss did not improve from 0.13342
# Epoch 17/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1460 - accuracy: 0.9521 - val_loss: 0.1631 - val_accuracy: 0.9515
#
# Epoch 00017: val_loss did not improve from 0.13342
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1388 - accuracy: 0.9526 - val_loss: 0.1449 - val_accuracy: 0.9560
#
# Epoch 00018: val_loss did not improve from 0.13342
# Epoch 19/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1272 - accuracy: 0.9569 - val_loss: 0.1540 - val_accuracy: 0.9515
#
# Epoch 00019: val_loss did not improve from 0.13342
# Epoch 20/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1276 - accuracy: 0.9565 - val_loss: 0.1567 - val_accuracy: 0.9535
#
# Epoch 00020: val_loss did not improve from 0.13342
# Epoch 21/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1247 - accuracy: 0.9596 - val_loss: 0.1420 - val_accuracy: 0.9565
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.13342
# Epoch 22/35
# ...
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1043 - accuracy: 0.9652 - val_loss: 0.1989 - val_accuracy: 0.9515
#
# Epoch 00028: val_loss did not improve from 0.13342
# Epoch 29/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0980 - accuracy: 0.9666 - val_loss: 0.2022 - val_accuracy: 0.9525
#
# Epoch 00029: val_loss did not improve from 0.13342
# Epoch 30/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0984 - accuracy: 0.9674 - val_loss: 0.2210 - val_accuracy: 0.9505
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00030: val_loss did not improve from 0.13342
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0814 - accuracy: 0.9730 - val_loss: 0.2038 - val_accuracy: 0.9550
#
# Epoch 00031: val_loss did not improve from 0.13342
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0799 - accuracy: 0.9727 - val_loss: 0.2353 - val_accuracy: 0.9500
#
# Epoch 00032: val_loss did not improve from 0.13342
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0781 - accuracy: 0.9742 - val_loss: 0.2196 - val_accuracy: 0.9535
#
# Epoch 00033: val_loss did not improve from 0.13342
# Epoch 34/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0747 - accuracy: 0.9754 - val_loss: 0.2082 - val_accuracy: 0.9545
#
# Epoch 00034: val_loss did not improve from 0.13342
# Epoch 35/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0756 - accuracy: 0.9741 - val_loss: 0.2115 - val_accuracy: 0.9535
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00035: val_loss did not improve from 0.13342
# Score for fold 8: loss of 0.2114958018064499; accuracy of 95.3499972820282%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.6625 - accuracy: 0.8067 - val_loss: 0.3703 - val_accuracy: 0.8670
#
# Epoch 00001: val_loss did not improve from 0.13342
# Epoch 2/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.3467 - accuracy: 0.8894 - val_loss: 0.2955 - val_accuracy: 0.9160
#
# Epoch 00002: val_loss did not improve from 0.13342
# Epoch 3/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2879 - accuracy: 0.9084 - val_loss: 0.2734 - val_accuracy: 0.9015
#
# Epoch 00003: val_loss did not improve from 0.13342
# Epoch 4/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2521 - accuracy: 0.9176 - val_loss: 0.2473 - val_accuracy: 0.9195
#
# Epoch 00004: val_loss did not improve from 0.13342
# Epoch 5/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2287 - accuracy: 0.9256 - val_loss: 0.2351 - val_accuracy: 0.9215
#
# Epoch 00005: val_loss did not improve from 0.13342
# Epoch 6/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.2103 - accuracy: 0.9316 - val_loss: 0.2016 - val_accuracy: 0.9355
#
# Epoch 00006: val_loss did not improve from 0.13342
# Epoch 7/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1979 - accuracy: 0.9360 - val_loss: 0.2021 - val_accuracy: 0.9340
#
# Epoch 00007: val_loss did not improve from 0.13342
# Epoch 8/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1837 - accuracy: 0.9403 - val_loss: 0.1961 - val_accuracy: 0.9385
#
# Epoch 00008: val_loss did not improve from 0.13342
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1744 - accuracy: 0.9444 - val_loss: 0.1907 - val_accuracy: 0.9385
#
# Epoch 00009: val_loss did not improve from 0.13342
# Epoch 10/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1618 - accuracy: 0.9456 - val_loss: 0.1835 - val_accuracy: 0.9455
#
# Epoch 00010: val_loss did not improve from 0.13342
# Epoch 11/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1529 - accuracy: 0.9519 - val_loss: 0.1908 - val_accuracy: 0.9380
#
# Epoch 00011: val_loss did not improve from 0.13342
# Epoch 12/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1492 - accuracy: 0.9511 - val_loss: 0.1759 - val_accuracy: 0.9445
#
# Epoch 00012: val_loss did not improve from 0.13342
# Epoch 13/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1480 - accuracy: 0.9522 - val_loss: 0.1833 - val_accuracy: 0.9455
#
# Epoch 00013: val_loss did not improve from 0.13342
# Epoch 14/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1336 - accuracy: 0.9562 - val_loss: 0.1780 - val_accuracy: 0.9455
#
# Epoch 00014: val_loss did not improve from 0.13342
# Epoch 15/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1210 - accuracy: 0.9606 - val_loss: 0.1786 - val_accuracy: 0.9455
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.13342
# Epoch 16/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1059 - accuracy: 0.9648 - val_loss: 0.1827 - val_accuracy: 0.9460
#
# Epoch 00016: val_loss did not improve from 0.13342
# Epoch 17/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1024 - accuracy: 0.9665 - val_loss: 0.1741 - val_accuracy: 0.9460
#
# Epoch 00017: val_loss did not improve from 0.13342
# Epoch 18/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0990 - accuracy: 0.9668 - val_loss: 0.1818 - val_accuracy: 0.9505
#
# Epoch 00018: val_loss did not improve from 0.13342
# Epoch 19/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.1783 - val_accuracy: 0.9450
#
# Epoch 00019: val_loss did not improve from 0.13342
# Epoch 20/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0926 - accuracy: 0.9684 - val_loss: 0.1752 - val_accuracy: 0.9485
#
# Epoch 00020: val_loss did not improve from 0.13342
# Epoch 21/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0911 - accuracy: 0.9694 - val_loss: 0.1827 - val_accuracy: 0.9485
#
# Epoch 00021: val_loss did not improve from 0.13342
# Epoch 22/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0883 - accuracy: 0.9706 - val_loss: 0.1789 - val_accuracy: 0.9475
#
# Epoch 00022: val_loss did not improve from 0.13342
# Epoch 23/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0869 - accuracy: 0.9704 - val_loss: 0.1798 - val_accuracy: 0.9485
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_loss did not improve from 0.13342
# Epoch 24/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0774 - accuracy: 0.9749 - val_loss: 0.1852 - val_accuracy: 0.9490
#
# Epoch 00024: val_loss did not improve from 0.13342
# Epoch 25/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0775 - accuracy: 0.9738 - val_loss: 0.1794 - val_accuracy: 0.9480
#
# Epoch 00025: val_loss did not improve from 0.13342
# Epoch 26/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0732 - accuracy: 0.9756 - val_loss: 0.1938 - val_accuracy: 0.9495
#
# Epoch 00026: val_loss did not improve from 0.13342
# Epoch 27/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0708 - accuracy: 0.9760 - val_loss: 0.1956 - val_accuracy: 0.9495
#
# Epoch 00027: val_loss did not improve from 0.13342
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0712 - accuracy: 0.9747 - val_loss: 0.2022 - val_accuracy: 0.9495
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00028: val_loss did not improve from 0.13342
# Epoch 29/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0661 - accuracy: 0.9782 - val_loss: 0.1980 - val_accuracy: 0.9505
#
# Epoch 00029: val_loss did not improve from 0.13342
# Epoch 30/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0669 - accuracy: 0.9768 - val_loss: 0.1942 - val_accuracy: 0.9505
#
# Epoch 00030: val_loss did not improve from 0.13342
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0668 - accuracy: 0.9764 - val_loss: 0.2037 - val_accuracy: 0.9495
#
# Epoch 00031: val_loss did not improve from 0.13342
# Epoch 32/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0635 - accuracy: 0.9786 - val_loss: 0.1990 - val_accuracy: 0.9490
#
# Epoch 00032: val_loss did not improve from 0.13342
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0642 - accuracy: 0.9781 - val_loss: 0.2083 - val_accuracy: 0.9500
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00033: val_loss did not improve from 0.13342
# Epoch 34/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0626 - accuracy: 0.9791 - val_loss: 0.2094 - val_accuracy: 0.9480
#
# Epoch 00034: val_loss did not improve from 0.13342
# Epoch 35/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0619 - accuracy: 0.9785 - val_loss: 0.2114 - val_accuracy: 0.9500
#
# Epoch 00035: val_loss did not improve from 0.13342
# Score for fold 9: loss of 0.211428701877594; accuracy of 94.9999988079071%
# Epoch 1/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.7027 - accuracy: 0.7951 - val_loss: 0.4181 - val_accuracy: 0.8665
#
# Epoch 00001: val_loss did not improve from 0.13342
# Epoch 2/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3887 - accuracy: 0.8775 - val_loss: 0.3297 - val_accuracy: 0.8940
#
# Epoch 00002: val_loss did not improve from 0.13342
# Epoch 3/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.3071 - accuracy: 0.9031 - val_loss: 0.2649 - val_accuracy: 0.9115
#
# Epoch 00003: val_loss did not improve from 0.13342
# Epoch 4/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2719 - accuracy: 0.9141 - val_loss: 0.2543 - val_accuracy: 0.9200
#
# Epoch 00004: val_loss did not improve from 0.13342
# Epoch 5/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2415 - accuracy: 0.9208 - val_loss: 0.2260 - val_accuracy: 0.9260
#
# Epoch 00005: val_loss did not improve from 0.13342
# Epoch 6/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2264 - accuracy: 0.9263 - val_loss: 0.2354 - val_accuracy: 0.9260
#
# Epoch 00006: val_loss did not improve from 0.13342
# Epoch 7/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.2097 - accuracy: 0.9317 - val_loss: 0.2170 - val_accuracy: 0.9335
#
# Epoch 00007: val_loss did not improve from 0.13342
# Epoch 8/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1974 - accuracy: 0.9358 - val_loss: 0.2120 - val_accuracy: 0.9350
#
# Epoch 00008: val_loss did not improve from 0.13342
# Epoch 9/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1886 - accuracy: 0.9383 - val_loss: 0.2245 - val_accuracy: 0.9345
#
# Epoch 00009: val_loss did not improve from 0.13342
# Epoch 10/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1766 - accuracy: 0.9414 - val_loss: 0.1923 - val_accuracy: 0.9390
#
# Epoch 00010: val_loss did not improve from 0.13342
# Epoch 11/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1682 - accuracy: 0.9463 - val_loss: 0.2083 - val_accuracy: 0.9400
#
# Epoch 00011: val_loss did not improve from 0.13342
# Epoch 12/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1552 - accuracy: 0.9487 - val_loss: 0.2008 - val_accuracy: 0.9390
#
# Epoch 00012: val_loss did not improve from 0.13342
# Epoch 13/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1522 - accuracy: 0.9499 - val_loss: 0.2243 - val_accuracy: 0.9375
#
# Epoch 00013: val_loss did not improve from 0.13342
# Epoch 14/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1430 - accuracy: 0.9514 - val_loss: 0.2017 - val_accuracy: 0.9415
#
# Epoch 00014: val_loss did not improve from 0.13342
# Epoch 15/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1394 - accuracy: 0.9544 - val_loss: 0.2027 - val_accuracy: 0.9400
#
# Epoch 00015: val_loss did not improve from 0.13342
# Epoch 16/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1333 - accuracy: 0.9557 - val_loss: 0.1936 - val_accuracy: 0.9425
#
# Epoch 00016: val_loss did not improve from 0.13342
# Epoch 17/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1303 - accuracy: 0.9575 - val_loss: 0.2016 - val_accuracy: 0.9415
#
# Epoch 00017: val_loss did not improve from 0.13342
# Epoch 18/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1303 - accuracy: 0.9574 - val_loss: 0.2142 - val_accuracy: 0.9410
#
# Epoch 00018: val_loss did not improve from 0.13342
# Epoch 19/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1252 - accuracy: 0.9592 - val_loss: 0.2016 - val_accuracy: 0.9440
#
# Epoch 00019: val_loss did not improve from 0.13342
# Epoch 20/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1186 - accuracy: 0.9610 - val_loss: 0.2274 - val_accuracy: 0.9415
#
# Epoch 00020: val_loss did not improve from 0.13342
# Epoch 21/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.1099 - accuracy: 0.9632 - val_loss: 0.2122 - val_accuracy: 0.9440
#
# Epoch 00021: val_loss did not improve from 0.13342
# Epoch 22/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1084 - accuracy: 0.9647 - val_loss: 0.2487 - val_accuracy: 0.9415
#
# Epoch 00022: val_loss did not improve from 0.13342
# Epoch 23/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1080 - accuracy: 0.9638 - val_loss: 0.2296 - val_accuracy: 0.9415
#
# Epoch 00023: val_loss did not improve from 0.13342
# Epoch 24/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.1002 - accuracy: 0.9662 - val_loss: 0.2258 - val_accuracy: 0.9415
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.13342
# Epoch 25/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0897 - accuracy: 0.9693 - val_loss: 0.2350 - val_accuracy: 0.9425
#
# Epoch 00025: val_loss did not improve from 0.13342
# Epoch 26/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0857 - accuracy: 0.9709 - val_loss: 0.2316 - val_accuracy: 0.9460
#
# Epoch 00026: val_loss did not improve from 0.13342
# Epoch 27/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0828 - accuracy: 0.9731 - val_loss: 0.2196 - val_accuracy: 0.9445
#
# Epoch 00027: val_loss did not improve from 0.13342
# Epoch 28/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0810 - accuracy: 0.9726 - val_loss: 0.2389 - val_accuracy: 0.9420
#
# Epoch 00028: val_loss did not improve from 0.13342
# Epoch 29/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0813 - accuracy: 0.9722 - val_loss: 0.2335 - val_accuracy: 0.9435
#
# Epoch 00029: val_loss did not improve from 0.13342
# Epoch 30/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0782 - accuracy: 0.9732 - val_loss: 0.2269 - val_accuracy: 0.9450
#
# Epoch 00030: val_loss did not improve from 0.13342
# Epoch 31/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0760 - accuracy: 0.9737 - val_loss: 0.2190 - val_accuracy: 0.9465
#
# Epoch 00031: val_loss did not improve from 0.13342
# Epoch 32/35
# 563/563 [==============================] - 4s 6ms/step - loss: 0.0804 - accuracy: 0.9735 - val_loss: 0.2298 - val_accuracy: 0.9440
#
# Epoch 00032: val_loss did not improve from 0.13342
# Epoch 33/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0750 - accuracy: 0.9742 - val_loss: 0.2343 - val_accuracy: 0.9465
#
# Epoch 00033: val_loss did not improve from 0.13342
# Epoch 34/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0718 - accuracy: 0.9758 - val_loss: 0.2369 - val_accuracy: 0.9475
#
# Epoch 00034: val_loss did not improve from 0.13342
# Epoch 35/35
# 563/563 [==============================] - 3s 6ms/step - loss: 0.0721 - accuracy: 0.9757 - val_loss: 0.2532 - val_accuracy: 0.9450
#
# Epoch 00035: val_loss did not improve from 0.13342
# Score for fold 10: loss of 0.253187358379364; accuracy of 94.49999928474426%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.23542647063732147 - Accuracy: 95.49999833106995%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.2510700523853302 - Accuracy: 94.90000009536743%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.19125594198703766 - Accuracy: 95.05000114440918%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.26322922110557556 - Accuracy: 95.14999985694885%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.17862586677074432 - Accuracy: 94.90000009536743%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.16195952892303467 - Accuracy: 96.20000123977661%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.15386682748794556 - Accuracy: 96.35000228881836%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.2114958018064499 - Accuracy: 95.3499972820282%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.211428701877594 - Accuracy: 94.9999988079071%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.253187358379364 - Accuracy: 94.49999928474426%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.28999984264374% (+- 0.005557883810483774)
# > Loss: 0.21115457713603974
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9529      | 0.0056       |
# | Loss     | 0.2112      | 0.0372       |
# | Macro F1 | 0.8792      | 0.0125       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9763      | 0.0077       |
# | Acc      | 0.9824      | 0.004        |
# | F1       | 0.9833      | 0.0038       |
# | MCC      | 0.9647      | 0.008        |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
