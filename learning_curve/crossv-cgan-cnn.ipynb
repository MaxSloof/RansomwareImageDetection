# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 150000 # Set very high so it uses all the images in the directory, does not actually take 150,000 images

# Number of epochs
epoch_t = 35 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import time

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/learning_curve"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cgan-lc-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 1 matches(es) found
# --------------
# New folder name: cgan-lc-cnn-local-v002
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/"
    path_root_gen = '/kaggle/input/cganlocalv007/'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/lc_original"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-lc-ckpt"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 1000 images belonging to 11 classes.

# %% [markdown]
# Count number of files in the CGAN folder

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 1602 images belonging to 10 classes.

# %%
plt.imshow(imgs_gen[900],cmap='gray')

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3269 - accuracy: 0.5863 - val_loss: 0.6353 - val_accuracy: 0.7900
#
# Epoch 00001: val_loss improved from inf to 0.63531, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.4148 - accuracy: 0.9033 - val_loss: 0.5672 - val_accuracy: 0.8300
#
# Epoch 00002: val_loss improved from 0.63531 to 0.56719, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 3/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2784 - accuracy: 0.9337 - val_loss: 0.5921 - val_accuracy: 0.8500
#
# Epoch 00003: val_loss did not improve from 0.56719
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2030 - accuracy: 0.9464 - val_loss: 0.5061 - val_accuracy: 0.8500
#
# Epoch 00004: val_loss improved from 0.56719 to 0.50612, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1891 - accuracy: 0.9468 - val_loss: 0.4530 - val_accuracy: 0.8400
#
# Epoch 00005: val_loss improved from 0.50612 to 0.45296, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1461 - accuracy: 0.9560 - val_loss: 0.3838 - val_accuracy: 0.8700
#
# Epoch 00006: val_loss improved from 0.45296 to 0.38383, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 7/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1423 - accuracy: 0.9544 - val_loss: 0.4560 - val_accuracy: 0.8900
#
# Epoch 00007: val_loss did not improve from 0.38383
# Epoch 8/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1366 - accuracy: 0.9580 - val_loss: 0.4189 - val_accuracy: 0.8700
#
# Epoch 00008: val_loss did not improve from 0.38383
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1046 - accuracy: 0.9680 - val_loss: 0.3665 - val_accuracy: 0.9000
#
# Epoch 00009: val_loss improved from 0.38383 to 0.36654, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1044 - accuracy: 0.9640 - val_loss: 0.4713 - val_accuracy: 0.8600
#
# Epoch 00010: val_loss did not improve from 0.36654
# Epoch 11/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0933 - accuracy: 0.9676 - val_loss: 0.3515 - val_accuracy: 0.9100
#
# Epoch 00011: val_loss improved from 0.36654 to 0.35152, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0807 - accuracy: 0.9728 - val_loss: 0.4380 - val_accuracy: 0.8800
#
# Epoch 00012: val_loss did not improve from 0.35152
# Epoch 13/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0904 - accuracy: 0.9732 - val_loss: 0.3908 - val_accuracy: 0.8800
#
# Epoch 00013: val_loss did not improve from 0.35152
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9776 - val_loss: 0.4231 - val_accuracy: 0.9100
#
# Epoch 00014: val_loss did not improve from 0.35152
# Epoch 15/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0613 - accuracy: 0.9800 - val_loss: 0.4509 - val_accuracy: 0.9000
#
# Epoch 00015: val_loss did not improve from 0.35152
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0576 - accuracy: 0.9820 - val_loss: 0.4336 - val_accuracy: 0.9000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.35152
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0420 - accuracy: 0.9864 - val_loss: 0.3408 - val_accuracy: 0.9100
#
# Epoch 00017: val_loss improved from 0.35152 to 0.34081, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 18/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0430 - accuracy: 0.9860 - val_loss: 0.4748 - val_accuracy: 0.8700
#
# Epoch 00018: val_loss did not improve from 0.34081
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.3995 - val_accuracy: 0.9100
#
# Epoch 00019: val_loss did not improve from 0.34081
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9896 - val_loss: 0.4178 - val_accuracy: 0.9100
#
# Epoch 00020: val_loss did not improve from 0.34081
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9884 - val_loss: 0.4410 - val_accuracy: 0.9100
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.34081
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.3925 - val_accuracy: 0.8900
#
# Epoch 00022: val_loss did not improve from 0.34081
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 0.4470 - val_accuracy: 0.8900
#
# Epoch 00023: val_loss did not improve from 0.34081
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9920 - val_loss: 0.4110 - val_accuracy: 0.9100
#
# Epoch 00024: val_loss did not improve from 0.34081
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 0.5352 - val_accuracy: 0.8800
#
# Epoch 00025: val_loss did not improve from 0.34081
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.9940 - val_loss: 0.4676 - val_accuracy: 0.8700
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_loss did not improve from 0.34081
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.4587 - val_accuracy: 0.9100
#
# Epoch 00027: val_loss did not improve from 0.34081
# Epoch 28/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9924 - val_loss: 0.4399 - val_accuracy: 0.9100
#
# Epoch 00028: val_loss did not improve from 0.34081
# Epoch 29/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9968 - val_loss: 0.4409 - val_accuracy: 0.9100
#
# Epoch 00029: val_loss did not improve from 0.34081
# Epoch 30/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9948 - val_loss: 0.4540 - val_accuracy: 0.9000
#
# Epoch 00030: val_loss did not improve from 0.34081
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9952 - val_loss: 0.4547 - val_accuracy: 0.9000
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00031: val_loss did not improve from 0.34081
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9948 - val_loss: 0.4393 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.34081
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9980 - val_loss: 0.4367 - val_accuracy: 0.9000
#
# Epoch 00033: val_loss did not improve from 0.34081
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9956 - val_loss: 0.4942 - val_accuracy: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.34081
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9952 - val_loss: 0.4683 - val_accuracy: 0.8900
#
# Epoch 00035: val_loss did not improve from 0.34081
# Score for fold 1: loss of 0.4682968258857727; accuracy of 88.99999856948853%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3908 - accuracy: 0.5616 - val_loss: 0.8688 - val_accuracy: 0.7500
#
# Epoch 00001: val_loss did not improve from 0.34081
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.4020 - accuracy: 0.9069 - val_loss: 0.6362 - val_accuracy: 0.8100
# Epoch 00002: val_loss did not improve from 0.34081
# Epoch 3/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3050 - accuracy: 0.9273 - val_loss: 0.5510 - val_accuracy: 0.8300
#
# Epoch 00003: val_loss did not improve from 0.34081
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2339 - accuracy: 0.9392 - val_loss: 0.4648 - val_accuracy: 0.8600
#
# Epoch 00004: val_loss did not improve from 0.34081
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2216 - accuracy: 0.9420 - val_loss: 0.6926 - val_accuracy: 0.7900
#
# Epoch 00005: val_loss did not improve from 0.34081
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1951 - accuracy: 0.9464 - val_loss: 0.4360 - val_accuracy: 0.8500
#
# Epoch 00006: val_loss did not improve from 0.34081
# Epoch 7/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1554 - accuracy: 0.9584 - val_loss: 0.5640 - val_accuracy: 0.8200
#
# Epoch 00007: val_loss did not improve from 0.34081
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1408 - accuracy: 0.9596 - val_loss: 0.4906 - val_accuracy: 0.8800
#
# Epoch 00008: val_loss did not improve from 0.34081
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9632 - val_loss: 0.4591 - val_accuracy: 0.8800
#
# Epoch 00009: val_loss did not improve from 0.34081
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1195 - accuracy: 0.9632 - val_loss: 0.4854 - val_accuracy: 0.8700
#
# Epoch 00010: val_loss did not improve from 0.34081
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0982 - accuracy: 0.9684 - val_loss: 0.4568 - val_accuracy: 0.8700
#
# Epoch 00011: val_loss did not improve from 0.34081
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0959 - accuracy: 0.9712 - val_loss: 0.4131 - val_accuracy: 0.8800
#
# Epoch 00012: val_loss did not improve from 0.34081
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.9744 - val_loss: 0.4800 - val_accuracy: 0.8500
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.34081
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 0.9732 - val_loss: 0.4584 - val_accuracy: 0.8900
#
# Epoch 00014: val_loss did not improve from 0.34081
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9816 - val_loss: 0.4573 - val_accuracy: 0.9000
#
# Epoch 00015: val_loss did not improve from 0.34081
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 0.9832 - val_loss: 0.4745 - val_accuracy: 0.9000
#
# Epoch 00016: val_loss did not improve from 0.34081
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9856 - val_loss: 0.5567 - val_accuracy: 0.8500
#
# Epoch 00017: val_loss did not improve from 0.34081
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9828 - val_loss: 0.5469 - val_accuracy: 0.8900
#
# Epoch 00018: val_loss did not improve from 0.34081
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0687 - accuracy: 0.9800 - val_loss: 0.5774 - val_accuracy: 0.8800
#
# Epoch 00019: val_loss did not improve from 0.34081
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9904 - val_loss: 0.6241 - val_accuracy: 0.8800
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss did not improve from 0.34081
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.5478 - val_accuracy: 0.8600
#
# Epoch 00021: val_loss did not improve from 0.34081
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.5469 - val_accuracy: 0.8800
#
# Epoch 00022: val_loss did not improve from 0.34081
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0325 - accuracy: 0.9892 - val_loss: 0.5328 - val_accuracy: 0.9000
#
# Epoch 00023: val_loss did not improve from 0.34081
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0399 - accuracy: 0.9884 - val_loss: 0.5446 - val_accuracy: 0.9000
#
# Epoch 00024: val_loss did not improve from 0.34081
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0315 - accuracy: 0.9908 - val_loss: 0.5444 - val_accuracy: 0.9100
#
# Epoch 00025: val_loss did not improve from 0.34081
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0346 - accuracy: 0.9876 - val_loss: 0.5550 - val_accuracy: 0.8900
#
# Epoch 00026: val_loss did not improve from 0.34081
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9920 - val_loss: 0.5969 - val_accuracy: 0.8800
#
# Epoch 00027: val_loss did not improve from 0.34081
# Epoch 28/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.5452 - val_accuracy: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.34081
# Epoch 29/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 0.9936 - val_loss: 0.5692 - val_accuracy: 0.8900
#
# Epoch 00029: val_loss did not improve from 0.34081
# Epoch 30/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9920 - val_loss: 0.5588 - val_accuracy: 0.9000
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.34081
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 0.5587 - val_accuracy: 0.8800
#
# Epoch 00031: val_loss did not improve from 0.34081
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9944 - val_loss: 0.5811 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.34081
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9940 - val_loss: 0.5631 - val_accuracy: 0.9000
#
# Epoch 00033: val_loss did not improve from 0.34081
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.5710 - val_accuracy: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.34081
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9940 - val_loss: 0.5715 - val_accuracy: 0.9000
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.34081
# Score for fold 2: loss of 0.5715148448944092; accuracy of 89.99999761581421%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.4846 - accuracy: 0.5004 - val_loss: 0.6851 - val_accuracy: 0.8100
#
# Epoch 00001: val_loss did not improve from 0.34081
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.4902 - accuracy: 0.8777 - val_loss: 0.6858 - val_accuracy: 0.8100
#
# Epoch 00002: val_loss did not improve from 0.34081
# Epoch 3/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3014 - accuracy: 0.9229 - val_loss: 0.6792 - val_accuracy: 0.8300
#
# Epoch 00003: val_loss did not improve from 0.34081
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2456 - accuracy: 0.9361 - val_loss: 0.5786 - val_accuracy: 0.8500
#
# Epoch 00004: val_loss did not improve from 0.34081
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2054 - accuracy: 0.9424 - val_loss: 0.5724 - val_accuracy: 0.8600
#
# Epoch 00005: val_loss did not improve from 0.34081
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1944 - accuracy: 0.9416 - val_loss: 0.5598 - val_accuracy: 0.8600
#
# Epoch 00006: val_loss did not improve from 0.34081
# Epoch 7/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1627 - accuracy: 0.9484 - val_loss: 0.4974 - val_accuracy: 0.8700
#
# Epoch 00007: val_loss did not improve from 0.34081
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1489 - accuracy: 0.9528 - val_loss: 0.4652 - val_accuracy: 0.8900
#
# Epoch 00008: val_loss did not improve from 0.34081
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1389 - accuracy: 0.9628 - val_loss: 0.6111 - val_accuracy: 0.8800
#
# Epoch 00009: val_loss did not improve from 0.34081
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1269 - accuracy: 0.9620 - val_loss: 0.4332 - val_accuracy: 0.9000
#
# Epoch 00010: val_loss did not improve from 0.34081
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1156 - accuracy: 0.9664 - val_loss: 0.6287 - val_accuracy: 0.8800
#
# Epoch 00011: val_loss did not improve from 0.34081
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1060 - accuracy: 0.9640 - val_loss: 0.5566 - val_accuracy: 0.8900
#
# Epoch 00012: val_loss did not improve from 0.34081
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0956 - accuracy: 0.9720 - val_loss: 0.4567 - val_accuracy: 0.9100
#
# Epoch 00013: val_loss did not improve from 0.34081
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0889 - accuracy: 0.9724 - val_loss: 0.5963 - val_accuracy: 0.9100
#
# Epoch 00014: val_loss did not improve from 0.34081
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9776 - val_loss: 0.6112 - val_accuracy: 0.8900
#
# Epoch 00015: val_loss did not improve from 0.34081
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0768 - accuracy: 0.9780 - val_loss: 0.5946 - val_accuracy: 0.8800
#
# Epoch 00016: val_loss did not improve from 0.34081
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0694 - accuracy: 0.9792 - val_loss: 0.5471 - val_accuracy: 0.8800
#
# Epoch 00017: val_loss did not improve from 0.34081
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0767 - accuracy: 0.9768 - val_loss: 0.5333 - val_accuracy: 0.9000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.34081
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9848 - val_loss: 0.6301 - val_accuracy: 0.9300
#
# Epoch 00019: val_loss did not improve from 0.34081
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0453 - accuracy: 0.9860 - val_loss: 0.5507 - val_accuracy: 0.8900
#
# Epoch 00020: val_loss did not improve from 0.34081
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9868 - val_loss: 0.5285 - val_accuracy: 0.9200
#
# Epoch 00021: val_loss did not improve from 0.34081
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9880 - val_loss: 0.5794 - val_accuracy: 0.9000
#
# Epoch 00022: val_loss did not improve from 0.34081
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0426 - accuracy: 0.9876 - val_loss: 0.5387 - val_accuracy: 0.9100
#
# Epoch 00023: val_loss did not improve from 0.34081
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9892 - val_loss: 0.6008 - val_accuracy: 0.9200
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.34081
# Epoch 25/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 0.6333 - val_accuracy: 0.9200
#
# Epoch 00025: val_loss did not improve from 0.34081
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9884 - val_loss: 0.6095 - val_accuracy: 0.9100
#
# Epoch 00026: val_loss did not improve from 0.34081
# Epoch 27/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0314 - accuracy: 0.9896 - val_loss: 0.6207 - val_accuracy: 0.9200
#
# Epoch 00027: val_loss did not improve from 0.34081
# Epoch 28/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0378 - accuracy: 0.9884 - val_loss: 0.6130 - val_accuracy: 0.9200
#
# Epoch 00028: val_loss did not improve from 0.34081
# Epoch 29/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9912 - val_loss: 0.6675 - val_accuracy: 0.9200
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.34081
# Epoch 30/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.6712 - val_accuracy: 0.9100
#
# Epoch 00030: val_loss did not improve from 0.34081
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9908 - val_loss: 0.6392 - val_accuracy: 0.9100
#
# Epoch 00031: val_loss did not improve from 0.34081
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9936 - val_loss: 0.6232 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.34081
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9932 - val_loss: 0.6576 - val_accuracy: 0.9200
#
# Epoch 00033: val_loss did not improve from 0.34081
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 0.6384 - val_accuracy: 0.9100
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.34081
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9932 - val_loss: 0.6518 - val_accuracy: 0.9200
#
# Epoch 00035: val_loss did not improve from 0.34081
# Score for fold 3: loss of 0.6517795324325562; accuracy of 92.00000166893005%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.5486 - accuracy: 0.4812 - val_loss: 0.9155 - val_accuracy: 0.7200
#
# Epoch 00001: val_loss did not improve from 0.34081
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.5879 - accuracy: 0.8437 - val_loss: 0.9038 - val_accuracy: 0.7400
#
# Epoch 00002: val_loss did not improve from 0.34081
# Epoch 3/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3659 - accuracy: 0.9081 - val_loss: 0.6374 - val_accuracy: 0.8000
#
# Epoch 00003: val_loss did not improve from 0.34081
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2915 - accuracy: 0.9313 - val_loss: 0.5614 - val_accuracy: 0.8200
#
# Epoch 00004: val_loss did not improve from 0.34081
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2415 - accuracy: 0.9384 - val_loss: 0.5537 - val_accuracy: 0.8100
#
# Epoch 00005: val_loss did not improve from 0.34081
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2089 - accuracy: 0.9448 - val_loss: 0.4596 - val_accuracy: 0.8600
#
# Epoch 00006: val_loss did not improve from 0.34081
# Epoch 7/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1821 - accuracy: 0.9492 - val_loss: 0.5308 - val_accuracy: 0.8400
#
# Epoch 00007: val_loss did not improve from 0.34081
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1580 - accuracy: 0.9540 - val_loss: 0.5315 - val_accuracy: 0.8500
#
# Epoch 00008: val_loss did not improve from 0.34081
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1349 - accuracy: 0.9596 - val_loss: 0.4641 - val_accuracy: 0.8200
#
# Epoch 00009: val_loss did not improve from 0.34081
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1254 - accuracy: 0.9628 - val_loss: 0.4234 - val_accuracy: 0.8600
#
# Epoch 00010: val_loss did not improve from 0.34081
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1258 - accuracy: 0.9596 - val_loss: 0.4224 - val_accuracy: 0.8700
#
# Epoch 00011: val_loss did not improve from 0.34081
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1101 - accuracy: 0.9672 - val_loss: 0.4127 - val_accuracy: 0.8900
#
# Epoch 00012: val_loss did not improve from 0.34081
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1094 - accuracy: 0.9664 - val_loss: 0.4217 - val_accuracy: 0.8700
# Epoch 00013: val_loss did not improve from 0.34081
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0868 - accuracy: 0.9720 - val_loss: 0.4070 - val_accuracy: 0.8700
#
# Epoch 00014: val_loss did not improve from 0.34081
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9776 - val_loss: 0.4310 - val_accuracy: 0.8800
#
# Epoch 00015: val_loss did not improve from 0.34081
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0820 - accuracy: 0.9756 - val_loss: 0.5254 - val_accuracy: 0.8700
#
# Epoch 00016: val_loss did not improve from 0.34081
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0706 - accuracy: 0.9764 - val_loss: 0.4099 - val_accuracy: 0.8500
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.34081
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9804 - val_loss: 0.5028 - val_accuracy: 0.8700
#
# Epoch 00018: val_loss did not improve from 0.34081
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9800 - val_loss: 0.4570 - val_accuracy: 0.8800
#
# Epoch 00019: val_loss did not improve from 0.34081
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9880 - val_loss: 0.4756 - val_accuracy: 0.8800
#
# Epoch 00020: val_loss did not improve from 0.34081
# Epoch 21/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 0.9868 - val_loss: 0.4169 - val_accuracy: 0.8900
#
# Epoch 00021: val_loss did not improve from 0.34081
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.9876 - val_loss: 0.4500 - val_accuracy: 0.8800
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.34081
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9880 - val_loss: 0.4201 - val_accuracy: 0.8800
#
# Epoch 00023: val_loss did not improve from 0.34081
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9872 - val_loss: 0.4624 - val_accuracy: 0.8800
#
# Epoch 00024: val_loss did not improve from 0.34081
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.4173 - val_accuracy: 0.8800
#
# Epoch 00025: val_loss did not improve from 0.34081
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0331 - accuracy: 0.9916 - val_loss: 0.4405 - val_accuracy: 0.8800
#
# Epoch 00026: val_loss did not improve from 0.34081
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0357 - accuracy: 0.9892 - val_loss: 0.4400 - val_accuracy: 0.8800
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.34081
# Epoch 28/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0346 - accuracy: 0.9888 - val_loss: 0.4223 - val_accuracy: 0.8800
#
# Epoch 00028: val_loss did not improve from 0.34081
# Epoch 29/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0259 - accuracy: 0.9928 - val_loss: 0.4572 - val_accuracy: 0.8800
#
# Epoch 00029: val_loss did not improve from 0.34081
# Epoch 30/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0336 - accuracy: 0.9904 - val_loss: 0.4226 - val_accuracy: 0.8800
#
# Epoch 00030: val_loss did not improve from 0.34081
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9888 - val_loss: 0.4343 - val_accuracy: 0.8800
#
# Epoch 00031: val_loss did not improve from 0.34081
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9912 - val_loss: 0.4515 - val_accuracy: 0.8800
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.34081
# Epoch 33/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0307 - accuracy: 0.9912 - val_loss: 0.4333 - val_accuracy: 0.8800
#
# Epoch 00033: val_loss did not improve from 0.34081
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9916 - val_loss: 0.4736 - val_accuracy: 0.8800
#
# Epoch 00034: val_loss did not improve from 0.34081
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.4414 - val_accuracy: 0.8800
#
# Epoch 00035: val_loss did not improve from 0.34081
# Score for fold 4: loss of 0.4414248764514923; accuracy of 87.99999952316284%
# Epoch 1/35
# 79/79 [==============================] - 1s 8ms/step - loss: 1.4157 - accuracy: 0.5348 - val_loss: 0.7377 - val_accuracy: 0.7500
#
# Epoch 00001: val_loss did not improve from 0.34081
# Epoch 2/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.4839 - accuracy: 0.8741 - val_loss: 0.5315 - val_accuracy: 0.7800
#
# Epoch 00002: val_loss did not improve from 0.34081
# Epoch 3/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3234 - accuracy: 0.9197 - val_loss: 0.5195 - val_accuracy: 0.8500
#
# Epoch 00003: val_loss did not improve from 0.34081
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2473 - accuracy: 0.9341 - val_loss: 0.4425 - val_accuracy: 0.8500
#
# Epoch 00004: val_loss did not improve from 0.34081
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.9444 - val_loss: 0.5035 - val_accuracy: 0.8500
#
# Epoch 00005: val_loss did not improve from 0.34081
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1830 - accuracy: 0.9524 - val_loss: 0.4710 - val_accuracy: 0.8800
#
# Epoch 00006: val_loss did not improve from 0.34081
# Epoch 7/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1635 - accuracy: 0.9560 - val_loss: 0.4509 - val_accuracy: 0.8700
#
# Epoch 00007: val_loss did not improve from 0.34081
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1354 - accuracy: 0.9568 - val_loss: 0.4418 - val_accuracy: 0.8700
#
# Epoch 00008: val_loss did not improve from 0.34081
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1220 - accuracy: 0.9628 - val_loss: 0.5883 - val_accuracy: 0.8600
#
# Epoch 00009: val_loss did not improve from 0.34081
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1111 - accuracy: 0.9680 - val_loss: 0.4496 - val_accuracy: 0.8800
#
# Epoch 00010: val_loss did not improve from 0.34081
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0943 - accuracy: 0.9708 - val_loss: 0.4973 - val_accuracy: 0.8500
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_loss did not improve from 0.34081
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0825 - accuracy: 0.9728 - val_loss: 0.4234 - val_accuracy: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.34081
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.9764 - val_loss: 0.3827 - val_accuracy: 0.8900
#
# Epoch 00013: val_loss did not improve from 0.34081
# Epoch 14/35
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0589 - accuracy: 0.9816 - val_loss: 0.4556 - val_accuracy: 0.9100
#
# Epoch 00014: val_loss did not improve from 0.34081
# Epoch 15/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0689 - accuracy: 0.9812 - val_loss: 0.4433 - val_accuracy: 0.8900
#
# Epoch 00015: val_loss did not improve from 0.34081
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0624 - accuracy: 0.9808 - val_loss: 0.4814 - val_accuracy: 0.8900
#
# Epoch 00016: val_loss did not improve from 0.34081
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9800 - val_loss: 0.4036 - val_accuracy: 0.8900
#
# Epoch 00017: val_loss did not improve from 0.34081
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9864 - val_loss: 0.3951 - val_accuracy: 0.9000
#
# Epoch 00018: val_loss did not improve from 0.34081
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9820 - val_loss: 0.4897 - val_accuracy: 0.9000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_loss did not improve from 0.34081
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 0.9868 - val_loss: 0.4114 - val_accuracy: 0.8900
#
# Epoch 00020: val_loss did not improve from 0.34081
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9864 - val_loss: 0.3940 - val_accuracy: 0.9200
#
# Epoch 00021: val_loss did not improve from 0.34081
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9896 - val_loss: 0.4186 - val_accuracy: 0.8900
#
# Epoch 00022: val_loss did not improve from 0.34081
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9892 - val_loss: 0.4003 - val_accuracy: 0.9000
#
# Epoch 00023: val_loss did not improve from 0.34081
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9876 - val_loss: 0.4269 - val_accuracy: 0.9000
#
# Epoch 00024: val_loss did not improve from 0.34081
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 0.9924 - val_loss: 0.4616 - val_accuracy: 0.9000
#
# Epoch 00025: val_loss did not improve from 0.34081
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 0.4263 - val_accuracy: 0.9000
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_loss did not improve from 0.34081
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9908 - val_loss: 0.4203 - val_accuracy: 0.9000
#
# Epoch 00027: val_loss did not improve from 0.34081
# Epoch 28/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9932 - val_loss: 0.4447 - val_accuracy: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.34081
# Epoch 29/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9900 - val_loss: 0.4728 - val_accuracy: 0.9000
#
# Epoch 00029: val_loss did not improve from 0.34081
# Epoch 30/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 0.4826 - val_accuracy: 0.9000
#
# Epoch 00030: val_loss did not improve from 0.34081
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9928 - val_loss: 0.4974 - val_accuracy: 0.9000
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00031: val_loss did not improve from 0.34081
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9940 - val_loss: 0.4496 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.34081
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9920 - val_loss: 0.4461 - val_accuracy: 0.9000
#
# Epoch 00033: val_loss did not improve from 0.34081
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9924 - val_loss: 0.4545 - val_accuracy: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.34081
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.4740 - val_accuracy: 0.9000
#
# Epoch 00035: val_loss did not improve from 0.34081
# Score for fold 5: loss of 0.47402888536453247; accuracy of 89.99999761581421%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.4468 - accuracy: 0.5304 - val_loss: 0.7781 - val_accuracy: 0.7800
#
# Epoch 00001: val_loss did not improve from 0.34081
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.4831 - accuracy: 0.8741 - val_loss: 0.5810 - val_accuracy: 0.8300
#
# Epoch 00002: val_loss did not improve from 0.34081
# Epoch 3/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2844 - accuracy: 0.9305 - val_loss: 0.5468 - val_accuracy: 0.8700
#
# Epoch 00003: val_loss did not improve from 0.34081
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2398 - accuracy: 0.9357 - val_loss: 0.4949 - val_accuracy: 0.8600
#
# Epoch 00004: val_loss did not improve from 0.34081
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9464 - val_loss: 0.6362 - val_accuracy: 0.8700
#
# Epoch 00005: val_loss did not improve from 0.34081
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1930 - accuracy: 0.9496 - val_loss: 0.5464 - val_accuracy: 0.8800
#
# Epoch 00006: val_loss did not improve from 0.34081
# Epoch 7/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1820 - accuracy: 0.9524 - val_loss: 0.5669 - val_accuracy: 0.8800
#
# Epoch 00007: val_loss did not improve from 0.34081
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9524 - val_loss: 0.5008 - val_accuracy: 0.8800
#
# Epoch 00008: val_loss did not improve from 0.34081
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1337 - accuracy: 0.9592 - val_loss: 0.4373 - val_accuracy: 0.8900
#
# Epoch 00009: val_loss did not improve from 0.34081
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1182 - accuracy: 0.9664 - val_loss: 0.4484 - val_accuracy: 0.8900
#
# Epoch 00010: val_loss did not improve from 0.34081
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1070 - accuracy: 0.9692 - val_loss: 0.4311 - val_accuracy: 0.8900
#
# Epoch 00011: val_loss did not improve from 0.34081
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9656 - val_loss: 0.5327 - val_accuracy: 0.8800
#
# Epoch 00012: val_loss did not improve from 0.34081
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1043 - accuracy: 0.9688 - val_loss: 0.5769 - val_accuracy: 0.8900
#
# Epoch 00013: val_loss did not improve from 0.34081
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0823 - accuracy: 0.9744 - val_loss: 0.5478 - val_accuracy: 0.8600
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.34081
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9760 - val_loss: 0.5219 - val_accuracy: 0.9000
#
# Epoch 00015: val_loss did not improve from 0.34081
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0703 - accuracy: 0.9788 - val_loss: 0.5034 - val_accuracy: 0.8800
#
# Epoch 00016: val_loss did not improve from 0.34081
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0601 - accuracy: 0.9824 - val_loss: 0.4937 - val_accuracy: 0.9100
#
# Epoch 00017: val_loss did not improve from 0.34081
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0539 - accuracy: 0.9828 - val_loss: 0.4940 - val_accuracy: 0.9100
#
# Epoch 00018: val_loss did not improve from 0.34081
# Epoch 19/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0551 - accuracy: 0.9816 - val_loss: 0.5119 - val_accuracy: 0.8900
#
# Epoch 00019: val_loss did not improve from 0.34081
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9836 - val_loss: 0.5771 - val_accuracy: 0.8900
#
# Epoch 00020: val_loss did not improve from 0.34081
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0483 - accuracy: 0.9820 - val_loss: 0.4812 - val_accuracy: 0.9000
#
# Epoch 00021: val_loss did not improve from 0.34081
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0430 - accuracy: 0.9892 - val_loss: 0.5134 - val_accuracy: 0.9200
#
# Epoch 00022: val_loss did not improve from 0.34081
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0461 - accuracy: 0.9856 - val_loss: 0.4679 - val_accuracy: 0.9200
#
# Epoch 00023: val_loss did not improve from 0.34081
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0424 - accuracy: 0.9872 - val_loss: 0.4618 - val_accuracy: 0.9200
# Epoch 00024: val_loss did not improve from 0.34081
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 0.9828 - val_loss: 0.5229 - val_accuracy: 0.8900
#
# Epoch 00025: val_loss did not improve from 0.34081
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9836 - val_loss: 0.5537 - val_accuracy: 0.9000
#
# Epoch 00026: val_loss did not improve from 0.34081
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.5448 - val_accuracy: 0.9100
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.34081
# Epoch 28/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0306 - accuracy: 0.9916 - val_loss: 0.5639 - val_accuracy: 0.9100
#
# Epoch 00028: val_loss did not improve from 0.34081
# Epoch 29/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.5725 - val_accuracy: 0.9100
#
# Epoch 00029: val_loss did not improve from 0.34081
# Epoch 30/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9900 - val_loss: 0.5611 - val_accuracy: 0.9000
#
# Epoch 00030: val_loss did not improve from 0.34081
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.9900 - val_loss: 0.6153 - val_accuracy: 0.8900
#
# Epoch 00031: val_loss did not improve from 0.34081
# Epoch 32/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0278 - accuracy: 0.9908 - val_loss: 0.5642 - val_accuracy: 0.9200
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.34081
# Epoch 33/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 0.9932 - val_loss: 0.5563 - val_accuracy: 0.9100
#
# Epoch 00033: val_loss did not improve from 0.34081
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 0.9936 - val_loss: 0.5691 - val_accuracy: 0.9100
#
# Epoch 00034: val_loss did not improve from 0.34081
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 0.5825 - val_accuracy: 0.9100
#
# Epoch 00035: val_loss did not improve from 0.34081
# Score for fold 6: loss of 0.5824660062789917; accuracy of 91.00000262260437%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.4456 - accuracy: 0.5188 - val_loss: 0.9007 - val_accuracy: 0.7800
#
# Epoch 00001: val_loss did not improve from 0.34081
# Epoch 2/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4582 - accuracy: 0.8841 - val_loss: 0.7277 - val_accuracy: 0.8000
#
# Epoch 00002: val_loss did not improve from 0.34081
# Epoch 3/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.3178 - accuracy: 0.9229 - val_loss: 0.6341 - val_accuracy: 0.8400
#
# Epoch 00003: val_loss did not improve from 0.34081
# Epoch 4/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.2428 - accuracy: 0.9361 - val_loss: 0.4519 - val_accuracy: 0.8900
#
# Epoch 00004: val_loss did not improve from 0.34081
# Epoch 5/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9416 - val_loss: 0.4500 - val_accuracy: 0.8700
#
# Epoch 00005: val_loss did not improve from 0.34081
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.9476 - val_loss: 0.4032 - val_accuracy: 0.9000
#
# Epoch 00006: val_loss did not improve from 0.34081
# Epoch 7/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1672 - accuracy: 0.9504 - val_loss: 0.4344 - val_accuracy: 0.8900
#
# Epoch 00007: val_loss did not improve from 0.34081
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1496 - accuracy: 0.9592 - val_loss: 0.4235 - val_accuracy: 0.8900
#
# Epoch 00008: val_loss did not improve from 0.34081
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1258 - accuracy: 0.9668 - val_loss: 0.3947 - val_accuracy: 0.9000
#
# Epoch 00009: val_loss did not improve from 0.34081
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1311 - accuracy: 0.9588 - val_loss: 0.3689 - val_accuracy: 0.9100
#
# Epoch 00010: val_loss did not improve from 0.34081
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0971 - accuracy: 0.9676 - val_loss: 0.3792 - val_accuracy: 0.9000
#
# Epoch 00011: val_loss did not improve from 0.34081
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0942 - accuracy: 0.9716 - val_loss: 0.3693 - val_accuracy: 0.8900
#
# Epoch 00012: val_loss did not improve from 0.34081
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9728 - val_loss: 0.3674 - val_accuracy: 0.9000
#
# Epoch 00013: val_loss did not improve from 0.34081
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0771 - accuracy: 0.9752 - val_loss: 0.3116 - val_accuracy: 0.9100
#
# Epoch 00014: val_loss improved from 0.34081 to 0.31161, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0755 - accuracy: 0.9768 - val_loss: 0.2919 - val_accuracy: 0.9000
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss improved from 0.31161 to 0.29189, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0611 - accuracy: 0.9836 - val_loss: 0.3302 - val_accuracy: 0.9100
#
# Epoch 00016: val_loss did not improve from 0.29189
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0495 - accuracy: 0.9852 - val_loss: 0.3195 - val_accuracy: 0.9200
#
# Epoch 00017: val_loss did not improve from 0.29189
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9840 - val_loss: 0.3011 - val_accuracy: 0.9200
#
# Epoch 00018: val_loss did not improve from 0.29189
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 0.9868 - val_loss: 0.3288 - val_accuracy: 0.9000
#
# Epoch 00019: val_loss did not improve from 0.29189
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0453 - accuracy: 0.9856 - val_loss: 0.3110 - val_accuracy: 0.9200
#
# Epoch 00020: val_loss did not improve from 0.29189
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0519 - accuracy: 0.9836 - val_loss: 0.3272 - val_accuracy: 0.9100
#
# Epoch 00021: val_loss did not improve from 0.29189
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9868 - val_loss: 0.3127 - val_accuracy: 0.9200
#
# ...
#
# Epoch 00031: val_loss did not improve from 0.29189
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.4839 - val_accuracy: 0.8900
#
# Epoch 00032: val_loss did not improve from 0.29189
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 0.4960 - val_accuracy: 0.8900
#
# Epoch 00033: val_loss did not improve from 0.29189
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9936 - val_loss: 0.4943 - val_accuracy: 0.8700
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.29189
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.5176 - val_accuracy: 0.8800
#
# Epoch 00035: val_loss did not improve from 0.29189
# Score for fold 8: loss of 0.5175861120223999; accuracy of 87.99999952316284%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.2708 - accuracy: 0.6279 - val_loss: 0.5199 - val_accuracy: 0.8500
#
# Epoch 00001: val_loss did not improve from 0.29189
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.9161 - val_loss: 0.3523 - val_accuracy: 0.9000
#
# Epoch 00002: val_loss did not improve from 0.29189
# Epoch 3/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.9277 - val_loss: 0.3322 - val_accuracy: 0.9200
#
# Epoch 00003: val_loss did not improve from 0.29189
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2325 - accuracy: 0.9416 - val_loss: 0.2572 - val_accuracy: 0.9300
#
# Epoch 00004: val_loss improved from 0.29189 to 0.25718, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2102 - accuracy: 0.9424 - val_loss: 0.2297 - val_accuracy: 0.9300
#
# Epoch 00005: val_loss improved from 0.25718 to 0.22973, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1726 - accuracy: 0.9532 - val_loss: 0.2492 - val_accuracy: 0.9400
#
# Epoch 00006: val_loss did not improve from 0.22973
# Epoch 7/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1515 - accuracy: 0.9532 - val_loss: 0.2098 - val_accuracy: 0.9400
#
# Epoch 00007: val_loss improved from 0.22973 to 0.20975, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1307 - accuracy: 0.9592 - val_loss: 0.1878 - val_accuracy: 0.9400
#
# Epoch 00008: val_loss improved from 0.20975 to 0.18781, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 9/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1163 - accuracy: 0.9664 - val_loss: 0.2143 - val_accuracy: 0.9500
#
# Epoch 00009: val_loss did not improve from 0.18781
# Epoch 10/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1077 - accuracy: 0.9632 - val_loss: 0.1982 - val_accuracy: 0.9400
#
# Epoch 00010: val_loss did not improve from 0.18781
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1223 - accuracy: 0.9632 - val_loss: 0.2112 - val_accuracy: 0.9500
#
# Epoch 00011: val_loss did not improve from 0.18781
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1082 - accuracy: 0.9708 - val_loss: 0.2065 - val_accuracy: 0.9400
#
# Epoch 00012: val_loss did not improve from 0.18781
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0867 - accuracy: 0.9736 - val_loss: 0.2171 - val_accuracy: 0.9500
#
# Epoch 00013: val_loss did not improve from 0.18781
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0882 - accuracy: 0.9748 - val_loss: 0.1635 - val_accuracy: 0.9600
#
# Epoch 00014: val_loss improved from 0.18781 to 0.16348, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0644 - accuracy: 0.9820 - val_loss: 0.1842 - val_accuracy: 0.9400
#
# Epoch 00015: val_loss did not improve from 0.16348
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0662 - accuracy: 0.9792 - val_loss: 0.1631 - val_accuracy: 0.9600
#
# Epoch 00016: val_loss improved from 0.16348 to 0.16309, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 17/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 0.9804 - val_loss: 0.2636 - val_accuracy: 0.9500
#
# Epoch 00017: val_loss did not improve from 0.16309
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9824 - val_loss: 0.1903 - val_accuracy: 0.9400
#
# Epoch 00018: val_loss did not improve from 0.16309
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0521 - accuracy: 0.9808 - val_loss: 0.1906 - val_accuracy: 0.9500
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.16309
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 0.9864 - val_loss: 0.2179 - val_accuracy: 0.9500
#
# Epoch 00020: val_loss did not improve from 0.16309
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9912 - val_loss: 0.1605 - val_accuracy: 0.9500
#
# Epoch 00021: val_loss improved from 0.16309 to 0.16046, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 22/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0376 - accuracy: 0.9868 - val_loss: 0.1454 - val_accuracy: 0.9600
#
# Epoch 00022: val_loss improved from 0.16046 to 0.14538, saving model to /Users/Max/Documents/GitHub/learning_curve/cgan-lc-cnn-local-v002\model.h5
# Epoch 23/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0336 - accuracy: 0.9900 - val_loss: 0.1647 - val_accuracy: 0.9500
#
# Epoch 00023: val_loss did not improve from 0.14538
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0378 - accuracy: 0.9868 - val_loss: 0.1812 - val_accuracy: 0.9500
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.14538
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0264 - accuracy: 0.9916 - val_loss: 0.1704 - val_accuracy: 0.9600
#
# Epoch 00025: val_loss did not improve from 0.14538
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.1740 - val_accuracy: 0.9500
#
# Epoch 00026: val_loss did not improve from 0.14538
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9936 - val_loss: 0.2127 - val_accuracy: 0.9400
#
# Epoch 00027: val_loss did not improve from 0.14538
# Epoch 28/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0228 - accuracy: 0.9936 - val_loss: 0.1701 - val_accuracy: 0.9500
#
# Epoch 00028: val_loss did not improve from 0.14538
# Epoch 29/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9948 - val_loss: 0.1959 - val_accuracy: 0.9500
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.14538
# Epoch 30/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9952 - val_loss: 0.1962 - val_accuracy: 0.9500
#
# Epoch 00030: val_loss did not improve from 0.14538
# Epoch 31/35
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0174 - accuracy: 0.9968 - val_loss: 0.1813 - val_accuracy: 0.9500
#
# Epoch 00031: val_loss did not improve from 0.14538
# Epoch 32/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9944 - val_loss: 0.1872 - val_accuracy: 0.9500
#
# Epoch 00032: val_loss did not improve from 0.14538
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 0.1954 - val_accuracy: 0.9500
#
# Epoch 00033: val_loss did not improve from 0.14538
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9968 - val_loss: 0.1980 - val_accuracy: 0.9500
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.14538
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.1934 - val_accuracy: 0.9500
#
# Epoch 00035: val_loss did not improve from 0.14538
# Score for fold 9: loss of 0.19344386458396912; accuracy of 94.9999988079071%
# Epoch 1/35
# 79/79 [==============================] - 1s 7ms/step - loss: 1.4422 - accuracy: 0.5428 - val_loss: 0.9142 - val_accuracy: 0.7500
#
# Epoch 00001: val_loss did not improve from 0.14538
# Epoch 2/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.4517 - accuracy: 0.8957 - val_loss: 0.8352 - val_accuracy: 0.7700
#
# Epoch 00002: val_loss did not improve from 0.14538
# Epoch 3/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2984 - accuracy: 0.9317 - val_loss: 0.7721 - val_accuracy: 0.7600
#
# Epoch 00003: val_loss did not improve from 0.14538
# Epoch 4/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2369 - accuracy: 0.9380 - val_loss: 0.6952 - val_accuracy: 0.7900
#
# Epoch 00004: val_loss did not improve from 0.14538
# Epoch 5/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2104 - accuracy: 0.9408 - val_loss: 0.6961 - val_accuracy: 0.8100
#
# Epoch 00005: val_loss did not improve from 0.14538
# Epoch 6/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1774 - accuracy: 0.9484 - val_loss: 0.6901 - val_accuracy: 0.8100
#
# Epoch 00006: val_loss did not improve from 0.14538
# Epoch 7/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1549 - accuracy: 0.9560 - val_loss: 0.6407 - val_accuracy: 0.8100
#
# Epoch 00007: val_loss did not improve from 0.14538
# Epoch 8/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1392 - accuracy: 0.9572 - val_loss: 0.6492 - val_accuracy: 0.8200
#
# Epoch 00008: val_loss did not improve from 0.14538
# Epoch 9/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1227 - accuracy: 0.9672 - val_loss: 0.5856 - val_accuracy: 0.8300
#
# Epoch 00009: val_loss did not improve from 0.14538
# Epoch 10/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1173 - accuracy: 0.9640 - val_loss: 0.5563 - val_accuracy: 0.8300
#
# Epoch 00010: val_loss did not improve from 0.14538
# Epoch 11/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1102 - accuracy: 0.9672 - val_loss: 0.6340 - val_accuracy: 0.8300
#
# Epoch 00011: val_loss did not improve from 0.14538
# Epoch 12/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1019 - accuracy: 0.9688 - val_loss: 0.6445 - val_accuracy: 0.8400
#
# Epoch 00012: val_loss did not improve from 0.14538
# Epoch 13/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1124 - accuracy: 0.9660 - val_loss: 0.6258 - val_accuracy: 0.8200
#
# Epoch 00013: val_loss did not improve from 0.14538
# Epoch 14/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9744 - val_loss: 0.6639 - val_accuracy: 0.8500
#
# Epoch 00014: val_loss did not improve from 0.14538
# Epoch 15/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9724 - val_loss: 0.6670 - val_accuracy: 0.8400
#
# Epoch 00015: val_loss did not improve from 0.14538
# Epoch 16/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0663 - accuracy: 0.9812 - val_loss: 0.6369 - val_accuracy: 0.8200
#
# Epoch 00016: val_loss did not improve from 0.14538
# Epoch 17/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0699 - accuracy: 0.9792 - val_loss: 0.6982 - val_accuracy: 0.8500
#
# Epoch 00017: val_loss did not improve from 0.14538
# Epoch 18/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 0.9792 - val_loss: 0.7374 - val_accuracy: 0.8300
#
# Epoch 00018: val_loss did not improve from 0.14538
# Epoch 19/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 0.9836 - val_loss: 0.7172 - val_accuracy: 0.8500
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.14538
# Epoch 20/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9884 - val_loss: 0.7255 - val_accuracy: 0.8500
#
# Epoch 00020: val_loss did not improve from 0.14538
# Epoch 21/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 0.9836 - val_loss: 0.7526 - val_accuracy: 0.8500
#
# Epoch 00021: val_loss did not improve from 0.14538
# Epoch 22/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0389 - accuracy: 0.9880 - val_loss: 0.6652 - val_accuracy: 0.8700
#
# Epoch 00022: val_loss did not improve from 0.14538
# Epoch 23/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 0.9888 - val_loss: 0.6985 - val_accuracy: 0.8700
#
# Epoch 00023: val_loss did not improve from 0.14538
# Epoch 24/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 0.9896 - val_loss: 0.8313 - val_accuracy: 0.8400
#
# Epoch 00024: val_loss did not improve from 0.14538
# Epoch 25/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9904 - val_loss: 0.8450 - val_accuracy: 0.8600
#
# Epoch 00025: val_loss did not improve from 0.14538
# Epoch 26/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.6988 - val_accuracy: 0.8700
#
# Epoch 00026: val_loss did not improve from 0.14538
# Epoch 27/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.6697 - val_accuracy: 0.8600
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.14538
# Epoch 28/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.7256 - val_accuracy: 0.8600
#
# Epoch 00028: val_loss did not improve from 0.14538
# Epoch 29/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0193 - accuracy: 0.9956 - val_loss: 0.8460 - val_accuracy: 0.8400
#
# Epoch 00029: val_loss did not improve from 0.14538
# Epoch 30/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9924 - val_loss: 0.7881 - val_accuracy: 0.8500
#
# Epoch 00030: val_loss did not improve from 0.14538
# Epoch 31/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9908 - val_loss: 0.7775 - val_accuracy: 0.8500
#
# Epoch 00031: val_loss did not improve from 0.14538
# Epoch 32/35
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0238 - accuracy: 0.9904 - val_loss: 0.7558 - val_accuracy: 0.8500
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.14538
# Epoch 33/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9924 - val_loss: 0.7537 - val_accuracy: 0.8600
#
# Epoch 00033: val_loss did not improve from 0.14538
# Epoch 34/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9944 - val_loss: 0.8051 - val_accuracy: 0.8600
#
# Epoch 00034: val_loss did not improve from 0.14538
# Epoch 35/35
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9952 - val_loss: 0.7849 - val_accuracy: 0.8600
#
# Epoch 00035: val_loss did not improve from 0.14538
# Score for fold 10: loss of 0.7848538160324097; accuracy of 86.00000143051147%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.4682968258857727 - Accuracy: 88.99999856948853%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.5715148448944092 - Accuracy: 89.99999761581421%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6517795324325562 - Accuracy: 92.00000166893005%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.4414248764514923 - Accuracy: 87.99999952316284%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.47402888536453247 - Accuracy: 89.99999761581421%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.5824660062789917 - Accuracy: 91.00000262260437%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.3536685109138489 - Accuracy: 91.00000262260437%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.5175861120223999 - Accuracy: 87.99999952316284%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.19344386458396912 - Accuracy: 94.9999988079071%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.7848538160324097 - Accuracy: 86.00000143051147%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 90.0% (+- 0.02366431923315586)
# > Loss: 0.5039063274860383
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph (I will use around 20% of cases for benign for and the remaining 80% equally distributed across the 10 ransomware families)

# %%
np.array(train_distr)
# Out:
# array([[ 9.192646 ,  9.352518 ,  7.673861 ,  7.8337326,  7.673861 ,
#          8.273381 ,  7.873701 ,  8.31335  ,  7.474021 ,  7.513989 ,
#         18.82494  ],
#        [ 9.31255  ,  9.31255  ,  7.673861 ,  7.673861 ,  7.713829 ,
#          8.433253 ,  7.7937646,  8.353317 ,  7.5539565,  7.474021 ,
#         18.705036 ],
#        [ 9.032774 ,  9.11271  ,  7.753797 ,  7.753797 ,  7.713829 ,
#          8.233413 ,  7.873701 ,  8.193445 ,  7.5939245,  7.474021 ,
#         19.264587 ],
#        [ 9.11271  ,  9.392486 ,  7.753797 ,  7.713829 ,  7.513989 ,
#          8.113509 ,  7.8337326,  8.273381 ,  7.5939245,  7.474021 ,
#         19.22462  ],
#        [ 9.0727415,  9.51239  ,  7.753797 ,  7.7937646,  7.5939245,
#          8.273381 ,  7.873701 ,  8.233413 ,  7.673861 ,  7.3541164,
#         18.864908 ],
#        [ 9.31255  ,  9.11271  ,  7.8337326,  7.713829 ,  7.5539565,
#          8.153478 ,  7.913669 ,  8.393286 ,  7.5539565,  7.513989 ,
#         18.944845 ],
#        [ 9.032774 ,  9.552358 ,  7.673861 ,  7.753797 ,  7.513989 ,
#          8.31335  ,  7.873701 ,  8.273381 ,  7.5939245,  7.5539565,
#         18.864908 ],
#        [ 8.952837 ,  9.31255  ,  7.7937646,  7.7937646,  7.713829 ,
#          8.233413 ,  7.8337326,  8.31335  ,  7.5539565,  7.394085 ,
#         19.104715 ],
#        [ 8.952837 ,  9.432454 ,  7.753797 ,  7.753797 ,  7.5539565,
#          8.31335  ,  7.913669 ,  8.233413 ,  7.633893 ,  7.5539565,
#         18.904877 ],
#        [ 9.0727415,  9.352518 ,  7.8337326,  7.673861 ,  7.5939245,
#          8.233413 ,  7.713829 ,  8.31335  ,  7.5539565,  7.434053 ,
#         19.22462  ]], dtype=float32)

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN - CNN"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of CGAN - CNN       |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9         | 0.0237       |
# | Loss     | 0.5039      | 0.1539       |
# | Macro F1 | 0.7396      | 0.0635       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9215      | 0.0284       |
# | Acc      | 0.943       | 0.0245       |
# | F1       | 0.9453      | 0.0272       |
# | MCC      | 0.886       | 0.0489       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
