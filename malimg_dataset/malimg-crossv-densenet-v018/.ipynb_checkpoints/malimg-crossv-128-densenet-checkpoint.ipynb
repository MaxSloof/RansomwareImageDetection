# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 128
iw = 128

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 35

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/malimg_dataset"
    for files in os.listdir(dir):
        if "densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: densenet-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 11 matches(es) found
# --------------
# New folder name: densenet-local-v023
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/malimgdataset"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/malimg_paper_dataset_imgs"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 9339 images belonging to 25 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = tf.keras.applications.densenet.preprocess_input(imgs)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # DenseNet
# We will now build our **DenseNet** model using Tensorflow/Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  25

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # DenseNet
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (ih,iw,3))
    
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    
    # Run the CNN
    history.append(
        head_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 263/263 [==============================] - 73s 214ms/step - loss: 1.9062 - accuracy: 0.7926 - val_loss: 145.3225 - val_accuracy: 0.3672
#
# Epoch 00001: val_loss improved from inf to 145.32254, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 2/35
# 263/263 [==============================] - 51s 195ms/step - loss: 0.2015 - accuracy: 0.9410 - val_loss: 0.0984 - val_accuracy: 0.9636
#
# Epoch 00002: val_loss improved from 145.32254 to 0.09837, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 3/35
# 263/263 [==============================] - 60s 227ms/step - loss: 0.1220 - accuracy: 0.9620 - val_loss: 0.0878 - val_accuracy: 0.9754
#
# Epoch 00003: val_loss improved from 0.09837 to 0.08783, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 4/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0856 - accuracy: 0.9735 - val_loss: 0.0670 - val_accuracy: 0.9775
#
# Epoch 00004: val_loss improved from 0.08783 to 0.06700, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 5/35
# 263/263 [==============================] - 62s 235ms/step - loss: 0.0654 - accuracy: 0.9791 - val_loss: 0.0814 - val_accuracy: 0.9786
#
# Epoch 00005: val_loss did not improve from 0.06700
# Epoch 6/35
# 263/263 [==============================] - 59s 224ms/step - loss: 0.1864 - accuracy: 0.9629 - val_loss: 27864.4512 - val_accuracy: 0.5278
#
# Epoch 00006: val_loss did not improve from 0.06700
# Epoch 7/35
# 263/263 [==============================] - 57s 217ms/step - loss: 0.0989 - accuracy: 0.9700 - val_loss: 0.0865 - val_accuracy: 0.9690
#
# Epoch 00007: val_loss did not improve from 0.06700
# Epoch 8/35
# 263/263 [==============================] - 58s 220ms/step - loss: 0.0671 - accuracy: 0.9788 - val_loss: 0.4242 - val_accuracy: 0.8062
#
# Epoch 00008: val_loss did not improve from 0.06700
# Epoch 9/35
# 263/263 [==============================] - 66s 251ms/step - loss: 0.0633 - accuracy: 0.9806 - val_loss: 0.0604 - val_accuracy: 0.9818
#
# Epoch 00009: val_loss improved from 0.06700 to 0.06044, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 10/35
# 263/263 [==============================] - 62s 234ms/step - loss: 0.0590 - accuracy: 0.9822 - val_loss: 0.0808 - val_accuracy: 0.9722
#
# Epoch 00010: val_loss did not improve from 0.06044
# Epoch 11/35
# 263/263 [==============================] - 62s 236ms/step - loss: 0.0551 - accuracy: 0.9829 - val_loss: 0.0657 - val_accuracy: 0.9775
#
# Epoch 00011: val_loss did not improve from 0.06044
# Epoch 12/35
# 263/263 [==============================] - 92s 350ms/step - loss: 0.0515 - accuracy: 0.9844 - val_loss: 0.0525 - val_accuracy: 0.9829
#
# Epoch 00012: val_loss improved from 0.06044 to 0.05254, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 13/35
# 263/263 [==============================] - 67s 254ms/step - loss: 0.3967 - accuracy: 0.9062 - val_loss: 0.3421 - val_accuracy: 0.9004
#
# Epoch 00013: val_loss did not improve from 0.05254
# Epoch 14/35
# 263/263 [==============================] - 59s 224ms/step - loss: 0.2110 - accuracy: 0.9421 - val_loss: 2.1377 - val_accuracy: 0.3223
#
# Epoch 00014: val_loss did not improve from 0.05254
# Epoch 15/35
# 263/263 [==============================] - 60s 229ms/step - loss: 0.1940 - accuracy: 0.9362 - val_loss: 0.2025 - val_accuracy: 0.9293
#
# Epoch 00015: val_loss did not improve from 0.05254
# Epoch 16/35
# 263/263 [==============================] - 58s 219ms/step - loss: 0.1645 - accuracy: 0.9540 - val_loss: 0.1698 - val_accuracy: 0.9529
#
# Epoch 00016: val_loss did not improve from 0.05254
# Epoch 17/35
# 263/263 [==============================] - 58s 221ms/step - loss: 0.2053 - accuracy: 0.9450 - val_loss: 5.4243 - val_accuracy: 0.3876
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.05254
# Epoch 18/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.1791 - accuracy: 0.9485 - val_loss: 0.4928 - val_accuracy: 0.8501
#
# Epoch 00018: val_loss did not improve from 0.05254
# Epoch 19/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.1661 - accuracy: 0.9511 - val_loss: 0.1031 - val_accuracy: 0.9636
#
# Epoch 00019: val_loss did not improve from 0.05254
# Epoch 20/35
# 263/263 [==============================] - 60s 227ms/step - loss: 0.1493 - accuracy: 0.9605 - val_loss: 0.0944 - val_accuracy: 0.9797
#
# Epoch 00020: val_loss did not improve from 0.05254
# Epoch 21/35
# 263/263 [==============================] - 81s 308ms/step - loss: 0.1357 - accuracy: 0.9616 - val_loss: 0.1929 - val_accuracy: 0.9443
#
# Epoch 00021: val_loss did not improve from 0.05254
# Epoch 22/35
# 263/263 [==============================] - 63s 241ms/step - loss: 0.1368 - accuracy: 0.9648 - val_loss: 0.1322 - val_accuracy: 0.9625
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.05254
# Epoch 23/35
# 263/263 [==============================] - 59s 222ms/step - loss: 0.1469 - accuracy: 0.9594 - val_loss: 0.0979 - val_accuracy: 0.9679
#
# Epoch 00023: val_loss did not improve from 0.05254
# Epoch 24/35
# 263/263 [==============================] - 57s 218ms/step - loss: 0.1406 - accuracy: 0.9617 - val_loss: 0.1208 - val_accuracy: 0.9593
#
# Epoch 00024: val_loss did not improve from 0.05254
# Epoch 25/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.1343 - accuracy: 0.9631 - val_loss: 0.0724 - val_accuracy: 0.9807
#
# Epoch 00025: val_loss did not improve from 0.05254
# Epoch 26/35
# 263/263 [==============================] - 87s 332ms/step - loss: 0.1291 - accuracy: 0.9644 - val_loss: 0.0922 - val_accuracy: 0.9797
#
# Epoch 00026: val_loss did not improve from 0.05254
# Epoch 27/35
# 263/263 [==============================] - 1256s 5s/step - loss: 0.1195 - accuracy: 0.9632 - val_loss: 0.1162 - val_accuracy: 0.9679
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.05254
# Epoch 28/35
# 263/263 [==============================] - 1429s 5s/step - loss: 0.0920 - accuracy: 0.9655 - val_loss: 0.0982 - val_accuracy: 0.9754
#
# Epoch 00028: val_loss did not improve from 0.05254
# Epoch 29/35
# 263/263 [==============================] - 414s 2s/step - loss: 0.0915 - accuracy: 0.9673 - val_loss: 0.0999 - val_accuracy: 0.9764
#
# Epoch 00029: val_loss did not improve from 0.05254
# Epoch 30/35
# 263/263 [==============================] - 279s 1s/step - loss: 0.1006 - accuracy: 0.9662 - val_loss: 0.1994 - val_accuracy: 0.9400
#
# Epoch 00030: val_loss did not improve from 0.05254
# Epoch 31/35
# 263/263 [==============================] - 166s 631ms/step - loss: 0.1052 - accuracy: 0.9657 - val_loss: 0.1371 - val_accuracy: 0.9636
#
# Epoch 00031: val_loss did not improve from 0.05254
# Epoch 32/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0959 - accuracy: 0.9673 - val_loss: 0.1343 - val_accuracy: 0.9657
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.05254
# Epoch 33/35
# 263/263 [==============================] - 54s 207ms/step - loss: 0.0932 - accuracy: 0.9673 - val_loss: 0.1035 - val_accuracy: 0.9754
#
# Epoch 00033: val_loss did not improve from 0.05254
# Epoch 34/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0938 - accuracy: 0.9676 - val_loss: 0.1690 - val_accuracy: 0.9486
#
# Epoch 00034: val_loss did not improve from 0.05254
# Epoch 35/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0920 - accuracy: 0.9674 - val_loss: 0.0870 - val_accuracy: 0.9818
#
# Epoch 00035: val_loss did not improve from 0.05254
# Score for fold 1: loss of 0.08704359829425812; accuracy of 98.17987084388733%
# Epoch 1/35
# 263/263 [==============================] - 71s 216ms/step - loss: 1.4046 - accuracy: 0.8426 - val_loss: 142.4983 - val_accuracy: 0.5503
#
# Epoch 00001: val_loss did not improve from 0.05254
# Epoch 2/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.1280 - accuracy: 0.9599 - val_loss: 0.0838 - val_accuracy: 0.9732
#
# Epoch 00002: val_loss did not improve from 0.05254
# Epoch 3/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.1026 - accuracy: 0.9666 - val_loss: 0.0789 - val_accuracy: 0.9711
#
# Epoch 00003: val_loss did not improve from 0.05254
# Epoch 4/35
# 263/263 [==============================] - 57s 217ms/step - loss: 0.0755 - accuracy: 0.9751 - val_loss: 0.0726 - val_accuracy: 0.9829
#
# Epoch 00004: val_loss did not improve from 0.05254
# Epoch 5/35
# 263/263 [==============================] - 54s 205ms/step - loss: 0.0822 - accuracy: 0.9737 - val_loss: 0.0748 - val_accuracy: 0.9722
#
# Epoch 00005: val_loss did not improve from 0.05254
# Epoch 6/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0680 - accuracy: 0.9780 - val_loss: 0.0820 - val_accuracy: 0.9732
#
# Epoch 00006: val_loss did not improve from 0.05254
# Epoch 7/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.1855 - accuracy: 0.9607 - val_loss: 13253.4482 - val_accuracy: 0.2998
#
# Epoch 00007: val_loss did not improve from 0.05254
# Epoch 8/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.2942 - accuracy: 0.9482 - val_loss: 0.1911 - val_accuracy: 0.9529
#
# Epoch 00008: val_loss did not improve from 0.05254
# Epoch 9/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0870 - accuracy: 0.9717 - val_loss: 0.0911 - val_accuracy: 0.9636
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.05254
# Epoch 10/35
# 263/263 [==============================] - 52s 197ms/step - loss: 0.0677 - accuracy: 0.9774 - val_loss: 0.0666 - val_accuracy: 0.9754
#
# Epoch 00010: val_loss did not improve from 0.05254
# Epoch 11/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0657 - accuracy: 0.9774 - val_loss: 0.0679 - val_accuracy: 0.9775
#
# Epoch 00011: val_loss did not improve from 0.05254
# Epoch 12/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0607 - accuracy: 0.9786 - val_loss: 0.0617 - val_accuracy: 0.9807
#
# Epoch 00012: val_loss did not improve from 0.05254
# Epoch 13/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0590 - accuracy: 0.9801 - val_loss: 0.0590 - val_accuracy: 0.9764
#
# Epoch 00013: val_loss did not improve from 0.05254
# Epoch 14/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0571 - accuracy: 0.9810 - val_loss: 0.0712 - val_accuracy: 0.9743
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00014: val_loss did not improve from 0.05254
# Epoch 15/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0502 - accuracy: 0.9838 - val_loss: 0.0498 - val_accuracy: 0.9839
#
# Epoch 00015: val_loss improved from 0.05254 to 0.04980, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 16/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0510 - accuracy: 0.9830 - val_loss: 0.0512 - val_accuracy: 0.9850
#
# Epoch 00016: val_loss did not improve from 0.04980
# Epoch 17/35
# 263/263 [==============================] - 52s 196ms/step - loss: 0.0509 - accuracy: 0.9833 - val_loss: 0.0529 - val_accuracy: 0.9797
#
# Epoch 00017: val_loss did not improve from 0.04980
# Epoch 18/35
# 263/263 [==============================] - 52s 197ms/step - loss: 0.0503 - accuracy: 0.9839 - val_loss: 0.0551 - val_accuracy: 0.9818
#
# Epoch 00018: val_loss did not improve from 0.04980
# Epoch 19/35
# 263/263 [==============================] - 52s 197ms/step - loss: 0.0465 - accuracy: 0.9849 - val_loss: 0.0661 - val_accuracy: 0.9775
#
# Epoch 00019: val_loss did not improve from 0.04980
# Epoch 20/35
# 263/263 [==============================] - 56s 213ms/step - loss: 0.0507 - accuracy: 0.9823 - val_loss: 0.0523 - val_accuracy: 0.9850
#
# Epoch 00020: val_loss did not improve from 0.04980
# Epoch 21/35
# 263/263 [==============================] - 73s 280ms/step - loss: 0.0485 - accuracy: 0.9848 - val_loss: 0.0454 - val_accuracy: 0.9839
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00021: val_loss improved from 0.04980 to 0.04542, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 22/35
# 263/263 [==============================] - 53s 202ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.0456 - val_accuracy: 0.9839
#
# Epoch 00022: val_loss did not improve from 0.04542
# Epoch 23/35
# 263/263 [==============================] - 54s 204ms/step - loss: 0.0416 - accuracy: 0.9863 - val_loss: 0.0447 - val_accuracy: 0.9839
#
# Epoch 00023: val_loss improved from 0.04542 to 0.04473, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 24/35
# 263/263 [==============================] - 61s 231ms/step - loss: 0.0403 - accuracy: 0.9875 - val_loss: 0.0553 - val_accuracy: 0.9829
#
# Epoch 00024: val_loss did not improve from 0.04473
# Epoch 25/35
# 263/263 [==============================] - 54s 203ms/step - loss: 0.0412 - accuracy: 0.9870 - val_loss: 0.0476 - val_accuracy: 0.9850
#
# Epoch 00025: val_loss did not improve from 0.04473
# Epoch 26/35
# 263/263 [==============================] - 55s 210ms/step - loss: 0.0397 - accuracy: 0.9872 - val_loss: 0.0464 - val_accuracy: 0.9839
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00026: val_loss did not improve from 0.04473
# Epoch 27/35
# 263/263 [==============================] - 70s 265ms/step - loss: 0.0397 - accuracy: 0.9870 - val_loss: 0.0469 - val_accuracy: 0.9850
#
# Epoch 00027: val_loss did not improve from 0.04473
# Epoch 28/35
# 263/263 [==============================] - 67s 257ms/step - loss: 0.0406 - accuracy: 0.9864 - val_loss: 0.0486 - val_accuracy: 0.9850
#
# Epoch 00028: val_loss did not improve from 0.04473
# Epoch 29/35
# 263/263 [==============================] - 68s 257ms/step - loss: 0.0405 - accuracy: 0.9866 - val_loss: 0.0464 - val_accuracy: 0.9850
#
# Epoch 00029: val_loss did not improve from 0.04473
# Epoch 30/35
# 263/263 [==============================] - 95s 363ms/step - loss: 0.0379 - accuracy: 0.9881 - val_loss: 0.0499 - val_accuracy: 0.9861
#
# Epoch 00030: val_loss did not improve from 0.04473
# Epoch 31/35
# 263/263 [==============================] - 61s 234ms/step - loss: 0.0386 - accuracy: 0.9875 - val_loss: 0.0525 - val_accuracy: 0.9850
#
# Epoch 00031: val_loss did not improve from 0.04473
# Epoch 32/35
# 263/263 [==============================] - 93s 354ms/step - loss: 0.0375 - accuracy: 0.9882 - val_loss: 0.0484 - val_accuracy: 0.9839
#
# Epoch 00032: val_loss did not improve from 0.04473
# Epoch 33/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0393 - accuracy: 0.9875 - val_loss: 0.0543 - val_accuracy: 0.9829
#
# Epoch 00033: val_loss did not improve from 0.04473
# Epoch 34/35
# 263/263 [==============================] - 54s 207ms/step - loss: 0.0392 - accuracy: 0.9876 - val_loss: 0.0518 - val_accuracy: 0.9850
#
# Epoch 00034: val_loss did not improve from 0.04473
# Epoch 35/35
# 263/263 [==============================] - 54s 205ms/step - loss: 0.0376 - accuracy: 0.9879 - val_loss: 0.0536 - val_accuracy: 0.9861
#
# Epoch 00035: val_loss did not improve from 0.04473
# Score for fold 2: loss of 0.053599826991558075; accuracy of 98.60813617706299%
# Epoch 1/35
# 263/263 [==============================] - 70s 215ms/step - loss: 1.4091 - accuracy: 0.8650 - val_loss: 0.2206 - val_accuracy: 0.9486
#
# Epoch 00001: val_loss did not improve from 0.04473
# Epoch 2/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.1105 - accuracy: 0.9640 - val_loss: 0.0850 - val_accuracy: 0.9657
#
# Epoch 00002: val_loss did not improve from 0.04473
# Epoch 3/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0892 - accuracy: 0.9718 - val_loss: 0.0765 - val_accuracy: 0.9732
#
# Epoch 00003: val_loss did not improve from 0.04473
# Epoch 4/35
# 263/263 [==============================] - 54s 205ms/step - loss: 0.0746 - accuracy: 0.9756 - val_loss: 0.0688 - val_accuracy: 0.9764
#
# Epoch 00004: val_loss did not improve from 0.04473
# Epoch 5/35
# 263/263 [==============================] - 54s 207ms/step - loss: 1.9185 - accuracy: 0.8558 - val_loss: 3.2073 - val_accuracy: 0.3694
#
# Epoch 00005: val_loss did not improve from 0.04473
# Epoch 6/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.1863 - accuracy: 0.9463 - val_loss: 0.0859 - val_accuracy: 0.9690
#
# Epoch 00006: val_loss did not improve from 0.04473
# Epoch 7/35
# 263/263 [==============================] - 55s 207ms/step - loss: 0.1323 - accuracy: 0.9600 - val_loss: 0.8329 - val_accuracy: 0.8255
#
# Epoch 00007: val_loss did not improve from 0.04473
# Epoch 8/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.1284 - accuracy: 0.9619 - val_loss: 0.1946 - val_accuracy: 0.9400
#
# Epoch 00008: val_loss did not improve from 0.04473
# Epoch 9/35
# 263/263 [==============================] - 54s 207ms/step - loss: 0.0946 - accuracy: 0.9684 - val_loss: 0.0648 - val_accuracy: 0.9775
#
# Epoch 00009: val_loss did not improve from 0.04473
# Epoch 10/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0971 - accuracy: 0.9706 - val_loss: 0.0584 - val_accuracy: 0.9797
#
# Epoch 00010: val_loss did not improve from 0.04473
# Epoch 11/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0968 - accuracy: 0.9688 - val_loss: 0.0766 - val_accuracy: 0.9754
#
# Epoch 00011: val_loss did not improve from 0.04473
# Epoch 12/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0721 - accuracy: 0.9764 - val_loss: 0.0534 - val_accuracy: 0.9807
#
# Epoch 00012: val_loss did not improve from 0.04473
# Epoch 13/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0852 - accuracy: 0.9733 - val_loss: 0.0668 - val_accuracy: 0.9818
#
# Epoch 00013: val_loss did not improve from 0.04473
# Epoch 14/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0836 - accuracy: 0.9735 - val_loss: 0.0556 - val_accuracy: 0.9839
#
# Epoch 00014: val_loss did not improve from 0.04473
# Epoch 15/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0655 - accuracy: 0.9794 - val_loss: 0.0648 - val_accuracy: 0.9775
#
# Epoch 00015: val_loss did not improve from 0.04473
# Epoch 16/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0578 - accuracy: 0.9820 - val_loss: 0.0790 - val_accuracy: 0.9743
#
# Epoch 00016: val_loss did not improve from 0.04473
# Epoch 17/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0617 - accuracy: 0.9794 - val_loss: 0.0909 - val_accuracy: 0.9722
#
# Epoch 00017: val_loss did not improve from 0.04473
# Epoch 18/35
# 263/263 [==============================] - 57s 218ms/step - loss: 0.0748 - accuracy: 0.9760 - val_loss: 1.0318 - val_accuracy: 0.7698
#
# Epoch 00018: val_loss did not improve from 0.04473
# Epoch 19/35
# 263/263 [==============================] - 55s 210ms/step - loss: 0.1094 - accuracy: 0.9703 - val_loss: 0.0699 - val_accuracy: 0.9786
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.04473
# Epoch 20/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0561 - accuracy: 0.9819 - val_loss: 0.0590 - val_accuracy: 0.9818
#
# Epoch 00020: val_loss did not improve from 0.04473
# Epoch 21/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0615 - accuracy: 0.9813 - val_loss: 0.0563 - val_accuracy: 0.9807
#
# Epoch 00021: val_loss did not improve from 0.04473
# Epoch 22/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0542 - accuracy: 0.9836 - val_loss: 0.0762 - val_accuracy: 0.9775
#
# Epoch 00022: val_loss did not improve from 0.04473
# Epoch 23/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0463 - accuracy: 0.9858 - val_loss: 0.0494 - val_accuracy: 0.9818
#
# Epoch 00023: val_loss did not improve from 0.04473
# Epoch 24/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0531 - accuracy: 0.9829 - val_loss: 0.0483 - val_accuracy: 0.9839
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.04473
# Epoch 25/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0449 - accuracy: 0.9860 - val_loss: 0.0566 - val_accuracy: 0.9818
#
# Epoch 00025: val_loss did not improve from 0.04473
# Epoch 26/35
# 263/263 [==============================] - 68s 260ms/step - loss: 0.0403 - accuracy: 0.9874 - val_loss: 0.0629 - val_accuracy: 0.9807
#
# Epoch 00026: val_loss did not improve from 0.04473
# Epoch 27/35
# 263/263 [==============================] - 66s 251ms/step - loss: 0.0408 - accuracy: 0.9869 - val_loss: 0.0547 - val_accuracy: 0.9829
#
# Epoch 00027: val_loss did not improve from 0.04473
# Epoch 28/35
# 263/263 [==============================] - 83s 318ms/step - loss: 0.0400 - accuracy: 0.9869 - val_loss: 0.0665 - val_accuracy: 0.9818
#
# Epoch 00028: val_loss did not improve from 0.04473
# Epoch 29/35
# 263/263 [==============================] - 65s 248ms/step - loss: 0.0417 - accuracy: 0.9867 - val_loss: 0.0568 - val_accuracy: 0.9807
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.04473
# Epoch 30/35
# 263/263 [==============================] - 69s 261ms/step - loss: 0.0391 - accuracy: 0.9877 - val_loss: 0.0585 - val_accuracy: 0.9807
#
# Epoch 00030: val_loss did not improve from 0.04473
# Epoch 31/35
# 263/263 [==============================] - 63s 238ms/step - loss: 0.0380 - accuracy: 0.9880 - val_loss: 0.0586 - val_accuracy: 0.9807
#
# Epoch 00031: val_loss did not improve from 0.04473
# Epoch 32/35
# 263/263 [==============================] - 65s 247ms/step - loss: 0.0407 - accuracy: 0.9873 - val_loss: 0.0543 - val_accuracy: 0.9818
#
# Epoch 00032: val_loss did not improve from 0.04473
# Epoch 33/35
# 263/263 [==============================] - 69s 262ms/step - loss: 0.0384 - accuracy: 0.9880 - val_loss: 0.0526 - val_accuracy: 0.9818
#
# Epoch 00033: val_loss did not improve from 0.04473
# Epoch 34/35
# 263/263 [==============================] - 63s 241ms/step - loss: 0.0375 - accuracy: 0.9881 - val_loss: 0.0569 - val_accuracy: 0.9818
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.04473
# Epoch 35/35
# 263/263 [==============================] - 72s 275ms/step - loss: 0.0368 - accuracy: 0.9881 - val_loss: 0.0642 - val_accuracy: 0.9807
#
# Epoch 00035: val_loss did not improve from 0.04473
# Score for fold 3: loss of 0.06419737637042999; accuracy of 98.0728030204773%
# Epoch 1/35
# 263/263 [==============================] - 81s 251ms/step - loss: 1.2536 - accuracy: 0.8494 - val_loss: 0.2371 - val_accuracy: 0.9465
#
# Epoch 00001: val_loss did not improve from 0.04473
# Epoch 2/35
# 263/263 [==============================] - 74s 281ms/step - loss: 0.1446 - accuracy: 0.9594 - val_loss: 0.0820 - val_accuracy: 0.9743
#
# Epoch 00002: val_loss did not improve from 0.04473
# Epoch 3/35
# 263/263 [==============================] - 68s 260ms/step - loss: 0.0997 - accuracy: 0.9706 - val_loss: 0.0789 - val_accuracy: 0.9786
#
# Epoch 00003: val_loss did not improve from 0.04473
# Epoch 4/35
# 263/263 [==============================] - 71s 269ms/step - loss: 0.0973 - accuracy: 0.9705 - val_loss: 0.7658 - val_accuracy: 0.9679
#
# Epoch 00004: val_loss did not improve from 0.04473
# Epoch 5/35
# 263/263 [==============================] - 68s 260ms/step - loss: 0.1322 - accuracy: 0.9663 - val_loss: 0.0917 - val_accuracy: 0.9668
#
# Epoch 00005: val_loss did not improve from 0.04473
# Epoch 6/35
# 263/263 [==============================] - 70s 264ms/step - loss: 0.0724 - accuracy: 0.9764 - val_loss: 0.0803 - val_accuracy: 0.9797
#
# Epoch 00006: val_loss did not improve from 0.04473
# Epoch 7/35
# 263/263 [==============================] - 62s 238ms/step - loss: 0.5022 - accuracy: 0.9189 - val_loss: 468.4545 - val_accuracy: 0.0771
#
# Epoch 00007: val_loss did not improve from 0.04473
# Epoch 8/35
# 263/263 [==============================] - 70s 267ms/step - loss: 0.1377 - accuracy: 0.9593 - val_loss: 0.0920 - val_accuracy: 0.9722
#
# Epoch 00008: val_loss did not improve from 0.04473
# Epoch 9/35
# 263/263 [==============================] - 66s 250ms/step - loss: 0.0769 - accuracy: 0.9728 - val_loss: 0.1026 - val_accuracy: 0.9754
# Epoch 00009: val_loss did not improve from 0.04473
# Epoch 10/35
# 263/263 [==============================] - 67s 255ms/step - loss: 0.0728 - accuracy: 0.9772 - val_loss: 0.0921 - val_accuracy: 0.9722
#
# Epoch 00010: val_loss did not improve from 0.04473
# Epoch 11/35
# 263/263 [==============================] - 74s 282ms/step - loss: 0.0649 - accuracy: 0.9780 - val_loss: 0.1073 - val_accuracy: 0.9700
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_loss did not improve from 0.04473
# Epoch 12/35
# 263/263 [==============================] - 63s 240ms/step - loss: 0.0562 - accuracy: 0.9813 - val_loss: 0.0918 - val_accuracy: 0.9775
#
# Epoch 00012: val_loss did not improve from 0.04473
# Epoch 13/35
# 263/263 [==============================] - 65s 249ms/step - loss: 0.0522 - accuracy: 0.9830 - val_loss: 0.0694 - val_accuracy: 0.9839
#
# Epoch 00013: val_loss did not improve from 0.04473
# Epoch 14/35
# 263/263 [==============================] - 57s 218ms/step - loss: 0.0477 - accuracy: 0.9842 - val_loss: 0.0690 - val_accuracy: 0.9829
#
# Epoch 00014: val_loss did not improve from 0.04473
# Epoch 15/35
# 263/263 [==============================] - 63s 241ms/step - loss: 0.0466 - accuracy: 0.9851 - val_loss: 0.0785 - val_accuracy: 0.9818
#
# Epoch 00015: val_loss did not improve from 0.04473
# Epoch 16/35
# 263/263 [==============================] - 70s 265ms/step - loss: 0.0574 - accuracy: 0.9818 - val_loss: 0.0721 - val_accuracy: 0.9839
#
# Epoch 00016: val_loss did not improve from 0.04473
# Epoch 17/35
# 263/263 [==============================] - 56s 213ms/step - loss: 0.0446 - accuracy: 0.9861 - val_loss: 0.2698 - val_accuracy: 0.9497
#
# Epoch 00017: val_loss did not improve from 0.04473
# Epoch 18/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0512 - accuracy: 0.9847 - val_loss: 0.0956 - val_accuracy: 0.9807
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_loss did not improve from 0.04473
# Epoch 19/35
# 263/263 [==============================] - 60s 230ms/step - loss: 0.0436 - accuracy: 0.9858 - val_loss: 0.0751 - val_accuracy: 0.9850
#
# Epoch 00019: val_loss did not improve from 0.04473
# Epoch 20/35
# 263/263 [==============================] - 62s 235ms/step - loss: 0.0392 - accuracy: 0.9877 - val_loss: 0.0874 - val_accuracy: 0.9829
#
# Epoch 00020: val_loss did not improve from 0.04473
# Epoch 21/35
# 263/263 [==============================] - 53s 202ms/step - loss: 0.0386 - accuracy: 0.9875 - val_loss: 0.0916 - val_accuracy: 0.9829
#
# Epoch 00021: val_loss did not improve from 0.04473
# Epoch 22/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.0680 - val_accuracy: 0.9850
#
# Epoch 00022: val_loss did not improve from 0.04473
# Epoch 23/35
# 263/263 [==============================] - 56s 213ms/step - loss: 0.0427 - accuracy: 0.9864 - val_loss: 0.1158 - val_accuracy: 0.9764
#
# Epoch 00023: val_loss did not improve from 0.04473
# Epoch 24/35
# 263/263 [==============================] - 54s 204ms/step - loss: 0.0556 - accuracy: 0.9839 - val_loss: 0.0676 - val_accuracy: 0.9839
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00024: val_loss did not improve from 0.04473
# Epoch 25/35
# 263/263 [==============================] - 68s 259ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 0.0824 - val_accuracy: 0.9829
#
# Epoch 00025: val_loss did not improve from 0.04473
# Epoch 26/35
# 263/263 [==============================] - 63s 239ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.0773 - val_accuracy: 0.9829
#
# Epoch 00026: val_loss did not improve from 0.04473
# Epoch 27/35
# 263/263 [==============================] - 67s 253ms/step - loss: 0.0375 - accuracy: 0.9881 - val_loss: 0.0742 - val_accuracy: 0.9850
#
# Epoch 00027: val_loss did not improve from 0.04473
# Epoch 28/35
# 263/263 [==============================] - 58s 223ms/step - loss: 0.0366 - accuracy: 0.9883 - val_loss: 0.0757 - val_accuracy: 0.9850
#
# Epoch 00028: val_loss did not improve from 0.04473
# Epoch 29/35
# 263/263 [==============================] - 61s 232ms/step - loss: 0.0373 - accuracy: 0.9882 - val_loss: 0.0793 - val_accuracy: 0.9850
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00029: val_loss did not improve from 0.04473
# Epoch 30/35
# 263/263 [==============================] - 69s 263ms/step - loss: 0.0373 - accuracy: 0.9881 - val_loss: 0.0724 - val_accuracy: 0.9839
#
# Epoch 00030: val_loss did not improve from 0.04473
# Epoch 31/35
# 263/263 [==============================] - 65s 248ms/step - loss: 0.0371 - accuracy: 0.9881 - val_loss: 0.0698 - val_accuracy: 0.9850
#
# Epoch 00031: val_loss did not improve from 0.04473
# Epoch 32/35
# 263/263 [==============================] - 66s 250ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.0712 - val_accuracy: 0.9861
#
# Epoch 00032: val_loss did not improve from 0.04473
# Epoch 33/35
# 263/263 [==============================] - 63s 239ms/step - loss: 0.0364 - accuracy: 0.9883 - val_loss: 0.0743 - val_accuracy: 0.9850
#
# Epoch 00033: val_loss did not improve from 0.04473
# Epoch 34/35
# 263/263 [==============================] - 63s 239ms/step - loss: 0.0363 - accuracy: 0.9882 - val_loss: 0.0731 - val_accuracy: 0.9850
#
# Epoch 00034: val_loss did not improve from 0.04473
# Epoch 35/35
# 263/263 [==============================] - 61s 233ms/step - loss: 0.0367 - accuracy: 0.9882 - val_loss: 0.0714 - val_accuracy: 0.9861
#
# Epoch 00035: val_loss did not improve from 0.04473
# Score for fold 4: loss of 0.07137713581323624; accuracy of 98.60813617706299%
# Epoch 1/35
# 263/263 [==============================] - 81s 243ms/step - loss: 0.8676 - accuracy: 0.8922 - val_loss: 0.0971 - val_accuracy: 0.9615
#
# Epoch 00001: val_loss did not improve from 0.04473
# Epoch 2/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.1091 - accuracy: 0.9672 - val_loss: 0.1353 - val_accuracy: 0.9604
#
# Epoch 00002: val_loss did not improve from 0.04473
# Epoch 3/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0833 - accuracy: 0.9729 - val_loss: 0.0581 - val_accuracy: 0.9797
#
# Epoch 00003: val_loss did not improve from 0.04473
# Epoch 4/35
# 263/263 [==============================] - 55s 208ms/step - loss: 0.0671 - accuracy: 0.9774 - val_loss: 0.0671 - val_accuracy: 0.9839
#
# Epoch 00004: val_loss did not improve from 0.04473
# Epoch 5/35
# 263/263 [==============================] - 59s 223ms/step - loss: 0.0658 - accuracy: 0.9798 - val_loss: 0.0631 - val_accuracy: 0.9807
#
# Epoch 00005: val_loss did not improve from 0.04473
# Epoch 6/35
# 263/263 [==============================] - 54s 206ms/step - loss: 0.0886 - accuracy: 0.9753 - val_loss: 1.5076 - val_accuracy: 0.7227
#
# Epoch 00006: val_loss did not improve from 0.04473
# Epoch 7/35
# 263/263 [==============================] - 55s 211ms/step - loss: 0.0788 - accuracy: 0.9769 - val_loss: 0.0889 - val_accuracy: 0.9657
#
# Epoch 00007: val_loss did not improve from 0.04473
# Epoch 8/35
# 263/263 [==============================] - 55s 209ms/step - loss: 0.0593 - accuracy: 0.9802 - val_loss: 0.0843 - val_accuracy: 0.9754
#
# Epoch 00008: val_loss did not improve from 0.04473
# Epoch 9/35
# 263/263 [==============================] - 57s 217ms/step - loss: 0.0532 - accuracy: 0.9844 - val_loss: 0.0599 - val_accuracy: 0.9839
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.04473
# Epoch 10/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0423 - accuracy: 0.9866 - val_loss: 0.0578 - val_accuracy: 0.9839
#
# Epoch 00010: val_loss did not improve from 0.04473
# Epoch 11/35
# 263/263 [==============================] - 59s 223ms/step - loss: 0.0386 - accuracy: 0.9876 - val_loss: 0.0579 - val_accuracy: 0.9829
#
# Epoch 00011: val_loss did not improve from 0.04473
# Epoch 12/35
# 263/263 [==============================] - 55s 210ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.0646 - val_accuracy: 0.9818
#
# Epoch 00012: val_loss did not improve from 0.04473
# Epoch 13/35
# 263/263 [==============================] - 56s 212ms/step - loss: 0.0442 - accuracy: 0.9864 - val_loss: 0.0578 - val_accuracy: 0.9829
#
# Epoch 00013: val_loss did not improve from 0.04473
# Epoch 14/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0314 - val_accuracy: 0.9925
#
# Epoch 00014: val_loss improved from 0.04473 to 0.03139, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 15/35
# 263/263 [==============================] - 56s 211ms/step - loss: 0.0352 - accuracy: 0.9892 - val_loss: 0.0892 - val_accuracy: 0.9818
#
# Epoch 00015: val_loss did not improve from 0.03139
# Epoch 16/35
# 263/263 [==============================] - 58s 222ms/step - loss: 0.0559 - accuracy: 0.9818 - val_loss: 0.0624 - val_accuracy: 0.9829
#
# Epoch 00016: val_loss did not improve from 0.03139
# Epoch 17/35
# 263/263 [==============================] - 67s 256ms/step - loss: 0.0446 - accuracy: 0.9862 - val_loss: 0.0754 - val_accuracy: 0.9829
#
# Epoch 00017: val_loss did not improve from 0.03139
# Epoch 18/35
# 263/263 [==============================] - 69s 262ms/step - loss: 0.0410 - accuracy: 0.9873 - val_loss: 0.0755 - val_accuracy: 0.9797
#
# Epoch 00018: val_loss did not improve from 0.03139
# Epoch 19/35
# 263/263 [==============================] - 65s 248ms/step - loss: 0.0495 - accuracy: 0.9844 - val_loss: 0.0612 - val_accuracy: 0.9818
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_loss did not improve from 0.03139
# Epoch 20/35
# 263/263 [==============================] - 95s 362ms/step - loss: 0.0199 - accuracy: 0.9929 - val_loss: 0.0388 - val_accuracy: 0.9946
#
# Epoch 00020: val_loss did not improve from 0.03139
# Epoch 21/35
# 263/263 [==============================] - 71s 269ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0370 - val_accuracy: 0.9946
#
# Epoch 00021: val_loss did not improve from 0.03139
# Epoch 22/35
# 263/263 [==============================] - 69s 263ms/step - loss: 8.0692e-04 - accuracy: 0.9999 - val_loss: 0.0345 - val_accuracy: 0.9957
#
# Epoch 00022: val_loss did not improve from 0.03139
# Epoch 23/35
# 263/263 [==============================] - 68s 258ms/step - loss: 2.9924e-04 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9957
#
# Epoch 00023: val_loss did not improve from 0.03139
# Epoch 24/35
# 263/263 [==============================] - 66s 251ms/step - loss: 2.4689e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9957
#
# Epoch 00024: val_loss did not improve from 0.03139
# Epoch 25/35
# 263/263 [==============================] - 69s 262ms/step - loss: 1.4779e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9946
#
# Epoch 00025: val_loss did not improve from 0.03139
# Epoch 26/35
# 263/263 [==============================] - 74s 280ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.2582 - val_accuracy: 0.9561
#
# Epoch 00026: val_loss did not improve from 0.03139
# Epoch 27/35
# 263/263 [==============================] - 66s 251ms/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0354 - val_accuracy: 0.9946
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.03139
# Epoch 28/35
# 263/263 [==============================] - 66s 250ms/step - loss: 4.5450e-04 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9946
#
# Epoch 00028: val_loss did not improve from 0.03139
# Epoch 29/35
# 263/263 [==============================] - 115s 439ms/step - loss: 1.4489e-04 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9946
#
# Epoch 00029: val_loss improved from 0.03139 to 0.02994, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-128densenet-local-v023\model.h5
# Epoch 30/35
# 263/263 [==============================] - 85s 323ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 0.0416 - val_accuracy: 0.9936
#
# Epoch 00030: val_loss did not improve from 0.02994
# Epoch 31/35
# 263/263 [==============================] - 100s 381ms/step - loss: 5.9888e-04 - accuracy: 0.9999 - val_loss: 0.0520 - val_accuracy: 0.9936
#
# Epoch 00031: val_loss did not improve from 0.02994
# Epoch 32/35
# 263/263 [==============================] - 68s 260ms/step - loss: 1.4806e-04 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9946
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.02994
# Epoch 33/35
# 263/263 [==============================] - 70s 266ms/step - loss: 7.1053e-05 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9946
#
# Epoch 00033: val_loss did not improve from 0.02994
# Epoch 34/35
# 263/263 [==============================] - 60s 228ms/step - loss: 4.3858e-05 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9936
#
# Epoch 00034: val_loss did not improve from 0.02994
# Epoch 35/35
# 263/263 [==============================] - 60s 227ms/step - loss: 2.9387e-05 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9936
#
# Epoch 00035: val_loss did not improve from 0.02994
# Score for fold 5: loss of 0.038472164422273636; accuracy of 99.35759902000427%
# Epoch 1/35
# 263/263 [==============================] - 79s 236ms/step - loss: 1.1563 - accuracy: 0.8725 - val_loss: 0.0911 - val_accuracy: 0.9690
#
# Epoch 00001: val_loss did not improve from 0.02994
# Epoch 2/35
# 263/263 [==============================] - 60s 227ms/step - loss: 0.1134 - accuracy: 0.9692 - val_loss: 0.0804 - val_accuracy: 0.9764
#
# Epoch 00002: val_loss did not improve from 0.02994
# Epoch 3/35
# 263/263 [==============================] - 60s 229ms/step - loss: 0.0775 - accuracy: 0.9774 - val_loss: 0.0831 - val_accuracy: 0.9743
#
# Epoch 00003: val_loss did not improve from 0.02994
# Epoch 4/35
# 263/263 [==============================] - 60s 227ms/step - loss: 0.0737 - accuracy: 0.9779 - val_loss: 0.0845 - val_accuracy: 0.9700
#
# Epoch 00004: val_loss did not improve from 0.02994
# Epoch 5/35
# 263/263 [==============================] - 60s 227ms/step - loss: 0.7058 - accuracy: 0.9321 - val_loss: 625832.5000 - val_accuracy: 0.0086
#
# Epoch 00005: val_loss did not improve from 0.02994
# Epoch 6/35
# 263/263 [==============================] - 60s 227ms/step - loss: 0.1227 - accuracy: 0.9585 - val_loss: 0.2397 - val_accuracy: 0.9647
#
# Epoch 00006: val_loss did not improve from 0.02994
# Epoch 7/35
# 263/263 [==============================] - 59s 223ms/step - loss: 0.1000 - accuracy: 0.9654 - val_loss: 0.0702 - val_accuracy: 0.9722
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.02994
# Epoch 8/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0690 - accuracy: 0.9760 - val_loss: 0.0670 - val_accuracy: 0.9775
#
# Epoch 00008: val_loss did not improve from 0.02994
# Epoch 9/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0661 - accuracy: 0.9768 - val_loss: 0.0657 - val_accuracy: 0.9775
#
# Epoch 00009: val_loss did not improve from 0.02994
# Epoch 10/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0602 - accuracy: 0.9802 - val_loss: 0.0728 - val_accuracy: 0.9743
#
# Epoch 00010: val_loss did not improve from 0.02994
# Epoch 11/35
# 263/263 [==============================] - 58s 219ms/step - loss: 0.0594 - accuracy: 0.9798 - val_loss: 0.0561 - val_accuracy: 0.9807
#
# Epoch 00011: val_loss did not improve from 0.02994
# Epoch 12/35
# 263/263 [==============================] - 57s 218ms/step - loss: 0.0567 - accuracy: 0.9819 - val_loss: 0.0609 - val_accuracy: 0.9786
#
# Epoch 00012: val_loss did not improve from 0.02994
# Epoch 13/35
# 263/263 [==============================] - 69s 262ms/step - loss: 0.0553 - accuracy: 0.9820 - val_loss: 0.0614 - val_accuracy: 0.9797
#
# Epoch 00013: val_loss did not improve from 0.02994
# Epoch 14/35
# 263/263 [==============================] - 91s 347ms/step - loss: 0.0515 - accuracy: 0.9837 - val_loss: 0.0556 - val_accuracy: 0.9775
#
# Epoch 00014: val_loss did not improve from 0.02994
# Epoch 15/35
# 263/263 [==============================] - 69s 264ms/step - loss: 0.0529 - accuracy: 0.9830 - val_loss: 0.0642 - val_accuracy: 0.9754
#
# Epoch 00015: val_loss did not improve from 0.02994
# Epoch 16/35
# 263/263 [==============================] - 139s 529ms/step - loss: 0.0511 - accuracy: 0.9836 - val_loss: 0.0609 - val_accuracy: 0.9775
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_loss did not improve from 0.02994
# Epoch 17/35
# 263/263 [==============================] - 99s 378ms/step - loss: 0.0454 - accuracy: 0.9857 - val_loss: 0.0568 - val_accuracy: 0.9818
#
# Epoch 00017: val_loss did not improve from 0.02994
# Epoch 18/35
# 263/263 [==============================] - 90s 342ms/step - loss: 0.0423 - accuracy: 0.9868 - val_loss: 0.0545 - val_accuracy: 0.9818
#
# Epoch 00018: val_loss did not improve from 0.02994
# Epoch 19/35
# 263/263 [==============================] - 77s 295ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 0.0589 - val_accuracy: 0.9807
#
# Epoch 00019: val_loss did not improve from 0.02994
# Epoch 20/35
# 263/263 [==============================] - 74s 281ms/step - loss: 0.0429 - accuracy: 0.9864 - val_loss: 0.0610 - val_accuracy: 0.9775
#
# Epoch 00020: val_loss did not improve from 0.02994
# Epoch 21/35
# 263/263 [==============================] - 70s 265ms/step - loss: 0.0438 - accuracy: 0.9855 - val_loss: 0.0689 - val_accuracy: 0.9775
#
# Epoch 00021: val_loss did not improve from 0.02994
# Epoch 22/35
# 263/263 [==============================] - 78s 298ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 0.0633 - val_accuracy: 0.9797
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00022: val_loss did not improve from 0.02994
# Epoch 23/35
# 263/263 [==============================] - 76s 287ms/step - loss: 0.0392 - accuracy: 0.9877 - val_loss: 0.0567 - val_accuracy: 0.9807
#
# Epoch 00023: val_loss did not improve from 0.02994
# Epoch 24/35
# 263/263 [==============================] - 71s 269ms/step - loss: 0.0371 - accuracy: 0.9886 - val_loss: 0.0615 - val_accuracy: 0.9786
#
# Epoch 00024: val_loss did not improve from 0.02994
# Epoch 25/35
# 263/263 [==============================] - 90s 341ms/step - loss: 0.0392 - accuracy: 0.9875 - val_loss: 0.0621 - val_accuracy: 0.9775
#
# Epoch 00025: val_loss did not improve from 0.02994
# Epoch 26/35
# 263/263 [==============================] - 81s 309ms/step - loss: 0.0379 - accuracy: 0.9881 - val_loss: 0.0568 - val_accuracy: 0.9797
#
# Epoch 00026: val_loss did not improve from 0.02994
# Epoch 27/35
# 263/263 [==============================] - 83s 316ms/step - loss: 0.0388 - accuracy: 0.9880 - val_loss: 0.0609 - val_accuracy: 0.9786
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00027: val_loss did not improve from 0.02994
# Epoch 28/35
# 263/263 [==============================] - 77s 294ms/step - loss: 0.0384 - accuracy: 0.9879 - val_loss: 0.0557 - val_accuracy: 0.9797
#
# Epoch 00028: val_loss did not improve from 0.02994
# Epoch 29/35
# 263/263 [==============================] - 76s 288ms/step - loss: 0.0375 - accuracy: 0.9880 - val_loss: 0.0540 - val_accuracy: 0.9818
#
# Epoch 00029: val_loss did not improve from 0.02994
# Epoch 30/35
# 263/263 [==============================] - 69s 263ms/step - loss: 0.0389 - accuracy: 0.9875 - val_loss: 0.0557 - val_accuracy: 0.9807
#
# Epoch 00030: val_loss did not improve from 0.02994
# Epoch 31/35
# 263/263 [==============================] - 66s 251ms/step - loss: 0.0371 - accuracy: 0.9877 - val_loss: 0.0546 - val_accuracy: 0.9818
#
# Epoch 00031: val_loss did not improve from 0.02994
# Epoch 32/35
# 263/263 [==============================] - 72s 275ms/step - loss: 0.0411 - accuracy: 0.9863 - val_loss: 0.0599 - val_accuracy: 0.9764
#
# Epoch 00032: val_loss did not improve from 0.02994
# Epoch 33/35
# 263/263 [==============================] - 79s 299ms/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 0.0545 - val_accuracy: 0.9797
#
# Epoch 00033: val_loss did not improve from 0.02994
# Epoch 34/35
# 263/263 [==============================] - 71s 270ms/step - loss: 0.0361 - accuracy: 0.9888 - val_loss: 0.0622 - val_accuracy: 0.9807
#
# Epoch 00034: val_loss did not improve from 0.02994
# Epoch 35/35
# 263/263 [==============================] - 71s 269ms/step - loss: 0.0364 - accuracy: 0.9882 - val_loss: 0.0574 - val_accuracy: 0.9807
#
# Epoch 00035: val_loss did not improve from 0.02994
# Score for fold 6: loss of 0.057428132742643356; accuracy of 98.0728030204773%
# Epoch 1/35
# 263/263 [==============================] - 91s 281ms/step - loss: 1.2203 - accuracy: 0.8796 - val_loss: 2437.0852 - val_accuracy: 0.6135
#
# Epoch 00001: val_loss did not improve from 0.02994
# Epoch 2/35
# 263/263 [==============================] - 74s 281ms/step - loss: 0.3168 - accuracy: 0.9559 - val_loss: 0.0634 - val_accuracy: 0.9743
#
# Epoch 00002: val_loss did not improve from 0.02994
# Epoch 3/35
# 263/263 [==============================] - 69s 261ms/step - loss: 0.0940 - accuracy: 0.9682 - val_loss: 0.0660 - val_accuracy: 0.9818
#
# Epoch 00003: val_loss did not improve from 0.02994
# Epoch 4/35
# 263/263 [==============================] - 66s 252ms/step - loss: 0.0745 - accuracy: 0.9758 - val_loss: 0.0751 - val_accuracy: 0.9679
#
# Epoch 00004: val_loss did not improve from 0.02994
# Epoch 5/35
# 263/263 [==============================] - 70s 266ms/step - loss: 0.0987 - accuracy: 0.9728 - val_loss: 0.0567 - val_accuracy: 0.9818
#
# Epoch 00005: val_loss did not improve from 0.02994
# Epoch 6/35
# 263/263 [==============================] - 61s 233ms/step - loss: 0.6946 - accuracy: 0.9354 - val_loss: 4614.4160 - val_accuracy: 0.4325
#
# Epoch 00006: val_loss did not improve from 0.02994
# Epoch 7/35
# 263/263 [==============================] - 66s 251ms/step - loss: 0.1584 - accuracy: 0.9645 - val_loss: 0.1703 - val_accuracy: 0.9818
#
# Epoch 00007: val_loss did not improve from 0.02994
# Epoch 8/35
# 263/263 [==============================] - 71s 270ms/step - loss: 0.1209 - accuracy: 0.9703 - val_loss: 1.1256 - val_accuracy: 0.8126
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_loss did not improve from 0.02994
# Epoch 9/35
# 263/263 [==============================] - 75s 287ms/step - loss: 0.0680 - accuracy: 0.9779 - val_loss: 0.0505 - val_accuracy: 0.9861
#
# Epoch 00009: val_loss did not improve from 0.02994
# Epoch 10/35
# 263/263 [==============================] - 64s 243ms/step - loss: 0.0740 - accuracy: 0.9762 - val_loss: 0.0970 - val_accuracy: 0.9797
#
# Epoch 00010: val_loss did not improve from 0.02994
# Epoch 11/35
# 263/263 [==============================] - 62s 238ms/step - loss: 0.0590 - accuracy: 0.9805 - val_loss: 0.0446 - val_accuracy: 0.9861
#
# Epoch 00011: val_loss did not improve from 0.02994
# Epoch 12/35
# 263/263 [==============================] - 68s 258ms/step - loss: 0.0717 - accuracy: 0.9806 - val_loss: 4.8803 - val_accuracy: 0.9700
#
# Epoch 00012: val_loss did not improve from 0.02994
# Epoch 13/35
# 263/263 [==============================] - 62s 237ms/step - loss: 0.1007 - accuracy: 0.9788 - val_loss: 0.0516 - val_accuracy: 0.9818
#
# Epoch 00013: val_loss did not improve from 0.02994
# Epoch 14/35
# 263/263 [==============================] - 79s 301ms/step - loss: 0.0766 - accuracy: 0.9788 - val_loss: 0.0560 - val_accuracy: 0.9797
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00014: val_loss did not improve from 0.02994
# Epoch 15/35
# ...
#
# Epoch 00019: val_loss did not improve from 0.02994
# Epoch 20/35
# 263/263 [==============================] - 58s 221ms/step - loss: 0.0439 - accuracy: 0.9857 - val_loss: 0.2150 - val_accuracy: 0.9604
#
# Epoch 00020: val_loss did not improve from 0.02994
# Epoch 21/35
# 263/263 [==============================] - 61s 230ms/step - loss: 0.0452 - accuracy: 0.9862 - val_loss: 0.1028 - val_accuracy: 0.9722
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.02994
# Epoch 22/35
# 263/263 [==============================] - 61s 232ms/step - loss: 0.0407 - accuracy: 0.9873 - val_loss: 0.0821 - val_accuracy: 0.9797
#
# Epoch 00022: val_loss did not improve from 0.02994
# Epoch 23/35
# 263/263 [==============================] - 63s 241ms/step - loss: 0.0398 - accuracy: 0.9874 - val_loss: 0.4937 - val_accuracy: 0.9593
#
# Epoch 00023: val_loss did not improve from 0.02994
# Epoch 24/35
# 263/263 [==============================] - 78s 297ms/step - loss: 0.0399 - accuracy: 0.9874 - val_loss: 0.0872 - val_accuracy: 0.9807
#
# Epoch 00024: val_loss did not improve from 0.02994
# Epoch 25/35
# 263/263 [==============================] - 68s 259ms/step - loss: 0.0430 - accuracy: 0.9862 - val_loss: 1.0051 - val_accuracy: 0.9582
#
# Epoch 00025: val_loss did not improve from 0.02994
# Epoch 26/35
# 263/263 [==============================] - 62s 235ms/step - loss: 0.0398 - accuracy: 0.9875 - val_loss: 4.9800 - val_accuracy: 0.9358
#
# Epoch 00026: val_loss did not improve from 0.02994
# Epoch 27/35
# 263/263 [==============================] - 58s 219ms/step - loss: 0.0385 - accuracy: 0.9881 - val_loss: 2.5047 - val_accuracy: 0.9390
#
# Epoch 00027: val_loss did not improve from 0.02994
# Epoch 28/35
# 263/263 [==============================] - 59s 224ms/step - loss: 0.0379 - accuracy: 0.9883 - val_loss: 0.9840 - val_accuracy: 0.9561
#
# Epoch 00028: val_loss did not improve from 0.02994
# Epoch 29/35
# 263/263 [==============================] - 63s 238ms/step - loss: 0.0400 - accuracy: 0.9873 - val_loss: 0.3937 - val_accuracy: 0.9582
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.02994
# Epoch 30/35
# 263/263 [==============================] - 59s 223ms/step - loss: 0.0397 - accuracy: 0.9873 - val_loss: 0.6223 - val_accuracy: 0.9572
#
# Epoch 00030: val_loss did not improve from 0.02994
# Epoch 31/35
# 263/263 [==============================] - 57s 218ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 1.0917 - val_accuracy: 0.9561
#
# Epoch 00031: val_loss did not improve from 0.02994
# Epoch 32/35
# 263/263 [==============================] - 61s 232ms/step - loss: 0.0364 - accuracy: 0.9885 - val_loss: 0.5194 - val_accuracy: 0.9604
#
# Epoch 00032: val_loss did not improve from 0.02994
# Epoch 33/35
# 263/263 [==============================] - 61s 232ms/step - loss: 0.0387 - accuracy: 0.9881 - val_loss: 2.9254 - val_accuracy: 0.9433
#
# Epoch 00033: val_loss did not improve from 0.02994
# Epoch 34/35
# 263/263 [==============================] - 63s 238ms/step - loss: 0.0366 - accuracy: 0.9883 - val_loss: 1.0541 - val_accuracy: 0.9582
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.02994
# Epoch 35/35
# 263/263 [==============================] - 80s 304ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.0988 - val_accuracy: 0.9797
#
# Epoch 00035: val_loss did not improve from 0.02994
# Score for fold 8: loss of 0.09881917387247086; accuracy of 97.96574115753174%
# Epoch 1/35
# 263/263 [==============================] - 96s 290ms/step - loss: 1.3416 - accuracy: 0.8789 - val_loss: 8.4583 - val_accuracy: 0.4315
#
# Epoch 00001: val_loss did not improve from 0.02994
# Epoch 2/35
# 263/263 [==============================] - 73s 279ms/step - loss: 0.1396 - accuracy: 0.9635 - val_loss: 0.0772 - val_accuracy: 0.9764
#
# Epoch 00002: val_loss did not improve from 0.02994
# Epoch 3/35
# 263/263 [==============================] - 64s 243ms/step - loss: 0.0862 - accuracy: 0.9728 - val_loss: 0.0701 - val_accuracy: 0.9764
#
# Epoch 00003: val_loss did not improve from 0.02994
# Epoch 4/35
# 263/263 [==============================] - 73s 279ms/step - loss: 0.1010 - accuracy: 0.9679 - val_loss: 0.0642 - val_accuracy: 0.9786
#
# Epoch 00004: val_loss did not improve from 0.02994
# Epoch 5/35
# 263/263 [==============================] - 68s 259ms/step - loss: 0.0788 - accuracy: 0.9744 - val_loss: 0.1092 - val_accuracy: 0.9743
#
# Epoch 00005: val_loss did not improve from 0.02994
# Epoch 6/35
# 263/263 [==============================] - 64s 242ms/step - loss: 0.0662 - accuracy: 0.9788 - val_loss: 0.0716 - val_accuracy: 0.9775
#
# Epoch 00006: val_loss did not improve from 0.02994
# Epoch 7/35
# 263/263 [==============================] - 65s 247ms/step - loss: 0.0599 - accuracy: 0.9801 - val_loss: 0.0889 - val_accuracy: 0.9722
#
# Epoch 00007: val_loss did not improve from 0.02994
# Epoch 8/35
# 263/263 [==============================] - 71s 271ms/step - loss: 0.0621 - accuracy: 0.9812 - val_loss: 0.2495 - val_accuracy: 0.9454
#
# Epoch 00008: val_loss did not improve from 0.02994
# Epoch 9/35
# 263/263 [==============================] - 63s 239ms/step - loss: 0.0598 - accuracy: 0.9812 - val_loss: 0.0571 - val_accuracy: 0.9818
#
# Epoch 00009: val_loss did not improve from 0.02994
# Epoch 10/35
# 263/263 [==============================] - 70s 267ms/step - loss: 1.9803 - accuracy: 0.8603 - val_loss: 4.4061 - val_accuracy: 0.5696
#
# Epoch 00010: val_loss did not improve from 0.02994
# Epoch 11/35
# 263/263 [==============================] - 65s 246ms/step - loss: 0.5668 - accuracy: 0.9366 - val_loss: 4661.4893 - val_accuracy: 0.5964
#
# Epoch 00011: val_loss did not improve from 0.02994
# Epoch 12/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.1901 - accuracy: 0.9407 - val_loss: 0.1165 - val_accuracy: 0.9668
#
# Epoch 00012: val_loss did not improve from 0.02994
# Epoch 13/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.1517 - accuracy: 0.9630 - val_loss: 0.0914 - val_accuracy: 0.9700
#
# Epoch 00013: val_loss did not improve from 0.02994
# Epoch 14/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.1054 - accuracy: 0.9649 - val_loss: 0.0722 - val_accuracy: 0.9786
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.02994
# Epoch 15/35
# 263/263 [==============================] - 57s 215ms/step - loss: 0.0905 - accuracy: 0.9711 - val_loss: 0.0731 - val_accuracy: 0.9764
#
# Epoch 00015: val_loss did not improve from 0.02994
# Epoch 16/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0835 - accuracy: 0.9718 - val_loss: 0.0700 - val_accuracy: 0.9754
#
# Epoch 00016: val_loss did not improve from 0.02994
# Epoch 17/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0761 - accuracy: 0.9735 - val_loss: 0.0664 - val_accuracy: 0.9754
#
# Epoch 00017: val_loss did not improve from 0.02994
# Epoch 18/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0866 - accuracy: 0.9720 - val_loss: 0.0609 - val_accuracy: 0.9797
#
# Epoch 00018: val_loss did not improve from 0.02994
# Epoch 19/35
# 263/263 [==============================] - 57s 215ms/step - loss: 0.0822 - accuracy: 0.9748 - val_loss: 0.0550 - val_accuracy: 0.9807
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_loss did not improve from 0.02994
# Epoch 20/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0670 - accuracy: 0.9782 - val_loss: 0.0646 - val_accuracy: 0.9775
#
# Epoch 00020: val_loss did not improve from 0.02994
# Epoch 21/35
# 263/263 [==============================] - 57s 215ms/step - loss: 0.0676 - accuracy: 0.9782 - val_loss: 0.0585 - val_accuracy: 0.9818
#
# Epoch 00021: val_loss did not improve from 0.02994
# Epoch 22/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0593 - accuracy: 0.9805 - val_loss: 0.0555 - val_accuracy: 0.9829
#
# Epoch 00022: val_loss did not improve from 0.02994
# Epoch 23/35
# 263/263 [==============================] - 57s 215ms/step - loss: 0.0717 - accuracy: 0.9767 - val_loss: 0.1781 - val_accuracy: 0.9411
#
# Epoch 00023: val_loss did not improve from 0.02994
# Epoch 24/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0694 - accuracy: 0.9767 - val_loss: 0.0580 - val_accuracy: 0.9818
#
# Epoch 00024: val_loss did not improve from 0.02994
# Epoch 25/35
# 263/263 [==============================] - 57s 215ms/step - loss: 0.0577 - accuracy: 0.9801 - val_loss: 0.0561 - val_accuracy: 0.9850
#
# Epoch 00025: val_loss did not improve from 0.02994
# Epoch 26/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0613 - accuracy: 0.9782 - val_loss: 0.0552 - val_accuracy: 0.9807
#
# Epoch 00026: val_loss did not improve from 0.02994
# Epoch 27/35
# 263/263 [==============================] - 56s 215ms/step - loss: 0.0601 - accuracy: 0.9806 - val_loss: 0.0578 - val_accuracy: 0.9807
#
# Epoch 00027: val_loss did not improve from 0.02994
# Epoch 28/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0583 - accuracy: 0.9810 - val_loss: 0.0579 - val_accuracy: 0.9829
#
# Epoch 00028: val_loss did not improve from 0.02994
# Epoch 29/35
# 263/263 [==============================] - 57s 215ms/step - loss: 0.0579 - accuracy: 0.9820 - val_loss: 0.0535 - val_accuracy: 0.9850
#
# Epoch 00029: val_loss did not improve from 0.02994
# Epoch 30/35
# 263/263 [==============================] - 56s 214ms/step - loss: 0.0511 - accuracy: 0.9826 - val_loss: 0.0461 - val_accuracy: 0.9829
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.02994
# Epoch 31/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0514 - accuracy: 0.9832 - val_loss: 0.0500 - val_accuracy: 0.9850
#
# Epoch 00031: val_loss did not improve from 0.02994
# Epoch 32/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0498 - accuracy: 0.9837 - val_loss: 0.0612 - val_accuracy: 0.9807
#
# Epoch 00032: val_loss did not improve from 0.02994
# Epoch 33/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0671 - accuracy: 0.9776 - val_loss: 0.0531 - val_accuracy: 0.9850
#
# Epoch 00033: val_loss did not improve from 0.02994
# Epoch 34/35
# 263/263 [==============================] - 57s 218ms/step - loss: 0.0531 - accuracy: 0.9839 - val_loss: 0.0483 - val_accuracy: 0.9861
#
# Epoch 00034: val_loss did not improve from 0.02994
# Epoch 35/35
# 263/263 [==============================] - 57s 216ms/step - loss: 0.0470 - accuracy: 0.9848 - val_loss: 0.0528 - val_accuracy: 0.9850
#
# Epoch 00035: val_loss did not improve from 0.02994
# Score for fold 9: loss of 0.05283762887120247; accuracy of 98.50106835365295%
# Epoch 1/35
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#      21     layer.trainable=True
#      24 # Run the CNN
#      25 history.append(
# ---> 26     head_model.fit(
#      27     imgs[train],
#      28     labels[train],
#      29     validation_data=(imgs[test], labels[test]),
#      30     epochs=epoch_t,
#      31     callbacks = [anne, checkpoint]) # The actual computation of the CNN
#      32 )
#      34 # Generate generalization metrics
#      35 scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1183, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1176 with trace.Trace(
#    1177     'train',
#    1178     epoch_num=epoch,
#    1179     step_num=step,
#    1180     batch_size=batch_size,
#    1181     _r=1):
#    1182   callbacks.on_train_batch_begin(step)
# -> 1183   tmp_logs = self.train_function(iterator)
#    1184   if data_handler.should_sync:
#    1185     context.async_wait()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:889, in Function.__call__(self, *args, **kwds)
#     886 compiler = "xla" if self._jit_compile else "nonXla"
#     888 with OptionalXlaContext(self._jit_compile):
# --> 889   result = self._call(*args, **kwds)
#     891 new_tracing_count = self.experimental_get_tracing_count()
#     892 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:950, in Function._call(self, *args, **kwds)
#     946     pass  # Fall through to cond-based initialization.
#     947   else:
#     948     # Lifting succeeded, so variables are initialized and we can run the
#     949     # stateless function.
# --> 950     return self._stateless_fn(*args, **kwds)
#     951 else:
#     952   _, _, _, filtered_flat_args = \
#     953       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     954           *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:3023, in Function.__call__(self, *args, **kwargs)
#    3020 with self._lock:
#    3021   (graph_function,
#    3022    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023 return graph_function._call_flat(
#    3024     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:1960, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1956 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1957 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1958     and executing_eagerly):
#    1959   # No tape is watching; skip to running the function.
# -> 1960   return self._build_call_outputs(self._inference_function.call(
#    1961       ctx, args, cancellation_manager=cancellation_manager))
#    1962 forward_backward = self._select_forward_and_backward_functions(
#    1963     args,
#    1964     possible_gradient_type,
#    1965     executing_eagerly)
#    1966 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[32,4,4,1664] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_9/relu/Relu-0-2-TransposeNCHWToNHWC-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_617950]
#
# Function call stack:
# train_function

# %%
(np.argmax(head_model.predict(imgs[test]), axis=-1))

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.08704359829425812 - Accuracy: 98.17987084388733%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.053599826991558075 - Accuracy: 98.60813617706299%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.06419737637042999 - Accuracy: 98.0728030204773%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.07137713581323624 - Accuracy: 98.60813617706299%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.038472164422273636 - Accuracy: 99.35759902000427%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.057428132742643356 - Accuracy: 98.0728030204773%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.05181850492954254 - Accuracy: 98.3940064907074%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.09881917387247086 - Accuracy: 97.96574115753174%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.05283762887120247 - Accuracy: 98.50106835365295%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 98.41779602898491% (+- 0.004030702972054102)
# > Loss: 0.06395483803417948
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of DenseNet169"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of DenseNet169      |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9842      | 0.004        |
# | Loss     | 0.064       | 0.0179       |
# | Macro F1 | 0.9473      | 0.0118       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9825      | 0.0066       |
# | Acc      | 0.9886      | 0.0042       |
# | F1       | 0.9852      | 0.0054       |
# | MCC      | 0.9762      | 0.0086       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for DenseNet169 across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 eval_metric(head_model, history, 'loss', 0,1)
#
# Input In [25], in eval_metric(model, history, metric_name, ymin, ymax)
#      18     plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
#      19     plt.plot(e, val_metric, color = linecolours[i])
# ---> 21 metric = history[n_folds-1].history[metric_name]
#      22 val_metric = history[n_folds-1].history['val_' + metric_name]
#      23 e = range(1, epoch_t + 1)
#
# IndexError: list index out of range

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 eval_metric(head_model, history, 'accuracy', 0.8,1)
#
# Input In [25], in eval_metric(model, history, metric_name, ymin, ymax)
#      18     plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
#      19     plt.plot(e, val_metric, color = linecolours[i])
# ---> 21 metric = history[n_folds-1].history[metric_name]
#      22 val_metric = history[n_folds-1].history['val_' + metric_name]
#      23 e = range(1, epoch_t + 1)
#
# IndexError: list index out of range

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - DenseNet169")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
