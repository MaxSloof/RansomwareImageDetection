# %% [markdown]
# Used ReLU instead of LeakyReLU
#
# 0.3 val split

# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Tweakable Parameters**

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 64

# Number of epochs
epoch_t = 50

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/malimg_dataset"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 5 matches(es) found
# --------------
# New folder name: cnn-local-v006
# --------------

# %% [markdown]
# Retrieve Data

# %%
path_root = "C:/Users/Max/Documents/image_data/malimg_paper_dataset_imgs"

# %%
t_datagen = ImageDataGenerator(
    rescale=1/255,
    validation_split=test_size
    )

# %%
train = t_datagen.flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic',
    subset='training',
    seed = 123
)
# Out:
# Found 6549 images belonging to 25 classes.

# %%
v_datagen = ImageDataGenerator(
    rescale=1/255,
    validation_split=test_size)

# %%
test = v_datagen.flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic',
    subset='validation',
    seed = 123,
    shuffle = False
)
# Out:
# Found 2790 images belonging to 25 classes.

# %%
display = t_datagen.flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = 50,
    interpolation = 'bicubic',
    subset='training',
    seed = 123,
    shuffle = True
)
# Out:
# Found 6549 images belonging to 25 classes.

# %%
num_samples = train.samples

# %%
train.class_indices
# Out:
# {'Adialer.C': 0,
#  'Agent.FYI': 1,
#  'Allaple.A': 2,
#  'Allaple.L': 3,
#  'Alueron.gen!J': 4,
#  'Autorun.K': 5,
#  'C2LOP.P': 6,
#  'C2LOP.gen!g': 7,
#  'Dialplatform.B': 8,
#  'Dontovo.A': 9,
#  'Fakerean': 10,
#  'Instantaccess': 11,
#  'Lolyda.AA1': 12,
#  'Lolyda.AA2': 13,
#  'Lolyda.AA3': 14,
#  'Lolyda.AT': 15,
#  'Malex.gen!J': 16,
#  'Obfuscator.AD': 17,
#  'Rbot!gen': 18,
#  'Skintrim.N': 19,
#  'Swizzor.gen!E': 20,
#  'Swizzor.gen!I': 21,
#  'VB.AT': 22,
#  'Wintrim.BX': 23,
#  'Yuner.A': 24}

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(display.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')

imgs, labels = display.next()
plots(imgs, titles = labels)

# %%
imgs.shape
# Out:
# (50, 64, 64, 1)

# %%
img, label = display.next()

# %%
display.class_indices
# Out:
# {'Adialer.C': 0,
#  'Agent.FYI': 1,
#  'Allaple.A': 2,
#  'Allaple.L': 3,
#  'Alueron.gen!J': 4,
#  'Autorun.K': 5,
#  'C2LOP.P': 6,
#  'C2LOP.gen!g': 7,
#  'Dialplatform.B': 8,
#  'Dontovo.A': 9,
#  'Fakerean': 10,
#  'Instantaccess': 11,
#  'Lolyda.AA1': 12,
#  'Lolyda.AA2': 13,
#  'Lolyda.AA3': 14,
#  'Lolyda.AT': 15,
#  'Malex.gen!J': 16,
#  'Obfuscator.AD': 17,
#  'Rbot!gen': 18,
#  'Skintrim.N': 19,
#  'Swizzor.gen!E': 20,
#  'Swizzor.gen!I': 21,
#  'VB.AT': 22,
#  'Wintrim.BX': 23,
#  'Yuner.A': 24}

# %%
perc = (sum(to_categorical(train.classes))/train.classes.shape[0])*100

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(list(display.class_indices.keys()),perc)
plt.ylabel('Distribution of data in percentages (%)')

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # CNN MODEL

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
num_classes = max(train.labels) + 1
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  25

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    
    Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='relu'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='relu'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 15)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 15)        2040
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 15)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 540)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               69248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                1275
# =================================================================
# Total params: 83,378
# Trainable params: 83,378
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    train,
    steps_per_epoch=num_samples//batch_size,
    epochs=epoch_t,
    callbacks = [anne, checkpoint],
    validation_data=test,
    validation_steps=test.samples//batch_size) # The actual computation of the CNN
# Out:
# Epoch 1/50
# 102/102 [==============================] - 19s 168ms/step - loss: 2.5095 - accuracy: 0.3045 - val_loss: 2.1256 - val_accuracy: 0.4462
#
# Epoch 00001: val_loss improved from inf to 2.12561, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 2/50
# 102/102 [==============================] - 12s 121ms/step - loss: 1.5031 - accuracy: 0.5187 - val_loss: 1.1619 - val_accuracy: 0.6468
#
# Epoch 00002: val_loss improved from 2.12561 to 1.16187, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 3/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.9142 - accuracy: 0.7081 - val_loss: 0.5648 - val_accuracy: 0.8434
#
# Epoch 00003: val_loss improved from 1.16187 to 0.56480, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 4/50
# 102/102 [==============================] - 12s 120ms/step - loss: 0.6062 - accuracy: 0.8171 - val_loss: 0.3888 - val_accuracy: 0.8881
#
# Epoch 00004: val_loss improved from 0.56480 to 0.38880, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 5/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.4371 - accuracy: 0.8629 - val_loss: 0.3151 - val_accuracy: 0.9237
#
# Epoch 00005: val_loss improved from 0.38880 to 0.31505, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 6/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.3447 - accuracy: 0.8955 - val_loss: 0.2668 - val_accuracy: 0.9273
#
# Epoch 00006: val_loss improved from 0.31505 to 0.26679, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 7/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.3304 - accuracy: 0.8951 - val_loss: 0.2484 - val_accuracy: 0.9328
#
# Epoch 00007: val_loss improved from 0.26679 to 0.24840, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 8/50
# 102/102 [==============================] - 12s 120ms/step - loss: 0.2621 - accuracy: 0.9149 - val_loss: 0.2564 - val_accuracy: 0.9455
#
# Epoch 00008: val_loss did not improve from 0.24840
# Epoch 9/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.2341 - accuracy: 0.9215 - val_loss: 0.2225 - val_accuracy: 0.9422
#
# Epoch 00009: val_loss improved from 0.24840 to 0.22254, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 10/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.2163 - accuracy: 0.9274 - val_loss: 0.2168 - val_accuracy: 0.9513
#
# Epoch 00010: val_loss improved from 0.22254 to 0.21679, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 11/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.2100 - accuracy: 0.9288 - val_loss: 0.2045 - val_accuracy: 0.9528
#
# Epoch 00011: val_loss improved from 0.21679 to 0.20445, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 12/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.2005 - accuracy: 0.9343 - val_loss: 0.2126 - val_accuracy: 0.9433
#
# Epoch 00012: val_loss did not improve from 0.20445
# Epoch 13/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1805 - accuracy: 0.9400 - val_loss: 0.1890 - val_accuracy: 0.9477
#
# Epoch 00013: val_loss improved from 0.20445 to 0.18899, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 14/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1830 - accuracy: 0.9377 - val_loss: 0.2034 - val_accuracy: 0.9473
#
# Epoch 00014: val_loss did not improve from 0.18899
# Epoch 15/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1723 - accuracy: 0.9437 - val_loss: 0.2193 - val_accuracy: 0.9433
#
# Epoch 00015: val_loss did not improve from 0.18899
# Epoch 16/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1785 - accuracy: 0.9412 - val_loss: 0.1863 - val_accuracy: 0.9495
#
# Epoch 00016: val_loss improved from 0.18899 to 0.18629, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 17/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1664 - accuracy: 0.9439 - val_loss: 0.1996 - val_accuracy: 0.9553
#
# Epoch 00017: val_loss did not improve from 0.18629
# Epoch 18/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1554 - accuracy: 0.9449 - val_loss: 0.1879 - val_accuracy: 0.9549
#
# Epoch 00018: val_loss did not improve from 0.18629
# Epoch 19/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1526 - accuracy: 0.9496 - val_loss: 0.1936 - val_accuracy: 0.9549
#
# Epoch 00019: val_loss did not improve from 0.18629
# Epoch 20/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1500 - accuracy: 0.9485 - val_loss: 0.1889 - val_accuracy: 0.9524
#
# Epoch 00020: val_loss did not improve from 0.18629
# Epoch 21/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1477 - accuracy: 0.9525 - val_loss: 0.1817 - val_accuracy: 0.9535
#
# Epoch 00021: val_loss improved from 0.18629 to 0.18172, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 22/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1385 - accuracy: 0.9517 - val_loss: 0.1776 - val_accuracy: 0.9560
#
# Epoch 00022: val_loss improved from 0.18172 to 0.17758, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 23/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1364 - accuracy: 0.9533 - val_loss: 0.1704 - val_accuracy: 0.9608
#
# Epoch 00023: val_loss improved from 0.17758 to 0.17036, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 24/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1319 - accuracy: 0.9530 - val_loss: 0.1936 - val_accuracy: 0.9597
#
# Epoch 00024: val_loss did not improve from 0.17036
# Epoch 25/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1336 - accuracy: 0.9571 - val_loss: 0.1850 - val_accuracy: 0.9495
#
# Epoch 00025: val_loss did not improve from 0.17036
# Epoch 26/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1232 - accuracy: 0.9576 - val_loss: 0.1644 - val_accuracy: 0.9633
#
# Epoch 00026: val_loss improved from 0.17036 to 0.16440, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 27/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1242 - accuracy: 0.9554 - val_loss: 0.1629 - val_accuracy: 0.9640
#
# Epoch 00027: val_loss improved from 0.16440 to 0.16288, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 28/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1197 - accuracy: 0.9594 - val_loss: 0.1671 - val_accuracy: 0.9626
#
# Epoch 00028: val_loss did not improve from 0.16288
# Epoch 29/50
# 102/102 [==============================] - 13s 127ms/step - loss: 0.1200 - accuracy: 0.9588 - val_loss: 0.1612 - val_accuracy: 0.9608
#
# Epoch 00029: val_loss improved from 0.16288 to 0.16121, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 30/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1103 - accuracy: 0.9639 - val_loss: 0.1812 - val_accuracy: 0.9560
#
# Epoch 00030: val_loss did not improve from 0.16121
# Epoch 31/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1262 - accuracy: 0.9573 - val_loss: 0.1803 - val_accuracy: 0.9597
#
# Epoch 00031: val_loss did not improve from 0.16121
# Epoch 32/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1251 - accuracy: 0.9587 - val_loss: 0.1696 - val_accuracy: 0.9535
#
# Epoch 00032: val_loss did not improve from 0.16121
# Epoch 33/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1165 - accuracy: 0.9610 - val_loss: 0.1531 - val_accuracy: 0.9608
#
# Epoch 00033: val_loss improved from 0.16121 to 0.15307, saving model to /Users/Max/Documents/GitHub/malimg_dataset/cnn-local-v006\model.h5
# Epoch 34/50
# 102/102 [==============================] - 13s 124ms/step - loss: 0.1123 - accuracy: 0.9605 - val_loss: 0.1641 - val_accuracy: 0.9593
#
# Epoch 00034: val_loss did not improve from 0.15307
# Epoch 35/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1225 - accuracy: 0.9598 - val_loss: 0.1716 - val_accuracy: 0.9557
#
# Epoch 00035: val_loss did not improve from 0.15307
# Epoch 36/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1105 - accuracy: 0.9628 - val_loss: 0.1664 - val_accuracy: 0.9629
#
# Epoch 00036: val_loss did not improve from 0.15307
# Epoch 37/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1077 - accuracy: 0.9622 - val_loss: 0.1628 - val_accuracy: 0.9651
#
# Epoch 00037: val_loss did not improve from 0.15307
# Epoch 38/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1077 - accuracy: 0.9602 - val_loss: 0.1612 - val_accuracy: 0.9633
#
# Epoch 00038: val_loss did not improve from 0.15307
# Epoch 39/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1068 - accuracy: 0.9630 - val_loss: 0.1631 - val_accuracy: 0.9637
#
# Epoch 00039: val_loss did not improve from 0.15307
# Epoch 40/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1017 - accuracy: 0.9639 - val_loss: 0.1634 - val_accuracy: 0.9673
#
# Epoch 00040: val_loss did not improve from 0.15307
# Epoch 41/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1027 - accuracy: 0.9645 - val_loss: 0.1677 - val_accuracy: 0.9669
#
# Epoch 00041: val_loss did not improve from 0.15307
# Epoch 42/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.1021 - accuracy: 0.9641 - val_loss: 0.1538 - val_accuracy: 0.9662
#
# Epoch 00042: val_loss did not improve from 0.15307
# Epoch 43/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1042 - accuracy: 0.9635 - val_loss: 0.1569 - val_accuracy: 0.9666
#
# Epoch 00043: val_loss did not improve from 0.15307
# Epoch 44/50
# 102/102 [==============================] - 13s 125ms/step - loss: 0.1055 - accuracy: 0.9642 - val_loss: 0.1649 - val_accuracy: 0.9651
#
# Epoch 00044: val_loss did not improve from 0.15307
# Epoch 45/50
# 102/102 [==============================] - 13s 125ms/step - loss: 0.0942 - accuracy: 0.9672 - val_loss: 0.1816 - val_accuracy: 0.9593
#
# Epoch 00045: val_loss did not improve from 0.15307
# Epoch 46/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.1025 - accuracy: 0.9648 - val_loss: 0.1607 - val_accuracy: 0.9677
#
# Epoch 00046: val_loss did not improve from 0.15307
# Epoch 47/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.0899 - accuracy: 0.9682 - val_loss: 0.1649 - val_accuracy: 0.9655
#
# Epoch 00047: val_loss did not improve from 0.15307
# Epoch 48/50
# 102/102 [==============================] - 12s 121ms/step - loss: 0.0989 - accuracy: 0.9665 - val_loss: 0.1611 - val_accuracy: 0.9655
#
# Epoch 00048: val_loss did not improve from 0.15307
# Epoch 49/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.0855 - accuracy: 0.9702 - val_loss: 0.1548 - val_accuracy: 0.9688
#
# Epoch 00049: val_loss did not improve from 0.15307
# Epoch 50/50
# 102/102 [==============================] - 12s 122ms/step - loss: 0.0944 - accuracy: 0.9679 - val_loss: 0.1744 - val_accuracy: 0.9662
#
# Epoch 00050: val_loss did not improve from 0.15307

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(test, steps = test.samples//batch_size) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 43/43 [==============================] - 4s 82ms/step - loss: 0.1531 - accuracy: 0.9608
# Overall CNN Accuracy: 0.9607558250427246
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9608          |
# | Validation loss               | 0.1531          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(best_model.predict(test, steps= test.samples//batch_size+1), axis=-1)
y_pred
# Out:
# array([ 0,  0,  0, ..., 24, 24, 24], dtype=int64)

# %%
true_classes = test.classes
class_labels = list(test.class_indices.keys())

# %%
report = metrics.classification_report(true_classes, y_pred, target_names=class_labels)
# Out:
# C:\Users\Max\anaconda3\envs\master_thesis\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Max\anaconda3\envs\master_thesis\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Max\anaconda3\envs\master_thesis\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(report)
# Out:
#                 precision    recall  f1-score   support
#
#      Adialer.C       1.00      1.00      1.00        36
#      Agent.FYI       1.00      1.00      1.00        34
#      Allaple.A       1.00      1.00      1.00       884
#      Allaple.L       1.00      1.00      1.00       477
#  Alueron.gen!J       0.98      1.00      0.99        59
#      Autorun.K       0.00      0.00      0.00        31
#        C2LOP.P       0.77      0.79      0.78        43
#    C2LOP.gen!g       0.88      0.88      0.88        60
# Dialplatform.B       1.00      0.96      0.98        53
#      Dontovo.A       1.00      1.00      1.00        48
#       Fakerean       0.98      0.96      0.97       114
#  Instantaccess       0.99      1.00      1.00       129
#     Lolyda.AA1       0.80      1.00      0.89        63
#     Lolyda.AA2       0.98      0.75      0.85        55
#     Lolyda.AA3       0.97      1.00      0.99        36
#      Lolyda.AT       1.00      0.96      0.98        47
#    Malex.gen!J       0.97      0.95      0.96        40
#  Obfuscator.AD       1.00      1.00      1.00        42
#       Rbot!gen       0.96      0.98      0.97        47
#     Skintrim.N       0.89      1.00      0.94        24
#  Swizzor.gen!E       0.79      0.68      0.73        38
#  Swizzor.gen!I       0.61      0.51      0.56        39
#          VB.AT       0.93      0.99      0.96       122
#     Wintrim.BX       0.97      1.00      0.98        29
#        Yuner.A       0.89      1.00      0.94       240
#
#       accuracy                           0.96      2790
#      macro avg       0.89      0.90      0.89      2790
#   weighted avg       0.95      0.96      0.96      2790

# %%
c_matrix = metrics.confusion_matrix(true_classes, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= train.class_indices.keys()
confusion_matrix(c_matrix, class_labels, figsize = (20,7), fontsize=14)
