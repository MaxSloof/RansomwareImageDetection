# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/malimg_dataset"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-cgan-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 16 matches(es) found
# --------------
# New folder name: crossv-cgan-cnn-local-v020
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/malimgdataset"
    path_root_gen = '/kaggle/input/malimgcganlocalv009woallaple'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/malimg_paper_dataset_imgs"
    path_root_gen = "C:/Users/Max/Documents/image_data/malimg-cgan-v025-rightsize"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 9339 images belonging to 25 classes.

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 58507 images belonging to 25 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  25

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))
    
    # Include lower weights for CGAN data
    sample_weights1 = np.full(len(labels[train]), 1)
    sample_weights2 = np.full(len(labels_gen), 0.5)
    sample_weights = np.concatenate((sample_weights1, sample_weights2))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        sample_weight=sample_weights,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(train_labels)/train_labels.shape[0])*100)
# Out:
# Epoch 1/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.2328 - accuracy: 0.9047 - val_loss: 0.1779 - val_accuracy: 0.9518
#
# Epoch 00001: val_loss improved from inf to 0.17792, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 2/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0555 - accuracy: 0.9818 - val_loss: 0.1597 - val_accuracy: 0.9615
#
# Epoch 00002: val_loss improved from 0.17792 to 0.15974, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 3/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0429 - accuracy: 0.9859 - val_loss: 0.1447 - val_accuracy: 0.9657
#
# Epoch 00003: val_loss improved from 0.15974 to 0.14470, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 4/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0362 - accuracy: 0.9875 - val_loss: 0.1454 - val_accuracy: 0.9754
#
# Epoch 00004: val_loss did not improve from 0.14470
# Epoch 5/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0301 - accuracy: 0.9898 - val_loss: 0.1328 - val_accuracy: 0.9786
#
# Epoch 00005: val_loss improved from 0.14470 to 0.13275, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 6/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0309 - accuracy: 0.9893 - val_loss: 0.1213 - val_accuracy: 0.9711
#
# Epoch 00006: val_loss improved from 0.13275 to 0.12134, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 7/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 0.1141 - val_accuracy: 0.9743
#
# Epoch 00007: val_loss improved from 0.12134 to 0.11406, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 8/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.1166 - val_accuracy: 0.9754
#
# Epoch 00008: val_loss did not improve from 0.11406
# Epoch 9/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.1135 - val_accuracy: 0.9764
#
# Epoch 00009: val_loss improved from 0.11406 to 0.11352, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 10/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0240 - accuracy: 0.9914 - val_loss: 0.1190 - val_accuracy: 0.9754
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_loss did not improve from 0.11352
# Epoch 11/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0169 - accuracy: 0.9939 - val_loss: 0.1136 - val_accuracy: 0.9754
#
# Epoch 00011: val_loss did not improve from 0.11352
# Epoch 12/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0158 - accuracy: 0.9949 - val_loss: 0.1272 - val_accuracy: 0.9807
#
# Epoch 00012: val_loss did not improve from 0.11352
# Epoch 13/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 0.1247 - val_accuracy: 0.9743
#
# Epoch 00013: val_loss did not improve from 0.11352
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.1206 - val_accuracy: 0.9786
#
# Epoch 00014: val_loss did not improve from 0.11352
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.1139 - val_accuracy: 0.9764
#
# Epoch 00015: val_loss did not improve from 0.11352
# Epoch 16/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.1079 - val_accuracy: 0.9764
#
# Epoch 00016: val_loss improved from 0.11352 to 0.10794, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 17/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.1267 - val_accuracy: 0.9754
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00017: val_loss did not improve from 0.10794
# Epoch 18/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.1181 - val_accuracy: 0.9786
#
# Epoch 00018: val_loss did not improve from 0.10794
# Epoch 19/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.1128 - val_accuracy: 0.9786
#
# Epoch 00019: val_loss did not improve from 0.10794
# Epoch 20/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.1177 - val_accuracy: 0.9786
#
# Epoch 00020: val_loss did not improve from 0.10794
# Epoch 21/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.1177 - val_accuracy: 0.9807
#
# Epoch 00021: val_loss did not improve from 0.10794
# Epoch 22/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.1253 - val_accuracy: 0.9786
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00022: val_loss did not improve from 0.10794
# Epoch 23/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.1174 - val_accuracy: 0.9786
#
# Epoch 00023: val_loss did not improve from 0.10794
# Epoch 24/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.1202 - val_accuracy: 0.9807
#
# Epoch 00024: val_loss did not improve from 0.10794
# Epoch 25/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.1167 - val_accuracy: 0.9797
#
# Epoch 00025: val_loss did not improve from 0.10794
# Epoch 26/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.1107 - val_accuracy: 0.9786
#
# Epoch 00026: val_loss did not improve from 0.10794
# Epoch 27/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0102 - accuracy: 0.9963 - val_loss: 0.1177 - val_accuracy: 0.9797
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00027: val_loss did not improve from 0.10794
# Epoch 28/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.1155 - val_accuracy: 0.9818
#
# Epoch 00028: val_loss did not improve from 0.10794
# Epoch 29/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.1138 - val_accuracy: 0.9797
#
# Epoch 00029: val_loss did not improve from 0.10794
# Epoch 30/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.1194 - val_accuracy: 0.9775
#
# Epoch 00030: val_loss did not improve from 0.10794
# Epoch 31/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.1191 - val_accuracy: 0.9797
#
# Epoch 00031: val_loss did not improve from 0.10794
# Epoch 32/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.1218 - val_accuracy: 0.9807
#
# Epoch 00032: val_loss did not improve from 0.10794
# Epoch 33/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.1207 - val_accuracy: 0.9797
#
# Epoch 00033: val_loss did not improve from 0.10794
# Epoch 34/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.1132 - val_accuracy: 0.9786
#
# Epoch 00034: val_loss did not improve from 0.10794
# Epoch 35/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.1168 - val_accuracy: 0.9786
#
# Epoch 00035: val_loss did not improve from 0.10794
# Epoch 36/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.1195 - val_accuracy: 0.9775
#
# Epoch 00036: val_loss did not improve from 0.10794
# Epoch 37/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.1211 - val_accuracy: 0.9797
#
# Epoch 00037: val_loss did not improve from 0.10794
# Epoch 38/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.1241 - val_accuracy: 0.9786
#
# Epoch 00038: val_loss did not improve from 0.10794
# Epoch 39/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.1275 - val_accuracy: 0.9775
#
# Epoch 00039: val_loss did not improve from 0.10794
# Epoch 40/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.1325 - val_accuracy: 0.9807
#
# Epoch 00040: val_loss did not improve from 0.10794
# Score for fold 1: loss of 0.1324928104877472; accuracy of 98.0728030204773%
# Epoch 1/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.2182 - accuracy: 0.9116 - val_loss: 0.1677 - val_accuracy: 0.9475
#
# Epoch 00001: val_loss did not improve from 0.10794
# Epoch 2/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0569 - accuracy: 0.9821 - val_loss: 0.1120 - val_accuracy: 0.9668
#
# Epoch 00002: val_loss did not improve from 0.10794
# Epoch 3/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0422 - accuracy: 0.9863 - val_loss: 0.0963 - val_accuracy: 0.9690
#
# Epoch 00003: val_loss improved from 0.10794 to 0.09630, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 4/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0338 - accuracy: 0.9884 - val_loss: 0.1063 - val_accuracy: 0.9636
#
# Epoch 00004: val_loss did not improve from 0.09630
# Epoch 5/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0314 - accuracy: 0.9898 - val_loss: 0.0963 - val_accuracy: 0.9657
#
# Epoch 00005: val_loss did not improve from 0.09630
# Epoch 6/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0283 - accuracy: 0.9905 - val_loss: 0.0825 - val_accuracy: 0.9679
#
# Epoch 00006: val_loss improved from 0.09630 to 0.08251, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 7/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0262 - accuracy: 0.9917 - val_loss: 0.0706 - val_accuracy: 0.9743
#
# Epoch 00007: val_loss improved from 0.08251 to 0.07062, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 8/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0233 - accuracy: 0.9920 - val_loss: 0.0867 - val_accuracy: 0.9679
#
# Epoch 00008: val_loss did not improve from 0.07062
# Epoch 9/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.0771 - val_accuracy: 0.9722
#
# Epoch 00009: val_loss did not improve from 0.07062
# Epoch 10/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.0760 - val_accuracy: 0.9732
#
# Epoch 00010: val_loss did not improve from 0.07062
# Epoch 11/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0812 - val_accuracy: 0.9711
#
# Epoch 00011: val_loss did not improve from 0.07062
# Epoch 12/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.0787 - val_accuracy: 0.9743
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00012: val_loss did not improve from 0.07062
# Epoch 13/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.0651 - val_accuracy: 0.9764
#
# Epoch 00013: val_loss improved from 0.07062 to 0.06512, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.0638 - val_accuracy: 0.9786
#
# Epoch 00014: val_loss improved from 0.06512 to 0.06379, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 15/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0141 - accuracy: 0.9950 - val_loss: 0.0664 - val_accuracy: 0.9732
#
# Epoch 00015: val_loss did not improve from 0.06379
# Epoch 16/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0647 - val_accuracy: 0.9786
#
# Epoch 00016: val_loss did not improve from 0.06379
# Epoch 17/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.0663 - val_accuracy: 0.9786
#
# Epoch 00017: val_loss did not improve from 0.06379
# Epoch 18/40
# 1513/1513 [==============================] - 11s 7ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0615 - val_accuracy: 0.9807
#
# Epoch 00018: val_loss improved from 0.06379 to 0.06149, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 19/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0645 - val_accuracy: 0.9797
#
# Epoch 00019: val_loss did not improve from 0.06149
# Epoch 20/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.0668 - val_accuracy: 0.9764
#
# Epoch 00020: val_loss did not improve from 0.06149
# Epoch 21/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.0734 - val_accuracy: 0.9764
#
# Epoch 00021: val_loss did not improve from 0.06149
# Epoch 22/40
# 1513/1513 [==============================] - 13s 8ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0594 - val_accuracy: 0.9786
#
# Epoch 00022: val_loss improved from 0.06149 to 0.05939, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 23/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0650 - val_accuracy: 0.9797
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_loss did not improve from 0.05939
# Epoch 24/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0644 - val_accuracy: 0.9786
#
# Epoch 00024: val_loss did not improve from 0.05939
# Epoch 25/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0611 - val_accuracy: 0.9775
#
# Epoch 00025: val_loss did not improve from 0.05939
# Epoch 26/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0605 - val_accuracy: 0.9775
#
# Epoch 00026: val_loss did not improve from 0.05939
# Epoch 27/40
# 1513/1513 [==============================] - 11s 7ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0704 - val_accuracy: 0.9754
#
# Epoch 00027: val_loss did not improve from 0.05939
# Epoch 28/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0664 - val_accuracy: 0.9786
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00028: val_loss did not improve from 0.05939
# Epoch 29/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0689 - val_accuracy: 0.9764
#
# Epoch 00029: val_loss did not improve from 0.05939
# Epoch 30/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0624 - val_accuracy: 0.9786
#
# Epoch 00030: val_loss did not improve from 0.05939
# Epoch 31/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0620 - val_accuracy: 0.9764
#
# Epoch 00031: val_loss did not improve from 0.05939
# Epoch 32/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0634 - val_accuracy: 0.9775
#
# Epoch 00032: val_loss did not improve from 0.05939
# Epoch 33/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0636 - val_accuracy: 0.9786
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00033: val_loss did not improve from 0.05939
# Epoch 34/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0660 - val_accuracy: 0.9786
#
# Epoch 00034: val_loss did not improve from 0.05939
# Epoch 35/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0647 - val_accuracy: 0.9797
#
# Epoch 00035: val_loss did not improve from 0.05939
# Epoch 36/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0619 - val_accuracy: 0.9786
#
# Epoch 00036: val_loss did not improve from 0.05939
# Epoch 37/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0576 - val_accuracy: 0.9797
#
# Epoch 00037: val_loss improved from 0.05939 to 0.05756, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-cnn-local-v020\model.h5
# Epoch 38/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0684 - val_accuracy: 0.9764
#
# Epoch 00038: val_loss did not improve from 0.05756
# Epoch 39/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0645 - val_accuracy: 0.9764
#
# Epoch 00039: val_loss did not improve from 0.05756
# Epoch 40/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0621 - val_accuracy: 0.9807
#
# Epoch 00040: val_loss did not improve from 0.05756
# Score for fold 2: loss of 0.06207190081477165; accuracy of 98.0728030204773%
# Epoch 1/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.2384 - accuracy: 0.9000 - val_loss: 0.1965 - val_accuracy: 0.9475
#
# Epoch 00001: val_loss did not improve from 0.05756
# Epoch 2/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0667 - accuracy: 0.9770 - val_loss: 0.1438 - val_accuracy: 0.9561
#
# Epoch 00002: val_loss did not improve from 0.05756
# Epoch 3/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0470 - accuracy: 0.9841 - val_loss: 0.1396 - val_accuracy: 0.9582
#
# Epoch 00003: val_loss did not improve from 0.05756
# Epoch 4/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0400 - accuracy: 0.9861 - val_loss: 0.1111 - val_accuracy: 0.9679
#
# Epoch 00004: val_loss did not improve from 0.05756
# Epoch 5/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0333 - accuracy: 0.9886 - val_loss: 0.1659 - val_accuracy: 0.9540
#
# Epoch 00005: val_loss did not improve from 0.05756
# Epoch 6/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0325 - accuracy: 0.9888 - val_loss: 0.1429 - val_accuracy: 0.9636
#
# Epoch 00006: val_loss did not improve from 0.05756
# Epoch 7/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.1208 - val_accuracy: 0.9668
#
# Epoch 00007: val_loss did not improve from 0.05756
# Epoch 8/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0254 - accuracy: 0.9913 - val_loss: 0.1069 - val_accuracy: 0.9722
#
# Epoch 00008: val_loss did not improve from 0.05756
# Epoch 9/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0251 - accuracy: 0.9913 - val_loss: 0.1072 - val_accuracy: 0.9647
#
# Epoch 00009: val_loss did not improve from 0.05756
# Epoch 10/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0226 - accuracy: 0.9921 - val_loss: 0.1172 - val_accuracy: 0.9690
#
# Epoch 00010: val_loss did not improve from 0.05756
# Epoch 11/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0220 - accuracy: 0.9923 - val_loss: 0.1064 - val_accuracy: 0.9754
#
# Epoch 00011: val_loss did not improve from 0.05756
# Epoch 12/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0197 - accuracy: 0.9926 - val_loss: 0.1004 - val_accuracy: 0.9786
#
# Epoch 00012: val_loss did not improve from 0.05756
# Epoch 13/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0209 - accuracy: 0.9926 - val_loss: 0.1057 - val_accuracy: 0.9743
#
# Epoch 00013: val_loss did not improve from 0.05756
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 0.1047 - val_accuracy: 0.9743
#
# Epoch 00014: val_loss did not improve from 0.05756
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0198 - accuracy: 0.9929 - val_loss: 0.0960 - val_accuracy: 0.9743
#
# Epoch 00015: val_loss did not improve from 0.05756
# Epoch 16/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0990 - val_accuracy: 0.9786
#
# Epoch 00016: val_loss did not improve from 0.05756
# Epoch 17/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.0989 - val_accuracy: 0.9775
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.05756
# Epoch 18/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.1173 - val_accuracy: 0.9732
#
# Epoch 00018: val_loss did not improve from 0.05756
# Epoch 19/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.1195 - val_accuracy: 0.9754
#
# Epoch 00019: val_loss did not improve from 0.05756
# Epoch 20/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.1150 - val_accuracy: 0.9764
#
# Epoch 00020: val_loss did not improve from 0.05756
# Epoch 21/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.1422 - val_accuracy: 0.9722
#
# Epoch 00021: val_loss did not improve from 0.05756
# Epoch 22/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.1091 - val_accuracy: 0.9786
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.05756
# Epoch 23/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.1214 - val_accuracy: 0.9754
#
# Epoch 00023: val_loss did not improve from 0.05756
# Epoch 24/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.1187 - val_accuracy: 0.9786
#
# Epoch 00024: val_loss did not improve from 0.05756
# Epoch 25/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.1083 - val_accuracy: 0.9818
#
# Epoch 00025: val_loss did not improve from 0.05756
# Epoch 26/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.1273 - val_accuracy: 0.9797
#
# Epoch 00026: val_loss did not improve from 0.05756
# Epoch 27/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.1223 - val_accuracy: 0.9807
#
# Epoch 00027: val_loss did not improve from 0.05756
# Epoch 28/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.1241 - val_accuracy: 0.9818
#
# Epoch 00028: val_loss did not improve from 0.05756
# Epoch 29/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.1395 - val_accuracy: 0.9775
#
# Epoch 00029: val_loss did not improve from 0.05756
# Epoch 30/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.1286 - val_accuracy: 0.9797
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.05756
# Epoch 31/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.1349 - val_accuracy: 0.9818
#
# Epoch 00031: val_loss did not improve from 0.05756
# Epoch 32/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.1284 - val_accuracy: 0.9829
#
# Epoch 00032: val_loss did not improve from 0.05756
# Epoch 33/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.1330 - val_accuracy: 0.9807
#
# Epoch 00033: val_loss did not improve from 0.05756
# Epoch 34/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.1353 - val_accuracy: 0.9829
#
# Epoch 00034: val_loss did not improve from 0.05756
# Epoch 35/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1485 - val_accuracy: 0.9786
#
# Epoch 00035: val_loss did not improve from 0.05756
# Epoch 36/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.1351 - val_accuracy: 0.9807
#
# Epoch 00036: val_loss did not improve from 0.05756
# Epoch 37/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.1305 - val_accuracy: 0.9829
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00037: val_loss did not improve from 0.05756
# Epoch 38/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.1361 - val_accuracy: 0.9839
#
# Epoch 00038: val_loss did not improve from 0.05756
# Epoch 39/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.1374 - val_accuracy: 0.9807
#
# Epoch 00039: val_loss did not improve from 0.05756
# Epoch 40/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.1400 - val_accuracy: 0.9829
#
# Epoch 00040: val_loss did not improve from 0.05756
# Score for fold 3: loss of 0.14000922441482544; accuracy of 98.28693866729736%
# Epoch 1/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.2542 - accuracy: 0.8898 - val_loss: 0.1809 - val_accuracy: 0.9422
#
# Epoch 00001: val_loss did not improve from 0.05756
# Epoch 2/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0659 - accuracy: 0.9765 - val_loss: 0.1865 - val_accuracy: 0.9465
#
# Epoch 00002: val_loss did not improve from 0.05756
# Epoch 3/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0491 - accuracy: 0.9826 - val_loss: 0.1520 - val_accuracy: 0.9529
#
# Epoch 00003: val_loss did not improve from 0.05756
# Epoch 4/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0391 - accuracy: 0.9862 - val_loss: 0.1685 - val_accuracy: 0.9561
#
# Epoch 00004: val_loss did not improve from 0.05756
# Epoch 5/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0374 - accuracy: 0.9871 - val_loss: 0.1522 - val_accuracy: 0.9572
#
# Epoch 00005: val_loss did not improve from 0.05756
# Epoch 6/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0315 - accuracy: 0.9893 - val_loss: 0.1510 - val_accuracy: 0.9561
#
# Epoch 00006: val_loss did not improve from 0.05756
# Epoch 7/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 0.1299 - val_accuracy: 0.9647
#
# Epoch 00007: val_loss did not improve from 0.05756
# Epoch 8/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0264 - accuracy: 0.9907 - val_loss: 0.1238 - val_accuracy: 0.9647
#
# Epoch 00008: val_loss did not improve from 0.05756
# Epoch 9/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 0.1315 - val_accuracy: 0.9657
#
# Epoch 00009: val_loss did not improve from 0.05756
# Epoch 10/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0234 - accuracy: 0.9916 - val_loss: 0.1400 - val_accuracy: 0.9625
#
# Epoch 00010: val_loss did not improve from 0.05756
# Epoch 11/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0235 - accuracy: 0.9916 - val_loss: 0.1382 - val_accuracy: 0.9615
#
# Epoch 00011: val_loss did not improve from 0.05756
# Epoch 12/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.1174 - val_accuracy: 0.9636
#
# Epoch 00012: val_loss did not improve from 0.05756
# Epoch 13/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0195 - accuracy: 0.9930 - val_loss: 0.1639 - val_accuracy: 0.9540
#
# Epoch 00013: val_loss did not improve from 0.05756
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0186 - accuracy: 0.9933 - val_loss: 0.1289 - val_accuracy: 0.9615
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.05756
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.1411 - val_accuracy: 0.9647
#
# Epoch 00015: val_loss did not improve from 0.05756
# Epoch 16/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 0.1300 - val_accuracy: 0.9625
#
# Epoch 00016: val_loss did not improve from 0.05756
# Epoch 17/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.1282 - val_accuracy: 0.9668
#
# Epoch 00017: val_loss did not improve from 0.05756
# Epoch 18/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.1517 - val_accuracy: 0.9636
#
# Epoch 00018: val_loss did not improve from 0.05756
# Epoch 19/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.1409 - val_accuracy: 0.9647
#
# Epoch 00019: val_loss did not improve from 0.05756
# Epoch 20/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.1301 - val_accuracy: 0.9679
#
# Epoch 00020: val_loss did not improve from 0.05756
# Epoch 21/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1304 - val_accuracy: 0.9690
#
# Epoch 00021: val_loss did not improve from 0.05756
# Epoch 22/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.1754 - val_accuracy: 0.9593
#
# Epoch 00022: val_loss did not improve from 0.05756
# Epoch 23/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.1378 - val_accuracy: 0.9668
#
# Epoch 00023: val_loss did not improve from 0.05756
# Epoch 24/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.1444 - val_accuracy: 0.9647
#
# Epoch 00024: val_loss did not improve from 0.05756
# Epoch 25/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.1543 - val_accuracy: 0.9657
#
# Epoch 00025: val_loss did not improve from 0.05756
# Epoch 26/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.1363 - val_accuracy: 0.9700
#
# Epoch 00026: val_loss did not improve from 0.05756
# Epoch 27/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.1230 - val_accuracy: 0.9700
#
# Epoch 00027: val_loss did not improve from 0.05756
# Epoch 28/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.1549 - val_accuracy: 0.9668
#
# Epoch 00028: val_loss did not improve from 0.05756
# Epoch 29/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.1470 - val_accuracy: 0.9647
#
# Epoch 00029: val_loss did not improve from 0.05756
# Epoch 30/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.1480 - val_accuracy: 0.9668
#
# Epoch 00030: val_loss did not improve from 0.05756
# Epoch 31/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.1583 - val_accuracy: 0.9647
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00031: val_loss did not improve from 0.05756
# Epoch 32/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1578 - val_accuracy: 0.9679
#
# Epoch 00032: val_loss did not improve from 0.05756
# Epoch 33/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.1744 - val_accuracy: 0.9657
#
# Epoch 00033: val_loss did not improve from 0.05756
# Epoch 34/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.1439 - val_accuracy: 0.9690
#
# Epoch 00034: val_loss did not improve from 0.05756
# Epoch 35/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.1733 - val_accuracy: 0.9625
#
# Epoch 00035: val_loss did not improve from 0.05756
# Epoch 36/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.1444 - val_accuracy: 0.9668
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00036: val_loss did not improve from 0.05756
# Epoch 37/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.1737 - val_accuracy: 0.9668
#
# Epoch 00037: val_loss did not improve from 0.05756
# Epoch 38/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.1630 - val_accuracy: 0.9679
#
# Epoch 00038: val_loss did not improve from 0.05756
# Epoch 39/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.1585 - val_accuracy: 0.9668
#
# Epoch 00039: val_loss did not improve from 0.05756
# Epoch 40/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.1865 - val_accuracy: 0.9647
#
# Epoch 00040: val_loss did not improve from 0.05756
# Score for fold 4: loss of 0.18654197454452515; accuracy of 96.46680951118469%
# Epoch 1/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.2234 - accuracy: 0.9076 - val_loss: 0.2123 - val_accuracy: 0.9336
#
# Epoch 00001: val_loss did not improve from 0.05756
# Epoch 2/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0559 - accuracy: 0.9816 - val_loss: 0.1816 - val_accuracy: 0.9443
#
# Epoch 00002: val_loss did not improve from 0.05756
# Epoch 3/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0447 - accuracy: 0.9852 - val_loss: 0.1584 - val_accuracy: 0.9529
#
# Epoch 00003: val_loss did not improve from 0.05756
# Epoch 4/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0361 - accuracy: 0.9876 - val_loss: 0.1586 - val_accuracy: 0.9529
#
# Epoch 00004: val_loss did not improve from 0.05756
# Epoch 5/40
# 1513/1513 [==============================] - 11s 7ms/step - loss: 0.0306 - accuracy: 0.9895 - val_loss: 0.1315 - val_accuracy: 0.9593
#
# Epoch 00005: val_loss did not improve from 0.05756
# Epoch 6/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0304 - accuracy: 0.9898 - val_loss: 0.1407 - val_accuracy: 0.9615
#
# Epoch 00006: val_loss did not improve from 0.05756
# Epoch 7/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0259 - accuracy: 0.9914 - val_loss: 0.1349 - val_accuracy: 0.9572
#
# Epoch 00007: val_loss did not improve from 0.05756
# Epoch 8/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.1305 - val_accuracy: 0.9636
#
# Epoch 00008: val_loss did not improve from 0.05756
# Epoch 9/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.1460 - val_accuracy: 0.9540
#
# Epoch 00009: val_loss did not improve from 0.05756
# Epoch 10/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0225 - accuracy: 0.9918 - val_loss: 0.1302 - val_accuracy: 0.9572
#
# Epoch 00010: val_loss did not improve from 0.05756
# Epoch 11/40
# 1513/1513 [==============================] - 11s 7ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 0.1385 - val_accuracy: 0.9615
#
# Epoch 00011: val_loss did not improve from 0.05756
# Epoch 12/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 0.1246 - val_accuracy: 0.9647
#
# Epoch 00012: val_loss did not improve from 0.05756
# Epoch 13/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.1368 - val_accuracy: 0.9593
#
# Epoch 00013: val_loss did not improve from 0.05756
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.1264 - val_accuracy: 0.9668
#
# Epoch 00014: val_loss did not improve from 0.05756
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.1236 - val_accuracy: 0.9625
#
# Epoch 00015: val_loss did not improve from 0.05756
# Epoch 16/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.1230 - val_accuracy: 0.9615
#
# Epoch 00016: val_loss did not improve from 0.05756
# Epoch 17/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0173 - accuracy: 0.9936 - val_loss: 0.1218 - val_accuracy: 0.9647
#
# Epoch 00017: val_loss did not improve from 0.05756
# Epoch 18/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 0.1430 - val_accuracy: 0.9657
#
# Epoch 00018: val_loss did not improve from 0.05756
# Epoch 19/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.1207 - val_accuracy: 0.9668
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.05756
# Epoch 20/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0940 - val_accuracy: 0.9647
#
# Epoch 00020: val_loss did not improve from 0.05756
# Epoch 21/40
# 1513/1513 [==============================] - 11s 7ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0998 - val_accuracy: 0.9657
#
# Epoch 00021: val_loss did not improve from 0.05756
# Epoch 22/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.0899 - val_accuracy: 0.9668
#
# Epoch 00022: val_loss did not improve from 0.05756
# Epoch 23/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.1041 - val_accuracy: 0.9657
#
# Epoch 00023: val_loss did not improve from 0.05756
# Epoch 24/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.1023 - val_accuracy: 0.9690
#
# Epoch 00024: val_loss did not improve from 0.05756
# Epoch 25/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.1241 - val_accuracy: 0.9668
#
# Epoch 00025: val_loss did not improve from 0.05756
# Epoch 26/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.1120 - val_accuracy: 0.9690
#
# Epoch 00026: val_loss did not improve from 0.05756
# Epoch 27/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.1338 - val_accuracy: 0.9690
#
# Epoch 00027: val_loss did not improve from 0.05756
# Epoch 28/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.1191 - val_accuracy: 0.9690
#
# Epoch 00028: val_loss did not improve from 0.05756
# Epoch 29/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.1100 - val_accuracy: 0.9679
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.05756
# Epoch 30/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.1201 - val_accuracy: 0.9679
#
# Epoch 00030: val_loss did not improve from 0.05756
# Epoch 31/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.1261 - val_accuracy: 0.9679
#
# Epoch 00031: val_loss did not improve from 0.05756
# Epoch 32/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.1258 - val_accuracy: 0.9700
#
# Epoch 00032: val_loss did not improve from 0.05756
# Epoch 33/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.1250 - val_accuracy: 0.9690
#
# Epoch 00033: val_loss did not improve from 0.05756
# Epoch 34/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.1285 - val_accuracy: 0.9690
#
# Epoch 00034: val_loss did not improve from 0.05756
# Epoch 35/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.1259 - val_accuracy: 0.9700
#
# Epoch 00035: val_loss did not improve from 0.05756
# Epoch 36/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.1273 - val_accuracy: 0.9690
#
# Epoch 00036: val_loss did not improve from 0.05756
# Epoch 37/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.1310 - val_accuracy: 0.9690
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00037: val_loss did not improve from 0.05756
# Epoch 38/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.1173 - val_accuracy: 0.9657
#
# Epoch 00038: val_loss did not improve from 0.05756
# Epoch 39/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.1201 - val_accuracy: 0.9679
#
# Epoch 00039: val_loss did not improve from 0.05756
# Epoch 40/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.1177 - val_accuracy: 0.9668
#
# Epoch 00040: val_loss did not improve from 0.05756
# Score for fold 5: loss of 0.11771202832460403; accuracy of 96.68094515800476%
# Epoch 1/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.2377 - accuracy: 0.9040 - val_loss: 0.1785 - val_accuracy: 0.9486
#
# Epoch 00001: val_loss did not improve from 0.05756
# Epoch 2/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0578 - accuracy: 0.9813 - val_loss: 0.1624 - val_accuracy: 0.9572
#
# Epoch 00002: val_loss did not improve from 0.05756
# Epoch 3/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0457 - accuracy: 0.9851 - val_loss: 0.1335 - val_accuracy: 0.9657
#
# Epoch 00003: val_loss did not improve from 0.05756
# Epoch 4/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 0.1358 - val_accuracy: 0.9647
#
# Epoch 00004: val_loss did not improve from 0.05756
# Epoch 5/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0345 - accuracy: 0.9885 - val_loss: 0.1265 - val_accuracy: 0.9647
#
# Epoch 00005: val_loss did not improve from 0.05756
# Epoch 6/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0307 - accuracy: 0.9898 - val_loss: 0.1417 - val_accuracy: 0.9636
#
# Epoch 00006: val_loss did not improve from 0.05756
# Epoch 7/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0292 - accuracy: 0.9903 - val_loss: 0.1207 - val_accuracy: 0.9690
#
# Epoch 00007: val_loss did not improve from 0.05756
# Epoch 8/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0261 - accuracy: 0.9913 - val_loss: 0.1284 - val_accuracy: 0.9647
#
# Epoch 00008: val_loss did not improve from 0.05756
# Epoch 9/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.1185 - val_accuracy: 0.9647
#
# Epoch 00009: val_loss did not improve from 0.05756
# Epoch 10/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.1278 - val_accuracy: 0.9711
#
# Epoch 00010: val_loss did not improve from 0.05756
# Epoch 11/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.1381 - val_accuracy: 0.9668
#
# Epoch 00011: val_loss did not improve from 0.05756
# Epoch 12/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0201 - accuracy: 0.9929 - val_loss: 0.1411 - val_accuracy: 0.9625
#
# Epoch 00012: val_loss did not improve from 0.05756
# Epoch 13/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.1126 - val_accuracy: 0.9636
#
# Epoch 00013: val_loss did not improve from 0.05756
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.0998 - val_accuracy: 0.9700
#
# Epoch 00014: val_loss did not improve from 0.05756
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.1451 - val_accuracy: 0.9657
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.05756
# Epoch 16/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.0971 - val_accuracy: 0.9754
#
# Epoch 00016: val_loss did not improve from 0.05756
# Epoch 17/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0989 - val_accuracy: 0.9700
#
# Epoch 00017: val_loss did not improve from 0.05756
# Epoch 18/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.1043 - val_accuracy: 0.9743
#
# Epoch 00018: val_loss did not improve from 0.05756
# Epoch 19/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.1217 - val_accuracy: 0.9722
#
# Epoch 00019: val_loss did not improve from 0.05756
# Epoch 20/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0131 - accuracy: 0.9952 - val_loss: 0.1129 - val_accuracy: 0.9722
#
# Epoch 00020: val_loss did not improve from 0.05756
# Epoch 21/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.1004 - val_accuracy: 0.9711
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.05756
# Epoch 22/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.1000 - val_accuracy: 0.9732
#
# Epoch 00022: val_loss did not improve from 0.05756
# Epoch 23/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.1170 - val_accuracy: 0.9743
#
# Epoch 00023: val_loss did not improve from 0.05756
# Epoch 24/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.1073 - val_accuracy: 0.9732
#
# Epoch 00024: val_loss did not improve from 0.05756
# Epoch 25/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.1166 - val_accuracy: 0.9743
#
# Epoch 00025: val_loss did not improve from 0.05756
# Epoch 26/40
# ...
#
# Epoch 00003: val_loss did not improve from 0.05756
# Epoch 4/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0323 - accuracy: 0.9893 - val_loss: 0.1412 - val_accuracy: 0.9668
#
# Epoch 00004: val_loss did not improve from 0.05756
# Epoch 5/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0303 - accuracy: 0.9903 - val_loss: 0.1046 - val_accuracy: 0.9679
#
# Epoch 00005: val_loss did not improve from 0.05756
# Epoch 6/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0280 - accuracy: 0.9909 - val_loss: 0.1018 - val_accuracy: 0.9668
#
# Epoch 00006: val_loss did not improve from 0.05756
# Epoch 7/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0243 - accuracy: 0.9919 - val_loss: 0.0899 - val_accuracy: 0.9732
#
# Epoch 00007: val_loss did not improve from 0.05756
# Epoch 8/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0246 - accuracy: 0.9923 - val_loss: 0.1020 - val_accuracy: 0.9668
#
# Epoch 00008: val_loss did not improve from 0.05756
# Epoch 9/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0932 - val_accuracy: 0.9711
#
# Epoch 00009: val_loss did not improve from 0.05756
# Epoch 10/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 0.0909 - val_accuracy: 0.9711
#
# Epoch 00010: val_loss did not improve from 0.05756
# Epoch 11/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.0943 - val_accuracy: 0.9690
#
# Epoch 00011: val_loss did not improve from 0.05756
# Epoch 12/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0782 - val_accuracy: 0.9786
#
# Epoch 00012: val_loss did not improve from 0.05756
# Epoch 13/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.0861 - val_accuracy: 0.9743
#
# Epoch 00013: val_loss did not improve from 0.05756
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0186 - accuracy: 0.9939 - val_loss: 0.0913 - val_accuracy: 0.9732
#
# Epoch 00014: val_loss did not improve from 0.05756
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0837 - val_accuracy: 0.9732
#
# Epoch 00015: val_loss did not improve from 0.05756
# Epoch 16/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.0863 - val_accuracy: 0.9754
#
# Epoch 00016: val_loss did not improve from 0.05756
# Epoch 17/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0162 - accuracy: 0.9943 - val_loss: 0.0887 - val_accuracy: 0.9743
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.05756
# Epoch 18/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.0865 - val_accuracy: 0.9732
#
# Epoch 00018: val_loss did not improve from 0.05756
# Epoch 19/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0943 - val_accuracy: 0.9743
#
# Epoch 00019: val_loss did not improve from 0.05756
# Epoch 20/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0856 - val_accuracy: 0.9764
#
# Epoch 00020: val_loss did not improve from 0.05756
# Epoch 21/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.0921 - val_accuracy: 0.9743
#
# Epoch 00021: val_loss did not improve from 0.05756
# Epoch 22/40
# 1513/1513 [==============================] - 14s 9ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0971 - val_accuracy: 0.9711
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.05756
# Epoch 23/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.0873 - val_accuracy: 0.9764
#
# Epoch 00023: val_loss did not improve from 0.05756
# Epoch 24/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0882 - val_accuracy: 0.9754
#
# Epoch 00024: val_loss did not improve from 0.05756
# Epoch 25/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0928 - val_accuracy: 0.9711
#
# Epoch 00025: val_loss did not improve from 0.05756
# Epoch 26/40
# 1513/1513 [==============================] - 13s 8ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0932 - val_accuracy: 0.9754
#
# Epoch 00026: val_loss did not improve from 0.05756
# Epoch 27/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0973 - val_accuracy: 0.9732
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.05756
# Epoch 28/40
# 1513/1513 [==============================] - 13s 9ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0905 - val_accuracy: 0.9764
#
# Epoch 00028: val_loss did not improve from 0.05756
# Epoch 29/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0918 - val_accuracy: 0.9775
#
# Epoch 00029: val_loss did not improve from 0.05756
# Epoch 30/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0953 - val_accuracy: 0.9743
#
# Epoch 00030: val_loss did not improve from 0.05756
# Epoch 31/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0965 - val_accuracy: 0.9743
#
# Epoch 00031: val_loss did not improve from 0.05756
# Epoch 32/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0953 - val_accuracy: 0.9775
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.05756
# Epoch 33/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0984 - val_accuracy: 0.9764
#
# Epoch 00033: val_loss did not improve from 0.05756
# Epoch 34/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0934 - val_accuracy: 0.9754
#
# Epoch 00034: val_loss did not improve from 0.05756
# Epoch 35/40
# 1513/1513 [==============================] - 8s 6ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.1036 - val_accuracy: 0.9754
#
# Epoch 00035: val_loss did not improve from 0.05756
# Epoch 36/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.1030 - val_accuracy: 0.9754
#
# Epoch 00036: val_loss did not improve from 0.05756
# Epoch 37/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0967 - val_accuracy: 0.9754
#
# Epoch 00037: val_loss did not improve from 0.05756
# Epoch 38/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0940 - val_accuracy: 0.9775
#
# Epoch 00038: val_loss did not improve from 0.05756
# Epoch 39/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0953 - val_accuracy: 0.9775
#
# Epoch 00039: val_loss did not improve from 0.05756
# Epoch 40/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.1002 - val_accuracy: 0.9764
#
# Epoch 00040: val_loss did not improve from 0.05756
# Score for fold 9: loss of 0.10023557394742966; accuracy of 97.64453768730164%
# Epoch 1/40
# 1513/1513 [==============================] - 11s 7ms/step - loss: 0.2116 - accuracy: 0.9152 - val_loss: 0.2203 - val_accuracy: 0.9357
#
# Epoch 00001: val_loss did not improve from 0.05756
# Epoch 2/40
# 1513/1513 [==============================] - 10s 6ms/step - loss: 0.0525 - accuracy: 0.9832 - val_loss: 0.1399 - val_accuracy: 0.9507
#
# Epoch 00002: val_loss did not improve from 0.05756
# Epoch 3/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0404 - accuracy: 0.9871 - val_loss: 0.1212 - val_accuracy: 0.9657
#
# Epoch 00003: val_loss did not improve from 0.05756
# Epoch 4/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0345 - accuracy: 0.9888 - val_loss: 0.1403 - val_accuracy: 0.9668
#
# Epoch 00004: val_loss did not improve from 0.05756
# Epoch 5/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.1222 - val_accuracy: 0.9657
#
# Epoch 00005: val_loss did not improve from 0.05756
# Epoch 6/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0275 - accuracy: 0.9910 - val_loss: 0.1004 - val_accuracy: 0.9678
#
# Epoch 00006: val_loss did not improve from 0.05756
# Epoch 7/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0240 - accuracy: 0.9914 - val_loss: 0.1317 - val_accuracy: 0.9711
#
# Epoch 00007: val_loss did not improve from 0.05756
# Epoch 8/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0231 - accuracy: 0.9923 - val_loss: 0.0934 - val_accuracy: 0.9700
#
# Epoch 00008: val_loss did not improve from 0.05756
# Epoch 9/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.1067 - val_accuracy: 0.9678
#
# Epoch 00009: val_loss did not improve from 0.05756
# Epoch 10/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.0950 - val_accuracy: 0.9743
#
# Epoch 00010: val_loss did not improve from 0.05756
# Epoch 11/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0195 - accuracy: 0.9927 - val_loss: 0.1100 - val_accuracy: 0.9668
#
# Epoch 00011: val_loss did not improve from 0.05756
# Epoch 12/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.1006 - val_accuracy: 0.9711
#
# Epoch 00012: val_loss did not improve from 0.05756
# Epoch 13/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.1098 - val_accuracy: 0.9678
#
# Epoch 00013: val_loss did not improve from 0.05756
# Epoch 14/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0175 - accuracy: 0.9939 - val_loss: 0.1037 - val_accuracy: 0.9721
#
# Epoch 00014: val_loss did not improve from 0.05756
# Epoch 15/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.0948 - val_accuracy: 0.9721
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.05756
# Epoch 16/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.1048 - val_accuracy: 0.9689
#
# Epoch 00016: val_loss did not improve from 0.05756
# Epoch 17/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.1054 - val_accuracy: 0.9753
#
# Epoch 00017: val_loss did not improve from 0.05756
# Epoch 18/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.1176 - val_accuracy: 0.9732
#
# Epoch 00018: val_loss did not improve from 0.05756
# Epoch 19/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0970 - val_accuracy: 0.9743
#
# Epoch 00019: val_loss did not improve from 0.05756
# Epoch 20/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0959 - val_accuracy: 0.9764
#
# Epoch 00020: val_loss did not improve from 0.05756
# Epoch 21/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0948 - val_accuracy: 0.9764
#
# Epoch 00021: val_loss did not improve from 0.05756
# Epoch 22/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.0885 - val_accuracy: 0.9753
#
# Epoch 00022: val_loss did not improve from 0.05756
# Epoch 23/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.1006 - val_accuracy: 0.9753
#
# Epoch 00023: val_loss did not improve from 0.05756
# Epoch 24/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.1218 - val_accuracy: 0.9753
#
# Epoch 00024: val_loss did not improve from 0.05756
# Epoch 25/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.1032 - val_accuracy: 0.9743
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.05756
# Epoch 26/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.0945 - val_accuracy: 0.9743
#
# Epoch 00026: val_loss did not improve from 0.05756
# Epoch 27/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.1100 - val_accuracy: 0.9753
#
# Epoch 00027: val_loss did not improve from 0.05756
# Epoch 28/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.1216 - val_accuracy: 0.9764
#
# Epoch 00028: val_loss did not improve from 0.05756
# Epoch 29/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.1041 - val_accuracy: 0.9753
#
# Epoch 00029: val_loss did not improve from 0.05756
# Epoch 30/40
# 1513/1513 [==============================] - 8s 5ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.1260 - val_accuracy: 0.9764
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.05756
# Epoch 31/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.1188 - val_accuracy: 0.9775
#
# Epoch 00031: val_loss did not improve from 0.05756
# Epoch 32/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.1191 - val_accuracy: 0.9753
#
# Epoch 00032: val_loss did not improve from 0.05756
# Epoch 33/40
# 1513/1513 [==============================] - 12s 8ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.1233 - val_accuracy: 0.9764
#
# Epoch 00033: val_loss did not improve from 0.05756
# Epoch 34/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.1142 - val_accuracy: 0.9775
#
# Epoch 00034: val_loss did not improve from 0.05756
# Epoch 35/40
# 1513/1513 [==============================] - 10s 7ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.1235 - val_accuracy: 0.9764
#
# Epoch 00035: val_loss did not improve from 0.05756
# Epoch 36/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.1110 - val_accuracy: 0.9764
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00036: val_loss did not improve from 0.05756
# Epoch 37/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.1207 - val_accuracy: 0.9775
#
# Epoch 00037: val_loss did not improve from 0.05756
# Epoch 38/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.1204 - val_accuracy: 0.9764
#
# Epoch 00038: val_loss did not improve from 0.05756
# Epoch 39/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.1209 - val_accuracy: 0.9775
#
# Epoch 00039: val_loss did not improve from 0.05756
# Epoch 40/40
# 1513/1513 [==============================] - 9s 6ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.1184 - val_accuracy: 0.9775
#
# Epoch 00040: val_loss did not improve from 0.05756
# Score for fold 10: loss of 0.11842785775661469; accuracy of 97.74919748306274%

# %%
(np.argmax(Malware_model.predict(imgs[test]), axis=-1))
# Out:
# array([ 2,  3,  2, 12,  2,  4, 11,  8, 17, 11,  3, 10, 17,  3, 24,  4,  2,
#         3,  2, 24,  6,  2,  2, 24, 22,  1,  3, 22,  2,  2,  2,  3, 23,  3,
#         3,  3, 22,  9,  3,  3, 11, 12,  3,  2, 12,  2,  2, 24,  3,  2,  2,
#        19, 24, 24,  3, 11, 22, 24, 17, 21,  8,  2,  0, 11, 23, 22, 23,  2,
#         3,  7,  3,  2,  0,  9,  3, 18, 15,  4,  2, 24, 24,  3, 15,  8,  2,
#         3,  2, 24,  1, 18,  2, 24, 24, 24,  2,  2, 24,  3, 18, 10,  1,  2,
#         3, 13,  2,  2,  2, 13,  6,  3,  2, 12,  9, 24,  2, 23,  2, 12, 24,
#         2,  2, 22,  3, 16,  2, 17, 16, 14,  2,  2, 11, 13,  2, 13, 11,  3,
#         2, 22, 24,  2,  3,  7, 20, 21,  2, 14, 20, 17, 13,  2,  0,  3,  7,
#         2,  2,  2, 11, 11,  4, 22,  8, 24,  9,  2, 16,  2,  2,  4,  2,  6,
#        15,  2,  2, 24,  3,  2,  1,  2, 19,  3,  1,  9,  3,  3, 18, 22, 24,
#        16, 16,  2,  2, 17,  2,  9, 11,  2,  2, 24,  3,  3,  4,  2,  4, 24,
#         6,  3,  2,  2,  6, 11, 24, 24, 22,  1,  2, 18,  3, 24,  2, 15, 23,
#         3,  7,  2,  2, 24,  2, 24, 19,  2, 24,  2,  3,  3, 15, 11, 14,  3,
#         3, 14,  2, 16,  2,  3, 10,  2,  3, 22,  2,  3, 22,  2,  2,  2,  2,
#        18, 12,  2, 24,  6,  3,  2,  2,  4, 15, 20,  2,  2,  2, 15,  2, 21,
#         6,  2,  2,  4, 16, 11,  4,  3,  2, 12, 17,  2, 24, 18, 24,  2,  2,
#         3,  3,  2, 19,  2, 21, 19, 20,  2, 13, 22,  2, 20,  2, 17,  2, 10,
#        10, 11,  2,  3,  3, 15,  3,  3,  2,  3, 13, 20, 11, 19,  2,  8, 10,
#         3, 21,  7,  2, 21,  3,  6, 13, 12,  2, 21,  3,  2, 24,  3,  2,  3,
#         2,  2,  2,  3,  3,  2,  3,  2, 11,  2, 10, 17,  2, 10,  2, 17, 10,
#         2, 19, 15, 24,  7, 13,  3, 10, 15,  2,  2,  2,  2,  7, 15,  2,  7,
#        21,  3,  2, 12,  3,  2,  2,  2,  2,  2,  3, 24,  2,  9, 11, 21, 24,
#         2,  2, 11,  2, 21,  3, 21,  3,  8,  3, 17,  2,  3, 12, 14,  3,  2,
#        16, 10,  2,  7, 12,  2,  2,  2, 22,  2,  7, 22, 24,  2,  2,  3,  2,
#         2, 22,  7, 11,  2,  3,  2,  2,  2,  2, 20, 24,  3,  9,  2, 15, 22,
#         3,  2,  3, 24,  3, 10,  3,  2, 15, 24,  2, 15, 24,  2,  2,  2,  2,
#        24, 18, 18, 11, 23,  2, 11,  2, 23,  3,  9, 10,  3,  2,  7,  9,  2,
#         8, 11,  0,  4,  3,  2,  4,  2, 10,  2,  2, 17, 11, 23,  3,  3,  2,
#         2,  2,  2, 13,  2,  1,  2,  8, 13,  2, 15,  2, 22, 12,  7,  4, 11,
#         2,  2,  2, 24,  2,  2,  3, 12, 22, 18, 15,  2, 21, 24,  2,  2,  8,
#        10, 22,  2,  3, 13,  7,  2,  3, 11, 17,  2,  2, 23,  3,  3, 17,  2,
#         7,  7, 24,  2,  2, 15,  6, 15,  2, 13,  2,  8,  6,  3, 24,  2,  7,
#         8,  0,  2,  2, 11, 11,  3,  2,  2, 15,  3,  2,  2,  2, 22, 16,  2,
#         2,  2, 19, 10,  3,  2,  4,  2, 24,  0, 14, 22, 11,  8,  2, 19,  2,
#         2,  4, 15, 12,  2,  3,  6,  2,  3,  6, 19,  2,  2, 11, 24,  3, 11,
#        22, 13,  2, 19,  3,  2,  9, 18,  0, 24,  2,  2,  2, 10,  3,  2,  2,
#         2, 20, 24,  2, 17, 24,  8,  8,  2, 21, 11,  3,  6, 13,  1, 24,  3,
#         0, 12,  2, 20, 12,  7,  7,  2, 13,  2,  6,  2,  3,  3, 11,  1,  2,
#         3, 20, 24,  7, 11,  2,  3,  4, 13,  2,  2,  2, 17, 19, 24,  2,  2,
#         3, 11, 18, 21,  2,  4, 22,  2,  2,  2,  3,  2,  2, 24,  2, 24,  0,
#         0,  2,  3, 24,  8,  4, 24, 13,  2, 10,  3,  3,  3, 24, 12,  8,  9,
#        10,  3,  2,  1,  2, 11,  2,  9, 15, 22, 24,  3,  6,  2, 14, 22,  3,
#        24, 24,  8, 11,  8,  3,  2, 18, 12, 19, 24,  2,  2, 21,  3,  2,  3,
#        16,  8, 14,  2, 11,  2,  2, 24, 22,  2,  3,  3,  2,  2, 10,  3, 24,
#        24,  2,  2, 23,  2,  3,  2,  6,  3, 21, 22,  2, 24,  2, 18, 24,  3,
#         7,  2, 24, 24,  2,  2,  8, 21, 24,  3,  3,  2,  7, 10,  2, 24, 24,
#        15,  3,  2,  2,  2, 15,  4,  2, 11,  2,  2, 12, 15,  9, 24, 24, 22,
#        21, 13,  0, 23, 24,  8,  8,  2,  3, 10,  2, 17, 18, 15, 24,  2, 10,
#        22, 10,  2,  2, 16,  2, 17,  2, 22, 20,  3,  4,  3,  2,  3,  2,  2,
#        24,  3, 14, 24, 23, 13, 24,  2,  2,  2,  8,  2,  3,  2,  2, 17,  2,
#        10, 16,  3, 13, 24,  2, 24, 11, 24,  3,  2, 24,  3, 10,  2, 10,  3,
#         3, 17, 24, 13,  2, 22, 11,  2,  2, 14,  3,  2,  3,  2,  3, 22,  2,
#        24,  3, 10,  2,  1,  3,  2, 24,  2, 19,  1,  2, 20,  3,  2,  2, 11,
#         2,  2, 11,  1,  3,  2, 17, 22, 16,  2,  9,  4, 22, 24, 11],
#       dtype=int64)

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.1324928104877472 - Accuracy: 98.0728030204773%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.06207190081477165 - Accuracy: 98.0728030204773%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.14000922441482544 - Accuracy: 98.28693866729736%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.18654197454452515 - Accuracy: 96.46680951118469%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.11771202832460403 - Accuracy: 96.68094515800476%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.10210682451725006 - Accuracy: 97.32334017753601%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.10796062648296356 - Accuracy: 97.10921049118042%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.08395887166261673 - Accuracy: 97.32334017753601%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.10023557394742966 - Accuracy: 97.64453768730164%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.11842785775661469 - Accuracy: 97.74919748306274%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 97.47299253940582% (+- 0.005748602275584172)
# > Loss: 0.11515176929533481
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +---------------------------------------+
# |           Performance of CNN          |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9747      | 0.0057       |
# | Loss     | 0.1152      | 0.032        |
# | Macro F1 | 0.921       | 0.0101       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9795      | 0.0066       |
# | Acc      | 0.985       | 0.0051       |
# | F1       | 0.9807      | 0.0066       |
# | MCC      | 0.9687      | 0.0107       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
