# %% [markdown]
# # CGAN-DenseNet

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 150000

# Number of epochs
epoch_t = 35

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/malimg_dataset"
    for files in os.listdir(dir):
        if "cgan-densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-cgan-densenet-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 1 matches(es) found
# --------------
# New folder name: crossv-cgan-densenet-local-v021
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/malimgdataset"
    path_root_gen = '/kaggle/input/malimgcganlocalv009woallaple'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/malimg_paper_dataset_imgs"
    path_root_gen = "C:/Users/Max/Documents/image_data/malimg-cgan-v025-rightsize"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 9339 images belonging to 25 classes.

# %% [markdown]
# Load CGAN generated images

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 58507 images belonging to 25 classes.

# %% [markdown]
# Original images

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %% [markdown]
# Generated images

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs_gen, titles = labels_gen)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # CGAN - DenseNet169
# We will now build our **DenseNet169** model using Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3
#
# Nota bene that the DenseNet only takes RGB images (with 3 channels)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  25

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # DenseNet169
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    # Run the CNN
    history.append(
        head_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint],
        batch_size = 64) # The actual computation of the CNN
    )
    
    
    
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 1046/1046 [==============================] - 161s 138ms/step - loss: 0.2164 - accuracy: 0.9737 - val_loss: 8.5917 - val_accuracy: 0.1156
#
# Epoch 00001: val_loss improved from inf to 8.59174, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 2/35
# 1046/1046 [==============================] - 142s 136ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.1140 - val_accuracy: 0.9582
#
# Epoch 00002: val_loss improved from 8.59174 to 0.11402, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 3/35
# 1046/1046 [==============================] - 142s 135ms/step - loss: 0.1114 - accuracy: 0.9837 - val_loss: 4.5370 - val_accuracy: 0.6413
#
# Epoch 00003: val_loss did not improve from 0.11402
# Epoch 4/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0372 - accuracy: 0.9934 - val_loss: 0.1153 - val_accuracy: 0.9636
#
# Epoch 00004: val_loss did not improve from 0.11402
# Epoch 5/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0199 - accuracy: 0.9948 - val_loss: 6.4967 - val_accuracy: 0.4486
#
# Epoch 00005: val_loss did not improve from 0.11402
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0476 - accuracy: 0.9918 - val_loss: 272.4879 - val_accuracy: 0.0867
#
# Epoch 00006: val_loss did not improve from 0.11402
# Epoch 7/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0516 - accuracy: 0.9930 - val_loss: 0.1935 - val_accuracy: 0.9582
#
# Epoch 00007: val_loss did not improve from 0.11402
# Epoch 8/35
# 1046/1046 [==============================] - 144s 138ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.1182 - val_accuracy: 0.9657
#
# Epoch 00008: val_loss did not improve from 0.11402
# Epoch 9/35
# 1046/1046 [==============================] - 144s 138ms/step - loss: 0.0319 - accuracy: 0.9930 - val_loss: 3.6055 - val_accuracy: 0.7227
#
# Epoch 00009: val_loss did not improve from 0.11402
# Epoch 10/35
# 1046/1046 [==============================] - 142s 136ms/step - loss: 0.0205 - accuracy: 0.9949 - val_loss: 0.1126 - val_accuracy: 0.9572
#
# Epoch 00010: val_loss improved from 0.11402 to 0.11256, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 11/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.1034 - val_accuracy: 0.9657
#
# Epoch 00011: val_loss improved from 0.11256 to 0.10339, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 12/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0178 - accuracy: 0.9954 - val_loss: 1.7078 - val_accuracy: 0.6188
#
# Epoch 00012: val_loss did not improve from 0.10339
# Epoch 13/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.1316 - val_accuracy: 0.9604
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.10339
# Epoch 14/35
# 1046/1046 [==============================] - 140s 133ms/step - loss: 0.0172 - accuracy: 0.9963 - val_loss: 0.1275 - val_accuracy: 0.9615
#
# Epoch 00014: val_loss did not improve from 0.10339
# Epoch 15/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0858 - val_accuracy: 0.9732
#
# Epoch 00015: val_loss improved from 0.10339 to 0.08583, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 16/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0953 - val_accuracy: 0.9657
#
# Epoch 00016: val_loss did not improve from 0.08583
# Epoch 17/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.3572 - val_accuracy: 0.9229
#
# Epoch 00017: val_loss did not improve from 0.08583
# Epoch 18/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0995 - val_accuracy: 0.9711
#
# Epoch 00018: val_loss did not improve from 0.08583
# Epoch 19/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0826 - val_accuracy: 0.9722
#
# Epoch 00019: val_loss improved from 0.08583 to 0.08263, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 20/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0932 - val_accuracy: 0.9711
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss did not improve from 0.08263
# Epoch 21/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0076 - accuracy: 0.9981 - val_loss: 0.0687 - val_accuracy: 0.9775
#
# Epoch 00021: val_loss improved from 0.08263 to 0.06871, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 22/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0741 - val_accuracy: 0.9786
#
# Epoch 00022: val_loss did not improve from 0.06871
# Epoch 23/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0667 - val_accuracy: 0.9786
#
# Epoch 00023: val_loss improved from 0.06871 to 0.06674, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 24/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0757 - val_accuracy: 0.9775
#
# Epoch 00024: val_loss did not improve from 0.06674
# Epoch 25/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0763 - val_accuracy: 0.9754
#
# Epoch 00025: val_loss did not improve from 0.06674
# Epoch 26/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.1200 - val_accuracy: 0.9657
#
# Epoch 00026: val_loss did not improve from 0.06674
# Epoch 27/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0777 - val_accuracy: 0.9786
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.06674
# Epoch 28/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0774 - val_accuracy: 0.9786
#
# Epoch 00028: val_loss did not improve from 0.06674
# Epoch 29/35
# 1046/1046 [==============================] - 139s 133ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0822 - val_accuracy: 0.9775
#
# Epoch 00029: val_loss did not improve from 0.06674
# Epoch 30/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0810 - val_accuracy: 0.9797
#
# Epoch 00030: val_loss did not improve from 0.06674
# Epoch 31/35
# 1046/1046 [==============================] - 143s 137ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0863 - val_accuracy: 0.9764
#
# Epoch 00031: val_loss did not improve from 0.06674
# Epoch 32/35
# 1046/1046 [==============================] - 141s 134ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0748 - val_accuracy: 0.9797
#
# Epoch 00032: val_loss did not improve from 0.06674
# Epoch 33/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0883 - val_accuracy: 0.9775
#
# Epoch 00033: val_loss did not improve from 0.06674
# Epoch 34/35
# 1046/1046 [==============================] - 141s 134ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0821 - val_accuracy: 0.9754
#
# Epoch 00034: val_loss did not improve from 0.06674
# Epoch 35/35
# 1046/1046 [==============================] - 142s 136ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0814 - val_accuracy: 0.9775
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.06674
# Score for fold 1: loss of 0.08143461495637894; accuracy of 97.75160551071167%
# Epoch 1/35
# 1046/1046 [==============================] - 163s 142ms/step - loss: 0.2383 - accuracy: 0.9686 - val_loss: 4.3022 - val_accuracy: 0.2527
#
# Epoch 00001: val_loss did not improve from 0.06674
# Epoch 2/35
# 1046/1046 [==============================] - 145s 139ms/step - loss: 0.0492 - accuracy: 0.9912 - val_loss: 0.1995 - val_accuracy: 0.9454
#
# Epoch 00002: val_loss did not improve from 0.06674
# Epoch 3/35
# 1046/1046 [==============================] - 145s 139ms/step - loss: 0.0348 - accuracy: 0.9932 - val_loss: 0.1089 - val_accuracy: 0.9690
#
# Epoch 00003: val_loss did not improve from 0.06674
# Epoch 4/35
# 1046/1046 [==============================] - 146s 139ms/step - loss: 0.0325 - accuracy: 0.9932 - val_loss: 0.1530 - val_accuracy: 0.9582
#
# Epoch 00004: val_loss did not improve from 0.06674
# Epoch 5/35
# 1046/1046 [==============================] - 145s 138ms/step - loss: 0.0742 - accuracy: 0.9898 - val_loss: 0.1330 - val_accuracy: 0.9636
#
# Epoch 00005: val_loss did not improve from 0.06674
# Epoch 6/35
# 1046/1046 [==============================] - 146s 140ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.1141 - val_accuracy: 0.9657
#
# Epoch 00006: val_loss did not improve from 0.06674
# Epoch 7/35
# 1046/1046 [==============================] - 146s 140ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.1214 - val_accuracy: 0.9732
#
# Epoch 00007: val_loss did not improve from 0.06674
# Epoch 8/35
# 1046/1046 [==============================] - 145s 139ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.1051 - val_accuracy: 0.9711
#
# Epoch 00008: val_loss did not improve from 0.06674
# Epoch 9/35
# 1046/1046 [==============================] - 146s 140ms/step - loss: 0.0518 - accuracy: 0.9927 - val_loss: 2.6084 - val_accuracy: 0.3630
#
# Epoch 00009: val_loss did not improve from 0.06674
# Epoch 10/35
# 1046/1046 [==============================] - 146s 139ms/step - loss: 0.0160 - accuracy: 0.9958 - val_loss: 0.1236 - val_accuracy: 0.9754
#
# Epoch 00010: val_loss did not improve from 0.06674
# Epoch 11/35
# 1046/1046 [==============================] - 146s 140ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.1159 - val_accuracy: 0.9722
#
# Epoch 00011: val_loss did not improve from 0.06674
# Epoch 12/35
# 1046/1046 [==============================] - 147s 141ms/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 2.2759 - val_accuracy: 0.6103
#
# Epoch 00012: val_loss did not improve from 0.06674
# Epoch 13/35
# 1046/1046 [==============================] - 145s 139ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.1355 - val_accuracy: 0.9732
#
# Epoch 00013: val_loss did not improve from 0.06674
# Epoch 14/35
# 1046/1046 [==============================] - 145s 138ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0971 - val_accuracy: 0.9764
#
# Epoch 00014: val_loss did not improve from 0.06674
# Epoch 15/35
# 1046/1046 [==============================] - 144s 138ms/step - loss: 0.0397 - accuracy: 0.9954 - val_loss: 0.1137 - val_accuracy: 0.9711
#
# Epoch 00015: val_loss did not improve from 0.06674
# Epoch 16/35
# 1046/1046 [==============================] - 147s 140ms/step - loss: 0.0546 - accuracy: 0.9959 - val_loss: 0.0809 - val_accuracy: 0.9764
#
# Epoch 00016: val_loss did not improve from 0.06674
# Epoch 17/35
# 1046/1046 [==============================] - 149s 143ms/step - loss: 0.0302 - accuracy: 0.9968 - val_loss: 0.2928 - val_accuracy: 0.9325
#
# Epoch 00017: val_loss did not improve from 0.06674
# Epoch 18/35
# 1046/1046 [==============================] - 145s 139ms/step - loss: 0.0206 - accuracy: 0.9974 - val_loss: 0.0762 - val_accuracy: 0.9764
#
# Epoch 00018: val_loss did not improve from 0.06674
# Epoch 19/35
# 1046/1046 [==============================] - 144s 138ms/step - loss: 0.0171 - accuracy: 0.9967 - val_loss: 0.0934 - val_accuracy: 0.9732
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.06674
# Epoch 20/35
# 1046/1046 [==============================] - 144s 138ms/step - loss: 0.0183 - accuracy: 0.9977 - val_loss: 0.0797 - val_accuracy: 0.9786
#
# Epoch 00020: val_loss did not improve from 0.06674
# Epoch 21/35
# 1046/1046 [==============================] - 144s 138ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.1076 - val_accuracy: 0.9732
#
# Epoch 00021: val_loss did not improve from 0.06674
# Epoch 22/35
# 1046/1046 [==============================] - 145s 138ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.1062 - val_accuracy: 0.9754
#
# Epoch 00022: val_loss did not improve from 0.06674
# Epoch 23/35
# 1046/1046 [==============================] - 142s 135ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0828 - val_accuracy: 0.9775
#
# Epoch 00023: val_loss did not improve from 0.06674
# Epoch 24/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0822 - val_accuracy: 0.9786
#
# Epoch 00024: val_loss did not improve from 0.06674
# Epoch 25/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.2800 - val_accuracy: 0.9443
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.06674
# Epoch 26/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.1052 - val_accuracy: 0.9775
#
# Epoch 00026: val_loss did not improve from 0.06674
# Epoch 27/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.1243 - val_accuracy: 0.9754
#
# Epoch 00027: val_loss did not improve from 0.06674
# Epoch 28/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.1057 - val_accuracy: 0.9786
#
# Epoch 00028: val_loss did not improve from 0.06674
# Epoch 29/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0898 - val_accuracy: 0.9754
#
# Epoch 00029: val_loss did not improve from 0.06674
# Epoch 30/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1058 - val_accuracy: 0.9764
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.06674
# Epoch 31/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1080 - val_accuracy: 0.9754
#
# Epoch 00031: val_loss did not improve from 0.06674
# Epoch 32/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1084 - val_accuracy: 0.9754
#
# Epoch 00032: val_loss did not improve from 0.06674
# Epoch 33/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0982 - val_accuracy: 0.9775
#
# Epoch 00033: val_loss did not improve from 0.06674
# Epoch 34/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1024 - val_accuracy: 0.9775
#
# Epoch 00034: val_loss did not improve from 0.06674
# Epoch 35/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1290 - val_accuracy: 0.9754
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.06674
# Score for fold 2: loss of 0.12904441356658936; accuracy of 97.53747582435608%
# Epoch 1/35
# 1046/1046 [==============================] - 156s 137ms/step - loss: 0.1788 - accuracy: 0.9734 - val_loss: 3.9757 - val_accuracy: 0.2901
#
# Epoch 00001: val_loss did not improve from 0.06674
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0821 - accuracy: 0.9855 - val_loss: 0.8536 - val_accuracy: 0.8480
#
# Epoch 00002: val_loss did not improve from 0.06674
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0180 - accuracy: 0.9944 - val_loss: 2.1219 - val_accuracy: 0.5161
#
# Epoch 00003: val_loss did not improve from 0.06674
# Epoch 4/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0678 - accuracy: 0.9879 - val_loss: 0.3878 - val_accuracy: 0.9261
#
# Epoch 00004: val_loss did not improve from 0.06674
# Epoch 5/35
# 1046/1046 [==============================] - 143s 137ms/step - loss: 0.0178 - accuracy: 0.9949 - val_loss: 0.0949 - val_accuracy: 0.9732
#
# Epoch 00005: val_loss did not improve from 0.06674
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0378 - accuracy: 0.9940 - val_loss: 0.1481 - val_accuracy: 0.9518
#
# Epoch 00006: val_loss did not improve from 0.06674
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0168 - accuracy: 0.9954 - val_loss: 2.8534 - val_accuracy: 0.4615
#
# Epoch 00007: val_loss did not improve from 0.06674
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0452 - accuracy: 0.9930 - val_loss: 331.2597 - val_accuracy: 0.0385
#
# Epoch 00008: val_loss did not improve from 0.06674
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0425 - accuracy: 0.9933 - val_loss: 0.0739 - val_accuracy: 0.9775
#
# Epoch 00009: val_loss did not improve from 0.06674
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.8189 - val_accuracy: 0.7388
#
# Epoch 00010: val_loss did not improve from 0.06674
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0220 - accuracy: 0.9959 - val_loss: 1.1418 - val_accuracy: 0.6895
#
# Epoch 00011: val_loss did not improve from 0.06674
# Epoch 12/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0314 - accuracy: 0.9947 - val_loss: 0.1145 - val_accuracy: 0.9754
#
# Epoch 00012: val_loss did not improve from 0.06674
# Epoch 13/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.1212 - val_accuracy: 0.9711
#
# Epoch 00013: val_loss did not improve from 0.06674
# Epoch 14/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0307 - accuracy: 0.9944 - val_loss: 1.2721 - val_accuracy: 0.8779
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.06674
# Epoch 15/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0208 - accuracy: 0.9956 - val_loss: 0.2913 - val_accuracy: 0.9743
#
# Epoch 00015: val_loss did not improve from 0.06674
# Epoch 16/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.1563 - val_accuracy: 0.9743
#
# Epoch 00016: val_loss did not improve from 0.06674
# Epoch 17/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 2.9419 - val_accuracy: 0.4272
#
# Epoch 00017: val_loss did not improve from 0.06674
# Epoch 18/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0673 - val_accuracy: 0.9807
#
# Epoch 00018: val_loss did not improve from 0.06674
# Epoch 19/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0866 - val_accuracy: 0.9764
#
# Epoch 00019: val_loss did not improve from 0.06674
# Epoch 20/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0765 - val_accuracy: 0.9754
#
# Epoch 00020: val_loss did not improve from 0.06674
# Epoch 21/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0923 - val_accuracy: 0.9775
#
# Epoch 00021: val_loss did not improve from 0.06674
# Epoch 22/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0854 - val_accuracy: 0.9764
#
# Epoch 00022: val_loss did not improve from 0.06674
# Epoch 23/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0735 - val_accuracy: 0.9807
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_loss did not improve from 0.06674
# Epoch 24/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0642 - val_accuracy: 0.9818
#
# Epoch 00024: val_loss improved from 0.06674 to 0.06424, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 25/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0537 - val_accuracy: 0.9818
#
# Epoch 00025: val_loss improved from 0.06424 to 0.05367, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 26/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0687 - val_accuracy: 0.9818
#
# Epoch 00026: val_loss did not improve from 0.05367
# Epoch 27/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0660 - val_accuracy: 0.9786
#
# Epoch 00027: val_loss did not improve from 0.05367
# Epoch 28/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0761 - val_accuracy: 0.9807
#
# Epoch 00028: val_loss did not improve from 0.05367
# Epoch 29/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0543 - val_accuracy: 0.9829
#
# Epoch 00029: val_loss did not improve from 0.05367
# Epoch 30/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0633 - val_accuracy: 0.9818
#
# Epoch 00030: val_loss did not improve from 0.05367
# Epoch 31/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0687 - val_accuracy: 0.9807
#
# Epoch 00031: val_loss did not improve from 0.05367
# Epoch 32/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0560 - val_accuracy: 0.9850
#
# Epoch 00032: val_loss did not improve from 0.05367
# Epoch 33/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0638 - val_accuracy: 0.9850
#
# Epoch 00033: val_loss did not improve from 0.05367
# Epoch 34/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0539 - val_accuracy: 0.9850
#
# Epoch 00034: val_loss did not improve from 0.05367
# Epoch 35/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0746 - val_accuracy: 0.9839
#
# Epoch 00035: val_loss did not improve from 0.05367
# Score for fold 3: loss of 0.07455125451087952; accuracy of 98.3940064907074%
# Epoch 1/35
# 1046/1046 [==============================] - 156s 137ms/step - loss: 0.2601 - accuracy: 0.9709 - val_loss: 8.3687 - val_accuracy: 0.1253
#
# Epoch 00001: val_loss did not improve from 0.05367
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.1307 - val_accuracy: 0.9540
#
# Epoch 00002: val_loss did not improve from 0.05367
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0394 - accuracy: 0.9918 - val_loss: 3.4218 - val_accuracy: 0.5054
#
# Epoch 00003: val_loss did not improve from 0.05367
# Epoch 4/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0665 - accuracy: 0.9886 - val_loss: 0.0967 - val_accuracy: 0.9722
#
# Epoch 00004: val_loss did not improve from 0.05367
# Epoch 5/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0278 - accuracy: 0.9938 - val_loss: 0.1689 - val_accuracy: 0.9475
#
# Epoch 00005: val_loss did not improve from 0.05367
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0311 - accuracy: 0.9926 - val_loss: 0.0702 - val_accuracy: 0.9807
#
# Epoch 00006: val_loss did not improve from 0.05367
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0243 - accuracy: 0.9939 - val_loss: 23.8034 - val_accuracy: 0.3801
#
# Epoch 00007: val_loss did not improve from 0.05367
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0212 - accuracy: 0.9945 - val_loss: 0.0843 - val_accuracy: 0.9722
# Epoch 00008: val_loss did not improve from 0.05367
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0374 - accuracy: 0.9926 - val_loss: 0.0704 - val_accuracy: 0.9732
#
# Epoch 00009: val_loss did not improve from 0.05367
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0905 - val_accuracy: 0.9636
#
# Epoch 00010: val_loss did not improve from 0.05367
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0300 - accuracy: 0.9936 - val_loss: 0.0778 - val_accuracy: 0.9786
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_loss did not improve from 0.05367
# Epoch 12/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0619 - val_accuracy: 0.9797
#
# Epoch 00012: val_loss did not improve from 0.05367
# Epoch 13/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0730 - val_accuracy: 0.9818
#
# Epoch 00013: val_loss did not improve from 0.05367
# Epoch 14/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0840 - val_accuracy: 0.9722
#
# Epoch 00014: val_loss did not improve from 0.05367
# Epoch 15/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0519 - val_accuracy: 0.9850
#
# Epoch 00015: val_loss improved from 0.05367 to 0.05188, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 16/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.0560 - val_accuracy: 0.9839
#
# Epoch 00016: val_loss did not improve from 0.05188
# Epoch 17/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0472 - val_accuracy: 0.9872
#
# Epoch 00017: val_loss improved from 0.05188 to 0.04719, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 18/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0909 - val_accuracy: 0.9797
#
# Epoch 00018: val_loss did not improve from 0.04719
# Epoch 19/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.1098 - val_accuracy: 0.9786
#
# Epoch 00019: val_loss did not improve from 0.04719
# Epoch 20/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.8710 - val_accuracy: 0.7666
#
# Epoch 00020: val_loss did not improve from 0.04719
# Epoch 21/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0137 - accuracy: 0.9973 - val_loss: 4.0185 - val_accuracy: 0.5460
#
# Epoch 00021: val_loss did not improve from 0.04719
# Epoch 22/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0128 - accuracy: 0.9970 - val_loss: 0.0496 - val_accuracy: 0.9882
#
# Epoch 00022: val_loss did not improve from 0.04719
# Epoch 23/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0542 - val_accuracy: 0.9872
#
# Epoch 00023: val_loss did not improve from 0.04719
# Epoch 24/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0619 - val_accuracy: 0.9818
#
# Epoch 00024: val_loss did not improve from 0.04719
# Epoch 25/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0474 - val_accuracy: 0.9850
#
# Epoch 00025: val_loss did not improve from 0.04719
# Epoch 26/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0580 - val_accuracy: 0.9829
#
# Epoch 00026: val_loss did not improve from 0.04719
# Epoch 27/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0907 - val_accuracy: 0.9850
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.04719
# Epoch 28/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0495 - val_accuracy: 0.9861
#
# Epoch 00028: val_loss did not improve from 0.04719
# Epoch 29/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0590 - val_accuracy: 0.9872
#
# Epoch 00029: val_loss did not improve from 0.04719
# Epoch 30/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0777 - val_accuracy: 0.9850
#
# Epoch 00030: val_loss did not improve from 0.04719
# Epoch 31/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.1103 - val_accuracy: 0.9786
#
# Epoch 00031: val_loss did not improve from 0.04719
# Epoch 32/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0427 - val_accuracy: 0.9882
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss improved from 0.04719 to 0.04273, saving model to /Users/Max/Documents/GitHub/malimg_dataset/crossv-cgan-densenet-local-v021\model.h5
# Epoch 33/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0523 - val_accuracy: 0.9872
#
# Epoch 00033: val_loss did not improve from 0.04273
# Epoch 34/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0543 - val_accuracy: 0.9861
#
# Epoch 00034: val_loss did not improve from 0.04273
# Epoch 35/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0507 - val_accuracy: 0.9872
#
# Epoch 00035: val_loss did not improve from 0.04273
# Score for fold 4: loss of 0.05068063735961914; accuracy of 98.71520400047302%
# Epoch 1/35
# 1046/1046 [==============================] - 158s 137ms/step - loss: 0.2704 - accuracy: 0.9683 - val_loss: 4.6649 - val_accuracy: 0.0824
#
# Epoch 00001: val_loss did not improve from 0.04273
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0350 - accuracy: 0.9918 - val_loss: 0.8928 - val_accuracy: 0.7912
#
# Epoch 00002: val_loss did not improve from 0.04273
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0347 - accuracy: 0.9923 - val_loss: 0.0933 - val_accuracy: 0.9711
#
# Epoch 00003: val_loss did not improve from 0.04273
# Epoch 4/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0935 - val_accuracy: 0.9679
#
# Epoch 00004: val_loss did not improve from 0.04273
# Epoch 5/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0579 - accuracy: 0.9894 - val_loss: 0.1399 - val_accuracy: 0.9529
#
# Epoch 00005: val_loss did not improve from 0.04273
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0232 - accuracy: 0.9939 - val_loss: 0.1300 - val_accuracy: 0.9582
#
# Epoch 00006: val_loss did not improve from 0.04273
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0295 - accuracy: 0.9936 - val_loss: 0.1103 - val_accuracy: 0.9657
#
# Epoch 00007: val_loss did not improve from 0.04273
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.0829 - val_accuracy: 0.9732
#
# Epoch 00008: val_loss did not improve from 0.04273
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0388 - accuracy: 0.9924 - val_loss: 1.7750 - val_accuracy: 0.7559
#
# Epoch 00009: val_loss did not improve from 0.04273
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0196 - accuracy: 0.9956 - val_loss: 4.7232 - val_accuracy: 0.4732
#
# Epoch 00010: val_loss did not improve from 0.04273
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0241 - accuracy: 0.9947 - val_loss: 0.1048 - val_accuracy: 0.9636
#
# Epoch 00011: val_loss did not improve from 0.04273
# Epoch 12/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.1073 - val_accuracy: 0.9690
#
# Epoch 00012: val_loss did not improve from 0.04273
# Epoch 13/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0294 - accuracy: 0.9941 - val_loss: 0.1378 - val_accuracy: 0.9593
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.04273
# Epoch 14/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0943 - val_accuracy: 0.9690
#
# Epoch 00014: val_loss did not improve from 0.04273
# Epoch 15/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.1220 - val_accuracy: 0.9657
#
# Epoch 00015: val_loss did not improve from 0.04273
# Epoch 16/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0837 - val_accuracy: 0.9679
#
# Epoch 00016: val_loss did not improve from 0.04273
# Epoch 17/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0762 - val_accuracy: 0.9775
#
# Epoch 00017: val_loss did not improve from 0.04273
# Epoch 18/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0932 - val_accuracy: 0.9711
#
# Epoch 00018: val_loss did not improve from 0.04273
# Epoch 19/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0730 - val_accuracy: 0.9679
#
# Epoch 00019: val_loss did not improve from 0.04273
# Epoch 20/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0763 - val_accuracy: 0.9711
#
# Epoch 00020: val_loss did not improve from 0.04273
# Epoch 21/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 1.2013 - val_accuracy: 0.8383
#
# Epoch 00021: val_loss did not improve from 0.04273
# Epoch 22/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0743 - val_accuracy: 0.9754
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.04273
# Epoch 23/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0735 - val_accuracy: 0.9732
#
# Epoch 00023: val_loss did not improve from 0.04273
# Epoch 24/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0653 - val_accuracy: 0.9764
#
# Epoch 00024: val_loss did not improve from 0.04273
# Epoch 25/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0704 - val_accuracy: 0.9764
#
# Epoch 00025: val_loss did not improve from 0.04273
# Epoch 26/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0697 - val_accuracy: 0.9754
#
# Epoch 00026: val_loss did not improve from 0.04273
# Epoch 27/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0614 - val_accuracy: 0.9775
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.04273
# Epoch 28/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0684 - val_accuracy: 0.9754
#
# Epoch 00028: val_loss did not improve from 0.04273
# Epoch 29/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0619 - val_accuracy: 0.9786
#
# Epoch 00029: val_loss did not improve from 0.04273
# Epoch 30/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0619 - val_accuracy: 0.9786
#
# Epoch 00030: val_loss did not improve from 0.04273
# Epoch 31/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0855 - val_accuracy: 0.9743
#
# Epoch 00031: val_loss did not improve from 0.04273
# Epoch 32/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0755 - val_accuracy: 0.9786
#
# Epoch 00032: val_loss did not improve from 0.04273
# Epoch 33/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0646 - val_accuracy: 0.9775
#
# Epoch 00033: val_loss did not improve from 0.04273
# Epoch 34/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0710 - val_accuracy: 0.9775
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.04273
# Epoch 35/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0693 - val_accuracy: 0.9764
#
# Epoch 00035: val_loss did not improve from 0.04273
# Score for fold 5: loss of 0.06928674131631851; accuracy of 97.64453768730164%
# Epoch 1/35
# 1046/1046 [==============================] - 158s 137ms/step - loss: 0.2812 - accuracy: 0.9684 - val_loss: 34.7440 - val_accuracy: 0.0268
#
# Epoch 00001: val_loss did not improve from 0.04273
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0292 - accuracy: 0.9932 - val_loss: 0.1487 - val_accuracy: 0.9475
#
# Epoch 00002: val_loss did not improve from 0.04273
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0817 - accuracy: 0.9857 - val_loss: 0.1772 - val_accuracy: 0.9540
#
# Epoch 00003: val_loss did not improve from 0.04273
# Epoch 4/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.1472 - val_accuracy: 0.9486
#
# Epoch 00004: val_loss did not improve from 0.04273
# Epoch 5/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0450 - accuracy: 0.9908 - val_loss: 0.1099 - val_accuracy: 0.9647
#
# Epoch 00005: val_loss did not improve from 0.04273
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0569 - accuracy: 0.9912 - val_loss: 0.1653 - val_accuracy: 0.9486
#
# Epoch 00006: val_loss did not improve from 0.04273
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0161 - accuracy: 0.9955 - val_loss: 0.1324 - val_accuracy: 0.9593
#
# Epoch 00007: val_loss did not improve from 0.04273
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0273 - accuracy: 0.9939 - val_loss: 0.1509 - val_accuracy: 0.9550
#
# Epoch 00008: val_loss did not improve from 0.04273
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0208 - accuracy: 0.9946 - val_loss: 19.5054 - val_accuracy: 0.2420
#
# Epoch 00009: val_loss did not improve from 0.04273
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0201 - accuracy: 0.9954 - val_loss: 0.1234 - val_accuracy: 0.9604
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_loss did not improve from 0.04273
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.1333 - val_accuracy: 0.9604
#
# Epoch 00011: val_loss did not improve from 0.04273
# Epoch 12/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.1269 - val_accuracy: 0.9636
#
# Epoch 00012: val_loss did not improve from 0.04273
# Epoch 13/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.2157 - val_accuracy: 0.9433
#
# Epoch 00013: val_loss did not improve from 0.04273
# Epoch 14/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.1013 - val_accuracy: 0.9615
# Epoch 00014: val_loss did not improve from 0.04273
# Epoch 15/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.1581 - val_accuracy: 0.9540
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00015: val_loss did not improve from 0.04273
# Epoch 16/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.1000 - val_accuracy: 0.9668
#
# Epoch 00016: val_loss did not improve from 0.04273
# Epoch 17/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.1144 - val_accuracy: 0.9657
#
# Epoch 00017: val_loss did not improve from 0.04273
# Epoch 18/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.1122 - val_accuracy: 0.9679
#
# Epoch 00018: val_loss did not improve from 0.04273
# Epoch 19/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.1450 - val_accuracy: 0.9625
#
# Epoch 00019: val_loss did not improve from 0.04273
# Epoch 20/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.1133 - val_accuracy: 0.9636
#
# Epoch 00020: val_loss did not improve from 0.04273
# Epoch 21/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.1294 - val_accuracy: 0.9593
#
# Epoch 00021: val_loss did not improve from 0.04273
# Epoch 22/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0889 - val_accuracy: 0.9722
#
# Epoch 00022: val_loss did not improve from 0.04273
# Epoch 23/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0953 - val_accuracy: 0.9711
#
# Epoch 00023: val_loss did not improve from 0.04273
# Epoch 24/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.1660 - val_accuracy: 0.9561
#
# Epoch 00024: val_loss did not improve from 0.04273
# Epoch 25/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.1181 - val_accuracy: 0.9711
#
# Epoch 00025: val_loss did not improve from 0.04273
# Epoch 26/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1874 - val_accuracy: 0.9540
#
# Epoch 00026: val_loss did not improve from 0.04273
# Epoch 27/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.1318 - val_accuracy: 0.9690
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.04273
# Epoch 28/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1176 - val_accuracy: 0.9700
#
# Epoch 00028: val_loss did not improve from 0.04273
# Epoch 29/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1205 - val_accuracy: 0.9690
#
# Epoch 00029: val_loss did not improve from 0.04273
# Epoch 30/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1330 - val_accuracy: 0.9711
#
# Epoch 00030: val_loss did not improve from 0.04273
# Epoch 31/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.1604 - val_accuracy: 0.9657
#
# Epoch 00031: val_loss did not improve from 0.04273
# Epoch 32/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1254 - val_accuracy: 0.9711
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.04273
# Epoch 33/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1273 - val_accuracy: 0.9732
#
# Epoch 00033: val_loss did not improve from 0.04273
# Epoch 34/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1469 - val_accuracy: 0.9690
#
# Epoch 00034: val_loss did not improve from 0.04273
# Epoch 35/35
# 1046/1046 [==============================] - 142s 136ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1433 - val_accuracy: 0.9700
#
# Epoch 00035: val_loss did not improve from 0.04273
# Score for fold 6: loss of 0.14328183233737946; accuracy of 97.00214266777039%
# Epoch 1/35
# 1046/1046 [==============================] - 159s 140ms/step - loss: 0.2075 - accuracy: 0.9727 - val_loss: 9.2826 - val_accuracy: 0.1381
#
# Epoch 00001: val_loss did not improve from 0.04273
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0628 - accuracy: 0.9899 - val_loss: 0.2107 - val_accuracy: 0.9347
#
# Epoch 00002: val_loss did not improve from 0.04273
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0513 - accuracy: 0.9894 - val_loss: 0.0920 - val_accuracy: 0.9636
#
# Epoch 00003: val_loss did not improve from 0.04273
# Epoch 4/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.1050 - val_accuracy: 0.9679
#
# Epoch 00004: val_loss did not improve from 0.04273
# Epoch 5/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0865 - accuracy: 0.9879 - val_loss: 0.1844 - val_accuracy: 0.9561
#
# Epoch 00005: val_loss did not improve from 0.04273
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.1405 - val_accuracy: 0.9657
#
# Epoch 00006: val_loss did not improve from 0.04273
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0414 - accuracy: 0.9924 - val_loss: 0.3609 - val_accuracy: 0.9325
#
# Epoch 00007: val_loss did not improve from 0.04273
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 1.6561 - val_accuracy: 0.7206
#
# Epoch 00008: val_loss did not improve from 0.04273
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0191 - accuracy: 0.9946 - val_loss: 0.2749 - val_accuracy: 0.9507
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.04273
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.1227 - val_accuracy: 0.9786
#
# Epoch 00010: val_loss did not improve from 0.04273
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.1280 - val_accuracy: 0.9679
#
# Epoch 00011: val_loss did not improve from 0.04273
# Epoch 12/35
# ...
# Epoch 31/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0499 - val_accuracy: 0.9882
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00031: val_loss did not improve from 0.03623
# Epoch 32/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0463 - val_accuracy: 0.9893
#
# Epoch 00032: val_loss did not improve from 0.03623
# Epoch 33/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0445 - val_accuracy: 0.9904
#
# Epoch 00033: val_loss did not improve from 0.03623
# Epoch 34/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0571 - val_accuracy: 0.9904
#
# Epoch 00034: val_loss did not improve from 0.03623
# Epoch 35/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0554 - val_accuracy: 0.9904
#
# Epoch 00035: val_loss did not improve from 0.03623
# Score for fold 8: loss of 0.05541291832923889; accuracy of 99.03640151023865%
# Epoch 1/35
# 1046/1046 [==============================] - 156s 137ms/step - loss: 0.2670 - accuracy: 0.9673 - val_loss: 6.6628 - val_accuracy: 0.1488
#
# Epoch 00001: val_loss did not improve from 0.03623
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0699 - val_accuracy: 0.9764
#
# Epoch 00002: val_loss did not improve from 0.03623
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0566 - accuracy: 0.9882 - val_loss: 3.8029 - val_accuracy: 0.7719
#
# Epoch 00003: val_loss did not improve from 0.03623
# Epoch 4/35
# 1046/1046 [==============================] - 142s 135ms/step - loss: 0.0525 - accuracy: 0.9907 - val_loss: 0.3717 - val_accuracy: 0.9572
#
# Epoch 00004: val_loss did not improve from 0.03623
# Epoch 5/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 1.3258 - val_accuracy: 0.7484
#
# Epoch 00005: val_loss did not improve from 0.03623
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0478 - accuracy: 0.9907 - val_loss: 0.0755 - val_accuracy: 0.9743
#
# Epoch 00006: val_loss did not improve from 0.03623
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0352 - accuracy: 0.9934 - val_loss: 0.0738 - val_accuracy: 0.9722
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.03623
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0676 - val_accuracy: 0.9732
#
# Epoch 00008: val_loss did not improve from 0.03623
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0691 - val_accuracy: 0.9775
#
# Epoch 00009: val_loss did not improve from 0.03623
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0633 - val_accuracy: 0.9764
#
# Epoch 00010: val_loss did not improve from 0.03623
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.1448 - val_accuracy: 0.9636
#
# Epoch 00011: val_loss did not improve from 0.03623
# Epoch 12/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0648 - val_accuracy: 0.9754
#
# Epoch 00012: val_loss did not improve from 0.03623
# Epoch 13/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0616 - val_accuracy: 0.9786
#
# Epoch 00013: val_loss did not improve from 0.03623
# Epoch 14/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0759 - val_accuracy: 0.9797
#
# Epoch 00014: val_loss did not improve from 0.03623
# Epoch 15/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 18.8214 - val_accuracy: 0.1799
#
# Epoch 00015: val_loss did not improve from 0.03623
# Epoch 16/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0189 - accuracy: 0.9967 - val_loss: 0.0510 - val_accuracy: 0.9829
#
# Epoch 00016: val_loss did not improve from 0.03623
# Epoch 17/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0606 - val_accuracy: 0.9818
#
# Epoch 00017: val_loss did not improve from 0.03623
# Epoch 18/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0667 - val_accuracy: 0.9807
#
# Epoch 00018: val_loss did not improve from 0.03623
# Epoch 19/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0735 - val_accuracy: 0.9764
#
# Epoch 00019: val_loss did not improve from 0.03623
# Epoch 20/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0549 - val_accuracy: 0.9807
#
# Epoch 00020: val_loss did not improve from 0.03623
# Epoch 21/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0149 - accuracy: 0.9973 - val_loss: 0.0691 - val_accuracy: 0.9754
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.03623
# Epoch 22/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0516 - val_accuracy: 0.9818
#
# Epoch 00022: val_loss did not improve from 0.03623
# Epoch 23/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0488 - val_accuracy: 0.9861
#
# Epoch 00023: val_loss did not improve from 0.03623
# Epoch 24/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0627 - val_accuracy: 0.9829
#
# Epoch 00024: val_loss did not improve from 0.03623
# Epoch 25/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0584 - val_accuracy: 0.9839
#
# Epoch 00025: val_loss did not improve from 0.03623
# Epoch 26/35
# 1046/1046 [==============================] - 142s 136ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0506 - val_accuracy: 0.9839
#
# Epoch 00026: val_loss did not improve from 0.03623
# Epoch 27/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0077 - accuracy: 0.9982 - val_loss: 0.0615 - val_accuracy: 0.9764
#
# Epoch 00027: val_loss did not improve from 0.03623
# Epoch 28/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0596 - val_accuracy: 0.9829
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00028: val_loss did not improve from 0.03623
# Epoch 29/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0586 - val_accuracy: 0.9829
#
# Epoch 00029: val_loss did not improve from 0.03623
# Epoch 30/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0620 - val_accuracy: 0.9839
#
# Epoch 00030: val_loss did not improve from 0.03623
# Epoch 31/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0675 - val_accuracy: 0.9818
#
# Epoch 00031: val_loss did not improve from 0.03623
# Epoch 32/35
# 1046/1046 [==============================] - 142s 135ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0655 - val_accuracy: 0.9818
#
# Epoch 00032: val_loss did not improve from 0.03623
# Epoch 33/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0683 - val_accuracy: 0.9797
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00033: val_loss did not improve from 0.03623
# Epoch 34/35
# 1046/1046 [==============================] - 142s 135ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0670 - val_accuracy: 0.9818
#
# Epoch 00034: val_loss did not improve from 0.03623
# Epoch 35/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0744 - val_accuracy: 0.9829
#
# Epoch 00035: val_loss did not improve from 0.03623
# Score for fold 9: loss of 0.07437176257371902; accuracy of 98.28693866729736%
# Epoch 1/35
# 1046/1046 [==============================] - 163s 139ms/step - loss: 0.2349 - accuracy: 0.9705 - val_loss: 4.2774 - val_accuracy: 0.1801
#
# Epoch 00001: val_loss did not improve from 0.03623
# Epoch 2/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0631 - accuracy: 0.9884 - val_loss: 0.1359 - val_accuracy: 0.9582
#
# Epoch 00002: val_loss did not improve from 0.03623
# Epoch 3/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0719 - accuracy: 0.9895 - val_loss: 0.1040 - val_accuracy: 0.9668
#
# Epoch 00003: val_loss did not improve from 0.03623
# Epoch 4/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.2222 - val_accuracy: 0.9378
#
# Epoch 00004: val_loss did not improve from 0.03623
# Epoch 5/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0706 - accuracy: 0.9884 - val_loss: 0.1875 - val_accuracy: 0.9625
#
# Epoch 00005: val_loss did not improve from 0.03623
# Epoch 6/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0370 - accuracy: 0.9929 - val_loss: 0.4033 - val_accuracy: 0.9346
#
# Epoch 00006: val_loss did not improve from 0.03623
# Epoch 7/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0211 - accuracy: 0.9952 - val_loss: 0.2440 - val_accuracy: 0.9443
#
# Epoch 00007: val_loss did not improve from 0.03623
# Epoch 8/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.1431 - val_accuracy: 0.9700
#
# Epoch 00008: val_loss did not improve from 0.03623
# Epoch 9/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 0.1335 - val_accuracy: 0.9550
#
# Epoch 00009: val_loss did not improve from 0.03623
# Epoch 10/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0322 - accuracy: 0.9948 - val_loss: 0.1559 - val_accuracy: 0.9539
#
# Epoch 00010: val_loss did not improve from 0.03623
# Epoch 11/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0170 - accuracy: 0.9954 - val_loss: 0.0935 - val_accuracy: 0.9700
#
# Epoch 00011: val_loss did not improve from 0.03623
# Epoch 12/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0316 - accuracy: 0.9952 - val_loss: 0.1169 - val_accuracy: 0.9646
#
# Epoch 00012: val_loss did not improve from 0.03623
# Epoch 13/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0208 - accuracy: 0.9957 - val_loss: 0.1013 - val_accuracy: 0.9657
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.03623
# Epoch 14/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0727 - val_accuracy: 0.9764
#
# Epoch 00014: val_loss did not improve from 0.03623
# Epoch 15/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.2748 - val_accuracy: 0.9357
#
# Epoch 00015: val_loss did not improve from 0.03623
# Epoch 16/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.1002 - val_accuracy: 0.9721
#
# Epoch 00016: val_loss did not improve from 0.03623
# Epoch 17/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0642 - val_accuracy: 0.9807
#
# Epoch 00017: val_loss did not improve from 0.03623
# Epoch 18/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0797 - val_accuracy: 0.9732
#
# Epoch 00018: val_loss did not improve from 0.03623
# Epoch 19/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0995 - val_accuracy: 0.9689
#
# Epoch 00019: val_loss did not improve from 0.03623
# Epoch 20/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0807 - val_accuracy: 0.9700
#
# Epoch 00020: val_loss did not improve from 0.03623
# Epoch 21/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.1636 - val_accuracy: 0.9475
#
# Epoch 00021: val_loss did not improve from 0.03623
# Epoch 22/35
# 1046/1046 [==============================] - 141s 135ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0800 - val_accuracy: 0.9753
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.03623
# Epoch 23/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0523 - val_accuracy: 0.9807
#
# Epoch 00023: val_loss did not improve from 0.03623
# Epoch 24/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0518 - val_accuracy: 0.9829
#
# Epoch 00024: val_loss did not improve from 0.03623
# Epoch 25/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0542 - val_accuracy: 0.9818
#
# Epoch 00025: val_loss did not improve from 0.03623
# Epoch 26/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1403 - val_accuracy: 0.9636
#
# Epoch 00026: val_loss did not improve from 0.03623
# Epoch 27/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0742 - val_accuracy: 0.9786
#
# Epoch 00027: val_loss did not improve from 0.03623
# Epoch 28/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0705 - val_accuracy: 0.9807
#
# Epoch 00028: val_loss did not improve from 0.03623
# Epoch 29/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0717 - val_accuracy: 0.9796
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.03623
# Epoch 30/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0532 - val_accuracy: 0.9829
#
# Epoch 00030: val_loss did not improve from 0.03623
# Epoch 31/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0537 - val_accuracy: 0.9829
#
# Epoch 00031: val_loss did not improve from 0.03623
# Epoch 32/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0592 - val_accuracy: 0.9818
#
# Epoch 00032: val_loss did not improve from 0.03623
# Epoch 33/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0551 - val_accuracy: 0.9818
#
# Epoch 00033: val_loss did not improve from 0.03623
# Epoch 34/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0596 - val_accuracy: 0.9807
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.03623
# Epoch 35/35
# 1046/1046 [==============================] - 140s 134ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0611 - val_accuracy: 0.9818
#
# Epoch 00035: val_loss did not improve from 0.03623
# Score for fold 10: loss of 0.06110109016299248; accuracy of 98.17792177200317%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.08143461495637894 - Accuracy: 97.75160551071167%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.12904441356658936 - Accuracy: 97.53747582435608%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.07455125451087952 - Accuracy: 98.3940064907074%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.05068063735961914 - Accuracy: 98.71520400047302%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.06928674131631851 - Accuracy: 97.64453768730164%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.14328183233737946 - Accuracy: 97.00214266777039%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.10501137375831604 - Accuracy: 98.0728030204773%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.05541291832923889 - Accuracy: 99.03640151023865%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.07437176257371902 - Accuracy: 98.28693866729736%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.06110109016299248 - Accuracy: 98.17792177200317%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 98.06190371513367% (+- 0.0056741137194231015)
# > Loss: 0.08441766388714314
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN-DenseNet"
print(t)
# Out:
# +---------------------------------------+
# |      Performance of CGAN-DenseNet     |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9806      | 0.0057       |
# | Loss     | 0.0844      | 0.0297       |
# | Macro F1 | 0.9358      | 0.0096       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9804      | 0.0062       |
# | Acc      | 0.9865      | 0.0042       |
# | F1       | 0.9826      | 0.0056       |
# | MCC      | 0.9718      | 0.0088       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-DenseNet across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-DenseNet")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
