# %% [markdown]
# # DenseNet

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 20000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/learning_curve"
    for files in os.listdir(dir):
        if "densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-densenet{batch_size}-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/learning_curve/crossv-densenet{batch_size}-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 5 matches(es) found
# --------------
# New folder name: crossv-densenet10000-local-v006
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = tf.keras.applications.densenet.preprocess_input(imgs)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # DenseNet
# We will now build our **DenseNet169** model using Tensorflow/Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3
#
# Nota bene that the DenseNet only takes RGB images (with 3 channels)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Build the DenseNet model
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    # Add the classification layers for this dataset
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    
    # Run the CNN
    history.append(
        head_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
    
    # Save the binary data distribution
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/40
# 282/282 [==============================] - 52s 140ms/step - loss: 0.6247 - accuracy: 0.8551 - val_loss: 0.8374 - val_accuracy: 0.7470
#
# Epoch 00001: val_loss improved from inf to 0.83744, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 2/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.4598 - accuracy: 0.8893 - val_loss: 0.5243 - val_accuracy: 0.8530
#
# Epoch 00002: val_loss improved from 0.83744 to 0.52430, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 3/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.2699 - accuracy: 0.9147 - val_loss: 0.2438 - val_accuracy: 0.9170
#
# Epoch 00003: val_loss improved from 0.52430 to 0.24377, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 4/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2141 - accuracy: 0.9314 - val_loss: 0.1855 - val_accuracy: 0.9340
#
# Epoch 00004: val_loss improved from 0.24377 to 0.18553, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 5/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.2013 - accuracy: 0.9368 - val_loss: 0.1951 - val_accuracy: 0.9390
#
# Epoch 00005: val_loss did not improve from 0.18553
# Epoch 6/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1738 - accuracy: 0.9446 - val_loss: 0.1814 - val_accuracy: 0.9340
#
# Epoch 00006: val_loss improved from 0.18553 to 0.18145, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 7/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.1590 - accuracy: 0.9497 - val_loss: 0.1831 - val_accuracy: 0.9470
#
# Epoch 00007: val_loss did not improve from 0.18145
# Epoch 8/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.1491 - accuracy: 0.9484 - val_loss: 0.1548 - val_accuracy: 0.9450
#
# Epoch 00008: val_loss improved from 0.18145 to 0.15481, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 9/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1472 - accuracy: 0.9526 - val_loss: 0.1822 - val_accuracy: 0.9440
#
# Epoch 00009: val_loss did not improve from 0.15481
# Epoch 10/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1299 - accuracy: 0.9596 - val_loss: 0.1543 - val_accuracy: 0.9490
#
# Epoch 00010: val_loss improved from 0.15481 to 0.15427, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 11/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1333 - accuracy: 0.9568 - val_loss: 0.1851 - val_accuracy: 0.9440
#
# Epoch 00011: val_loss did not improve from 0.15427
# Epoch 12/40
# 282/282 [==============================] - 35s 125ms/step - loss: 1.5292 - accuracy: 0.8010 - val_loss: 141.7324 - val_accuracy: 0.3240
#
# Epoch 00012: val_loss did not improve from 0.15427
# Epoch 13/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.3792 - accuracy: 0.8833 - val_loss: 12.6910 - val_accuracy: 0.8930
#
# Epoch 00013: val_loss did not improve from 0.15427
# Epoch 14/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.2682 - accuracy: 0.9147 - val_loss: 18.0793 - val_accuracy: 0.9070
#
# Epoch 00014: val_loss did not improve from 0.15427
# Epoch 15/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2477 - accuracy: 0.9203 - val_loss: 5.6529 - val_accuracy: 0.9080
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.15427
# Epoch 16/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2021 - accuracy: 0.9340 - val_loss: 17.5788 - val_accuracy: 0.9190
#
# Epoch 00016: val_loss did not improve from 0.15427
# Epoch 17/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1953 - accuracy: 0.9339 - val_loss: 37.5047 - val_accuracy: 0.9230
#
# Epoch 00017: val_loss did not improve from 0.15427
# Epoch 18/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1804 - accuracy: 0.9404 - val_loss: 68.5967 - val_accuracy: 0.9230
#
# Epoch 00018: val_loss did not improve from 0.15427
# Epoch 19/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1726 - accuracy: 0.9432 - val_loss: 46.3872 - val_accuracy: 0.9230
#
# Epoch 00019: val_loss did not improve from 0.15427
# Epoch 20/40
# 282/282 [==============================] - 36s 129ms/step - loss: 0.1734 - accuracy: 0.9430 - val_loss: 28.8617 - val_accuracy: 0.9200
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss did not improve from 0.15427
# Epoch 21/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.1468 - accuracy: 0.9492 - val_loss: 12.1086 - val_accuracy: 0.9290
#
# Epoch 00021: val_loss did not improve from 0.15427
# Epoch 22/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1434 - accuracy: 0.9511 - val_loss: 20.8609 - val_accuracy: 0.9290
#
# Epoch 00022: val_loss did not improve from 0.15427
# Epoch 23/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1351 - accuracy: 0.9540 - val_loss: 17.9751 - val_accuracy: 0.9280
#
# Epoch 00023: val_loss did not improve from 0.15427
# Epoch 24/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1327 - accuracy: 0.9552 - val_loss: 25.5063 - val_accuracy: 0.9320
#
# Epoch 00024: val_loss did not improve from 0.15427
# Epoch 25/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1232 - accuracy: 0.9567 - val_loss: 42.6852 - val_accuracy: 0.9340
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_loss did not improve from 0.15427
# Epoch 26/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1061 - accuracy: 0.9649 - val_loss: 9.7243 - val_accuracy: 0.9330
#
# Epoch 00026: val_loss did not improve from 0.15427
# Epoch 27/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1052 - accuracy: 0.9650 - val_loss: 18.1451 - val_accuracy: 0.9310
#
# Epoch 00027: val_loss did not improve from 0.15427
# Epoch 28/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1026 - accuracy: 0.9660 - val_loss: 15.3397 - val_accuracy: 0.9320
#
# Epoch 00028: val_loss did not improve from 0.15427
# Epoch 29/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0964 - accuracy: 0.9660 - val_loss: 27.2134 - val_accuracy: 0.9370
#
# Epoch 00029: val_loss did not improve from 0.15427
# Epoch 30/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0945 - accuracy: 0.9678 - val_loss: 41.5345 - val_accuracy: 0.9310
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00030: val_loss did not improve from 0.15427
# Epoch 31/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0929 - accuracy: 0.9678 - val_loss: 24.0240 - val_accuracy: 0.9370
#
# Epoch 00031: val_loss did not improve from 0.15427
# Epoch 32/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0852 - accuracy: 0.9711 - val_loss: 24.5290 - val_accuracy: 0.9310
#
# Epoch 00032: val_loss did not improve from 0.15427
# Epoch 33/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0905 - accuracy: 0.9694 - val_loss: 30.7331 - val_accuracy: 0.9370
#
# Epoch 00033: val_loss did not improve from 0.15427
# Epoch 34/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0834 - accuracy: 0.9721 - val_loss: 0.1569 - val_accuracy: 0.9470
#
# Epoch 00034: val_loss did not improve from 0.15427
# Epoch 35/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0810 - accuracy: 0.9732 - val_loss: 0.1513 - val_accuracy: 0.9540
#
# Epoch 00035: val_loss improved from 0.15427 to 0.15128, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 36/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.0818 - accuracy: 0.9736 - val_loss: 39.4042 - val_accuracy: 0.9320
# Epoch 00036: val_loss did not improve from 0.15128
# Epoch 37/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0750 - accuracy: 0.9747 - val_loss: 22.9982 - val_accuracy: 0.9390
#
# Epoch 00037: val_loss did not improve from 0.15128
# Epoch 38/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0779 - accuracy: 0.9724 - val_loss: 38.1082 - val_accuracy: 0.9420
#
# Epoch 00038: val_loss did not improve from 0.15128
# Epoch 39/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0787 - accuracy: 0.9733 - val_loss: 20.6929 - val_accuracy: 0.9420
#
# Epoch 00039: val_loss did not improve from 0.15128
# Epoch 40/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0701 - accuracy: 0.9771 - val_loss: 20.2918 - val_accuracy: 0.9380
#
# Epoch 00040: val_loss did not improve from 0.15128
# Score for fold 1: loss of 20.291828155517578; accuracy of 93.80000233650208%
# Epoch 1/40
# 282/282 [==============================] - 49s 133ms/step - loss: 0.5908 - accuracy: 0.8596 - val_loss: 32.6649 - val_accuracy: 0.2690
#
# Epoch 00001: val_loss did not improve from 0.15128
# Epoch 2/40
# 282/282 [==============================] - 37s 130ms/step - loss: 1.0592 - accuracy: 0.8007 - val_loss: 0.5295 - val_accuracy: 0.8380
#
# Epoch 00002: val_loss did not improve from 0.15128
# Epoch 3/40
# 282/282 [==============================] - 36s 129ms/step - loss: 0.3765 - accuracy: 0.8812 - val_loss: 0.3202 - val_accuracy: 0.8990
#
# Epoch 00003: val_loss did not improve from 0.15128
# Epoch 4/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.3064 - accuracy: 0.9019 - val_loss: 0.3431 - val_accuracy: 0.8980
#
# Epoch 00004: val_loss did not improve from 0.15128
# Epoch 5/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.2853 - accuracy: 0.9063 - val_loss: 0.2556 - val_accuracy: 0.9120
#
# Epoch 00005: val_loss did not improve from 0.15128
# Epoch 6/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.2445 - accuracy: 0.9187 - val_loss: 0.2680 - val_accuracy: 0.9130
#
# Epoch 00006: val_loss did not improve from 0.15128
# Epoch 7/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2298 - accuracy: 0.9244 - val_loss: 0.2233 - val_accuracy: 0.9300
#
# Epoch 00007: val_loss did not improve from 0.15128
# Epoch 8/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2180 - accuracy: 0.9289 - val_loss: 0.2232 - val_accuracy: 0.9410
#
# Epoch 00008: val_loss did not improve from 0.15128
# Epoch 9/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1999 - accuracy: 0.9357 - val_loss: 0.2164 - val_accuracy: 0.9370
#
# Epoch 00009: val_loss did not improve from 0.15128
# Epoch 10/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.6546 - accuracy: 0.8959 - val_loss: 8987.4297 - val_accuracy: 0.4160
#
# Epoch 00010: val_loss did not improve from 0.15128
# Epoch 11/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.6345 - accuracy: 0.8846 - val_loss: 0.3335 - val_accuracy: 0.8950
#
# Epoch 00011: val_loss did not improve from 0.15128
# Epoch 12/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.3506 - accuracy: 0.9156 - val_loss: 0.6410 - val_accuracy: 0.8860
#
# Epoch 00012: val_loss did not improve from 0.15128
# Epoch 13/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.4100 - accuracy: 0.9092 - val_loss: 1.2811 - val_accuracy: 0.7810
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.15128
# Epoch 14/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2357 - accuracy: 0.9287 - val_loss: 0.2778 - val_accuracy: 0.9360
#
# Epoch 00014: val_loss did not improve from 0.15128
# Epoch 15/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2244 - accuracy: 0.9286 - val_loss: 0.2781 - val_accuracy: 0.9280
#
# Epoch 00015: val_loss did not improve from 0.15128
# Epoch 16/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1969 - accuracy: 0.9354 - val_loss: 0.2069 - val_accuracy: 0.9390
#
# Epoch 00016: val_loss did not improve from 0.15128
# Epoch 17/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.1910 - accuracy: 0.9393 - val_loss: 0.2151 - val_accuracy: 0.9370
#
# Epoch 00017: val_loss did not improve from 0.15128
# Epoch 18/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1715 - accuracy: 0.9410 - val_loss: 0.1958 - val_accuracy: 0.9390
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_loss did not improve from 0.15128
# Epoch 19/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1521 - accuracy: 0.9470 - val_loss: 0.1871 - val_accuracy: 0.9430
#
# Epoch 00019: val_loss did not improve from 0.15128
# Epoch 20/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1465 - accuracy: 0.9493 - val_loss: 0.1928 - val_accuracy: 0.9390
#
# Epoch 00020: val_loss did not improve from 0.15128
# Epoch 21/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1392 - accuracy: 0.9517 - val_loss: 0.1948 - val_accuracy: 0.9390
#
# Epoch 00021: val_loss did not improve from 0.15128
# Epoch 22/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1347 - accuracy: 0.9556 - val_loss: 0.1874 - val_accuracy: 0.9440
#
# Epoch 00022: val_loss did not improve from 0.15128
# Epoch 23/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1319 - accuracy: 0.9549 - val_loss: 0.2006 - val_accuracy: 0.9380
#
# Epoch 00023: val_loss did not improve from 0.15128
# Epoch 24/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1273 - accuracy: 0.9558 - val_loss: 0.1985 - val_accuracy: 0.9440
#
# Epoch 00024: val_loss did not improve from 0.15128
# Epoch 25/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.1223 - accuracy: 0.9582 - val_loss: 0.2007 - val_accuracy: 0.9440
#
# Epoch 00025: val_loss did not improve from 0.15128
# Epoch 26/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.1188 - accuracy: 0.9598 - val_loss: 0.2098 - val_accuracy: 0.9430
#
# Epoch 00026: val_loss did not improve from 0.15128
# Epoch 27/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1202 - accuracy: 0.9596 - val_loss: 0.2317 - val_accuracy: 0.9340
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.15128
# Epoch 28/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1019 - accuracy: 0.9654 - val_loss: 0.2082 - val_accuracy: 0.9460
#
# Epoch 00028: val_loss did not improve from 0.15128
# Epoch 29/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0988 - accuracy: 0.9659 - val_loss: 0.1974 - val_accuracy: 0.9490
#
# Epoch 00029: val_loss did not improve from 0.15128
# Epoch 30/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1069 - accuracy: 0.9651 - val_loss: 0.1850 - val_accuracy: 0.9450
#
# Epoch 00030: val_loss did not improve from 0.15128
# Epoch 31/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0913 - accuracy: 0.9698 - val_loss: 0.1956 - val_accuracy: 0.9430
#
# Epoch 00031: val_loss did not improve from 0.15128
# Epoch 32/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0950 - accuracy: 0.9689 - val_loss: 0.2125 - val_accuracy: 0.9460
#
# Epoch 00032: val_loss did not improve from 0.15128
# Epoch 33/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0872 - accuracy: 0.9708 - val_loss: 0.2368 - val_accuracy: 0.9380
#
# Epoch 00033: val_loss did not improve from 0.15128
# Epoch 34/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0889 - accuracy: 0.9699 - val_loss: 0.1908 - val_accuracy: 0.9520
#
# Epoch 00034: val_loss did not improve from 0.15128
# Epoch 35/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0847 - accuracy: 0.9730 - val_loss: 0.2167 - val_accuracy: 0.9480
#
# Epoch 00035: val_loss did not improve from 0.15128
# Epoch 36/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0900 - accuracy: 0.9698 - val_loss: 0.1990 - val_accuracy: 0.9480
# Epoch 00036: val_loss did not improve from 0.15128
# Epoch 37/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0792 - accuracy: 0.9737 - val_loss: 0.2120 - val_accuracy: 0.9520
#
# Epoch 00037: val_loss did not improve from 0.15128
# Epoch 38/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0805 - accuracy: 0.9740 - val_loss: 0.2033 - val_accuracy: 0.9460
#
# Epoch 00038: val_loss did not improve from 0.15128
# Epoch 39/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0800 - accuracy: 0.9731 - val_loss: 0.2019 - val_accuracy: 0.9510
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00039: val_loss did not improve from 0.15128
# Epoch 40/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0694 - accuracy: 0.9761 - val_loss: 0.2016 - val_accuracy: 0.9520
#
# Epoch 00040: val_loss did not improve from 0.15128
# Score for fold 2: loss of 0.20160551369190216; accuracy of 95.20000219345093%
# Epoch 1/40
# 282/282 [==============================] - 60s 127ms/step - loss: 0.5302 - accuracy: 0.8683 - val_loss: 0.2066 - val_accuracy: 0.9300
#
# Epoch 00001: val_loss did not improve from 0.15128
# Epoch 2/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.5516 - accuracy: 0.8838 - val_loss: 7.3129 - val_accuracy: 0.6730
#
# Epoch 00002: val_loss did not improve from 0.15128
# Epoch 3/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.3801 - accuracy: 0.8999 - val_loss: 0.3516 - val_accuracy: 0.8970
#
# Epoch 00003: val_loss did not improve from 0.15128
# Epoch 4/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2502 - accuracy: 0.9207 - val_loss: 0.2275 - val_accuracy: 0.9270
#
# Epoch 00004: val_loss did not improve from 0.15128
# Epoch 5/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.2824 - accuracy: 0.9218 - val_loss: 70.6011 - val_accuracy: 0.4290
#
# Epoch 00005: val_loss did not improve from 0.15128
# Epoch 6/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.3820 - accuracy: 0.8909 - val_loss: 0.2404 - val_accuracy: 0.9160
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.15128
# Epoch 7/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2283 - accuracy: 0.9263 - val_loss: 0.1810 - val_accuracy: 0.9360
#
# Epoch 00007: val_loss did not improve from 0.15128
# Epoch 8/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.1937 - accuracy: 0.9369 - val_loss: 0.1707 - val_accuracy: 0.9420
#
# Epoch 00008: val_loss did not improve from 0.15128
# Epoch 9/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1799 - accuracy: 0.9418 - val_loss: 0.2334 - val_accuracy: 0.9320
#
# Epoch 00009: val_loss did not improve from 0.15128
# Epoch 10/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1616 - accuracy: 0.9450 - val_loss: 0.1559 - val_accuracy: 0.9480
#
# Epoch 00010: val_loss did not improve from 0.15128
# Epoch 11/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.1589 - accuracy: 0.9464 - val_loss: 0.1662 - val_accuracy: 0.9430
#
# Epoch 00011: val_loss did not improve from 0.15128
# Epoch 12/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1442 - accuracy: 0.9514 - val_loss: 0.1626 - val_accuracy: 0.9500
#
# Epoch 00012: val_loss did not improve from 0.15128
# Epoch 13/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1355 - accuracy: 0.9544 - val_loss: 0.1468 - val_accuracy: 0.9520
#
# Epoch 00013: val_loss improved from 0.15128 to 0.14678, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 14/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1313 - accuracy: 0.9543 - val_loss: 0.1598 - val_accuracy: 0.9490
#
# Epoch 00014: val_loss did not improve from 0.14678
# Epoch 15/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.1262 - accuracy: 0.9573 - val_loss: 0.1673 - val_accuracy: 0.9510
#
# Epoch 00015: val_loss did not improve from 0.14678
# Epoch 16/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1168 - accuracy: 0.9593 - val_loss: 0.1682 - val_accuracy: 0.9520
#
# Epoch 00016: val_loss did not improve from 0.14678
# Epoch 17/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.1136 - accuracy: 0.9601 - val_loss: 0.1687 - val_accuracy: 0.9480
#
# Epoch 00017: val_loss did not improve from 0.14678
# Epoch 18/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1224 - accuracy: 0.9593 - val_loss: 0.1527 - val_accuracy: 0.9590
#
# Epoch 00018: val_loss did not improve from 0.14678
# Epoch 19/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1091 - accuracy: 0.9612 - val_loss: 0.1674 - val_accuracy: 0.9530
#
# Epoch 00019: val_loss did not improve from 0.14678
# Epoch 20/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1120 - accuracy: 0.9618 - val_loss: 0.1723 - val_accuracy: 0.9590
#
# Epoch 00020: val_loss did not improve from 0.14678
# Epoch 21/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0992 - accuracy: 0.9654 - val_loss: 0.1670 - val_accuracy: 0.9560
#
# Epoch 00021: val_loss did not improve from 0.14678
# Epoch 22/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0945 - accuracy: 0.9678 - val_loss: 0.1718 - val_accuracy: 0.9470
#
# Epoch 00022: val_loss did not improve from 0.14678
# Epoch 23/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.0970 - accuracy: 0.9677 - val_loss: 0.1520 - val_accuracy: 0.9630
#
# Epoch 00023: val_loss did not improve from 0.14678
# Epoch 24/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0884 - accuracy: 0.9691 - val_loss: 0.1636 - val_accuracy: 0.9510
#
# Epoch 00024: val_loss did not improve from 0.14678
# Epoch 25/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0920 - accuracy: 0.9689 - val_loss: 0.1718 - val_accuracy: 0.9520
#
# Epoch 00025: val_loss did not improve from 0.14678
# Epoch 26/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0870 - accuracy: 0.9703 - val_loss: 0.1589 - val_accuracy: 0.9560
#
# Epoch 00026: val_loss did not improve from 0.14678
# Epoch 27/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0849 - accuracy: 0.9719 - val_loss: 0.1849 - val_accuracy: 0.9520
#
# Epoch 00027: val_loss did not improve from 0.14678
# Epoch 28/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0831 - accuracy: 0.9729 - val_loss: 0.1670 - val_accuracy: 0.9530
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.14678
# Epoch 29/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0596 - accuracy: 0.9797 - val_loss: 0.1558 - val_accuracy: 0.9550
#
# Epoch 00029: val_loss did not improve from 0.14678
# Epoch 30/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.0589 - accuracy: 0.9798 - val_loss: 0.1550 - val_accuracy: 0.9600
#
# Epoch 00030: val_loss did not improve from 0.14678
# Epoch 31/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0571 - accuracy: 0.9803 - val_loss: 0.1576 - val_accuracy: 0.9610
#
# Epoch 00031: val_loss did not improve from 0.14678
# Epoch 32/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0506 - accuracy: 0.9834 - val_loss: 0.1645 - val_accuracy: 0.9630
#
# Epoch 00032: val_loss did not improve from 0.14678
# Epoch 33/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0507 - accuracy: 0.9828 - val_loss: 0.1784 - val_accuracy: 0.9590
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.14678
# Epoch 34/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0425 - accuracy: 0.9853 - val_loss: 0.1732 - val_accuracy: 0.9600
#
# Epoch 00034: val_loss did not improve from 0.14678
# Epoch 35/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.0405 - accuracy: 0.9862 - val_loss: 0.1685 - val_accuracy: 0.9600
# Epoch 00035: val_loss did not improve from 0.14678
# Epoch 36/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.1780 - val_accuracy: 0.9550
#
# Epoch 00036: val_loss did not improve from 0.14678
# Epoch 37/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0384 - accuracy: 0.9863 - val_loss: 0.1772 - val_accuracy: 0.9610
#
# Epoch 00037: val_loss did not improve from 0.14678
# Epoch 38/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0397 - accuracy: 0.9860 - val_loss: 0.1820 - val_accuracy: 0.9570
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00038: val_loss did not improve from 0.14678
# Epoch 39/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0338 - accuracy: 0.9886 - val_loss: 0.1969 - val_accuracy: 0.9510
#
# Epoch 00039: val_loss did not improve from 0.14678
# Epoch 40/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0337 - accuracy: 0.9879 - val_loss: 0.1827 - val_accuracy: 0.9600
#
# Epoch 00040: val_loss did not improve from 0.14678
# Score for fold 3: loss of 0.18271075189113617; accuracy of 95.99999785423279%
# Epoch 1/40
# 282/282 [==============================] - 49s 134ms/step - loss: 0.7733 - accuracy: 0.8493 - val_loss: 2670.8213 - val_accuracy: 0.0610
#
# Epoch 00001: val_loss did not improve from 0.14678
# Epoch 2/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.4820 - accuracy: 0.8682 - val_loss: 0.2865 - val_accuracy: 0.9110
#
# Epoch 00002: val_loss did not improve from 0.14678
# Epoch 3/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2866 - accuracy: 0.9086 - val_loss: 0.4231 - val_accuracy: 0.8440
#
# Epoch 00003: val_loss did not improve from 0.14678
# Epoch 4/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.6167 - accuracy: 0.8787 - val_loss: 23739.4688 - val_accuracy: 0.6300
#
# Epoch 00004: val_loss did not improve from 0.14678
# Epoch 5/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.3793 - accuracy: 0.9047 - val_loss: 0.2684 - val_accuracy: 0.9260
#
# Epoch 00005: val_loss did not improve from 0.14678
# Epoch 6/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2566 - accuracy: 0.9216 - val_loss: 0.2462 - val_accuracy: 0.9300
#
# Epoch 00006: val_loss did not improve from 0.14678
# Epoch 7/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2242 - accuracy: 0.9301 - val_loss: 0.2669 - val_accuracy: 0.9220
#
# Epoch 00007: val_loss did not improve from 0.14678
# Epoch 8/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2578 - accuracy: 0.9329 - val_loss: 0.2409 - val_accuracy: 0.9380
#
# Epoch 00008: val_loss did not improve from 0.14678
# Epoch 9/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2819 - accuracy: 0.9301 - val_loss: 20970.2227 - val_accuracy: 0.1290
#
# Epoch 00009: val_loss did not improve from 0.14678
# Epoch 10/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.3354 - accuracy: 0.9193 - val_loss: 1.1394 - val_accuracy: 0.7710
#
# Epoch 00010: val_loss did not improve from 0.14678
# Epoch 11/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1964 - accuracy: 0.9357 - val_loss: 0.5596 - val_accuracy: 0.8400
#
# Epoch 00011: val_loss did not improve from 0.14678
# Epoch 12/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1665 - accuracy: 0.9431 - val_loss: 0.2091 - val_accuracy: 0.9410
#
# Epoch 00012: val_loss did not improve from 0.14678
# Epoch 13/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1545 - accuracy: 0.9472 - val_loss: 0.2178 - val_accuracy: 0.9380
#
# Epoch 00013: val_loss did not improve from 0.14678
# Epoch 14/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1755 - accuracy: 0.9466 - val_loss: 0.9807 - val_accuracy: 0.8340
#
# Epoch 00014: val_loss did not improve from 0.14678
# Epoch 15/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2473 - accuracy: 0.9333 - val_loss: 0.2115 - val_accuracy: 0.9390
#
# Epoch 00015: val_loss did not improve from 0.14678
# Epoch 16/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.3254 - accuracy: 0.9283 - val_loss: 3.6366 - val_accuracy: 0.6880
#
# Epoch 00016: val_loss did not improve from 0.14678
# Epoch 17/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2766 - accuracy: 0.9162 - val_loss: 0.2685 - val_accuracy: 0.9240
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.14678
# Epoch 18/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1715 - accuracy: 0.9463 - val_loss: 0.2021 - val_accuracy: 0.9460
#
# Epoch 00018: val_loss did not improve from 0.14678
# Epoch 19/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1499 - accuracy: 0.9507 - val_loss: 0.1954 - val_accuracy: 0.9410
#
# Epoch 00019: val_loss did not improve from 0.14678
# Epoch 20/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1415 - accuracy: 0.9529 - val_loss: 0.2024 - val_accuracy: 0.9380
#
# Epoch 00020: val_loss did not improve from 0.14678
# Epoch 21/40
# 282/282 [==============================] - 33s 119ms/step - loss: 0.1345 - accuracy: 0.9559 - val_loss: 0.1825 - val_accuracy: 0.9520
#
# Epoch 00021: val_loss did not improve from 0.14678
# Epoch 22/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.1236 - accuracy: 0.9584 - val_loss: 0.1818 - val_accuracy: 0.9470
#
# Epoch 00022: val_loss did not improve from 0.14678
# Epoch 23/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1133 - accuracy: 0.9624 - val_loss: 0.1841 - val_accuracy: 0.9440
#
# Epoch 00023: val_loss did not improve from 0.14678
# Epoch 24/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1129 - accuracy: 0.9614 - val_loss: 0.2093 - val_accuracy: 0.9390
#
# Epoch 00024: val_loss did not improve from 0.14678
# Epoch 25/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1072 - accuracy: 0.9647 - val_loss: 0.1911 - val_accuracy: 0.9490
#
# Epoch 00025: val_loss did not improve from 0.14678
# Epoch 26/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1029 - accuracy: 0.9654 - val_loss: 0.2007 - val_accuracy: 0.9500
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00026: val_loss did not improve from 0.14678
# Epoch 27/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0836 - accuracy: 0.9721 - val_loss: 0.1810 - val_accuracy: 0.9500
#
# Epoch 00027: val_loss did not improve from 0.14678
# Epoch 28/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0796 - accuracy: 0.9723 - val_loss: 0.2111 - val_accuracy: 0.9470
#
# Epoch 00028: val_loss did not improve from 0.14678
# Epoch 29/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0798 - accuracy: 0.9728 - val_loss: 0.2019 - val_accuracy: 0.9520
#
# Epoch 00029: val_loss did not improve from 0.14678
# Epoch 30/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0740 - accuracy: 0.9753 - val_loss: 0.2048 - val_accuracy: 0.9490
#
# Epoch 00030: val_loss did not improve from 0.14678
# Epoch 31/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0757 - accuracy: 0.9729 - val_loss: 0.2015 - val_accuracy: 0.9510
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00031: val_loss did not improve from 0.14678
# Epoch 32/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0666 - accuracy: 0.9771 - val_loss: 0.2140 - val_accuracy: 0.9490
#
# Epoch 00032: val_loss did not improve from 0.14678
# Epoch 33/40
# 282/282 [==============================] - 35s 122ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.2162 - val_accuracy: 0.9560
#
# Epoch 00033: val_loss did not improve from 0.14678
# Epoch 34/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0609 - accuracy: 0.9797 - val_loss: 0.2333 - val_accuracy: 0.9480
#
# Epoch 00034: val_loss did not improve from 0.14678
# Epoch 35/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0589 - accuracy: 0.9801 - val_loss: 0.2216 - val_accuracy: 0.9530
#
# Epoch 00035: val_loss did not improve from 0.14678
# Epoch 36/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0577 - accuracy: 0.9812 - val_loss: 0.2351 - val_accuracy: 0.9500
#
# Epoch 00036: val_loss did not improve from 0.14678
# Epoch 37/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0588 - accuracy: 0.9799 - val_loss: 0.2408 - val_accuracy: 0.9480
#
# Epoch 00037: val_loss did not improve from 0.14678
# Epoch 38/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.0545 - accuracy: 0.9811 - val_loss: 0.2575 - val_accuracy: 0.9530
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00038: val_loss did not improve from 0.14678
# Epoch 39/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0536 - accuracy: 0.9818 - val_loss: 0.2372 - val_accuracy: 0.9510
#
# Epoch 00039: val_loss did not improve from 0.14678
# Epoch 40/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.0514 - accuracy: 0.9834 - val_loss: 0.2764 - val_accuracy: 0.9500
#
# Epoch 00040: val_loss did not improve from 0.14678
# Score for fold 4: loss of 0.2764442563056946; accuracy of 94.9999988079071%
# Epoch 1/40
# 282/282 [==============================] - 49s 134ms/step - loss: 0.6072 - accuracy: 0.8589 - val_loss: 59.4994 - val_accuracy: 0.8420
#
# Epoch 00001: val_loss did not improve from 0.14678
# Epoch 2/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.9952 - accuracy: 0.8687 - val_loss: 1564073.2500 - val_accuracy: 0.5280
#
# Epoch 00002: val_loss did not improve from 0.14678
# Epoch 3/40
# 282/282 [==============================] - 34s 121ms/step - loss: 1.0264 - accuracy: 0.8238 - val_loss: 656.5221 - val_accuracy: 0.2260
#
# Epoch 00003: val_loss did not improve from 0.14678
# Epoch 4/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.3754 - accuracy: 0.8884 - val_loss: 0.5266 - val_accuracy: 0.8770
#
# Epoch 00004: val_loss did not improve from 0.14678
# Epoch 5/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.3116 - accuracy: 0.9036 - val_loss: 0.2847 - val_accuracy: 0.9090
#
# Epoch 00005: val_loss did not improve from 0.14678
# Epoch 6/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.2997 - accuracy: 0.9080 - val_loss: 0.4128 - val_accuracy: 0.8880
#
# Epoch 00006: val_loss did not improve from 0.14678
# Epoch 7/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.2909 - accuracy: 0.9100 - val_loss: 0.2349 - val_accuracy: 0.9290
#
# Epoch 00007: val_loss did not improve from 0.14678
# Epoch 8/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.2539 - accuracy: 0.9223 - val_loss: 0.2221 - val_accuracy: 0.9350
#
# Epoch 00008: val_loss did not improve from 0.14678
# Epoch 9/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.2245 - accuracy: 0.9293 - val_loss: 0.2256 - val_accuracy: 0.9240
#
# Epoch 00009: val_loss did not improve from 0.14678
# Epoch 10/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.2081 - accuracy: 0.9318 - val_loss: 0.2148 - val_accuracy: 0.9300
#
# Epoch 00010: val_loss did not improve from 0.14678
# Epoch 11/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2080 - accuracy: 0.9329 - val_loss: 0.1782 - val_accuracy: 0.9350
#
# Epoch 00011: val_loss did not improve from 0.14678
# Epoch 12/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1874 - accuracy: 0.9373 - val_loss: 0.1928 - val_accuracy: 0.9360
#
# Epoch 00012: val_loss did not improve from 0.14678
# Epoch 13/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.1957 - accuracy: 0.9378 - val_loss: 7.4379 - val_accuracy: 0.5870
#
# Epoch 00013: val_loss did not improve from 0.14678
# Epoch 14/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1900 - accuracy: 0.9383 - val_loss: 0.3099 - val_accuracy: 0.9140
#
# Epoch 00014: val_loss did not improve from 0.14678
# Epoch 15/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1823 - accuracy: 0.9397 - val_loss: 0.1519 - val_accuracy: 0.9470
#
# Epoch 00015: val_loss did not improve from 0.14678
# Epoch 16/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1589 - accuracy: 0.9452 - val_loss: 0.1830 - val_accuracy: 0.9390
#
# Epoch 00016: val_loss did not improve from 0.14678
# Epoch 17/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1506 - accuracy: 0.9483 - val_loss: 0.1560 - val_accuracy: 0.9490
#
# Epoch 00017: val_loss did not improve from 0.14678
# Epoch 18/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.1435 - accuracy: 0.9512 - val_loss: 0.1709 - val_accuracy: 0.9400
#
# Epoch 00018: val_loss did not improve from 0.14678
# Epoch 19/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1368 - accuracy: 0.9531 - val_loss: 0.2011 - val_accuracy: 0.9430
#
# Epoch 00019: val_loss did not improve from 0.14678
# Epoch 20/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1464 - accuracy: 0.9501 - val_loss: 0.1521 - val_accuracy: 0.9490
#
# Epoch 00020: val_loss did not improve from 0.14678
# Epoch 21/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1388 - accuracy: 0.9533 - val_loss: 0.2014 - val_accuracy: 0.9310
#
# Epoch 00021: val_loss did not improve from 0.14678
# Epoch 22/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1744 - accuracy: 0.9456 - val_loss: 0.3813 - val_accuracy: 0.8440
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.14678
# Epoch 23/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1219 - accuracy: 0.9593 - val_loss: 0.1465 - val_accuracy: 0.9500
#
# Epoch 00023: val_loss improved from 0.14678 to 0.14648, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 24/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1366 - accuracy: 0.9549 - val_loss: 0.1191 - val_accuracy: 0.9570
#
# Epoch 00024: val_loss improved from 0.14648 to 0.11914, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet10000-local-v006\model.h5
# Epoch 25/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1228 - accuracy: 0.9612 - val_loss: 0.4694 - val_accuracy: 0.8850
#
# Epoch 00025: val_loss did not improve from 0.11914
# Epoch 26/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.1316 - accuracy: 0.9549 - val_loss: 0.1454 - val_accuracy: 0.9520
#
# Epoch 00026: val_loss did not improve from 0.11914
# Epoch 27/40
# 282/282 [==============================] - 34s 119ms/step - loss: 0.0998 - accuracy: 0.9662 - val_loss: 0.1554 - val_accuracy: 0.9500
#
# Epoch 00027: val_loss did not improve from 0.11914
# Epoch 28/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1066 - accuracy: 0.9642 - val_loss: 0.1279 - val_accuracy: 0.9530
#
# Epoch 00028: val_loss did not improve from 0.11914
# Epoch 29/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0929 - accuracy: 0.9693 - val_loss: 0.1302 - val_accuracy: 0.9590
#
# Epoch 00029: val_loss did not improve from 0.11914
# Epoch 30/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0881 - accuracy: 0.9707 - val_loss: 0.1511 - val_accuracy: 0.9530
#
# Epoch 00030: val_loss did not improve from 0.11914
# Epoch 31/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0886 - accuracy: 0.9704 - val_loss: 0.1448 - val_accuracy: 0.9550
#
# Epoch 00031: val_loss did not improve from 0.11914
# Epoch 32/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.0908 - accuracy: 0.9688 - val_loss: 0.3325 - val_accuracy: 0.8730
#
# Epoch 00032: val_loss did not improve from 0.11914
# Epoch 33/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0997 - accuracy: 0.9668 - val_loss: 0.1636 - val_accuracy: 0.9510
#
# Epoch 00033: val_loss did not improve from 0.11914
# Epoch 34/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0868 - accuracy: 0.9706 - val_loss: 0.1433 - val_accuracy: 0.9540
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.11914
# Epoch 35/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.0689 - accuracy: 0.9762 - val_loss: 0.1449 - val_accuracy: 0.9610
#
# Epoch 00035: val_loss did not improve from 0.11914
# Epoch 36/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0598 - accuracy: 0.9807 - val_loss: 0.1319 - val_accuracy: 0.9620
#
# Epoch 00036: val_loss did not improve from 0.11914
# Epoch 37/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0602 - accuracy: 0.9798 - val_loss: 0.1385 - val_accuracy: 0.9580
#
# Epoch 00037: val_loss did not improve from 0.11914
# Epoch 38/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0589 - accuracy: 0.9794 - val_loss: 0.1291 - val_accuracy: 0.9620
#
# Epoch 00038: val_loss did not improve from 0.11914
# Epoch 39/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0574 - accuracy: 0.9807 - val_loss: 0.1753 - val_accuracy: 0.9570
#
# Epoch 00039: val_loss did not improve from 0.11914
# Epoch 40/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0571 - accuracy: 0.9802 - val_loss: 0.1399 - val_accuracy: 0.9610
#
# Epoch 00040: val_loss did not improve from 0.11914
# Score for fold 5: loss of 0.13991107046604156; accuracy of 96.10000252723694%
# Epoch 1/40
# 282/282 [==============================] - 50s 134ms/step - loss: 0.4672 - accuracy: 0.8791 - val_loss: 0.4781 - val_accuracy: 0.8690
#
# Epoch 00001: val_loss did not improve from 0.11914
# Epoch 2/40
# 282/282 [==============================] - 37s 130ms/step - loss: 0.2369 - accuracy: 0.9257 - val_loss: 0.2125 - val_accuracy: 0.9310
#
# Epoch 00002: val_loss did not improve from 0.11914
# Epoch 3/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.6816 - accuracy: 0.8578 - val_loss: 0.5358 - val_accuracy: 0.8090
#
# Epoch 00003: val_loss did not improve from 0.11914
# Epoch 4/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.2949 - accuracy: 0.9077 - val_loss: 0.2987 - val_accuracy: 0.9130
#
# Epoch 00004: val_loss did not improve from 0.11914
# Epoch 5/40
# 282/282 [==============================] - 36s 129ms/step - loss: 0.2457 - accuracy: 0.9208 - val_loss: 0.3011 - val_accuracy: 0.9040
#
# Epoch 00005: val_loss did not improve from 0.11914
# Epoch 6/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.2394 - accuracy: 0.9266 - val_loss: 1.0770 - val_accuracy: 0.8500
#
# Epoch 00006: val_loss did not improve from 0.11914
# Epoch 7/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.2197 - accuracy: 0.9291 - val_loss: 0.2414 - val_accuracy: 0.9300
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.11914
# Epoch 8/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.1791 - accuracy: 0.9410 - val_loss: 0.2118 - val_accuracy: 0.9280
#
# Epoch 00008: val_loss did not improve from 0.11914
# Epoch 9/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.1594 - accuracy: 0.9466 - val_loss: 0.2503 - val_accuracy: 0.8980
#
# Epoch 00009: val_loss did not improve from 0.11914
# Epoch 10/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1542 - accuracy: 0.9487 - val_loss: 0.1966 - val_accuracy: 0.9290
#
# Epoch 00010: val_loss did not improve from 0.11914
# Epoch 11/40
# 282/282 [==============================] - 37s 130ms/step - loss: 0.1404 - accuracy: 0.9523 - val_loss: 0.2073 - val_accuracy: 0.9300
#
# Epoch 00011: val_loss did not improve from 0.11914
# Epoch 12/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.1348 - accuracy: 0.9544 - val_loss: 0.1918 - val_accuracy: 0.9300
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00012: val_loss did not improve from 0.11914
# Epoch 13/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.1120 - accuracy: 0.9614 - val_loss: 0.1686 - val_accuracy: 0.9390
#
# Epoch 00013: val_loss did not improve from 0.11914
# Epoch 14/40
# 282/282 [==============================] - 35s 122ms/step - loss: 0.1058 - accuracy: 0.9659 - val_loss: 0.1830 - val_accuracy: 0.9390
#
# Epoch 00014: val_loss did not improve from 0.11914
# Epoch 15/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.1163 - accuracy: 0.9608 - val_loss: 0.2020 - val_accuracy: 0.9330
#
# Epoch 00015: val_loss did not improve from 0.11914
# Epoch 16/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0996 - accuracy: 0.9670 - val_loss: 0.2091 - val_accuracy: 0.9390
#
# Epoch 00016: val_loss did not improve from 0.11914
# Epoch 17/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0954 - accuracy: 0.9691 - val_loss: 0.1968 - val_accuracy: 0.9370
#
# Epoch 00017: val_loss did not improve from 0.11914
# Epoch 18/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0888 - accuracy: 0.9704 - val_loss: 0.2011 - val_accuracy: 0.9330
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00018: val_loss did not improve from 0.11914
# Epoch 19/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0755 - accuracy: 0.9756 - val_loss: 0.1888 - val_accuracy: 0.9410
#
# Epoch 00019: val_loss did not improve from 0.11914
# Epoch 20/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0686 - accuracy: 0.9773 - val_loss: 0.2014 - val_accuracy: 0.9460
#
# Epoch 00020: val_loss did not improve from 0.11914
# Epoch 21/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0733 - accuracy: 0.9747 - val_loss: 0.1775 - val_accuracy: 0.9410
#
# Epoch 00021: val_loss did not improve from 0.11914
# Epoch 22/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.0717 - accuracy: 0.9761 - val_loss: 0.1883 - val_accuracy: 0.9460
#
# Epoch 00022: val_loss did not improve from 0.11914
# Epoch 23/40
# 282/282 [==============================] - 38s 134ms/step - loss: 0.0643 - accuracy: 0.9782 - val_loss: 0.1931 - val_accuracy: 0.9430
#
# Epoch 00023: val_loss did not improve from 0.11914
# Epoch 24/40
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0672 - accuracy: 0.9771 - val_loss: 0.1926 - val_accuracy: 0.9460
#
# Epoch 00024: val_loss did not improve from 0.11914
# Epoch 25/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0590 - accuracy: 0.9803 - val_loss: 0.2135 - val_accuracy: 0.9430
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00025: val_loss did not improve from 0.11914
# Epoch 26/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0546 - accuracy: 0.9814 - val_loss: 0.2211 - val_accuracy: 0.9430
#
# Epoch 00026: val_loss did not improve from 0.11914
# Epoch 27/40
# ...
#
# Epoch 00003: val_loss did not improve from 0.11914
# Epoch 4/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1841 - accuracy: 0.9403 - val_loss: 0.1829 - val_accuracy: 0.9420
#
# Epoch 00004: val_loss did not improve from 0.11914
# Epoch 5/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1498 - accuracy: 0.9507 - val_loss: 0.2103 - val_accuracy: 0.9410
#
# Epoch 00005: val_loss did not improve from 0.11914
# Epoch 6/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1546 - accuracy: 0.9496 - val_loss: 4875.7563 - val_accuracy: 0.6370
#
# Epoch 00006: val_loss did not improve from 0.11914
# Epoch 7/40
# 282/282 [==============================] - 36s 126ms/step - loss: 1.3166 - accuracy: 0.7081 - val_loss: 0.5585 - val_accuracy: 0.8320
#
# Epoch 00007: val_loss did not improve from 0.11914
# Epoch 8/40
# 282/282 [==============================] - 36s 128ms/step - loss: 0.4422 - accuracy: 0.8597 - val_loss: 0.3152 - val_accuracy: 0.9030
#
# Epoch 00008: val_loss did not improve from 0.11914
# Epoch 9/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.3587 - accuracy: 0.8871 - val_loss: 0.9114 - val_accuracy: 0.7290
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.11914
# Epoch 10/40
# 282/282 [==============================] - 36s 128ms/step - loss: 0.3387 - accuracy: 0.8964 - val_loss: 0.2627 - val_accuracy: 0.9140
#
# Epoch 00010: val_loss did not improve from 0.11914
# Epoch 11/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.2871 - accuracy: 0.9042 - val_loss: 0.2459 - val_accuracy: 0.9140
#
# Epoch 00011: val_loss did not improve from 0.11914
# Epoch 12/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.2632 - accuracy: 0.9150 - val_loss: 0.2365 - val_accuracy: 0.9190
#
# Epoch 00012: val_loss did not improve from 0.11914
# Epoch 13/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2536 - accuracy: 0.9178 - val_loss: 0.2141 - val_accuracy: 0.9350
#
# Epoch 00013: val_loss did not improve from 0.11914
# Epoch 14/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2436 - accuracy: 0.9178 - val_loss: 0.2368 - val_accuracy: 0.9210
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00014: val_loss did not improve from 0.11914
# Epoch 15/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2376 - accuracy: 0.9193 - val_loss: 0.1968 - val_accuracy: 0.9370
#
# Epoch 00015: val_loss did not improve from 0.11914
# Epoch 16/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2156 - accuracy: 0.9296 - val_loss: 0.1989 - val_accuracy: 0.9290
#
# Epoch 00016: val_loss did not improve from 0.11914
# Epoch 17/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2071 - accuracy: 0.9314 - val_loss: 0.1878 - val_accuracy: 0.9340
#
# Epoch 00017: val_loss did not improve from 0.11914
# Epoch 18/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1973 - accuracy: 0.9332 - val_loss: 0.1809 - val_accuracy: 0.9430
#
# Epoch 00018: val_loss did not improve from 0.11914
# Epoch 19/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1987 - accuracy: 0.9316 - val_loss: 0.1930 - val_accuracy: 0.9330
#
# Epoch 00019: val_loss did not improve from 0.11914
# Epoch 20/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1938 - accuracy: 0.9360 - val_loss: 0.2102 - val_accuracy: 0.9310
#
# Epoch 00020: val_loss did not improve from 0.11914
# Epoch 21/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1811 - accuracy: 0.9396 - val_loss: 0.1831 - val_accuracy: 0.9340
#
# Epoch 00021: val_loss did not improve from 0.11914
# Epoch 22/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1734 - accuracy: 0.9421 - val_loss: 0.1792 - val_accuracy: 0.9420
#
# Epoch 00022: val_loss did not improve from 0.11914
# Epoch 23/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1728 - accuracy: 0.9427 - val_loss: 0.1797 - val_accuracy: 0.9380
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00023: val_loss did not improve from 0.11914
# Epoch 24/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1572 - accuracy: 0.9482 - val_loss: 0.1727 - val_accuracy: 0.9420
#
# Epoch 00024: val_loss did not improve from 0.11914
# Epoch 25/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1532 - accuracy: 0.9478 - val_loss: 0.1698 - val_accuracy: 0.9440
#
# Epoch 00025: val_loss did not improve from 0.11914
# Epoch 26/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1445 - accuracy: 0.9504 - val_loss: 0.1691 - val_accuracy: 0.9470
#
# Epoch 00026: val_loss did not improve from 0.11914
# Epoch 27/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1416 - accuracy: 0.9517 - val_loss: 0.1617 - val_accuracy: 0.9480
#
# Epoch 00027: val_loss did not improve from 0.11914
# Epoch 28/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1437 - accuracy: 0.9519 - val_loss: 0.1770 - val_accuracy: 0.9470
#
# Epoch 00028: val_loss did not improve from 0.11914
# Epoch 29/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1378 - accuracy: 0.9537 - val_loss: 0.1689 - val_accuracy: 0.9450
#
# Epoch 00029: val_loss did not improve from 0.11914
# Epoch 30/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1332 - accuracy: 0.9549 - val_loss: 0.1770 - val_accuracy: 0.9420
#
# Epoch 00030: val_loss did not improve from 0.11914
# Epoch 31/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1313 - accuracy: 0.9563 - val_loss: 0.1725 - val_accuracy: 0.9450
#
# Epoch 00031: val_loss did not improve from 0.11914
# Epoch 32/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1334 - accuracy: 0.9539 - val_loss: 0.1738 - val_accuracy: 0.9470
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.11914
# Epoch 33/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1212 - accuracy: 0.9601 - val_loss: 0.1705 - val_accuracy: 0.9440
#
# Epoch 00033: val_loss did not improve from 0.11914
# Epoch 34/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1168 - accuracy: 0.9614 - val_loss: 0.1827 - val_accuracy: 0.9450
#
# Epoch 00034: val_loss did not improve from 0.11914
# Epoch 35/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1161 - accuracy: 0.9609 - val_loss: 0.1691 - val_accuracy: 0.9460
#
# Epoch 00035: val_loss did not improve from 0.11914
# Epoch 36/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1095 - accuracy: 0.9638 - val_loss: 0.1661 - val_accuracy: 0.9470
#
# Epoch 00036: val_loss did not improve from 0.11914
# Epoch 37/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1120 - accuracy: 0.9619 - val_loss: 0.1683 - val_accuracy: 0.9510
#
# Epoch 00037: val_loss did not improve from 0.11914
# Epoch 38/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1052 - accuracy: 0.9650 - val_loss: 0.1610 - val_accuracy: 0.9520
#
# Epoch 00038: val_loss did not improve from 0.11914
# Epoch 39/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1035 - accuracy: 0.9657 - val_loss: 0.1721 - val_accuracy: 0.9510
#
# Epoch 00039: val_loss did not improve from 0.11914
# Epoch 40/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1045 - accuracy: 0.9647 - val_loss: 0.1894 - val_accuracy: 0.9390
#
# Epoch 00040: val_loss did not improve from 0.11914
# Score for fold 9: loss of 0.1893693208694458; accuracy of 93.90000104904175%
# Epoch 1/40
# 282/282 [==============================] - 51s 129ms/step - loss: 1.3152 - accuracy: 0.7801 - val_loss: 52.6786 - val_accuracy: 0.6260
#
# Epoch 00001: val_loss did not improve from 0.11914
# Epoch 2/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.4647 - accuracy: 0.8633 - val_loss: 0.3238 - val_accuracy: 0.9120
#
# Epoch 00002: val_loss did not improve from 0.11914
# Epoch 3/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.3287 - accuracy: 0.8972 - val_loss: 0.2367 - val_accuracy: 0.9290
#
# Epoch 00003: val_loss did not improve from 0.11914
# Epoch 4/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.2847 - accuracy: 0.9049 - val_loss: 0.2132 - val_accuracy: 0.9330
#
# Epoch 00004: val_loss did not improve from 0.11914
# Epoch 5/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2530 - accuracy: 0.9174 - val_loss: 0.2836 - val_accuracy: 0.9220
#
# Epoch 00005: val_loss did not improve from 0.11914
# Epoch 6/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2318 - accuracy: 0.9218 - val_loss: 0.1801 - val_accuracy: 0.9450
#
# Epoch 00006: val_loss did not improve from 0.11914
# Epoch 7/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.2118 - accuracy: 0.9293 - val_loss: 0.3049 - val_accuracy: 0.9540
#
# Epoch 00007: val_loss did not improve from 0.11914
# Epoch 8/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1922 - accuracy: 0.9371 - val_loss: 0.4170 - val_accuracy: 0.9570
#
# Epoch 00008: val_loss did not improve from 0.11914
# Epoch 9/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.2799 - accuracy: 0.9194 - val_loss: 0.4180 - val_accuracy: 0.9470
#
# Epoch 00009: val_loss did not improve from 0.11914
# Epoch 10/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.2031 - accuracy: 0.9320 - val_loss: 0.1573 - val_accuracy: 0.9550
#
# Epoch 00010: val_loss did not improve from 0.11914
# Epoch 11/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1840 - accuracy: 0.9378 - val_loss: 0.1547 - val_accuracy: 0.9500
#
# Epoch 00011: val_loss did not improve from 0.11914
# Epoch 12/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2683 - accuracy: 0.9229 - val_loss: 237.7411 - val_accuracy: 0.5290
#
# Epoch 00012: val_loss did not improve from 0.11914
# Epoch 13/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.2278 - accuracy: 0.9257 - val_loss: 0.1707 - val_accuracy: 0.9450
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.11914
# Epoch 14/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1713 - accuracy: 0.9430 - val_loss: 0.1646 - val_accuracy: 0.9540
#
# Epoch 00014: val_loss did not improve from 0.11914
# Epoch 15/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1558 - accuracy: 0.9478 - val_loss: 0.1463 - val_accuracy: 0.9570
#
# Epoch 00015: val_loss did not improve from 0.11914
# Epoch 16/40
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1478 - accuracy: 0.9489 - val_loss: 0.1385 - val_accuracy: 0.9600
#
# Epoch 00016: val_loss did not improve from 0.11914
# Epoch 17/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1437 - accuracy: 0.9517 - val_loss: 0.1555 - val_accuracy: 0.9530
#
# Epoch 00017: val_loss did not improve from 0.11914
# Epoch 18/40
# 282/282 [==============================] - 35s 125ms/step - loss: 0.1388 - accuracy: 0.9529 - val_loss: 0.1536 - val_accuracy: 0.9560
#
# Epoch 00018: val_loss did not improve from 0.11914
# Epoch 19/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1235 - accuracy: 0.9582 - val_loss: 0.1494 - val_accuracy: 0.9530
#
# Epoch 00019: val_loss did not improve from 0.11914
# Epoch 20/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.1198 - accuracy: 0.9577 - val_loss: 0.1610 - val_accuracy: 0.9500
#
# Epoch 00020: val_loss did not improve from 0.11914
# Epoch 21/40
# 282/282 [==============================] - 34s 121ms/step - loss: 0.1177 - accuracy: 0.9586 - val_loss: 0.1517 - val_accuracy: 0.9570
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.11914
# Epoch 22/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0929 - accuracy: 0.9680 - val_loss: 0.1334 - val_accuracy: 0.9610
#
# Epoch 00022: val_loss did not improve from 0.11914
# Epoch 23/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0874 - accuracy: 0.9699 - val_loss: 0.1398 - val_accuracy: 0.9590
#
# Epoch 00023: val_loss did not improve from 0.11914
# Epoch 24/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0848 - accuracy: 0.9719 - val_loss: 0.1443 - val_accuracy: 0.9610
#
# Epoch 00024: val_loss did not improve from 0.11914
# Epoch 25/40
# 282/282 [==============================] - 37s 131ms/step - loss: 0.0821 - accuracy: 0.9713 - val_loss: 0.1240 - val_accuracy: 0.9630
#
# Epoch 00025: val_loss did not improve from 0.11914
# Epoch 26/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0807 - accuracy: 0.9724 - val_loss: 0.1550 - val_accuracy: 0.9510
#
# Epoch 00026: val_loss did not improve from 0.11914
# Epoch 27/40
# 282/282 [==============================] - 35s 122ms/step - loss: 0.1413 - accuracy: 0.9549 - val_loss: 0.1345 - val_accuracy: 0.9630
#
# Epoch 00027: val_loss did not improve from 0.11914
# Epoch 28/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0915 - accuracy: 0.9697 - val_loss: 0.1235 - val_accuracy: 0.9600
#
# Epoch 00028: val_loss did not improve from 0.11914
# Epoch 29/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0792 - accuracy: 0.9724 - val_loss: 0.1647 - val_accuracy: 0.9550
#
# Epoch 00029: val_loss did not improve from 0.11914
# Epoch 30/40
# 282/282 [==============================] - 36s 126ms/step - loss: 0.0735 - accuracy: 0.9748 - val_loss: 0.1338 - val_accuracy: 0.9650
#
# Epoch 00030: val_loss did not improve from 0.11914
# Epoch 31/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0673 - accuracy: 0.9771 - val_loss: 0.1989 - val_accuracy: 0.9550
#
# Epoch 00031: val_loss did not improve from 0.11914
# Epoch 32/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0732 - accuracy: 0.9747 - val_loss: 0.1445 - val_accuracy: 0.9680
#
# Epoch 00032: val_loss did not improve from 0.11914
# Epoch 33/40
# 282/282 [==============================] - 35s 122ms/step - loss: 0.0643 - accuracy: 0.9784 - val_loss: 0.1504 - val_accuracy: 0.9600
#
# Epoch 00033: val_loss did not improve from 0.11914
# Epoch 34/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0628 - accuracy: 0.9786 - val_loss: 0.1738 - val_accuracy: 0.9520
#
# Epoch 00034: val_loss did not improve from 0.11914
# Epoch 35/40
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0640 - accuracy: 0.9784 - val_loss: 0.2172 - val_accuracy: 0.9470
#
# Epoch 00035: val_loss did not improve from 0.11914
# Epoch 36/40
# 282/282 [==============================] - 35s 123ms/step - loss: 0.0645 - accuracy: 0.9776 - val_loss: 0.1571 - val_accuracy: 0.9620
#
# Epoch 00036: val_loss did not improve from 0.11914
# Epoch 37/40
# 282/282 [==============================] - 35s 126ms/step - loss: 0.0572 - accuracy: 0.9810 - val_loss: 0.1479 - val_accuracy: 0.9660
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00037: val_loss did not improve from 0.11914
# Epoch 38/40
# 282/282 [==============================] - 35s 124ms/step - loss: 0.0531 - accuracy: 0.9814 - val_loss: 0.1485 - val_accuracy: 0.9660
#
# Epoch 00038: val_loss did not improve from 0.11914
# Epoch 39/40
# 282/282 [==============================] - 35s 122ms/step - loss: 0.0482 - accuracy: 0.9828 - val_loss: 0.1407 - val_accuracy: 0.9660
#
# Epoch 00039: val_loss did not improve from 0.11914
# Epoch 40/40
# 282/282 [==============================] - 34s 122ms/step - loss: 0.0449 - accuracy: 0.9843 - val_loss: 0.1396 - val_accuracy: 0.9680
#
# Epoch 00040: val_loss did not improve from 0.11914
# Score for fold 10: loss of 0.13961754739284515; accuracy of 96.79999947547913%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 20.291828155517578 - Accuracy: 93.80000233650208%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.20160551369190216 - Accuracy: 95.20000219345093%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.18271075189113617 - Accuracy: 95.99999785423279%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.2764442563056946 - Accuracy: 94.9999988079071%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.13991107046604156 - Accuracy: 96.10000252723694%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.23546534776687622 - Accuracy: 94.0999984741211%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.16989821195602417 - Accuracy: 94.49999928474426%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.18367689847946167 - Accuracy: 94.9999988079071%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.1893693208694458 - Accuracy: 93.90000104904175%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.13961754739284515 - Accuracy: 96.79999947547913%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.04000008106232% (+- 0.009583316617440649)
# > Loss: 2.2010527074337007
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of DenseNet169"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of DenseNet169      |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9504      | 0.0096       |
# | Loss     | 2.2011      | 6.0304       |
# | Macro F1 | 0.8647      | 0.0202       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9817      | 0.0098       |
# | Acc      | 0.9858      | 0.0051       |
# | F1       | 0.9865      | 0.0049       |
# | MCC      | 0.9716      | 0.0101       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for DenseNet169 across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - DenseNet169")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
