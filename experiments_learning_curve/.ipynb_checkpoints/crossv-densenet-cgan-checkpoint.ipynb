# %% [markdown]
# # CGAN-DenseNet

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 150000

# Number of epochs
epoch_t = 35

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/experiments_learning_curve"
    for files in os.listdir(dir):
        if "cgan-densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-cgan-densenet-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# No matches found
# New folder name: crossv-cgan-densenet-local-v001
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/"
    path_root_gen = '/kaggle/input/cganlocalv007/'

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/lc_original"
    path_root_gen = "C:/Users/Max/Documents/image_data/cgan-lc-ckpt"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 1000 images belonging to 11 classes.

# %% [markdown]
# Load CGAN generated images

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 1602 images belonging to 10 classes.

# %% [markdown]
# Original images

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %% [markdown]
# Generated images

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs_gen, titles = labels_gen)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # CGAN - DenseNet169
# We will now build our **DenseNet169** model using Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3
#
# Nota bene that the DenseNet only takes RGB images (with 3 channels)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # DenseNet169
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    # Run the CNN
    history.append(
        head_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    
    
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 79/79 [==============================] - 31s 174ms/step - loss: 1.0160 - accuracy: 0.8681 - val_loss: 3299.0671 - val_accuracy: 0.1200
#
# Epoch 00001: val_loss improved from inf to 3299.06714, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 2/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.7595 - accuracy: 0.8965 - val_loss: 851.7175 - val_accuracy: 0.3000
#
# Epoch 00002: val_loss improved from 3299.06714 to 851.71753, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 3/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.6683 - accuracy: 0.9297 - val_loss: 59.7299 - val_accuracy: 0.3300
#
# Epoch 00003: val_loss improved from 851.71753 to 59.72993, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 4/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.2016 - accuracy: 0.9540 - val_loss: 2.7875 - val_accuracy: 0.8600
#
# Epoch 00004: val_loss improved from 59.72993 to 2.78746, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 5/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1707 - accuracy: 0.9616 - val_loss: 0.4414 - val_accuracy: 0.9100
#
# Epoch 00005: val_loss improved from 2.78746 to 0.44140, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 6/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.1204 - accuracy: 0.9656 - val_loss: 0.3343 - val_accuracy: 0.8900
#
# Epoch 00006: val_loss improved from 0.44140 to 0.33427, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 7/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1295 - accuracy: 0.9664 - val_loss: 1.1721 - val_accuracy: 0.7200
#
# Epoch 00007: val_loss did not improve from 0.33427
# Epoch 8/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1890 - accuracy: 0.9524 - val_loss: 2.7952 - val_accuracy: 0.6000
#
# Epoch 00008: val_loss did not improve from 0.33427
# Epoch 9/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.6885 - accuracy: 0.8857 - val_loss: 10.6826 - val_accuracy: 0.5000
#
# Epoch 00009: val_loss did not improve from 0.33427
# Epoch 10/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1809 - accuracy: 0.9516 - val_loss: 0.3645 - val_accuracy: 0.9400
#
# Epoch 00010: val_loss did not improve from 0.33427
# Epoch 11/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1490 - accuracy: 0.9644 - val_loss: 0.1894 - val_accuracy: 0.9400
#
# Epoch 00011: val_loss improved from 0.33427 to 0.18940, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 12/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.1852 - accuracy: 0.9592 - val_loss: 0.3018 - val_accuracy: 0.9200
#
# Epoch 00012: val_loss did not improve from 0.18940
# Epoch 13/35
# 79/79 [==============================] - 10s 120ms/step - loss: 0.1011 - accuracy: 0.9704 - val_loss: 0.3088 - val_accuracy: 0.9000
#
# Epoch 00013: val_loss did not improve from 0.18940
# Epoch 14/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.2292 - accuracy: 0.9480 - val_loss: 45.9303 - val_accuracy: 0.8700
#
# Epoch 00014: val_loss did not improve from 0.18940
# Epoch 15/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.1943 - accuracy: 0.9608 - val_loss: 5.4234 - val_accuracy: 0.8600
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.18940
# Epoch 16/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.1631 - accuracy: 0.9604 - val_loss: 0.2464 - val_accuracy: 0.8900
#
# Epoch 00016: val_loss did not improve from 0.18940
# Epoch 17/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0994 - accuracy: 0.9684 - val_loss: 0.2155 - val_accuracy: 0.8900
#
# Epoch 00017: val_loss did not improve from 0.18940
# Epoch 18/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1176 - accuracy: 0.9708 - val_loss: 0.1890 - val_accuracy: 0.9200
#
# Epoch 00018: val_loss improved from 0.18940 to 0.18905, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 19/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0889 - accuracy: 0.9720 - val_loss: 0.1765 - val_accuracy: 0.9300
#
# Epoch 00019: val_loss improved from 0.18905 to 0.17654, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 20/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0732 - accuracy: 0.9740 - val_loss: 0.1649 - val_accuracy: 0.9300
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss improved from 0.17654 to 0.16488, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 21/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.1588 - val_accuracy: 0.9400
#
# Epoch 00021: val_loss improved from 0.16488 to 0.15884, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 22/35
# 79/79 [==============================] - 10s 127ms/step - loss: 0.0567 - accuracy: 0.9808 - val_loss: 0.1797 - val_accuracy: 0.9400
#
# Epoch 00022: val_loss did not improve from 0.15884
# Epoch 23/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.0546 - accuracy: 0.9800 - val_loss: 0.1610 - val_accuracy: 0.9400
#
# Epoch 00023: val_loss did not improve from 0.15884
# Epoch 24/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0527 - accuracy: 0.9812 - val_loss: 0.1543 - val_accuracy: 0.9600
#
# Epoch 00024: val_loss improved from 0.15884 to 0.15426, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 25/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0430 - accuracy: 0.9864 - val_loss: 0.1571 - val_accuracy: 0.9300
#
# Epoch 00025: val_loss did not improve from 0.15426
# Epoch 26/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0438 - accuracy: 0.9828 - val_loss: 0.1709 - val_accuracy: 0.9500
#
# Epoch 00026: val_loss did not improve from 0.15426
# Epoch 27/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0435 - accuracy: 0.9840 - val_loss: 0.2544 - val_accuracy: 0.9300
#
# Epoch 00027: val_loss did not improve from 0.15426
# Epoch 28/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0388 - accuracy: 0.9876 - val_loss: 0.1974 - val_accuracy: 0.9500
#
# Epoch 00028: val_loss did not improve from 0.15426
# Epoch 29/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0374 - accuracy: 0.9852 - val_loss: 0.1895 - val_accuracy: 0.9400
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.15426
# Epoch 30/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0328 - accuracy: 0.9888 - val_loss: 0.1609 - val_accuracy: 0.9600
#
# Epoch 00030: val_loss did not improve from 0.15426
# Epoch 31/35
# 79/79 [==============================] - 10s 123ms/step - loss: 0.0316 - accuracy: 0.9884 - val_loss: 0.1700 - val_accuracy: 0.9600
#
# Epoch 00031: val_loss did not improve from 0.15426
# Epoch 32/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.0272 - accuracy: 0.9920 - val_loss: 0.1830 - val_accuracy: 0.9600
#
# Epoch 00032: val_loss did not improve from 0.15426
# Epoch 33/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0276 - accuracy: 0.9904 - val_loss: 0.1957 - val_accuracy: 0.9500
#
# Epoch 00033: val_loss did not improve from 0.15426
# Epoch 34/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0249 - accuracy: 0.9928 - val_loss: 0.1879 - val_accuracy: 0.9500
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.1842 - val_accuracy: 0.9300
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 1: loss of 0.18418535590171814; accuracy of 93.00000071525574%
# Epoch 1/35
# 79/79 [==============================] - 26s 155ms/step - loss: 0.8919 - accuracy: 0.8557 - val_loss: 222.2592 - val_accuracy: 0.0400
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.7892 - accuracy: 0.8853 - val_loss: 9.1752 - val_accuracy: 0.2900
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.2626 - accuracy: 0.9416 - val_loss: 1.0866 - val_accuracy: 0.7600
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1696 - accuracy: 0.9560 - val_loss: 1.8633 - val_accuracy: 0.6200
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1377 - accuracy: 0.9624 - val_loss: 0.3999 - val_accuracy: 0.8700
#
# Epoch 00005: val_loss did not improve from 0.15426
# Epoch 6/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2962 - accuracy: 0.9468 - val_loss: 140.3775 - val_accuracy: 0.4500
#
# Epoch 00006: val_loss did not improve from 0.15426
# Epoch 7/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1882 - accuracy: 0.9504 - val_loss: 0.6547 - val_accuracy: 0.8400
#
# Epoch 00007: val_loss did not improve from 0.15426
# Epoch 8/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1530 - accuracy: 0.9576 - val_loss: 1.0151 - val_accuracy: 0.8300
#
# Epoch 00008: val_loss did not improve from 0.15426
# Epoch 9/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.3615 - accuracy: 0.9444 - val_loss: 1.4504 - val_accuracy: 0.7200
#
# Epoch 00009: val_loss did not improve from 0.15426
# Epoch 10/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1565 - accuracy: 0.9600 - val_loss: 0.3708 - val_accuracy: 0.9000
#
# Epoch 00010: val_loss did not improve from 0.15426
# Epoch 11/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1041 - accuracy: 0.9672 - val_loss: 0.4929 - val_accuracy: 0.9000
#
# Epoch 00011: val_loss did not improve from 0.15426
# Epoch 12/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.1265 - accuracy: 0.9648 - val_loss: 0.3747 - val_accuracy: 0.9200
#
# Epoch 00012: val_loss did not improve from 0.15426
# Epoch 13/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.1040 - accuracy: 0.9720 - val_loss: 0.3215 - val_accuracy: 0.9000
#
# Epoch 00013: val_loss did not improve from 0.15426
# Epoch 14/35
# 79/79 [==============================] - 10s 127ms/step - loss: 0.0891 - accuracy: 0.9756 - val_loss: 0.3267 - val_accuracy: 0.9000
#
# Epoch 00014: val_loss did not improve from 0.15426
# Epoch 15/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0793 - accuracy: 0.9788 - val_loss: 0.2846 - val_accuracy: 0.9000
#
# Epoch 00015: val_loss did not improve from 0.15426
# Epoch 16/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.0724 - accuracy: 0.9784 - val_loss: 0.3256 - val_accuracy: 0.9100
#
# Epoch 00016: val_loss did not improve from 0.15426
# Epoch 17/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0582 - accuracy: 0.9784 - val_loss: 0.3347 - val_accuracy: 0.9100
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_loss did not improve from 0.15426
# Epoch 18/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 0.3511 - val_accuracy: 0.9000
#
# Epoch 00018: val_loss did not improve from 0.15426
# Epoch 19/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0380 - accuracy: 0.9868 - val_loss: 0.3254 - val_accuracy: 0.9100
#
# Epoch 00019: val_loss did not improve from 0.15426
# Epoch 20/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.0323 - accuracy: 0.9884 - val_loss: 0.3411 - val_accuracy: 0.9000
#
# Epoch 00020: val_loss did not improve from 0.15426
# Epoch 21/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0432 - accuracy: 0.9888 - val_loss: 0.4150 - val_accuracy: 0.8700
#
# Epoch 00021: val_loss did not improve from 0.15426
# Epoch 22/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0792 - accuracy: 0.9848 - val_loss: 0.3614 - val_accuracy: 0.9000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.15426
# Epoch 23/35
# 79/79 [==============================] - 10s 123ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.3632 - val_accuracy: 0.9200
#
# Epoch 00023: val_loss did not improve from 0.15426
# Epoch 24/35
# 79/79 [==============================] - 10s 131ms/step - loss: 0.0661 - accuracy: 0.9916 - val_loss: 0.5131 - val_accuracy: 0.8100
#
# Epoch 00024: val_loss did not improve from 0.15426
# Epoch 25/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.0254 - accuracy: 0.9928 - val_loss: 0.3698 - val_accuracy: 0.9000
#
# Epoch 00025: val_loss did not improve from 0.15426
# Epoch 26/35
# 79/79 [==============================] - 10s 123ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.4358 - val_accuracy: 0.9200
#
# Epoch 00026: val_loss did not improve from 0.15426
# Epoch 27/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0606 - accuracy: 0.9932 - val_loss: 0.5052 - val_accuracy: 0.8200
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.15426
# Epoch 28/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0206 - accuracy: 0.9928 - val_loss: 0.3951 - val_accuracy: 0.9200
#
# Epoch 00028: val_loss did not improve from 0.15426
# Epoch 29/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.4407 - val_accuracy: 0.9300
#
# Epoch 00029: val_loss did not improve from 0.15426
# Epoch 30/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.4518 - val_accuracy: 0.9300
#
# Epoch 00030: val_loss did not improve from 0.15426
# Epoch 31/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0080 - accuracy: 0.9984 - val_loss: 0.5907 - val_accuracy: 0.8900
#
# Epoch 00031: val_loss did not improve from 0.15426
# Epoch 32/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.6400 - val_accuracy: 0.8800
#
# Epoch 00032: val_loss did not improve from 0.15426
# Epoch 33/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.6807 - val_accuracy: 0.8600
#
# Epoch 00033: val_loss did not improve from 0.15426
# Epoch 34/35
# 79/79 [==============================] - 10s 126ms/step - loss: 0.0099 - accuracy: 0.9980 - val_loss: 0.5664 - val_accuracy: 0.9100
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0173 - accuracy: 0.9964 - val_loss: 0.5916 - val_accuracy: 0.9100
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 2: loss of 0.591635525226593; accuracy of 91.00000262260437%
# Epoch 1/35
# 79/79 [==============================] - 26s 144ms/step - loss: 0.7735 - accuracy: 0.8641 - val_loss: 483.3841 - val_accuracy: 0.0700
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.4371 - accuracy: 0.9209 - val_loss: 346.4610 - val_accuracy: 0.5700
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.3443 - accuracy: 0.9353 - val_loss: 92.3590 - val_accuracy: 0.7300
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.6008 - accuracy: 0.9516 - val_loss: 0.8948 - val_accuracy: 0.8900
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.4196 - accuracy: 0.9440 - val_loss: 0.2950 - val_accuracy: 0.8900
#
# Epoch 00005: val_loss did not improve from 0.15426
# Epoch 6/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.2667 - accuracy: 0.9540 - val_loss: 0.3701 - val_accuracy: 0.9000
#
# Epoch 00006: val_loss did not improve from 0.15426
# Epoch 7/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1327 - accuracy: 0.9624 - val_loss: 1.3882 - val_accuracy: 0.7100
#
# Epoch 00007: val_loss did not improve from 0.15426
# Epoch 8/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.7225 - accuracy: 0.9021 - val_loss: 4.9829 - val_accuracy: 0.4100
#
# Epoch 00008: val_loss did not improve from 0.15426
# Epoch 9/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2454 - accuracy: 0.9440 - val_loss: 0.5175 - val_accuracy: 0.8800
#
# Epoch 00009: val_loss did not improve from 0.15426
# Epoch 10/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.6581 - accuracy: 0.9013 - val_loss: 2.5480 - val_accuracy: 0.6100
#
# Epoch 00010: val_loss did not improve from 0.15426
# Epoch 11/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.2901 - accuracy: 0.9289 - val_loss: 0.7385 - val_accuracy: 0.8100
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_loss did not improve from 0.15426
# Epoch 12/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1607 - accuracy: 0.9520 - val_loss: 0.4071 - val_accuracy: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.15426
# Epoch 13/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1310 - accuracy: 0.9596 - val_loss: 0.2959 - val_accuracy: 0.9000
#
# Epoch 00013: val_loss did not improve from 0.15426
# Epoch 14/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1370 - accuracy: 0.9612 - val_loss: 0.3462 - val_accuracy: 0.9000
#
# Epoch 00014: val_loss did not improve from 0.15426
# Epoch 15/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1133 - accuracy: 0.9684 - val_loss: 0.2729 - val_accuracy: 0.9000
#
# Epoch 00015: val_loss did not improve from 0.15426
# Epoch 16/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1196 - accuracy: 0.9640 - val_loss: 0.2737 - val_accuracy: 0.9000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_loss did not improve from 0.15426
# Epoch 17/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0977 - accuracy: 0.9684 - val_loss: 0.3496 - val_accuracy: 0.9000
#
# Epoch 00017: val_loss did not improve from 0.15426
# Epoch 18/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0937 - accuracy: 0.9720 - val_loss: 0.3682 - val_accuracy: 0.9100
#
# Epoch 00018: val_loss did not improve from 0.15426
# Epoch 19/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0941 - accuracy: 0.9712 - val_loss: 0.2958 - val_accuracy: 0.9200
#
# Epoch 00019: val_loss did not improve from 0.15426
# Epoch 20/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0907 - accuracy: 0.9696 - val_loss: 0.2840 - val_accuracy: 0.9200
#
# Epoch 00020: val_loss did not improve from 0.15426
# Epoch 21/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0838 - accuracy: 0.9752 - val_loss: 0.2764 - val_accuracy: 0.9000
#
# Epoch 00021: val_loss did not improve from 0.15426
# Epoch 22/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0885 - accuracy: 0.9736 - val_loss: 0.3021 - val_accuracy: 0.9000
#
# Epoch 00022: val_loss did not improve from 0.15426
# Epoch 23/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0843 - accuracy: 0.9728 - val_loss: 0.2575 - val_accuracy: 0.9100
#
# Epoch 00023: val_loss did not improve from 0.15426
# Epoch 24/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0690 - accuracy: 0.9764 - val_loss: 0.3159 - val_accuracy: 0.9100
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00024: val_loss did not improve from 0.15426
# Epoch 25/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0638 - accuracy: 0.9804 - val_loss: 0.2598 - val_accuracy: 0.9100
#
# Epoch 00025: val_loss did not improve from 0.15426
# Epoch 26/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0693 - accuracy: 0.9796 - val_loss: 0.2252 - val_accuracy: 0.9200
#
# Epoch 00026: val_loss did not improve from 0.15426
# Epoch 27/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0535 - accuracy: 0.9828 - val_loss: 0.2566 - val_accuracy: 0.9100
#
# Epoch 00027: val_loss did not improve from 0.15426
# Epoch 28/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0543 - accuracy: 0.9836 - val_loss: 0.2777 - val_accuracy: 0.9100
#
# Epoch 00028: val_loss did not improve from 0.15426
# Epoch 29/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0484 - accuracy: 0.9856 - val_loss: 0.2380 - val_accuracy: 0.9000
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00029: val_loss did not improve from 0.15426
# Epoch 30/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0498 - accuracy: 0.9848 - val_loss: 0.2649 - val_accuracy: 0.9100
#
# Epoch 00030: val_loss did not improve from 0.15426
# Epoch 31/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0469 - accuracy: 0.9836 - val_loss: 0.2937 - val_accuracy: 0.9100
#
# Epoch 00031: val_loss did not improve from 0.15426
# Epoch 32/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0484 - accuracy: 0.9844 - val_loss: 0.3073 - val_accuracy: 0.8900
#
# Epoch 00032: val_loss did not improve from 0.15426
# Epoch 33/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0555 - accuracy: 0.9832 - val_loss: 0.4439 - val_accuracy: 0.8900
#
# Epoch 00033: val_loss did not improve from 0.15426
# Epoch 34/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0385 - accuracy: 0.9868 - val_loss: 0.3365 - val_accuracy: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0394 - accuracy: 0.9848 - val_loss: 0.4439 - val_accuracy: 0.8800
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 3: loss of 0.44388556480407715; accuracy of 87.99999952316284%
# Epoch 1/35
# 79/79 [==============================] - 26s 145ms/step - loss: 0.8591 - accuracy: 0.8653 - val_loss: 787.8619 - val_accuracy: 0.0200
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 9s 120ms/step - loss: 1.5058 - accuracy: 0.8921 - val_loss: 4.6519 - val_accuracy: 0.5000
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.6395 - accuracy: 0.8969 - val_loss: 367.1444 - val_accuracy: 0.1100
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.5567 - accuracy: 0.9237 - val_loss: 6.3711 - val_accuracy: 0.5900
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.2689 - accuracy: 0.9396 - val_loss: 0.8478 - val_accuracy: 0.8200
#
# Epoch 00005: val_loss did not improve from 0.15426
# Epoch 6/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.1498 - accuracy: 0.9604 - val_loss: 0.9083 - val_accuracy: 0.8600
#
# Epoch 00006: val_loss did not improve from 0.15426
# Epoch 7/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1637 - accuracy: 0.9580 - val_loss: 0.5733 - val_accuracy: 0.8700
#
# Epoch 00007: val_loss did not improve from 0.15426
# Epoch 8/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1334 - accuracy: 0.9632 - val_loss: 0.5382 - val_accuracy: 0.8900
#
# Epoch 00008: val_loss did not improve from 0.15426
# Epoch 9/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1593 - accuracy: 0.9560 - val_loss: 0.3713 - val_accuracy: 0.8600
#
# Epoch 00009: val_loss did not improve from 0.15426
# Epoch 10/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.1472 - accuracy: 0.9600 - val_loss: 0.3391 - val_accuracy: 0.9100
#
# Epoch 00010: val_loss did not improve from 0.15426
# Epoch 11/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.1414 - accuracy: 0.9620 - val_loss: 0.7021 - val_accuracy: 0.9400
#
# Epoch 00011: val_loss did not improve from 0.15426
# Epoch 12/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.2241 - accuracy: 0.9520 - val_loss: 0.4387 - val_accuracy: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.15426
# Epoch 13/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.3284 - accuracy: 0.9337 - val_loss: 25.2886 - val_accuracy: 0.4000
#
# Epoch 00013: val_loss did not improve from 0.15426
# Epoch 14/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.3265 - accuracy: 0.9392 - val_loss: 7.1216 - val_accuracy: 0.5200
#
# Epoch 00014: val_loss did not improve from 0.15426
# Epoch 15/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.5131 - accuracy: 0.9325 - val_loss: 2.6711 - val_accuracy: 0.7500
#
# Epoch 00015: val_loss did not improve from 0.15426
# Epoch 16/35
# 79/79 [==============================] - 10s 129ms/step - loss: 0.1676 - accuracy: 0.9580 - val_loss: 0.6053 - val_accuracy: 0.8800
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.15426
# Epoch 17/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1120 - accuracy: 0.9680 - val_loss: 0.5497 - val_accuracy: 0.9200
#
# Epoch 00017: val_loss did not improve from 0.15426
# Epoch 18/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1009 - accuracy: 0.9688 - val_loss: 0.5192 - val_accuracy: 0.9200
#
# Epoch 00018: val_loss did not improve from 0.15426
# Epoch 19/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0864 - accuracy: 0.9720 - val_loss: 0.5367 - val_accuracy: 0.8900
#
# Epoch 00019: val_loss did not improve from 0.15426
# Epoch 20/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0778 - accuracy: 0.9744 - val_loss: 0.4713 - val_accuracy: 0.9200
#
# Epoch 00020: val_loss did not improve from 0.15426
# Epoch 21/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.1007 - accuracy: 0.9696 - val_loss: 0.4289 - val_accuracy: 0.9200
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.15426
# Epoch 22/35
# 79/79 [==============================] - 10s 125ms/step - loss: 0.0712 - accuracy: 0.9760 - val_loss: 0.4413 - val_accuracy: 0.9100
#
# Epoch 00022: val_loss did not improve from 0.15426
# Epoch 23/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0683 - accuracy: 0.9772 - val_loss: 0.4502 - val_accuracy: 0.9300
#
# Epoch 00023: val_loss did not improve from 0.15426
# Epoch 24/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0590 - accuracy: 0.9772 - val_loss: 0.4898 - val_accuracy: 0.9300
#
# Epoch 00024: val_loss did not improve from 0.15426
# Epoch 25/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0737 - accuracy: 0.9760 - val_loss: 0.5468 - val_accuracy: 0.9000
#
# Epoch 00025: val_loss did not improve from 0.15426
# Epoch 26/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0605 - accuracy: 0.9800 - val_loss: 0.5068 - val_accuracy: 0.9300
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_loss did not improve from 0.15426
# Epoch 27/35
# 79/79 [==============================] - 10s 131ms/step - loss: 0.0561 - accuracy: 0.9788 - val_loss: 0.5286 - val_accuracy: 0.9100
#
# Epoch 00027: val_loss did not improve from 0.15426
# Epoch 28/35
# 79/79 [==============================] - 10s 130ms/step - loss: 0.0525 - accuracy: 0.9804 - val_loss: 0.5195 - val_accuracy: 0.9100
#
# Epoch 00028: val_loss did not improve from 0.15426
# Epoch 29/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0483 - accuracy: 0.9836 - val_loss: 0.5228 - val_accuracy: 0.9000
#
# Epoch 00029: val_loss did not improve from 0.15426
# Epoch 30/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0433 - accuracy: 0.9848 - val_loss: 0.5523 - val_accuracy: 0.9200
#
# Epoch 00030: val_loss did not improve from 0.15426
# Epoch 31/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0435 - accuracy: 0.9848 - val_loss: 0.6423 - val_accuracy: 0.8300
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00031: val_loss did not improve from 0.15426
# Epoch 32/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0453 - accuracy: 0.9840 - val_loss: 0.5591 - val_accuracy: 0.9100
#
# Epoch 00032: val_loss did not improve from 0.15426
# Epoch 33/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0383 - accuracy: 0.9856 - val_loss: 0.6334 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.15426
# Epoch 34/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0417 - accuracy: 0.9860 - val_loss: 0.5625 - val_accuracy: 0.9300
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0445 - accuracy: 0.9880 - val_loss: 0.5917 - val_accuracy: 0.9200
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 4: loss of 0.5916783213615417; accuracy of 92.00000166893005%
# Epoch 1/35
# 79/79 [==============================] - 27s 149ms/step - loss: 1.2535 - accuracy: 0.8485 - val_loss: 790.6523 - val_accuracy: 0.5900
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.6956 - accuracy: 0.8993 - val_loss: 1813.0363 - val_accuracy: 0.6300
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.9466 - accuracy: 0.9153 - val_loss: 16341.4248 - val_accuracy: 0.5100
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.6239 - accuracy: 0.9073 - val_loss: 1048.8832 - val_accuracy: 0.1400
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.2722 - accuracy: 0.9357 - val_loss: 6.8600 - val_accuracy: 0.6700
#
# Epoch 00005: val_loss did not improve from 0.15426
# Epoch 6/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.2716 - accuracy: 0.9365 - val_loss: 1.3258 - val_accuracy: 0.8700
#
# Epoch 00006: val_loss did not improve from 0.15426
# Epoch 7/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1664 - accuracy: 0.9592 - val_loss: 0.8295 - val_accuracy: 0.7900
#
# Epoch 00007: val_loss did not improve from 0.15426
# Epoch 8/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1662 - accuracy: 0.9552 - val_loss: 0.8041 - val_accuracy: 0.7700
#
# Epoch 00008: val_loss did not improve from 0.15426
# Epoch 9/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1849 - accuracy: 0.9584 - val_loss: 1.2389 - val_accuracy: 0.7800
#
# Epoch 00009: val_loss did not improve from 0.15426
# Epoch 10/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1277 - accuracy: 0.9636 - val_loss: 0.6539 - val_accuracy: 0.8700
#
# Epoch 00010: val_loss did not improve from 0.15426
# Epoch 11/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1200 - accuracy: 0.9680 - val_loss: 0.5468 - val_accuracy: 0.9100
#
# Epoch 00011: val_loss did not improve from 0.15426
# Epoch 12/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0916 - accuracy: 0.9684 - val_loss: 0.5584 - val_accuracy: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.15426
# Epoch 13/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0841 - accuracy: 0.9716 - val_loss: 0.8311 - val_accuracy: 0.7700
#
# Epoch 00013: val_loss did not improve from 0.15426
# Epoch 14/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0775 - accuracy: 0.9764 - val_loss: 0.6124 - val_accuracy: 0.8600
#
# Epoch 00014: val_loss did not improve from 0.15426
# Epoch 15/35
# 79/79 [==============================] - 10s 127ms/step - loss: 0.1079 - accuracy: 0.9740 - val_loss: 0.7916 - val_accuracy: 0.8800
#
# Epoch 00015: val_loss did not improve from 0.15426
# Epoch 16/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1341 - accuracy: 0.9764 - val_loss: 1.0885 - val_accuracy: 0.7400
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.15426
# Epoch 17/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1317 - accuracy: 0.9728 - val_loss: 0.6601 - val_accuracy: 0.9000
#
# Epoch 00017: val_loss did not improve from 0.15426
# Epoch 18/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0518 - accuracy: 0.9840 - val_loss: 1.1610 - val_accuracy: 0.7600
#
# Epoch 00018: val_loss did not improve from 0.15426
# Epoch 19/35
# 79/79 [==============================] - 10s 123ms/step - loss: 0.0425 - accuracy: 0.9848 - val_loss: 0.6451 - val_accuracy: 0.9000
#
# Epoch 00019: val_loss did not improve from 0.15426
# Epoch 20/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0350 - accuracy: 0.9892 - val_loss: 0.6499 - val_accuracy: 0.9100
#
# Epoch 00020: val_loss did not improve from 0.15426
# Epoch 21/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0378 - accuracy: 0.9872 - val_loss: 0.6978 - val_accuracy: 0.9000
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.15426
# Epoch 22/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 0.7733 - val_accuracy: 0.9200
#
# Epoch 00022: val_loss did not improve from 0.15426
# Epoch 23/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0222 - accuracy: 0.9948 - val_loss: 0.7804 - val_accuracy: 0.9100
#
# Epoch 00023: val_loss did not improve from 0.15426
# Epoch 24/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.9918 - val_accuracy: 0.7800
#
# Epoch 00024: val_loss did not improve from 0.15426
# Epoch 25/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.6898 - val_accuracy: 0.9000
#
# Epoch 00025: val_loss did not improve from 0.15426
# Epoch 26/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.7749 - val_accuracy: 0.9100
#
# Epoch 00026: val_loss did not improve from 0.15426
# Epoch 27/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0310 - accuracy: 0.9932 - val_loss: 0.9237 - val_accuracy: 0.8900
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.15426
# Epoch 28/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0203 - accuracy: 0.9924 - val_loss: 0.9312 - val_accuracy: 0.8500
#
# Epoch 00028: val_loss did not improve from 0.15426
# Epoch 29/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0235 - accuracy: 0.9952 - val_loss: 0.8842 - val_accuracy: 0.8400
#
# Epoch 00029: val_loss did not improve from 0.15426
# Epoch 30/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0165 - accuracy: 0.9940 - val_loss: 0.7312 - val_accuracy: 0.9100
#
# Epoch 00030: val_loss did not improve from 0.15426
# Epoch 31/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0171 - accuracy: 0.9968 - val_loss: 0.7245 - val_accuracy: 0.9000
#
# Epoch 00031: val_loss did not improve from 0.15426
# Epoch 32/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.7899 - val_accuracy: 0.8800
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss did not improve from 0.15426
# Epoch 33/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.8197 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.15426
# Epoch 34/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 1.2048 - val_accuracy: 0.7700
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0135 - accuracy: 0.9980 - val_loss: 0.9673 - val_accuracy: 0.8500
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 5: loss of 0.9673045873641968; accuracy of 85.00000238418579%
# Epoch 1/35
# 79/79 [==============================] - 28s 151ms/step - loss: 0.9225 - accuracy: 0.8681 - val_loss: 242.0809 - val_accuracy: 0.1500
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.5640 - accuracy: 0.9245 - val_loss: 28.5026 - val_accuracy: 0.4900
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.3372 - accuracy: 0.9341 - val_loss: 16.8913 - val_accuracy: 0.1900
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.3939 - accuracy: 0.9293 - val_loss: 12.0746 - val_accuracy: 0.3400
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2002 - accuracy: 0.9492 - val_loss: 0.7934 - val_accuracy: 0.8300
#
# Epoch 00005: val_loss did not improve from 0.15426
# Epoch 6/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.3353 - accuracy: 0.9612 - val_loss: 0.4071 - val_accuracy: 0.9000
#
# Epoch 00006: val_loss did not improve from 0.15426
# Epoch 7/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1669 - accuracy: 0.9604 - val_loss: 0.7357 - val_accuracy: 0.9000
#
# Epoch 00007: val_loss did not improve from 0.15426
# Epoch 8/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1491 - accuracy: 0.9600 - val_loss: 0.4066 - val_accuracy: 0.8800
#
# Epoch 00008: val_loss did not improve from 0.15426
# Epoch 9/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1514 - accuracy: 0.9636 - val_loss: 0.5552 - val_accuracy: 0.8000
#
# Epoch 00009: val_loss did not improve from 0.15426
# Epoch 10/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1888 - accuracy: 0.9544 - val_loss: 1.2596 - val_accuracy: 0.7400
#
# Epoch 00010: val_loss did not improve from 0.15426
# Epoch 11/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2383 - accuracy: 0.9436 - val_loss: 9.8605 - val_accuracy: 0.6700
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_loss did not improve from 0.15426
# Epoch 12/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2238 - accuracy: 0.9524 - val_loss: 0.4336 - val_accuracy: 0.8900
#
# Epoch 00012: val_loss did not improve from 0.15426
# Epoch 13/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.2261 - accuracy: 0.9536 - val_loss: 1.5071 - val_accuracy: 0.8600
#
# Epoch 00013: val_loss did not improve from 0.15426
# Epoch 14/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1754 - accuracy: 0.9540 - val_loss: 0.4221 - val_accuracy: 0.8800
#
# Epoch 00014: val_loss did not improve from 0.15426
# Epoch 15/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0995 - accuracy: 0.9704 - val_loss: 0.3520 - val_accuracy: 0.8900
#
# Epoch 00015: val_loss did not improve from 0.15426
# Epoch 16/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0999 - accuracy: 0.9700 - val_loss: 0.3391 - val_accuracy: 0.9000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_loss did not improve from 0.15426
# Epoch 17/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0739 - accuracy: 0.9792 - val_loss: 0.3362 - val_accuracy: 0.9200
#
# Epoch 00017: val_loss did not improve from 0.15426
# Epoch 18/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0720 - accuracy: 0.9768 - val_loss: 0.3012 - val_accuracy: 0.9100
#
# Epoch 00018: val_loss did not improve from 0.15426
# Epoch 19/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0602 - accuracy: 0.9828 - val_loss: 0.3210 - val_accuracy: 0.9000
#
# Epoch 00019: val_loss did not improve from 0.15426
# Epoch 20/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0541 - accuracy: 0.9812 - val_loss: 0.3179 - val_accuracy: 0.9000
#
# Epoch 00020: val_loss did not improve from 0.15426
# Epoch 21/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0744 - accuracy: 0.9740 - val_loss: 0.3326 - val_accuracy: 0.8900
#
# Epoch 00021: val_loss did not improve from 0.15426
# Epoch 22/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 0.3187 - val_accuracy: 0.9000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00022: val_loss did not improve from 0.15426
# Epoch 23/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0450 - accuracy: 0.9848 - val_loss: 0.3461 - val_accuracy: 0.9000
#
# Epoch 00023: val_loss did not improve from 0.15426
# Epoch 24/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0485 - accuracy: 0.9836 - val_loss: 0.3284 - val_accuracy: 0.8900
#
# Epoch 00024: val_loss did not improve from 0.15426
# Epoch 25/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0305 - accuracy: 0.9912 - val_loss: 0.3347 - val_accuracy: 0.8900
#
# Epoch 00025: val_loss did not improve from 0.15426
# Epoch 26/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0346 - accuracy: 0.9892 - val_loss: 0.3902 - val_accuracy: 0.8800
#
# Epoch 00026: val_loss did not improve from 0.15426
# Epoch 27/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.3669 - val_accuracy: 0.8900
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00027: val_loss did not improve from 0.15426
# Epoch 28/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.3865 - val_accuracy: 0.8900
#
# Epoch 00028: val_loss did not improve from 0.15426
# Epoch 29/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0206 - accuracy: 0.9924 - val_loss: 0.3953 - val_accuracy: 0.8800
#
# Epoch 00029: val_loss did not improve from 0.15426
# Epoch 30/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.4196 - val_accuracy: 0.8900
#
# Epoch 00030: val_loss did not improve from 0.15426
# Epoch 31/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0177 - accuracy: 0.9960 - val_loss: 0.4310 - val_accuracy: 0.8700
#
# Epoch 00031: val_loss did not improve from 0.15426
# Epoch 32/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0267 - accuracy: 0.9904 - val_loss: 0.4392 - val_accuracy: 0.8800
#
# Epoch 00032: val_loss did not improve from 0.15426
# Epoch 33/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0301 - accuracy: 0.9908 - val_loss: 0.4252 - val_accuracy: 0.8700
#
# Epoch 00033: val_loss did not improve from 0.15426
# Epoch 34/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.4049 - val_accuracy: 0.8900
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0218 - accuracy: 0.9936 - val_loss: 0.4827 - val_accuracy: 0.8900
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 6: loss of 0.4826717674732208; accuracy of 88.99999856948853%
# Epoch 1/35
# 79/79 [==============================] - 25s 147ms/step - loss: 1.2417 - accuracy: 0.8457 - val_loss: 574.3581 - val_accuracy: 0.0100
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.6480 - accuracy: 0.8949 - val_loss: 30.1037 - val_accuracy: 0.2500
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.6111 - accuracy: 0.9041 - val_loss: 17.0482 - val_accuracy: 0.4900
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.2259 - accuracy: 0.9484 - val_loss: 11.2509 - val_accuracy: 0.6600
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1620 - accuracy: 0.9584 - val_loss: 0.5628 - val_accuracy: 0.7800
#
# Epoch 00005: val_loss did not improve from 0.15426
# Epoch 6/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.2197 - accuracy: 0.9488 - val_loss: 1.1033 - val_accuracy: 0.8600
#
# Epoch 00006: val_loss did not improve from 0.15426
# Epoch 7/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1814 - accuracy: 0.9464 - val_loss: 0.5622 - val_accuracy: 0.8400
#
# Epoch 00007: val_loss did not improve from 0.15426
# Epoch 8/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2167 - accuracy: 0.9480 - val_loss: 2.0502 - val_accuracy: 0.7000
#
# Epoch 00008: val_loss did not improve from 0.15426
# Epoch 9/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.3130 - accuracy: 0.9424 - val_loss: 100.5460 - val_accuracy: 0.4200
#
# Epoch 00009: val_loss did not improve from 0.15426
# Epoch 10/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1823 - accuracy: 0.9580 - val_loss: 0.3283 - val_accuracy: 0.9100
#
# Epoch 00010: val_loss did not improve from 0.15426
# Epoch 11/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1021 - accuracy: 0.9668 - val_loss: 0.2596 - val_accuracy: 0.9200
#
# Epoch 00011: val_loss did not improve from 0.15426
# Epoch 12/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0906 - accuracy: 0.9712 - val_loss: 0.3350 - val_accuracy: 0.8600
#
# Epoch 00012: val_loss did not improve from 0.15426
# Epoch 13/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0802 - accuracy: 0.9740 - val_loss: 0.1984 - val_accuracy: 0.9500
#
# Epoch 00013: val_loss did not improve from 0.15426
# Epoch 14/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0812 - accuracy: 0.9708 - val_loss: 0.2422 - val_accuracy: 0.9500
#
# Epoch 00014: val_loss did not improve from 0.15426
# Epoch 15/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1862 - accuracy: 0.9540 - val_loss: 1.5806 - val_accuracy: 0.5900
#
# Epoch 00015: val_loss did not improve from 0.15426
# Epoch 16/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.2195 - accuracy: 0.9444 - val_loss: 1.0811 - val_accuracy: 0.7800
#
# Epoch 00016: val_loss did not improve from 0.15426
# Epoch 17/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1213 - accuracy: 0.9664 - val_loss: 0.2801 - val_accuracy: 0.9200
#
# ...
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00034: val_loss did not improve from 0.15426
# Epoch 35/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 1.0486 - val_accuracy: 0.8800
#
# Epoch 00035: val_loss did not improve from 0.15426
# Score for fold 8: loss of 1.0485622882843018; accuracy of 87.99999952316284%
# Epoch 1/35
# 79/79 [==============================] - 25s 153ms/step - loss: 1.0480 - accuracy: 0.8573 - val_loss: 531.3805 - val_accuracy: 0.0200
#
# Epoch 00001: val_loss did not improve from 0.15426
# Epoch 2/35
# 79/79 [==============================] - 10s 132ms/step - loss: 0.4487 - accuracy: 0.9101 - val_loss: 109.9097 - val_accuracy: 0.7400
#
# Epoch 00002: val_loss did not improve from 0.15426
# Epoch 3/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.4515 - accuracy: 0.9149 - val_loss: 186.0001 - val_accuracy: 0.5100
#
# Epoch 00003: val_loss did not improve from 0.15426
# Epoch 4/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.2415 - accuracy: 0.9444 - val_loss: 0.1829 - val_accuracy: 0.9600
#
# Epoch 00004: val_loss did not improve from 0.15426
# Epoch 5/35
# 79/79 [==============================] - 10s 129ms/step - loss: 0.1368 - accuracy: 0.9588 - val_loss: 0.1498 - val_accuracy: 0.9700
#
# Epoch 00005: val_loss improved from 0.15426 to 0.14982, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 6/35
# 79/79 [==============================] - 11s 136ms/step - loss: 0.1444 - accuracy: 0.9604 - val_loss: 0.1418 - val_accuracy: 0.9700
#
# Epoch 00006: val_loss improved from 0.14982 to 0.14182, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 7/35
# 79/79 [==============================] - 10s 123ms/step - loss: 0.1628 - accuracy: 0.9548 - val_loss: 0.1944 - val_accuracy: 0.9300
#
# Epoch 00007: val_loss did not improve from 0.14182
# Epoch 8/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.3131 - accuracy: 0.9337 - val_loss: 4.5893 - val_accuracy: 0.7500
#
# Epoch 00008: val_loss did not improve from 0.14182
# Epoch 9/35
# 79/79 [==============================] - 10s 126ms/step - loss: 0.2021 - accuracy: 0.9512 - val_loss: 5.4606 - val_accuracy: 0.8000
#
# Epoch 00009: val_loss did not improve from 0.14182
# Epoch 10/35
# 79/79 [==============================] - 10s 133ms/step - loss: 0.6859 - accuracy: 0.8937 - val_loss: 79.3373 - val_accuracy: 0.5500
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_loss did not improve from 0.14182
# Epoch 11/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.2637 - accuracy: 0.9508 - val_loss: 0.6680 - val_accuracy: 0.8800
#
# Epoch 00011: val_loss did not improve from 0.14182
# Epoch 12/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.1189 - accuracy: 0.9656 - val_loss: 0.1435 - val_accuracy: 0.9700
#
# Epoch 00012: val_loss did not improve from 0.14182
# Epoch 13/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.1250 - accuracy: 0.9656 - val_loss: 0.1586 - val_accuracy: 0.9600
#
# Epoch 00013: val_loss did not improve from 0.14182
# Epoch 14/35
# 79/79 [==============================] - 10s 127ms/step - loss: 0.1029 - accuracy: 0.9700 - val_loss: 0.1287 - val_accuracy: 0.9700
#
# Epoch 00014: val_loss improved from 0.14182 to 0.12865, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 15/35
# 79/79 [==============================] - 10s 130ms/step - loss: 0.1270 - accuracy: 0.9648 - val_loss: 0.1400 - val_accuracy: 0.9600
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00015: val_loss did not improve from 0.12865
# Epoch 16/35
# 79/79 [==============================] - 10s 126ms/step - loss: 0.0912 - accuracy: 0.9716 - val_loss: 0.1236 - val_accuracy: 0.9700
#
# Epoch 00016: val_loss improved from 0.12865 to 0.12361, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 17/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.1168 - accuracy: 0.9680 - val_loss: 0.1095 - val_accuracy: 0.9700
#
# Epoch 00017: val_loss improved from 0.12361 to 0.10947, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 18/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0780 - accuracy: 0.9752 - val_loss: 0.0862 - val_accuracy: 0.9700
#
# Epoch 00018: val_loss improved from 0.10947 to 0.08619, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 19/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0854 - accuracy: 0.9744 - val_loss: 0.0987 - val_accuracy: 0.9600
#
# Epoch 00019: val_loss did not improve from 0.08619
# Epoch 20/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0883 - accuracy: 0.9720 - val_loss: 0.1286 - val_accuracy: 0.9500
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00020: val_loss did not improve from 0.08619
# Epoch 21/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0780 - accuracy: 0.9756 - val_loss: 0.1110 - val_accuracy: 0.9600
#
# Epoch 00021: val_loss did not improve from 0.08619
# Epoch 22/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0789 - accuracy: 0.9768 - val_loss: 0.0984 - val_accuracy: 0.9700
#
# Epoch 00022: val_loss did not improve from 0.08619
# Epoch 23/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0617 - accuracy: 0.9804 - val_loss: 0.0932 - val_accuracy: 0.9600
#
# Epoch 00023: val_loss did not improve from 0.08619
# Epoch 24/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0783 - accuracy: 0.9760 - val_loss: 0.0808 - val_accuracy: 0.9600
#
# Epoch 00024: val_loss improved from 0.08619 to 0.08077, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 25/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.0782 - accuracy: 0.9720 - val_loss: 0.1251 - val_accuracy: 0.9600
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00025: val_loss did not improve from 0.08077
# Epoch 26/35
# 79/79 [==============================] - 9s 120ms/step - loss: 0.0620 - accuracy: 0.9780 - val_loss: 0.0999 - val_accuracy: 0.9700
#
# Epoch 00026: val_loss did not improve from 0.08077
# Epoch 27/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0572 - accuracy: 0.9808 - val_loss: 0.0912 - val_accuracy: 0.9700
# Epoch 00027: val_loss did not improve from 0.08077
# Epoch 28/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0601 - accuracy: 0.9776 - val_loss: 0.1192 - val_accuracy: 0.9600
#
# Epoch 00028: val_loss did not improve from 0.08077
# Epoch 29/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0558 - accuracy: 0.9812 - val_loss: 0.1099 - val_accuracy: 0.9600
#
# Epoch 00029: val_loss did not improve from 0.08077
# Epoch 30/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0464 - accuracy: 0.9828 - val_loss: 0.0843 - val_accuracy: 0.9700
#
# Epoch 00030: val_loss did not improve from 0.08077
# Epoch 31/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0473 - accuracy: 0.9832 - val_loss: 0.0851 - val_accuracy: 0.9700
#
# Epoch 00031: val_loss did not improve from 0.08077
# Epoch 32/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0450 - accuracy: 0.9856 - val_loss: 0.0868 - val_accuracy: 0.9700
#
# Epoch 00032: val_loss did not improve from 0.08077
# Epoch 33/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0491 - accuracy: 0.9820 - val_loss: 0.1107 - val_accuracy: 0.9700
#
# Epoch 00033: val_loss did not improve from 0.08077
# Epoch 34/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.0417 - accuracy: 0.9868 - val_loss: 0.0778 - val_accuracy: 0.9700
#
# Epoch 00034: val_loss improved from 0.08077 to 0.07780, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Epoch 35/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.0357 - accuracy: 0.9888 - val_loss: 0.0758 - val_accuracy: 0.9700
#
# Epoch 00035: val_loss improved from 0.07780 to 0.07576, saving model to /Users/Max/Documents/GitHub/experiments_learning_curve/crossv-cgan-densenet-local-v001\model.h5
# Score for fold 9: loss of 0.07575537264347076; accuracy of 97.00000286102295%
# Epoch 1/35
# 79/79 [==============================] - 25s 146ms/step - loss: 1.2232 - accuracy: 0.8697 - val_loss: 143.6831 - val_accuracy: 0.5400
#
# Epoch 00001: val_loss did not improve from 0.07576
# Epoch 2/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.4423 - accuracy: 0.9273 - val_loss: 97.1404 - val_accuracy: 0.6100
#
# Epoch 00002: val_loss did not improve from 0.07576
# Epoch 3/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.4686 - accuracy: 0.9305 - val_loss: 57.9976 - val_accuracy: 0.5300
#
# Epoch 00003: val_loss did not improve from 0.07576
# Epoch 4/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.7324 - accuracy: 0.8821 - val_loss: 196.5973 - val_accuracy: 0.1300
#
# Epoch 00004: val_loss did not improve from 0.07576
# Epoch 5/35
# 79/79 [==============================] - 10s 120ms/step - loss: 0.2904 - accuracy: 0.9345 - val_loss: 16.2922 - val_accuracy: 0.6200
#
# Epoch 00005: val_loss did not improve from 0.07576
# Epoch 6/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.2010 - accuracy: 0.9436 - val_loss: 6.2658 - val_accuracy: 0.7800
#
# Epoch 00006: val_loss did not improve from 0.07576
# Epoch 7/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1650 - accuracy: 0.9528 - val_loss: 0.5392 - val_accuracy: 0.8700
#
# Epoch 00007: val_loss did not improve from 0.07576
# Epoch 8/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1464 - accuracy: 0.9644 - val_loss: 0.5786 - val_accuracy: 0.8300
#
# Epoch 00008: val_loss did not improve from 0.07576
# Epoch 9/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1314 - accuracy: 0.9676 - val_loss: 0.7159 - val_accuracy: 0.6900
#
# Epoch 00009: val_loss did not improve from 0.07576
# Epoch 10/35
# 79/79 [==============================] - 9s 119ms/step - loss: 0.1442 - accuracy: 0.9624 - val_loss: 2.6992 - val_accuracy: 0.7300
#
# Epoch 00010: val_loss did not improve from 0.07576
# Epoch 11/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.3107 - accuracy: 0.9353 - val_loss: 14.9097 - val_accuracy: 0.6100
#
# Epoch 00011: val_loss did not improve from 0.07576
# Epoch 12/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.3002 - accuracy: 0.9548 - val_loss: 1.5795 - val_accuracy: 0.7100
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00012: val_loss did not improve from 0.07576
# Epoch 13/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1250 - accuracy: 0.9688 - val_loss: 3.6338 - val_accuracy: 0.6000
#
# Epoch 00013: val_loss did not improve from 0.07576
# Epoch 14/35
# 79/79 [==============================] - 9s 118ms/step - loss: 0.1235 - accuracy: 0.9720 - val_loss: 0.5038 - val_accuracy: 0.8700
#
# Epoch 00014: val_loss did not improve from 0.07576
# Epoch 15/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1187 - accuracy: 0.9708 - val_loss: 0.6004 - val_accuracy: 0.8300
#
# Epoch 00015: val_loss did not improve from 0.07576
# Epoch 16/35
# 79/79 [==============================] - 9s 117ms/step - loss: 0.1149 - accuracy: 0.9660 - val_loss: 0.3481 - val_accuracy: 0.8700
#
# Epoch 00016: val_loss did not improve from 0.07576
# Epoch 17/35
# 79/79 [==============================] - 10s 120ms/step - loss: 0.0882 - accuracy: 0.9744 - val_loss: 1.0231 - val_accuracy: 0.8300
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00017: val_loss did not improve from 0.07576
# Epoch 18/35
# 79/79 [==============================] - 10s 131ms/step - loss: 0.0745 - accuracy: 0.9776 - val_loss: 0.2692 - val_accuracy: 0.8900
#
# Epoch 00018: val_loss did not improve from 0.07576
# Epoch 19/35
# 79/79 [==============================] - 10s 129ms/step - loss: 0.0563 - accuracy: 0.9812 - val_loss: 0.3029 - val_accuracy: 0.9000
#
# Epoch 00019: val_loss did not improve from 0.07576
# Epoch 20/35
# 79/79 [==============================] - 10s 130ms/step - loss: 0.0494 - accuracy: 0.9840 - val_loss: 0.3280 - val_accuracy: 0.8900
#
# Epoch 00020: val_loss did not improve from 0.07576
# Epoch 21/35
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0496 - accuracy: 0.9824 - val_loss: 0.2726 - val_accuracy: 0.9200
#
# Epoch 00021: val_loss did not improve from 0.07576
# Epoch 22/35
# 79/79 [==============================] - 11s 138ms/step - loss: 0.0380 - accuracy: 0.9864 - val_loss: 0.3089 - val_accuracy: 0.9200
#
# Epoch 00022: val_loss did not improve from 0.07576
# Epoch 23/35
# 79/79 [==============================] - 10s 126ms/step - loss: 0.0453 - accuracy: 0.9840 - val_loss: 0.3327 - val_accuracy: 0.9000
#
# Epoch 00023: val_loss did not improve from 0.07576
# Epoch 24/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0360 - accuracy: 0.9856 - val_loss: 0.3554 - val_accuracy: 0.9200
#
# Epoch 00024: val_loss did not improve from 0.07576
# Epoch 25/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0515 - accuracy: 0.9824 - val_loss: 0.3735 - val_accuracy: 0.9300
#
# Epoch 00025: val_loss did not improve from 0.07576
# Epoch 26/35
# 79/79 [==============================] - 10s 125ms/step - loss: 0.0355 - accuracy: 0.9876 - val_loss: 0.3568 - val_accuracy: 0.9000
#
# Epoch 00026: val_loss did not improve from 0.07576
# Epoch 27/35
# 79/79 [==============================] - 10s 131ms/step - loss: 0.0344 - accuracy: 0.9876 - val_loss: 0.3729 - val_accuracy: 0.9200
#
# Epoch 00027: val_loss did not improve from 0.07576
# Epoch 28/35
# 79/79 [==============================] - 10s 126ms/step - loss: 0.0312 - accuracy: 0.9908 - val_loss: 0.3785 - val_accuracy: 0.8800
#
# Epoch 00028: val_loss did not improve from 0.07576
# Epoch 29/35
# 79/79 [==============================] - 10s 121ms/step - loss: 0.0262 - accuracy: 0.9924 - val_loss: 0.5036 - val_accuracy: 0.9000
#
# Epoch 00029: val_loss did not improve from 0.07576
# Epoch 30/35
# 79/79 [==============================] - 10s 125ms/step - loss: 0.0275 - accuracy: 0.9884 - val_loss: 0.5497 - val_accuracy: 0.8500
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.07576
# Epoch 31/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.4106 - val_accuracy: 0.9000
#
# Epoch 00031: val_loss did not improve from 0.07576
# Epoch 32/35
# 79/79 [==============================] - 10s 120ms/step - loss: 0.0152 - accuracy: 0.9940 - val_loss: 0.4695 - val_accuracy: 0.8900
#
# Epoch 00032: val_loss did not improve from 0.07576
# Epoch 33/35
# 79/79 [==============================] - 10s 124ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.3747 - val_accuracy: 0.9100
#
# Epoch 00033: val_loss did not improve from 0.07576
# Epoch 34/35
# 79/79 [==============================] - 10s 123ms/step - loss: 0.0197 - accuracy: 0.9952 - val_loss: 0.5835 - val_accuracy: 0.9300
#
# Epoch 00034: val_loss did not improve from 0.07576
# Epoch 35/35
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.5920 - val_accuracy: 0.9100
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00035: val_loss did not improve from 0.07576
# Score for fold 10: loss of 0.5919816493988037; accuracy of 91.00000262260437%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.18418535590171814 - Accuracy: 93.00000071525574%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.591635525226593 - Accuracy: 91.00000262260437%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.44388556480407715 - Accuracy: 87.99999952316284%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.5916783213615417 - Accuracy: 92.00000166893005%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.9673045873641968 - Accuracy: 85.00000238418579%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.4826717674732208 - Accuracy: 88.99999856948853%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.3275466561317444 - Accuracy: 94.9999988079071%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 1.0485622882843018 - Accuracy: 87.99999952316284%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.07575537264347076 - Accuracy: 97.00000286102295%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.5919816493988037 - Accuracy: 91.00000262260437%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 90.90000092983246% (+- 0.03389690482742764)
# > Loss: 0.5305207088589668
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN-DenseNet"
print(t)
# Out:
# +---------------------------------------+
# |      Performance of CGAN-DenseNet     |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.909       | 0.0339       |
# | Loss     | 0.5305      | 0.2912       |
# | Macro F1 | 0.7453      | 0.0662       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9644      | 0.0397       |
# | Acc      | 0.972       | 0.0166       |
# | F1       | 0.9734      | 0.0168       |
# | MCC      | 0.9448      | 0.032        |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-DenseNet across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-DenseNet")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
