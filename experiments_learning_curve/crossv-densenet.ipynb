# %% [markdown]
# # DenseNet

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'rgb'

# Batch size
batch_size = 20000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras import datasets, layers, models, losses, Model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/learning_curve"
    for files in os.listdir(dir):
        if "densenet" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: crossv-densenet{batch_size}-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/learning_curve/crossv-densenet{batch_size}-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 6 matches(es) found
# --------------
# New folder name: crossv-densenet20000-local-v007
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = tf.keras.applications.densenet.preprocess_input(imgs)

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # DenseNet
# We will now build our **DenseNet169** model using Tensorflow/Keras. This model will have the following layers :
#
# **Input shape** : 64 * 64 * 3
#
# Nota bene that the DenseNet only takes RGB images (with 3 channels)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Build the DenseNet model
    base_model = tf.keras.applications.DenseNet169(weights = 'imagenet', include_top = False, input_shape = (64,64,3))
    
    # Add the classification layers for this dataset
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(1000, activation='relu')(x)
    predictions = layers.Dense(num_classes, activation = 'softmax')(x)
    
    # Compile the model
    head_model = Model(inputs = base_model.input, outputs = predictions)
    head_model.compile(optimizer='adam', loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    # Freeze all but last eight layers
    for layer in head_model.layers[:-8]:
        layer.trainable=False
    
    for layer in head_model.layers[-8:]:
        layer.trainable=True
    
    
    # Run the CNN
    history.append(
        head_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = head_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {head_model.metrics_names[0]} of {scores[0]}; {head_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(head_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(head_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
    
    # Save the binary data distribution
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/40
# 563/563 [==============================] - 88s 128ms/step - loss: 0.4384 - accuracy: 0.8847 - val_loss: 0.2456 - val_accuracy: 0.9300
#
# Epoch 00001: val_loss improved from inf to 0.24563, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 2/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.2382 - accuracy: 0.9303 - val_loss: 0.1687 - val_accuracy: 0.9455
#
# Epoch 00002: val_loss improved from 0.24563 to 0.16875, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 3/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2433 - accuracy: 0.9302 - val_loss: 0.6537 - val_accuracy: 0.7580
#
# Epoch 00003: val_loss did not improve from 0.16875
# Epoch 4/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.3253 - accuracy: 0.9124 - val_loss: 0.2272 - val_accuracy: 0.9310
#
# Epoch 00004: val_loss did not improve from 0.16875
# Epoch 5/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1958 - accuracy: 0.9376 - val_loss: 0.1754 - val_accuracy: 0.9445
#
# Epoch 00005: val_loss did not improve from 0.16875
# Epoch 6/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.5357 - accuracy: 0.9025 - val_loss: 0.2347 - val_accuracy: 0.9250
#
# Epoch 00006: val_loss did not improve from 0.16875
# Epoch 7/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.2808 - accuracy: 0.9171 - val_loss: 0.2031 - val_accuracy: 0.9380
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.16875
# Epoch 8/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.1879 - accuracy: 0.9391 - val_loss: 0.1754 - val_accuracy: 0.9455
#
# Epoch 00008: val_loss did not improve from 0.16875
# Epoch 9/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1713 - accuracy: 0.9430 - val_loss: 0.1838 - val_accuracy: 0.9485
#
# Epoch 00009: val_loss did not improve from 0.16875
# Epoch 10/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1537 - accuracy: 0.9494 - val_loss: 0.1514 - val_accuracy: 0.9535
#
# Epoch 00010: val_loss improved from 0.16875 to 0.15141, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 11/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1388 - accuracy: 0.9541 - val_loss: 0.1432 - val_accuracy: 0.9545
#
# Epoch 00011: val_loss improved from 0.15141 to 0.14318, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 12/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1336 - accuracy: 0.9561 - val_loss: 0.1443 - val_accuracy: 0.9570
#
# Epoch 00012: val_loss did not improve from 0.14318
# Epoch 13/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1280 - accuracy: 0.9571 - val_loss: 0.1521 - val_accuracy: 0.9550
#
# Epoch 00013: val_loss did not improve from 0.14318
# Epoch 14/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1165 - accuracy: 0.9611 - val_loss: 0.1333 - val_accuracy: 0.9640
#
# Epoch 00014: val_loss improved from 0.14318 to 0.13328, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 15/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1169 - accuracy: 0.9604 - val_loss: 0.1510 - val_accuracy: 0.9600
#
# Epoch 00015: val_loss did not improve from 0.13328
# Epoch 16/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1113 - accuracy: 0.9634 - val_loss: 0.2391 - val_accuracy: 0.9620
#
# Epoch 00016: val_loss did not improve from 0.13328
# Epoch 17/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1106 - accuracy: 0.9633 - val_loss: 0.3662 - val_accuracy: 0.8575
#
# Epoch 00017: val_loss did not improve from 0.13328
# Epoch 18/40
# 563/563 [==============================] - 66s 116ms/step - loss: 0.0962 - accuracy: 0.9688 - val_loss: 0.1493 - val_accuracy: 0.9610
#
# Epoch 00018: val_loss did not improve from 0.13328
# Epoch 19/40
# 563/563 [==============================] - 67s 120ms/step - loss: 0.0909 - accuracy: 0.9698 - val_loss: 0.1397 - val_accuracy: 0.9595
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_loss did not improve from 0.13328
# Epoch 20/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0732 - accuracy: 0.9764 - val_loss: 0.1310 - val_accuracy: 0.9650
#
# Epoch 00020: val_loss improved from 0.13328 to 0.13100, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 21/40
# 563/563 [==============================] - 74s 131ms/step - loss: 0.0735 - accuracy: 0.9777 - val_loss: 0.1708 - val_accuracy: 0.9665
#
# Epoch 00021: val_loss did not improve from 0.13100
# Epoch 22/40
# 563/563 [==============================] - 72s 127ms/step - loss: 0.0648 - accuracy: 0.9788 - val_loss: 0.1371 - val_accuracy: 0.9685
#
# Epoch 00022: val_loss did not improve from 0.13100
# Epoch 23/40
# 563/563 [==============================] - 74s 131ms/step - loss: 0.0630 - accuracy: 0.9794 - val_loss: 0.1296 - val_accuracy: 0.9690
#
# Epoch 00023: val_loss improved from 0.13100 to 0.12961, saving model to /Users/Max/Documents/GitHub/learning_curve/crossv-densenet20000-local-v007\model.h5
# Epoch 24/40
# 563/563 [==============================] - 72s 127ms/step - loss: 0.0669 - accuracy: 0.9791 - val_loss: 0.2045 - val_accuracy: 0.9685
#
# Epoch 00024: val_loss did not improve from 0.12961
# Epoch 25/40
# 563/563 [==============================] - 74s 132ms/step - loss: 0.0612 - accuracy: 0.9803 - val_loss: 0.1445 - val_accuracy: 0.9715
#
# Epoch 00025: val_loss did not improve from 0.12961
# Epoch 26/40
# 563/563 [==============================] - 67s 120ms/step - loss: 0.0590 - accuracy: 0.9808 - val_loss: 0.1416 - val_accuracy: 0.9680
#
# Epoch 00026: val_loss did not improve from 0.12961
# Epoch 27/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0578 - accuracy: 0.9813 - val_loss: 0.2009 - val_accuracy: 0.9675
#
# Epoch 00027: val_loss did not improve from 0.12961
# Epoch 28/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0538 - accuracy: 0.9824 - val_loss: 0.1501 - val_accuracy: 0.9690
#
# Epoch 00028: val_loss did not improve from 0.12961
# Epoch 29/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0587 - accuracy: 0.9812 - val_loss: 0.2293 - val_accuracy: 0.9535
#
# Epoch 00029: val_loss did not improve from 0.12961
# Epoch 30/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0580 - accuracy: 0.9814 - val_loss: 0.2838 - val_accuracy: 0.9715
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.12961
# Epoch 31/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0491 - accuracy: 0.9841 - val_loss: 0.1507 - val_accuracy: 0.9705
#
# Epoch 00031: val_loss did not improve from 0.12961
# Epoch 32/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0447 - accuracy: 0.9856 - val_loss: 0.1608 - val_accuracy: 0.9685
#
# Epoch 00032: val_loss did not improve from 0.12961
# Epoch 33/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0443 - accuracy: 0.9854 - val_loss: 0.1734 - val_accuracy: 0.9685
#
# Epoch 00033: val_loss did not improve from 0.12961
# Epoch 34/40
# 563/563 [==============================] - 66s 116ms/step - loss: 0.0447 - accuracy: 0.9849 - val_loss: 0.1621 - val_accuracy: 0.9720
#
# Epoch 00034: val_loss did not improve from 0.12961
# Epoch 35/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0432 - accuracy: 0.9855 - val_loss: 0.1759 - val_accuracy: 0.9705
#
# Epoch 00035: val_loss did not improve from 0.12961
# Epoch 36/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0441 - accuracy: 0.9850 - val_loss: 0.2408 - val_accuracy: 0.9695
#
# Epoch 00036: val_loss did not improve from 0.12961
# Epoch 37/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0438 - accuracy: 0.9849 - val_loss: 0.1695 - val_accuracy: 0.9695
# Epoch 00037: val_loss did not improve from 0.12961
# Epoch 38/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0412 - accuracy: 0.9856 - val_loss: 0.1784 - val_accuracy: 0.9705
#
# Epoch 00038: val_loss did not improve from 0.12961
# Epoch 39/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0407 - accuracy: 0.9861 - val_loss: 0.1673 - val_accuracy: 0.9725
#
# Epoch 00039: val_loss did not improve from 0.12961
# Epoch 40/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0408 - accuracy: 0.9862 - val_loss: 0.1862 - val_accuracy: 0.9730
#
# Epoch 00040: val_loss did not improve from 0.12961
# Score for fold 1: loss of 0.18617752194404602; accuracy of 97.29999899864197%
# Epoch 1/40
# 563/563 [==============================] - 78s 118ms/step - loss: 0.5898 - accuracy: 0.8763 - val_loss: 25331902.0000 - val_accuracy: 0.0590
#
# Epoch 00001: val_loss did not improve from 0.12961
# Epoch 2/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.5312 - accuracy: 0.8813 - val_loss: 0.2309 - val_accuracy: 0.9240
#
# Epoch 00002: val_loss did not improve from 0.12961
# Epoch 3/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.2664 - accuracy: 0.9193 - val_loss: 1.4846 - val_accuracy: 0.9060
#
# Epoch 00003: val_loss did not improve from 0.12961
# Epoch 4/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.2464 - accuracy: 0.9241 - val_loss: 0.2209 - val_accuracy: 0.9350
#
# Epoch 00004: val_loss did not improve from 0.12961
# Epoch 5/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.2021 - accuracy: 0.9371 - val_loss: 0.1738 - val_accuracy: 0.9445
#
# Epoch 00005: val_loss did not improve from 0.12961
# Epoch 6/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1791 - accuracy: 0.9433 - val_loss: 0.2598 - val_accuracy: 0.9485
#
# Epoch 00006: val_loss did not improve from 0.12961
# Epoch 7/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.2831 - accuracy: 0.9229 - val_loss: 0.2123 - val_accuracy: 0.9260
#
# Epoch 00007: val_loss did not improve from 0.12961
# Epoch 8/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1926 - accuracy: 0.9407 - val_loss: 0.2339 - val_accuracy: 0.9015
#
# Epoch 00008: val_loss did not improve from 0.12961
# Epoch 9/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1558 - accuracy: 0.9492 - val_loss: 0.1506 - val_accuracy: 0.9520
#
# Epoch 00009: val_loss did not improve from 0.12961
# Epoch 10/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1715 - accuracy: 0.9472 - val_loss: 0.2247 - val_accuracy: 0.8965
#
# Epoch 00010: val_loss did not improve from 0.12961
# Epoch 11/40
# 563/563 [==============================] - 64s 115ms/step - loss: 0.1528 - accuracy: 0.9497 - val_loss: 0.1735 - val_accuracy: 0.9445
#
# Epoch 00011: val_loss did not improve from 0.12961
# Epoch 12/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1311 - accuracy: 0.9574 - val_loss: 0.1554 - val_accuracy: 0.9485
#
# Epoch 00012: val_loss did not improve from 0.12961
# Epoch 13/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1232 - accuracy: 0.9589 - val_loss: 0.1815 - val_accuracy: 0.9405
#
# Epoch 00013: val_loss did not improve from 0.12961
# Epoch 14/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1261 - accuracy: 0.9601 - val_loss: 0.1448 - val_accuracy: 0.9550
#
# Epoch 00014: val_loss did not improve from 0.12961
# Epoch 15/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1182 - accuracy: 0.9612 - val_loss: 0.1939 - val_accuracy: 0.9365
#
# Epoch 00015: val_loss did not improve from 0.12961
# Epoch 16/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1073 - accuracy: 0.9654 - val_loss: 0.1732 - val_accuracy: 0.9440
#
# Epoch 00016: val_loss did not improve from 0.12961
# Epoch 17/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0987 - accuracy: 0.9676 - val_loss: 0.1874 - val_accuracy: 0.9435
#
# Epoch 00017: val_loss did not improve from 0.12961
# Epoch 18/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1002 - accuracy: 0.9662 - val_loss: 0.1520 - val_accuracy: 0.9500
#
# Epoch 00018: val_loss did not improve from 0.12961
# Epoch 19/40
# 563/563 [==============================] - 64s 115ms/step - loss: 0.1122 - accuracy: 0.9655 - val_loss: 9.7139 - val_accuracy: 0.4645
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.12961
# Epoch 20/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.1125 - accuracy: 0.9641 - val_loss: 0.1333 - val_accuracy: 0.9570
#
# Epoch 00020: val_loss did not improve from 0.12961
# Epoch 21/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.0773 - accuracy: 0.9757 - val_loss: 0.1601 - val_accuracy: 0.9555
#
# Epoch 00021: val_loss did not improve from 0.12961
# Epoch 22/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.0708 - accuracy: 0.9768 - val_loss: 0.1423 - val_accuracy: 0.9605
#
# Epoch 00022: val_loss did not improve from 0.12961
# Epoch 23/40
# 563/563 [==============================] - 64s 115ms/step - loss: 0.0658 - accuracy: 0.9789 - val_loss: 0.1426 - val_accuracy: 0.9600
#
# Epoch 00023: val_loss did not improve from 0.12961
# Epoch 24/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.0609 - accuracy: 0.9807 - val_loss: 0.1705 - val_accuracy: 0.9590
#
# Epoch 00024: val_loss did not improve from 0.12961
# Epoch 25/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.0624 - accuracy: 0.9800 - val_loss: 0.1576 - val_accuracy: 0.9580
#
# Epoch 00025: val_loss did not improve from 0.12961
# Epoch 26/40
# 563/563 [==============================] - 64s 115ms/step - loss: 0.0615 - accuracy: 0.9804 - val_loss: 0.1671 - val_accuracy: 0.9580
#
# Epoch 00026: val_loss did not improve from 0.12961
# Epoch 27/40
# 563/563 [==============================] - 64s 114ms/step - loss: 0.0564 - accuracy: 0.9823 - val_loss: 0.1521 - val_accuracy: 0.9595
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.12961
# Epoch 28/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0474 - accuracy: 0.9850 - val_loss: 0.1688 - val_accuracy: 0.9625
#
# Epoch 00028: val_loss did not improve from 0.12961
# Epoch 29/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0452 - accuracy: 0.9856 - val_loss: 0.1791 - val_accuracy: 0.9615
#
# Epoch 00029: val_loss did not improve from 0.12961
# Epoch 30/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0451 - accuracy: 0.9853 - val_loss: 0.1668 - val_accuracy: 0.9625
#
# Epoch 00030: val_loss did not improve from 0.12961
# Epoch 31/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0449 - accuracy: 0.9849 - val_loss: 0.1629 - val_accuracy: 0.9545
#
# Epoch 00031: val_loss did not improve from 0.12961
# Epoch 32/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0427 - accuracy: 0.9859 - val_loss: 0.1850 - val_accuracy: 0.9595
#
# Epoch 00032: val_loss did not improve from 0.12961
# Epoch 33/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0410 - accuracy: 0.9864 - val_loss: 0.1908 - val_accuracy: 0.9600
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.12961
# Epoch 34/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0388 - accuracy: 0.9871 - val_loss: 0.1881 - val_accuracy: 0.9630
#
# Epoch 00034: val_loss did not improve from 0.12961
# Epoch 35/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0369 - accuracy: 0.9873 - val_loss: 0.1945 - val_accuracy: 0.9625
#
# Epoch 00035: val_loss did not improve from 0.12961
# Epoch 36/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0356 - accuracy: 0.9879 - val_loss: 0.2041 - val_accuracy: 0.9635
#
# Epoch 00036: val_loss did not improve from 0.12961
# Epoch 37/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0348 - accuracy: 0.9880 - val_loss: 0.2107 - val_accuracy: 0.9620
# Epoch 00037: val_loss did not improve from 0.12961
# Epoch 38/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0342 - accuracy: 0.9884 - val_loss: 0.2086 - val_accuracy: 0.9595
#
# Epoch 00038: val_loss did not improve from 0.12961
# Epoch 39/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0331 - accuracy: 0.9883 - val_loss: 0.2202 - val_accuracy: 0.9615
#
# Epoch 00039: val_loss did not improve from 0.12961
# Epoch 40/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0320 - accuracy: 0.9887 - val_loss: 0.2133 - val_accuracy: 0.9615
#
# Epoch 00040: val_loss did not improve from 0.12961
# Score for fold 2: loss of 0.21329396963119507; accuracy of 96.14999890327454%
# Epoch 1/40
# 563/563 [==============================] - 78s 118ms/step - loss: 0.8782 - accuracy: 0.8391 - val_loss: 0.3406 - val_accuracy: 0.9005
#
# Epoch 00001: val_loss did not improve from 0.12961
# Epoch 2/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.3843 - accuracy: 0.8867 - val_loss: 0.2439 - val_accuracy: 0.9265
#
# Epoch 00002: val_loss did not improve from 0.12961
# Epoch 3/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2519 - accuracy: 0.9211 - val_loss: 0.1942 - val_accuracy: 0.9415
#
# Epoch 00003: val_loss did not improve from 0.12961
# Epoch 4/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2057 - accuracy: 0.9328 - val_loss: 0.2903 - val_accuracy: 0.8795
#
# Epoch 00004: val_loss did not improve from 0.12961
# Epoch 5/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.3255 - accuracy: 0.9053 - val_loss: 0.2419 - val_accuracy: 0.9210
#
# Epoch 00005: val_loss did not improve from 0.12961
# Epoch 6/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2465 - accuracy: 0.9231 - val_loss: 0.2039 - val_accuracy: 0.9375
#
# Epoch 00006: val_loss did not improve from 0.12961
# Epoch 7/40
# 563/563 [==============================] - 64s 115ms/step - loss: 0.2181 - accuracy: 0.9286 - val_loss: 0.2148 - val_accuracy: 0.9350
#
# Epoch 00007: val_loss did not improve from 0.12961
# Epoch 8/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1841 - accuracy: 0.9399 - val_loss: 0.1789 - val_accuracy: 0.9445
#
# Epoch 00008: val_loss did not improve from 0.12961
# Epoch 9/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1781 - accuracy: 0.9418 - val_loss: 0.2140 - val_accuracy: 0.9310
#
# Epoch 00009: val_loss did not improve from 0.12961
# Epoch 10/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1588 - accuracy: 0.9473 - val_loss: 0.1631 - val_accuracy: 0.9465
#
# Epoch 00010: val_loss did not improve from 0.12961
# Epoch 11/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1490 - accuracy: 0.9502 - val_loss: 0.1646 - val_accuracy: 0.9510
#
# Epoch 00011: val_loss did not improve from 0.12961
# Epoch 12/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1406 - accuracy: 0.9529 - val_loss: 0.3996 - val_accuracy: 0.8550
#
# Epoch 00012: val_loss did not improve from 0.12961
# Epoch 13/40
# 563/563 [==============================] - 64s 115ms/step - loss: 0.1380 - accuracy: 0.9549 - val_loss: 0.2290 - val_accuracy: 0.9275
#
# Epoch 00013: val_loss did not improve from 0.12961
# Epoch 14/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1345 - accuracy: 0.9557 - val_loss: 0.3793 - val_accuracy: 0.8725
#
# Epoch 00014: val_loss did not improve from 0.12961
# Epoch 15/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1506 - accuracy: 0.9528 - val_loss: 0.1531 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.12961
# Epoch 16/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1243 - accuracy: 0.9591 - val_loss: 0.1554 - val_accuracy: 0.9570
#
# Epoch 00016: val_loss did not improve from 0.12961
# Epoch 17/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1154 - accuracy: 0.9628 - val_loss: 0.1601 - val_accuracy: 0.9540
#
# Epoch 00017: val_loss did not improve from 0.12961
# Epoch 18/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1036 - accuracy: 0.9656 - val_loss: 0.1448 - val_accuracy: 0.9600
#
# Epoch 00018: val_loss did not improve from 0.12961
# Epoch 19/40
# 563/563 [==============================] - 69s 123ms/step - loss: 0.1215 - accuracy: 0.9603 - val_loss: 0.2099 - val_accuracy: 0.9405
#
# Epoch 00019: val_loss did not improve from 0.12961
# Epoch 20/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.1020 - accuracy: 0.9668 - val_loss: 0.1694 - val_accuracy: 0.9460
#
# Epoch 00020: val_loss did not improve from 0.12961
# Epoch 21/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.0963 - accuracy: 0.9682 - val_loss: 0.1544 - val_accuracy: 0.9575
#
# Epoch 00021: val_loss did not improve from 0.12961
# Epoch 22/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0909 - accuracy: 0.9709 - val_loss: 0.1686 - val_accuracy: 0.9480
#
# Epoch 00022: val_loss did not improve from 0.12961
# Epoch 23/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0907 - accuracy: 0.9696 - val_loss: 0.1339 - val_accuracy: 0.9615
#
# Epoch 00023: val_loss did not improve from 0.12961
# Epoch 24/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0962 - accuracy: 0.9691 - val_loss: 0.1546 - val_accuracy: 0.9555
#
# Epoch 00024: val_loss did not improve from 0.12961
# Epoch 25/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.0857 - accuracy: 0.9719 - val_loss: 0.1390 - val_accuracy: 0.9620
#
# Epoch 00025: val_loss did not improve from 0.12961
# Epoch 26/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.0748 - accuracy: 0.9752 - val_loss: 0.1353 - val_accuracy: 0.9595
#
# Epoch 00026: val_loss did not improve from 0.12961
# Epoch 27/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.0814 - accuracy: 0.9744 - val_loss: 0.1384 - val_accuracy: 0.9655
#
# Epoch 00027: val_loss did not improve from 0.12961
# Epoch 28/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.0705 - accuracy: 0.9767 - val_loss: 0.1632 - val_accuracy: 0.9530
#
# Epoch 00028: val_loss did not improve from 0.12961
# Epoch 29/40
# 563/563 [==============================] - 69s 123ms/step - loss: 0.0737 - accuracy: 0.9748 - val_loss: 0.1408 - val_accuracy: 0.9620
#
# Epoch 00029: val_loss did not improve from 0.12961
# Epoch 30/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.0714 - accuracy: 0.9764 - val_loss: 0.2259 - val_accuracy: 0.9420
#
# Epoch 00030: val_loss did not improve from 0.12961
# Epoch 31/40
# 563/563 [==============================] - 72s 127ms/step - loss: 0.0729 - accuracy: 0.9762 - val_loss: 0.1390 - val_accuracy: 0.9625
#
# Epoch 00031: val_loss did not improve from 0.12961
# Epoch 32/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.0600 - accuracy: 0.9803 - val_loss: 0.1458 - val_accuracy: 0.9675
#
# Epoch 00032: val_loss did not improve from 0.12961
# Epoch 33/40
# 563/563 [==============================] - 71s 125ms/step - loss: 0.0636 - accuracy: 0.9791 - val_loss: 0.5465 - val_accuracy: 0.9595
#
# Epoch 00033: val_loss did not improve from 0.12961
# Epoch 34/40
# 563/563 [==============================] - 70s 125ms/step - loss: 0.0672 - accuracy: 0.9785 - val_loss: 0.1432 - val_accuracy: 0.9600
#
# Epoch 00034: val_loss did not improve from 0.12961
# Epoch 35/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.1118 - accuracy: 0.9703 - val_loss: 0.1363 - val_accuracy: 0.9590
#
# Epoch 00035: val_loss did not improve from 0.12961
# Epoch 36/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0581 - accuracy: 0.9808 - val_loss: 0.1348 - val_accuracy: 0.9675
#
# Epoch 00036: val_loss did not improve from 0.12961
# Epoch 37/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0550 - accuracy: 0.9817 - val_loss: 0.1418 - val_accuracy: 0.9665
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00037: val_loss did not improve from 0.12961
# Epoch 38/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0464 - accuracy: 0.9844 - val_loss: 0.1358 - val_accuracy: 0.9665
#
# Epoch 00038: val_loss did not improve from 0.12961
# Epoch 39/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0430 - accuracy: 0.9856 - val_loss: 0.1484 - val_accuracy: 0.9650
#
# Epoch 00039: val_loss did not improve from 0.12961
# Epoch 40/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0437 - accuracy: 0.9848 - val_loss: 0.1520 - val_accuracy: 0.9705
#
# Epoch 00040: val_loss did not improve from 0.12961
# Score for fold 3: loss of 0.15202480554580688; accuracy of 97.04999923706055%
# Epoch 1/40
# 563/563 [==============================] - 80s 120ms/step - loss: 0.4641 - accuracy: 0.8824 - val_loss: 0.2269 - val_accuracy: 0.9310
#
# Epoch 00001: val_loss did not improve from 0.12961
# Epoch 2/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.2172 - accuracy: 0.9302 - val_loss: 0.2229 - val_accuracy: 0.9385
#
# Epoch 00002: val_loss did not improve from 0.12961
# Epoch 3/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1840 - accuracy: 0.9409 - val_loss: 0.1611 - val_accuracy: 0.9435
#
# Epoch 00003: val_loss did not improve from 0.12961
# Epoch 4/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.1653 - accuracy: 0.9458 - val_loss: 0.1644 - val_accuracy: 0.9515
#
# Epoch 00004: val_loss did not improve from 0.12961
# Epoch 5/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.4769 - accuracy: 0.8919 - val_loss: 0.7962 - val_accuracy: 0.7975
#
# Epoch 00005: val_loss did not improve from 0.12961
# Epoch 6/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.3921 - accuracy: 0.8982 - val_loss: 0.2899 - val_accuracy: 0.8980
#
# Epoch 00006: val_loss did not improve from 0.12961
# Epoch 7/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.2408 - accuracy: 0.9213 - val_loss: 0.2445 - val_accuracy: 0.9320
#
# Epoch 00007: val_loss did not improve from 0.12961
# Epoch 8/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.2218 - accuracy: 0.9276 - val_loss: 0.1945 - val_accuracy: 0.9420
#
# Epoch 00008: val_loss did not improve from 0.12961
# Epoch 9/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.2006 - accuracy: 0.9354 - val_loss: 0.2018 - val_accuracy: 0.9440
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.12961
# Epoch 10/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1680 - accuracy: 0.9429 - val_loss: 0.1614 - val_accuracy: 0.9500
#
# Epoch 00010: val_loss did not improve from 0.12961
# Epoch 11/40
# 563/563 [==============================] - 66s 116ms/step - loss: 0.1537 - accuracy: 0.9484 - val_loss: 0.1620 - val_accuracy: 0.9530
#
# Epoch 00011: val_loss did not improve from 0.12961
# Epoch 12/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1496 - accuracy: 0.9496 - val_loss: 0.1674 - val_accuracy: 0.9480
#
# Epoch 00012: val_loss did not improve from 0.12961
# Epoch 13/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1440 - accuracy: 0.9503 - val_loss: 0.1642 - val_accuracy: 0.9555
#
# Epoch 00013: val_loss did not improve from 0.12961
# Epoch 14/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1362 - accuracy: 0.9543 - val_loss: 0.1542 - val_accuracy: 0.9580
#
# Epoch 00014: val_loss did not improve from 0.12961
# Epoch 15/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1273 - accuracy: 0.9571 - val_loss: 0.1710 - val_accuracy: 0.9485
#
# Epoch 00015: val_loss did not improve from 0.12961
# Epoch 16/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1272 - accuracy: 0.9576 - val_loss: 0.1494 - val_accuracy: 0.9550
#
# Epoch 00016: val_loss did not improve from 0.12961
# Epoch 17/40
# 563/563 [==============================] - 70s 125ms/step - loss: 0.1490 - accuracy: 0.9551 - val_loss: 0.1528 - val_accuracy: 0.9525
#
# Epoch 00017: val_loss did not improve from 0.12961
# Epoch 18/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.1649 - accuracy: 0.9513 - val_loss: 0.1618 - val_accuracy: 0.9505
#
# Epoch 00018: val_loss did not improve from 0.12961
# Epoch 19/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.1182 - accuracy: 0.9627 - val_loss: 0.1493 - val_accuracy: 0.9575
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_loss did not improve from 0.12961
# Epoch 20/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0954 - accuracy: 0.9682 - val_loss: 0.1388 - val_accuracy: 0.9645
#
# Epoch 00020: val_loss did not improve from 0.12961
# Epoch 21/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0920 - accuracy: 0.9707 - val_loss: 0.1487 - val_accuracy: 0.9605
#
# Epoch 00021: val_loss did not improve from 0.12961
# Epoch 22/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0860 - accuracy: 0.9719 - val_loss: 0.1438 - val_accuracy: 0.9635
#
# Epoch 00022: val_loss did not improve from 0.12961
# Epoch 23/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0926 - accuracy: 0.9697 - val_loss: 0.1326 - val_accuracy: 0.9640
#
# Epoch 00023: val_loss did not improve from 0.12961
# Epoch 24/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0806 - accuracy: 0.9743 - val_loss: 0.1394 - val_accuracy: 0.9630
#
# Epoch 00024: val_loss did not improve from 0.12961
# Epoch 25/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0760 - accuracy: 0.9761 - val_loss: 0.1421 - val_accuracy: 0.9640
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_loss did not improve from 0.12961
# Epoch 26/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0651 - accuracy: 0.9787 - val_loss: 0.1437 - val_accuracy: 0.9645
#
# Epoch 00026: val_loss did not improve from 0.12961
# Epoch 27/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0638 - accuracy: 0.9798 - val_loss: 0.1419 - val_accuracy: 0.9645
#
# Epoch 00027: val_loss did not improve from 0.12961
# Epoch 28/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0611 - accuracy: 0.9804 - val_loss: 0.1438 - val_accuracy: 0.9660
#
# Epoch 00028: val_loss did not improve from 0.12961
# Epoch 29/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.0596 - accuracy: 0.9809 - val_loss: 0.1542 - val_accuracy: 0.9635
#
# Epoch 00029: val_loss did not improve from 0.12961
# Epoch 30/40
# 563/563 [==============================] - 70s 125ms/step - loss: 0.0587 - accuracy: 0.9812 - val_loss: 0.1499 - val_accuracy: 0.9645
#
# Epoch 00030: val_loss did not improve from 0.12961
# Epoch 31/40
# 563/563 [==============================] - 70s 125ms/step - loss: 0.0568 - accuracy: 0.9811 - val_loss: 0.1561 - val_accuracy: 0.9660
#
# Epoch 00031: val_loss did not improve from 0.12961
# Epoch 32/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.1514 - val_accuracy: 0.9665
#
# Epoch 00032: val_loss did not improve from 0.12961
# Epoch 33/40
# 563/563 [==============================] - 66s 116ms/step - loss: 0.0559 - accuracy: 0.9812 - val_loss: 0.1522 - val_accuracy: 0.9645
#
# Epoch 00033: val_loss did not improve from 0.12961
# Epoch 34/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 0.1709 - val_accuracy: 0.9610
#
# Epoch 00034: val_loss did not improve from 0.12961
# Epoch 35/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0529 - accuracy: 0.9826 - val_loss: 0.1725 - val_accuracy: 0.9675
#
# Epoch 00035: val_loss did not improve from 0.12961
# Epoch 36/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0532 - accuracy: 0.9831 - val_loss: 0.1881 - val_accuracy: 0.9635
#
# Epoch 00036: val_loss did not improve from 0.12961
# Epoch 37/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0512 - accuracy: 0.9830 - val_loss: 0.1728 - val_accuracy: 0.9660
#
# Epoch 00037: val_loss did not improve from 0.12961
# Epoch 38/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0503 - accuracy: 0.9834 - val_loss: 0.1770 - val_accuracy: 0.9660
#
# Epoch 00038: val_loss did not improve from 0.12961
# Epoch 39/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0554 - accuracy: 0.9810 - val_loss: 0.1615 - val_accuracy: 0.9665
#
# Epoch 00039: val_loss did not improve from 0.12961
# Epoch 40/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0494 - accuracy: 0.9836 - val_loss: 0.1718 - val_accuracy: 0.9665
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00040: val_loss did not improve from 0.12961
# Score for fold 4: loss of 0.17181795835494995; accuracy of 96.64999842643738%
# Epoch 1/40
# 563/563 [==============================] - 80s 120ms/step - loss: 0.5713 - accuracy: 0.8754 - val_loss: 0.2906 - val_accuracy: 0.9060
#
# Epoch 00001: val_loss did not improve from 0.12961
# Epoch 2/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2395 - accuracy: 0.9256 - val_loss: 0.2089 - val_accuracy: 0.9340
#
# Epoch 00002: val_loss did not improve from 0.12961
# Epoch 3/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1969 - accuracy: 0.9383 - val_loss: 0.2010 - val_accuracy: 0.9395
#
# Epoch 00003: val_loss did not improve from 0.12961
# Epoch 4/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.2330 - accuracy: 0.9276 - val_loss: 0.2062 - val_accuracy: 0.9445
#
# Epoch 00004: val_loss did not improve from 0.12961
# Epoch 5/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.3499 - accuracy: 0.9075 - val_loss: 0.2207 - val_accuracy: 0.9340
#
# Epoch 00005: val_loss did not improve from 0.12961
# Epoch 6/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.2007 - accuracy: 0.9362 - val_loss: 0.1762 - val_accuracy: 0.9470
#
# Epoch 00006: val_loss did not improve from 0.12961
# Epoch 7/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.1725 - accuracy: 0.9440 - val_loss: 0.1692 - val_accuracy: 0.9465
#
# Epoch 00007: val_loss did not improve from 0.12961
# Epoch 8/40
# 563/563 [==============================] - 69s 123ms/step - loss: 0.1583 - accuracy: 0.9477 - val_loss: 0.1795 - val_accuracy: 0.9425
#
# Epoch 00008: val_loss did not improve from 0.12961
# Epoch 9/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1441 - accuracy: 0.9528 - val_loss: 0.1959 - val_accuracy: 0.9375
#
# Epoch 00009: val_loss did not improve from 0.12961
# Epoch 10/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1396 - accuracy: 0.9539 - val_loss: 0.1747 - val_accuracy: 0.9475
#
# Epoch 00010: val_loss did not improve from 0.12961
# Epoch 11/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1314 - accuracy: 0.9560 - val_loss: 0.1460 - val_accuracy: 0.9595
#
# Epoch 00011: val_loss did not improve from 0.12961
# Epoch 12/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1269 - accuracy: 0.9596 - val_loss: 0.1498 - val_accuracy: 0.9540
#
# Epoch 00012: val_loss did not improve from 0.12961
# Epoch 13/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1214 - accuracy: 0.9606 - val_loss: 0.1482 - val_accuracy: 0.9570
#
# Epoch 00013: val_loss did not improve from 0.12961
# Epoch 14/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1108 - accuracy: 0.9634 - val_loss: 0.2149 - val_accuracy: 0.9415
#
# Epoch 00014: val_loss did not improve from 0.12961
# Epoch 15/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.6486 - accuracy: 0.8591 - val_loss: 0.2877 - val_accuracy: 0.9135
#
# Epoch 00015: val_loss did not improve from 0.12961
# Epoch 16/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2741 - accuracy: 0.9116 - val_loss: 0.2249 - val_accuracy: 0.9265
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.12961
# Epoch 17/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2217 - accuracy: 0.9281 - val_loss: 0.1967 - val_accuracy: 0.9395
#
# Epoch 00017: val_loss did not improve from 0.12961
# Epoch 18/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.2054 - accuracy: 0.9326 - val_loss: 0.1846 - val_accuracy: 0.9420
#
# Epoch 00018: val_loss did not improve from 0.12961
# Epoch 19/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1881 - accuracy: 0.9377 - val_loss: 0.1780 - val_accuracy: 0.9495
#
# Epoch 00019: val_loss did not improve from 0.12961
# Epoch 20/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1705 - accuracy: 0.9437 - val_loss: 0.2018 - val_accuracy: 0.9495
#
# Epoch 00020: val_loss did not improve from 0.12961
# Epoch 21/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1638 - accuracy: 0.9464 - val_loss: 0.2156 - val_accuracy: 0.9465
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.12961
# Epoch 22/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1410 - accuracy: 0.9538 - val_loss: 0.1644 - val_accuracy: 0.9505
#
# Epoch 00022: val_loss did not improve from 0.12961
# Epoch 23/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1316 - accuracy: 0.9547 - val_loss: 0.2376 - val_accuracy: 0.9545
#
# Epoch 00023: val_loss did not improve from 0.12961
# Epoch 24/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1320 - accuracy: 0.9566 - val_loss: 0.2053 - val_accuracy: 0.9480
#
# Epoch 00024: val_loss did not improve from 0.12961
# Epoch 25/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1253 - accuracy: 0.9583 - val_loss: 0.2179 - val_accuracy: 0.9540
#
# Epoch 00025: val_loss did not improve from 0.12961
# Epoch 26/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1118 - accuracy: 0.9620 - val_loss: 0.2554 - val_accuracy: 0.9520
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_loss did not improve from 0.12961
# Epoch 27/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1030 - accuracy: 0.9669 - val_loss: 0.2552 - val_accuracy: 0.9575
#
# Epoch 00027: val_loss did not improve from 0.12961
# Epoch 28/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0970 - accuracy: 0.9687 - val_loss: 0.1667 - val_accuracy: 0.9590
#
# Epoch 00028: val_loss did not improve from 0.12961
# Epoch 29/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0918 - accuracy: 0.9702 - val_loss: 0.1631 - val_accuracy: 0.9595
#
# Epoch 00029: val_loss did not improve from 0.12961
# Epoch 30/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0868 - accuracy: 0.9707 - val_loss: 0.1899 - val_accuracy: 0.9605
#
# Epoch 00030: val_loss did not improve from 0.12961
# Epoch 31/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0851 - accuracy: 0.9716 - val_loss: 0.2010 - val_accuracy: 0.9570
#
# Epoch 00031: val_loss did not improve from 0.12961
# Epoch 32/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0843 - accuracy: 0.9722 - val_loss: 0.1874 - val_accuracy: 0.9630
#
# Epoch 00032: val_loss did not improve from 0.12961
# Epoch 33/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0748 - accuracy: 0.9749 - val_loss: 0.2099 - val_accuracy: 0.9575
#
# Epoch 00033: val_loss did not improve from 0.12961
# Epoch 34/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.0750 - accuracy: 0.9748 - val_loss: 0.2655 - val_accuracy: 0.9640
#
# Epoch 00034: val_loss did not improve from 0.12961
# Epoch 35/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0712 - accuracy: 0.9759 - val_loss: 0.1928 - val_accuracy: 0.9590
#
# Epoch 00035: val_loss did not improve from 0.12961
# Epoch 36/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0693 - accuracy: 0.9766 - val_loss: 0.3038 - val_accuracy: 0.9465
#
# Epoch 00036: val_loss did not improve from 0.12961
# Epoch 37/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.0697 - accuracy: 0.9773 - val_loss: 0.2546 - val_accuracy: 0.9570
# Epoch 00037: val_loss did not improve from 0.12961
# Epoch 38/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.0643 - accuracy: 0.9793 - val_loss: 0.1874 - val_accuracy: 0.9640
#
# Epoch 00038: val_loss did not improve from 0.12961
# Epoch 39/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0675 - accuracy: 0.9778 - val_loss: 0.1590 - val_accuracy: 0.9565
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00039: val_loss did not improve from 0.12961
# Epoch 40/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.0623 - accuracy: 0.9797 - val_loss: 0.1581 - val_accuracy: 0.9595
#
# Epoch 00040: val_loss did not improve from 0.12961
# Score for fold 5: loss of 0.15810048580169678; accuracy of 95.95000147819519%
# Epoch 1/40
# 563/563 [==============================] - 81s 122ms/step - loss: 0.5225 - accuracy: 0.8759 - val_loss: 0.5260 - val_accuracy: 0.8175
#
# Epoch 00001: val_loss did not improve from 0.12961
# Epoch 2/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.3559 - accuracy: 0.9006 - val_loss: 0.2715 - val_accuracy: 0.9110
#
# Epoch 00002: val_loss did not improve from 0.12961
# Epoch 3/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.5602 - accuracy: 0.8911 - val_loss: 0.2975 - val_accuracy: 0.9155
#
# Epoch 00003: val_loss did not improve from 0.12961
# Epoch 4/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.2545 - accuracy: 0.9214 - val_loss: 0.2493 - val_accuracy: 0.9190
#
# Epoch 00004: val_loss did not improve from 0.12961
# Epoch 5/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.2162 - accuracy: 0.9336 - val_loss: 0.2050 - val_accuracy: 0.9345
#
# Epoch 00005: val_loss did not improve from 0.12961
# Epoch 6/40
# 563/563 [==============================] - 67s 120ms/step - loss: 0.2484 - accuracy: 0.9333 - val_loss: 0.2193 - val_accuracy: 0.9340
#
# Epoch 00006: val_loss did not improve from 0.12961
# Epoch 7/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.3066 - accuracy: 0.9172 - val_loss: 0.2183 - val_accuracy: 0.9330
#
# Epoch 00007: val_loss did not improve from 0.12961
# Epoch 8/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1908 - accuracy: 0.9384 - val_loss: 0.1853 - val_accuracy: 0.9435
#
# Epoch 00008: val_loss did not improve from 0.12961
# Epoch 9/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.1696 - accuracy: 0.9444 - val_loss: 0.1750 - val_accuracy: 0.9450
#
# Epoch 00009: val_loss did not improve from 0.12961
# Epoch 10/40
# 563/563 [==============================] - 67s 120ms/step - loss: 0.1653 - accuracy: 0.9477 - val_loss: 0.1737 - val_accuracy: 0.9455
#
# Epoch 00010: val_loss did not improve from 0.12961
# Epoch 11/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.2996 - accuracy: 0.9212 - val_loss: 0.3582 - val_accuracy: 0.8930
#
# Epoch 00011: val_loss did not improve from 0.12961
# Epoch 12/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.2249 - accuracy: 0.9335 - val_loss: 0.1942 - val_accuracy: 0.9415
#
# Epoch 00012: val_loss did not improve from 0.12961
# Epoch 13/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.1857 - accuracy: 0.9423 - val_loss: 0.4991 - val_accuracy: 0.9310
#
# Epoch 00013: val_loss did not improve from 0.12961
# Epoch 14/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1646 - accuracy: 0.9476 - val_loss: 0.1931 - val_accuracy: 0.9370
#
# Epoch 00014: val_loss did not improve from 0.12961
# Epoch 15/40
# 563/563 [==============================] - 70s 125ms/step - loss: 0.1711 - accuracy: 0.9482 - val_loss: 0.1990 - val_accuracy: 0.9440
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.12961
# Epoch 16/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.1199 - accuracy: 0.9617 - val_loss: 0.1716 - val_accuracy: 0.9480
#
# Epoch 00016: val_loss did not improve from 0.12961
# Epoch 17/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.1125 - accuracy: 0.9639 - val_loss: 0.1591 - val_accuracy: 0.9505
#
# Epoch 00017: val_loss did not improve from 0.12961
# Epoch 18/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.1045 - accuracy: 0.9658 - val_loss: 0.1699 - val_accuracy: 0.9515
#
# Epoch 00018: val_loss did not improve from 0.12961
# Epoch 19/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1007 - accuracy: 0.9661 - val_loss: 0.1916 - val_accuracy: 0.9475
#
# Epoch 00019: val_loss did not improve from 0.12961
# Epoch 20/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0981 - accuracy: 0.9677 - val_loss: 0.1655 - val_accuracy: 0.9535
#
# Epoch 00020: val_loss did not improve from 0.12961
# Epoch 21/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0923 - accuracy: 0.9695 - val_loss: 0.1529 - val_accuracy: 0.9570
#
# Epoch 00021: val_loss did not improve from 0.12961
# Epoch 22/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0886 - accuracy: 0.9715 - val_loss: 0.1670 - val_accuracy: 0.9500
#
# Epoch 00022: val_loss did not improve from 0.12961
# Epoch 23/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.0838 - accuracy: 0.9729 - val_loss: 0.1566 - val_accuracy: 0.9590
#
# Epoch 00023: val_loss did not improve from 0.12961
# Epoch 24/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0817 - accuracy: 0.9721 - val_loss: 0.2051 - val_accuracy: 0.9360
#
# Epoch 00024: val_loss did not improve from 0.12961
# Epoch 25/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0741 - accuracy: 0.9754 - val_loss: 0.1645 - val_accuracy: 0.9540
#
# Epoch 00025: val_loss did not improve from 0.12961
# Epoch 26/40
# 563/563 [==============================] - 70s 124ms/step - loss: 0.0747 - accuracy: 0.9759 - val_loss: 0.1861 - val_accuracy: 0.9570
#
# Epoch 00026: val_loss did not improve from 0.12961
# Epoch 27/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0756 - accuracy: 0.9757 - val_loss: 0.1614 - val_accuracy: 0.9620
#
# Epoch 00027: val_loss did not improve from 0.12961
# Epoch 28/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0665 - accuracy: 0.9782 - val_loss: 0.1928 - val_accuracy: 0.9565
#
# Epoch 00028: val_loss did not improve from 0.12961
# Epoch 29/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0640 - accuracy: 0.9792 - val_loss: 0.2028 - val_accuracy: 0.9555
#
# Epoch 00029: val_loss did not improve from 0.12961
# Epoch 30/40
# 563/563 [==============================] - 67s 118ms/step - loss: 0.0671 - accuracy: 0.9776 - val_loss: 0.1925 - val_accuracy: 0.9575
#
# Epoch 00030: val_loss did not improve from 0.12961
# Epoch 31/40
# ...
#
# Epoch 00002: val_loss did not improve from 0.12001
# Epoch 3/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.1745 - accuracy: 0.9445 - val_loss: 0.1718 - val_accuracy: 0.9415
#
# Epoch 00003: val_loss did not improve from 0.12001
# Epoch 4/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.6919 - accuracy: 0.8972 - val_loss: 0.3319 - val_accuracy: 0.8895
#
# Epoch 00004: val_loss did not improve from 0.12001
# Epoch 5/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.5564 - accuracy: 0.8969 - val_loss: 0.9309 - val_accuracy: 0.7330
#
# Epoch 00005: val_loss did not improve from 0.12001
# Epoch 6/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.3343 - accuracy: 0.8967 - val_loss: 0.2497 - val_accuracy: 0.9185
#
# Epoch 00006: val_loss did not improve from 0.12001
# Epoch 7/40
# 563/563 [==============================] - 70s 124ms/step - loss: 0.2671 - accuracy: 0.9201 - val_loss: 0.2221 - val_accuracy: 0.9255
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.12001
# Epoch 8/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.2099 - accuracy: 0.9339 - val_loss: 0.7224 - val_accuracy: 0.9375
#
# Epoch 00008: val_loss did not improve from 0.12001
# Epoch 9/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.1895 - accuracy: 0.9398 - val_loss: 0.1930 - val_accuracy: 0.9395
#
# Epoch 00009: val_loss did not improve from 0.12001
# Epoch 10/40
# 563/563 [==============================] - 67s 120ms/step - loss: 0.1807 - accuracy: 0.9439 - val_loss: 0.1749 - val_accuracy: 0.9425
#
# Epoch 00010: val_loss did not improve from 0.12001
# Epoch 11/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2452 - accuracy: 0.9244 - val_loss: 0.1963 - val_accuracy: 0.9365
#
# Epoch 00011: val_loss did not improve from 0.12001
# Epoch 12/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2191 - accuracy: 0.9317 - val_loss: 14.3771 - val_accuracy: 0.8630
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00012: val_loss did not improve from 0.12001
# Epoch 13/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1963 - accuracy: 0.9367 - val_loss: 0.1704 - val_accuracy: 0.9405
#
# Epoch 00013: val_loss did not improve from 0.12001
# Epoch 14/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1690 - accuracy: 0.9458 - val_loss: 0.2009 - val_accuracy: 0.9265
#
# Epoch 00014: val_loss did not improve from 0.12001
# Epoch 15/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1556 - accuracy: 0.9488 - val_loss: 0.1908 - val_accuracy: 0.9420
#
# Epoch 00015: val_loss did not improve from 0.12001
# Epoch 16/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.1446 - accuracy: 0.9521 - val_loss: 46.6518 - val_accuracy: 0.8950
#
# Epoch 00016: val_loss did not improve from 0.12001
# Epoch 17/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1399 - accuracy: 0.9542 - val_loss: 0.1602 - val_accuracy: 0.9450
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00017: val_loss did not improve from 0.12001
# Epoch 18/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1165 - accuracy: 0.9614 - val_loss: 0.3756 - val_accuracy: 0.8700
#
# Epoch 00018: val_loss did not improve from 0.12001
# Epoch 19/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1116 - accuracy: 0.9628 - val_loss: 0.2025 - val_accuracy: 0.9320
#
# Epoch 00019: val_loss did not improve from 0.12001
# Epoch 20/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1082 - accuracy: 0.9643 - val_loss: 0.1444 - val_accuracy: 0.9565
#
# Epoch 00020: val_loss did not improve from 0.12001
# Epoch 21/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1016 - accuracy: 0.9663 - val_loss: 0.1532 - val_accuracy: 0.9555
#
# Epoch 00021: val_loss did not improve from 0.12001
# Epoch 22/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1041 - accuracy: 0.9663 - val_loss: 0.1345 - val_accuracy: 0.9570
#
# Epoch 00022: val_loss did not improve from 0.12001
# Epoch 23/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0926 - accuracy: 0.9690 - val_loss: 0.1472 - val_accuracy: 0.9590
#
# Epoch 00023: val_loss did not improve from 0.12001
# Epoch 24/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0924 - accuracy: 0.9696 - val_loss: 0.1371 - val_accuracy: 0.9630
#
# Epoch 00024: val_loss did not improve from 0.12001
# Epoch 25/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0882 - accuracy: 0.9705 - val_loss: 0.1602 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.12001
# Epoch 26/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0905 - accuracy: 0.9701 - val_loss: 0.1647 - val_accuracy: 0.9475
#
# Epoch 00026: val_loss did not improve from 0.12001
# Epoch 27/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0803 - accuracy: 0.9741 - val_loss: 0.1420 - val_accuracy: 0.9585
#
# Epoch 00027: val_loss did not improve from 0.12001
# Epoch 28/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0739 - accuracy: 0.9754 - val_loss: 0.1283 - val_accuracy: 0.9660
#
# Epoch 00028: val_loss did not improve from 0.12001
# Epoch 29/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0719 - accuracy: 0.9762 - val_loss: 0.4329 - val_accuracy: 0.8805
#
# Epoch 00029: val_loss did not improve from 0.12001
# Epoch 30/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0754 - accuracy: 0.9759 - val_loss: 2.9974 - val_accuracy: 0.9070
#
# Epoch 00030: val_loss did not improve from 0.12001
# Epoch 31/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0706 - accuracy: 0.9768 - val_loss: 0.1343 - val_accuracy: 0.9595
#
# Epoch 00031: val_loss did not improve from 0.12001
# Epoch 32/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0696 - accuracy: 0.9775 - val_loss: 0.1995 - val_accuracy: 0.9285
#
# Epoch 00032: val_loss did not improve from 0.12001
# Epoch 33/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0678 - accuracy: 0.9781 - val_loss: 0.1522 - val_accuracy: 0.9605
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00033: val_loss did not improve from 0.12001
# Epoch 34/40
# 563/563 [==============================] - 65s 115ms/step - loss: 0.0618 - accuracy: 0.9803 - val_loss: 0.1416 - val_accuracy: 0.9620
# Epoch 00034: val_loss did not improve from 0.12001
# Epoch 35/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0582 - accuracy: 0.9817 - val_loss: 0.1405 - val_accuracy: 0.9585
#
# Epoch 00035: val_loss did not improve from 0.12001
# Epoch 36/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0572 - accuracy: 0.9812 - val_loss: 0.1541 - val_accuracy: 0.9600
#
# Epoch 00036: val_loss did not improve from 0.12001
# Epoch 37/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0584 - accuracy: 0.9813 - val_loss: 0.2161 - val_accuracy: 0.9515
#
# Epoch 00037: val_loss did not improve from 0.12001
# Epoch 38/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0554 - accuracy: 0.9821 - val_loss: 0.1639 - val_accuracy: 0.9605
#
# Epoch 00038: val_loss did not improve from 0.12001
# Epoch 39/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0524 - accuracy: 0.9828 - val_loss: 0.3686 - val_accuracy: 0.8890
#
# Epoch 00039: val_loss did not improve from 0.12001
# Epoch 40/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0547 - accuracy: 0.9823 - val_loss: 0.1759 - val_accuracy: 0.9520
#
# Epoch 00040: val_loss did not improve from 0.12001
# Score for fold 9: loss of 0.17589403688907623; accuracy of 95.20000219345093%
# Epoch 1/40
# 563/563 [==============================] - 79s 120ms/step - loss: 0.4693 - accuracy: 0.8752 - val_loss: 0.2684 - val_accuracy: 0.9170
#
# Epoch 00001: val_loss did not improve from 0.12001
# Epoch 2/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2370 - accuracy: 0.9257 - val_loss: 163.0119 - val_accuracy: 0.7655
#
# Epoch 00002: val_loss did not improve from 0.12001
# Epoch 3/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.6627 - accuracy: 0.8664 - val_loss: 0.3242 - val_accuracy: 0.9005
#
# Epoch 00003: val_loss did not improve from 0.12001
# Epoch 4/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2648 - accuracy: 0.9169 - val_loss: 0.2108 - val_accuracy: 0.9285
#
# Epoch 00004: val_loss did not improve from 0.12001
# Epoch 5/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2265 - accuracy: 0.9291 - val_loss: 0.6621 - val_accuracy: 0.8510
#
# Epoch 00005: val_loss did not improve from 0.12001
# Epoch 6/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.2097 - accuracy: 0.9330 - val_loss: 0.1970 - val_accuracy: 0.9410
#
# Epoch 00006: val_loss did not improve from 0.12001
# Epoch 7/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1880 - accuracy: 0.9394 - val_loss: 0.2112 - val_accuracy: 0.9375
#
# Epoch 00007: val_loss did not improve from 0.12001
# Epoch 8/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1694 - accuracy: 0.9458 - val_loss: 0.1978 - val_accuracy: 0.9440
#
# Epoch 00008: val_loss did not improve from 0.12001
# Epoch 9/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1565 - accuracy: 0.9495 - val_loss: 0.1889 - val_accuracy: 0.9495
#
# Epoch 00009: val_loss did not improve from 0.12001
# Epoch 10/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1545 - accuracy: 0.9498 - val_loss: 0.1738 - val_accuracy: 0.9505
#
# Epoch 00010: val_loss did not improve from 0.12001
# Epoch 11/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1489 - accuracy: 0.9508 - val_loss: 0.1840 - val_accuracy: 0.9460
#
# Epoch 00011: val_loss did not improve from 0.12001
# Epoch 12/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1360 - accuracy: 0.9557 - val_loss: 0.1812 - val_accuracy: 0.9470
#
# Epoch 00012: val_loss did not improve from 0.12001
# Epoch 13/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1526 - accuracy: 0.9535 - val_loss: 0.2411 - val_accuracy: 0.9220
#
# Epoch 00013: val_loss did not improve from 0.12001
# Epoch 14/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1436 - accuracy: 0.9537 - val_loss: 0.1722 - val_accuracy: 0.9515
#
# Epoch 00014: val_loss did not improve from 0.12001
# Epoch 15/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1208 - accuracy: 0.9617 - val_loss: 0.1614 - val_accuracy: 0.9535
#
# Epoch 00015: val_loss did not improve from 0.12001
# Epoch 16/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.1135 - accuracy: 0.9627 - val_loss: 0.2033 - val_accuracy: 0.9500
#
# Epoch 00016: val_loss did not improve from 0.12001
# Epoch 17/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1105 - accuracy: 0.9641 - val_loss: 0.2187 - val_accuracy: 0.9510
#
# Epoch 00017: val_loss did not improve from 0.12001
# Epoch 18/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1059 - accuracy: 0.9651 - val_loss: 0.1950 - val_accuracy: 0.9540
#
# Epoch 00018: val_loss did not improve from 0.12001
# Epoch 19/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1016 - accuracy: 0.9671 - val_loss: 0.3273 - val_accuracy: 0.9310
#
# Epoch 00019: val_loss did not improve from 0.12001
# Epoch 20/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0934 - accuracy: 0.9699 - val_loss: 0.1828 - val_accuracy: 0.9570
#
# Epoch 00020: val_loss did not improve from 0.12001
# Epoch 21/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1820 - accuracy: 0.9562 - val_loss: 77.8250 - val_accuracy: 0.9100
#
# Epoch 00021: val_loss did not improve from 0.12001
# Epoch 22/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.1415 - accuracy: 0.9549 - val_loss: 0.1675 - val_accuracy: 0.9565
#
# Epoch 00022: val_loss did not improve from 0.12001
# Epoch 23/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0995 - accuracy: 0.9673 - val_loss: 0.2007 - val_accuracy: 0.9555
#
# Epoch 00023: val_loss did not improve from 0.12001
# Epoch 24/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0868 - accuracy: 0.9725 - val_loss: 0.2339 - val_accuracy: 0.9380
#
# Epoch 00024: val_loss did not improve from 0.12001
# Epoch 25/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0782 - accuracy: 0.9746 - val_loss: 0.1724 - val_accuracy: 0.9605
#
# Epoch 00025: val_loss did not improve from 0.12001
# Epoch 26/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0816 - accuracy: 0.9734 - val_loss: 0.1729 - val_accuracy: 0.9600
#
# Epoch 00026: val_loss did not improve from 0.12001
# Epoch 27/40
# 563/563 [==============================] - 65s 116ms/step - loss: 0.0742 - accuracy: 0.9763 - val_loss: 0.1800 - val_accuracy: 0.9610
#
# Epoch 00027: val_loss did not improve from 0.12001
# Epoch 28/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0798 - accuracy: 0.9741 - val_loss: 0.1811 - val_accuracy: 0.9575
#
# Epoch 00028: val_loss did not improve from 0.12001
# Epoch 29/40
# 563/563 [==============================] - 69s 123ms/step - loss: 0.0703 - accuracy: 0.9773 - val_loss: 0.1774 - val_accuracy: 0.9605
#
# Epoch 00029: val_loss did not improve from 0.12001
# Epoch 30/40
# 563/563 [==============================] - 70s 124ms/step - loss: 0.0704 - accuracy: 0.9769 - val_loss: 0.1954 - val_accuracy: 0.9585
#
# Epoch 00030: val_loss did not improve from 0.12001
# Epoch 31/40
# 563/563 [==============================] - 69s 122ms/step - loss: 0.0780 - accuracy: 0.9753 - val_loss: 0.1742 - val_accuracy: 0.9630
#
# Epoch 00031: val_loss did not improve from 0.12001
# Epoch 32/40
# 563/563 [==============================] - 69s 123ms/step - loss: 0.0706 - accuracy: 0.9766 - val_loss: 0.2021 - val_accuracy: 0.9585
#
# Epoch 00032: val_loss did not improve from 0.12001
# Epoch 33/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0764 - accuracy: 0.9752 - val_loss: 0.2256 - val_accuracy: 0.9520
#
# Epoch 00033: val_loss did not improve from 0.12001
# Epoch 34/40
# 563/563 [==============================] - 66s 118ms/step - loss: 0.0686 - accuracy: 0.9777 - val_loss: 0.1920 - val_accuracy: 0.9615
#
# Epoch 00034: val_loss did not improve from 0.12001
# Epoch 35/40
# 563/563 [==============================] - 68s 120ms/step - loss: 0.0650 - accuracy: 0.9781 - val_loss: 0.1841 - val_accuracy: 0.9600
#
# Epoch 00035: val_loss did not improve from 0.12001
# Epoch 36/40
# 563/563 [==============================] - 68s 121ms/step - loss: 0.0683 - accuracy: 0.9778 - val_loss: 0.1924 - val_accuracy: 0.9635
#
# Epoch 00036: val_loss did not improve from 0.12001
# Epoch 37/40
# 563/563 [==============================] - 67s 119ms/step - loss: 0.0589 - accuracy: 0.9808 - val_loss: 0.1955 - val_accuracy: 0.9630
#
# Epoch 00037: val_loss did not improve from 0.12001
# Epoch 38/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0611 - accuracy: 0.9799 - val_loss: 0.2224 - val_accuracy: 0.9605
#
# Epoch 00038: val_loss did not improve from 0.12001
# Epoch 39/40
# 563/563 [==============================] - 66s 117ms/step - loss: 0.0608 - accuracy: 0.9806 - val_loss: 0.2004 - val_accuracy: 0.9580
#
# Epoch 00039: val_loss did not improve from 0.12001
# Epoch 40/40
# 563/563 [==============================] - 67s 120ms/step - loss: 0.0618 - accuracy: 0.9801 - val_loss: 0.2213 - val_accuracy: 0.9515
#
# Epoch 00040: val_loss did not improve from 0.12001
# Score for fold 10: loss of 0.22126883268356323; accuracy of 95.14999985694885%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.18617752194404602 - Accuracy: 97.29999899864197%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.21329396963119507 - Accuracy: 96.14999890327454%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.15202480554580688 - Accuracy: 97.04999923706055%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.17181795835494995 - Accuracy: 96.64999842643738%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.15810048580169678 - Accuracy: 95.95000147819519%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.20622238516807556 - Accuracy: 96.10000252723694%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.25329744815826416 - Accuracy: 95.80000042915344%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.1974804550409317 - Accuracy: 95.70000171661377%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.17589403688907623 - Accuracy: 95.20000219345093%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.22126883268356323 - Accuracy: 95.14999985694885%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.10500037670135% (+- 0.006806055038168915)
# > Loss: 0.19355778992176056
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of DenseNet169"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of DenseNet169      |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9611      | 0.0068       |
# | Loss     | 0.1936      | 0.0295       |
# | Macro F1 | 0.8998      | 0.0141       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.988       | 0.0036       |
# | Acc      | 0.99        | 0.0034       |
# | F1       | 0.9906      | 0.0033       |
# | MCC      | 0.9801      | 0.0069       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for DenseNet169 across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(head_model, history, 'loss', 0,1)

# %%
eval_metric(head_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - DenseNet169")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
