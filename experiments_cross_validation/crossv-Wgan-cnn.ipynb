# %% [markdown]
# # WGAN-CNN

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses grayscale, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021.
#
# The Wasserstein-GAN generated images are used
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 150000 # Set very high so it uses all the images in the directory, does not actually take 150,000 images

# Number of epochs
epoch_t = 30 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import time

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/experiments_cross_validation"
    for files in os.listdir(dir):
        if "wgan-cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: wgan-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# No matches found
# New folder name: wgan-cnn-local-v001
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"
    path_root_gen = ''

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"
    path_root_gen = "C:/Users/Max/Documents/image_data/rightsize_wgan_images"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# Count number of files in the CGAN folder

# %%
batches_gen = ImageDataGenerator().flow_from_directory(
    directory     = path_root_gen, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs_gen, labels_gen = next(batches_gen)
# Out:
# Found 42528 images belonging to 10 classes.

# %%
plt.imshow(imgs_gen[900],cmap='gray')

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0
imgs_gen = imgs_gen / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Add generated images to training data   
    train_images = np.concatenate((imgs[train], imgs_gen), axis = 0)
    train_labels = to_categorical(np.concatenate((np.argmax(labels[train], axis = 1), np.argmax(labels_gen, axis = 1)), axis = 0))

    # Run the CNN
    history.append(
        Malware_model.fit(
        train_images, 
        train_labels, 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    multi_f1_per_fold.append(f1_score(y_true2, y_pred2, average='macro'))
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(train_labels)/train_labels.shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/30
# 2076/2076 [==============================] - 13s 6ms/step - loss: 0.3498 - accuracy: 0.8948 - val_loss: 0.2424 - val_accuracy: 0.9235
#
# Epoch 00001: val_loss improved from inf to 0.24238, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1350 - accuracy: 0.9615 - val_loss: 0.2077 - val_accuracy: 0.9439
#
# Epoch 00002: val_loss improved from 0.24238 to 0.20770, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1114 - accuracy: 0.9669 - val_loss: 0.1818 - val_accuracy: 0.9450
#
# Epoch 00003: val_loss improved from 0.20770 to 0.18182, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0952 - accuracy: 0.9714 - val_loss: 0.1714 - val_accuracy: 0.9446
#
# Epoch 00004: val_loss improved from 0.18182 to 0.17138, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0867 - accuracy: 0.9735 - val_loss: 0.1582 - val_accuracy: 0.9488
#
# Epoch 00005: val_loss improved from 0.17138 to 0.15823, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0801 - accuracy: 0.9756 - val_loss: 0.1596 - val_accuracy: 0.9522
#
# Epoch 00006: val_loss did not improve from 0.15823
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0743 - accuracy: 0.9770 - val_loss: 0.1577 - val_accuracy: 0.9522
#
# Epoch 00007: val_loss improved from 0.15823 to 0.15774, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 8/30
# 2076/2076 [==============================] - 12s 6ms/step - loss: 0.0692 - accuracy: 0.9779 - val_loss: 0.1629 - val_accuracy: 0.9514
#
# Epoch 00008: val_loss did not improve from 0.15774
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0658 - accuracy: 0.9795 - val_loss: 0.1687 - val_accuracy: 0.9522
#
# Epoch 00009: val_loss did not improve from 0.15774
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0619 - accuracy: 0.9806 - val_loss: 0.1577 - val_accuracy: 0.9556
#
# Epoch 00010: val_loss did not improve from 0.15774
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0603 - accuracy: 0.9809 - val_loss: 0.1496 - val_accuracy: 0.9563
#
# Epoch 00011: val_loss improved from 0.15774 to 0.14962, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0599 - accuracy: 0.9811 - val_loss: 0.1349 - val_accuracy: 0.9589
#
# Epoch 00012: val_loss improved from 0.14962 to 0.13490, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0558 - accuracy: 0.9819 - val_loss: 0.1406 - val_accuracy: 0.9593
#
# Epoch 00013: val_loss did not improve from 0.13490
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0526 - accuracy: 0.9828 - val_loss: 0.1332 - val_accuracy: 0.9616
#
# Epoch 00014: val_loss improved from 0.13490 to 0.13323, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0501 - accuracy: 0.9836 - val_loss: 0.1741 - val_accuracy: 0.9567
#
# Epoch 00015: val_loss did not improve from 0.13323
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0501 - accuracy: 0.9843 - val_loss: 0.1329 - val_accuracy: 0.9605
#
# Epoch 00016: val_loss improved from 0.13323 to 0.13285, saving model to /Users/Max/Documents/GitHub/experiments_cross_validation/wgan-cnn-local-v001\model.h5
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0467 - accuracy: 0.9846 - val_loss: 0.1446 - val_accuracy: 0.9597
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0454 - accuracy: 0.9857 - val_loss: 0.1459 - val_accuracy: 0.9582
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0474 - accuracy: 0.9847 - val_loss: 0.1427 - val_accuracy: 0.9597
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0373 - accuracy: 0.9876 - val_loss: 0.1426 - val_accuracy: 0.9616
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0357 - accuracy: 0.9881 - val_loss: 0.1380 - val_accuracy: 0.9608
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.1411 - val_accuracy: 0.9605
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.1366 - val_accuracy: 0.9635
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0307 - accuracy: 0.9898 - val_loss: 0.1483 - val_accuracy: 0.9612
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0303 - accuracy: 0.9899 - val_loss: 0.1504 - val_accuracy: 0.9612
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0304 - accuracy: 0.9898 - val_loss: 0.1503 - val_accuracy: 0.9612
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.1469 - val_accuracy: 0.9638
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0292 - accuracy: 0.9902 - val_loss: 0.1423 - val_accuracy: 0.9635
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.1427 - val_accuracy: 0.9620
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0278 - accuracy: 0.9907 - val_loss: 0.1639 - val_accuracy: 0.9638
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 1: loss of 0.1638597995042801; accuracy of 96.38417959213257%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.3684 - accuracy: 0.8852 - val_loss: 0.3089 - val_accuracy: 0.9115
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.1418 - accuracy: 0.9600 - val_loss: 0.2667 - val_accuracy: 0.9205
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.1099 - accuracy: 0.9681 - val_loss: 0.2398 - val_accuracy: 0.9303
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0964 - accuracy: 0.9711 - val_loss: 0.2214 - val_accuracy: 0.9330
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0886 - accuracy: 0.9738 - val_loss: 0.2213 - val_accuracy: 0.9405
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0779 - accuracy: 0.9759 - val_loss: 0.2149 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0750 - accuracy: 0.9772 - val_loss: 0.1944 - val_accuracy: 0.9424
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0681 - accuracy: 0.9783 - val_loss: 0.1983 - val_accuracy: 0.9454
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0655 - accuracy: 0.9795 - val_loss: 0.2050 - val_accuracy: 0.9473
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0615 - accuracy: 0.9807 - val_loss: 0.2051 - val_accuracy: 0.9443
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0589 - accuracy: 0.9813 - val_loss: 0.1996 - val_accuracy: 0.9476
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0558 - accuracy: 0.9818 - val_loss: 0.2163 - val_accuracy: 0.9492
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 0.2078 - val_accuracy: 0.9461
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0526 - accuracy: 0.9831 - val_loss: 0.1988 - val_accuracy: 0.9495
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0513 - accuracy: 0.9834 - val_loss: 0.2071 - val_accuracy: 0.9461
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0500 - accuracy: 0.9839 - val_loss: 0.2030 - val_accuracy: 0.9503
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0486 - accuracy: 0.9838 - val_loss: 0.2571 - val_accuracy: 0.9495
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0477 - accuracy: 0.9847 - val_loss: 0.2329 - val_accuracy: 0.9488
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0458 - accuracy: 0.9854 - val_loss: 0.2105 - val_accuracy: 0.9499
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0444 - accuracy: 0.9857 - val_loss: 0.2316 - val_accuracy: 0.9503
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0429 - accuracy: 0.9864 - val_loss: 0.1967 - val_accuracy: 0.9529
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0427 - accuracy: 0.9862 - val_loss: 0.2142 - val_accuracy: 0.9518
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0440 - accuracy: 0.9858 - val_loss: 0.2051 - val_accuracy: 0.9514
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0431 - accuracy: 0.9860 - val_loss: 0.2164 - val_accuracy: 0.9537
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0391 - accuracy: 0.9872 - val_loss: 0.2240 - val_accuracy: 0.9540
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0415 - accuracy: 0.9865 - val_loss: 0.1966 - val_accuracy: 0.9529
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0395 - accuracy: 0.9874 - val_loss: 0.2029 - val_accuracy: 0.9529
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0405 - accuracy: 0.9871 - val_loss: 0.2259 - val_accuracy: 0.9503
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.1992 - val_accuracy: 0.9525
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 10s 5ms/step - loss: 0.0374 - accuracy: 0.9882 - val_loss: 0.2208 - val_accuracy: 0.9529
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 2: loss of 0.22078050673007965; accuracy of 95.29190063476562%
# Epoch 1/30
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.3688 - accuracy: 0.8876 - val_loss: 0.2818 - val_accuracy: 0.9145
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1429 - accuracy: 0.9612 - val_loss: 0.2255 - val_accuracy: 0.9333
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1131 - accuracy: 0.9671 - val_loss: 0.2025 - val_accuracy: 0.9348
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0974 - accuracy: 0.9707 - val_loss: 0.1846 - val_accuracy: 0.9443
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0889 - accuracy: 0.9734 - val_loss: 0.1663 - val_accuracy: 0.9514
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0822 - accuracy: 0.9748 - val_loss: 0.1652 - val_accuracy: 0.9514
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0786 - accuracy: 0.9753 - val_loss: 0.2152 - val_accuracy: 0.9379
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0720 - accuracy: 0.9773 - val_loss: 0.1607 - val_accuracy: 0.9507
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0696 - accuracy: 0.9784 - val_loss: 0.1498 - val_accuracy: 0.9529
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0632 - accuracy: 0.9798 - val_loss: 0.1490 - val_accuracy: 0.9540
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0639 - accuracy: 0.9798 - val_loss: 0.1806 - val_accuracy: 0.9507
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0607 - accuracy: 0.9806 - val_loss: 0.1464 - val_accuracy: 0.9540
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0591 - accuracy: 0.9817 - val_loss: 0.1536 - val_accuracy: 0.9548
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0569 - accuracy: 0.9820 - val_loss: 0.1406 - val_accuracy: 0.9537
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0568 - accuracy: 0.9817 - val_loss: 0.1561 - val_accuracy: 0.9529
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0529 - accuracy: 0.9832 - val_loss: 0.1487 - val_accuracy: 0.9540
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0499 - accuracy: 0.9839 - val_loss: 0.1388 - val_accuracy: 0.9567
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0516 - accuracy: 0.9837 - val_loss: 0.1430 - val_accuracy: 0.9563
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 0.1543 - val_accuracy: 0.9544
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0482 - accuracy: 0.9842 - val_loss: 0.1513 - val_accuracy: 0.9559
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0457 - accuracy: 0.9853 - val_loss: 0.1353 - val_accuracy: 0.9567
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0455 - accuracy: 0.9853 - val_loss: 0.1505 - val_accuracy: 0.9567
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0367 - accuracy: 0.9879 - val_loss: 0.1516 - val_accuracy: 0.9556
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.1508 - val_accuracy: 0.9563
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.1497 - val_accuracy: 0.9567
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0324 - accuracy: 0.9894 - val_loss: 0.1516 - val_accuracy: 0.9574
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.1539 - val_accuracy: 0.9589
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.1666 - val_accuracy: 0.9578
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.1463 - val_accuracy: 0.9589
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0294 - accuracy: 0.9905 - val_loss: 0.1643 - val_accuracy: 0.9597
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 3: loss of 0.16426315903663635; accuracy of 95.96986770629883%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.3846 - accuracy: 0.8813 - val_loss: 0.2820 - val_accuracy: 0.9077
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1426 - accuracy: 0.9599 - val_loss: 0.2282 - val_accuracy: 0.9209
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1159 - accuracy: 0.9664 - val_loss: 0.2183 - val_accuracy: 0.9318
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1002 - accuracy: 0.9705 - val_loss: 0.2114 - val_accuracy: 0.9322
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0883 - accuracy: 0.9737 - val_loss: 0.1973 - val_accuracy: 0.9390
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0820 - accuracy: 0.9751 - val_loss: 0.1933 - val_accuracy: 0.9416
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0765 - accuracy: 0.9762 - val_loss: 0.1951 - val_accuracy: 0.9416
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0704 - accuracy: 0.9780 - val_loss: 0.1882 - val_accuracy: 0.9461
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0675 - accuracy: 0.9793 - val_loss: 0.1848 - val_accuracy: 0.9420
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0640 - accuracy: 0.9795 - val_loss: 0.2132 - val_accuracy: 0.9420
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0635 - accuracy: 0.9806 - val_loss: 0.1812 - val_accuracy: 0.9454
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0595 - accuracy: 0.9810 - val_loss: 0.1787 - val_accuracy: 0.9465
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0563 - accuracy: 0.9824 - val_loss: 0.1913 - val_accuracy: 0.9446
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0555 - accuracy: 0.9825 - val_loss: 0.1919 - val_accuracy: 0.9488
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0536 - accuracy: 0.9827 - val_loss: 0.1967 - val_accuracy: 0.9454
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0541 - accuracy: 0.9827 - val_loss: 0.1761 - val_accuracy: 0.9507
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0507 - accuracy: 0.9841 - val_loss: 0.1907 - val_accuracy: 0.9469
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0495 - accuracy: 0.9843 - val_loss: 0.1894 - val_accuracy: 0.9507
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0493 - accuracy: 0.9844 - val_loss: 0.1827 - val_accuracy: 0.9488
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0486 - accuracy: 0.9843 - val_loss: 0.1977 - val_accuracy: 0.9473
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0461 - accuracy: 0.9854 - val_loss: 0.1918 - val_accuracy: 0.9533
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0457 - accuracy: 0.9857 - val_loss: 0.2244 - val_accuracy: 0.9503
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0457 - accuracy: 0.9854 - val_loss: 0.1924 - val_accuracy: 0.9503
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0434 - accuracy: 0.9860 - val_loss: 0.1952 - val_accuracy: 0.9476
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0452 - accuracy: 0.9859 - val_loss: 0.1852 - val_accuracy: 0.9495
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0414 - accuracy: 0.9864 - val_loss: 0.1903 - val_accuracy: 0.9514
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0345 - accuracy: 0.9891 - val_loss: 0.2034 - val_accuracy: 0.9548
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.1862 - val_accuracy: 0.9533
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0314 - accuracy: 0.9895 - val_loss: 0.2060 - val_accuracy: 0.9507
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.1942 - val_accuracy: 0.9529
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 4: loss of 0.19420327246189117; accuracy of 95.29190063476562%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.3757 - accuracy: 0.8839 - val_loss: 0.2853 - val_accuracy: 0.9164
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1435 - accuracy: 0.9596 - val_loss: 0.2457 - val_accuracy: 0.9299
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1174 - accuracy: 0.9661 - val_loss: 0.2331 - val_accuracy: 0.9299
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1009 - accuracy: 0.9703 - val_loss: 0.2108 - val_accuracy: 0.9394
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0898 - accuracy: 0.9729 - val_loss: 0.2027 - val_accuracy: 0.9386
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0822 - accuracy: 0.9749 - val_loss: 0.1997 - val_accuracy: 0.9439
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0775 - accuracy: 0.9761 - val_loss: 0.1938 - val_accuracy: 0.9416
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0732 - accuracy: 0.9774 - val_loss: 0.2203 - val_accuracy: 0.9363
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0694 - accuracy: 0.9789 - val_loss: 0.1935 - val_accuracy: 0.9454
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0682 - accuracy: 0.9787 - val_loss: 0.1830 - val_accuracy: 0.9450
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0662 - accuracy: 0.9788 - val_loss: 0.1827 - val_accuracy: 0.9469
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0612 - accuracy: 0.9807 - val_loss: 0.1849 - val_accuracy: 0.9499
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0572 - accuracy: 0.9817 - val_loss: 0.1889 - val_accuracy: 0.9484
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0592 - accuracy: 0.9814 - val_loss: 0.1814 - val_accuracy: 0.9476
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.1873 - val_accuracy: 0.9473
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0524 - accuracy: 0.9830 - val_loss: 0.1793 - val_accuracy: 0.9499
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0544 - accuracy: 0.9830 - val_loss: 0.1764 - val_accuracy: 0.9518
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0516 - accuracy: 0.9837 - val_loss: 0.1760 - val_accuracy: 0.9510
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0505 - accuracy: 0.9839 - val_loss: 0.1909 - val_accuracy: 0.9480
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0472 - accuracy: 0.9848 - val_loss: 0.1896 - val_accuracy: 0.9514
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0471 - accuracy: 0.9853 - val_loss: 0.1749 - val_accuracy: 0.9525
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0491 - accuracy: 0.9845 - val_loss: 0.1766 - val_accuracy: 0.9525
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0464 - accuracy: 0.9856 - val_loss: 0.1869 - val_accuracy: 0.9503
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0479 - accuracy: 0.9846 - val_loss: 0.1862 - val_accuracy: 0.9514
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0457 - accuracy: 0.9855 - val_loss: 0.2019 - val_accuracy: 0.9510
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0468 - accuracy: 0.9849 - val_loss: 0.1654 - val_accuracy: 0.9537
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0420 - accuracy: 0.9865 - val_loss: 0.1939 - val_accuracy: 0.9525
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0442 - accuracy: 0.9857 - val_loss: 0.1917 - val_accuracy: 0.9510
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.1979 - val_accuracy: 0.9507
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.1947 - val_accuracy: 0.9537
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 5: loss of 0.1947188377380371; accuracy of 95.36722898483276%
# Epoch 1/30
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.4087 - accuracy: 0.8713 - val_loss: 0.3146 - val_accuracy: 0.9077
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1560 - accuracy: 0.9558 - val_loss: 0.2295 - val_accuracy: 0.9288
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1260 - accuracy: 0.9637 - val_loss: 0.2163 - val_accuracy: 0.9318
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1083 - accuracy: 0.9675 - val_loss: 0.2300 - val_accuracy: 0.9318
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0988 - accuracy: 0.9702 - val_loss: 0.1946 - val_accuracy: 0.9446
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0921 - accuracy: 0.9723 - val_loss: 0.1985 - val_accuracy: 0.9424
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0838 - accuracy: 0.9743 - val_loss: 0.1908 - val_accuracy: 0.9435
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0791 - accuracy: 0.9752 - val_loss: 0.1879 - val_accuracy: 0.9450
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0743 - accuracy: 0.9760 - val_loss: 0.1835 - val_accuracy: 0.9454
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0717 - accuracy: 0.9773 - val_loss: 0.1861 - val_accuracy: 0.9488
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0681 - accuracy: 0.9787 - val_loss: 0.1724 - val_accuracy: 0.9503
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0656 - accuracy: 0.9790 - val_loss: 0.1721 - val_accuracy: 0.9484
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0635 - accuracy: 0.9803 - val_loss: 0.1815 - val_accuracy: 0.9488
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0596 - accuracy: 0.9808 - val_loss: 0.1853 - val_accuracy: 0.9510
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0612 - accuracy: 0.9806 - val_loss: 0.1929 - val_accuracy: 0.9495
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0578 - accuracy: 0.9818 - val_loss: 0.1777 - val_accuracy: 0.9525
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0581 - accuracy: 0.9821 - val_loss: 0.1716 - val_accuracy: 0.9529
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0532 - accuracy: 0.9828 - val_loss: 0.1743 - val_accuracy: 0.9525
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0503 - accuracy: 0.9834 - val_loss: 0.1753 - val_accuracy: 0.9544
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0520 - accuracy: 0.9836 - val_loss: 0.2027 - val_accuracy: 0.9484
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0490 - accuracy: 0.9847 - val_loss: 0.1849 - val_accuracy: 0.9495
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0516 - accuracy: 0.9836 - val_loss: 0.1725 - val_accuracy: 0.9514
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0465 - accuracy: 0.9845 - val_loss: 0.1840 - val_accuracy: 0.9492
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0463 - accuracy: 0.9851 - val_loss: 0.1803 - val_accuracy: 0.9495
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0385 - accuracy: 0.9869 - val_loss: 0.1720 - val_accuracy: 0.9522
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.1845 - val_accuracy: 0.9525
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0357 - accuracy: 0.9883 - val_loss: 0.1837 - val_accuracy: 0.9525
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.1866 - val_accuracy: 0.9540
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0335 - accuracy: 0.9888 - val_loss: 0.2008 - val_accuracy: 0.9514
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0301 - accuracy: 0.9901 - val_loss: 0.1929 - val_accuracy: 0.9552
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 6: loss of 0.19286978244781494; accuracy of 95.51789164543152%
# Epoch 1/30
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.3686 - accuracy: 0.8868 - val_loss: 0.3149 - val_accuracy: 0.8991
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1436 - accuracy: 0.9605 - val_loss: 0.2527 - val_accuracy: 0.9250
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1166 - accuracy: 0.9658 - val_loss: 0.2167 - val_accuracy: 0.9345
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1016 - accuracy: 0.9706 - val_loss: 0.2321 - val_accuracy: 0.9315
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0891 - accuracy: 0.9733 - val_loss: 0.2051 - val_accuracy: 0.9326
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0826 - accuracy: 0.9751 - val_loss: 0.1907 - val_accuracy: 0.9394
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0771 - accuracy: 0.9765 - val_loss: 0.2101 - val_accuracy: 0.9348
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0748 - accuracy: 0.9766 - val_loss: 0.2026 - val_accuracy: 0.9382
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0702 - accuracy: 0.9785 - val_loss: 0.2180 - val_accuracy: 0.9326
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0649 - accuracy: 0.9795 - val_loss: 0.1910 - val_accuracy: 0.9405
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0626 - accuracy: 0.9802 - val_loss: 0.1836 - val_accuracy: 0.9446
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0608 - accuracy: 0.9805 - val_loss: 0.2060 - val_accuracy: 0.9431
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0587 - accuracy: 0.9813 - val_loss: 0.2061 - val_accuracy: 0.9461
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0563 - accuracy: 0.9823 - val_loss: 0.1817 - val_accuracy: 0.9476
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0540 - accuracy: 0.9831 - val_loss: 0.1846 - val_accuracy: 0.9450
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0533 - accuracy: 0.9830 - val_loss: 0.1985 - val_accuracy: 0.9431
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0500 - accuracy: 0.9840 - val_loss: 0.1893 - val_accuracy: 0.9469
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0508 - accuracy: 0.9838 - val_loss: 0.1992 - val_accuracy: 0.9431
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0478 - accuracy: 0.9851 - val_loss: 0.1925 - val_accuracy: 0.9461
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0405 - accuracy: 0.9873 - val_loss: 0.1915 - val_accuracy: 0.9469
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0369 - accuracy: 0.9879 - val_loss: 0.1961 - val_accuracy: 0.9465
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0354 - accuracy: 0.9882 - val_loss: 0.1929 - val_accuracy: 0.9476
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0351 - accuracy: 0.9884 - val_loss: 0.1980 - val_accuracy: 0.9495
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0346 - accuracy: 0.9886 - val_loss: 0.1946 - val_accuracy: 0.9480
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0325 - accuracy: 0.9893 - val_loss: 0.2020 - val_accuracy: 0.9476
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0339 - accuracy: 0.9890 - val_loss: 0.1923 - val_accuracy: 0.9492
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0322 - accuracy: 0.9894 - val_loss: 0.2141 - val_accuracy: 0.9480
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0304 - accuracy: 0.9901 - val_loss: 0.2040 - val_accuracy: 0.9499
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0308 - accuracy: 0.9899 - val_loss: 0.2122 - val_accuracy: 0.9488
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0309 - accuracy: 0.9899 - val_loss: 0.2004 - val_accuracy: 0.9488
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 7: loss of 0.2003834992647171; accuracy of 94.87758874893188%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.3823 - accuracy: 0.8843 - val_loss: 0.3614 - val_accuracy: 0.8896
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1490 - accuracy: 0.9581 - val_loss: 0.2632 - val_accuracy: 0.9179
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1194 - accuracy: 0.9652 - val_loss: 0.2357 - val_accuracy: 0.9303
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1042 - accuracy: 0.9686 - val_loss: 0.2130 - val_accuracy: 0.9348
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0934 - accuracy: 0.9715 - val_loss: 0.2151 - val_accuracy: 0.9386
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0870 - accuracy: 0.9736 - val_loss: 0.2041 - val_accuracy: 0.9375
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0798 - accuracy: 0.9755 - val_loss: 0.1990 - val_accuracy: 0.9412
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0757 - accuracy: 0.9761 - val_loss: 0.1971 - val_accuracy: 0.9416
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0701 - accuracy: 0.9783 - val_loss: 0.2077 - val_accuracy: 0.9420
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0677 - accuracy: 0.9791 - val_loss: 0.2026 - val_accuracy: 0.9409
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0638 - accuracy: 0.9799 - val_loss: 0.2023 - val_accuracy: 0.9431
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0627 - accuracy: 0.9801 - val_loss: 0.1988 - val_accuracy: 0.9458
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0610 - accuracy: 0.9805 - val_loss: 0.2004 - val_accuracy: 0.9443
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0569 - accuracy: 0.9815 - val_loss: 0.2020 - val_accuracy: 0.9461
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0551 - accuracy: 0.9824 - val_loss: 0.1959 - val_accuracy: 0.9503
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 0.2019 - val_accuracy: 0.9473
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0523 - accuracy: 0.9833 - val_loss: 0.2059 - val_accuracy: 0.9446
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0547 - accuracy: 0.9826 - val_loss: 0.2019 - val_accuracy: 0.9484
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0487 - accuracy: 0.9844 - val_loss: 0.1946 - val_accuracy: 0.9514
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0497 - accuracy: 0.9842 - val_loss: 0.1980 - val_accuracy: 0.9480
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0471 - accuracy: 0.9847 - val_loss: 0.1875 - val_accuracy: 0.9484
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0465 - accuracy: 0.9853 - val_loss: 0.1785 - val_accuracy: 0.9537
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0465 - accuracy: 0.9852 - val_loss: 0.1751 - val_accuracy: 0.9503
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0426 - accuracy: 0.9855 - val_loss: 0.1987 - val_accuracy: 0.9480
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0462 - accuracy: 0.9854 - val_loss: 0.2023 - val_accuracy: 0.9488
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0436 - accuracy: 0.9861 - val_loss: 0.1986 - val_accuracy: 0.9495
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0444 - accuracy: 0.9857 - val_loss: 0.2003 - val_accuracy: 0.9507
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0345 - accuracy: 0.9885 - val_loss: 0.2011 - val_accuracy: 0.9499
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.1985 - val_accuracy: 0.9522
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0332 - accuracy: 0.9889 - val_loss: 0.2029 - val_accuracy: 0.9525
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 8: loss of 0.20286925137043; accuracy of 95.25423645973206%
# Epoch 1/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.4099 - accuracy: 0.8736 - val_loss: 0.2845 - val_accuracy: 0.9179
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1556 - accuracy: 0.9558 - val_loss: 0.2420 - val_accuracy: 0.9303
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1233 - accuracy: 0.9642 - val_loss: 0.2095 - val_accuracy: 0.9367
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1056 - accuracy: 0.9686 - val_loss: 0.1991 - val_accuracy: 0.9416
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0950 - accuracy: 0.9720 - val_loss: 0.1924 - val_accuracy: 0.9457
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0865 - accuracy: 0.9731 - val_loss: 0.2007 - val_accuracy: 0.9461
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0813 - accuracy: 0.9744 - val_loss: 0.1899 - val_accuracy: 0.9457
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0742 - accuracy: 0.9768 - val_loss: 0.1710 - val_accuracy: 0.9499
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0721 - accuracy: 0.9771 - val_loss: 0.1866 - val_accuracy: 0.9469
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0680 - accuracy: 0.9785 - val_loss: 0.1705 - val_accuracy: 0.9503
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0648 - accuracy: 0.9794 - val_loss: 0.1768 - val_accuracy: 0.9488
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0618 - accuracy: 0.9801 - val_loss: 0.1800 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0592 - accuracy: 0.9809 - val_loss: 0.1772 - val_accuracy: 0.9510
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0573 - accuracy: 0.9813 - val_loss: 0.1763 - val_accuracy: 0.9529
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0574 - accuracy: 0.9820 - val_loss: 0.2007 - val_accuracy: 0.9484
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0551 - accuracy: 0.9823 - val_loss: 0.1770 - val_accuracy: 0.9540
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0538 - accuracy: 0.9825 - val_loss: 0.1684 - val_accuracy: 0.9525
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0535 - accuracy: 0.9827 - val_loss: 0.1815 - val_accuracy: 0.9521
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0510 - accuracy: 0.9840 - val_loss: 0.1880 - val_accuracy: 0.9491
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0491 - accuracy: 0.9840 - val_loss: 0.1650 - val_accuracy: 0.9548
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0478 - accuracy: 0.9844 - val_loss: 0.1756 - val_accuracy: 0.9552
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0467 - accuracy: 0.9848 - val_loss: 0.1674 - val_accuracy: 0.9552
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0472 - accuracy: 0.9849 - val_loss: 0.1637 - val_accuracy: 0.9544
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0447 - accuracy: 0.9857 - val_loss: 0.1777 - val_accuracy: 0.9552
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 0.1717 - val_accuracy: 0.9544
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0469 - accuracy: 0.9855 - val_loss: 0.1811 - val_accuracy: 0.9563
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0436 - accuracy: 0.9859 - val_loss: 0.1981 - val_accuracy: 0.9548
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0424 - accuracy: 0.9857 - val_loss: 0.1920 - val_accuracy: 0.9540
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0417 - accuracy: 0.9864 - val_loss: 0.1936 - val_accuracy: 0.9567
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0434 - accuracy: 0.9859 - val_loss: 0.1981 - val_accuracy: 0.9548
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 9: loss of 0.1981496512889862; accuracy of 95.47852277755737%
# Epoch 1/30
# 2076/2076 [==============================] - 12s 5ms/step - loss: 0.3621 - accuracy: 0.8895 - val_loss: 0.2590 - val_accuracy: 0.9167
#
# Epoch 00001: val_loss did not improve from 0.13285
# Epoch 2/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1377 - accuracy: 0.9610 - val_loss: 0.2333 - val_accuracy: 0.9322
#
# Epoch 00002: val_loss did not improve from 0.13285
# Epoch 3/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.1096 - accuracy: 0.9684 - val_loss: 0.1798 - val_accuracy: 0.9469
#
# Epoch 00003: val_loss did not improve from 0.13285
# Epoch 4/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0956 - accuracy: 0.9716 - val_loss: 0.1958 - val_accuracy: 0.9454
#
# Epoch 00004: val_loss did not improve from 0.13285
# Epoch 5/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0863 - accuracy: 0.9740 - val_loss: 0.1769 - val_accuracy: 0.9465
#
# Epoch 00005: val_loss did not improve from 0.13285
# Epoch 6/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0789 - accuracy: 0.9754 - val_loss: 0.1660 - val_accuracy: 0.9533
#
# Epoch 00006: val_loss did not improve from 0.13285
# Epoch 7/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0726 - accuracy: 0.9779 - val_loss: 0.1696 - val_accuracy: 0.9521
#
# Epoch 00007: val_loss did not improve from 0.13285
# Epoch 8/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0687 - accuracy: 0.9788 - val_loss: 0.1673 - val_accuracy: 0.9503
#
# Epoch 00008: val_loss did not improve from 0.13285
# Epoch 9/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0652 - accuracy: 0.9800 - val_loss: 0.1631 - val_accuracy: 0.9555
#
# Epoch 00009: val_loss did not improve from 0.13285
# Epoch 10/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0639 - accuracy: 0.9798 - val_loss: 0.1599 - val_accuracy: 0.9533
#
# Epoch 00010: val_loss did not improve from 0.13285
# Epoch 11/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0601 - accuracy: 0.9812 - val_loss: 0.1507 - val_accuracy: 0.9563
#
# Epoch 00011: val_loss did not improve from 0.13285
# Epoch 12/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0563 - accuracy: 0.9823 - val_loss: 0.1732 - val_accuracy: 0.9514
#
# Epoch 00012: val_loss did not improve from 0.13285
# Epoch 13/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0562 - accuracy: 0.9823 - val_loss: 0.1682 - val_accuracy: 0.9544
#
# Epoch 00013: val_loss did not improve from 0.13285
# Epoch 14/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0550 - accuracy: 0.9827 - val_loss: 0.1494 - val_accuracy: 0.9563
#
# Epoch 00014: val_loss did not improve from 0.13285
# Epoch 15/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0516 - accuracy: 0.9838 - val_loss: 0.1683 - val_accuracy: 0.9552
#
# Epoch 00015: val_loss did not improve from 0.13285
# Epoch 16/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0505 - accuracy: 0.9838 - val_loss: 0.1705 - val_accuracy: 0.9518
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.13285
# Epoch 17/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0400 - accuracy: 0.9871 - val_loss: 0.1632 - val_accuracy: 0.9559
#
# Epoch 00017: val_loss did not improve from 0.13285
# Epoch 18/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0378 - accuracy: 0.9877 - val_loss: 0.1617 - val_accuracy: 0.9559
#
# Epoch 00018: val_loss did not improve from 0.13285
# Epoch 19/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0354 - accuracy: 0.9880 - val_loss: 0.1620 - val_accuracy: 0.9574
#
# Epoch 00019: val_loss did not improve from 0.13285
# Epoch 20/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0363 - accuracy: 0.9881 - val_loss: 0.1703 - val_accuracy: 0.9548
#
# Epoch 00020: val_loss did not improve from 0.13285
# Epoch 21/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0344 - accuracy: 0.9888 - val_loss: 0.1679 - val_accuracy: 0.9582
#
# Epoch 00021: val_loss did not improve from 0.13285
# Epoch 22/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0338 - accuracy: 0.9890 - val_loss: 0.1623 - val_accuracy: 0.9567
#
# Epoch 00022: val_loss did not improve from 0.13285
# Epoch 23/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.1608 - val_accuracy: 0.9563
#
# Epoch 00023: val_loss did not improve from 0.13285
# Epoch 24/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0319 - accuracy: 0.9895 - val_loss: 0.1686 - val_accuracy: 0.9529
#
# Epoch 00024: val_loss did not improve from 0.13285
# Epoch 25/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.1793 - val_accuracy: 0.9559
#
# Epoch 00025: val_loss did not improve from 0.13285
# Epoch 26/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0313 - accuracy: 0.9896 - val_loss: 0.1749 - val_accuracy: 0.9544
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00026: val_loss did not improve from 0.13285
# Epoch 27/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0272 - accuracy: 0.9906 - val_loss: 0.1801 - val_accuracy: 0.9559
#
# Epoch 00027: val_loss did not improve from 0.13285
# Epoch 28/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 0.1787 - val_accuracy: 0.9555
#
# Epoch 00028: val_loss did not improve from 0.13285
# Epoch 29/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0264 - accuracy: 0.9913 - val_loss: 0.1806 - val_accuracy: 0.9552
#
# Epoch 00029: val_loss did not improve from 0.13285
# Epoch 30/30
# 2076/2076 [==============================] - 11s 5ms/step - loss: 0.0265 - accuracy: 0.9913 - val_loss: 0.1873 - val_accuracy: 0.9552
#
# Epoch 00030: val_loss did not improve from 0.13285
# Score for fold 10: loss of 0.18728163838386536; accuracy of 95.51620483398438%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.1638597995042801 - Accuracy: 96.38417959213257%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.22078050673007965 - Accuracy: 95.29190063476562%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.16426315903663635 - Accuracy: 95.96986770629883%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.19420327246189117 - Accuracy: 95.29190063476562%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.1947188377380371 - Accuracy: 95.36722898483276%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.19286978244781494 - Accuracy: 95.51789164543152%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.2003834992647171 - Accuracy: 94.87758874893188%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.20286925137043 - Accuracy: 95.25423645973206%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.1981496512889862 - Accuracy: 95.47852277755737%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.18728163838386536 - Accuracy: 95.51620483398438%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.49495220184326% (+- 0.003943821377649008)
# > Loss: 0.1919379398226738
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph (I will use around 20% of cases for benign for and the remaining 80% equally distributed across the 10 ransomware families)

# %%
np.array(train_distr)
# Out:
# array([[ 9.10555397,  9.35698047,  7.73550534,  7.7595941 ,  7.60602821,
#          8.26244712,  7.83938815,  8.30159136,  7.58344499,  7.48558438,
#         18.9638819 ],
#        [ 9.10254287,  9.32988061,  7.76712184,  7.74002198,  7.58946719,
#          8.24438054,  7.84842143,  8.31062465,  7.59548938,  7.49913431,
#         18.97291519],
#        [ 9.12964273,  9.32536397,  7.74905527,  7.74754972,  7.61205041,
#          8.2398639 ,  7.83336595,  8.31363575,  7.59247828,  7.49762876,
#         18.95936526],
#        [ 9.15975369,  9.35396938,  7.73550534,  7.74905527,  7.59850047,
#          8.28503034,  7.82734376,  8.2775026 ,  7.57892835,  7.46149561,
#         18.97291519],
#        [ 9.0844763 ,  9.31934177,  7.74303308,  7.74754972,  7.59548938,
#          8.28352479,  7.84992698,  8.26545821,  7.56688397,  7.49010102,
#         19.05421478],
#        [ 9.09501513,  9.34945273,  7.74152753,  7.7626052 ,  7.60602821,
#          8.24287499,  7.84541034,  8.29556917,  7.58796164,  7.47504554,
#         18.99850951],
#        [ 9.08297075,  9.36450821,  7.75357191,  7.7279776 ,  7.56838952,
#          8.26545821,  7.85444362,  8.2775026 ,  7.58193945,  7.49010102,
#         19.03313711],
#        [ 9.11007061,  9.34644164,  7.74754972,  7.73701089,  7.61656705,
#          8.24739164,  7.86648801,  8.31363575,  7.56838952,  7.48558438,
#         18.96087081],
#        [ 9.0707898 ,  9.31317937,  7.7368944 ,  7.75345518,  7.6119358 ,
#          8.29996086,  7.85281985,  8.29845533,  7.59236398,  7.47944958,
#         18.99069585],
#        [ 9.13853844,  9.32522357,  7.74141098,  7.75194966,  7.61344133,
#          8.27587245,  7.8437867 ,  8.27436693,  7.60440818,  7.47643853,
#         18.95456325]])

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['Macro F1', round(np.mean(multi_f1_per_fold), 4), round(np.std(multi_f1_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CGAN - CNN"
print(t)
# Out:
# +---------------------------------------+
# |       Performance of CGAN - CNN       |
# | Metric   | Performance | St.Deviation |
# | M-Class  |             |              |
# | Acc      | 0.9549      | 0.0039       |
# | Loss     | 0.1919      | 0.0163       |
# | Macro F1 | 0.8844      | 0.0076       |
# |          |             |              |
# | B-Class  |             |              |
# | TPR      | 0.9811      | 0.0051       |
# | Acc      | 0.984       | 0.0027       |
# | F1       | 0.9849      | 0.0027       |
# | MCC      | 0.968       | 0.0054       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CGAN-CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CGAN-CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, 'binary', figsize = (5,2), fontsize=10)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'multi-class', figsize = (20,7), fontsize=14)
