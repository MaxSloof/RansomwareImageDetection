# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 15

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set 
test_size = 0.3

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/draft_cross_validation"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/draft_cross_validation/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 6 matches(es) found
# --------------
# New folder name: cnn-local-v007
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='softmax'))
        Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

y_pred = []
y_true = []

rw_count = []
bn_count = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Binary
    y_predbin = [] 
    y_truebin = []
    for count, value in enumerate(y_true2):
        if y_true2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_truebin.append(0)
        else: y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

        if y_pred2[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
            y_predbin.append(0)
        else: y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
        continue
        
    rw_count.append(len(y_truebin) - np.sum(y_truebin))
    bn_count.append(np.sum(y_truebin))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
    
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_acc_per_fold.append(accuracy_score(y_truebin, y_predbin)) # Accuracy
    bin_f1_per_fold.append(f1_score(y_truebin, y_predbin, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_truebin, y_predbin))  # Matthews Correlation Coefficient
    
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/15
# 747/747 [==============================] - 5s 6ms/step - loss: 0.6112 - accuracy: 0.8169 - val_loss: 0.3137 - val_accuracy: 0.8927
#
# Epoch 00001: val_loss improved from inf to 0.31375, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 2/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3277 - accuracy: 0.8962 - val_loss: 0.2616 - val_accuracy: 0.9183
#
# Epoch 00002: val_loss improved from 0.31375 to 0.26163, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 3/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2774 - accuracy: 0.9121 - val_loss: 0.2206 - val_accuracy: 0.9292
#
# Epoch 00003: val_loss improved from 0.26163 to 0.22060, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 4/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2452 - accuracy: 0.9204 - val_loss: 0.2152 - val_accuracy: 0.9296
#
# Epoch 00004: val_loss improved from 0.22060 to 0.21518, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2262 - accuracy: 0.9282 - val_loss: 0.1932 - val_accuracy: 0.9397
#
# Epoch 00005: val_loss improved from 0.21518 to 0.19320, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2117 - accuracy: 0.9322 - val_loss: 0.1877 - val_accuracy: 0.9420
#
# Epoch 00006: val_loss improved from 0.19320 to 0.18773, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1954 - accuracy: 0.9375 - val_loss: 0.1693 - val_accuracy: 0.9439
#
# Epoch 00007: val_loss improved from 0.18773 to 0.16926, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1868 - accuracy: 0.9388 - val_loss: 0.1693 - val_accuracy: 0.9446
#
# Epoch 00008: val_loss did not improve from 0.16926
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1733 - accuracy: 0.9435 - val_loss: 0.1664 - val_accuracy: 0.9484
#
# Epoch 00009: val_loss improved from 0.16926 to 0.16635, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 10/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1670 - accuracy: 0.9457 - val_loss: 0.1750 - val_accuracy: 0.9431
#
# Epoch 00010: val_loss did not improve from 0.16635
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1592 - accuracy: 0.9477 - val_loss: 0.1769 - val_accuracy: 0.9503
#
# Epoch 00011: val_loss did not improve from 0.16635
# Epoch 12/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1547 - accuracy: 0.9497 - val_loss: 0.1591 - val_accuracy: 0.9499
#
# Epoch 00012: val_loss improved from 0.16635 to 0.15907, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1456 - accuracy: 0.9523 - val_loss: 0.1521 - val_accuracy: 0.9548
#
# Epoch 00013: val_loss improved from 0.15907 to 0.15210, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 14/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1386 - accuracy: 0.9546 - val_loss: 0.1643 - val_accuracy: 0.9514
#
# Epoch 00014: val_loss did not improve from 0.15210
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1341 - accuracy: 0.9556 - val_loss: 0.1550 - val_accuracy: 0.9507
#
# Epoch 00015: val_loss did not improve from 0.15210
# Score for fold 1: loss of 0.1550365537405014; accuracy of 95.06591558456421%
# Epoch 1/15
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5995 - accuracy: 0.8193 - val_loss: 0.3459 - val_accuracy: 0.8757
#
# Epoch 00001: val_loss did not improve from 0.15210
# Epoch 2/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3553 - accuracy: 0.8885 - val_loss: 0.2605 - val_accuracy: 0.9168
#
# Epoch 00002: val_loss did not improve from 0.15210
# Epoch 3/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2941 - accuracy: 0.9080 - val_loss: 0.2452 - val_accuracy: 0.9220
#
# Epoch 00003: val_loss did not improve from 0.15210
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2626 - accuracy: 0.9165 - val_loss: 0.2069 - val_accuracy: 0.9307
#
# Epoch 00004: val_loss did not improve from 0.15210
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2343 - accuracy: 0.9253 - val_loss: 0.1936 - val_accuracy: 0.9345
#
# Epoch 00005: val_loss did not improve from 0.15210
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2216 - accuracy: 0.9288 - val_loss: 0.1837 - val_accuracy: 0.9412
#
# Epoch 00006: val_loss did not improve from 0.15210
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2063 - accuracy: 0.9333 - val_loss: 0.1912 - val_accuracy: 0.9397
#
# Epoch 00007: val_loss did not improve from 0.15210
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1979 - accuracy: 0.9368 - val_loss: 0.1795 - val_accuracy: 0.9435
#
# Epoch 00008: val_loss did not improve from 0.15210
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1864 - accuracy: 0.9404 - val_loss: 0.1725 - val_accuracy: 0.9424
#
# Epoch 00009: val_loss did not improve from 0.15210
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1718 - accuracy: 0.9440 - val_loss: 0.1680 - val_accuracy: 0.9446
#
# Epoch 00010: val_loss did not improve from 0.15210
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1684 - accuracy: 0.9452 - val_loss: 0.1779 - val_accuracy: 0.9424
#
# Epoch 00011: val_loss did not improve from 0.15210
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1585 - accuracy: 0.9492 - val_loss: 0.1728 - val_accuracy: 0.9473
#
# Epoch 00012: val_loss did not improve from 0.15210
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1532 - accuracy: 0.9512 - val_loss: 0.1751 - val_accuracy: 0.9439
#
# Epoch 00013: val_loss did not improve from 0.15210
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1472 - accuracy: 0.9533 - val_loss: 0.1720 - val_accuracy: 0.9495
#
# Epoch 00014: val_loss did not improve from 0.15210
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1437 - accuracy: 0.9535 - val_loss: 0.1618 - val_accuracy: 0.9503
#
# Epoch 00015: val_loss did not improve from 0.15210
# Score for fold 2: loss of 0.16182729601860046; accuracy of 95.02825140953064%
# Epoch 1/15
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5668 - accuracy: 0.8322 - val_loss: 0.3141 - val_accuracy: 0.9028
#
# Epoch 00001: val_loss did not improve from 0.15210
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3245 - accuracy: 0.8992 - val_loss: 0.2484 - val_accuracy: 0.9296
#
# Epoch 00002: val_loss did not improve from 0.15210
# Epoch 3/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2747 - accuracy: 0.9160 - val_loss: 0.2233 - val_accuracy: 0.9284
#
# Epoch 00003: val_loss did not improve from 0.15210
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2474 - accuracy: 0.9218 - val_loss: 0.2027 - val_accuracy: 0.9375
#
# Epoch 00004: val_loss did not improve from 0.15210
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2254 - accuracy: 0.9287 - val_loss: 0.2035 - val_accuracy: 0.9401
#
# Epoch 00005: val_loss did not improve from 0.15210
# Epoch 6/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2170 - accuracy: 0.9325 - val_loss: 0.1864 - val_accuracy: 0.9431
#
# Epoch 00006: val_loss did not improve from 0.15210
# Epoch 7/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2011 - accuracy: 0.9350 - val_loss: 0.1710 - val_accuracy: 0.9458
#
# Epoch 00007: val_loss did not improve from 0.15210
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1928 - accuracy: 0.9375 - val_loss: 0.1707 - val_accuracy: 0.9469
#
# Epoch 00008: val_loss did not improve from 0.15210
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1781 - accuracy: 0.9425 - val_loss: 0.1725 - val_accuracy: 0.9476
#
# Epoch 00009: val_loss did not improve from 0.15210
# Epoch 10/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1755 - accuracy: 0.9416 - val_loss: 0.1553 - val_accuracy: 0.9503
#
# Epoch 00010: val_loss did not improve from 0.15210
# Epoch 11/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1616 - accuracy: 0.9464 - val_loss: 0.1481 - val_accuracy: 0.9540
#
# Epoch 00011: val_loss improved from 0.15210 to 0.14808, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 12/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1536 - accuracy: 0.9496 - val_loss: 0.1536 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.14808
# Epoch 13/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1519 - accuracy: 0.9502 - val_loss: 0.1586 - val_accuracy: 0.9552
#
# Epoch 00013: val_loss did not improve from 0.14808
# Epoch 14/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1479 - accuracy: 0.9524 - val_loss: 0.1441 - val_accuracy: 0.9567
#
# Epoch 00014: val_loss improved from 0.14808 to 0.14407, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 15/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1405 - accuracy: 0.9547 - val_loss: 0.1513 - val_accuracy: 0.9529
#
# Epoch 00015: val_loss did not improve from 0.14407
# Score for fold 3: loss of 0.15132464468479156; accuracy of 95.29190063476562%
# Epoch 1/15
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5831 - accuracy: 0.8272 - val_loss: 0.3326 - val_accuracy: 0.9058
#
# Epoch 00001: val_loss did not improve from 0.14407
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3220 - accuracy: 0.8967 - val_loss: 0.2595 - val_accuracy: 0.9205
#
# Epoch 00002: val_loss did not improve from 0.14407
# Epoch 3/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2663 - accuracy: 0.9152 - val_loss: 0.2193 - val_accuracy: 0.9311
#
# Epoch 00003: val_loss did not improve from 0.14407
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2368 - accuracy: 0.9247 - val_loss: 0.1984 - val_accuracy: 0.9394
#
# Epoch 00004: val_loss did not improve from 0.14407
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2187 - accuracy: 0.9292 - val_loss: 0.2039 - val_accuracy: 0.9379
#
# Epoch 00005: val_loss did not improve from 0.14407
# Epoch 6/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2012 - accuracy: 0.9336 - val_loss: 0.1779 - val_accuracy: 0.9461
#
# Epoch 00006: val_loss did not improve from 0.14407
# Epoch 7/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1907 - accuracy: 0.9392 - val_loss: 0.1850 - val_accuracy: 0.9492
#
# Epoch 00007: val_loss did not improve from 0.14407
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1805 - accuracy: 0.9410 - val_loss: 0.1668 - val_accuracy: 0.9540
#
# Epoch 00008: val_loss did not improve from 0.14407
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1722 - accuracy: 0.9431 - val_loss: 0.1682 - val_accuracy: 0.9514
#
# Epoch 00009: val_loss did not improve from 0.14407
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1581 - accuracy: 0.9477 - val_loss: 0.1556 - val_accuracy: 0.9529
#
# Epoch 00010: val_loss did not improve from 0.14407
# Epoch 11/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1593 - accuracy: 0.9485 - val_loss: 0.1648 - val_accuracy: 0.9492
#
# Epoch 00011: val_loss did not improve from 0.14407
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1461 - accuracy: 0.9505 - val_loss: 0.1557 - val_accuracy: 0.9537
#
# Epoch 00012: val_loss did not improve from 0.14407
# Epoch 13/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1405 - accuracy: 0.9534 - val_loss: 0.1549 - val_accuracy: 0.9548
#
# Epoch 00013: val_loss did not improve from 0.14407
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1302 - accuracy: 0.9565 - val_loss: 0.1485 - val_accuracy: 0.9544
#
# Epoch 00014: val_loss did not improve from 0.14407
# Epoch 15/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1266 - accuracy: 0.9576 - val_loss: 0.1553 - val_accuracy: 0.9552
#
# Epoch 00015: val_loss did not improve from 0.14407
# Score for fold 4: loss of 0.15532755851745605; accuracy of 95.51789164543152%
# Epoch 1/15
# 747/747 [==============================] - 5s 7ms/step - loss: 0.6223 - accuracy: 0.8154 - val_loss: 0.3253 - val_accuracy: 0.8964
#
# Epoch 00001: val_loss did not improve from 0.14407
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3383 - accuracy: 0.8955 - val_loss: 0.2411 - val_accuracy: 0.9247
#
# Epoch 00002: val_loss did not improve from 0.14407
# Epoch 3/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2809 - accuracy: 0.9100 - val_loss: 0.2247 - val_accuracy: 0.9296
#
# Epoch 00003: val_loss did not improve from 0.14407
# Epoch 4/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2552 - accuracy: 0.9164 - val_loss: 0.1988 - val_accuracy: 0.9363
#
# Epoch 00004: val_loss did not improve from 0.14407
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2319 - accuracy: 0.9238 - val_loss: 0.1895 - val_accuracy: 0.9401
#
# Epoch 00005: val_loss did not improve from 0.14407
# Epoch 6/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2144 - accuracy: 0.9283 - val_loss: 0.1796 - val_accuracy: 0.9439
#
# Epoch 00006: val_loss did not improve from 0.14407
# Epoch 7/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2032 - accuracy: 0.9340 - val_loss: 0.1714 - val_accuracy: 0.9439
#
# Epoch 00007: val_loss did not improve from 0.14407
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1875 - accuracy: 0.9385 - val_loss: 0.1789 - val_accuracy: 0.9439
#
# Epoch 00008: val_loss did not improve from 0.14407
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1812 - accuracy: 0.9408 - val_loss: 0.1650 - val_accuracy: 0.9469
#
# Epoch 00009: val_loss did not improve from 0.14407
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1687 - accuracy: 0.9448 - val_loss: 0.1603 - val_accuracy: 0.9495
#
# Epoch 00010: val_loss did not improve from 0.14407
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1593 - accuracy: 0.9471 - val_loss: 0.1756 - val_accuracy: 0.9465
#
# Epoch 00011: val_loss did not improve from 0.14407
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1505 - accuracy: 0.9504 - val_loss: 0.2075 - val_accuracy: 0.9416
#
# Epoch 00012: val_loss did not improve from 0.14407
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1413 - accuracy: 0.9527 - val_loss: 0.1591 - val_accuracy: 0.9488
#
# Epoch 00013: val_loss did not improve from 0.14407
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1400 - accuracy: 0.9541 - val_loss: 0.1577 - val_accuracy: 0.9503
#
# Epoch 00014: val_loss did not improve from 0.14407
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1364 - accuracy: 0.9560 - val_loss: 0.1571 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.14407
# Score for fold 5: loss of 0.1571483314037323; accuracy of 95.25423645973206%
# Epoch 1/15
# 747/747 [==============================] - 5s 6ms/step - loss: 0.5798 - accuracy: 0.8282 - val_loss: 0.3386 - val_accuracy: 0.8896
#
# Epoch 00001: val_loss did not improve from 0.14407
# Epoch 2/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.3348 - accuracy: 0.8957 - val_loss: 0.2826 - val_accuracy: 0.9149
#
# Epoch 00002: val_loss did not improve from 0.14407
# Epoch 3/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2767 - accuracy: 0.9128 - val_loss: 0.2572 - val_accuracy: 0.9228
#
# Epoch 00003: val_loss did not improve from 0.14407
# Epoch 4/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.2531 - accuracy: 0.9209 - val_loss: 0.2241 - val_accuracy: 0.9348
#
# Epoch 00004: val_loss did not improve from 0.14407
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2295 - accuracy: 0.9278 - val_loss: 0.2009 - val_accuracy: 0.9416
#
# Epoch 00005: val_loss did not improve from 0.14407
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2160 - accuracy: 0.9298 - val_loss: 0.2213 - val_accuracy: 0.9363
#
# Epoch 00006: val_loss did not improve from 0.14407
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2010 - accuracy: 0.9367 - val_loss: 0.1819 - val_accuracy: 0.9484
#
# Epoch 00007: val_loss did not improve from 0.14407
# Epoch 8/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1876 - accuracy: 0.9389 - val_loss: 0.1957 - val_accuracy: 0.9446
#
# Epoch 00008: val_loss did not improve from 0.14407
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1766 - accuracy: 0.9430 - val_loss: 0.1921 - val_accuracy: 0.9495
#
# Epoch 00009: val_loss did not improve from 0.14407
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1658 - accuracy: 0.9462 - val_loss: 0.1788 - val_accuracy: 0.9480
#
# Epoch 00010: val_loss did not improve from 0.14407
# Epoch 11/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1586 - accuracy: 0.9485 - val_loss: 0.1880 - val_accuracy: 0.9499
#
# Epoch 00011: val_loss did not improve from 0.14407
# Epoch 12/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1458 - accuracy: 0.9532 - val_loss: 0.1842 - val_accuracy: 0.9484
#
# Epoch 00012: val_loss did not improve from 0.14407
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1446 - accuracy: 0.9518 - val_loss: 0.1868 - val_accuracy: 0.9510
#
# Epoch 00013: val_loss did not improve from 0.14407
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1363 - accuracy: 0.9557 - val_loss: 0.1715 - val_accuracy: 0.9540
#
# Epoch 00014: val_loss did not improve from 0.14407
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1307 - accuracy: 0.9567 - val_loss: 0.1757 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.14407
# Score for fold 6: loss of 0.17567481100559235; accuracy of 95.25423645973206%
# Epoch 1/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.5662 - accuracy: 0.8336 - val_loss: 0.3193 - val_accuracy: 0.9006
#
# Epoch 00001: val_loss did not improve from 0.14407
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3225 - accuracy: 0.8974 - val_loss: 0.2466 - val_accuracy: 0.9262
#
# Epoch 00002: val_loss did not improve from 0.14407
# Epoch 3/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2655 - accuracy: 0.9156 - val_loss: 0.2151 - val_accuracy: 0.9281
#
# Epoch 00003: val_loss did not improve from 0.14407
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2382 - accuracy: 0.9246 - val_loss: 0.2116 - val_accuracy: 0.9296
#
# Epoch 00004: val_loss did not improve from 0.14407
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2195 - accuracy: 0.9291 - val_loss: 0.1826 - val_accuracy: 0.9371
#
# Epoch 00005: val_loss did not improve from 0.14407
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1982 - accuracy: 0.9359 - val_loss: 0.1868 - val_accuracy: 0.9401
#
# Epoch 00006: val_loss did not improve from 0.14407
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1910 - accuracy: 0.9394 - val_loss: 0.1663 - val_accuracy: 0.9458
#
# Epoch 00007: val_loss did not improve from 0.14407
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1812 - accuracy: 0.9402 - val_loss: 0.1586 - val_accuracy: 0.9450
#
# Epoch 00008: val_loss did not improve from 0.14407
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1688 - accuracy: 0.9449 - val_loss: 0.1632 - val_accuracy: 0.9492
#
# Epoch 00009: val_loss did not improve from 0.14407
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1613 - accuracy: 0.9467 - val_loss: 0.1424 - val_accuracy: 0.9529
#
# Epoch 00010: val_loss improved from 0.14407 to 0.14244, saving model to /Users/Max/Documents/GitHub/cross_validation/cnn-local-v007\model.h5
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1539 - accuracy: 0.9491 - val_loss: 0.1551 - val_accuracy: 0.9495
#
# Epoch 00011: val_loss did not improve from 0.14244
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1460 - accuracy: 0.9515 - val_loss: 0.1535 - val_accuracy: 0.9522
#
# Epoch 00012: val_loss did not improve from 0.14244
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1423 - accuracy: 0.9518 - val_loss: 0.1460 - val_accuracy: 0.9548
#
# Epoch 00013: val_loss did not improve from 0.14244
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1369 - accuracy: 0.9544 - val_loss: 0.1512 - val_accuracy: 0.9552
#
# Epoch 00014: val_loss did not improve from 0.14244
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1325 - accuracy: 0.9553 - val_loss: 0.1599 - val_accuracy: 0.9525
#
# Epoch 00015: val_loss did not improve from 0.14244
# Score for fold 7: loss of 0.15993115305900574; accuracy of 95.25423645973206%
# Epoch 1/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.6225 - accuracy: 0.8168 - val_loss: 0.3613 - val_accuracy: 0.8825
#
# Epoch 00001: val_loss did not improve from 0.14244
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3679 - accuracy: 0.8856 - val_loss: 0.2813 - val_accuracy: 0.9085
#
# Epoch 00002: val_loss did not improve from 0.14244
# Epoch 3/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3073 - accuracy: 0.9041 - val_loss: 0.2532 - val_accuracy: 0.9175
#
# Epoch 00003: val_loss did not improve from 0.14244
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2698 - accuracy: 0.9137 - val_loss: 0.2258 - val_accuracy: 0.9273
#
# Epoch 00004: val_loss did not improve from 0.14244
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2487 - accuracy: 0.9204 - val_loss: 0.2129 - val_accuracy: 0.9326
#
# Epoch 00005: val_loss did not improve from 0.14244
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2348 - accuracy: 0.9253 - val_loss: 0.2013 - val_accuracy: 0.9375
#
# Epoch 00006: val_loss did not improve from 0.14244
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2152 - accuracy: 0.9303 - val_loss: 0.1880 - val_accuracy: 0.9394
#
# Epoch 00007: val_loss did not improve from 0.14244
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2091 - accuracy: 0.9325 - val_loss: 0.1909 - val_accuracy: 0.9375
#
# Epoch 00008: val_loss did not improve from 0.14244
# Epoch 9/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1930 - accuracy: 0.9381 - val_loss: 0.1798 - val_accuracy: 0.9424
#
# Epoch 00009: val_loss did not improve from 0.14244
# Epoch 10/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1828 - accuracy: 0.9402 - val_loss: 0.1764 - val_accuracy: 0.9450
#
# Epoch 00010: val_loss did not improve from 0.14244
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1788 - accuracy: 0.9421 - val_loss: 0.1687 - val_accuracy: 0.9473
#
# Epoch 00011: val_loss did not improve from 0.14244
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1607 - accuracy: 0.9468 - val_loss: 0.1679 - val_accuracy: 0.9446
#
# Epoch 00012: val_loss did not improve from 0.14244
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1564 - accuracy: 0.9499 - val_loss: 0.1637 - val_accuracy: 0.9446
#
# Epoch 00013: val_loss did not improve from 0.14244
# Epoch 14/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1504 - accuracy: 0.9502 - val_loss: 0.1695 - val_accuracy: 0.9522
#
# Epoch 00014: val_loss did not improve from 0.14244
# Epoch 15/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1441 - accuracy: 0.9535 - val_loss: 0.1564 - val_accuracy: 0.9514
#
# Epoch 00015: val_loss did not improve from 0.14244
# Score for fold 8: loss of 0.15643878281116486; accuracy of 95.14124393463135%
# Epoch 1/15
# 747/747 [==============================] - 4s 6ms/step - loss: 0.5454 - accuracy: 0.8407 - val_loss: 0.3213 - val_accuracy: 0.9069
#
# Epoch 00001: val_loss did not improve from 0.14244
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3181 - accuracy: 0.9011 - val_loss: 0.2660 - val_accuracy: 0.9209
#
# Epoch 00002: val_loss did not improve from 0.14244
# Epoch 3/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2713 - accuracy: 0.9151 - val_loss: 0.2350 - val_accuracy: 0.9322
#
# Epoch 00003: val_loss did not improve from 0.14244
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2435 - accuracy: 0.9248 - val_loss: 0.2086 - val_accuracy: 0.9322
#
# Epoch 00004: val_loss did not improve from 0.14244
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2220 - accuracy: 0.9309 - val_loss: 0.2136 - val_accuracy: 0.9326
#
# Epoch 00005: val_loss did not improve from 0.14244
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2026 - accuracy: 0.9350 - val_loss: 0.1988 - val_accuracy: 0.9337
#
# Epoch 00006: val_loss did not improve from 0.14244
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1873 - accuracy: 0.9398 - val_loss: 0.1840 - val_accuracy: 0.9431
#
# Epoch 00007: val_loss did not improve from 0.14244
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1787 - accuracy: 0.9419 - val_loss: 0.1805 - val_accuracy: 0.9424
#
# Epoch 00008: val_loss did not improve from 0.14244
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1685 - accuracy: 0.9449 - val_loss: 0.1809 - val_accuracy: 0.9469
#
# Epoch 00009: val_loss did not improve from 0.14244
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1611 - accuracy: 0.9481 - val_loss: 0.1773 - val_accuracy: 0.9457
#
# Epoch 00010: val_loss did not improve from 0.14244
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1501 - accuracy: 0.9515 - val_loss: 0.1753 - val_accuracy: 0.9472
#
# Epoch 00011: val_loss did not improve from 0.14244
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1422 - accuracy: 0.9527 - val_loss: 0.1683 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss did not improve from 0.14244
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1348 - accuracy: 0.9553 - val_loss: 0.1802 - val_accuracy: 0.9439
#
# Epoch 00013: val_loss did not improve from 0.14244
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1331 - accuracy: 0.9561 - val_loss: 0.1831 - val_accuracy: 0.9476
#
# Epoch 00014: val_loss did not improve from 0.14244
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1267 - accuracy: 0.9584 - val_loss: 0.1684 - val_accuracy: 0.9514
#
# Epoch 00015: val_loss did not improve from 0.14244
# Score for fold 9: loss of 0.16842110455036163; accuracy of 95.13941407203674%
# Epoch 1/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.5853 - accuracy: 0.8282 - val_loss: 0.3277 - val_accuracy: 0.8994
#
# Epoch 00001: val_loss did not improve from 0.14244
# Epoch 2/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.3078 - accuracy: 0.9035 - val_loss: 0.2675 - val_accuracy: 0.9160
#
# Epoch 00002: val_loss did not improve from 0.14244
# Epoch 3/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2553 - accuracy: 0.9182 - val_loss: 0.2521 - val_accuracy: 0.9201
#
# Epoch 00003: val_loss did not improve from 0.14244
# Epoch 4/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2274 - accuracy: 0.9265 - val_loss: 0.2396 - val_accuracy: 0.9254
#
# Epoch 00004: val_loss did not improve from 0.14244
# Epoch 5/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.2087 - accuracy: 0.9326 - val_loss: 0.2649 - val_accuracy: 0.9258
#
# Epoch 00005: val_loss did not improve from 0.14244
# Epoch 6/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1895 - accuracy: 0.9370 - val_loss: 0.2238 - val_accuracy: 0.9280
#
# Epoch 00006: val_loss did not improve from 0.14244
# Epoch 7/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1786 - accuracy: 0.9426 - val_loss: 0.2225 - val_accuracy: 0.9352
#
# Epoch 00007: val_loss did not improve from 0.14244
# Epoch 8/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1679 - accuracy: 0.9476 - val_loss: 0.2143 - val_accuracy: 0.9344
#
# Epoch 00008: val_loss did not improve from 0.14244
# Epoch 9/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1573 - accuracy: 0.9499 - val_loss: 0.2274 - val_accuracy: 0.9375
#
# Epoch 00009: val_loss did not improve from 0.14244
# Epoch 10/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1502 - accuracy: 0.9528 - val_loss: 0.1999 - val_accuracy: 0.9397
#
# Epoch 00010: val_loss did not improve from 0.14244
# Epoch 11/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1377 - accuracy: 0.9554 - val_loss: 0.2337 - val_accuracy: 0.9390
#
# Epoch 00011: val_loss did not improve from 0.14244
# Epoch 12/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1343 - accuracy: 0.9557 - val_loss: 0.2088 - val_accuracy: 0.9397
#
# Epoch 00012: val_loss did not improve from 0.14244
# Epoch 13/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1275 - accuracy: 0.9589 - val_loss: 0.2153 - val_accuracy: 0.9412
#
# Epoch 00013: val_loss did not improve from 0.14244
# Epoch 14/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1242 - accuracy: 0.9587 - val_loss: 0.2191 - val_accuracy: 0.9427
#
# Epoch 00014: val_loss did not improve from 0.14244
# Epoch 15/15
# 747/747 [==============================] - 4s 5ms/step - loss: 0.1111 - accuracy: 0.9641 - val_loss: 0.2184 - val_accuracy: 0.9457
#
# Epoch 00015: val_loss did not improve from 0.14244
# Score for fold 10: loss of 0.21838845312595367; accuracy of 94.57422494888306%

# %%
(np.argmax(Malware_model.predict(imgs[test]), axis=-1))
# Out:
# array([ 0, 10, 10, ...,  9, 10, 10], dtype=int64)

# %% [markdown]
# Run the model

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.1550365537405014 - Accuracy: 95.06591558456421%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.16182729601860046 - Accuracy: 95.02825140953064%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.15132464468479156 - Accuracy: 95.29190063476562%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.15532755851745605 - Accuracy: 95.51789164543152%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.1571483314037323 - Accuracy: 95.25423645973206%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.17567481100559235 - Accuracy: 95.25423645973206%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.15993115305900574 - Accuracy: 95.25423645973206%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.15643878281116486 - Accuracy: 95.14124393463135%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.16842110455036163 - Accuracy: 95.13941407203674%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.21838845312595367 - Accuracy: 94.57422494888306%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.15215516090393% (+- 0.0023272899960966476)
# > Loss: 0.165951868891716
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['M-Class', "", ""])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.border = True
t.add_row(['', '', ''])
t.add_row(['B-Class', "", ""])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(bin_acc_per_fold),4), round(np.std(bin_acc_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +--------------------------------------+
# |          Performance of CNN          |
# | Metric  | Performance | St.Deviation |
# | M-Class |             |              |
# | Acc     | 0.9515      | 0.0023       |
# | Loss    | 0.166       | 0.0188       |
# |         |             |              |
# | B-Class |             |              |
# | TPR     | 0.9777      | 0.0075       |
# | Acc     | 0.9822      | 0.003        |
# | F1      | 0.9832      | 0.0029       |
# | MCC     | 0.9643      | 0.006        |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19528/540448878.py in <module>
# ----> 1 eval_metric(Malware_model, history, 'loss')
#
# NameError: name 'Malware_model' is not defined

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title("Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix_bin = metrics.confusion_matrix(all_y_truebin, all_y_predbin)

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
