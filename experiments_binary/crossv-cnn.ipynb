# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with ReLU activation and Adam optimizer. No class or sample specific weights are used. Same as cnn-kaggle-v021.
#
# This notebook is set up for cross-validation, which is freq. used in research

# %% [markdown]
# # Changeable Parameters

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000 # Set high so all the images in the directory

# Number of epochs
epoch_t = 35 # Seems to be optimal point

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# number of folds
n_folds = 10

# %% [markdown]
# _____________________________________________________________________

# %%
# To check whether the right environment has been selected
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %% [markdown]
# Import the necessary libraries

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Check whether a, and which GPU is available for the computation

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Image size
im_si = (ih, iw)

# Convert the color channel to the corresponding number of layers
if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files if computation is done locally

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/misc_experiments"
    for files in os.listdir(dir):
        if "cnn-binary" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-binary-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 2 matches(es) found
# --------------
# New folder name: cnn-binary-local-v003
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/bin_class"

# %% [markdown]
# Load the data. No data augmentation takes place

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 2 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
# A dictionary of all the different classes
classes = batches.class_indices.keys()
x_axis = np.arange(len(list(classes)))

# %% [markdown]
# Plot data distribution among all classes

# %% [markdown]
# Standardize images

# %%
imgs = imgs / 255.0

# %% [markdown]
# Plot data distribution among train, val. and test set

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, ReLU activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64 * 1

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %% [markdown]
# We want **11** classes

# %%
num_classes = len(list(batches.class_indices))
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  2

# %% [markdown]
# Building the model

# %%
def malware_model():
        Malware_model = Sequential()
        Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=(ih,iw,chnum)))

        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Conv2D(15, (3, 3), activation='relu'))
        Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
        Malware_model.add(Dropout(0.25))
        Malware_model.add(Flatten())
        Malware_model.add(Dense(128, activation='relu'))
        Malware_model.add(Dropout(0.5))
        Malware_model.add(Dense(50, activation='relu'))
        Malware_model.add(Dense(num_classes, activation='sigmoid'))
        Malware_model.compile(loss='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        return Malware_model

# %%
def confusion_matrix(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):

        df_cm = pd.DataFrame(
            confusion_matrix, index=class_names_bin, columns=class_names_bin, 
        )
        fig = plt.figure(figsize=figsize)
        try:
            heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        except ValueError:
            raise ValueError("Confusion matrix values must be integers.")
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

class_names_bin= ("ransomware", "benign")

# %% [markdown]
# Reduce learning rate after 5 epochs of no improvement on the validition accuracy. Also save save checkpoints for the best performing model based on validation loss

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-4)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %% [markdown]
# Initialize variables to keep track of performance across folds

# %%
# Performance metrics
multi_acc_per_fold = []
loss_per_fold = []
multi_f1_per_fold = []
bin_acc_per_fold = []
bin_tpr_per_fold = []
bin_f1_per_fold = []
bin_mcc_per_fold = []

tp = []
fp = []
fn = []
tn = []

# Predictions
y_pred = []
y_true = []

# History
history = []

# Data distribution
train_distr = []
test_distr= []

rw_count = []
bn_count = []

# %%
kfold = KFold(n_splits=n_folds, shuffle=True)

# %%
fold_no = 1

for train, test in kfold.split(imgs,labels):
    
    # Compile the CNN
    Malware_model = malware_model()
    
    # Run the CNN
    history.append(
        Malware_model.fit(
        imgs[train], 
        labels[train], 
        validation_data=(imgs[test], labels[test]), 
        epochs=epoch_t,
        callbacks = [anne, checkpoint]) # The actual computation of the CNN
    )
    
    # Generate generalization metrics
    scores = Malware_model.evaluate(imgs[test], labels[test], verbose=0)
    print(f'Score for fold {fold_no}: {Malware_model.metrics_names[0]} of {scores[0]}; {Malware_model.metrics_names[1]} of {scores[1]*100}%')
    multi_acc_per_fold.append(scores[1])
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
    
    # Create two 1D-arrays: one with the prediction per image of the model and one with the true labels
    y_pred = np.append(y_pred, np.argmax(Malware_model.predict(imgs[test]), axis=-1))
    y_true = np.append(y_true, np.argmax(labels[test], axis=1))
    
    y_pred2 = np.argmax(Malware_model.predict(imgs[test]), axis=-1)
    y_true2 = np.argmax(labels[test], axis=1)
    
    # Transform predictions to binary: ransomware / benign
    
    # Save the binary data distribution
    bn_count.append(len(y_true2) - np.sum(y_true2))
    rw_count.append(np.sum(y_true2))
    
    # Binary confusion Matrix
    c_matrix_bin = metrics.confusion_matrix(y_true2, y_pred2)
    
    # Plot the confusion matrix
    confusion_matrix(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
    
    # Save the true/false positives/negatives
    tp.append(c_matrix_bin[0,0])
    fp.append(c_matrix_bin[0,1])
    fn.append(c_matrix_bin[1,0])
    tn.append(c_matrix_bin[1,1])
    
    # Save the performance metrics used to compare the models
    bin_tpr_per_fold.append(c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1])) #True Positive Rate
    bin_f1_per_fold.append(f1_score(y_true2, y_pred2, labels=0)) # F1 Score
    bin_mcc_per_fold.append(matthews_corrcoef(y_true2, y_pred2))  # Matthews Correlation Coefficient
    
    # Save the multi-class data distribution
    train_distr.append((sum(labels[train])/labels[train].shape[0])*100)
    test_distr.append((sum(labels[test])/labels[test].shape[0])*100)
# Out:
# Epoch 1/35
# 747/747 [==============================] - 6s 6ms/step - loss: 0.1852 - accuracy: 0.9302 - val_loss: 0.0923 - val_accuracy: 0.9714
#
# Epoch 00001: val_loss improved from inf to 0.09234, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0937 - accuracy: 0.9689 - val_loss: 0.0765 - val_accuracy: 0.9808
#
# Epoch 00002: val_loss improved from 0.09234 to 0.07647, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0705 - accuracy: 0.9761 - val_loss: 0.0625 - val_accuracy: 0.9838
#
# Epoch 00003: val_loss improved from 0.07647 to 0.06254, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0633 - accuracy: 0.9777 - val_loss: 0.0670 - val_accuracy: 0.9823
#
# Epoch 00004: val_loss did not improve from 0.06254
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0606 - accuracy: 0.9788 - val_loss: 0.0630 - val_accuracy: 0.9849
#
# Epoch 00005: val_loss did not improve from 0.06254
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0490 - accuracy: 0.9836 - val_loss: 0.0604 - val_accuracy: 0.9838
#
# Epoch 00006: val_loss improved from 0.06254 to 0.06043, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0437 - accuracy: 0.9846 - val_loss: 0.0661 - val_accuracy: 0.9838
#
# Epoch 00007: val_loss did not improve from 0.06043
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0425 - accuracy: 0.9841 - val_loss: 0.0667 - val_accuracy: 0.9857
#
# Epoch 00008: val_loss did not improve from 0.06043
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0334 - accuracy: 0.9881 - val_loss: 0.0650 - val_accuracy: 0.9861
#
# Epoch 00009: val_loss did not improve from 0.06043
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0365 - accuracy: 0.9866 - val_loss: 0.0611 - val_accuracy: 0.9876
#
# Epoch 00010: val_loss did not improve from 0.06043
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0331 - accuracy: 0.9877 - val_loss: 0.0567 - val_accuracy: 0.9891
#
# Epoch 00011: val_loss improved from 0.06043 to 0.05675, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0297 - accuracy: 0.9895 - val_loss: 0.0615 - val_accuracy: 0.9853
#
# Epoch 00012: val_loss did not improve from 0.05675
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0266 - accuracy: 0.9905 - val_loss: 0.0735 - val_accuracy: 0.9827
#
# Epoch 00013: val_loss did not improve from 0.05675
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0232 - accuracy: 0.9913 - val_loss: 0.0683 - val_accuracy: 0.9879
#
# Epoch 00014: val_loss did not improve from 0.05675
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0270 - accuracy: 0.9905 - val_loss: 0.0638 - val_accuracy: 0.9879
#
# Epoch 00015: val_loss did not improve from 0.05675
# Epoch 16/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0246 - accuracy: 0.9912 - val_loss: 0.0680 - val_accuracy: 0.9861
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.05675
# Epoch 17/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0664 - val_accuracy: 0.9906
#
# Epoch 00017: val_loss did not improve from 0.05675
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0144 - accuracy: 0.9945 - val_loss: 0.0625 - val_accuracy: 0.9887
#
# Epoch 00018: val_loss did not improve from 0.05675
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.0718 - val_accuracy: 0.9906
#
# Epoch 00019: val_loss did not improve from 0.05675
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0837 - val_accuracy: 0.9883
#
# Epoch 00020: val_loss did not improve from 0.05675
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0812 - val_accuracy: 0.9883
#
# Epoch 00021: val_loss did not improve from 0.05675
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0818 - val_accuracy: 0.9895
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.05675
# Epoch 23/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0747 - val_accuracy: 0.9891
#
# Epoch 00023: val_loss did not improve from 0.05675
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0813 - val_accuracy: 0.9898
#
# Epoch 00024: val_loss did not improve from 0.05675
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0900 - val_accuracy: 0.9891
#
# Epoch 00025: val_loss did not improve from 0.05675
# Epoch 26/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0891 - val_accuracy: 0.9898
#
# Epoch 00026: val_loss did not improve from 0.05675
# Epoch 27/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0967 - val_accuracy: 0.9910
#
# Epoch 00027: val_loss did not improve from 0.05675
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0913 - val_accuracy: 0.9902
#
# Epoch 00028: val_loss did not improve from 0.05675
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.1020 - val_accuracy: 0.9887
#
# Epoch 00029: val_loss did not improve from 0.05675
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0971 - val_accuracy: 0.9906
#
# Epoch 00030: val_loss did not improve from 0.05675
# Epoch 31/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.1008 - val_accuracy: 0.9887
#
# Epoch 00031: val_loss did not improve from 0.05675
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0928 - val_accuracy: 0.9895
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.05675
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.1016 - val_accuracy: 0.9895
#
# Epoch 00033: val_loss did not improve from 0.05675
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1069 - val_accuracy: 0.9906
#
# Epoch 00034: val_loss did not improve from 0.05675
# Epoch 35/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.1059 - val_accuracy: 0.9895
#
# Epoch 00035: val_loss did not improve from 0.05675
# Score for fold 1: loss of 0.10590444505214691; accuracy of 98.94538521766663%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1976 - accuracy: 0.9241 - val_loss: 0.1111 - val_accuracy: 0.9620
#
# Epoch 00001: val_loss did not improve from 0.05675
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0952 - accuracy: 0.9671 - val_loss: 0.0765 - val_accuracy: 0.9766
#
# Epoch 00002: val_loss did not improve from 0.05675
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0755 - accuracy: 0.9740 - val_loss: 0.0694 - val_accuracy: 0.9774
#
# Epoch 00003: val_loss did not improve from 0.05675
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0644 - accuracy: 0.9779 - val_loss: 0.0679 - val_accuracy: 0.9804
#
# Epoch 00004: val_loss did not improve from 0.05675
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0550 - accuracy: 0.9803 - val_loss: 0.0569 - val_accuracy: 0.9834
#
# Epoch 00005: val_loss did not improve from 0.05675
# Epoch 6/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0494 - accuracy: 0.9823 - val_loss: 0.0658 - val_accuracy: 0.9800
#
# Epoch 00006: val_loss did not improve from 0.05675
# Epoch 7/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0447 - accuracy: 0.9840 - val_loss: 0.0668 - val_accuracy: 0.9812
#
# Epoch 00007: val_loss did not improve from 0.05675
# Epoch 8/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0394 - accuracy: 0.9858 - val_loss: 0.0525 - val_accuracy: 0.9849
#
# Epoch 00008: val_loss improved from 0.05675 to 0.05252, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0368 - accuracy: 0.9866 - val_loss: 0.0434 - val_accuracy: 0.9857
#
# Epoch 00009: val_loss improved from 0.05252 to 0.04345, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0325 - accuracy: 0.9889 - val_loss: 0.0483 - val_accuracy: 0.9857
#
# Epoch 00010: val_loss did not improve from 0.04345
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0289 - accuracy: 0.9896 - val_loss: 0.0494 - val_accuracy: 0.9872
#
# Epoch 00011: val_loss did not improve from 0.04345
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0301 - accuracy: 0.9893 - val_loss: 0.0392 - val_accuracy: 0.9887
#
# Epoch 00012: val_loss improved from 0.04345 to 0.03917, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 0.0483 - val_accuracy: 0.9868
#
# Epoch 00013: val_loss did not improve from 0.03917
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0426 - val_accuracy: 0.9883
#
# Epoch 00014: val_loss did not improve from 0.03917
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.0663 - val_accuracy: 0.9868
#
# Epoch 00015: val_loss did not improve from 0.03917
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 0.0556 - val_accuracy: 0.9902
#
# Epoch 00016: val_loss did not improve from 0.03917
# Epoch 17/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0203 - accuracy: 0.9928 - val_loss: 0.0409 - val_accuracy: 0.9898
#
# Epoch 00017: val_loss did not improve from 0.03917
# Epoch 18/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.0510 - val_accuracy: 0.9879
#
# Epoch 00018: val_loss did not improve from 0.03917
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0153 - accuracy: 0.9943 - val_loss: 0.0515 - val_accuracy: 0.9902
#
# Epoch 00019: val_loss did not improve from 0.03917
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0157 - accuracy: 0.9943 - val_loss: 0.0409 - val_accuracy: 0.9891
#
# Epoch 00020: val_loss did not improve from 0.03917
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 0.0440 - val_accuracy: 0.9887
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_loss did not improve from 0.03917
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0636 - val_accuracy: 0.9895
#
# Epoch 00022: val_loss did not improve from 0.03917
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.0490 - val_accuracy: 0.9925
#
# Epoch 00023: val_loss did not improve from 0.03917
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0730 - val_accuracy: 0.9913
#
# Epoch 00024: val_loss did not improve from 0.03917
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0557 - val_accuracy: 0.9913
#
# Epoch 00025: val_loss did not improve from 0.03917
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0496 - val_accuracy: 0.9917
#
# Epoch 00026: val_loss did not improve from 0.03917
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0578 - val_accuracy: 0.9917
#
# Epoch 00027: val_loss did not improve from 0.03917
# Epoch 28/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0636 - val_accuracy: 0.9902
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.03917
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0845 - val_accuracy: 0.9913
#
# Epoch 00029: val_loss did not improve from 0.03917
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0611 - val_accuracy: 0.9921
#
# Epoch 00030: val_loss did not improve from 0.03917
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0610 - val_accuracy: 0.9917
#
# Epoch 00031: val_loss did not improve from 0.03917
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0591 - val_accuracy: 0.9913
#
# Epoch 00032: val_loss did not improve from 0.03917
# Epoch 33/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0759 - val_accuracy: 0.9917
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_loss did not improve from 0.03917
# Epoch 34/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0742 - val_accuracy: 0.9913
#
# Epoch 00034: val_loss did not improve from 0.03917
# Epoch 35/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0670 - val_accuracy: 0.9921
#
# Epoch 00035: val_loss did not improve from 0.03917
# Score for fold 2: loss of 0.06701161712408066; accuracy of 99.20904040336609%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1962 - accuracy: 0.9262 - val_loss: 0.0984 - val_accuracy: 0.9642
#
# Epoch 00001: val_loss did not improve from 0.03917
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0906 - accuracy: 0.9703 - val_loss: 0.0725 - val_accuracy: 0.9736
#
# Epoch 00002: val_loss did not improve from 0.03917
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0725 - accuracy: 0.9761 - val_loss: 0.0631 - val_accuracy: 0.9759
#
# Epoch 00003: val_loss did not improve from 0.03917
# Epoch 4/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0591 - accuracy: 0.9800 - val_loss: 0.0620 - val_accuracy: 0.9774
#
# Epoch 00004: val_loss did not improve from 0.03917
# Epoch 5/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0499 - accuracy: 0.9821 - val_loss: 0.0701 - val_accuracy: 0.9774
#
# Epoch 00005: val_loss did not improve from 0.03917
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0462 - accuracy: 0.9841 - val_loss: 0.0569 - val_accuracy: 0.9782
#
# Epoch 00006: val_loss did not improve from 0.03917
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0389 - accuracy: 0.9854 - val_loss: 0.0670 - val_accuracy: 0.9766
#
# Epoch 00007: val_loss did not improve from 0.03917
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0365 - accuracy: 0.9872 - val_loss: 0.0410 - val_accuracy: 0.9853
#
# Epoch 00008: val_loss did not improve from 0.03917
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.0481 - val_accuracy: 0.9815
#
# Epoch 00009: val_loss did not improve from 0.03917
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0299 - accuracy: 0.9897 - val_loss: 0.0421 - val_accuracy: 0.9849
#
# Epoch 00010: val_loss did not improve from 0.03917
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0269 - accuracy: 0.9907 - val_loss: 0.0586 - val_accuracy: 0.9827
#
# Epoch 00011: val_loss did not improve from 0.03917
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0225 - accuracy: 0.9920 - val_loss: 0.0499 - val_accuracy: 0.9827
#
# Epoch 00012: val_loss did not improve from 0.03917
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.0394 - val_accuracy: 0.9857
#
# Epoch 00013: val_loss did not improve from 0.03917
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0198 - accuracy: 0.9931 - val_loss: 0.0439 - val_accuracy: 0.9861
#
# Epoch 00014: val_loss did not improve from 0.03917
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0461 - val_accuracy: 0.9853
#
# Epoch 00015: val_loss did not improve from 0.03917
# Epoch 16/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.0416 - val_accuracy: 0.9868
#
# Epoch 00016: val_loss did not improve from 0.03917
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.0482 - val_accuracy: 0.9842
#
# Epoch 00017: val_loss did not improve from 0.03917
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0121 - accuracy: 0.9952 - val_loss: 0.0615 - val_accuracy: 0.9838
#
# Epoch 00018: val_loss did not improve from 0.03917
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.0414 - val_accuracy: 0.9883
#
# Epoch 00019: val_loss did not improve from 0.03917
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 0.0383 - val_accuracy: 0.9879
#
# Epoch 00020: val_loss improved from 0.03917 to 0.03827, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0710 - val_accuracy: 0.9846
#
# Epoch 00021: val_loss did not improve from 0.03827
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.0481 - val_accuracy: 0.9879
#
# Epoch 00022: val_loss did not improve from 0.03827
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0413 - val_accuracy: 0.9891
#
# Epoch 00023: val_loss did not improve from 0.03827
# Epoch 24/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0493 - val_accuracy: 0.9868
#
# Epoch 00024: val_loss did not improve from 0.03827
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.0476 - val_accuracy: 0.9872
#
# Epoch 00025: val_loss did not improve from 0.03827
# Epoch 26/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 0.0452 - val_accuracy: 0.9868
#
# Epoch 00026: val_loss did not improve from 0.03827
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0571 - val_accuracy: 0.9857
#
# Epoch 00027: val_loss did not improve from 0.03827
# Epoch 28/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0563 - val_accuracy: 0.9864
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.03827
# Epoch 29/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0562 - val_accuracy: 0.9872
#
# Epoch 00029: val_loss did not improve from 0.03827
# Epoch 30/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0585 - val_accuracy: 0.9887
#
# Epoch 00030: val_loss did not improve from 0.03827
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0639 - val_accuracy: 0.9879
#
# Epoch 00031: val_loss did not improve from 0.03827
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0610 - val_accuracy: 0.9872
#
# Epoch 00032: val_loss did not improve from 0.03827
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0597 - val_accuracy: 0.9876
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.03827
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0608 - val_accuracy: 0.9887
#
# Epoch 00034: val_loss did not improve from 0.03827
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0667 - val_accuracy: 0.9864
#
# Epoch 00035: val_loss did not improve from 0.03827
# Score for fold 3: loss of 0.06665042787790298; accuracy of 98.6440658569336%
# Epoch 1/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.1828 - accuracy: 0.9353 - val_loss: 0.1062 - val_accuracy: 0.9601
#
# Epoch 00001: val_loss did not improve from 0.03827
# Epoch 2/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0961 - accuracy: 0.9686 - val_loss: 0.0867 - val_accuracy: 0.9702
#
# Epoch 00002: val_loss did not improve from 0.03827
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0773 - accuracy: 0.9753 - val_loss: 0.1066 - val_accuracy: 0.9669
#
# Epoch 00003: val_loss did not improve from 0.03827
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0654 - accuracy: 0.9796 - val_loss: 0.0777 - val_accuracy: 0.9725
#
# Epoch 00004: val_loss did not improve from 0.03827
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0603 - accuracy: 0.9794 - val_loss: 0.0827 - val_accuracy: 0.9721
#
# Epoch 00005: val_loss did not improve from 0.03827
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0505 - accuracy: 0.9835 - val_loss: 0.0757 - val_accuracy: 0.9755
#
# Epoch 00006: val_loss did not improve from 0.03827
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0512 - accuracy: 0.9824 - val_loss: 0.0626 - val_accuracy: 0.9785
#
# Epoch 00007: val_loss did not improve from 0.03827
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0440 - accuracy: 0.9847 - val_loss: 0.0714 - val_accuracy: 0.9770
#
# Epoch 00008: val_loss did not improve from 0.03827
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0407 - accuracy: 0.9849 - val_loss: 0.0625 - val_accuracy: 0.9789
#
# Epoch 00009: val_loss did not improve from 0.03827
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0352 - accuracy: 0.9880 - val_loss: 0.0543 - val_accuracy: 0.9831
#
# Epoch 00010: val_loss did not improve from 0.03827
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0320 - accuracy: 0.9879 - val_loss: 0.0572 - val_accuracy: 0.9819
#
# Epoch 00011: val_loss did not improve from 0.03827
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0328 - accuracy: 0.9886 - val_loss: 0.0528 - val_accuracy: 0.9838
#
# Epoch 00012: val_loss did not improve from 0.03827
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0289 - accuracy: 0.9895 - val_loss: 0.0523 - val_accuracy: 0.9834
#
# Epoch 00013: val_loss did not improve from 0.03827
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.0617 - val_accuracy: 0.9823
#
# Epoch 00014: val_loss did not improve from 0.03827
# Epoch 15/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0243 - accuracy: 0.9912 - val_loss: 0.0595 - val_accuracy: 0.9838
#
# Epoch 00015: val_loss did not improve from 0.03827
# Epoch 16/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.0574 - val_accuracy: 0.9815
#
# Epoch 00016: val_loss did not improve from 0.03827
# Epoch 17/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.0519 - val_accuracy: 0.9861
#
# Epoch 00017: val_loss did not improve from 0.03827
# Epoch 18/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0197 - accuracy: 0.9928 - val_loss: 0.0480 - val_accuracy: 0.9876
#
# Epoch 00018: val_loss did not improve from 0.03827
# Epoch 19/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0175 - accuracy: 0.9939 - val_loss: 0.0688 - val_accuracy: 0.9834
#
# Epoch 00019: val_loss did not improve from 0.03827
# Epoch 20/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.0666 - val_accuracy: 0.9857
#
# Epoch 00020: val_loss did not improve from 0.03827
# Epoch 21/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.0588 - val_accuracy: 0.9846
#
# Epoch 00021: val_loss did not improve from 0.03827
# Epoch 22/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0156 - accuracy: 0.9943 - val_loss: 0.0578 - val_accuracy: 0.9853
#
# Epoch 00022: val_loss did not improve from 0.03827
# Epoch 23/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0622 - val_accuracy: 0.9846
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.03827
# Epoch 24/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0521 - val_accuracy: 0.9887
#
# Epoch 00024: val_loss did not improve from 0.03827
# Epoch 25/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.0557 - val_accuracy: 0.9857
#
# Epoch 00025: val_loss did not improve from 0.03827
# Epoch 26/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0640 - val_accuracy: 0.9834
#
# Epoch 00026: val_loss did not improve from 0.03827
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0774 - val_accuracy: 0.9838
#
# Epoch 00027: val_loss did not improve from 0.03827
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0598 - val_accuracy: 0.9868
#
# Epoch 00028: val_loss did not improve from 0.03827
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0611 - val_accuracy: 0.9879
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.03827
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0713 - val_accuracy: 0.9868
#
# Epoch 00030: val_loss did not improve from 0.03827
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0748 - val_accuracy: 0.9864
#
# Epoch 00031: val_loss did not improve from 0.03827
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0617 - val_accuracy: 0.9883
#
# Epoch 00032: val_loss did not improve from 0.03827
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0763 - val_accuracy: 0.9853
#
# Epoch 00033: val_loss did not improve from 0.03827
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0841 - val_accuracy: 0.9868
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_loss did not improve from 0.03827
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.0748 - val_accuracy: 0.9876
#
# Epoch 00035: val_loss did not improve from 0.03827
# Score for fold 4: loss of 0.07483630627393723; accuracy of 98.75706434249878%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1846 - accuracy: 0.9309 - val_loss: 0.0997 - val_accuracy: 0.9661
#
# Epoch 00001: val_loss did not improve from 0.03827
# Epoch 2/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0992 - accuracy: 0.9670 - val_loss: 0.0758 - val_accuracy: 0.9740
#
# Epoch 00002: val_loss did not improve from 0.03827
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0796 - accuracy: 0.9733 - val_loss: 0.0687 - val_accuracy: 0.9729
#
# Epoch 00003: val_loss did not improve from 0.03827
# Epoch 4/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0710 - accuracy: 0.9746 - val_loss: 0.0694 - val_accuracy: 0.9759
#
# Epoch 00004: val_loss did not improve from 0.03827
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0621 - accuracy: 0.9777 - val_loss: 0.0640 - val_accuracy: 0.9763
#
# Epoch 00005: val_loss did not improve from 0.03827
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0523 - accuracy: 0.9807 - val_loss: 0.0658 - val_accuracy: 0.9763
#
# Epoch 00006: val_loss did not improve from 0.03827
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0499 - accuracy: 0.9810 - val_loss: 0.0586 - val_accuracy: 0.9800
#
# Epoch 00007: val_loss did not improve from 0.03827
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0424 - accuracy: 0.9856 - val_loss: 0.0576 - val_accuracy: 0.9782
#
# Epoch 00008: val_loss did not improve from 0.03827
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0372 - accuracy: 0.9864 - val_loss: 0.0585 - val_accuracy: 0.9815
#
# Epoch 00009: val_loss did not improve from 0.03827
# Epoch 10/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0348 - accuracy: 0.9880 - val_loss: 0.0458 - val_accuracy: 0.9827
#
# Epoch 00010: val_loss did not improve from 0.03827
# Epoch 11/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0312 - accuracy: 0.9891 - val_loss: 0.0451 - val_accuracy: 0.9838
#
# Epoch 00011: val_loss did not improve from 0.03827
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0294 - accuracy: 0.9902 - val_loss: 0.0469 - val_accuracy: 0.9861
#
# Epoch 00012: val_loss did not improve from 0.03827
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0286 - accuracy: 0.9902 - val_loss: 0.0505 - val_accuracy: 0.9849
#
# Epoch 00013: val_loss did not improve from 0.03827
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.0444 - val_accuracy: 0.9864
#
# Epoch 00014: val_loss did not improve from 0.03827
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0238 - accuracy: 0.9914 - val_loss: 0.0475 - val_accuracy: 0.9879
#
# Epoch 00015: val_loss did not improve from 0.03827
# Epoch 16/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0199 - accuracy: 0.9930 - val_loss: 0.0490 - val_accuracy: 0.9838
#
# Epoch 00016: val_loss did not improve from 0.03827
# Epoch 17/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.0537 - val_accuracy: 0.9846
#
# Epoch 00017: val_loss did not improve from 0.03827
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.0594 - val_accuracy: 0.9831
#
# Epoch 00018: val_loss did not improve from 0.03827
# Epoch 19/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0544 - val_accuracy: 0.9827
#
# Epoch 00019: val_loss did not improve from 0.03827
# Epoch 20/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 0.0641 - val_accuracy: 0.9868
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.03827
# Epoch 21/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.0575 - val_accuracy: 0.9872
#
# Epoch 00021: val_loss did not improve from 0.03827
# Epoch 22/35
# 747/747 [==============================] - 5s 7ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.0511 - val_accuracy: 0.9876
#
# Epoch 00022: val_loss did not improve from 0.03827
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0570 - val_accuracy: 0.9872
#
# Epoch 00023: val_loss did not improve from 0.03827
# Epoch 24/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0849 - val_accuracy: 0.9872
#
# Epoch 00024: val_loss did not improve from 0.03827
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0677 - val_accuracy: 0.9887
#
# Epoch 00025: val_loss did not improve from 0.03827
# Epoch 26/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0727 - val_accuracy: 0.9876
#
# Epoch 00026: val_loss did not improve from 0.03827
# Epoch 27/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0658 - val_accuracy: 0.9868
#
# Epoch 00027: val_loss did not improve from 0.03827
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0676 - val_accuracy: 0.9876
#
# Epoch 00028: val_loss did not improve from 0.03827
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0648 - val_accuracy: 0.9876
#
# Epoch 00029: val_loss did not improve from 0.03827
# Epoch 30/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0700 - val_accuracy: 0.9868
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.03827
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0640 - val_accuracy: 0.9879
#
# Epoch 00031: val_loss did not improve from 0.03827
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0641 - val_accuracy: 0.9887
#
# Epoch 00032: val_loss did not improve from 0.03827
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0681 - val_accuracy: 0.9876
#
# Epoch 00033: val_loss did not improve from 0.03827
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0656 - val_accuracy: 0.9891
#
# Epoch 00034: val_loss did not improve from 0.03827
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0707 - val_accuracy: 0.9879
#
# Epoch 00035: val_loss did not improve from 0.03827
# Score for fold 5: loss of 0.0706629678606987; accuracy of 98.79472851753235%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1876 - accuracy: 0.9309 - val_loss: 0.1158 - val_accuracy: 0.9631
#
# Epoch 00001: val_loss did not improve from 0.03827
# Epoch 2/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0971 - accuracy: 0.9671 - val_loss: 0.0754 - val_accuracy: 0.9778
#
# Epoch 00002: val_loss did not improve from 0.03827
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0773 - accuracy: 0.9746 - val_loss: 0.0737 - val_accuracy: 0.9770
#
# Epoch 00003: val_loss did not improve from 0.03827
# Epoch 4/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.0642 - accuracy: 0.9784 - val_loss: 0.0555 - val_accuracy: 0.9800
#
# Epoch 00004: val_loss did not improve from 0.03827
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0563 - accuracy: 0.9805 - val_loss: 0.0636 - val_accuracy: 0.9800
#
# Epoch 00005: val_loss did not improve from 0.03827
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0486 - accuracy: 0.9837 - val_loss: 0.0518 - val_accuracy: 0.9815
#
# Epoch 00006: val_loss did not improve from 0.03827
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0464 - accuracy: 0.9834 - val_loss: 0.0468 - val_accuracy: 0.9815
#
# Epoch 00007: val_loss did not improve from 0.03827
# Epoch 8/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0409 - accuracy: 0.9856 - val_loss: 0.0465 - val_accuracy: 0.9819
#
# Epoch 00008: val_loss did not improve from 0.03827
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0351 - accuracy: 0.9877 - val_loss: 0.0419 - val_accuracy: 0.9831
#
# Epoch 00009: val_loss did not improve from 0.03827
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 0.0441 - val_accuracy: 0.9823
#
# Epoch 00010: val_loss did not improve from 0.03827
# Epoch 11/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0299 - accuracy: 0.9895 - val_loss: 0.0360 - val_accuracy: 0.9868
#
# Epoch 00011: val_loss improved from 0.03827 to 0.03602, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 12/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0267 - accuracy: 0.9913 - val_loss: 0.0326 - val_accuracy: 0.9872
#
# Epoch 00012: val_loss improved from 0.03602 to 0.03257, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0284 - accuracy: 0.9901 - val_loss: 0.0417 - val_accuracy: 0.9864
#
# Epoch 00013: val_loss did not improve from 0.03257
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9916 - val_loss: 0.0406 - val_accuracy: 0.9857
#
# Epoch 00014: val_loss did not improve from 0.03257
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0207 - accuracy: 0.9923 - val_loss: 0.0313 - val_accuracy: 0.9891
#
# Epoch 00015: val_loss improved from 0.03257 to 0.03133, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.0355 - val_accuracy: 0.9883
#
# Epoch 00016: val_loss did not improve from 0.03133
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0207 - accuracy: 0.9929 - val_loss: 0.0346 - val_accuracy: 0.9876
#
# Epoch 00017: val_loss did not improve from 0.03133
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0418 - val_accuracy: 0.9853
#
# Epoch 00018: val_loss did not improve from 0.03133
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.0415 - val_accuracy: 0.9861
#
# Epoch 00019: val_loss did not improve from 0.03133
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0302 - val_accuracy: 0.9898
#
# Epoch 00020: val_loss improved from 0.03133 to 0.03024, saving model to /Users/Max/Documents/GitHub/misc_experiments/cnn-binary-local-v003\model.h5
# Epoch 21/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.0425 - val_accuracy: 0.9857
#
# Epoch 00021: val_loss did not improve from 0.03024
# Epoch 22/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0344 - val_accuracy: 0.9864
#
# Epoch 00022: val_loss did not improve from 0.03024
# Epoch 23/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0149 - accuracy: 0.9945 - val_loss: 0.0344 - val_accuracy: 0.9891
#
# Epoch 00023: val_loss did not improve from 0.03024
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0410 - val_accuracy: 0.9876
#
# Epoch 00024: val_loss did not improve from 0.03024
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0421 - val_accuracy: 0.9872
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.03024
# Epoch 26/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0407 - val_accuracy: 0.9868
#
# Epoch 00026: val_loss did not improve from 0.03024
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0444 - val_accuracy: 0.9887
#
# Epoch 00027: val_loss did not improve from 0.03024
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0465 - val_accuracy: 0.9879
#
# Epoch 00028: val_loss did not improve from 0.03024
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0396 - val_accuracy: 0.9887
#
# Epoch 00029: val_loss did not improve from 0.03024
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0399 - val_accuracy: 0.9883
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.03024
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0413 - val_accuracy: 0.9895
#
# Epoch 00031: val_loss did not improve from 0.03024
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0442 - val_accuracy: 0.9895
#
# Epoch 00032: val_loss did not improve from 0.03024
# Epoch 33/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.0469 - val_accuracy: 0.9891
#
# Epoch 00033: val_loss did not improve from 0.03024
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0493 - val_accuracy: 0.9876
#
# Epoch 00034: val_loss did not improve from 0.03024
# Epoch 35/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0420 - val_accuracy: 0.9891
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00035: val_loss did not improve from 0.03024
# Score for fold 6: loss of 0.04203662648797035; accuracy of 98.90772104263306%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1985 - accuracy: 0.9241 - val_loss: 0.0975 - val_accuracy: 0.9676
#
# Epoch 00001: val_loss did not improve from 0.03024
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0941 - accuracy: 0.9684 - val_loss: 0.0799 - val_accuracy: 0.9744
#
# Epoch 00002: val_loss did not improve from 0.03024
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0749 - accuracy: 0.9740 - val_loss: 0.0696 - val_accuracy: 0.9778
#
# Epoch 00003: val_loss did not improve from 0.03024
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0655 - accuracy: 0.9771 - val_loss: 0.0598 - val_accuracy: 0.9797
#
# Epoch 00004: val_loss did not improve from 0.03024
# Epoch 5/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0546 - accuracy: 0.9806 - val_loss: 0.0573 - val_accuracy: 0.9823
#
# Epoch 00005: val_loss did not improve from 0.03024
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0489 - accuracy: 0.9826 - val_loss: 0.0487 - val_accuracy: 0.9846
#
# Epoch 00006: val_loss did not improve from 0.03024
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0438 - accuracy: 0.9840 - val_loss: 0.0477 - val_accuracy: 0.9827
#
# Epoch 00007: val_loss did not improve from 0.03024
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0389 - accuracy: 0.9864 - val_loss: 0.0494 - val_accuracy: 0.9861
#
# Epoch 00008: val_loss did not improve from 0.03024
# Epoch 9/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0325 - accuracy: 0.9882 - val_loss: 0.0445 - val_accuracy: 0.9879
#
# Epoch 00009: val_loss did not improve from 0.03024
# Epoch 10/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0344 - accuracy: 0.9882 - val_loss: 0.0605 - val_accuracy: 0.9846
#
# Epoch 00010: val_loss did not improve from 0.03024
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0290 - accuracy: 0.9895 - val_loss: 0.0519 - val_accuracy: 0.9861
#
# Epoch 00011: val_loss did not improve from 0.03024
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0263 - accuracy: 0.9898 - val_loss: 0.0603 - val_accuracy: 0.9842
#
# Epoch 00012: val_loss did not improve from 0.03024
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.0669 - val_accuracy: 0.9849
#
# Epoch 00013: val_loss did not improve from 0.03024
# Epoch 14/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 0.0612 - val_accuracy: 0.9857
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.03024
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0138 - accuracy: 0.9950 - val_loss: 0.0623 - val_accuracy: 0.9868
#
# Epoch 00015: val_loss did not improve from 0.03024
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 0.0542 - val_accuracy: 0.9887
#
# Epoch 00016: val_loss did not improve from 0.03024
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.0496 - val_accuracy: 0.9887
#
# Epoch 00017: val_loss did not improve from 0.03024
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0533 - val_accuracy: 0.9895
#
# Epoch 00018: val_loss did not improve from 0.03024
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0517 - val_accuracy: 0.9883
#
# Epoch 00019: val_loss did not improve from 0.03024
# Epoch 20/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0618 - val_accuracy: 0.9883
#
# Epoch 00020: val_loss did not improve from 0.03024
# Epoch 21/35
# ...
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss did not improve from 0.03024
# Epoch 28/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0570 - val_accuracy: 0.9857
#
# Epoch 00028: val_loss did not improve from 0.03024
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0632 - val_accuracy: 0.9842
#
# Epoch 00029: val_loss did not improve from 0.03024
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0641 - val_accuracy: 0.9857
#
# Epoch 00030: val_loss did not improve from 0.03024
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0631 - val_accuracy: 0.9857
#
# Epoch 00031: val_loss did not improve from 0.03024
# Epoch 32/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0537 - val_accuracy: 0.9861
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.03024
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0585 - val_accuracy: 0.9861
#
# Epoch 00033: val_loss did not improve from 0.03024
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0582 - val_accuracy: 0.9849
#
# Epoch 00034: val_loss did not improve from 0.03024
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0547 - val_accuracy: 0.9864
#
# Epoch 00035: val_loss did not improve from 0.03024
# Score for fold 8: loss of 0.0546606071293354; accuracy of 98.6440658569336%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.2142 - accuracy: 0.9181 - val_loss: 0.1299 - val_accuracy: 0.9601
#
# Epoch 00001: val_loss did not improve from 0.03024
# Epoch 2/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.1116 - accuracy: 0.9619 - val_loss: 0.0909 - val_accuracy: 0.9702
#
# Epoch 00002: val_loss did not improve from 0.03024
# Epoch 3/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0869 - accuracy: 0.9712 - val_loss: 0.0705 - val_accuracy: 0.9763
#
# Epoch 00003: val_loss did not improve from 0.03024
# Epoch 4/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0751 - accuracy: 0.9739 - val_loss: 0.0564 - val_accuracy: 0.9781
#
# Epoch 00004: val_loss did not improve from 0.03024
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0659 - accuracy: 0.9767 - val_loss: 0.0532 - val_accuracy: 0.9778
#
# Epoch 00005: val_loss did not improve from 0.03024
# Epoch 6/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0560 - accuracy: 0.9797 - val_loss: 0.0501 - val_accuracy: 0.9838
#
# Epoch 00006: val_loss did not improve from 0.03024
# Epoch 7/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0501 - accuracy: 0.9819 - val_loss: 0.0545 - val_accuracy: 0.9823
#
# Epoch 00007: val_loss did not improve from 0.03024
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0453 - accuracy: 0.9831 - val_loss: 0.0500 - val_accuracy: 0.9808
#
# Epoch 00008: val_loss did not improve from 0.03024
# Epoch 9/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0398 - accuracy: 0.9856 - val_loss: 0.0426 - val_accuracy: 0.9842
#
# Epoch 00009: val_loss did not improve from 0.03024
# Epoch 10/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0357 - accuracy: 0.9869 - val_loss: 0.0350 - val_accuracy: 0.9872
#
# Epoch 00010: val_loss did not improve from 0.03024
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.0583 - val_accuracy: 0.9793
#
# Epoch 00011: val_loss did not improve from 0.03024
# Epoch 12/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0323 - accuracy: 0.9881 - val_loss: 0.0459 - val_accuracy: 0.9846
#
# Epoch 00012: val_loss did not improve from 0.03024
# Epoch 13/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0286 - accuracy: 0.9902 - val_loss: 0.0428 - val_accuracy: 0.9834
#
# Epoch 00013: val_loss did not improve from 0.03024
# Epoch 14/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0243 - accuracy: 0.9913 - val_loss: 0.0494 - val_accuracy: 0.9853
#
# Epoch 00014: val_loss did not improve from 0.03024
# Epoch 15/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.0535 - val_accuracy: 0.9861
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.03024
# Epoch 16/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.0359 - val_accuracy: 0.9876
#
# Epoch 00016: val_loss did not improve from 0.03024
# Epoch 17/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0380 - val_accuracy: 0.9879
#
# Epoch 00017: val_loss did not improve from 0.03024
# Epoch 18/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0452 - val_accuracy: 0.9883
#
# Epoch 00018: val_loss did not improve from 0.03024
# Epoch 19/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0385 - val_accuracy: 0.9872
#
# Epoch 00019: val_loss did not improve from 0.03024
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0403 - val_accuracy: 0.9883
#
# Epoch 00020: val_loss did not improve from 0.03024
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0456 - val_accuracy: 0.9887
#
# Epoch 00021: val_loss did not improve from 0.03024
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0480 - val_accuracy: 0.9872
#
# Epoch 00022: val_loss did not improve from 0.03024
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0384 - val_accuracy: 0.9894
#
# Epoch 00023: val_loss did not improve from 0.03024
# Epoch 24/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0423 - val_accuracy: 0.9883
#
# Epoch 00024: val_loss did not improve from 0.03024
# Epoch 25/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0498 - val_accuracy: 0.9876
#
# Epoch 00025: val_loss did not improve from 0.03024
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0400 - val_accuracy: 0.9887
#
# Epoch 00026: val_loss did not improve from 0.03024
# Epoch 27/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0395 - val_accuracy: 0.9898
#
# Epoch 00027: val_loss did not improve from 0.03024
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0418 - val_accuracy: 0.9894
#
# Epoch 00028: val_loss did not improve from 0.03024
# Epoch 29/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0424 - val_accuracy: 0.9902
#
# Epoch 00029: val_loss did not improve from 0.03024
# Epoch 30/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0493 - val_accuracy: 0.9891
#
# Epoch 00030: val_loss did not improve from 0.03024
# Epoch 31/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0397 - val_accuracy: 0.9921
#
# Epoch 00031: val_loss did not improve from 0.03024
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0519 - val_accuracy: 0.9876
#
# Epoch 00032: val_loss did not improve from 0.03024
# Epoch 33/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0471 - val_accuracy: 0.9887
#
# Epoch 00033: val_loss did not improve from 0.03024
# Epoch 34/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0412 - val_accuracy: 0.9898
#
# Epoch 00034: val_loss did not improve from 0.03024
# Epoch 35/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0425 - val_accuracy: 0.9891
#
# Epoch 00035: val_loss did not improve from 0.03024
# Score for fold 9: loss of 0.042494092136621475; accuracy of 98.9073097705841%
# Epoch 1/35
# 747/747 [==============================] - 5s 6ms/step - loss: 0.1877 - accuracy: 0.9306 - val_loss: 0.0914 - val_accuracy: 0.9642
#
# Epoch 00001: val_loss did not improve from 0.03024
# Epoch 2/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0959 - accuracy: 0.9673 - val_loss: 0.0934 - val_accuracy: 0.9714
#
# Epoch 00002: val_loss did not improve from 0.03024
# Epoch 3/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0736 - accuracy: 0.9749 - val_loss: 0.0671 - val_accuracy: 0.9755
#
# Epoch 00003: val_loss did not improve from 0.03024
# Epoch 4/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0613 - accuracy: 0.9795 - val_loss: 0.0480 - val_accuracy: 0.9834
#
# Epoch 00004: val_loss did not improve from 0.03024
# Epoch 5/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0556 - accuracy: 0.9812 - val_loss: 0.0483 - val_accuracy: 0.9838
#
# Epoch 00005: val_loss did not improve from 0.03024
# Epoch 6/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0489 - accuracy: 0.9823 - val_loss: 0.0443 - val_accuracy: 0.9853
#
# Epoch 00006: val_loss did not improve from 0.03024
# Epoch 7/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0421 - accuracy: 0.9847 - val_loss: 0.0495 - val_accuracy: 0.9838
#
# Epoch 00007: val_loss did not improve from 0.03024
# Epoch 8/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0384 - accuracy: 0.9862 - val_loss: 0.0408 - val_accuracy: 0.9857
#
# Epoch 00008: val_loss did not improve from 0.03024
# Epoch 9/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0355 - accuracy: 0.9873 - val_loss: 0.0409 - val_accuracy: 0.9861
#
# Epoch 00009: val_loss did not improve from 0.03024
# Epoch 10/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0328 - accuracy: 0.9882 - val_loss: 0.0343 - val_accuracy: 0.9868
#
# Epoch 00010: val_loss did not improve from 0.03024
# Epoch 11/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0311 - accuracy: 0.9896 - val_loss: 0.0420 - val_accuracy: 0.9849
#
# Epoch 00011: val_loss did not improve from 0.03024
# Epoch 12/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0277 - accuracy: 0.9900 - val_loss: 0.0367 - val_accuracy: 0.9891
#
# Epoch 00012: val_loss did not improve from 0.03024
# Epoch 13/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0270 - accuracy: 0.9903 - val_loss: 0.0355 - val_accuracy: 0.9887
#
# Epoch 00013: val_loss did not improve from 0.03024
# Epoch 14/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.0347 - val_accuracy: 0.9906
#
# Epoch 00014: val_loss did not improve from 0.03024
# Epoch 15/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.0398 - val_accuracy: 0.9872
#
# Epoch 00015: val_loss did not improve from 0.03024
# Epoch 16/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9929 - val_loss: 0.0381 - val_accuracy: 0.9879
#
# Epoch 00016: val_loss did not improve from 0.03024
# Epoch 17/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.0424 - val_accuracy: 0.9898
#
# Epoch 00017: val_loss did not improve from 0.03024
# Epoch 18/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.0722 - val_accuracy: 0.9872
#
# Epoch 00018: val_loss did not improve from 0.03024
# Epoch 19/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0410 - val_accuracy: 0.9891
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.03024
# Epoch 20/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0383 - val_accuracy: 0.9898
#
# Epoch 00020: val_loss did not improve from 0.03024
# Epoch 21/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0433 - val_accuracy: 0.9906
#
# Epoch 00021: val_loss did not improve from 0.03024
# Epoch 22/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0477 - val_accuracy: 0.9902
#
# Epoch 00022: val_loss did not improve from 0.03024
# Epoch 23/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0452 - val_accuracy: 0.9910
#
# Epoch 00023: val_loss did not improve from 0.03024
# Epoch 24/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0400 - val_accuracy: 0.9917
#
# Epoch 00024: val_loss did not improve from 0.03024
# Epoch 25/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0428 - val_accuracy: 0.9891
#
# Epoch 00025: val_loss did not improve from 0.03024
# Epoch 26/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.0411 - val_accuracy: 0.9879
#
# Epoch 00026: val_loss did not improve from 0.03024
# Epoch 27/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0049 - accuracy: 0.9981 - val_loss: 0.0441 - val_accuracy: 0.9910
#
# Epoch 00027: val_loss did not improve from 0.03024
# Epoch 28/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0385 - val_accuracy: 0.9921
#
# Epoch 00028: val_loss did not improve from 0.03024
# Epoch 29/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0542 - val_accuracy: 0.9883
#
# Epoch 00029: val_loss did not improve from 0.03024
# Epoch 30/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0412 - val_accuracy: 0.9913
#
# Epoch 00030: val_loss did not improve from 0.03024
# Epoch 31/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0504 - val_accuracy: 0.9917
#
# Epoch 00031: val_loss did not improve from 0.03024
# Epoch 32/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0464 - val_accuracy: 0.9894
#
# Epoch 00032: val_loss did not improve from 0.03024
# Epoch 33/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0453 - val_accuracy: 0.9913
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.03024
# Epoch 34/35
# 747/747 [==============================] - 4s 6ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0509 - val_accuracy: 0.9921
#
# Epoch 00034: val_loss did not improve from 0.03024
# Epoch 35/35
# 747/747 [==============================] - 4s 5ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0580 - val_accuracy: 0.9894
#
# Epoch 00035: val_loss did not improve from 0.03024
# Score for fold 10: loss of 0.0580013208091259; accuracy of 98.94498586654663%

# %% [markdown]
# Cross validation run overview

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(multi_acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {multi_acc_per_fold[i]*100}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(multi_acc_per_fold)*100}% (+- {np.std(multi_acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.10590444505214691 - Accuracy: 98.94538521766663%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.06701161712408066 - Accuracy: 99.20904040336609%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.06665042787790298 - Accuracy: 98.6440658569336%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.07483630627393723 - Accuracy: 98.75706434249878%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.0706629678606987 - Accuracy: 98.79472851753235%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.04203662648797035 - Accuracy: 98.90772104263306%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.08266853541135788 - Accuracy: 98.90772104263306%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.0546606071293354 - Accuracy: 98.6440658569336%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.042494092136621475 - Accuracy: 98.9073097705841%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.0580013208091259 - Accuracy: 98.94498586654663%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 98.86620879173279% (+- 0.0015838591466664016)
# > Loss: 0.06649269461631775
# ------------------------------------------------------------------------

# %% [markdown]
# # Evaluating performance

# %% [markdown]
# Create data distribution graph

# %%
perc_train = np.mean(train_distr, axis = 0)
perc_test =  np.mean(test_distr, axis = 0)

plt.bar(x_axis - 0.2, perc_train, 0.4, label = 'Training')
plt.errorbar(x_axis - 0.2, perc_train, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize = 0)

plt.bar(x_axis + 0.2, perc_test,0.4, label = 'Test')
plt.errorbar(x_axis + 0.2, perc_test, yerr = np.std(train_distr, axis = 0), 
             fmt='|', color='red', capsize=0.0)


plt.title('Distribution of the dataset')
plt.ylabel('Dataset distribution in percentage (%)')
plt.xticks(x_axis, list(classes), rotation='vertical')
plt.legend()

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %%
t = PrettyTable(['Metric', 'Performance', 'St.Deviation'])
t.add_row(['TPR    ', round(np.mean(bin_tpr_per_fold),4), round(np.std(bin_tpr_per_fold),4)])
t.add_row(['Acc    ', round(np.mean(multi_acc_per_fold),4), round(np.std(multi_acc_per_fold),4)])
t.add_row(['Loss   ', round(np.mean(loss_per_fold),4), round(np.std(loss_per_fold),4)])
t.add_row(['F1     ', round(np.mean(bin_f1_per_fold),4), round(np.std(bin_f1_per_fold),4)])
t.add_row(['MCC    ', round(np.mean(bin_mcc_per_fold),4), round(np.std(bin_mcc_per_fold),4)])
t.header = True
t.set_style(MSWORD_FRIENDLY)
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +--------------------------------------+
# |          Performance of CNN          |
# | Metric  | Performance | St.Deviation |
# | TPR     | 0.9885      | 0.0034       |
# | Acc     | 0.9887      | 0.0016       |
# | Loss    | 0.0665      | 0.0181       |
# | F1      | 0.988       | 0.0016       |
# | MCC     | 0.9773      | 0.0032       |

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# Evaluate the model based on the test set

# %% [markdown]
# Save a table with the performance on the test set

# %% [markdown]
# **Evaluating overfitting and other model performance measures**

# %%
linecolours = ['gray', 'orange', 'blue', 'green','silver', 'cyan', 'red', 'purple', 'lightgreen', 'black', 'brown']

# %%
def eval_metric(model, history, metric_name, ymin, ymax):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    for i in range(n_folds-1):  
        metric = history[i].history[metric_name]
        val_metric = history[i].history['val_' + metric_name]
        e = range(1, epoch_t + 1)
        plt.plot(e, metric, marker = 'o', linestyle = 'none', color = linecolours[i])
        plt.plot(e, val_metric, color = linecolours[i])
        
    metric = history[n_folds-1].history[metric_name]
    val_metric = history[n_folds-1].history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, marker = 'o', linestyle = 'none', label = 'Training', color = linecolours[n_folds-1])
    plt.plot(e, val_metric, label = 'Validation', color = linecolours[n_folds-1])
    
    plt.ylim(ymin, ymax)
    
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for CNN across folds')
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight', dpi = 150)

# %%
eval_metric(Malware_model, history, 'loss', 0,1)

# %%
eval_metric(Malware_model, history, 'accuracy', 0.8,1)

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %% [markdown]
# # Binary classification
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %% [markdown]
# Plot the distribution of dataset as ransomware - benign

# %%
rw_count
# Out:
# [1221, 1242, 1250, 1241, 1249, 1267, 1285, 1265, 1248, 1268]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [np.mean(rw_count), np.mean(bn_count)]
plt.title('Distribution of the test set')
plt.ylabel('Dataset distribution in absolute numbers')
ax.bar(x_lab, y_lab)
ax.errorbar(x_lab, y_lab, yerr = [np.std(rw_count), np.std(bn_count)], fmt = '|', ecolor='red')
if cenv == 0:
    plt.savefig("bin_data_dist.png", bbox_inches = 'tight', dpi = 150)
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight', dpi = 150)

# %% [markdown]
# Plot binary confusion matrix

# %%
all_y_predbin = [] 
all_y_truebin = []
for count, value in enumerate(y_true):
    if y_true[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_truebin.append(0)
    else: all_y_truebin.append(1) # if prediction is not one of the ransomware families, then it is benign

    if y_pred[count] in range(10): # range(10) is 0 to 9, meaning all ransomware families
        all_y_predbin.append(0)
    else: all_y_predbin.append(1) # if prediction is not one of the ransomware families, then it is benign
    continue

# %%
def confusion_matrix_bin(confusion_matrix, class_names_bin, name, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(f"{(name.capitalize())} Confusion Matrix - CNN")
    if cenv == 0:
        plt.savefig(f"{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)
    if cenv == 1:
        plt.savefig(f"{new_dir}/{name}_cmatrix.png", bbox_inches = 'tight', dpi = 150)

# %%
c_matrix = metrics.confusion_matrix(y_true, y_pred)
class_names= batches.class_indices.keys()
confusion_matrix_bin(c_matrix, class_names, 'binary-class', figsize = (20,7), fontsize=14)
