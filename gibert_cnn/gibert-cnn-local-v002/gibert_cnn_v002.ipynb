# %% [markdown]
# # Gibert CNN

# %% [markdown]
# **Notes about this specific notebook**
#
# This Convolutional Neural Network is based on the following paper: https://link.springer.com/article/10.1007/s11416-018-0323-0
#
# Uses the thesis dataset.

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 40

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/gibert_cnn"
    for files in os.listdir(dir):
        if "gibert-cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: gibert-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 1 matches(es) found
# --------------
# New folder name: gibert-cnn-local-v002
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# **Automatic reverse weight calculation.**
#
# The weight is determined by how well respresented the class is in the dataset; the less represented, the higher the weigth. This way of calculating weights aims to overcome the unbalanced data. The 'Adam' optimizer is not affected by the weights like other optimizer would be

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9,
#  'benign': 10}

# %%
imgs.shape
# Out:
# (26548, 64, 64, 1)

# %%
labels.shape
# Out:
# (26548, 11)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (7965, 11)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 18583 | Shape of training data (18583, 64, 64, 1)
# Size of training data: 7965  | Shape of training data (7965, 64, 64, 1)
# Shape of training labels (18583, 11)
# Shape of training labels (7965, 11)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = 11
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(50, kernel_size=(5, 5),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(BatchNormalization())
    
    Malware_model.add(Conv2D(70, (3, 3), activation='relu'))
    
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(BatchNormalization())
    
    Malware_model.add(Conv2D(70, (3, 3), activation='relu'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(BatchNormalization())
    
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='relu'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 60, 60, 50)        1300
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 50)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 30, 30, 50)        200
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 70)        31570
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 70)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 14, 14, 70)        280
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 70)        44170
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 70)          0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 6, 6, 70)          280
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 70)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2520)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               322688
# _________________________________________________________________
# dense_7 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 401,907
# Trainable params: 401,527
# Non-trainable params: 380
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint]) # The actual computation of the CNN
# Out:
# Epoch 1/40
# 581/581 [==============================] - 6s 10ms/step - loss: 0.3956 - accuracy: 0.8893 - val_loss: 0.5353 - val_accuracy: 0.7847
#
# Epoch 00001: val_loss improved from inf to 0.53533, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v002\model.h5
# Epoch 2/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.2271 - accuracy: 0.9318 - val_loss: 0.3018 - val_accuracy: 0.9185
#
# Epoch 00002: val_loss improved from 0.53533 to 0.30180, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v002\model.h5
# Epoch 3/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1782 - accuracy: 0.9437 - val_loss: 0.2174 - val_accuracy: 0.9352
#
# Epoch 00003: val_loss improved from 0.30180 to 0.21745, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v002\model.h5
# Epoch 4/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1391 - accuracy: 0.9564 - val_loss: 0.2006 - val_accuracy: 0.9444
#
# Epoch 00004: val_loss improved from 0.21745 to 0.20058, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v002\model.h5
# Epoch 5/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1166 - accuracy: 0.9623 - val_loss: 0.2747 - val_accuracy: 0.9328
#
# Epoch 00005: val_loss did not improve from 0.20058
# Epoch 6/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1120 - accuracy: 0.9636 - val_loss: 0.1991 - val_accuracy: 0.9517
#
# Epoch 00006: val_loss improved from 0.20058 to 0.19911, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v002\model.h5
# Epoch 7/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0918 - accuracy: 0.9716 - val_loss: 0.2062 - val_accuracy: 0.9510
#
# Epoch 00007: val_loss did not improve from 0.19911
# Epoch 8/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0795 - accuracy: 0.9732 - val_loss: 0.2371 - val_accuracy: 0.9382
#
# Epoch 00008: val_loss did not improve from 0.19911
# Epoch 9/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0854 - accuracy: 0.9731 - val_loss: 0.2717 - val_accuracy: 0.9446
#
# Epoch 00009: val_loss did not improve from 0.19911
# Epoch 10/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0743 - accuracy: 0.9759 - val_loss: 0.3061 - val_accuracy: 0.8937
#
# Epoch 00010: val_loss did not improve from 0.19911
# Epoch 11/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0669 - accuracy: 0.9776 - val_loss: 0.2314 - val_accuracy: 0.9498
#
# Epoch 00011: val_loss did not improve from 0.19911
# Epoch 12/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0736 - accuracy: 0.9766 - val_loss: 0.2542 - val_accuracy: 0.9346
#
# Epoch 00012: val_loss did not improve from 0.19911
# Epoch 13/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0734 - accuracy: 0.9770 - val_loss: 0.2339 - val_accuracy: 0.9518
#
# Epoch 00013: val_loss did not improve from 0.19911
# Epoch 14/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0656 - accuracy: 0.9792 - val_loss: 0.2846 - val_accuracy: 0.9429
#
# Epoch 00014: val_loss did not improve from 0.19911
# Epoch 15/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0554 - accuracy: 0.9814 - val_loss: 0.2414 - val_accuracy: 0.9547
#
# Epoch 00015: val_loss did not improve from 0.19911
# Epoch 16/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0511 - accuracy: 0.9827 - val_loss: 0.2679 - val_accuracy: 0.9481
#
# Epoch 00016: val_loss did not improve from 0.19911
# Epoch 17/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0566 - accuracy: 0.9816 - val_loss: 0.2582 - val_accuracy: 0.9537
#
# Epoch 00017: val_loss did not improve from 0.19911
# Epoch 18/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0537 - accuracy: 0.9816 - val_loss: 0.2644 - val_accuracy: 0.9391
#
# Epoch 00018: val_loss did not improve from 0.19911
# Epoch 19/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0435 - accuracy: 0.9850 - val_loss: 0.3132 - val_accuracy: 0.9450
#
# Epoch 00019: val_loss did not improve from 0.19911
# Epoch 20/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0456 - accuracy: 0.9844 - val_loss: 0.3428 - val_accuracy: 0.9340
#
# Epoch 00020: val_loss did not improve from 0.19911
# Epoch 21/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0545 - accuracy: 0.9827 - val_loss: 0.2946 - val_accuracy: 0.9530
#
# Epoch 00021: val_loss did not improve from 0.19911
# Epoch 22/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0459 - accuracy: 0.9841 - val_loss: 0.2744 - val_accuracy: 0.9551
#
# Epoch 00022: val_loss did not improve from 0.19911
# Epoch 23/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0378 - accuracy: 0.9859 - val_loss: 0.2456 - val_accuracy: 0.9551
#
# Epoch 00023: val_loss did not improve from 0.19911
# Epoch 24/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0407 - accuracy: 0.9849 - val_loss: 0.3234 - val_accuracy: 0.9381
#
# Epoch 00024: val_loss did not improve from 0.19911
# Epoch 25/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0438 - accuracy: 0.9851 - val_loss: 0.3393 - val_accuracy: 0.9384
#
# Epoch 00025: val_loss did not improve from 0.19911
# Epoch 26/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0408 - accuracy: 0.9854 - val_loss: 0.3366 - val_accuracy: 0.9514
#
# Epoch 00026: val_loss did not improve from 0.19911
# Epoch 27/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0431 - accuracy: 0.9849 - val_loss: 0.3047 - val_accuracy: 0.9436
#
# Epoch 00027: val_loss did not improve from 0.19911
# Epoch 28/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0350 - accuracy: 0.9876 - val_loss: 0.2934 - val_accuracy: 0.9539
#
# Epoch 00028: val_loss did not improve from 0.19911
# Epoch 29/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0330 - accuracy: 0.9885 - val_loss: 0.3937 - val_accuracy: 0.9419
#
# Epoch 00029: val_loss did not improve from 0.19911
# Epoch 30/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0361 - accuracy: 0.9876 - val_loss: 0.3579 - val_accuracy: 0.9463
#
# Epoch 00030: val_loss did not improve from 0.19911
# Epoch 31/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0305 - accuracy: 0.9890 - val_loss: 0.3035 - val_accuracy: 0.9312
#
# Epoch 00031: val_loss did not improve from 0.19911
# Epoch 32/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0292 - accuracy: 0.9893 - val_loss: 0.3364 - val_accuracy: 0.9485
#
# Epoch 00032: val_loss did not improve from 0.19911
# Epoch 33/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0234 - accuracy: 0.9923 - val_loss: 0.3447 - val_accuracy: 0.9530
#
# Epoch 00033: val_loss did not improve from 0.19911
# Epoch 34/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0380 - accuracy: 0.9879 - val_loss: 0.3704 - val_accuracy: 0.9352
#
# Epoch 00034: val_loss did not improve from 0.19911
# Epoch 35/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0249 - accuracy: 0.9906 - val_loss: 0.3426 - val_accuracy: 0.9507
#
# Epoch 00035: val_loss did not improve from 0.19911
# Epoch 36/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 0.3650 - val_accuracy: 0.9395
#
# Epoch 00036: val_loss did not improve from 0.19911
# Epoch 37/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0281 - accuracy: 0.9903 - val_loss: 0.3686 - val_accuracy: 0.9459
#
# Epoch 00037: val_loss did not improve from 0.19911
# Epoch 38/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0220 - accuracy: 0.9919 - val_loss: 0.3302 - val_accuracy: 0.9548
#
# Epoch 00038: val_loss did not improve from 0.19911
# Epoch 39/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.3879 - val_accuracy: 0.9507
#
# Epoch 00039: val_loss did not improve from 0.19911
# Epoch 40/40
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 0.3763 - val_accuracy: 0.9470
#
# Epoch 00040: val_loss did not improve from 0.19911

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 249/249 [==============================] - 1s 4ms/step - loss: 0.1991 - accuracy: 0.9517
# Overall CNN Accuracy: 0.9516635537147522
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9517          |
# | Validation loss               | 0.1991          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([10,  0, 10, ...,  7,  1, 10], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([10,  0, 10, ...,  7,  1, 10], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 7965
# 7965

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Ransomware' 'Benign' 'Benign' ... 'Benign' 'Benign' 'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 14012

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +------------------------------------------------+
# |               Performance of CNN               |
# +----------------------------------+-------------+
# | Metric                           | Performance |
# +----------------------------------+-------------+
# | True Positive Rate               | 0.9732      |
# | Accuracy                         | 0.982       |
# | F1 Score                         | 0.9831      |
# | Matthews Correlation Coefficient | 0.9641      |
# +----------------------------------+-------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)
