# %% [markdown]
# # Gibert CNN

# %% [markdown]
# **Notes about this specific notebook**
#
# This Convolutional Neural Network is based on the following paper: https://link.springer.com/article/10.1007/s11416-018-0323-0
#
# Uses the thesis dataset

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 200

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/gibert_cnn"
    for files in os.listdir(dir):
        if "gibert_cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: gibert-cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# No matches found
# New folder name: gibert-cnn-local-v001
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# **Automatic reverse weight calculation.**
#
# The weight is determined by how well respresented the class is in the dataset; the less represented, the higher the weigth. This way of calculating weights aims to overcome the unbalanced data. The 'Adam' optimizer is not affected by the weights like other optimizer would be

# %%
distr = (sum(labels)/labels.shape[0])
weights = 1-(distr)/(wf/distr)

# %%
class_weight = {0: weights[0], 1: weights[1], 2: weights[2], 3: weights[3], 4: weights[4], 5: weights[5],
               6: weights[6], 7: weights[7], 8: weights[8], 9: weights[9], 10: weights[10]}

# %%
print(class_weight)
# Out:
# {0: 0.98318845, 1: 0.9792672, 2: 0.9980167, 3: 0.99800247, 4: 0.99873376, 5: 0.9940748, 6: 0.99741197, 7: 0.9938011, 8: 0.99880844, 9: 0.9992029, 10: 0.44285703}

# %%
(max(weights)-min(weights))/max(weights)
# Out:
# 0.5567897

# %%
b_weight = weights[10]/sum(weights)*100
print("The weight for the benign sample makes up {b_weight}% of the total weights".format(b_weight = b_weight))
# Out:
# The weight for the benign sample makes up 4.265062753598218% of the total weights

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9,
#  'benign': 10}

# %%
imgs.shape
# Out:
# (26548, 64, 64, 1)

# %%
labels.shape
# Out:
# (26548, 11)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (7965, 11)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 18583 | Shape of training data (18583, 64, 64, 1)
# Size of training data: 7965  | Shape of training data (7965, 64, 64, 1)
# Shape of training labels (18583, 11)
# Shape of training labels (7965, 11)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = 11
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(50, kernel_size=(5, 5),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(BatchNormalization())
    
    Malware_model.add(Conv2D(70, (3, 3), activation='relu'))
    
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(BatchNormalization())
    
    Malware_model.add(Conv2D(70, (3, 3), activation='relu'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(BatchNormalization())
    
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(256, activation='relu'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 60, 60, 50)        1300
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 50)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 50)        200
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 70)        31570
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 70)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 70)        280
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 70)        44170
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 70)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 70)          280
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 70)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2520)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               645376
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                2827
# =================================================================
# Total params: 726,003
# Trainable params: 725,623
# Non-trainable params: 380
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint],
    class_weight=class_weight) # The actual computation of the CNN
# Out:
# WARNING:tensorflow:From C:\Users\Max\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/200
# 581/581 [==============================] - 7s 10ms/step - loss: 0.3446 - accuracy: 0.8844 - val_loss: 1.7736 - val_accuracy: 0.4948
#
# Epoch 00001: val_loss improved from inf to 1.77364, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v001\model.h5
# Epoch 2/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.2073 - accuracy: 0.9234 - val_loss: 0.2730 - val_accuracy: 0.9188
#
# Epoch 00002: val_loss improved from 1.77364 to 0.27296, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v001\model.h5
# Epoch 3/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1639 - accuracy: 0.9385 - val_loss: 0.3087 - val_accuracy: 0.8908
#
# Epoch 00003: val_loss did not improve from 0.27296
# Epoch 4/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1388 - accuracy: 0.9451 - val_loss: 0.2091 - val_accuracy: 0.9377
#
# Epoch 00004: val_loss improved from 0.27296 to 0.20913, saving model to /Users/Max/Documents/GitHub/gibert_cnn/gibert-cnn-local-v001\model.h5
# Epoch 5/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1141 - accuracy: 0.9557 - val_loss: 0.3260 - val_accuracy: 0.8937
#
# Epoch 00005: val_loss did not improve from 0.20913
# Epoch 6/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.1031 - accuracy: 0.9611 - val_loss: 0.4794 - val_accuracy: 0.8608
#
# Epoch 00006: val_loss did not improve from 0.20913
# Epoch 7/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0879 - accuracy: 0.9673 - val_loss: 0.2179 - val_accuracy: 0.9322
#
# Epoch 00007: val_loss did not improve from 0.20913
# Epoch 8/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0782 - accuracy: 0.9719 - val_loss: 0.4096 - val_accuracy: 0.8768
#
# Epoch 00008: val_loss did not improve from 0.20913
# Epoch 9/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0853 - accuracy: 0.9696 - val_loss: 0.3745 - val_accuracy: 0.8878
#
# Epoch 00009: val_loss did not improve from 0.20913
# Epoch 10/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0746 - accuracy: 0.9731 - val_loss: 0.2350 - val_accuracy: 0.9384
#
# Epoch 00010: val_loss did not improve from 0.20913
# Epoch 11/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0611 - accuracy: 0.9786 - val_loss: 0.2468 - val_accuracy: 0.9504
#
# Epoch 00011: val_loss did not improve from 0.20913
# Epoch 12/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0620 - accuracy: 0.9784 - val_loss: 0.3799 - val_accuracy: 0.9400
#
# Epoch 00012: val_loss did not improve from 0.20913
# Epoch 13/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0612 - accuracy: 0.9790 - val_loss: 0.3244 - val_accuracy: 0.9281
#
# Epoch 00013: val_loss did not improve from 0.20913
# Epoch 14/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0664 - accuracy: 0.9761 - val_loss: 0.2606 - val_accuracy: 0.9381
#
# Epoch 00014: val_loss did not improve from 0.20913
# Epoch 15/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0515 - accuracy: 0.9819 - val_loss: 0.2356 - val_accuracy: 0.9520
#
# Epoch 00015: val_loss did not improve from 0.20913
# Epoch 16/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0519 - accuracy: 0.9815 - val_loss: 0.4714 - val_accuracy: 0.8624
#
# Epoch 00016: val_loss did not improve from 0.20913
# Epoch 17/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0613 - accuracy: 0.9787 - val_loss: 0.2544 - val_accuracy: 0.9528
#
# Epoch 00017: val_loss did not improve from 0.20913
# Epoch 18/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0508 - accuracy: 0.9826 - val_loss: 0.2618 - val_accuracy: 0.9502
#
# Epoch 00018: val_loss did not improve from 0.20913
# Epoch 19/200
# 581/581 [==============================] - 5s 9ms/step - loss: 0.0421 - accuracy: 0.9844 - val_loss: 0.3068 - val_accuracy: 0.9510
#
# Epoch 00019: val_loss did not improve from 0.20913
# Epoch 20/200
# 581/581 [==============================] - 6s 10ms/step - loss: 0.0524 - accuracy: 0.9824 - val_loss: 0.2609 - val_accuracy: 0.9475
#
# Epoch 00020: val_loss did not improve from 0.20913
# Epoch 21/200
# 581/581 [==============================] - 6s 10ms/step - loss: 0.0538 - accuracy: 0.9814 - val_loss: 0.2454 - val_accuracy: 0.9504
#
# Epoch 00021: val_loss did not improve from 0.20913
# Epoch 22/200
# 581/581 [==============================] - 6s 10ms/step - loss: 0.0433 - accuracy: 0.9848 - val_loss: 0.2791 - val_accuracy: 0.9397
#
# Epoch 00022: val_loss did not improve from 0.20913
# Epoch 23/200
# 581/581 [==============================] - 6s 10ms/step - loss: 0.0418 - accuracy: 0.9849 - val_loss: 0.2930 - val_accuracy: 0.9445
#
# Epoch 00023: val_loss did not improve from 0.20913
# Epoch 24/200
# 581/581 [==============================] - 6s 10ms/step - loss: 0.0401 - accuracy: 0.9855 - val_loss: 0.8426 - val_accuracy: 0.8393
#
# Epoch 00024: val_loss did not improve from 0.20913
# Epoch 25/200
# 275/581 [=============>................] - ETA: 2s - loss: 0.0403 - accuracy: 0.9850
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15424/649333456.py in <module>
# ----> 1 history = Malware_model.fit(
#       2     X_train,
#       3     y_train,
#       4     validation_data=(X_test, y_test),
#       5     epochs=epoch_t,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1186               logs = tmp_logs  # No error, now safe to assign to logs.
#    1187               end_step = step + data_handler.step_increment
# -> 1188               callbacks.on_train_batch_end(end_step, logs)
#    1189               if self.stop_training:
#    1190                 break
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     455     """
#     456     if self._should_call_train_batch_hooks:
# --> 457       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     458
#     459   def on_test_batch_begin(self, batch, logs=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     315       self._call_batch_begin_hook(mode, batch, logs)
#     316     elif hook == 'end':
# --> 317       self._call_batch_end_hook(mode, batch, logs)
#     318     else:
#     319       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     335       self._batch_times.append(batch_time)
#     336
# --> 337     self._call_batch_hook_helper(hook_name, batch, logs)
#     338
#     339     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     373     for callback in self.callbacks:
#     374       hook = getattr(callback, hook_name)
# --> 375       hook(batch, logs)
#     376
#     377     if self._check_timing:
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1027
#    1028   def on_train_batch_end(self, batch, logs=None):
# -> 1029     self._batch_update_progbar(batch, logs)
#    1030
#    1031   def on_test_batch_end(self, batch, logs=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1099     if self.verbose == 1:
#    1100       # Only block async when verbose = 1.
# -> 1101       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1102       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1103
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     517     return t  # Don't turn ragged or sparse tensors to NumPy.
#     518
# --> 519   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     520
#     521
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     513   def _to_single_numpy_or_python_type(t):
#     514     if isinstance(t, ops.Tensor):
# --> 515       x = t.numpy()
#     516       return x.item() if np.ndim(x) == 0 else x
#     517     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 249/249 [==============================] - 1s 4ms/step - loss: 0.2091 - accuracy: 0.9377
# Overall CNN Accuracy: 0.9377275705337524
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9377          |
# | Validation loss               | 0.2091          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([10,  0, 10, ...,  0, 10,  0], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([10,  0, 10, ...,  0, 10,  0], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 7965
# 7965

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Benign' 'Benign' 'Ransomware' ... 'Benign' 'Benign' 'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 14012

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +------------------------------------------------+
# |               Performance of CNN               |
# +----------------------------------+-------------+
# | Metric                           | Performance |
# +----------------------------------+-------------+
# | True Positive Rate               | 0.9808      |
# | Accuracy                         | 0.9832      |
# | F1 Score                         | 0.9839      |
# | Matthews Correlation Coefficient | 0.9663      |
# +----------------------------------+-------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with LeakyReLU activation.
#
# Includes weights for all classes to overcome unbalanced data

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 200

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cnn"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cnn/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 11 matches(es) found
# --------------
# New folder name: cnn-local-v012
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# **Automatic reverse weight calculation.**
#
# The weight is determined by how well respresented the class is in the dataset; the less represented, the higher the weigth. This way of calculating weights aims to overcome the unbalanced data. The 'Adam' optimizer is not affected by the weights like other optimizer would be

# %%
distr = (sum(labels)/labels.shape[0])
weights = 1-(distr)/(wf/distr)

# %%
class_weight = {0: weights[0], 1: weights[1], 2: weights[2], 3: weights[3], 4: weights[4], 5: weights[5],
               6: weights[6], 7: weights[7], 8: weights[8], 9: weights[9], 10: weights[10]}

# %%
print(class_weight)
# Out:
# {0: 0.98318845, 1: 0.9792672, 2: 0.9980167, 3: 0.99800247, 4: 0.99873376, 5: 0.9940748, 6: 0.99741197, 7: 0.9938011, 8: 0.99880844, 9: 0.9992029, 10: 0.44285703}

# %%
(max(weights)-min(weights))/max(weights)
# Out:
# 0.5567897

# %%
b_weight = weights[10]/sum(weights)*100
print("The weight for the benign sample makes up {b_weight}% of the total weights".format(b_weight = b_weight))
# Out:
# The weight for the benign sample makes up 4.265062753598218% of the total weights

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9,
#  'benign': 10}

# %%
imgs.shape
# Out:
# (26548, 64, 64, 1)

# %%
labels.shape
# Out:
# (26548, 11)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (7965, 11)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 18583 | Shape of training data (18583, 64, 64, 1)
# Size of training data: 7965  | Shape of training data (7965, 64, 64, 1)
# Shape of training labels (18583, 11)
# Shape of training labels (7965, 11)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = 11
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='LeakyReLU'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='LeakyReLU'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='LeakyReLU'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2940)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               376448
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_5 (Dense)              (None, 11)                561
# =================================================================
# Total params: 387,824
# Trainable params: 387,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint],
    class_weight=class_weight) # The actual computation of the CNN
# Out:
# Epoch 1/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.4605 - accuracy: 0.8384 - val_loss: 0.3564 - val_accuracy: 0.8873
#
# Epoch 00001: val_loss improved from inf to 0.35643, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 2/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.2686 - accuracy: 0.9017 - val_loss: 0.2558 - val_accuracy: 0.9189
#
# Epoch 00002: val_loss improved from 0.35643 to 0.25580, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 3/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.2197 - accuracy: 0.9187 - val_loss: 0.2567 - val_accuracy: 0.9155
#
# Epoch 00003: val_loss did not improve from 0.25580
# Epoch 4/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.1934 - accuracy: 0.9286 - val_loss: 0.1986 - val_accuracy: 0.9370
#
# Epoch 00004: val_loss improved from 0.25580 to 0.19864, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 5/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1704 - accuracy: 0.9363 - val_loss: 0.2078 - val_accuracy: 0.9377
#
# Epoch 00005: val_loss did not improve from 0.19864
# Epoch 6/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1553 - accuracy: 0.9410 - val_loss: 0.1824 - val_accuracy: 0.9424
#
# Epoch 00006: val_loss improved from 0.19864 to 0.18244, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 7/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1392 - accuracy: 0.9444 - val_loss: 0.1932 - val_accuracy: 0.9434
#
# Epoch 00007: val_loss did not improve from 0.18244
# Epoch 8/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1318 - accuracy: 0.9482 - val_loss: 0.1701 - val_accuracy: 0.9464
#
# Epoch 00008: val_loss improved from 0.18244 to 0.17014, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 9/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.1183 - accuracy: 0.9526 - val_loss: 0.1857 - val_accuracy: 0.9466
#
# Epoch 00009: val_loss did not improve from 0.17014
# Epoch 10/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1150 - accuracy: 0.9538 - val_loss: 0.1723 - val_accuracy: 0.9478
#
# Epoch 00010: val_loss did not improve from 0.17014
# Epoch 11/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1038 - accuracy: 0.9590 - val_loss: 0.1740 - val_accuracy: 0.9484
#
# Epoch 00011: val_loss did not improve from 0.17014
# Epoch 12/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0987 - accuracy: 0.9599 - val_loss: 0.1850 - val_accuracy: 0.9485
#
# Epoch 00012: val_loss did not improve from 0.17014
# Epoch 13/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0916 - accuracy: 0.9633 - val_loss: 0.2006 - val_accuracy: 0.9470
#
# Epoch 00013: val_loss did not improve from 0.17014
# Epoch 14/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0974 - accuracy: 0.9621 - val_loss: 0.2190 - val_accuracy: 0.9400
#
# Epoch 00014: val_loss did not improve from 0.17014
# Epoch 15/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0837 - accuracy: 0.9661 - val_loss: 0.1929 - val_accuracy: 0.9461
#
# Epoch 00015: val_loss did not improve from 0.17014
# Epoch 16/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0795 - accuracy: 0.9671 - val_loss: 0.2007 - val_accuracy: 0.9507
#
# Epoch 00016: val_loss did not improve from 0.17014
# Epoch 17/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0823 - accuracy: 0.9680 - val_loss: 0.2049 - val_accuracy: 0.9474
#
# Epoch 00017: val_loss did not improve from 0.17014
# Epoch 18/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0784 - accuracy: 0.9681 - val_loss: 0.1963 - val_accuracy: 0.9485
#
# Epoch 00018: val_loss did not improve from 0.17014
# Epoch 19/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0769 - accuracy: 0.9688 - val_loss: 0.2006 - val_accuracy: 0.9460
#
# Epoch 00019: val_loss did not improve from 0.17014
# Epoch 20/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0732 - accuracy: 0.9703 - val_loss: 0.2080 - val_accuracy: 0.9503
#
# Epoch 00020: val_loss did not improve from 0.17014
# Epoch 21/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0723 - accuracy: 0.9715 - val_loss: 0.2141 - val_accuracy: 0.9500
#
# Epoch 00021: val_loss did not improve from 0.17014
# Epoch 22/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0741 - accuracy: 0.9708 - val_loss: 0.2189 - val_accuracy: 0.9494
#
# Epoch 00022: val_loss did not improve from 0.17014
# Epoch 23/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0732 - accuracy: 0.9706 - val_loss: 0.2007 - val_accuracy: 0.9484
#
# Epoch 00023: val_loss did not improve from 0.17014
# Epoch 24/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0631 - accuracy: 0.9750 - val_loss: 0.2073 - val_accuracy: 0.9490
#
# Epoch 00024: val_loss did not improve from 0.17014
# Epoch 25/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0636 - accuracy: 0.9759 - val_loss: 0.2515 - val_accuracy: 0.9465
#
# Epoch 00025: val_loss did not improve from 0.17014
# Epoch 26/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0614 - accuracy: 0.9756 - val_loss: 0.2351 - val_accuracy: 0.9490
#
# Epoch 00026: val_loss did not improve from 0.17014
# Epoch 27/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0633 - accuracy: 0.9748 - val_loss: 0.2291 - val_accuracy: 0.9480
#
# Epoch 00027: val_loss did not improve from 0.17014
# Epoch 28/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0663 - accuracy: 0.9750 - val_loss: 0.2242 - val_accuracy: 0.9461
#
# Epoch 00028: val_loss did not improve from 0.17014
# Epoch 29/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0593 - accuracy: 0.9763 - val_loss: 0.2394 - val_accuracy: 0.9509
#
# Epoch 00029: val_loss did not improve from 0.17014
# Epoch 30/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0596 - accuracy: 0.9762 - val_loss: 0.2201 - val_accuracy: 0.9495
#
# Epoch 00030: val_loss did not improve from 0.17014
# Epoch 31/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0608 - accuracy: 0.9770 - val_loss: 0.2719 - val_accuracy: 0.9444
#
# Epoch 00031: val_loss did not improve from 0.17014
# Epoch 32/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0580 - accuracy: 0.9778 - val_loss: 0.2421 - val_accuracy: 0.9500
#
# Epoch 00032: val_loss did not improve from 0.17014
# Epoch 33/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0565 - accuracy: 0.9788 - val_loss: 0.2459 - val_accuracy: 0.9493
#
# Epoch 00033: val_loss did not improve from 0.17014
# Epoch 34/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0546 - accuracy: 0.9784 - val_loss: 0.2516 - val_accuracy: 0.9481
#
# Epoch 00034: val_loss did not improve from 0.17014
# Epoch 35/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0576 - accuracy: 0.9777 - val_loss: 0.2714 - val_accuracy: 0.9483
#
# Epoch 00035: val_loss did not improve from 0.17014
# Epoch 36/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0568 - accuracy: 0.9779 - val_loss: 0.2519 - val_accuracy: 0.9507
#
# Epoch 00036: val_loss did not improve from 0.17014
# Epoch 37/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0565 - accuracy: 0.9778 - val_loss: 0.2487 - val_accuracy: 0.9479
#
# Epoch 00037: val_loss did not improve from 0.17014
# Epoch 38/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0553 - accuracy: 0.9780 - val_loss: 0.2423 - val_accuracy: 0.9489
#
# Epoch 00038: val_loss did not improve from 0.17014
# Epoch 39/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0527 - accuracy: 0.9793 - val_loss: 0.2557 - val_accuracy: 0.9500
#
# Epoch 00039: val_loss did not improve from 0.17014
# Epoch 40/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0554 - accuracy: 0.9789 - val_loss: 0.2487 - val_accuracy: 0.9493
#
# Epoch 00040: val_loss did not improve from 0.17014
# Epoch 41/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0531 - accuracy: 0.9790 - val_loss: 0.2506 - val_accuracy: 0.9510
#
# Epoch 00041: val_loss did not improve from 0.17014
# Epoch 42/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0514 - accuracy: 0.9791 - val_loss: 0.2457 - val_accuracy: 0.9480
#
# Epoch 00042: val_loss did not improve from 0.17014
# Epoch 43/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0515 - accuracy: 0.9795 - val_loss: 0.2814 - val_accuracy: 0.9481
#
# Epoch 00043: val_loss did not improve from 0.17014
# Epoch 44/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0510 - accuracy: 0.9804 - val_loss: 0.2580 - val_accuracy: 0.9490
#
# Epoch 00044: val_loss did not improve from 0.17014
# Epoch 45/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0504 - accuracy: 0.9804 - val_loss: 0.2813 - val_accuracy: 0.9480
#
# Epoch 00045: val_loss did not improve from 0.17014
# Epoch 46/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0489 - accuracy: 0.9805 - val_loss: 0.2629 - val_accuracy: 0.9487
#
# Epoch 00046: val_loss did not improve from 0.17014
# Epoch 47/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0497 - accuracy: 0.9814 - val_loss: 0.2742 - val_accuracy: 0.9499
#
# Epoch 00047: val_loss did not improve from 0.17014
# Epoch 48/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0454 - accuracy: 0.9829 - val_loss: 0.2812 - val_accuracy: 0.9451
#
# Epoch 00048: val_loss did not improve from 0.17014
# Epoch 49/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0507 - accuracy: 0.9805 - val_loss: 0.2960 - val_accuracy: 0.9490
#
# Epoch 00049: val_loss did not improve from 0.17014
# Epoch 50/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0478 - accuracy: 0.9818 - val_loss: 0.2803 - val_accuracy: 0.9497
#
# Epoch 00050: val_loss did not improve from 0.17014
# Epoch 51/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0440 - accuracy: 0.9838 - val_loss: 0.2930 - val_accuracy: 0.9509
#
# Epoch 00051: val_loss did not improve from 0.17014
# Epoch 52/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0517 - accuracy: 0.9806 - val_loss: 0.2562 - val_accuracy: 0.9489
#
# Epoch 00052: val_loss did not improve from 0.17014
# Epoch 53/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0487 - accuracy: 0.9818 - val_loss: 0.2781 - val_accuracy: 0.9455
#
# Epoch 00053: val_loss did not improve from 0.17014
# Epoch 54/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0428 - accuracy: 0.9832 - val_loss: 0.2879 - val_accuracy: 0.9478
#
# Epoch 00054: val_loss did not improve from 0.17014
# Epoch 55/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0469 - accuracy: 0.9815 - val_loss: 0.2876 - val_accuracy: 0.9474
#
# Epoch 00055: val_loss did not improve from 0.17014
# Epoch 56/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0473 - accuracy: 0.9815 - val_loss: 0.2940 - val_accuracy: 0.9459
#
# Epoch 00056: val_loss did not improve from 0.17014
# Epoch 57/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0409 - accuracy: 0.9834 - val_loss: 0.3123 - val_accuracy: 0.9478
#
# Epoch 00057: val_loss did not improve from 0.17014
# Epoch 58/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0434 - accuracy: 0.9832 - val_loss: 0.3043 - val_accuracy: 0.9479
#
# Epoch 00058: val_loss did not improve from 0.17014
# Epoch 59/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0449 - accuracy: 0.9829 - val_loss: 0.3157 - val_accuracy: 0.9465
#
# Epoch 00059: val_loss did not improve from 0.17014
# Epoch 60/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0399 - accuracy: 0.9847 - val_loss: 0.2922 - val_accuracy: 0.9471
#
# Epoch 00060: val_loss did not improve from 0.17014
# Epoch 61/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0421 - accuracy: 0.9830 - val_loss: 0.3044 - val_accuracy: 0.9488
#
# Epoch 00061: val_loss did not improve from 0.17014
# Epoch 62/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0415 - accuracy: 0.9843 - val_loss: 0.3164 - val_accuracy: 0.9484
#
# Epoch 00062: val_loss did not improve from 0.17014
# Epoch 63/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0462 - accuracy: 0.9820 - val_loss: 0.2935 - val_accuracy: 0.9484
#
# Epoch 00063: val_loss did not improve from 0.17014
# Epoch 64/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0433 - accuracy: 0.9838 - val_loss: 0.3132 - val_accuracy: 0.9479
#
# Epoch 00064: val_loss did not improve from 0.17014
# Epoch 65/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0424 - accuracy: 0.9836 - val_loss: 0.3124 - val_accuracy: 0.9469
#
# Epoch 00065: val_loss did not improve from 0.17014
# Epoch 66/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0473 - accuracy: 0.9808 - val_loss: 0.3001 - val_accuracy: 0.9480
#
# Epoch 00066: val_loss did not improve from 0.17014
# Epoch 67/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0442 - accuracy: 0.9831 - val_loss: 0.3009 - val_accuracy: 0.9469
#
# Epoch 00067: val_loss did not improve from 0.17014
# Epoch 68/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0367 - accuracy: 0.9859 - val_loss: 0.3015 - val_accuracy: 0.9471
#
# Epoch 00068: val_loss did not improve from 0.17014
# Epoch 69/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0351 - accuracy: 0.9857 - val_loss: 0.3662 - val_accuracy: 0.9464
#
# Epoch 00069: val_loss did not improve from 0.17014
# Epoch 70/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0400 - accuracy: 0.9853 - val_loss: 0.3300 - val_accuracy: 0.9488
#
# Epoch 00070: val_loss did not improve from 0.17014
# Epoch 71/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0404 - accuracy: 0.9846 - val_loss: 0.3294 - val_accuracy: 0.9487
#
# Epoch 00071: val_loss did not improve from 0.17014
# Epoch 72/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0384 - accuracy: 0.9857 - val_loss: 0.3438 - val_accuracy: 0.9456
#
# Epoch 00072: val_loss did not improve from 0.17014
# Epoch 73/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0400 - accuracy: 0.9850 - val_loss: 0.3412 - val_accuracy: 0.9473
#
# Epoch 00073: val_loss did not improve from 0.17014
# Epoch 74/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0389 - accuracy: 0.9843 - val_loss: 0.3079 - val_accuracy: 0.9481
#
# Epoch 00074: val_loss did not improve from 0.17014
# Epoch 75/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0388 - accuracy: 0.9842 - val_loss: 0.2988 - val_accuracy: 0.9484
#
# Epoch 00075: val_loss did not improve from 0.17014
# Epoch 76/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0368 - accuracy: 0.9860 - val_loss: 0.3248 - val_accuracy: 0.9483
#
# Epoch 00076: val_loss did not improve from 0.17014
# Epoch 77/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0400 - accuracy: 0.9851 - val_loss: 0.2966 - val_accuracy: 0.9464
#
# Epoch 00077: val_loss did not improve from 0.17014
# Epoch 78/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0422 - accuracy: 0.9839 - val_loss: 0.2882 - val_accuracy: 0.9469
#
# Epoch 00078: val_loss did not improve from 0.17014
# Epoch 79/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0347 - accuracy: 0.9863 - val_loss: 0.3126 - val_accuracy: 0.9483
#
# Epoch 00079: val_loss did not improve from 0.17014
# Epoch 80/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0362 - accuracy: 0.9856 - val_loss: 0.3395 - val_accuracy: 0.9458
#
# Epoch 00080: val_loss did not improve from 0.17014
# Epoch 81/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0290 - accuracy: 0.9890 - val_loss: 0.3614 - val_accuracy: 0.9464
#
# Epoch 00081: val_loss did not improve from 0.17014
# Epoch 82/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0355 - accuracy: 0.9864 - val_loss: 0.3638 - val_accuracy: 0.9459
#
# Epoch 00082: val_loss did not improve from 0.17014
# Epoch 83/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0412 - accuracy: 0.9848 - val_loss: 0.3136 - val_accuracy: 0.9474
#
# Epoch 00083: val_loss did not improve from 0.17014
# Epoch 84/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0361 - accuracy: 0.9862 - val_loss: 0.3610 - val_accuracy: 0.9464
#
# Epoch 00084: val_loss did not improve from 0.17014
# Epoch 85/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0386 - accuracy: 0.9848 - val_loss: 0.3755 - val_accuracy: 0.9431
#
# Epoch 00085: val_loss did not improve from 0.17014
# Epoch 86/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0353 - accuracy: 0.9867 - val_loss: 0.3219 - val_accuracy: 0.9463
#
# Epoch 00086: val_loss did not improve from 0.17014
# Epoch 87/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0322 - accuracy: 0.9883 - val_loss: 0.3452 - val_accuracy: 0.9513
#
# Epoch 00087: val_loss did not improve from 0.17014
# Epoch 88/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0362 - accuracy: 0.9864 - val_loss: 0.3314 - val_accuracy: 0.9481
#
# Epoch 00088: val_loss did not improve from 0.17014
# Epoch 89/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0336 - accuracy: 0.9863 - val_loss: 0.3290 - val_accuracy: 0.9433
#
# Epoch 00089: val_loss did not improve from 0.17014
# Epoch 90/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0320 - accuracy: 0.9879 - val_loss: 0.3464 - val_accuracy: 0.9490
#
# Epoch 00090: val_loss did not improve from 0.17014
# Epoch 91/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0373 - accuracy: 0.9860 - val_loss: 0.3054 - val_accuracy: 0.9485
#
# Epoch 00091: val_loss did not improve from 0.17014
# Epoch 92/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0380 - accuracy: 0.9858 - val_loss: 0.3067 - val_accuracy: 0.9518
#
# Epoch 00092: val_loss did not improve from 0.17014
# Epoch 93/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0313 - accuracy: 0.9890 - val_loss: 0.3253 - val_accuracy: 0.9494
#
# Epoch 00093: val_loss did not improve from 0.17014
# Epoch 94/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0330 - accuracy: 0.9878 - val_loss: 0.3273 - val_accuracy: 0.9488
#
# Epoch 00094: val_loss did not improve from 0.17014
# Epoch 95/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0337 - accuracy: 0.9876 - val_loss: 0.3114 - val_accuracy: 0.9505
#
# Epoch 00095: val_loss did not improve from 0.17014
# Epoch 96/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0343 - accuracy: 0.9875 - val_loss: 0.3486 - val_accuracy: 0.9448
#
# Epoch 00096: val_loss did not improve from 0.17014
# Epoch 97/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0358 - accuracy: 0.9868 - val_loss: 0.3192 - val_accuracy: 0.9504
#
# Epoch 00097: val_loss did not improve from 0.17014
# Epoch 98/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0354 - accuracy: 0.9864 - val_loss: 0.3332 - val_accuracy: 0.9463
#
# Epoch 00098: val_loss did not improve from 0.17014
# Epoch 99/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0294 - accuracy: 0.9894 - val_loss: 0.3299 - val_accuracy: 0.9469
#
# Epoch 00099: val_loss did not improve from 0.17014
# Epoch 100/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0308 - accuracy: 0.9876 - val_loss: 0.3360 - val_accuracy: 0.9449
#
# Epoch 00100: val_loss did not improve from 0.17014
# Epoch 101/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0305 - accuracy: 0.9891 - val_loss: 0.3596 - val_accuracy: 0.9464
#
# Epoch 00101: val_loss did not improve from 0.17014
# Epoch 102/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0325 - accuracy: 0.9884 - val_loss: 0.4613 - val_accuracy: 0.9327
#
# Epoch 00102: val_loss did not improve from 0.17014
# Epoch 103/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0350 - accuracy: 0.9866 - val_loss: 0.3354 - val_accuracy: 0.9464
#
# Epoch 00103: val_loss did not improve from 0.17014
# Epoch 104/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0338 - accuracy: 0.9877 - val_loss: 0.3552 - val_accuracy: 0.9474
#
# Epoch 00104: val_loss did not improve from 0.17014
# Epoch 105/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0336 - accuracy: 0.9878 - val_loss: 0.3569 - val_accuracy: 0.9507
#
# Epoch 00105: val_loss did not improve from 0.17014
# Epoch 106/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0306 - accuracy: 0.9885 - val_loss: 0.4037 - val_accuracy: 0.9436
#
# Epoch 00106: val_loss did not improve from 0.17014
# Epoch 107/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0355 - accuracy: 0.9861 - val_loss: 0.3370 - val_accuracy: 0.9478
#
# Epoch 00107: val_loss did not improve from 0.17014
# Epoch 108/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0272 - accuracy: 0.9892 - val_loss: 0.3954 - val_accuracy: 0.9458
#
# Epoch 00108: val_loss did not improve from 0.17014
# Epoch 109/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0333 - accuracy: 0.9874 - val_loss: 0.3521 - val_accuracy: 0.9499
#
# Epoch 00109: val_loss did not improve from 0.17014
# Epoch 110/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0304 - accuracy: 0.9889 - val_loss: 0.3747 - val_accuracy: 0.9490
#
# Epoch 00110: val_loss did not improve from 0.17014
# Epoch 111/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0280 - accuracy: 0.9894 - val_loss: 0.3735 - val_accuracy: 0.9464
#
# Epoch 00111: val_loss did not improve from 0.17014
# Epoch 112/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0338 - accuracy: 0.9873 - val_loss: 0.3720 - val_accuracy: 0.9479
#
# Epoch 00112: val_loss did not improve from 0.17014
# Epoch 113/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0306 - accuracy: 0.9888 - val_loss: 0.3516 - val_accuracy: 0.9478
#
# Epoch 00113: val_loss did not improve from 0.17014
# Epoch 114/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0317 - accuracy: 0.9884 - val_loss: 0.3422 - val_accuracy: 0.9509
#
# Epoch 00114: val_loss did not improve from 0.17014
# Epoch 115/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 0.3535 - val_accuracy: 0.9476
#
# Epoch 00115: val_loss did not improve from 0.17014
# Epoch 116/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0297 - accuracy: 0.9889 - val_loss: 0.3635 - val_accuracy: 0.9468
#
# Epoch 00116: val_loss did not improve from 0.17014
# Epoch 117/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0293 - accuracy: 0.9892 - val_loss: 0.4065 - val_accuracy: 0.9458
#
# Epoch 00117: val_loss did not improve from 0.17014
# Epoch 118/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0264 - accuracy: 0.9891 - val_loss: 0.3910 - val_accuracy: 0.9487
#
# Epoch 00118: val_loss did not improve from 0.17014
# Epoch 119/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0295 - accuracy: 0.9892 - val_loss: 0.4296 - val_accuracy: 0.9454
#
# Epoch 00119: val_loss did not improve from 0.17014
# Epoch 120/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0279 - accuracy: 0.9893 - val_loss: 0.3955 - val_accuracy: 0.9483
#
# Epoch 00120: val_loss did not improve from 0.17014
# Epoch 121/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0289 - accuracy: 0.9890 - val_loss: 0.3659 - val_accuracy: 0.9425
#
# Epoch 00121: val_loss did not improve from 0.17014
# Epoch 122/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0307 - accuracy: 0.9890 - val_loss: 0.3472 - val_accuracy: 0.9479
#
# Epoch 00122: val_loss did not improve from 0.17014
# Epoch 123/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0320 - accuracy: 0.9876 - val_loss: 0.3547 - val_accuracy: 0.9450
#
# Epoch 00123: val_loss did not improve from 0.17014
# Epoch 124/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9890 - val_loss: 0.3754 - val_accuracy: 0.9480
#
# Epoch 00124: val_loss did not improve from 0.17014
# Epoch 125/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0284 - accuracy: 0.9892 - val_loss: 0.3403 - val_accuracy: 0.9475
#
# Epoch 00125: val_loss did not improve from 0.17014
# Epoch 126/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0281 - accuracy: 0.9894 - val_loss: 0.3779 - val_accuracy: 0.9485
#
# Epoch 00126: val_loss did not improve from 0.17014
# Epoch 127/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0263 - accuracy: 0.9901 - val_loss: 0.3671 - val_accuracy: 0.9492
#
# Epoch 00127: val_loss did not improve from 0.17014
# Epoch 128/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.3670 - val_accuracy: 0.9453
#
# Epoch 00128: val_loss did not improve from 0.17014
# Epoch 129/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0292 - accuracy: 0.9895 - val_loss: 0.3733 - val_accuracy: 0.9458
#
# Epoch 00129: val_loss did not improve from 0.17014
# Epoch 130/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0253 - accuracy: 0.9899 - val_loss: 0.3853 - val_accuracy: 0.9490
#
# Epoch 00130: val_loss did not improve from 0.17014
# Epoch 131/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0268 - accuracy: 0.9896 - val_loss: 0.3690 - val_accuracy: 0.9489
#
# Epoch 00131: val_loss did not improve from 0.17014
# Epoch 132/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9898 - val_loss: 0.3659 - val_accuracy: 0.9485
#
# Epoch 00132: val_loss did not improve from 0.17014
# Epoch 133/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0311 - accuracy: 0.9895 - val_loss: 0.4036 - val_accuracy: 0.9430
#
# Epoch 00133: val_loss did not improve from 0.17014
# Epoch 134/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0252 - accuracy: 0.9895 - val_loss: 0.3739 - val_accuracy: 0.9471
#
# Epoch 00134: val_loss did not improve from 0.17014
# Epoch 135/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0313 - accuracy: 0.9879 - val_loss: 0.4454 - val_accuracy: 0.9469
#
# Epoch 00135: val_loss did not improve from 0.17014
# Epoch 136/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0286 - accuracy: 0.9894 - val_loss: 0.3786 - val_accuracy: 0.9465
#
# Epoch 00136: val_loss did not improve from 0.17014
# Epoch 137/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0265 - accuracy: 0.9894 - val_loss: 0.4445 - val_accuracy: 0.9484
#
# Epoch 00137: val_loss did not improve from 0.17014
# Epoch 138/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0283 - accuracy: 0.9898 - val_loss: 0.3530 - val_accuracy: 0.9459
#
# Epoch 00138: val_loss did not improve from 0.17014
# Epoch 139/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0274 - accuracy: 0.9897 - val_loss: 0.4273 - val_accuracy: 0.9474
#
# Epoch 00139: val_loss did not improve from 0.17014
# Epoch 140/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0269 - accuracy: 0.9898 - val_loss: 0.4428 - val_accuracy: 0.9459
#
# Epoch 00140: val_loss did not improve from 0.17014
# Epoch 141/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0236 - accuracy: 0.9912 - val_loss: 0.3908 - val_accuracy: 0.9455
#
# Epoch 00141: val_loss did not improve from 0.17014
# Epoch 142/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0277 - accuracy: 0.9897 - val_loss: 0.4139 - val_accuracy: 0.9450
#
# Epoch 00142: val_loss did not improve from 0.17014
# Epoch 143/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0251 - accuracy: 0.9904 - val_loss: 0.4244 - val_accuracy: 0.9456
#
# Epoch 00143: val_loss did not improve from 0.17014
# Epoch 144/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9904 - val_loss: 0.4238 - val_accuracy: 0.9498
#
# Epoch 00144: val_loss did not improve from 0.17014
# Epoch 145/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0278 - accuracy: 0.9897 - val_loss: 0.4247 - val_accuracy: 0.9443
#
# Epoch 00145: val_loss did not improve from 0.17014
# Epoch 146/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0240 - accuracy: 0.9906 - val_loss: 0.4143 - val_accuracy: 0.9500
#
# Epoch 00146: val_loss did not improve from 0.17014
# Epoch 147/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0300 - accuracy: 0.9893 - val_loss: 0.4000 - val_accuracy: 0.9481
#
# Epoch 00147: val_loss did not improve from 0.17014
# Epoch 148/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0251 - accuracy: 0.9897 - val_loss: 0.4329 - val_accuracy: 0.9478
#
# Epoch 00148: val_loss did not improve from 0.17014
# Epoch 149/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9909 - val_loss: 0.3631 - val_accuracy: 0.9497
#
# Epoch 00149: val_loss did not improve from 0.17014
# Epoch 150/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0267 - accuracy: 0.9904 - val_loss: 0.3805 - val_accuracy: 0.9480
#
# Epoch 00150: val_loss did not improve from 0.17014
# Epoch 151/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0233 - accuracy: 0.9907 - val_loss: 0.3958 - val_accuracy: 0.9484
#
# Epoch 00151: val_loss did not improve from 0.17014
# Epoch 152/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0226 - accuracy: 0.9914 - val_loss: 0.3972 - val_accuracy: 0.9481
#
# Epoch 00152: val_loss did not improve from 0.17014
# Epoch 153/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0266 - accuracy: 0.9902 - val_loss: 0.4107 - val_accuracy: 0.9464
#
# Epoch 00153: val_loss did not improve from 0.17014
# Epoch 154/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0300 - accuracy: 0.9897 - val_loss: 0.4023 - val_accuracy: 0.9471
#
# Epoch 00154: val_loss did not improve from 0.17014
# Epoch 155/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0290 - accuracy: 0.9893 - val_loss: 0.4013 - val_accuracy: 0.9485
#
# Epoch 00155: val_loss did not improve from 0.17014
# Epoch 156/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0281 - accuracy: 0.9896 - val_loss: 0.3649 - val_accuracy: 0.9510
#
# Epoch 00156: val_loss did not improve from 0.17014
# Epoch 157/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 0.3710 - val_accuracy: 0.9481
#
# Epoch 00157: val_loss did not improve from 0.17014
# Epoch 158/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0221 - accuracy: 0.9917 - val_loss: 0.4587 - val_accuracy: 0.9489
#
# Epoch 00158: val_loss did not improve from 0.17014
# Epoch 159/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0280 - accuracy: 0.9899 - val_loss: 0.4065 - val_accuracy: 0.9492
#
# Epoch 00159: val_loss did not improve from 0.17014
# Epoch 160/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0270 - accuracy: 0.9902 - val_loss: 0.3637 - val_accuracy: 0.9497
#
# Epoch 00160: val_loss did not improve from 0.17014
# Epoch 161/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0201 - accuracy: 0.9919 - val_loss: 0.4077 - val_accuracy: 0.9485
#
# Epoch 00161: val_loss did not improve from 0.17014
# Epoch 162/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0232 - accuracy: 0.9907 - val_loss: 0.4237 - val_accuracy: 0.9465
#
# Epoch 00162: val_loss did not improve from 0.17014
# Epoch 163/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0259 - accuracy: 0.9904 - val_loss: 0.4635 - val_accuracy: 0.9436
#
# Epoch 00163: val_loss did not improve from 0.17014
# Epoch 164/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0255 - accuracy: 0.9898 - val_loss: 0.3897 - val_accuracy: 0.9465
#
# Epoch 00164: val_loss did not improve from 0.17014
# Epoch 165/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0259 - accuracy: 0.9917 - val_loss: 0.4346 - val_accuracy: 0.9461
#
# Epoch 00165: val_loss did not improve from 0.17014
# Epoch 166/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0296 - accuracy: 0.9891 - val_loss: 0.4126 - val_accuracy: 0.9478
# Epoch 00166: val_loss did not improve from 0.17014
# Epoch 167/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.3979 - val_accuracy: 0.9444
#
# Epoch 00167: val_loss did not improve from 0.17014
# Epoch 168/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0255 - accuracy: 0.9905 - val_loss: 0.4221 - val_accuracy: 0.9466
#
# Epoch 00168: val_loss did not improve from 0.17014
# Epoch 169/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.4180 - val_accuracy: 0.9494
#
# Epoch 00169: val_loss did not improve from 0.17014
# Epoch 170/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0192 - accuracy: 0.9923 - val_loss: 0.4363 - val_accuracy: 0.9509
#
# Epoch 00170: val_loss did not improve from 0.17014
# Epoch 171/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0261 - accuracy: 0.9901 - val_loss: 0.3955 - val_accuracy: 0.9500
#
# Epoch 00171: val_loss did not improve from 0.17014
# Epoch 172/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.4298 - val_accuracy: 0.9478
#
# Epoch 00172: val_loss did not improve from 0.17014
# Epoch 173/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9915 - val_loss: 0.4585 - val_accuracy: 0.9476
#
# Epoch 00173: val_loss did not improve from 0.17014
# Epoch 174/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9909 - val_loss: 0.4095 - val_accuracy: 0.9481
#
# Epoch 00174: val_loss did not improve from 0.17014
# Epoch 175/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9905 - val_loss: 0.4382 - val_accuracy: 0.9469
#
# Epoch 00175: val_loss did not improve from 0.17014
# Epoch 176/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.4679 - val_accuracy: 0.9470
#
# Epoch 00176: val_loss did not improve from 0.17014
# Epoch 177/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.4724 - val_accuracy: 0.9483
#
# Epoch 00177: val_loss did not improve from 0.17014
# Epoch 178/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.4612 - val_accuracy: 0.9479
#
# Epoch 00178: val_loss did not improve from 0.17014
# Epoch 179/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0253 - accuracy: 0.9910 - val_loss: 0.4315 - val_accuracy: 0.9473
#
# Epoch 00179: val_loss did not improve from 0.17014
# Epoch 180/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0240 - accuracy: 0.9906 - val_loss: 0.4463 - val_accuracy: 0.9461
#
# Epoch 00180: val_loss did not improve from 0.17014
# Epoch 181/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.4350 - val_accuracy: 0.9485
#
# Epoch 00181: val_loss did not improve from 0.17014
# Epoch 182/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9920 - val_loss: 0.4260 - val_accuracy: 0.9498
#
# Epoch 00182: val_loss did not improve from 0.17014
# Epoch 183/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0214 - accuracy: 0.9923 - val_loss: 0.4377 - val_accuracy: 0.9500
#
# Epoch 00183: val_loss did not improve from 0.17014
# Epoch 184/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.4222 - val_accuracy: 0.9483
#
# Epoch 00184: val_loss did not improve from 0.17014
# Epoch 185/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0232 - accuracy: 0.9910 - val_loss: 0.4305 - val_accuracy: 0.9475
#
# Epoch 00185: val_loss did not improve from 0.17014
# Epoch 186/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0266 - accuracy: 0.9903 - val_loss: 0.4184 - val_accuracy: 0.9497
#
# Epoch 00186: val_loss did not improve from 0.17014
# Epoch 187/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9928 - val_loss: 0.4428 - val_accuracy: 0.9461
#
# Epoch 00187: val_loss did not improve from 0.17014
# Epoch 188/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9914 - val_loss: 0.4256 - val_accuracy: 0.9479
#
# Epoch 00188: val_loss did not improve from 0.17014
# Epoch 189/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0296 - accuracy: 0.9902 - val_loss: 0.3903 - val_accuracy: 0.9514
#
# Epoch 00189: val_loss did not improve from 0.17014
# Epoch 190/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.4263 - val_accuracy: 0.9485
#
# Epoch 00190: val_loss did not improve from 0.17014
# Epoch 191/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 0.4193 - val_accuracy: 0.9492
#
# Epoch 00191: val_loss did not improve from 0.17014
# Epoch 192/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.4703 - val_accuracy: 0.9489
#
# Epoch 00192: val_loss did not improve from 0.17014
# Epoch 193/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.4575 - val_accuracy: 0.9481
#
# Epoch 00193: val_loss did not improve from 0.17014
# Epoch 194/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.4581 - val_accuracy: 0.9463
#
# Epoch 00194: val_loss did not improve from 0.17014
# Epoch 195/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.4246 - val_accuracy: 0.9478
#
# Epoch 00195: val_loss did not improve from 0.17014
# Epoch 196/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9912 - val_loss: 0.4839 - val_accuracy: 0.9480
#
# Epoch 00196: val_loss did not improve from 0.17014
# Epoch 197/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.4709 - val_accuracy: 0.9509
#
# Epoch 00197: val_loss did not improve from 0.17014
# Epoch 198/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0316 - accuracy: 0.9892 - val_loss: 0.4041 - val_accuracy: 0.9455
#
# Epoch 00198: val_loss did not improve from 0.17014
# Epoch 199/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0223 - accuracy: 0.9919 - val_loss: 0.4149 - val_accuracy: 0.9495
#
# Epoch 00199: val_loss did not improve from 0.17014
# Epoch 200/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.3919 - val_accuracy: 0.9471
#
# Epoch 00200: val_loss did not improve from 0.17014

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 249/249 [==============================] - 1s 3ms/step - loss: 0.1701 - accuracy: 0.9464
# Overall CNN Accuracy: 0.9463904500007629
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9464          |
# | Validation loss               | 0.1701          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([10,  0, 10, ...,  0, 10,  0], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([10,  0, 10, ...,  0, 10,  0], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 7965
# 7965

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Benign' 'Benign' 'Ransomware' ... 'Benign' 'Benign' 'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 14012

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +------------------------------------------------+
# |               Performance of CNN               |
# +----------------------------------+-------------+
# | Metric                           | Performance |
# +----------------------------------+-------------+
# | True Positive Rate               | 0.9808      |
# | Accuracy                         | 0.9832      |
# | F1 Score                         | 0.9839      |
# | Matthews Correlation Coefficient | 0.9663      |
# +----------------------------------+-------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with LeakyReLU activation.
#
# Includes weights for all classes to overcome unbalanced data

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 200

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cnn"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cnn/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 11 matches(es) found
# --------------
# New folder name: cnn-local-v012
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# **Automatic reverse weight calculation.**
#
# The weight is determined by how well respresented the class is in the dataset; the less represented, the higher the weigth. This way of calculating weights aims to overcome the unbalanced data. The 'Adam' optimizer is not affected by the weights like other optimizer would be

# %%
distr = (sum(labels)/labels.shape[0])
weights = 1-(distr)/(wf/distr)

# %%
class_weight = {0: weights[0], 1: weights[1], 2: weights[2], 3: weights[3], 4: weights[4], 5: weights[5],
               6: weights[6], 7: weights[7], 8: weights[8], 9: weights[9], 10: weights[10]}

# %%
print(class_weight)
# Out:
# {0: 0.98318845, 1: 0.9792672, 2: 0.9980167, 3: 0.99800247, 4: 0.99873376, 5: 0.9940748, 6: 0.99741197, 7: 0.9938011, 8: 0.99880844, 9: 0.9992029, 10: 0.44285703}

# %%
(max(weights)-min(weights))/max(weights)
# Out:
# 0.5567897

# %%
b_weight = weights[10]/sum(weights)*100
print("The weight for the benign sample makes up {b_weight}% of the total weights".format(b_weight = b_weight))
# Out:
# The weight for the benign sample makes up 4.265062753598218% of the total weights

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9,
#  'benign': 10}

# %%
imgs.shape
# Out:
# (26548, 64, 64, 1)

# %%
labels.shape
# Out:
# (26548, 11)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (7965, 11)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 18583 | Shape of training data (18583, 64, 64, 1)
# Size of training data: 7965  | Shape of training data (7965, 64, 64, 1)
# Shape of training labels (18583, 11)
# Shape of training labels (7965, 11)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = 11
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='LeakyReLU'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='LeakyReLU'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='LeakyReLU'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2940)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               376448
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_5 (Dense)              (None, 11)                561
# =================================================================
# Total params: 387,824
# Trainable params: 387,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint],
    class_weight=class_weight) # The actual computation of the CNN
# Out:
# Epoch 1/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.4605 - accuracy: 0.8384 - val_loss: 0.3564 - val_accuracy: 0.8873
#
# Epoch 00001: val_loss improved from inf to 0.35643, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 2/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.2686 - accuracy: 0.9017 - val_loss: 0.2558 - val_accuracy: 0.9189
#
# Epoch 00002: val_loss improved from 0.35643 to 0.25580, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 3/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.2197 - accuracy: 0.9187 - val_loss: 0.2567 - val_accuracy: 0.9155
#
# Epoch 00003: val_loss did not improve from 0.25580
# Epoch 4/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.1934 - accuracy: 0.9286 - val_loss: 0.1986 - val_accuracy: 0.9370
#
# Epoch 00004: val_loss improved from 0.25580 to 0.19864, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 5/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1704 - accuracy: 0.9363 - val_loss: 0.2078 - val_accuracy: 0.9377
#
# Epoch 00005: val_loss did not improve from 0.19864
# Epoch 6/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1553 - accuracy: 0.9410 - val_loss: 0.1824 - val_accuracy: 0.9424
#
# Epoch 00006: val_loss improved from 0.19864 to 0.18244, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 7/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1392 - accuracy: 0.9444 - val_loss: 0.1932 - val_accuracy: 0.9434
#
# Epoch 00007: val_loss did not improve from 0.18244
# Epoch 8/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1318 - accuracy: 0.9482 - val_loss: 0.1701 - val_accuracy: 0.9464
#
# Epoch 00008: val_loss improved from 0.18244 to 0.17014, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v012\model.h5
# Epoch 9/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.1183 - accuracy: 0.9526 - val_loss: 0.1857 - val_accuracy: 0.9466
#
# Epoch 00009: val_loss did not improve from 0.17014
# Epoch 10/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1150 - accuracy: 0.9538 - val_loss: 0.1723 - val_accuracy: 0.9478
#
# Epoch 00010: val_loss did not improve from 0.17014
# Epoch 11/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.1038 - accuracy: 0.9590 - val_loss: 0.1740 - val_accuracy: 0.9484
#
# Epoch 00011: val_loss did not improve from 0.17014
# Epoch 12/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0987 - accuracy: 0.9599 - val_loss: 0.1850 - val_accuracy: 0.9485
#
# Epoch 00012: val_loss did not improve from 0.17014
# Epoch 13/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0916 - accuracy: 0.9633 - val_loss: 0.2006 - val_accuracy: 0.9470
#
# Epoch 00013: val_loss did not improve from 0.17014
# Epoch 14/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0974 - accuracy: 0.9621 - val_loss: 0.2190 - val_accuracy: 0.9400
#
# Epoch 00014: val_loss did not improve from 0.17014
# Epoch 15/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0837 - accuracy: 0.9661 - val_loss: 0.1929 - val_accuracy: 0.9461
#
# Epoch 00015: val_loss did not improve from 0.17014
# Epoch 16/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0795 - accuracy: 0.9671 - val_loss: 0.2007 - val_accuracy: 0.9507
#
# Epoch 00016: val_loss did not improve from 0.17014
# Epoch 17/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0823 - accuracy: 0.9680 - val_loss: 0.2049 - val_accuracy: 0.9474
#
# Epoch 00017: val_loss did not improve from 0.17014
# Epoch 18/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0784 - accuracy: 0.9681 - val_loss: 0.1963 - val_accuracy: 0.9485
#
# Epoch 00018: val_loss did not improve from 0.17014
# Epoch 19/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0769 - accuracy: 0.9688 - val_loss: 0.2006 - val_accuracy: 0.9460
#
# Epoch 00019: val_loss did not improve from 0.17014
# Epoch 20/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0732 - accuracy: 0.9703 - val_loss: 0.2080 - val_accuracy: 0.9503
#
# Epoch 00020: val_loss did not improve from 0.17014
# Epoch 21/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0723 - accuracy: 0.9715 - val_loss: 0.2141 - val_accuracy: 0.9500
#
# Epoch 00021: val_loss did not improve from 0.17014
# Epoch 22/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0741 - accuracy: 0.9708 - val_loss: 0.2189 - val_accuracy: 0.9494
#
# Epoch 00022: val_loss did not improve from 0.17014
# Epoch 23/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0732 - accuracy: 0.9706 - val_loss: 0.2007 - val_accuracy: 0.9484
#
# Epoch 00023: val_loss did not improve from 0.17014
# Epoch 24/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0631 - accuracy: 0.9750 - val_loss: 0.2073 - val_accuracy: 0.9490
#
# Epoch 00024: val_loss did not improve from 0.17014
# Epoch 25/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0636 - accuracy: 0.9759 - val_loss: 0.2515 - val_accuracy: 0.9465
#
# Epoch 00025: val_loss did not improve from 0.17014
# Epoch 26/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0614 - accuracy: 0.9756 - val_loss: 0.2351 - val_accuracy: 0.9490
#
# Epoch 00026: val_loss did not improve from 0.17014
# Epoch 27/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0633 - accuracy: 0.9748 - val_loss: 0.2291 - val_accuracy: 0.9480
#
# Epoch 00027: val_loss did not improve from 0.17014
# Epoch 28/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0663 - accuracy: 0.9750 - val_loss: 0.2242 - val_accuracy: 0.9461
#
# Epoch 00028: val_loss did not improve from 0.17014
# Epoch 29/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0593 - accuracy: 0.9763 - val_loss: 0.2394 - val_accuracy: 0.9509
#
# Epoch 00029: val_loss did not improve from 0.17014
# Epoch 30/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0596 - accuracy: 0.9762 - val_loss: 0.2201 - val_accuracy: 0.9495
#
# Epoch 00030: val_loss did not improve from 0.17014
# Epoch 31/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0608 - accuracy: 0.9770 - val_loss: 0.2719 - val_accuracy: 0.9444
#
# Epoch 00031: val_loss did not improve from 0.17014
# Epoch 32/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0580 - accuracy: 0.9778 - val_loss: 0.2421 - val_accuracy: 0.9500
#
# Epoch 00032: val_loss did not improve from 0.17014
# Epoch 33/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0565 - accuracy: 0.9788 - val_loss: 0.2459 - val_accuracy: 0.9493
#
# Epoch 00033: val_loss did not improve from 0.17014
# Epoch 34/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0546 - accuracy: 0.9784 - val_loss: 0.2516 - val_accuracy: 0.9481
#
# Epoch 00034: val_loss did not improve from 0.17014
# Epoch 35/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0576 - accuracy: 0.9777 - val_loss: 0.2714 - val_accuracy: 0.9483
#
# Epoch 00035: val_loss did not improve from 0.17014
# Epoch 36/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0568 - accuracy: 0.9779 - val_loss: 0.2519 - val_accuracy: 0.9507
#
# Epoch 00036: val_loss did not improve from 0.17014
# Epoch 37/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0565 - accuracy: 0.9778 - val_loss: 0.2487 - val_accuracy: 0.9479
#
# Epoch 00037: val_loss did not improve from 0.17014
# Epoch 38/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0553 - accuracy: 0.9780 - val_loss: 0.2423 - val_accuracy: 0.9489
#
# Epoch 00038: val_loss did not improve from 0.17014
# Epoch 39/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0527 - accuracy: 0.9793 - val_loss: 0.2557 - val_accuracy: 0.9500
#
# Epoch 00039: val_loss did not improve from 0.17014
# Epoch 40/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0554 - accuracy: 0.9789 - val_loss: 0.2487 - val_accuracy: 0.9493
#
# Epoch 00040: val_loss did not improve from 0.17014
# Epoch 41/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0531 - accuracy: 0.9790 - val_loss: 0.2506 - val_accuracy: 0.9510
#
# Epoch 00041: val_loss did not improve from 0.17014
# Epoch 42/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0514 - accuracy: 0.9791 - val_loss: 0.2457 - val_accuracy: 0.9480
#
# Epoch 00042: val_loss did not improve from 0.17014
# Epoch 43/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0515 - accuracy: 0.9795 - val_loss: 0.2814 - val_accuracy: 0.9481
#
# Epoch 00043: val_loss did not improve from 0.17014
# Epoch 44/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0510 - accuracy: 0.9804 - val_loss: 0.2580 - val_accuracy: 0.9490
#
# Epoch 00044: val_loss did not improve from 0.17014
# Epoch 45/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0504 - accuracy: 0.9804 - val_loss: 0.2813 - val_accuracy: 0.9480
#
# Epoch 00045: val_loss did not improve from 0.17014
# Epoch 46/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0489 - accuracy: 0.9805 - val_loss: 0.2629 - val_accuracy: 0.9487
#
# Epoch 00046: val_loss did not improve from 0.17014
# Epoch 47/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0497 - accuracy: 0.9814 - val_loss: 0.2742 - val_accuracy: 0.9499
#
# Epoch 00047: val_loss did not improve from 0.17014
# Epoch 48/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0454 - accuracy: 0.9829 - val_loss: 0.2812 - val_accuracy: 0.9451
#
# Epoch 00048: val_loss did not improve from 0.17014
# Epoch 49/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0507 - accuracy: 0.9805 - val_loss: 0.2960 - val_accuracy: 0.9490
#
# Epoch 00049: val_loss did not improve from 0.17014
# Epoch 50/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0478 - accuracy: 0.9818 - val_loss: 0.2803 - val_accuracy: 0.9497
#
# Epoch 00050: val_loss did not improve from 0.17014
# Epoch 51/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0440 - accuracy: 0.9838 - val_loss: 0.2930 - val_accuracy: 0.9509
#
# Epoch 00051: val_loss did not improve from 0.17014
# Epoch 52/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0517 - accuracy: 0.9806 - val_loss: 0.2562 - val_accuracy: 0.9489
#
# Epoch 00052: val_loss did not improve from 0.17014
# Epoch 53/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0487 - accuracy: 0.9818 - val_loss: 0.2781 - val_accuracy: 0.9455
#
# Epoch 00053: val_loss did not improve from 0.17014
# Epoch 54/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0428 - accuracy: 0.9832 - val_loss: 0.2879 - val_accuracy: 0.9478
#
# Epoch 00054: val_loss did not improve from 0.17014
# Epoch 55/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0469 - accuracy: 0.9815 - val_loss: 0.2876 - val_accuracy: 0.9474
#
# Epoch 00055: val_loss did not improve from 0.17014
# Epoch 56/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0473 - accuracy: 0.9815 - val_loss: 0.2940 - val_accuracy: 0.9459
#
# Epoch 00056: val_loss did not improve from 0.17014
# Epoch 57/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0409 - accuracy: 0.9834 - val_loss: 0.3123 - val_accuracy: 0.9478
#
# Epoch 00057: val_loss did not improve from 0.17014
# Epoch 58/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0434 - accuracy: 0.9832 - val_loss: 0.3043 - val_accuracy: 0.9479
#
# Epoch 00058: val_loss did not improve from 0.17014
# Epoch 59/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0449 - accuracy: 0.9829 - val_loss: 0.3157 - val_accuracy: 0.9465
#
# Epoch 00059: val_loss did not improve from 0.17014
# Epoch 60/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0399 - accuracy: 0.9847 - val_loss: 0.2922 - val_accuracy: 0.9471
#
# Epoch 00060: val_loss did not improve from 0.17014
# Epoch 61/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0421 - accuracy: 0.9830 - val_loss: 0.3044 - val_accuracy: 0.9488
#
# Epoch 00061: val_loss did not improve from 0.17014
# Epoch 62/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0415 - accuracy: 0.9843 - val_loss: 0.3164 - val_accuracy: 0.9484
#
# Epoch 00062: val_loss did not improve from 0.17014
# Epoch 63/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0462 - accuracy: 0.9820 - val_loss: 0.2935 - val_accuracy: 0.9484
#
# Epoch 00063: val_loss did not improve from 0.17014
# Epoch 64/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0433 - accuracy: 0.9838 - val_loss: 0.3132 - val_accuracy: 0.9479
#
# Epoch 00064: val_loss did not improve from 0.17014
# Epoch 65/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0424 - accuracy: 0.9836 - val_loss: 0.3124 - val_accuracy: 0.9469
#
# Epoch 00065: val_loss did not improve from 0.17014
# Epoch 66/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0473 - accuracy: 0.9808 - val_loss: 0.3001 - val_accuracy: 0.9480
#
# Epoch 00066: val_loss did not improve from 0.17014
# Epoch 67/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0442 - accuracy: 0.9831 - val_loss: 0.3009 - val_accuracy: 0.9469
#
# Epoch 00067: val_loss did not improve from 0.17014
# Epoch 68/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0367 - accuracy: 0.9859 - val_loss: 0.3015 - val_accuracy: 0.9471
#
# Epoch 00068: val_loss did not improve from 0.17014
# Epoch 69/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0351 - accuracy: 0.9857 - val_loss: 0.3662 - val_accuracy: 0.9464
#
# Epoch 00069: val_loss did not improve from 0.17014
# Epoch 70/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0400 - accuracy: 0.9853 - val_loss: 0.3300 - val_accuracy: 0.9488
#
# Epoch 00070: val_loss did not improve from 0.17014
# Epoch 71/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0404 - accuracy: 0.9846 - val_loss: 0.3294 - val_accuracy: 0.9487
#
# Epoch 00071: val_loss did not improve from 0.17014
# Epoch 72/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0384 - accuracy: 0.9857 - val_loss: 0.3438 - val_accuracy: 0.9456
#
# Epoch 00072: val_loss did not improve from 0.17014
# Epoch 73/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0400 - accuracy: 0.9850 - val_loss: 0.3412 - val_accuracy: 0.9473
#
# Epoch 00073: val_loss did not improve from 0.17014
# Epoch 74/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0389 - accuracy: 0.9843 - val_loss: 0.3079 - val_accuracy: 0.9481
#
# Epoch 00074: val_loss did not improve from 0.17014
# Epoch 75/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0388 - accuracy: 0.9842 - val_loss: 0.2988 - val_accuracy: 0.9484
#
# Epoch 00075: val_loss did not improve from 0.17014
# Epoch 76/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0368 - accuracy: 0.9860 - val_loss: 0.3248 - val_accuracy: 0.9483
#
# Epoch 00076: val_loss did not improve from 0.17014
# Epoch 77/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0400 - accuracy: 0.9851 - val_loss: 0.2966 - val_accuracy: 0.9464
#
# Epoch 00077: val_loss did not improve from 0.17014
# Epoch 78/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0422 - accuracy: 0.9839 - val_loss: 0.2882 - val_accuracy: 0.9469
#
# Epoch 00078: val_loss did not improve from 0.17014
# Epoch 79/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0347 - accuracy: 0.9863 - val_loss: 0.3126 - val_accuracy: 0.9483
#
# Epoch 00079: val_loss did not improve from 0.17014
# Epoch 80/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0362 - accuracy: 0.9856 - val_loss: 0.3395 - val_accuracy: 0.9458
#
# Epoch 00080: val_loss did not improve from 0.17014
# Epoch 81/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0290 - accuracy: 0.9890 - val_loss: 0.3614 - val_accuracy: 0.9464
#
# Epoch 00081: val_loss did not improve from 0.17014
# Epoch 82/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0355 - accuracy: 0.9864 - val_loss: 0.3638 - val_accuracy: 0.9459
#
# Epoch 00082: val_loss did not improve from 0.17014
# Epoch 83/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0412 - accuracy: 0.9848 - val_loss: 0.3136 - val_accuracy: 0.9474
#
# Epoch 00083: val_loss did not improve from 0.17014
# Epoch 84/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0361 - accuracy: 0.9862 - val_loss: 0.3610 - val_accuracy: 0.9464
#
# Epoch 00084: val_loss did not improve from 0.17014
# Epoch 85/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0386 - accuracy: 0.9848 - val_loss: 0.3755 - val_accuracy: 0.9431
#
# Epoch 00085: val_loss did not improve from 0.17014
# Epoch 86/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0353 - accuracy: 0.9867 - val_loss: 0.3219 - val_accuracy: 0.9463
#
# Epoch 00086: val_loss did not improve from 0.17014
# Epoch 87/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0322 - accuracy: 0.9883 - val_loss: 0.3452 - val_accuracy: 0.9513
#
# Epoch 00087: val_loss did not improve from 0.17014
# Epoch 88/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0362 - accuracy: 0.9864 - val_loss: 0.3314 - val_accuracy: 0.9481
#
# Epoch 00088: val_loss did not improve from 0.17014
# Epoch 89/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0336 - accuracy: 0.9863 - val_loss: 0.3290 - val_accuracy: 0.9433
#
# Epoch 00089: val_loss did not improve from 0.17014
# Epoch 90/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0320 - accuracy: 0.9879 - val_loss: 0.3464 - val_accuracy: 0.9490
#
# Epoch 00090: val_loss did not improve from 0.17014
# Epoch 91/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0373 - accuracy: 0.9860 - val_loss: 0.3054 - val_accuracy: 0.9485
#
# Epoch 00091: val_loss did not improve from 0.17014
# Epoch 92/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0380 - accuracy: 0.9858 - val_loss: 0.3067 - val_accuracy: 0.9518
#
# Epoch 00092: val_loss did not improve from 0.17014
# Epoch 93/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0313 - accuracy: 0.9890 - val_loss: 0.3253 - val_accuracy: 0.9494
#
# Epoch 00093: val_loss did not improve from 0.17014
# Epoch 94/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0330 - accuracy: 0.9878 - val_loss: 0.3273 - val_accuracy: 0.9488
#
# Epoch 00094: val_loss did not improve from 0.17014
# Epoch 95/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0337 - accuracy: 0.9876 - val_loss: 0.3114 - val_accuracy: 0.9505
#
# Epoch 00095: val_loss did not improve from 0.17014
# Epoch 96/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0343 - accuracy: 0.9875 - val_loss: 0.3486 - val_accuracy: 0.9448
#
# Epoch 00096: val_loss did not improve from 0.17014
# Epoch 97/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0358 - accuracy: 0.9868 - val_loss: 0.3192 - val_accuracy: 0.9504
#
# Epoch 00097: val_loss did not improve from 0.17014
# Epoch 98/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0354 - accuracy: 0.9864 - val_loss: 0.3332 - val_accuracy: 0.9463
#
# Epoch 00098: val_loss did not improve from 0.17014
# Epoch 99/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0294 - accuracy: 0.9894 - val_loss: 0.3299 - val_accuracy: 0.9469
#
# Epoch 00099: val_loss did not improve from 0.17014
# Epoch 100/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0308 - accuracy: 0.9876 - val_loss: 0.3360 - val_accuracy: 0.9449
#
# Epoch 00100: val_loss did not improve from 0.17014
# Epoch 101/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0305 - accuracy: 0.9891 - val_loss: 0.3596 - val_accuracy: 0.9464
#
# Epoch 00101: val_loss did not improve from 0.17014
# Epoch 102/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0325 - accuracy: 0.9884 - val_loss: 0.4613 - val_accuracy: 0.9327
#
# Epoch 00102: val_loss did not improve from 0.17014
# Epoch 103/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0350 - accuracy: 0.9866 - val_loss: 0.3354 - val_accuracy: 0.9464
#
# Epoch 00103: val_loss did not improve from 0.17014
# Epoch 104/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0338 - accuracy: 0.9877 - val_loss: 0.3552 - val_accuracy: 0.9474
#
# Epoch 00104: val_loss did not improve from 0.17014
# Epoch 105/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0336 - accuracy: 0.9878 - val_loss: 0.3569 - val_accuracy: 0.9507
#
# Epoch 00105: val_loss did not improve from 0.17014
# Epoch 106/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0306 - accuracy: 0.9885 - val_loss: 0.4037 - val_accuracy: 0.9436
#
# Epoch 00106: val_loss did not improve from 0.17014
# Epoch 107/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0355 - accuracy: 0.9861 - val_loss: 0.3370 - val_accuracy: 0.9478
#
# Epoch 00107: val_loss did not improve from 0.17014
# Epoch 108/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0272 - accuracy: 0.9892 - val_loss: 0.3954 - val_accuracy: 0.9458
#
# Epoch 00108: val_loss did not improve from 0.17014
# Epoch 109/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0333 - accuracy: 0.9874 - val_loss: 0.3521 - val_accuracy: 0.9499
#
# Epoch 00109: val_loss did not improve from 0.17014
# Epoch 110/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0304 - accuracy: 0.9889 - val_loss: 0.3747 - val_accuracy: 0.9490
#
# Epoch 00110: val_loss did not improve from 0.17014
# Epoch 111/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0280 - accuracy: 0.9894 - val_loss: 0.3735 - val_accuracy: 0.9464
#
# Epoch 00111: val_loss did not improve from 0.17014
# Epoch 112/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0338 - accuracy: 0.9873 - val_loss: 0.3720 - val_accuracy: 0.9479
#
# Epoch 00112: val_loss did not improve from 0.17014
# Epoch 113/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0306 - accuracy: 0.9888 - val_loss: 0.3516 - val_accuracy: 0.9478
#
# Epoch 00113: val_loss did not improve from 0.17014
# Epoch 114/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0317 - accuracy: 0.9884 - val_loss: 0.3422 - val_accuracy: 0.9509
#
# Epoch 00114: val_loss did not improve from 0.17014
# Epoch 115/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 0.3535 - val_accuracy: 0.9476
#
# Epoch 00115: val_loss did not improve from 0.17014
# Epoch 116/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0297 - accuracy: 0.9889 - val_loss: 0.3635 - val_accuracy: 0.9468
#
# Epoch 00116: val_loss did not improve from 0.17014
# Epoch 117/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0293 - accuracy: 0.9892 - val_loss: 0.4065 - val_accuracy: 0.9458
#
# Epoch 00117: val_loss did not improve from 0.17014
# Epoch 118/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0264 - accuracy: 0.9891 - val_loss: 0.3910 - val_accuracy: 0.9487
#
# Epoch 00118: val_loss did not improve from 0.17014
# Epoch 119/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0295 - accuracy: 0.9892 - val_loss: 0.4296 - val_accuracy: 0.9454
#
# Epoch 00119: val_loss did not improve from 0.17014
# Epoch 120/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0279 - accuracy: 0.9893 - val_loss: 0.3955 - val_accuracy: 0.9483
#
# Epoch 00120: val_loss did not improve from 0.17014
# Epoch 121/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0289 - accuracy: 0.9890 - val_loss: 0.3659 - val_accuracy: 0.9425
#
# Epoch 00121: val_loss did not improve from 0.17014
# Epoch 122/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0307 - accuracy: 0.9890 - val_loss: 0.3472 - val_accuracy: 0.9479
#
# Epoch 00122: val_loss did not improve from 0.17014
# Epoch 123/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0320 - accuracy: 0.9876 - val_loss: 0.3547 - val_accuracy: 0.9450
#
# Epoch 00123: val_loss did not improve from 0.17014
# Epoch 124/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9890 - val_loss: 0.3754 - val_accuracy: 0.9480
#
# Epoch 00124: val_loss did not improve from 0.17014
# Epoch 125/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0284 - accuracy: 0.9892 - val_loss: 0.3403 - val_accuracy: 0.9475
#
# Epoch 00125: val_loss did not improve from 0.17014
# Epoch 126/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0281 - accuracy: 0.9894 - val_loss: 0.3779 - val_accuracy: 0.9485
#
# Epoch 00126: val_loss did not improve from 0.17014
# Epoch 127/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0263 - accuracy: 0.9901 - val_loss: 0.3671 - val_accuracy: 0.9492
#
# Epoch 00127: val_loss did not improve from 0.17014
# Epoch 128/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.3670 - val_accuracy: 0.9453
#
# Epoch 00128: val_loss did not improve from 0.17014
# Epoch 129/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0292 - accuracy: 0.9895 - val_loss: 0.3733 - val_accuracy: 0.9458
#
# Epoch 00129: val_loss did not improve from 0.17014
# Epoch 130/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0253 - accuracy: 0.9899 - val_loss: 0.3853 - val_accuracy: 0.9490
#
# Epoch 00130: val_loss did not improve from 0.17014
# Epoch 131/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0268 - accuracy: 0.9896 - val_loss: 0.3690 - val_accuracy: 0.9489
#
# Epoch 00131: val_loss did not improve from 0.17014
# Epoch 132/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9898 - val_loss: 0.3659 - val_accuracy: 0.9485
#
# Epoch 00132: val_loss did not improve from 0.17014
# Epoch 133/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0311 - accuracy: 0.9895 - val_loss: 0.4036 - val_accuracy: 0.9430
#
# Epoch 00133: val_loss did not improve from 0.17014
# Epoch 134/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0252 - accuracy: 0.9895 - val_loss: 0.3739 - val_accuracy: 0.9471
#
# Epoch 00134: val_loss did not improve from 0.17014
# Epoch 135/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0313 - accuracy: 0.9879 - val_loss: 0.4454 - val_accuracy: 0.9469
#
# Epoch 00135: val_loss did not improve from 0.17014
# Epoch 136/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0286 - accuracy: 0.9894 - val_loss: 0.3786 - val_accuracy: 0.9465
#
# Epoch 00136: val_loss did not improve from 0.17014
# Epoch 137/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0265 - accuracy: 0.9894 - val_loss: 0.4445 - val_accuracy: 0.9484
#
# Epoch 00137: val_loss did not improve from 0.17014
# Epoch 138/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0283 - accuracy: 0.9898 - val_loss: 0.3530 - val_accuracy: 0.9459
#
# Epoch 00138: val_loss did not improve from 0.17014
# Epoch 139/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0274 - accuracy: 0.9897 - val_loss: 0.4273 - val_accuracy: 0.9474
#
# Epoch 00139: val_loss did not improve from 0.17014
# Epoch 140/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0269 - accuracy: 0.9898 - val_loss: 0.4428 - val_accuracy: 0.9459
#
# Epoch 00140: val_loss did not improve from 0.17014
# Epoch 141/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0236 - accuracy: 0.9912 - val_loss: 0.3908 - val_accuracy: 0.9455
#
# Epoch 00141: val_loss did not improve from 0.17014
# Epoch 142/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0277 - accuracy: 0.9897 - val_loss: 0.4139 - val_accuracy: 0.9450
#
# Epoch 00142: val_loss did not improve from 0.17014
# Epoch 143/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0251 - accuracy: 0.9904 - val_loss: 0.4244 - val_accuracy: 0.9456
#
# Epoch 00143: val_loss did not improve from 0.17014
# Epoch 144/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9904 - val_loss: 0.4238 - val_accuracy: 0.9498
#
# Epoch 00144: val_loss did not improve from 0.17014
# Epoch 145/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0278 - accuracy: 0.9897 - val_loss: 0.4247 - val_accuracy: 0.9443
#
# Epoch 00145: val_loss did not improve from 0.17014
# Epoch 146/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0240 - accuracy: 0.9906 - val_loss: 0.4143 - val_accuracy: 0.9500
#
# Epoch 00146: val_loss did not improve from 0.17014
# Epoch 147/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0300 - accuracy: 0.9893 - val_loss: 0.4000 - val_accuracy: 0.9481
#
# Epoch 00147: val_loss did not improve from 0.17014
# Epoch 148/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0251 - accuracy: 0.9897 - val_loss: 0.4329 - val_accuracy: 0.9478
#
# Epoch 00148: val_loss did not improve from 0.17014
# Epoch 149/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9909 - val_loss: 0.3631 - val_accuracy: 0.9497
#
# Epoch 00149: val_loss did not improve from 0.17014
# Epoch 150/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0267 - accuracy: 0.9904 - val_loss: 0.3805 - val_accuracy: 0.9480
#
# Epoch 00150: val_loss did not improve from 0.17014
# Epoch 151/200
# 581/581 [==============================] - 4s 7ms/step - loss: 0.0233 - accuracy: 0.9907 - val_loss: 0.3958 - val_accuracy: 0.9484
#
# Epoch 00151: val_loss did not improve from 0.17014
# Epoch 152/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0226 - accuracy: 0.9914 - val_loss: 0.3972 - val_accuracy: 0.9481
#
# Epoch 00152: val_loss did not improve from 0.17014
# Epoch 153/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0266 - accuracy: 0.9902 - val_loss: 0.4107 - val_accuracy: 0.9464
#
# Epoch 00153: val_loss did not improve from 0.17014
# Epoch 154/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0300 - accuracy: 0.9897 - val_loss: 0.4023 - val_accuracy: 0.9471
#
# Epoch 00154: val_loss did not improve from 0.17014
# Epoch 155/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0290 - accuracy: 0.9893 - val_loss: 0.4013 - val_accuracy: 0.9485
#
# Epoch 00155: val_loss did not improve from 0.17014
# Epoch 156/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0281 - accuracy: 0.9896 - val_loss: 0.3649 - val_accuracy: 0.9510
#
# Epoch 00156: val_loss did not improve from 0.17014
# Epoch 157/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 0.3710 - val_accuracy: 0.9481
#
# Epoch 00157: val_loss did not improve from 0.17014
# Epoch 158/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0221 - accuracy: 0.9917 - val_loss: 0.4587 - val_accuracy: 0.9489
#
# Epoch 00158: val_loss did not improve from 0.17014
# Epoch 159/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0280 - accuracy: 0.9899 - val_loss: 0.4065 - val_accuracy: 0.9492
#
# Epoch 00159: val_loss did not improve from 0.17014
# Epoch 160/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0270 - accuracy: 0.9902 - val_loss: 0.3637 - val_accuracy: 0.9497
#
# Epoch 00160: val_loss did not improve from 0.17014
# Epoch 161/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0201 - accuracy: 0.9919 - val_loss: 0.4077 - val_accuracy: 0.9485
#
# Epoch 00161: val_loss did not improve from 0.17014
# Epoch 162/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0232 - accuracy: 0.9907 - val_loss: 0.4237 - val_accuracy: 0.9465
#
# Epoch 00162: val_loss did not improve from 0.17014
# Epoch 163/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0259 - accuracy: 0.9904 - val_loss: 0.4635 - val_accuracy: 0.9436
#
# Epoch 00163: val_loss did not improve from 0.17014
# Epoch 164/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0255 - accuracy: 0.9898 - val_loss: 0.3897 - val_accuracy: 0.9465
#
# Epoch 00164: val_loss did not improve from 0.17014
# Epoch 165/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0259 - accuracy: 0.9917 - val_loss: 0.4346 - val_accuracy: 0.9461
#
# Epoch 00165: val_loss did not improve from 0.17014
# Epoch 166/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0296 - accuracy: 0.9891 - val_loss: 0.4126 - val_accuracy: 0.9478
# Epoch 00166: val_loss did not improve from 0.17014
# Epoch 167/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.3979 - val_accuracy: 0.9444
#
# Epoch 00167: val_loss did not improve from 0.17014
# Epoch 168/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0255 - accuracy: 0.9905 - val_loss: 0.4221 - val_accuracy: 0.9466
#
# Epoch 00168: val_loss did not improve from 0.17014
# Epoch 169/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.4180 - val_accuracy: 0.9494
#
# Epoch 00169: val_loss did not improve from 0.17014
# Epoch 170/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0192 - accuracy: 0.9923 - val_loss: 0.4363 - val_accuracy: 0.9509
#
# Epoch 00170: val_loss did not improve from 0.17014
# Epoch 171/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0261 - accuracy: 0.9901 - val_loss: 0.3955 - val_accuracy: 0.9500
#
# Epoch 00171: val_loss did not improve from 0.17014
# Epoch 172/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.4298 - val_accuracy: 0.9478
#
# Epoch 00172: val_loss did not improve from 0.17014
# Epoch 173/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9915 - val_loss: 0.4585 - val_accuracy: 0.9476
#
# Epoch 00173: val_loss did not improve from 0.17014
# Epoch 174/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9909 - val_loss: 0.4095 - val_accuracy: 0.9481
#
# Epoch 00174: val_loss did not improve from 0.17014
# Epoch 175/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9905 - val_loss: 0.4382 - val_accuracy: 0.9469
#
# Epoch 00175: val_loss did not improve from 0.17014
# Epoch 176/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.4679 - val_accuracy: 0.9470
#
# Epoch 00176: val_loss did not improve from 0.17014
# Epoch 177/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.4724 - val_accuracy: 0.9483
#
# Epoch 00177: val_loss did not improve from 0.17014
# Epoch 178/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.4612 - val_accuracy: 0.9479
#
# Epoch 00178: val_loss did not improve from 0.17014
# Epoch 179/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0253 - accuracy: 0.9910 - val_loss: 0.4315 - val_accuracy: 0.9473
#
# Epoch 00179: val_loss did not improve from 0.17014
# Epoch 180/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0240 - accuracy: 0.9906 - val_loss: 0.4463 - val_accuracy: 0.9461
#
# Epoch 00180: val_loss did not improve from 0.17014
# Epoch 181/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.4350 - val_accuracy: 0.9485
#
# Epoch 00181: val_loss did not improve from 0.17014
# Epoch 182/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9920 - val_loss: 0.4260 - val_accuracy: 0.9498
#
# Epoch 00182: val_loss did not improve from 0.17014
# Epoch 183/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0214 - accuracy: 0.9923 - val_loss: 0.4377 - val_accuracy: 0.9500
#
# Epoch 00183: val_loss did not improve from 0.17014
# Epoch 184/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.4222 - val_accuracy: 0.9483
#
# Epoch 00184: val_loss did not improve from 0.17014
# Epoch 185/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0232 - accuracy: 0.9910 - val_loss: 0.4305 - val_accuracy: 0.9475
#
# Epoch 00185: val_loss did not improve from 0.17014
# Epoch 186/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0266 - accuracy: 0.9903 - val_loss: 0.4184 - val_accuracy: 0.9497
#
# Epoch 00186: val_loss did not improve from 0.17014
# Epoch 187/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9928 - val_loss: 0.4428 - val_accuracy: 0.9461
#
# Epoch 00187: val_loss did not improve from 0.17014
# Epoch 188/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9914 - val_loss: 0.4256 - val_accuracy: 0.9479
#
# Epoch 00188: val_loss did not improve from 0.17014
# Epoch 189/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0296 - accuracy: 0.9902 - val_loss: 0.3903 - val_accuracy: 0.9514
#
# Epoch 00189: val_loss did not improve from 0.17014
# Epoch 190/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.4263 - val_accuracy: 0.9485
#
# Epoch 00190: val_loss did not improve from 0.17014
# Epoch 191/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 0.4193 - val_accuracy: 0.9492
#
# Epoch 00191: val_loss did not improve from 0.17014
# Epoch 192/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.4703 - val_accuracy: 0.9489
#
# Epoch 00192: val_loss did not improve from 0.17014
# Epoch 193/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.4575 - val_accuracy: 0.9481
#
# Epoch 00193: val_loss did not improve from 0.17014
# Epoch 194/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.4581 - val_accuracy: 0.9463
#
# Epoch 00194: val_loss did not improve from 0.17014
# Epoch 195/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.4246 - val_accuracy: 0.9478
#
# Epoch 00195: val_loss did not improve from 0.17014
# Epoch 196/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9912 - val_loss: 0.4839 - val_accuracy: 0.9480
#
# Epoch 00196: val_loss did not improve from 0.17014
# Epoch 197/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.4709 - val_accuracy: 0.9509
#
# Epoch 00197: val_loss did not improve from 0.17014
# Epoch 198/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0316 - accuracy: 0.9892 - val_loss: 0.4041 - val_accuracy: 0.9455
#
# Epoch 00198: val_loss did not improve from 0.17014
# Epoch 199/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0223 - accuracy: 0.9919 - val_loss: 0.4149 - val_accuracy: 0.9495
#
# Epoch 00199: val_loss did not improve from 0.17014
# Epoch 200/200
# 581/581 [==============================] - 4s 6ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.3919 - val_accuracy: 0.9471
#
# Epoch 00200: val_loss did not improve from 0.17014

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 249/249 [==============================] - 1s 3ms/step - loss: 0.1701 - accuracy: 0.9464
# Overall CNN Accuracy: 0.9463904500007629
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9464          |
# | Validation loss               | 0.1701          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([10,  0, 10, ...,  0, 10,  0], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([10,  0, 10, ...,  0, 10,  0], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 7965
# 7965

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Benign' 'Benign' 'Ransomware' ... 'Benign' 'Benign' 'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 14012

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +------------------------------------------------+
# |               Performance of CNN               |
# +----------------------------------+-------------+
# | Metric                           | Performance |
# +----------------------------------+-------------+
# | True Positive Rate               | 0.9808      |
# | Accuracy                         | 0.9832      |
# | F1 Score                         | 0.9839      |
# | Matthews Correlation Coefficient | 0.9663      |
# +----------------------------------+-------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)
