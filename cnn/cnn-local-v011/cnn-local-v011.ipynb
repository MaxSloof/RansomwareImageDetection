# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# Uses rgb, 64x64 images with LeakyReLU activation.
#
# Includes weights for all classes to overcome unbalanced data

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 50

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 1

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cnn"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cnn/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 10 matches(es) found
# --------------
# New folder name: cnn-local-v011
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/thesis_data"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 26548 images belonging to 11 classes.

# %% [markdown]
# **Automatic reverse weight calculation.**
#
# The weight is determined by how well respresented the class is in the dataset; the less represented, the higher the weigth. This way of calculating weights aims to overcome the unbalanced data. The 'Adam' optimizer is not affected by the weights like other optimizer would be

# %%
distr = (sum(labels)/labels.shape[0])
weights = (wf/distr)/(1-distr)

# %%
class_weight = {0: weights[0], 1: weights[1], 2: weights[2], 3: weights[3], 4: weights[4], 5: weights[5],
               6: weights[6], 7: weights[7], 8: weights[8], 9: weights[9], 10: weights[10]}

# %%
print(class_weight)
# Out:
# {0: 12.008085, 1: 10.935036, 2: 32.788494, 3: 32.675064, 4: 40.768326, 5: 19.42988, 6: 28.83627, 7: 19.021067, 8: 41.994156, 9: 51.11094, 10: 4.0124025}

# %%
(max(weights)-min(weights))/max(weights)
# Out:
# 0.9214962

# %%
weights[10]/sum(weights)
# Out:
# 0.013667165272037646

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9,
#  'benign': 10}

# %%
imgs.shape
# Out:
# (26548, 64, 64, 1)

# %%
labels.shape
# Out:
# (26548, 11)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (7965, 11)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 18583 | Shape of training data (18583, 64, 64, 1)
# Size of training data: 7965  | Shape of training data (7965, 64, 64, 1)
# Shape of training labels (18583, 11)
# Shape of training labels (7965, 11)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# We want **11** classes

# %%
num_classes = 11
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  11

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='LeakyReLU'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='LeakyReLU'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='LeakyReLU'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 2940)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               376448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_2 (Dense)              (None, 11)                561
# =================================================================
# Total params: 387,824
# Trainable params: 387,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint],
    class_weight=class_weight) # The actual computation of the CNN
# Out:
# WARNING:tensorflow:From C:\Users\Max\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/50
# 581/581 [==============================] - 7s 7ms/step - loss: 11.7484 - accuracy: 0.7716 - val_loss: 0.4394 - val_accuracy: 0.8780
#
# Epoch 00001: val_loss improved from inf to 0.43939, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 2/50
# 581/581 [==============================] - 4s 6ms/step - loss: 7.5925 - accuracy: 0.8616 - val_loss: 0.5160 - val_accuracy: 0.8562
#
# Epoch 00002: val_loss did not improve from 0.43939
# Epoch 3/50
# 581/581 [==============================] - 4s 6ms/step - loss: 6.2338 - accuracy: 0.8855 - val_loss: 0.3057 - val_accuracy: 0.9032
#
# Epoch 00003: val_loss improved from 0.43939 to 0.30572, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 4/50
# 581/581 [==============================] - 4s 6ms/step - loss: 5.4230 - accuracy: 0.8963 - val_loss: 0.2527 - val_accuracy: 0.9184
#
# Epoch 00004: val_loss improved from 0.30572 to 0.25268, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 5/50
# 581/581 [==============================] - 3s 6ms/step - loss: 4.7823 - accuracy: 0.9045 - val_loss: 0.2921 - val_accuracy: 0.9122
#
# Epoch 00005: val_loss did not improve from 0.25268
# Epoch 6/50
# 581/581 [==============================] - 4s 6ms/step - loss: 4.1861 - accuracy: 0.9141 - val_loss: 0.2397 - val_accuracy: 0.9232
#
# Epoch 00006: val_loss improved from 0.25268 to 0.23969, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 7/50
# 581/581 [==============================] - 3s 6ms/step - loss: 3.8428 - accuracy: 0.9217 - val_loss: 0.2801 - val_accuracy: 0.9151
#
# Epoch 00007: val_loss did not improve from 0.23969
# Epoch 8/50
# 581/581 [==============================] - 4s 6ms/step - loss: 3.6039 - accuracy: 0.9239 - val_loss: 0.2270 - val_accuracy: 0.9336
#
# Epoch 00008: val_loss improved from 0.23969 to 0.22705, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 9/50
# 581/581 [==============================] - 4s 6ms/step - loss: 3.1399 - accuracy: 0.9336 - val_loss: 0.2312 - val_accuracy: 0.9323
#
# Epoch 00009: val_loss did not improve from 0.22705
# Epoch 10/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.8117 - accuracy: 0.9355 - val_loss: 0.2679 - val_accuracy: 0.9209
#
# Epoch 00010: val_loss did not improve from 0.22705
# Epoch 11/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.6949 - accuracy: 0.9408 - val_loss: 0.2153 - val_accuracy: 0.9361
#
# Epoch 00011: val_loss improved from 0.22705 to 0.21528, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 12/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.6984 - accuracy: 0.9377 - val_loss: 0.2198 - val_accuracy: 0.9399
#
# Epoch 00012: val_loss did not improve from 0.21528
# Epoch 13/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.5301 - accuracy: 0.9445 - val_loss: 0.2322 - val_accuracy: 0.9321
#
# Epoch 00013: val_loss did not improve from 0.21528
# Epoch 14/50
# 581/581 [==============================] - 4s 7ms/step - loss: 2.4691 - accuracy: 0.9417 - val_loss: 0.2126 - val_accuracy: 0.9397
#
# Epoch 00014: val_loss improved from 0.21528 to 0.21256, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v011\model.h5
# Epoch 15/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.4316 - accuracy: 0.9445 - val_loss: 0.2911 - val_accuracy: 0.9183
#
# Epoch 00015: val_loss did not improve from 0.21256
# Epoch 16/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.2217 - accuracy: 0.9460 - val_loss: 0.2195 - val_accuracy: 0.9343
#
# Epoch 00016: val_loss did not improve from 0.21256
# Epoch 17/50
# 581/581 [==============================] - 4s 7ms/step - loss: 2.1289 - accuracy: 0.9490 - val_loss: 0.2249 - val_accuracy: 0.9315
#
# Epoch 00017: val_loss did not improve from 0.21256
# Epoch 18/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.9275 - accuracy: 0.9523 - val_loss: 0.2196 - val_accuracy: 0.9389
#
# Epoch 00018: val_loss did not improve from 0.21256
# Epoch 19/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.9699 - accuracy: 0.9528 - val_loss: 0.2277 - val_accuracy: 0.9368
#
# Epoch 00019: val_loss did not improve from 0.21256
# Epoch 20/50
# 581/581 [==============================] - 4s 6ms/step - loss: 2.0327 - accuracy: 0.9511 - val_loss: 0.2371 - val_accuracy: 0.9368
#
# Epoch 00020: val_loss did not improve from 0.21256
# Epoch 21/50
# 581/581 [==============================] - 3s 6ms/step - loss: 2.1629 - accuracy: 0.9506 - val_loss: 0.2440 - val_accuracy: 0.9345
#
# Epoch 00021: val_loss did not improve from 0.21256
# Epoch 22/50
# 581/581 [==============================] - 3s 6ms/step - loss: 1.8377 - accuracy: 0.9549 - val_loss: 0.2563 - val_accuracy: 0.9273
#
# Epoch 00022: val_loss did not improve from 0.21256
# Epoch 23/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.8162 - accuracy: 0.9556 - val_loss: 0.2496 - val_accuracy: 0.9345
#
# Epoch 00023: val_loss did not improve from 0.21256
# Epoch 24/50
# 581/581 [==============================] - 3s 6ms/step - loss: 1.8073 - accuracy: 0.9574 - val_loss: 0.2307 - val_accuracy: 0.9353
#
# Epoch 00024: val_loss did not improve from 0.21256
# Epoch 25/50
# 581/581 [==============================] - 3s 6ms/step - loss: 1.7429 - accuracy: 0.9558 - val_loss: 0.2769 - val_accuracy: 0.9282
#
# Epoch 00025: val_loss did not improve from 0.21256
# Epoch 26/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.6673 - accuracy: 0.9574 - val_loss: 0.2349 - val_accuracy: 0.9371
#
# Epoch 00026: val_loss did not improve from 0.21256
# Epoch 27/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.6962 - accuracy: 0.9597 - val_loss: 0.2494 - val_accuracy: 0.9315
#
# Epoch 00027: val_loss did not improve from 0.21256
# Epoch 28/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.6455 - accuracy: 0.9595 - val_loss: 0.2503 - val_accuracy: 0.9424
#
# Epoch 00028: val_loss did not improve from 0.21256
# Epoch 29/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.5312 - accuracy: 0.9606 - val_loss: 0.2418 - val_accuracy: 0.9412
#
# Epoch 00029: val_loss did not improve from 0.21256
# Epoch 30/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.6355 - accuracy: 0.9609 - val_loss: 0.2588 - val_accuracy: 0.9318
#
# Epoch 00030: val_loss did not improve from 0.21256
# Epoch 31/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.5631 - accuracy: 0.9606 - val_loss: 0.2728 - val_accuracy: 0.9332
#
# Epoch 00031: val_loss did not improve from 0.21256
# Epoch 32/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.5638 - accuracy: 0.9634 - val_loss: 0.2483 - val_accuracy: 0.9414
#
# Epoch 00032: val_loss did not improve from 0.21256
# Epoch 33/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.6111 - accuracy: 0.9593 - val_loss: 0.2645 - val_accuracy: 0.9284
#
# Epoch 00033: val_loss did not improve from 0.21256
# Epoch 34/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.5644 - accuracy: 0.9630 - val_loss: 0.2429 - val_accuracy: 0.9389
#
# Epoch 00034: val_loss did not improve from 0.21256
# Epoch 35/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.5099 - accuracy: 0.9639 - val_loss: 0.3185 - val_accuracy: 0.9232
#
# Epoch 00035: val_loss did not improve from 0.21256
# Epoch 36/50
# 581/581 [==============================] - 3s 6ms/step - loss: 1.4491 - accuracy: 0.9638 - val_loss: 0.2805 - val_accuracy: 0.9268
#
# Epoch 00036: val_loss did not improve from 0.21256
# Epoch 37/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.4430 - accuracy: 0.9647 - val_loss: 0.2456 - val_accuracy: 0.9376
#
# Epoch 00037: val_loss did not improve from 0.21256
# Epoch 38/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.4992 - accuracy: 0.9641 - val_loss: 0.2654 - val_accuracy: 0.9371
#
# Epoch 00038: val_loss did not improve from 0.21256
# Epoch 39/50
# 581/581 [==============================] - 3s 6ms/step - loss: 1.4046 - accuracy: 0.9651 - val_loss: 0.2550 - val_accuracy: 0.9384
#
# Epoch 00039: val_loss did not improve from 0.21256
# Epoch 40/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.3498 - accuracy: 0.9669 - val_loss: 0.2764 - val_accuracy: 0.9377
#
# Epoch 00040: val_loss did not improve from 0.21256
# Epoch 41/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.5447 - accuracy: 0.9628 - val_loss: 0.2534 - val_accuracy: 0.9405
#
# Epoch 00041: val_loss did not improve from 0.21256
# Epoch 42/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.3627 - accuracy: 0.9637 - val_loss: 0.2531 - val_accuracy: 0.9417
#
# Epoch 00042: val_loss did not improve from 0.21256
# Epoch 43/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.3274 - accuracy: 0.9679 - val_loss: 0.2504 - val_accuracy: 0.9410
#
# Epoch 00043: val_loss did not improve from 0.21256
# Epoch 44/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.2959 - accuracy: 0.9683 - val_loss: 0.2670 - val_accuracy: 0.9368
#
# Epoch 00044: val_loss did not improve from 0.21256
# Epoch 45/50
# 581/581 [==============================] - 4s 7ms/step - loss: 1.2910 - accuracy: 0.9677 - val_loss: 0.2695 - val_accuracy: 0.9416
#
# Epoch 00045: val_loss did not improve from 0.21256
# Epoch 46/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.2376 - accuracy: 0.9705 - val_loss: 0.2629 - val_accuracy: 0.9396
#
# Epoch 00046: val_loss did not improve from 0.21256
# Epoch 47/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.3627 - accuracy: 0.9681 - val_loss: 0.2762 - val_accuracy: 0.9350
#
# Epoch 00047: val_loss did not improve from 0.21256
# Epoch 48/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.4103 - accuracy: 0.9650 - val_loss: 0.2754 - val_accuracy: 0.9330
#
# Epoch 00048: val_loss did not improve from 0.21256
# Epoch 49/50
# 581/581 [==============================] - 4s 6ms/step - loss: 1.1874 - accuracy: 0.9707 - val_loss: 0.2684 - val_accuracy: 0.9400
#
# Epoch 00049: val_loss did not improve from 0.21256
# Epoch 50/50
# 581/581 [==============================] - 3s 6ms/step - loss: 1.1767 - accuracy: 0.9703 - val_loss: 0.2780 - val_accuracy: 0.9443
#
# Epoch 00050: val_loss did not improve from 0.21256

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 249/249 [==============================] - 1s 3ms/step - loss: 0.2126 - accuracy: 0.9397
# Overall CNN Accuracy: 0.9397363662719727
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9397          |
# | Validation loss               | 0.2126          |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([10, 10, 10, ..., 10, 10,  1], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([10, 10, 10, ..., 10, 10,  1], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 7965
# 7965

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Ransomware' 'Ransomware' 'Benign' ... 'Ransomware' 'Benign' 'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 14012

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)
# Out:
# +------------------------------------------------+
# |               Performance of CNN               |
# +----------------------------------+-------------+
# | Metric                           | Performance |
# +----------------------------------+-------------+
# | True Positive Rate               | 0.9854      |
# | Accuracy                         | 0.98        |
# | F1 Score                         | 0.9813      |
# | Matthews Correlation Coefficient | 0.96        |
# +----------------------------------+-------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)
