# %% [markdown]
# # Convolutional Neural Network (1of1)

# %% [markdown]
# **Notes about this specific notebook**
#
# This notebook only ran on the ransomware images!
#
# Uses rgb, 64x64 images with LeakyReLU activation.
#
# Weights were not included

# %% [markdown]
# # CHANGE

# %% [markdown]
# _____________________________________________________________________

# %%
# Image size (height x width)
ih = 64
iw = 64

# Grayscale or RGB
ch = 'grayscale'

# Batch size
batch_size = 40000

# Number of epochs
epoch_t = 50

# Where computation is performed: Kaggle (0) or Local (1)
cenv = 1

# Division of the training vs. test set (in %)
test_size = 0.3

# Weight factor (1 is perfect reverse)
wf = 0.5

# %% [markdown]
# _____________________________________________________________________

# %%
if cenv == 0:
    print("Computation environment: Kaggle")
if cenv == 1:
    print("Computation environment: Local")
# Out:
# Computation environment: Local

# %%
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.utils import class_weight
from sklearn import metrics
import sys
import os
from math import log
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
is_cuda_gpu_available = tf.config.list_physical_devices('GPU')
print(is_cuda_gpu_available)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
im_si = (ih, iw)

if(ch == 'rgb'):
    chnum = 3
elif(ch == 'grayscale'):
    chnum = 1

# %% [markdown]
# Create new directory for saving output files

# %%
if cenv == 1:
    file_exists = []
    vnum = 1
    dir = "C:/Users/Max/Documents/GitHub/cnn"
    for files in os.listdir(dir):
        if "cnn" in files:
            try:
                vnum = max(vnum, int(files[-3:]))
            except: 
                continue
            new_vnum = vnum + 1
            file_exists.append(True)
        else: 
            file_exists.append(False)
    # If this is the first notebook you want to save, a new folder will be created with version #001
    if sum(file_exists) == 0:
        new_vnum = 1
        print("No matches found")

    else: 
        print(f"{sum(file_exists)} matches(es) found")
        print("--------------")

    # Print new folder name
    print(f"New folder name: cnn-local-v{new_vnum:03}")
    print("--------------")
    
    # Create new folder with the name of the notebook and the version number
    new_dir = f"/Users/Max/Documents/GitHub/cnn/cnn-local-v{new_vnum:03}"
    os.makedirs(new_dir)
# Out:
# 12 matches(es) found
# --------------
# New folder name: cnn-local-v013
# --------------

# %% [markdown]
# **Data**

# %%
if cenv == 0:
    path_root = "/kaggle/input/thesis-data"

if cenv == 1:
    path_root = "C:/Users/Max/Documents/image_data/data_wo_benign"

# %%
batches = ImageDataGenerator().flow_from_directory(
    directory     = path_root, 
    color_mode    = ch, 
    target_size   = (ih,iw), 
    batch_size    = batch_size,
    interpolation = 'bicubic'
)
imgs, labels = next(batches)
# Out:
# Found 12536 images belonging to 10 classes.

# %%
batches.class_indices
# Out:
# {'BetterSurf': 0,
#  'Eksor.A': 1,
#  'Obfuscator.AFQ': 2,
#  'Occamy.C': 3,
#  'OnLineGames.CTB': 4,
#  'Reveton.A': 5,
#  'Sfone': 6,
#  'VB.IL': 7,
#  'Zbot': 8,
#  'Zbot!CI': 9}

# %%
imgs.shape
# Out:
# (12536, 64, 64, 1)

# %%
labels.shape
# Out:
# (12536, 10)

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != chnum):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,50):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], cmap = 'gray',interpolation=None if interp else 'none')
        
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()

# %%
perc = (sum(labels)/labels.shape[0])*100
plt.xticks(rotation='vertical')
plt.bar(classes,perc)

if cenv == 0:
    plt.savefig("multi_data_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/multi_data_dist.png", bbox_inches = 'tight')

# %%
# Train and Test
X_train, X_test, y_train, y_test = train_test_split(imgs/255.,labels, test_size=test_size)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (3761, 10)

# %%
trainsize = len(X_train)
testsize = len(X_test)

print(f"Size of training data: {trainsize} | Shape of training data {X_train.shape}")
print(f"Size of training data: {testsize}  | Shape of training data {X_test.shape}")
print(f"Shape of training labels {y_train.shape}")
print(f"Shape of training labels {y_test.shape}")
# Out:
# Size of training data: 8775 | Shape of training data (8775, 64, 64, 1)
# Size of training data: 3761  | Shape of training data (3761, 64, 64, 1)
# Shape of training labels (8775, 10)
# Shape of training labels (3761, 10)

# %%
def my_fmt(x):
    return '{:.1f}%\n({:.0f})'.format(x, total*x/100)
total = trainsize + testsize

# %%
plt.pie(
    [trainsize, testsize], 
    labels = ["Training", "Validation"], 
    startangle=90, 
    counterclock=False, 
    autopct=my_fmt,
    colors = ['gray', 'silver']
)

plt.title("Training and validation data distribution")

if cenv == 0:
    plt.savefig("train_test_dist.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/train_test_dist.png", bbox_inches = 'tight')

# %% [markdown]
# # Convolutional Neural Network
# We will now build our **CNN** model using Keras. This model will have the following layers :
#
# * **Convolutional Layer** : 30 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **Convolutional Layer** : 15 filters, (3 * 3) kernel size
# * **Max Pooling Layer** : (2 * 2) pool size
# * **DropOut Layer** : Dropping 25% of neurons.
# * **Flatten Layer**
# * **Dense/Fully Connected Layer** : 128 Neurons, Relu activation function
# * **DropOut Layer** : Dropping 50% of neurons.
# * **Dense/Fully Connected Layer** : 50 Neurons, Softmax activation function
# * **Dense/Fully Connected Layer** : num_class Neurons, Softmax activation function
#
# **Input shape** : 64 * 64* 3

# %%
import keras
from keras.models import Sequential, Input, Model, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Retrieve the number of classes in our dataset

# %%
num_classes = labels[1].shape[0]
print("The number of classes in our dataset: ", num_classes)
# Out:
# The number of classes in our dataset:  10

# %% [markdown]
# Building the model

# %%
def malware_model():
    Malware_model = Sequential()
    Malware_model.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(ih,iw,chnum)))

    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Conv2D(15, (3, 3), activation='LeakyReLU'))
    Malware_model.add(MaxPooling2D(pool_size=(2, 2)))
    Malware_model.add(Dropout(0.25))
    Malware_model.add(Flatten())
    Malware_model.add(Dense(128, activation='LeakyReLU'))
    Malware_model.add(Dropout(0.5))
    Malware_model.add(Dense(50, activation='LeakyReLU'))
    Malware_model.add(Dense(num_classes, activation='softmax'))
    Malware_model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return Malware_model

# %%
Malware_model = malware_model()
Malware_model.summary() # Overview of the CNN model
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 62, 62, 30)        300
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2940)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               376448
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                510
# =================================================================
# Total params: 387,773
# Trainable params: 387,773
# Non-trainable params: 0
# _________________________________________________________________

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
if cenv == 0:
    checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
if cenv == 1:
    checkpoint = ModelCheckpoint(f'{new_dir}/model.h5', verbose=1, save_best_only=True)

# %%
history = Malware_model.fit(
    X_train, 
    y_train, 
    validation_data=(X_test, y_test), 
    epochs=epoch_t,
    callbacks = [anne, checkpoint]) # The actual computation of the CNN
# Out:
# Epoch 1/50
# 275/275 [==============================] - 2s 7ms/step - loss: 0.7299 - accuracy: 0.7516 - val_loss: 0.4452 - val_accuracy: 0.8439
#
# Epoch 00001: val_loss improved from inf to 0.44522, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 2/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.4332 - accuracy: 0.8539 - val_loss: 0.3440 - val_accuracy: 0.8881
#
# Epoch 00002: val_loss improved from 0.44522 to 0.34402, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 3/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.3564 - accuracy: 0.8803 - val_loss: 0.3244 - val_accuracy: 0.8995
#
# Epoch 00003: val_loss improved from 0.34402 to 0.32438, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 4/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.3127 - accuracy: 0.8968 - val_loss: 0.2999 - val_accuracy: 0.9053
#
# Epoch 00004: val_loss improved from 0.32438 to 0.29989, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 5/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.2892 - accuracy: 0.9064 - val_loss: 0.2953 - val_accuracy: 0.9093
#
# Epoch 00005: val_loss improved from 0.29989 to 0.29528, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 6/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.2599 - accuracy: 0.9149 - val_loss: 0.2771 - val_accuracy: 0.9144
#
# Epoch 00006: val_loss improved from 0.29528 to 0.27706, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 7/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.2410 - accuracy: 0.9186 - val_loss: 0.2796 - val_accuracy: 0.9176
#
# Epoch 00007: val_loss did not improve from 0.27706
# Epoch 8/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.2228 - accuracy: 0.9244 - val_loss: 0.2773 - val_accuracy: 0.9194
#
# Epoch 00008: val_loss did not improve from 0.27706
# Epoch 9/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.2057 - accuracy: 0.9338 - val_loss: 0.2837 - val_accuracy: 0.9144
#
# Epoch 00009: val_loss did not improve from 0.27706
# Epoch 10/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1861 - accuracy: 0.9380 - val_loss: 0.2750 - val_accuracy: 0.9202
#
# Epoch 00010: val_loss improved from 0.27706 to 0.27504, saving model to /Users/Max/Documents/GitHub/cnn/cnn-local-v013\model.h5
# Epoch 11/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1727 - accuracy: 0.9435 - val_loss: 0.2873 - val_accuracy: 0.9213
#
# Epoch 00011: val_loss did not improve from 0.27504
# Epoch 12/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1660 - accuracy: 0.9452 - val_loss: 0.2760 - val_accuracy: 0.9229
#
# Epoch 00012: val_loss did not improve from 0.27504
# Epoch 13/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1589 - accuracy: 0.9459 - val_loss: 0.2859 - val_accuracy: 0.9248
#
# Epoch 00013: val_loss did not improve from 0.27504
# Epoch 14/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1489 - accuracy: 0.9497 - val_loss: 0.2940 - val_accuracy: 0.9261
#
# Epoch 00014: val_loss did not improve from 0.27504
# Epoch 15/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1493 - accuracy: 0.9503 - val_loss: 0.2947 - val_accuracy: 0.9181
#
# Epoch 00015: val_loss did not improve from 0.27504
# Epoch 16/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1388 - accuracy: 0.9542 - val_loss: 0.3000 - val_accuracy: 0.9221
#
# Epoch 00016: val_loss did not improve from 0.27504
# Epoch 17/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1246 - accuracy: 0.9566 - val_loss: 0.3097 - val_accuracy: 0.9208
#
# Epoch 00017: val_loss did not improve from 0.27504
# Epoch 18/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1274 - accuracy: 0.9566 - val_loss: 0.3077 - val_accuracy: 0.9218
#
# Epoch 00018: val_loss did not improve from 0.27504
# Epoch 19/50
# 275/275 [==============================] - 2s 7ms/step - loss: 0.1188 - accuracy: 0.9591 - val_loss: 0.3263 - val_accuracy: 0.9237
#
# Epoch 00019: val_loss did not improve from 0.27504
# Epoch 20/50
# 275/275 [==============================] - 2s 7ms/step - loss: 0.1269 - accuracy: 0.9578 - val_loss: 0.3063 - val_accuracy: 0.9216
#
# Epoch 00020: val_loss did not improve from 0.27504
# Epoch 21/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1154 - accuracy: 0.9601 - val_loss: 0.3178 - val_accuracy: 0.9229
#
# Epoch 00021: val_loss did not improve from 0.27504
# Epoch 22/50
# 275/275 [==============================] - 2s 7ms/step - loss: 0.1091 - accuracy: 0.9622 - val_loss: 0.3457 - val_accuracy: 0.9208
#
# Epoch 00022: val_loss did not improve from 0.27504
# Epoch 23/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1068 - accuracy: 0.9632 - val_loss: 0.3417 - val_accuracy: 0.9181
#
# Epoch 00023: val_loss did not improve from 0.27504
# Epoch 24/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1065 - accuracy: 0.9633 - val_loss: 0.3339 - val_accuracy: 0.9205
#
# Epoch 00024: val_loss did not improve from 0.27504
# Epoch 25/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1104 - accuracy: 0.9613 - val_loss: 0.3660 - val_accuracy: 0.9176
#
# Epoch 00025: val_loss did not improve from 0.27504
# Epoch 26/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1052 - accuracy: 0.9648 - val_loss: 0.3602 - val_accuracy: 0.9226
#
# Epoch 00026: val_loss did not improve from 0.27504
# Epoch 27/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1022 - accuracy: 0.9643 - val_loss: 0.3476 - val_accuracy: 0.9218
#
# Epoch 00027: val_loss did not improve from 0.27504
# Epoch 28/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1019 - accuracy: 0.9659 - val_loss: 0.3428 - val_accuracy: 0.9216
#
# Epoch 00028: val_loss did not improve from 0.27504
# Epoch 29/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1038 - accuracy: 0.9635 - val_loss: 0.3602 - val_accuracy: 0.9184
#
# Epoch 00029: val_loss did not improve from 0.27504
# Epoch 30/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.1005 - accuracy: 0.9652 - val_loss: 0.3492 - val_accuracy: 0.9250
#
# Epoch 00030: val_loss did not improve from 0.27504
# Epoch 31/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0958 - accuracy: 0.9672 - val_loss: 0.3775 - val_accuracy: 0.9210
#
# Epoch 00031: val_loss did not improve from 0.27504
# Epoch 32/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0946 - accuracy: 0.9660 - val_loss: 0.3723 - val_accuracy: 0.9192
#
# Epoch 00032: val_loss did not improve from 0.27504
# Epoch 33/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0951 - accuracy: 0.9654 - val_loss: 0.3817 - val_accuracy: 0.9200
#
# Epoch 00033: val_loss did not improve from 0.27504
# Epoch 34/50
# 275/275 [==============================] - 2s 7ms/step - loss: 0.0972 - accuracy: 0.9650 - val_loss: 0.3827 - val_accuracy: 0.9194
#
# Epoch 00034: val_loss did not improve from 0.27504
# Epoch 35/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0930 - accuracy: 0.9688 - val_loss: 0.3954 - val_accuracy: 0.9213
#
# Epoch 00035: val_loss did not improve from 0.27504
# Epoch 36/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0921 - accuracy: 0.9674 - val_loss: 0.3784 - val_accuracy: 0.9232
#
# Epoch 00036: val_loss did not improve from 0.27504
# Epoch 37/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0943 - accuracy: 0.9681 - val_loss: 0.3895 - val_accuracy: 0.9216
#
# Epoch 00037: val_loss did not improve from 0.27504
# Epoch 38/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0811 - accuracy: 0.9708 - val_loss: 0.3826 - val_accuracy: 0.9147
#
# Epoch 00038: val_loss did not improve from 0.27504
# Epoch 39/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0852 - accuracy: 0.9704 - val_loss: 0.3944 - val_accuracy: 0.9136
#
# Epoch 00039: val_loss did not improve from 0.27504
# Epoch 40/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0867 - accuracy: 0.9693 - val_loss: 0.4062 - val_accuracy: 0.9213
#
# Epoch 00040: val_loss did not improve from 0.27504
# Epoch 41/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0818 - accuracy: 0.9722 - val_loss: 0.4465 - val_accuracy: 0.9213
#
# Epoch 00041: val_loss did not improve from 0.27504
# Epoch 42/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0872 - accuracy: 0.9708 - val_loss: 0.3860 - val_accuracy: 0.9200
#
# Epoch 00042: val_loss did not improve from 0.27504
# Epoch 43/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0857 - accuracy: 0.9701 - val_loss: 0.4105 - val_accuracy: 0.9210
#
# Epoch 00043: val_loss did not improve from 0.27504
# Epoch 44/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0743 - accuracy: 0.9745 - val_loss: 0.4086 - val_accuracy: 0.9232
#
# Epoch 00044: val_loss did not improve from 0.27504
# Epoch 45/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0816 - accuracy: 0.9720 - val_loss: 0.4194 - val_accuracy: 0.9213
#
# Epoch 00045: val_loss did not improve from 0.27504
# Epoch 46/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0804 - accuracy: 0.9717 - val_loss: 0.3949 - val_accuracy: 0.9152
#
# Epoch 00046: val_loss did not improve from 0.27504
# Epoch 47/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0845 - accuracy: 0.9716 - val_loss: 0.3885 - val_accuracy: 0.9224
#
# Epoch 00047: val_loss did not improve from 0.27504
# Epoch 48/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0759 - accuracy: 0.9725 - val_loss: 0.4215 - val_accuracy: 0.9160
#
# Epoch 00048: val_loss did not improve from 0.27504
# Epoch 49/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0732 - accuracy: 0.9748 - val_loss: 0.4098 - val_accuracy: 0.9216
#
# Epoch 00049: val_loss did not improve from 0.27504
# Epoch 50/50
# 275/275 [==============================] - 2s 6ms/step - loss: 0.0727 - accuracy: 0.9754 - val_loss: 0.4224 - val_accuracy: 0.9178
#
# Epoch 00050: val_loss did not improve from 0.27504

# %% [markdown]
# # Evaluating performance

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, accuracy_score
from prettytable import PrettyTable, MSWORD_FRIENDLY

# %%
if cenv == 0:
    best_model = load_model("/kaggle/working/model.h5")
if cenv == 1:
    best_model = load_model(f"{new_dir}/model.h5")

# %%
scores = best_model.evaluate(X_test, y_test) # Testing the CNN on the test set
print(f"Overall CNN Accuracy: {scores[1]}\n(The number of correct predictions divided by the number of total predictions)")
# Out:
# 118/118 [==============================] - 0s 3ms/step - loss: 0.2750 - accuracy: 0.9202
# Overall CNN Accuracy: 0.920233964920044
# (The number of correct predictions divided by the number of total predictions)

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['Valididation accuracy', round(scores[1],4)])
t.add_row(['Validation loss', round(scores[0],4)])
t.header = True
t.align = "l"
t.title = "Performance of multi-class classification - CNN"
print(t)
# Out:
# +-------------------------------------------------+
# | Performance of multi-class classification - CNN |
# +-------------------------------+-----------------+
# | Metric                        | Performance     |
# +-------------------------------+-----------------+
# | Valididation accuracy         | 0.9202          |
# | Validation loss               | 0.275           |
# +-------------------------------+-----------------+

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('multi_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/multi_performance_table.txt', 'w') as f:
        f.write(table)

# %% [markdown]
# # Evaluating overfitting and other model performance measures

# %%
def eval_metric(model, history, metric_name):
    '''
    Function to evaluate a trained model on a chosen metric. 
    Training and validation metric are plotted in a
    line chart for each epoch.
    
    Parameters:
        history : model training history
        metric_name : loss or accuracy
    Output:
        line chart with epochs of x-axis and metric on
        y-axis
    '''
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]
    e = range(1, epoch_t + 1)
    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    if cenv == 0:
        plt.savefig(f"cnn_model_{metric_name}.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/cnn_model_{metric_name}.png", bbox_inches = 'tight')

# %%
eval_metric(Malware_model, history, 'loss')

# %%
eval_metric(Malware_model, history, 'accuracy')

# %% [markdown]
# # Confusion Matrix
# Analysing the results

# %%
y_pred = np.argmax(Malware_model.predict(X_test), axis=-1)
y_pred
# Out:
# array([1, 4, 1, ..., 0, 1, 0], dtype=int64)

# %%
y_test2 = np.argmax(y_test, axis=1)
y_test2
# Out:
# array([1, 4, 1, ..., 0, 1, 0], dtype=int64)

# %%
c_matrix = metrics.confusion_matrix(y_test2, y_pred)
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("multi_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/multi_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %% [markdown]
# # Detection Measurement
# y_predbin and y_testbin are the binary classification arrays. 0 = ransomware and 1 = benign

# %%
y_predbin = [] 
y_truebin = []
for count, value in enumerate(y_test2):
    if y_test2[count] in range(10): # range(10) is 0 to 9
        y_truebin.append(0)
    else: y_truebin.append(1)
    
    if y_pred[count] in range(10):
        y_predbin.append(0)
    else: y_predbin.append(1)
    
    continue
print(len(y_truebin))
print(len(y_predbin))
# Out:
# 3761
# 3761

# %%
binary_labels = np.array([])
for count, value in enumerate(labels):
    if labels[count].argmax() in range(10): # range(10) is 0 to 9
        binary_labels = np.append(binary_labels, "Ransomware")
    else: binary_labels = np.append(binary_labels, "Benign")
    continue
print(binary_labels)
rw_count = np.count_nonzero(binary_labels == "Ransomware")
bn_count = np.count_nonzero(binary_labels == "Benign")
print(f"Ransomware Occurences: {rw_count}, Benign Occurences: {bn_count}")
# Out:
# ['Ransomware' 'Ransomware' 'Ransomware' ... 'Ransomware' 'Ransomware'
#  'Ransomware']
# Ransomware Occurences: 12536, Benign Occurences: 0

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_lab = ['Ransomware', 'Benign']
y_lab = [rw_count, bn_count]
ax.bar(x_lab, y_lab)
if cenv == 0:
    plt.savefig("data_dist.png.png", bbox_inches = 'tight')
if cenv == 1:
    plt.savefig(f"{new_dir}/bin_data_dist.png", bbox_inches = 'tight')

# %%
c_matrix_bin = metrics.confusion_matrix(y_truebin, y_predbin)
def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
   
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names_bin, columns=class_names_bin, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if cenv == 0:
        plt.savefig("bin_class_cmatrix.png", bbox_inches = 'tight')
    if cenv == 1:
        plt.savefig(f"{new_dir}/bin_class_cmatrix.png", bbox_inches = 'tight')

# %%
class_names_bin= ("ransomware", "benign")
confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1674                 blocks = [
# -> 1675                     make_block(
#    1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2741
# -> 2742     return klass(values, ndim=ndim, placement=placement)
#    2743
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 1, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16476/3489594119.py in <module>
#       1 class_names_bin= ("ransomware", "benign")
# ----> 2 confusion_matrix_bin(c_matrix_bin, class_names_bin, figsize = (5,2), fontsize=10)
#
# ~\AppData\Local\Temp/ipykernel_16476/2541008972.py in confusion_matrix_bin(confusion_matrix, class_names_bin, figsize, fontsize)
#       2 def confusion_matrix_bin(confusion_matrix, class_names_bin, figsize = (5,2), fontsize=7):
#       3
# ----> 4     df_cm = pd.DataFrame(
#       5         confusion_matrix, index=class_names_bin, columns=class_names_bin,
#       6     )
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# ~\anaconda3\envs\master_thesis\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# ValueError: Shape of passed values is (1, 1), indices imply (2, 2)

# %% [markdown]
# **True Positive Rate**

# %%
TPR = c_matrix_bin[0,0]/(c_matrix_bin[0,0] + c_matrix_bin[0,1]) #True Positive Rate

# %% [markdown]
# **Accuracy**

# %%
ACC = accuracy_score(y_truebin, y_predbin) # Accuracy

# %% [markdown]
# **F1 Score**

# %%
F1 = f1_score(y_truebin, y_predbin, labels=0) # F1 Score

# %% [markdown]
# **Matthews Correlation Coefficient**

# %%
MCC = matthews_corrcoef(y_truebin, y_predbin) # Matthews Correlation Coefficient

# %% [markdown]
# **Show Performance of CNN**

# %%
t = PrettyTable(['Metric', 'Performance'])
t.add_row(['True Positive Rate', round(TPR,4)])
t.add_row(['Accuracy', round(ACC,4)])
t.add_row(['F1 Score', round(F1,4)])
t.add_row(['Matthews Correlation Coefficient', round(MCC,4)])
t.header = True
t.align = "l"
t.title = "Performance of CNN"
print(t)

# %%
# Saving PrettyTable
table = t.get_string()

if cenv == 0:
    with open('bin_performance_table.txt', 'w') as f:
        f.write(table)
if cenv == 1:
    with open(f'{new_dir}/bin_performance_table.txt', 'w') as f:
        f.write(table)
